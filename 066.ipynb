# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/066.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   537,502
# 2504                                    99,339
# 2505                                   137,959
# 2506                                   261,207
# 2507                                 1,383,562
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   537,502
# 2504                                    99,339
# 2505                                   137,959
# 2506                                   261,207
# 2507                                 1,383,562
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1  diff
# 0                                       42,214     0
# 1                                       58,500    -0
# 2                                       99,409     0
# 3                                       51,623     0
# 4                                       50,638    -0
# ...                                        ...   ...
# 2503                                   537,502     0
# 2504                                    99,339    -0
# 2505                                   137,959     0
# 2506                                   261,207    -0
# 2507                                 1,383,562     0
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           41,547     0
# 1                  14            1           59,347    -0
# 2                   9            1           99,121     0
# 3                  15            1           51,450     0
# 4                  15            0           51,060    -0
# ...               ...          ...              ...   ...
# 4650               15            0           46,740     0
# 4651                8            1          170,355    -0
# 4652                8            0           31,492     0
# 4653                8            0           66,290    -0
# 4654                9            1          146,419    -0
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.021988920978924558
# Fold 1 RMSLE for model2 = 0.015450859517853306
# Fold 1 RMSLE for model3 = 0.02343101777384949
# Fold 1 RMSLE for model4 = 0.018135718453352764
# Fold 1 RMSLE for ('model1', 'model2') = 0.01840005933492665
# Fold 1 RMSLE for ('model1', 'model3') = 0.02262182623831814
# Fold 1 RMSLE for ('model1', 'model4') = 0.019848037298783573
# Fold 1 RMSLE for ('model2', 'model3') = 0.019001068567774615
# Fold 1 RMSLE for ('model2', 'model4') = 0.016684044221293496
# Fold 1 RMSLE for ('model3', 'model4') = 0.020441348843128832
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.019928051006074848
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.018234004891368647
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.020903832385752788
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.018596119026737117
# Fold 1 RMSLE for all models ensemble = 0.019374088236233065
# Fold 1 best combination: model2 with RMSLE = 0.015450859517853306
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.015191979697453685
# Fold 2 RMSLE for model2 = 0.01157115410396825
# Fold 2 RMSLE for model3 = 0.016494694801334763
# Fold 2 RMSLE for model4 = 0.013141129705366903
# Fold 2 RMSLE for ('model1', 'model2') = 0.012545662321648415
# Fold 2 RMSLE for ('model1', 'model3') = 0.01558206035509386
# Fold 2 RMSLE for ('model1', 'model4') = 0.01390752579003787
# Fold 2 RMSLE for ('model2', 'model3') = 0.012789016026513762
# Fold 2 RMSLE for ('model2', 'model4') = 0.012082997984381932
# Fold 2 RMSLE for ('model3', 'model4') = 0.014136098109642357
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.013409159012715784
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.01269238565948103
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.014409241261627785
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.012731816271362219
# Fold 2 RMSLE for all models ensemble = 0.013212442177261446
# Fold 2 best combination: model2 with RMSLE = 0.01157115410396825
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.014882870764026685
# Fold 3 RMSLE for model2 = 0.010528973991620567
# Fold 3 RMSLE for model3 = 0.018129428785854843
# Fold 3 RMSLE for model4 = 0.012689396308899344
# Fold 3 RMSLE for ('model1', 'model2') = 0.0122976055797773
# Fold 3 RMSLE for ('model1', 'model3') = 0.01629378489040117
# Fold 3 RMSLE for ('model1', 'model4') = 0.013637733375114161
# Fold 3 RMSLE for ('model2', 'model3') = 0.013759517605198954
# Fold 3 RMSLE for ('model2', 'model4') = 0.011389551035688244
# Fold 3 RMSLE for ('model3', 'model4') = 0.015068796730676716
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.01399657135843275
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.012357557630970557
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.01491821600128007
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.01326609324401125
# Fold 3 RMSLE for all models ensemble = 0.01358117337627527
# Fold 3 best combination: model2 with RMSLE = 0.010528973991620567
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.016742131897196873
# Fold 4 RMSLE for model2 = 0.011934010466456015
# Fold 4 RMSLE for model3 = 0.020200652386624305
# Fold 4 RMSLE for model4 = 0.01433196969444133
# Fold 4 RMSLE for ('model1', 'model2') = 0.013812552777526016
# Fold 4 RMSLE for ('model1', 'model3') = 0.018141275058029174
# Fold 4 RMSLE for ('model1', 'model4') = 0.015403555864533944
# Fold 4 RMSLE for ('model2', 'model3') = 0.015209253521513694
# Fold 4 RMSLE for ('model2', 'model4') = 0.012841854083201565
# Fold 4 RMSLE for ('model3', 'model4') = 0.016838316216360644
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.01554230614701734
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.013919420939396542
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.016686143457109115
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.014769193500628965
# Fold 4 RMSLE for all models ensemble = 0.015156103225711476
# Fold 4 best combination: model2 with RMSLE = 0.011934010466456015
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.0216163289152137
# Fold 5 RMSLE for model2 = 0.015181667546509292
# Fold 5 RMSLE for model3 = 0.022466424513318956
# Fold 5 RMSLE for model4 = 0.017527065973743348
# Fold 5 RMSLE for ('model1', 'model2') = 0.018086614429271754
# Fold 5 RMSLE for ('model1', 'model3') = 0.021910978036105668
# Fold 5 RMSLE for ('model1', 'model4') = 0.019418090858432397
# Fold 5 RMSLE for ('model2', 'model3') = 0.01830470679551412
# Fold 5 RMSLE for ('model2', 'model4') = 0.016226922553805454
# Fold 5 RMSLE for ('model3', 'model4') = 0.01964039456941102
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.019340879410297634
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.017842075152587802
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.02025501115307373
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.017932157085226094
# Fold 5 RMSLE for all models ensemble = 0.0187986418995559
# Fold 5 best combination: model2 with RMSLE = 0.015181667546509292
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.01873593863840763
# Fold 6 RMSLE for model2 = 0.015341402942764216
# Fold 6 RMSLE for model3 = 0.020761032364060423
# Fold 6 RMSLE for model4 = 0.01712241379805642
# Fold 6 RMSLE for ('model1', 'model2') = 0.01661059277770026
# Fold 6 RMSLE for ('model1', 'model3') = 0.019589680070769954
# Fold 6 RMSLE for ('model1', 'model4') = 0.017679603508338866
# Fold 6 RMSLE for ('model2', 'model3') = 0.01743681796376446
# Fold 6 RMSLE for ('model2', 'model4') = 0.0160501154141071
# Fold 6 RMSLE for ('model3', 'model4') = 0.018368173570341328
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.01775582974196368
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.01668257379087849
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.018437950199362743
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.0171159390949733
# Fold 6 RMSLE for all models ensemble = 0.017435442236046674
# Fold 6 best combination: model2 with RMSLE = 0.015341402942764216
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.020389990370770883
# Fold 7 RMSLE for model2 = 0.016681168302253815
# Fold 7 RMSLE for model3 = 0.021252321409814322
# Fold 7 RMSLE for model4 = 0.018705751493467725
# Fold 7 RMSLE for ('model1', 'model2') = 0.018088609668781064
# Fold 7 RMSLE for ('model1', 'model3') = 0.020729715996193783
# Fold 7 RMSLE for ('model1', 'model4') = 0.01940724243070634
# Fold 7 RMSLE for ('model2', 'model3') = 0.018335589836916914
# Fold 7 RMSLE for ('model2', 'model4') = 0.017491287620843184
# Fold 7 RMSLE for ('model3', 'model4') = 0.01966422585433732
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.018934908585587128
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.018242860955001137
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.019874209520222497
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.018364989103190843
# Fold 7 RMSLE for all models ensemble = 0.018805524888437817
# Fold 7 best combination: model2 with RMSLE = 0.016681168302253815
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.017025749935490293
# Fold 8 RMSLE for model2 = 0.014438474497445952
# Fold 8 RMSLE for model3 = 0.01693654565381826
# Fold 8 RMSLE for model4 = 0.016044399769722488
# Fold 8 RMSLE for ('model1', 'model2') = 0.01526560278679543
# Fold 8 RMSLE for ('model1', 'model3') = 0.016857660860201757
# Fold 8 RMSLE for ('model1', 'model4') = 0.016350769824696996
# Fold 8 RMSLE for ('model2', 'model3') = 0.01509330788616527
# Fold 8 RMSLE for ('model2', 'model4') = 0.015067074922437982
# Fold 8 RMSLE for ('model3', 'model4') = 0.016179119429936738
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.015616646799470276
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.015469840642148678
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.016394523913550136
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.015324691377368893
# Fold 8 RMSLE for all models ensemble = 0.01565126274150336
# Fold 8 best combination: model2 with RMSLE = 0.014438474497445952
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.01753740811797052
# Fold 9 RMSLE for model2 = 0.013501793420810492
# Fold 9 RMSLE for model3 = 0.01948294615978849
# Fold 9 RMSLE for model4 = 0.015966516024185015
# Fold 9 RMSLE for ('model1', 'model2') = 0.015073057713918677
# Fold 9 RMSLE for ('model1', 'model3') = 0.018185896043646097
# Fold 9 RMSLE for ('model1', 'model4') = 0.016584327140332384
# Fold 9 RMSLE for ('model2', 'model3') = 0.01581496786116995
# Fold 9 RMSLE for ('model2', 'model4') = 0.01458127014868168
# Fold 9 RMSLE for ('model3', 'model4') = 0.01730611083929182
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.016202551460754284
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.015328306841878596
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.0172530102471779
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.015748365803501627
# Fold 9 RMSLE for all models ensemble = 0.016070197123514277
# Fold 9 best combination: model2 with RMSLE = 0.013501793420810492
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.022176433974634417
# Fold 10 RMSLE for model2 = 0.01732688851967055
# Fold 10 RMSLE for model3 = 0.026230434904266423
# Fold 10 RMSLE for model4 = 0.019252038951984515
# Fold 10 RMSLE for ('model1', 'model2') = 0.019296399458658325
# Fold 10 RMSLE for ('model1', 'model3') = 0.023998485715705207
# Fold 10 RMSLE for ('model1', 'model4') = 0.020534620067846815
# Fold 10 RMSLE for ('model2', 'model3') = 0.021107119150597018
# Fold 10 RMSLE for ('model2', 'model4') = 0.018113649977536683
# Fold 10 RMSLE for ('model3', 'model4') = 0.022308154476586396
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.02133100064360232
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.019223387324984652
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.02218742342556157
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.020347471634199678
# Fold 10 RMSLE for all models ensemble = 0.020711539741757688
# Fold 10 best combination: model2 with RMSLE = 0.01732688851967055
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.0196130851819975
# Fold 11 RMSLE for model2 = 0.016148606439828538
# Fold 11 RMSLE for model3 = 0.02079083672952481
# Fold 11 RMSLE for model4 = 0.017639462998108642
# Fold 11 RMSLE for ('model1', 'model2') = 0.01745794552483493
# Fold 11 RMSLE for ('model1', 'model3') = 0.02007275118406408
# Fold 11 RMSLE for ('model1', 'model4') = 0.018444605999642576
# Fold 11 RMSLE for ('model2', 'model3') = 0.01783321111601606
# Fold 11 RMSLE for ('model2', 'model4') = 0.0167403123182914
# Fold 11 RMSLE for ('model3', 'model4') = 0.01882589093798798
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.018333833282175485
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.01746197259001517
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.019038117723814977
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.01765885217926298
# Fold 11 RMSLE for all models ensemble = 0.018070308951851223
# Fold 11 best combination: model2 with RMSLE = 0.016148606439828538
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.01526867466909964
# Fold 12 RMSLE for model2 = 0.01112508367982955
# Fold 12 RMSLE for model3 = 0.016042160407609536
# Fold 12 RMSLE for model4 = 0.01363993748935966
# Fold 12 RMSLE for ('model1', 'model2') = 0.012723849833106782
# Fold 12 RMSLE for ('model1', 'model3') = 0.015514646931688655
# Fold 12 RMSLE for ('model1', 'model4') = 0.014295717882684621
# Fold 12 RMSLE for ('model2', 'model3') = 0.012891642273075895
# Fold 12 RMSLE for ('model2', 'model4') = 0.012159092471469313
# Fold 12 RMSLE for ('model3', 'model4') = 0.014501092910620432
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.01358483400025059
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.012967831689729419
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.01470027523077274
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.013038883605824959
# Fold 12 RMSLE for all models ensemble = 0.013519786242713166
# Fold 12 best combination: model2 with RMSLE = 0.01112508367982955
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.01891148189600429
# Fold 13 RMSLE for model2 = 0.01468627430195473
# Fold 13 RMSLE for model3 = 0.01993244194858431
# Fold 13 RMSLE for model4 = 0.016857380051666242
# Fold 13 RMSLE for ('model1', 'model2') = 0.016157428349795864
# Fold 13 RMSLE for ('model1', 'model3') = 0.019235330037483376
# Fold 13 RMSLE for ('model1', 'model4') = 0.0177138270331492
# Fold 13 RMSLE for ('model2', 'model3') = 0.016313776604440697
# Fold 13 RMSLE for ('model2', 'model4') = 0.015524813746275559
# Fold 13 RMSLE for ('model3', 'model4') = 0.017940587970870545
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.01705600524527794
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.016350147607220807
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.01820699344482295
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.016394224002083773
# Fold 13 RMSLE for all models ensemble = 0.016929720712682225
# Fold 13 best combination: model2 with RMSLE = 0.01468627430195473
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.018328581608576564
# Fold 14 RMSLE for model2 = 0.013822544597281761
# Fold 14 RMSLE for model3 = 0.02024799055454147
# Fold 14 RMSLE for model4 = 0.01637276825286701
# Fold 14 RMSLE for ('model1', 'model2') = 0.015696480418706225
# Fold 14 RMSLE for ('model1', 'model3') = 0.019136859746094616
# Fold 14 RMSLE for ('model1', 'model4') = 0.017187456198171937
# Fold 14 RMSLE for ('model2', 'model3') = 0.01646571211802168
# Fold 14 RMSLE for ('model2', 'model4') = 0.014978862046022673
# Fold 14 RMSLE for ('model3', 'model4') = 0.017966080428755683
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.01698984512322827
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.015879933675982956
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.01802358586986667
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.016343373505888204
# Fold 14 RMSLE for all models ensemble = 0.01676118602190784
# Fold 14 best combination: model2 with RMSLE = 0.013822544597281761
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.02570849050399138
# Fold 15 RMSLE for model2 = 0.02095030070332342
# Fold 15 RMSLE for model3 = 0.030397783991880967
# Fold 15 RMSLE for model4 = 0.021614674224989423
# Fold 15 RMSLE for ('model1', 'model2') = 0.023009119392551767
# Fold 15 RMSLE for ('model1', 'model3') = 0.027870502494012572
# Fold 15 RMSLE for ('model1', 'model4') = 0.023486295126807735
# Fold 15 RMSLE for ('model2', 'model3') = 0.025032839240803923
# Fold 15 RMSLE for ('model2', 'model4') = 0.021131713748092362
# Fold 15 RMSLE for ('model3', 'model4') = 0.025476287281286515
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.02518254079990989
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.0224679132056169
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.025511441518009707
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.02370841343179066
# Fold 15 RMSLE for all models ensemble = 0.02415829891671626
# Fold 15 best combination: model2 with RMSLE = 0.02095030070332342
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.020939106326616008
# Fold 16 RMSLE for model2 = 0.01513122148863516
# Fold 16 RMSLE for model3 = 0.022065808096459017
# Fold 16 RMSLE for model4 = 0.018542945725810243
# Fold 16 RMSLE for ('model1', 'model2') = 0.017616518451191217
# Fold 16 RMSLE for ('model1', 'model3') = 0.02122799866680422
# Fold 16 RMSLE for ('model1', 'model4') = 0.01961340237603924
# Fold 16 RMSLE for ('model2', 'model3') = 0.017674727442849154
# Fold 16 RMSLE for ('model2', 'model4') = 0.01665501989408091
# Fold 16 RMSLE for ('model3', 'model4') = 0.019780853989621976
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.018676076912810896
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.017883657895238828
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.020103056059655438
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.0178405806543574
# Fold 16 RMSLE for all models ensemble = 0.018558372003685306
# Fold 16 best combination: model2 with RMSLE = 0.01513122148863516
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.021378911626295412
# Fold 17 RMSLE for model2 = 0.017517073004048513
# Fold 17 RMSLE for model3 = 0.023666764026307435
# Fold 17 RMSLE for model4 = 0.019608573294862864
# Fold 17 RMSLE for ('model1', 'model2') = 0.01900984857110823
# Fold 17 RMSLE for ('model1', 'model3') = 0.022300140685097482
# Fold 17 RMSLE for ('model1', 'model4') = 0.020368978732773664
# Fold 17 RMSLE for ('model2', 'model3') = 0.019717221817288997
# Fold 17 RMSLE for ('model2', 'model4') = 0.018387565555336643
# Fold 17 RMSLE for ('model3', 'model4') = 0.02116471865453719
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.020181774996374014
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.019174887981256727
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.02118405533472074
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.019572676996014064
# Fold 17 RMSLE for all models ensemble = 0.01996324022713711
# Fold 17 best combination: model2 with RMSLE = 0.017517073004048513
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.017705555812504457
# Fold 18 RMSLE for model2 = 0.013454739784314029
# Fold 18 RMSLE for model3 = 0.018995703964676775
# Fold 18 RMSLE for model4 = 0.016376253734150147
# Fold 18 RMSLE for ('model1', 'model2') = 0.015195996094985375
# Fold 18 RMSLE for ('model1', 'model3') = 0.018161476955005713
# Fold 18 RMSLE for ('model1', 'model4') = 0.016913495912697342
# Fold 18 RMSLE for ('model2', 'model3') = 0.01554843339925158
# Fold 18 RMSLE for ('model2', 'model4') = 0.0147630219160241
# Fold 18 RMSLE for ('model3', 'model4') = 0.017301948802729863
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.016175055555095418
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.015552875453840303
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.017379895561882585
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.015727483518430455
# Fold 18 RMSLE for all models ensemble = 0.016156378961908545
# Fold 18 best combination: model2 with RMSLE = 0.013454739784314029
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.021839602753809008
# Fold 19 RMSLE for model2 = 0.01922090605471269
# Fold 19 RMSLE for model3 = 0.02472834551673326
# Fold 19 RMSLE for model4 = 0.01993364847799275
# Fold 19 RMSLE for ('model1', 'model2') = 0.02007290610995703
# Fold 19 RMSLE for ('model1', 'model3') = 0.022907487694987315
# Fold 19 RMSLE for ('model1', 'model4') = 0.020734990154419423
# Fold 19 RMSLE for ('model2', 'model3') = 0.020822334809680456
# Fold 19 RMSLE for ('model2', 'model4') = 0.019376728244762297
# Fold 19 RMSLE for ('model3', 'model4') = 0.021616226993867182
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.02104776092948829
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.019970851191577252
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.021607628918557345
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.02034936344128498
# Fold 19 RMSLE for all models ensemble = 0.020653549426362213
# Fold 19 best combination: model2 with RMSLE = 0.01922090605471269
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.018892552853633195
# Fold 20 RMSLE for model2 = 0.014301669896834488
# Fold 20 RMSLE for model3 = 0.019949660517119668
# Fold 20 RMSLE for model4 = 0.017620240405556757
# Fold 20 RMSLE for ('model1', 'model2') = 0.016218152102601687
# Fold 20 RMSLE for ('model1', 'model3') = 0.01926470128487041
# Fold 20 RMSLE for ('model1', 'model4') = 0.018119995524106557
# Fold 20 RMSLE for ('model2', 'model3') = 0.016551689470825654
# Fold 20 RMSLE for ('model2', 'model4') = 0.015782279087239434
# Fold 20 RMSLE for ('model3', 'model4') = 0.01846797334354078
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.017233710901542465
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.016632741897641936
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.018549410274628197
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.016810775642226876
# Fold 20 RMSLE for all models ensemble = 0.01726001258459157
# Fold 20 best combination: model2 with RMSLE = 0.014301669896834488
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.021161453277779543
# Fold 21 RMSLE for model2 = 0.014884645567694513
# Fold 21 RMSLE for model3 = 0.02191166977403946
# Fold 21 RMSLE for model4 = 0.01893753905698987
# Fold 21 RMSLE for ('model1', 'model2') = 0.017713840787013824
# Fold 21 RMSLE for ('model1', 'model3') = 0.021410022939376355
# Fold 21 RMSLE for ('model1', 'model4') = 0.019936842014987317
# Fold 21 RMSLE for ('model2', 'model3') = 0.017933728384797187
# Fold 21 RMSLE for ('model2', 'model4') = 0.016750624328498494
# Fold 21 RMSLE for ('model3', 'model4') = 0.020141747489129547
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.018931661751547254
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.018072000434596003
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.02043871111171181
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.01816976656384822
# Fold 21 RMSLE for all models ensemble = 0.018864538219199926
# Fold 21 best combination: model2 with RMSLE = 0.014884645567694513
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.017170963980464835
# Fold 22 RMSLE for model2 = 0.01227191885728985
# Fold 22 RMSLE for model3 = 0.017848485461926744
# Fold 22 RMSLE for model4 = 0.015329823123204132
# Fold 22 RMSLE for ('model1', 'model2') = 0.014404889226360858
# Fold 22 RMSLE for ('model1', 'model3') = 0.017403037170337015
# Fold 22 RMSLE for ('model1', 'model4') = 0.016137618971712554
# Fold 22 RMSLE for ('model2', 'model3') = 0.014680141240766205
# Fold 22 RMSLE for ('model2', 'model4') = 0.013639151061610722
# Fold 22 RMSLE for ('model3', 'model4') = 0.01637203548481238
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.015418177940785576
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.014664221811676021
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.016589535056953385
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.014810410134135414
# Fold 22 RMSLE for all models ensemble = 0.015336711369491496
# Fold 22 best combination: model2 with RMSLE = 0.01227191885728985
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.018715197056710528
# Fold 23 RMSLE for model2 = 0.013164659648278615
# Fold 23 RMSLE for model3 = 0.021553854223499522
# Fold 23 RMSLE for model4 = 0.01650703274107734
# Fold 23 RMSLE for ('model1', 'model2') = 0.01552145306272923
# Fold 23 RMSLE for ('model1', 'model3') = 0.02002763617574688
# Fold 23 RMSLE for ('model1', 'model4') = 0.017458766208091996
# Fold 23 RMSLE for ('model2', 'model3') = 0.01681569501234034
# Fold 23 RMSLE for ('model2', 'model4') = 0.014687897210354158
# Fold 23 RMSLE for ('model3', 'model4') = 0.018747364996760496
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.017355824365298957
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.015810630720975483
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.01868512278063916
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.01663164134570364
# Fold 23 RMSLE for all models ensemble = 0.017076936463249152
# Fold 23 best combination: model2 with RMSLE = 0.013164659648278615
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.020606056771506086
# Fold 24 RMSLE for model2 = 0.015621656870655452
# Fold 24 RMSLE for model3 = 0.023050179252456005
# Fold 24 RMSLE for model4 = 0.018368084452812187
# Fold 24 RMSLE for ('model1', 'model2') = 0.01779870270685257
# Fold 24 RMSLE for ('model1', 'model3') = 0.021694756142480072
# Fold 24 RMSLE for ('model1', 'model4') = 0.019373434302074884
# Fold 24 RMSLE for ('model2', 'model3') = 0.018864641903521943
# Fold 24 RMSLE for ('model2', 'model4') = 0.016807523824635934
# Fold 24 RMSLE for ('model3', 'model4') = 0.020431752212415378
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.0193602324262884
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.017927118693188693
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.02044094128361916
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.018590806645319657
# Fold 24 RMSLE for all models ensemble = 0.019039030781874675
# Fold 24 best combination: model2 with RMSLE = 0.015621656870655452
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.01698927332927793
# Fold 25 RMSLE for model2 = 0.012369612970102821
# Fold 25 RMSLE for model3 = 0.018645694895746436
# Fold 25 RMSLE for model4 = 0.015040138892728655
# Fold 25 RMSLE for ('model1', 'model2') = 0.014217414099738042
# Fold 25 RMSLE for ('model1', 'model3') = 0.01769011752392273
# Fold 25 RMSLE for ('model1', 'model4') = 0.015836439082116533
# Fold 25 RMSLE for ('model2', 'model3') = 0.01478643529791394
# Fold 25 RMSLE for ('model2', 'model4') = 0.013534861082364812
# Fold 25 RMSLE for ('model3', 'model4') = 0.016450318095467903
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.015440029115199169
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.014440036983701898
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.016582725220959826
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.014768214192927174
# Fold 25 RMSLE for all models ensemble = 0.015252514537562014
# Fold 25 best combination: model2 with RMSLE = 0.012369612970102821
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.02003311425532446
# Fold 26 RMSLE for model2 = 0.014414067959464025
# Fold 26 RMSLE for model3 = 0.021600730765216958
# Fold 26 RMSLE for model4 = 0.01700799949920694
# Fold 26 RMSLE for ('model1', 'model2') = 0.016806153848264276
# Fold 26 RMSLE for ('model1', 'model3') = 0.02064653971185741
# Fold 26 RMSLE for ('model1', 'model4') = 0.018367289941369054
# Fold 26 RMSLE for ('model2', 'model3') = 0.017304635892747854
# Fold 26 RMSLE for ('model2', 'model4') = 0.015499901730529838
# Fold 26 RMSLE for ('model3', 'model4') = 0.018926390431695847
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.018126177325574033
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.01680555904587577
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.019235937155240364
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.017087986538768262
# Fold 26 RMSLE for all models ensemble = 0.017758885535473095
# Fold 26 best combination: model2 with RMSLE = 0.014414067959464025
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.016199580165543098
# Fold 27 RMSLE for model2 = 0.012485817889253705
# Fold 27 RMSLE for model3 = 0.01926749516355772
# Fold 27 RMSLE for model4 = 0.015165813786035615
# Fold 27 RMSLE for ('model1', 'model2') = 0.01393769401367149
# Fold 27 RMSLE for ('model1', 'model3') = 0.017514624901781198
# Fold 27 RMSLE for ('model1', 'model4') = 0.015525217862495801
# Fold 27 RMSLE for ('model2', 'model3') = 0.01516349455236287
# Fold 27 RMSLE for ('model2', 'model4') = 0.0136631030382632
# Fold 27 RMSLE for ('model3', 'model4') = 0.01672203463036895
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.015399326998773924
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.01429671446804547
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.016485748020986644
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.015010439513063122
# Fold 27 RMSLE for all models ensemble = 0.015235747607878412
# Fold 27 best combination: model2 with RMSLE = 0.012485817889253705
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.02515546965427923
# Fold 28 RMSLE for model2 = 0.019833937137590043
# Fold 28 RMSLE for model3 = 0.02681659145240827
# Fold 28 RMSLE for model4 = 0.02213296532002926
# Fold 28 RMSLE for ('model1', 'model2') = 0.022171175886709048
# Fold 28 RMSLE for ('model1', 'model3') = 0.025886647205659166
# Fold 28 RMSLE for ('model1', 'model4') = 0.023547647480588005
# Fold 28 RMSLE for ('model2', 'model3') = 0.022884561573405612
# Fold 28 RMSLE for ('model2', 'model4') = 0.02080305016404161
# Fold 28 RMSLE for ('model3', 'model4') = 0.024285250090843286
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.023561311310216194
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.0221088913311299
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.02453056806287573
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.022564945558879706
# Fold 28 RMSLE for all models ensemble = 0.02315612472308401
# Fold 28 best combination: model2 with RMSLE = 0.019833937137590043
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.016480071084566936
# Fold 29 RMSLE for model2 = 0.011371099949568602
# Fold 29 RMSLE for model3 = 0.017810455992634377
# Fold 29 RMSLE for model4 = 0.014423948006827055
# Fold 29 RMSLE for ('model1', 'model2') = 0.01348528360773607
# Fold 29 RMSLE for ('model1', 'model3') = 0.01701912800208312
# Fold 29 RMSLE for ('model1', 'model4') = 0.015292733330338716
# Fold 29 RMSLE for ('model2', 'model3') = 0.013904212020612355
# Fold 29 RMSLE for ('model2', 'model4') = 0.012713336282613707
# Fold 29 RMSLE for ('model3', 'model4') = 0.015759109414319225
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.014686410249254822
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.013745516486783332
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.0159534614754732
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.013978784364145456
# Fold 29 RMSLE for all models ensemble = 0.014539585682106514
# Fold 29 best combination: model2 with RMSLE = 0.011371099949568602
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.022038121130064682
# Fold 30 RMSLE for model2 = 0.01898493922702384
# Fold 30 RMSLE for model3 = 0.023282244935962974
# Fold 30 RMSLE for model4 = 0.020910636152610934
# Fold 30 RMSLE for ('model1', 'model2') = 0.020130659181470154
# Fold 30 RMSLE for ('model1', 'model3') = 0.022450585542666063
# Fold 30 RMSLE for ('model1', 'model4') = 0.021323525152214473
# Fold 30 RMSLE for ('model2', 'model3') = 0.02056516593266948
# Fold 30 RMSLE for ('model2', 'model4') = 0.01981339003020298
# Fold 30 RMSLE for ('model3', 'model4') = 0.021704456979405533
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.020924795208931715
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.020348805450176633
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.021741469486893008
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.020565813481420853
# Fold 30 RMSLE for all models ensemble = 0.020843660398998126
# Fold 30 best combination: model2 with RMSLE = 0.01898493922702384
# ---------------
#
# OOF RMSLE = 0.015023345991585712
# Sum of RMSLE for each combination:
# ('model1',): 0.579423097228134
# ('model2',): 0.4437171693370369
# ('model3',): 0.6339903964236159
# ('model4',): 0.5149462658601055
# ('model1', 'model2'): 0.4988222681183886
# ('model1', 'model3'): 0.6013463542604833
# ('model1', 'model4'): 0.542449785445305
# ('model2', 'model3'): 0.5186056653185206
# ('model2', 'model4'): 0.4739410157426875
# ('model3', 'model4'): 0.5625328597787498
# ('model1', 'model2', 'model3'): 0.5357232886039394
# ('model1', 'model2', 'model4'): 0.5025547224429657
# ('model1', 'model3', 'model4'): 0.5663082411568019
# ('model2', 'model3', 'model4'): 0.5138202714565758
# ('model1', 'model2', 'model3', 'model4'): 0.52793100501477

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                          26,446                       23,385           130
# 3                          43,906                       42,958            82
# 4                          40,203                       39,437           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           45,108     0
# 1                  14            1          293,984    -0
# 2                   8            0           41,227     0
# 3                   8            0           29,464    -0
# 4                   8            0           48,383     0
# ...               ...          ...              ...   ...
# 2503                1            1          537,502     0
# 2504                9            1           99,339    -0
# 2505                8            0          137,959     0
# 2506                8            0          261,207    -0
# 2507                9            1        1,383,562     0
#
# [2508 rows x 19 columns]

# %%
test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
train_df["preds"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           41,547     0  42,214
# 1                  14            1           59,347    -0  58,528
# 2                   9            1           99,121     0  98,249
# 3                  15            1           51,450     0  51,796
# 4                  15            0           51,060    -0  51,140
# ...               ...          ...              ...   ...     ...
# 4650               15            0           46,740     0  49,433
# 4651                8            1          170,355    -0 169,332
# 4652                8            0           31,492     0  31,738
# 4653                8            0           66,290    -0  65,555
# 4654                9            1          146,419    -0 146,504
#
# [4655 rows x 20 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 0.00)

# %%
train_df_GHG14
# Out:
# 0       42,214
# 1       58,500
# 2       99,409
# 3       51,623
# 4       50,638
#          ...
# 4650    49,222
# 4651   169,634
# 4652    31,716
# 4653    65,663
# 4654   145,438
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["preds"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)
# after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["preds"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232483.7264782835

# %%
# def adjust_predictions(test_x, bins, bin_centers, y_means):
#     """
#     テストデータの予測値をビン平均で補正します。

#     Parameters:
#     - test_x: テストデータの予測値の配列
#     - bins: トレーニングデータで使用したビンの境界
#     - bin_centers: 各ビンの中心値
#     - y_means: 各ビン内の y の平均値

#     Returns:
#     - adjusted_predictions: 補正後の予測値
#     """
#     # テストデータをビンに割り当て
#     bin_indices = np.digitize(test_x, bins)

#     # 補正後の予測値を初期化
#     adjusted_predictions = np.copy(test_x)

#     for i in range(1, len(bins)):
#         mask = bin_indices == i
#         if np.any(mask):
#             # 補正係数を計算（y_mean / bin_center）
#             correction_factor = np.log1p(y_means[i-1]) / np.log1p(bin_centers[i-1])
#             adjusted_predictions[mask] = test_x[mask] / correction_factor

#     # ビンの範囲外のデータを処理（例えば、最小ビンより小さい値や最大ビンより大きい値）
#     # 最小ビンより小さい値は最初のビンに、
#     # 最大ビンより大きい値は最後のビンに割り当て
#     adjusted_predictions[bin_indices == 0] = y_means[0]
#     adjusted_predictions[bin_indices > len(y_means)] = y_means[-1]

#     return adjusted_predictions

# # テストデータの定義（例）
# # test_x = test_df["GHG_Direct_Emissions_14_in_metric_tons"]

# # 実際のデータに合わせて定義してください
# x_test = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]  # テストデータの予測値

# # 予測値を調整

# # 調整後の予測値をデータフレームに追加
# test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = adjust_predictions(x_test, bins, bin_centers, y_means)
# train_df["preds"] = adjust_predictions(train_df["preds"], bins, bin_centers, y_means)

# %%
def after_act(preds):
    r = preds.copy()
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            r[i] = np.expm1(np.log1p(r[i])*100/102)
        if r[i] > np.expm1(14):
            r[i] = np.expm1(np.log1p(r[i])*100/99)
    return r

after_test_preds = after_act(test_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
after_train_preds = after_act(train_df["preds"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 231987.0775829582

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_66.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,533
# 1     4656   293,456
# 2     4657    41,167
# 3     4658    23,294
# 4     4659    48,696
# ...    ...       ...
# 2503  7158   549,521
# 2504  7159    98,313
# 2505  7160   140,770
# 2506  7161   259,066
# 2507  7162 1,680,974
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,158,471
# 43    4698 1,185,271
# 110   4765 1,581,757
# 114   4769 1,495,702
# 148   4803 2,017,623
# ...    ...       ...
# 2417  7072 1,425,512
# 2423  7078 1,389,730
# 2466  7121 1,920,159
# 2490  7145 1,635,541
# 2507  7162 1,680,974
#
# [111 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Thu Nov 28 15:40:18 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           41,547     0  42,214
# 1                  14            1           59,347    -0  58,528
# 2                   9            1           99,121     0  98,249
# 3                  15            1           51,450     0  51,796
# 4                  15            0           51,060    -0  51,140
# ...               ...          ...              ...   ...     ...
# 4650               15            0           46,740     0  49,433
# 4651                8            1          170,355    -0 169,332
# 4652                8            0           31,492     0  25,901
# 4653                8            0           66,290    -0  65,555
# 4654                9            1          146,419    -0 146,504
#
# [4655 rows x 20 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["preds"])
# Out:
# 0.05493125503844096

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           41,547     0  42,214
# 1                  14            1           59,347    -0  58,528
# 2                   9            1           99,121     0  98,249
# 3                  15            1           51,450     0  51,796
# 4                  15            0           51,060    -0  51,140
# ...               ...          ...              ...   ...     ...
# 4650               15            0           46,740     0  49,433
# 4651                8            1          170,355    -0 169,332
# 4652                8            0           31,492     0  25,901
# 4653                8            0           66,290    -0  65,555
# 4654                9            1          146,419    -0 146,504
#
# [4655 rows x 20 columns]
