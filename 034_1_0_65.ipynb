# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/034_1_0_65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = abs(np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions']))

# 2. 条件を満たす行のマスクを作成
mask = diff > 0.70

# 3. 除外する行の数をカウント
exclude_num = mask.sum()

# 4. 条件を満たさない行だけを保持
train_all_df = train_all_df[~mask].reset_index(drop=True)

# 5. 'oof_predictions' 列を削除
train_all_df.drop('oof_predictions', axis=1, inplace=True)

# 6. 結果の表示
print(f"除外された行数: {exclude_num}")
# Out:
# 除外された行数: 1323

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                    28337.832145                 30840.825454
# 4                             NaN                          NaN
# ...                           ...                          ...
# 5835                          NaN                          NaN
# 5836                          NaN                          NaN
# 5837                 23592.402994                 25069.498286
# 5838                140816.449347                 93118.705227
# 5839                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN            21
# 3                    25153.901905            21
# 4                             NaN             4
# ...                           ...           ...
# 5835                          NaN           240
# 5836                          NaN             4
# 5837                 24560.172725           132
# 5838                130326.946431            98
# 5839                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                               54811.222708
# 3                               81812.306362
# 4                              104771.429060
# ...                                      ...
# 5835                           110523.066755
# 5836                                     NaN
# 5837                           166520.232511
# 5838                            71773.803649
# 5839                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                               69339.923002
# 3                               53823.561587
# 4                               82533.281481
# ...                                      ...
# 5835                            98954.793233
# 5836                                     NaN
# 5837                           469732.826538
# 5838                           936031.894142
# 5839                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               6.364734e+04
# 3                               7.739116e+04
# 4                               4.834559e+04
# ...                                      ...
# 5835                            3.467008e+06
# 5836                                     NaN
# 5837                            8.255855e+04
# 5838                            3.369613e+05
# 5839                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                               53799.011225  35.490363 -119.042957
# 3                               17662.966241  41.532802  -81.636448
# 4                               57390.377419  34.390000  -96.232800
# ...                                      ...        ...         ...
# 5835                           147802.356027  38.651945  -75.914445
# 5836                                     NaN  31.361795 -101.776403
# 5837                            85775.307153  41.005565  -96.154917
# 5838                           156640.371706  39.364417  -93.449361
# 5839                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                        -1215.964481                      2502.993309
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 5835                              NaN                              NaN
# 5836                              NaN                              NaN
# 5837                       636.277440                      1477.095292
# 5838                     16355.554326                    -47697.744120
# 5839                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                        -5686.923550                         -0.041144
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 5835                              NaN                               NaN
# 5836                              NaN                               NaN
# 5837                      -509.325561                          0.027717
# 5838                     37208.241204                          0.131411
# 5839                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                             0.088327                         -0.184396
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 5835                               NaN                               NaN
# 5836                               NaN                               NaN
# 5837                          0.062609                         -0.020317
# 5838                         -0.338723                          0.399579
# 5839                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                  15            1                              6.141190e+04
# 3                  15            0                              4.310047e+04
# 4                   9            1                              5.371204e+04
# ...               ...          ...                                       ...
# 5835                1            1                              5.497954e+05
# 5836                9            1                              1.137684e+05
# 5837                8            0                              1.412656e+05
# 5838                8            0                              2.599965e+05
# 5839                9            1                              1.293278e+06
#
# [5840 rows x 19 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)

        test_predictions += test_preds / kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                    28337.832145                 30840.825454
# 4                             NaN                          NaN
# ...                           ...                          ...
# 5835                          NaN                          NaN
# 5836                          NaN                          NaN
# 5837                 23592.402994                 25069.498286
# 5838                140816.449347                 93118.705227
# 5839                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN            21
# 3                    25153.901905            21
# 4                             NaN             4
# ...                           ...           ...
# 5835                          NaN           240
# 5836                          NaN             4
# 5837                 24560.172725           132
# 5838                130326.946431            98
# 5839                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                               54811.222708
# 3                               81812.306362
# 4                              104771.429060
# ...                                      ...
# 5835                           110523.066755
# 5836                                     NaN
# 5837                           166520.232511
# 5838                            71773.803649
# 5839                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                               69339.923002
# 3                               53823.561587
# 4                               82533.281481
# ...                                      ...
# 5835                            98954.793233
# 5836                                     NaN
# 5837                           469732.826538
# 5838                           936031.894142
# 5839                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               6.364734e+04
# 3                               7.739116e+04
# 4                               4.834559e+04
# ...                                      ...
# 5835                            3.467008e+06
# 5836                                     NaN
# 5837                            8.255855e+04
# 5838                            3.369613e+05
# 5839                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                               53799.011225  35.490363 -119.042957
# 3                               17662.966241  41.532802  -81.636448
# 4                               57390.377419  34.390000  -96.232800
# ...                                      ...        ...         ...
# 5835                           147802.356027  38.651945  -75.914445
# 5836                                     NaN  31.361795 -101.776403
# 5837                            85775.307153  41.005565  -96.154917
# 5838                           156640.371706  39.364417  -93.449361
# 5839                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                        -1215.964481                      2502.993309
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 5835                              NaN                              NaN
# 5836                              NaN                              NaN
# 5837                       636.277440                      1477.095292
# 5838                     16355.554326                    -47697.744120
# 5839                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                        -5686.923550                         -0.041144
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 5835                              NaN                               NaN
# 5836                              NaN                               NaN
# 5837                      -509.325561                          0.027717
# 5838                     37208.241204                          0.131411
# 5839                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                             0.088327                         -0.184396
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 5835                               NaN                               NaN
# 5836                               NaN                               NaN
# 5837                          0.062609                         -0.020317
# 5838                         -0.338723                          0.399579
# 5839                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                  15            1                              6.141190e+04
# 3                  15            0                              4.310047e+04
# 4                   9            1                              5.371204e+04
# ...               ...          ...                                       ...
# 5835                1            1                              5.497954e+05
# 5836                9            1                              1.137684e+05
# 5837                8            0                              1.412656e+05
# 5838                8            0                              2.599965e+05
# 5839                9            1                              1.293278e+06
#
# [5840 rows x 19 columns]

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    32075.140635                 26445.792090
# 3                    42503.897432                 43906.102080
# 4                    39897.800897                 40203.428231
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                    23385.161510           130
# 3                    42958.306538            82
# 4                    39437.099224           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing
# 0                   9            1
# 1                  14            1
# 2                   8            0
# 3                   8            0
# 4                   8            0
# ...               ...          ...
# 2503                1            1
# 2504                9            1
# 2505                8            0
# 2506                8            0
# 2507                9            1
#
# [2508 rows x 18 columns]

# %%
train = train_all_df.iloc[:, :-1].values
test = test_df.values
target = train_all_df.iloc[:, -1].values

# %%
oof_predictions,test_preds = get_models_trained(train,test,target,30)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.2516772189914301
# Fold 1 RMSLE for model2 = 0.25952367897993095
# Fold 1 RMSLE for model3 = 0.2530160743957856
# Fold 1 RMSLE for model4 = 0.2515751328328513
# Fold 1 RMSLE for ('model1', 'model2') = 0.25356989495279014
# Fold 1 RMSLE for ('model1', 'model3') = 0.2519192677356999
# Fold 1 RMSLE for ('model1', 'model4') = 0.24976327693349
# Fold 1 RMSLE for ('model2', 'model3') = 0.2541000843528843
# Fold 1 RMSLE for ('model2', 'model4') = 0.2541981987363907
# Fold 1 RMSLE for ('model3', 'model4') = 0.25024977361639866
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.2526773361147936
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.25192244738322256
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.2501548684929902
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.2522277424960755
# Fold 1 RMSLE for all models ensemble = 0.251467723633455
# Fold 1 best combination: ('model1', 'model4') with RMSLE = 0.24976327693349
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.2802151372045251
# Fold 2 RMSLE for model2 = 0.2702131611696234
# Fold 2 RMSLE for model3 = 0.28110652209751513
# Fold 2 RMSLE for model4 = 0.27587560223204344
# Fold 2 RMSLE for ('model1', 'model2') = 0.273203595059825
# Fold 2 RMSLE for ('model1', 'model3') = 0.2800742311021784
# Fold 2 RMSLE for ('model1', 'model4') = 0.2763852422628052
# Fold 2 RMSLE for ('model2', 'model3') = 0.2729269947757211
# Fold 2 RMSLE for ('model2', 'model4') = 0.2718353733185169
# Fold 2 RMSLE for ('model3', 'model4') = 0.2759847122370019
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.2748130567581601
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.2732705593685363
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.27693785825722567
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.2728873097369542
# Fold 2 RMSLE for all models ensemble = 0.2741830523638253
# Fold 2 best combination: model2 with RMSLE = 0.2702131611696234
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.25812068972170404
# Fold 3 RMSLE for model2 = 0.26049474404254763
# Fold 3 RMSLE for model3 = 0.25919259318929405
# Fold 3 RMSLE for model4 = 0.26026467980436574
# Fold 3 RMSLE for ('model1', 'model2') = 0.2570477694876543
# Fold 3 RMSLE for ('model1', 'model3') = 0.25816856911845043
# Fold 3 RMSLE for ('model1', 'model4') = 0.25774695480487914
# Fold 3 RMSLE for ('model2', 'model3') = 0.25741277202923785
# Fold 3 RMSLE for ('model2', 'model4') = 0.2593211979994421
# Fold 3 RMSLE for ('model3', 'model4') = 0.25798000921180925
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.2569821795400076
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.2574838862929207
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.2575703004477717
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.2576373957308401
# Fold 3 RMSLE for all models ensemble = 0.25715488993713576
# Fold 3 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.2569821795400076
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.2327838739245668
# Fold 4 RMSLE for model2 = 0.23494058303980309
# Fold 4 RMSLE for model3 = 0.23416142136688237
# Fold 4 RMSLE for model4 = 0.23688357289044965
# Fold 4 RMSLE for ('model1', 'model2') = 0.23189901918895667
# Fold 4 RMSLE for ('model1', 'model3') = 0.23290690878616224
# Fold 4 RMSLE for ('model1', 'model4') = 0.23362032717188652
# Fold 4 RMSLE for ('model2', 'model3') = 0.2322203441990666
# Fold 4 RMSLE for ('model2', 'model4') = 0.23421761882780373
# Fold 4 RMSLE for ('model3', 'model4') = 0.23358282574344372
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.23180372003077301
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.23270911859479107
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.23295774502910913
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.2326894199181364
# Fold 4 RMSLE for all models ensemble = 0.23227361270030183
# Fold 4 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.23180372003077301
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.24744759569138314
# Fold 5 RMSLE for model2 = 0.24457691888223917
# Fold 5 RMSLE for model3 = 0.24639198198230255
# Fold 5 RMSLE for model4 = 0.25132317975406404
# Fold 5 RMSLE for ('model1', 'model2') = 0.24391982601431678
# Fold 5 RMSLE for ('model1', 'model3') = 0.2465561902593492
# Fold 5 RMSLE for ('model1', 'model4') = 0.24795126246174531
# Fold 5 RMSLE for ('model2', 'model3') = 0.24333450081106095
# Fold 5 RMSLE for ('model2', 'model4') = 0.24674722766329968
# Fold 5 RMSLE for ('model3', 'model4') = 0.2469805234307406
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.24408676929614306
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.245678412734716
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.24672793542148133
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.24511215402829128
# Fold 5 RMSLE for all models ensemble = 0.24514329629646459
# Fold 5 best combination: ('model2', 'model3') with RMSLE = 0.24333450081106095
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.2773308518255114
# Fold 6 RMSLE for model2 = 0.2755446418393457
# Fold 6 RMSLE for model3 = 0.2784602979613089
# Fold 6 RMSLE for model4 = 0.27747032528912635
# Fold 6 RMSLE for ('model1', 'model2') = 0.2745970472749894
# Fold 6 RMSLE for ('model1', 'model3') = 0.2775024125650589
# Fold 6 RMSLE for ('model1', 'model4') = 0.2764180662137849
# Fold 6 RMSLE for ('model2', 'model3') = 0.27490486053371277
# Fold 6 RMSLE for ('model2', 'model4') = 0.27518333746035123
# Fold 6 RMSLE for ('model3', 'model4') = 0.2766775959656194
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.27519462928539146
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.2749382104409431
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.27657310589922146
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.2750620761431432
# Fold 6 RMSLE for all models ensemble = 0.27522331838873054
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.2745970472749894
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.2676125805999542
# Fold 7 RMSLE for model2 = 0.2652489130346616
# Fold 7 RMSLE for model3 = 0.2679812909587229
# Fold 7 RMSLE for model4 = 0.2697954752552576
# Fold 7 RMSLE for ('model1', 'model2') = 0.26455266484802126
# Fold 7 RMSLE for ('model1', 'model3') = 0.26730277664615015
# Fold 7 RMSLE for ('model1', 'model4') = 0.2676196114072055
# Fold 7 RMSLE for ('model2', 'model3') = 0.2645101875342392
# Fold 7 RMSLE for ('model2', 'model4') = 0.26625323004342305
# Fold 7 RMSLE for ('model3', 'model4') = 0.2669017062900704
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.26495315391341495
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.2656752768985965
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.26686254961307976
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.26529324109251295
# Fold 7 RMSLE for all models ensemble = 0.2654485122283825
# Fold 7 best combination: ('model2', 'model3') with RMSLE = 0.2645101875342392
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.258859474160953
# Fold 8 RMSLE for model2 = 0.256810993715675
# Fold 8 RMSLE for model3 = 0.25750589829050596
# Fold 8 RMSLE for model4 = 0.2567354353164312
# Fold 8 RMSLE for ('model1', 'model2') = 0.2547263479735325
# Fold 8 RMSLE for ('model1', 'model3') = 0.25774024236685117
# Fold 8 RMSLE for ('model1', 'model4') = 0.2562038244910516
# Fold 8 RMSLE for ('model2', 'model3') = 0.2542818107688261
# Fold 8 RMSLE for ('model2', 'model4') = 0.2555734403420855
# Fold 8 RMSLE for ('model3', 'model4') = 0.2552544642998739
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.2548017369336168
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.25489045945922106
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.2559392470731495
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.25441648090849583
# Fold 8 RMSLE for all models ensemble = 0.25470526524267295
# Fold 8 best combination: ('model2', 'model3') with RMSLE = 0.2542818107688261
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.25006910610845545
# Fold 9 RMSLE for model2 = 0.23827135988067485
# Fold 9 RMSLE for model3 = 0.2519821103067887
# Fold 9 RMSLE for model4 = 0.24100794615579668
# Fold 9 RMSLE for ('model1', 'model2') = 0.24157780416832467
# Fold 9 RMSLE for ('model1', 'model3') = 0.250546293832581
# Fold 9 RMSLE for ('model1', 'model4') = 0.24415700298127765
# Fold 9 RMSLE for ('model2', 'model3') = 0.2423393546773351
# Fold 9 RMSLE for ('model2', 'model4') = 0.23808888802861722
# Fold 9 RMSLE for ('model3', 'model4') = 0.24450467890958902
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.2441375563682611
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.24069022100975923
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.24595566254733872
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.24095843188881544
# Fold 9 RMSLE for all models ensemble = 0.24263779934581634
# Fold 9 best combination: ('model2', 'model4') with RMSLE = 0.23808888802861722
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.2989653774255236
# Fold 10 RMSLE for model2 = 0.29399707748189713
# Fold 10 RMSLE for model3 = 0.29766126026703954
# Fold 10 RMSLE for model4 = 0.29426307477914776
# Fold 10 RMSLE for ('model1', 'model2') = 0.29380239483459947
# Fold 10 RMSLE for ('model1', 'model3') = 0.2978171704006465
# Fold 10 RMSLE for ('model1', 'model4') = 0.29514940611302426
# Fold 10 RMSLE for ('model2', 'model3') = 0.29351289884040466
# Fold 10 RMSLE for ('model2', 'model4') = 0.2932995485611323
# Fold 10 RMSLE for ('model3', 'model4') = 0.2944985010516388
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.29440796760669136
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.29355422679205156
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.29544090121911964
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.29325449668505454
# Fold 10 RMSLE for all models ensemble = 0.2939064462832823
# Fold 10 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.29325449668505454
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.254798348227478
# Fold 11 RMSLE for model2 = 0.2521171741252721
# Fold 11 RMSLE for model3 = 0.2531324521426202
# Fold 11 RMSLE for model4 = 0.2553111541348954
# Fold 11 RMSLE for ('model1', 'model2') = 0.25030498196694767
# Fold 11 RMSLE for ('model1', 'model3') = 0.25366722876577363
# Fold 11 RMSLE for ('model1', 'model4') = 0.2528588447259578
# Fold 11 RMSLE for ('model2', 'model3') = 0.24964319666574486
# Fold 11 RMSLE for ('model2', 'model4') = 0.2523430841132952
# Fold 11 RMSLE for ('model3', 'model4') = 0.25187799003196837
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.2504029492368614
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.2511291041868659
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.2522114443592251
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.25056587661043933
# Fold 11 RMSLE for all models ensemble = 0.2507256440344622
# Fold 11 best combination: ('model2', 'model3') with RMSLE = 0.24964319666574486
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.2696178086255656
# Fold 12 RMSLE for model2 = 0.26739563841148994
# Fold 12 RMSLE for model3 = 0.26881357302717857
# Fold 12 RMSLE for model4 = 0.27443795451321107
# Fold 12 RMSLE for ('model1', 'model2') = 0.26652965814148283
# Fold 12 RMSLE for ('model1', 'model3') = 0.26860009225677967
# Fold 12 RMSLE for ('model1', 'model4') = 0.27084219110171986
# Fold 12 RMSLE for ('model2', 'model3') = 0.2655197210416684
# Fold 12 RMSLE for ('model2', 'model4') = 0.2697359782908988
# Fold 12 RMSLE for ('model3', 'model4') = 0.2696206472855224
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.2663306670886632
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.2685556166451313
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.26926197273363484
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.2676645979964944
# Fold 12 RMSLE for all models ensemble = 0.26769403549314125
# Fold 12 best combination: ('model2', 'model3') with RMSLE = 0.2655197210416684
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.2787084684069917
# Fold 13 RMSLE for model2 = 0.27507275696332695
# Fold 13 RMSLE for model3 = 0.27665676210290335
# Fold 13 RMSLE for model4 = 0.28116219107609325
# Fold 13 RMSLE for ('model1', 'model2') = 0.27481503978463934
# Fold 13 RMSLE for ('model1', 'model3') = 0.27733292531998355
# Fold 13 RMSLE for ('model1', 'model4') = 0.2784887366009231
# Fold 13 RMSLE for ('model2', 'model3') = 0.2735090733539107
# Fold 13 RMSLE for ('model2', 'model4') = 0.27681189560377606
# Fold 13 RMSLE for ('model3', 'model4') = 0.27686739614759726
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.27469077622363774
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.2761707759150232
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.27713631649697823
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.27509687108303726
# Fold 13 RMSLE for all models ensemble = 0.27550913876894323
# Fold 13 best combination: ('model2', 'model3') with RMSLE = 0.2735090733539107
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.26815114610369073
# Fold 14 RMSLE for model2 = 0.26176891992976836
# Fold 14 RMSLE for model3 = 0.26735014014723396
# Fold 14 RMSLE for model4 = 0.26354670772801875
# Fold 14 RMSLE for ('model1', 'model2') = 0.26214506654890907
# Fold 14 RMSLE for ('model1', 'model3') = 0.26726769168486736
# Fold 14 RMSLE for ('model1', 'model4') = 0.2640675788297489
# Fold 14 RMSLE for ('model2', 'model3') = 0.26177361221399703
# Fold 14 RMSLE for ('model2', 'model4') = 0.261562940968113
# Fold 14 RMSLE for ('model3', 'model4') = 0.2633722283368736
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.2629981672177556
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.2619865522686269
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.26440313845201185
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.2615839185592241
# Fold 14 RMSLE for all models ensemble = 0.262434045376822
# Fold 14 best combination: ('model2', 'model4') with RMSLE = 0.261562940968113
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.2613975182676427
# Fold 15 RMSLE for model2 = 0.2596290869897994
# Fold 15 RMSLE for model3 = 0.25824455723593914
# Fold 15 RMSLE for model4 = 0.2558909986446833
# Fold 15 RMSLE for ('model1', 'model2') = 0.2577205388296333
# Fold 15 RMSLE for ('model1', 'model3') = 0.2594017442181068
# Fold 15 RMSLE for ('model1', 'model4') = 0.256399306900266
# Fold 15 RMSLE for ('model2', 'model3') = 0.25609373592692436
# Fold 15 RMSLE for ('model2', 'model4') = 0.2563554612284694
# Fold 15 RMSLE for ('model3', 'model4') = 0.2544828857573399
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.25703015991858513
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.25614829324388966
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.2561642355055728
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.25490840524305336
# Fold 15 RMSLE for all models ensemble = 0.2557260576651108
# Fold 15 best combination: ('model3', 'model4') with RMSLE = 0.2544828857573399
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.28416548862386937
# Fold 16 RMSLE for model2 = 0.2693135104151203
# Fold 16 RMSLE for model3 = 0.28604994607179074
# Fold 16 RMSLE for model4 = 0.273506785120994
# Fold 16 RMSLE for ('model1', 'model2') = 0.273121222179691
# Fold 16 RMSLE for ('model1', 'model3') = 0.2844648064726652
# Fold 16 RMSLE for ('model1', 'model4') = 0.2766478276377722
# Fold 16 RMSLE for ('model2', 'model3') = 0.2740801907317834
# Fold 16 RMSLE for ('model2', 'model4') = 0.2697806097199456
# Fold 16 RMSLE for ('model3', 'model4') = 0.27705401690502596
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.2763164168101699
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.2723915813602829
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.27876911333023796
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.27278158791909307
# Fold 16 RMSLE for all models ensemble = 0.2746725473781371
# Fold 16 best combination: model2 with RMSLE = 0.2693135104151203
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.27579443884211213
# Fold 17 RMSLE for model2 = 0.2719182641972236
# Fold 17 RMSLE for model3 = 0.2741406688606012
# Fold 17 RMSLE for model4 = 0.2739815026823668
# Fold 17 RMSLE for ('model1', 'model2') = 0.2701173640751369
# Fold 17 RMSLE for ('model1', 'model3') = 0.27435126661023407
# Fold 17 RMSLE for ('model1', 'model4') = 0.2725297681403926
# Fold 17 RMSLE for ('model2', 'model3') = 0.2691612014082965
# Fold 17 RMSLE for ('model2', 'model4') = 0.27131536595095346
# Fold 17 RMSLE for ('model3', 'model4') = 0.2714032216238158
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.27023261882121646
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.2704760699162156
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.27212870463988154
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.26973095284522425
# Fold 17 RMSLE for all models ensemble = 0.27022431132446995
# Fold 17 best combination: ('model2', 'model3') with RMSLE = 0.2691612014082965
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.26854175506874667
# Fold 18 RMSLE for model2 = 0.26637709122265163
# Fold 18 RMSLE for model3 = 0.2691784662130874
# Fold 18 RMSLE for model4 = 0.26477062153931796
# Fold 18 RMSLE for ('model1', 'model2') = 0.2654642926943578
# Fold 18 RMSLE for ('model1', 'model3') = 0.2684349955824166
# Fold 18 RMSLE for ('model1', 'model4') = 0.2649055674799925
# Fold 18 RMSLE for ('model2', 'model3') = 0.26556971813106584
# Fold 18 RMSLE for ('model2', 'model4') = 0.26449841840467897
# Fold 18 RMSLE for ('model3', 'model4') = 0.2645951188371954
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.2659840371348176
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.2644045594700075
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.2654816936318418
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.2642555060407272
# Fold 18 RMSLE for all models ensemble = 0.2647584379131213
# Fold 18 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.2642555060407272
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.2679227302517524
# Fold 19 RMSLE for model2 = 0.2515858297001971
# Fold 19 RMSLE for model3 = 0.2652174967085718
# Fold 19 RMSLE for model4 = 0.25545701381981173
# Fold 19 RMSLE for ('model1', 'model2') = 0.2556885789995229
# Fold 19 RMSLE for ('model1', 'model3') = 0.26596822963921174
# Fold 19 RMSLE for ('model1', 'model4') = 0.2588931323289145
# Fold 19 RMSLE for ('model2', 'model3') = 0.25470854042122765
# Fold 19 RMSLE for ('model2', 'model4') = 0.25191562676831847
# Fold 19 RMSLE for ('model3', 'model4') = 0.2573315301865303
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.25777631848968385
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.2546263570248389
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.2599813844067924
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.25375975246212024
# Fold 19 RMSLE for all models ensemble = 0.25609731654413276
# Fold 19 best combination: model2 with RMSLE = 0.2515858297001971
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.27859842039033705
# Fold 20 RMSLE for model2 = 0.2693440938808766
# Fold 20 RMSLE for model3 = 0.2742275331638882
# Fold 20 RMSLE for model4 = 0.2754870064204725
# Fold 20 RMSLE for ('model1', 'model2') = 0.27166641934860153
# Fold 20 RMSLE for ('model1', 'model3') = 0.27600993314309197
# Fold 20 RMSLE for ('model1', 'model4') = 0.27576024984311603
# Fold 20 RMSLE for ('model2', 'model3') = 0.26917931294760417
# Fold 20 RMSLE for ('model2', 'model4') = 0.27145745326006576
# Fold 20 RMSLE for ('model3', 'model4') = 0.2730493219099632
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.27169512490747594
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.2724553875346094
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.27454135143078984
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.27064171740626275
# Fold 20 RMSLE for all models ensemble = 0.2720742508287779
# Fold 20 best combination: ('model2', 'model3') with RMSLE = 0.26917931294760417
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.24462621276858149
# Fold 21 RMSLE for model2 = 0.24924003389162414
# Fold 21 RMSLE for model3 = 0.24256833408701645
# Fold 21 RMSLE for model4 = 0.2488071535541501
# Fold 21 RMSLE for ('model1', 'model2') = 0.24386592882019228
# Fold 21 RMSLE for ('model1', 'model3') = 0.2429333887546323
# Fold 21 RMSLE for ('model1', 'model4') = 0.2449558022835458
# Fold 21 RMSLE for ('model2', 'model3') = 0.2427474253250355
# Fold 21 RMSLE for ('model2', 'model4') = 0.24750151583816568
# Fold 21 RMSLE for ('model3', 'model4') = 0.24325010933469
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.24238689857130935
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.2447467821992704
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.24314619561382594
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.24372170891901185
# Fold 21 RMSLE for all models ensemble = 0.24314471942692498
# Fold 21 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.24238689857130935
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.26649148873136863
# Fold 22 RMSLE for model2 = 0.2643050741835625
# Fold 22 RMSLE for model3 = 0.2671902133712405
# Fold 22 RMSLE for model4 = 0.26511267939260086
# Fold 22 RMSLE for ('model1', 'model2') = 0.26362383694294794
# Fold 22 RMSLE for ('model1', 'model3') = 0.26624737047883545
# Fold 22 RMSLE for ('model1', 'model4') = 0.26435800193198544
# Fold 22 RMSLE for ('model2', 'model3') = 0.2631133754903611
# Fold 22 RMSLE for ('model2', 'model4') = 0.26360191278614314
# Fold 22 RMSLE for ('model3', 'model4') = 0.263895377747048
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.26376114098885955
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.26338925794000007
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.2643437930203637
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.26290533305394903
# Fold 22 RMSLE for all models ensemble = 0.26333146654118067
# Fold 22 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.26290533305394903
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.2693098717489535
# Fold 23 RMSLE for model2 = 0.26507891899873676
# Fold 23 RMSLE for model3 = 0.27024278466693247
# Fold 23 RMSLE for model4 = 0.2665225853723446
# Fold 23 RMSLE for ('model1', 'model2') = 0.264647919613219
# Fold 23 RMSLE for ('model1', 'model3') = 0.2690578484689071
# Fold 23 RMSLE for ('model1', 'model4') = 0.2663024894152619
# Fold 23 RMSLE for ('model2', 'model3') = 0.2646536702934852
# Fold 23 RMSLE for ('model2', 'model4') = 0.2644132726378226
# Fold 23 RMSLE for ('model3', 'model4') = 0.2659276413432609
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.2654264912611555
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.2645021978577497
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.2665706147697672
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.26424722392724526
# Fold 23 RMSLE for all models ensemble = 0.2648646389175229
# Fold 23 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.26424722392724526
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.2928032450029345
# Fold 24 RMSLE for model2 = 0.28789414610165664
# Fold 24 RMSLE for model3 = 0.29102885469433787
# Fold 24 RMSLE for model4 = 0.286672362595828
# Fold 24 RMSLE for ('model1', 'model2') = 0.2873010150078422
# Fold 24 RMSLE for ('model1', 'model3') = 0.29158081621931087
# Fold 24 RMSLE for ('model1', 'model4') = 0.28810697470398877
# Fold 24 RMSLE for ('model2', 'model3') = 0.28676186139302146
# Fold 24 RMSLE for ('model2', 'model4') = 0.28605696024801613
# Fold 24 RMSLE for ('model3', 'model4') = 0.28736559142139484
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.28782604070417817
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.286542184651592
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.28861003866518226
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.28614462726686
# Fold 24 RMSLE for all models ensemble = 0.28699298974393705
# Fold 24 best combination: ('model2', 'model4') with RMSLE = 0.28605696024801613
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.30284915283421354
# Fold 25 RMSLE for model2 = 0.3067818629777958
# Fold 25 RMSLE for model3 = 0.30253658970871994
# Fold 25 RMSLE for model4 = 0.29909654285474746
# Fold 25 RMSLE for ('model1', 'model2') = 0.30278861716595246
# Fold 25 RMSLE for ('model1', 'model3') = 0.3022978588344082
# Fold 25 RMSLE for ('model1', 'model4') = 0.29975040410371034
# Fold 25 RMSLE for ('model2', 'model3') = 0.30236389503715094
# Fold 25 RMSLE for ('model2', 'model4') = 0.30188414747688724
# Fold 25 RMSLE for ('model3', 'model4') = 0.29940060222116516
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.30199136188220727
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.30100676351731115
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.3001524949582493
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.3006931804925341
# Fold 25 RMSLE for all models ensemble = 0.30073673778126714
# Fold 25 best combination: model4 with RMSLE = 0.29909654285474746
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.26048253710044905
# Fold 26 RMSLE for model2 = 0.2618857542769869
# Fold 26 RMSLE for model3 = 0.264619272236014
# Fold 26 RMSLE for model4 = 0.2614475064868038
# Fold 26 RMSLE for ('model1', 'model2') = 0.2584030274195604
# Fold 26 RMSLE for ('model1', 'model3') = 0.2619746492088192
# Fold 26 RMSLE for ('model1', 'model4') = 0.25884245463347794
# Fold 26 RMSLE for ('model2', 'model3') = 0.25995747037995237
# Fold 26 RMSLE for ('model2', 'model4') = 0.2605302677671168
# Fold 26 RMSLE for ('model3', 'model4') = 0.2603011039227113
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.2593255397600422
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.2586384172883935
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.25971209875721063
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.25952121564641556
# Fold 26 RMSLE for all models ensemble = 0.2589524236067024
# Fold 26 best combination: ('model1', 'model2') with RMSLE = 0.2584030274195604
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.26273524281020083
# Fold 27 RMSLE for model2 = 0.25658076757218573
# Fold 27 RMSLE for model3 = 0.2647001621233645
# Fold 27 RMSLE for model4 = 0.25617501405523685
# Fold 27 RMSLE for ('model1', 'model2') = 0.2558547092980449
# Fold 27 RMSLE for ('model1', 'model3') = 0.26309357999177174
# Fold 27 RMSLE for ('model1', 'model4') = 0.2567446448218628
# Fold 27 RMSLE for ('model2', 'model3') = 0.25716466476338856
# Fold 27 RMSLE for ('model2', 'model4') = 0.2545644850762636
# Fold 27 RMSLE for ('model3', 'model4') = 0.2573756460483351
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.25777687366444013
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.2548109302909265
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.2583514241441533
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.2554409781115784
# Fold 27 RMSLE for all models ensemble = 0.2561611573806973
# Fold 27 best combination: ('model2', 'model4') with RMSLE = 0.2545644850762636
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.2570974238624331
# Fold 28 RMSLE for model2 = 0.25348665450718294
# Fold 28 RMSLE for model3 = 0.25752901317440435
# Fold 28 RMSLE for model4 = 0.2653321672171403
# Fold 28 RMSLE for ('model1', 'model2') = 0.25368603060430805
# Fold 28 RMSLE for ('model1', 'model3') = 0.2564522602215262
# Fold 28 RMSLE for ('model1', 'model4') = 0.2598270741209659
# Fold 28 RMSLE for ('model2', 'model3') = 0.25360689363857924
# Fold 28 RMSLE for ('model2', 'model4') = 0.25795340281468826
# Fold 28 RMSLE for ('model3', 'model4') = 0.2591895240854384
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.2541056378525237
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.25665700672068076
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.2579765985409254
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.2562944433009924
# Fold 28 RMSLE for all models ensemble = 0.2559938235806456
# Fold 28 best combination: model2 with RMSLE = 0.25348665450718294
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.23819920585103088
# Fold 29 RMSLE for model2 = 0.23629907484712065
# Fold 29 RMSLE for model3 = 0.2456517394696199
# Fold 29 RMSLE for model4 = 0.23380694634304935
# Fold 29 RMSLE for ('model1', 'model2') = 0.23428742626199278
# Fold 29 RMSLE for ('model1', 'model3') = 0.2409999077338732
# Fold 29 RMSLE for ('model1', 'model4') = 0.23434815985005494
# Fold 29 RMSLE for ('model2', 'model3') = 0.23730056975562808
# Fold 29 RMSLE for ('model2', 'model4') = 0.2336664155162828
# Fold 29 RMSLE for ('model3', 'model4') = 0.23704997422733964
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.23665199726929087
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.2334418752863926
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.23688661806476527
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.23518314895331568
# Fold 29 RMSLE for all models ensemble = 0.2351742379327184
# Fold 29 best combination: ('model1', 'model2', 'model4') with RMSLE = 0.2334418752863926
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.24725798799717946
# Fold 30 RMSLE for model2 = 0.24723488094306653
# Fold 30 RMSLE for model3 = 0.24540071499437402
# Fold 30 RMSLE for model4 = 0.24879430741872421
# Fold 30 RMSLE for ('model1', 'model2') = 0.2434545296361287
# Fold 30 RMSLE for ('model1', 'model3') = 0.24579631334799482
# Fold 30 RMSLE for ('model1', 'model4') = 0.24578784183676272
# Fold 30 RMSLE for ('model2', 'model3') = 0.24239221977963218
# Fold 30 RMSLE for ('model2', 'model4') = 0.2465334232780951
# Fold 30 RMSLE for ('model3', 'model4') = 0.24448490883046145
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.2429170926333751
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.24445220705958828
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.24473081656316314
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.24359632022380426
# Fold 30 RMSLE for all models ensemble = 0.24351703124216906
# Fold 30 best combination: ('model2', 'model3') with RMSLE = 0.24239221977963218
# ---------------
#
# OOF RMSLE = 0.2605462458164501
# Sum of RMSLE for each combination:
# ('model1',): 7.97263039716954
# ('model2',): 7.872931606202043
# ('model3',): 7.9719387250159865
# ('model4',): 7.920513625280025
# ('model1', 'model2'): 7.844382567142123
# ('model1', 'model3'): 7.956466969766336
# ('model1', 'model4'): 7.89543202613157
# ('model2', 'model3'): 7.838844157220947
# ('model2', 'model4'): 7.857200698729058
# ('model3', 'model4'): 7.880509626959861
# ('model1', 'model2', 'model3'): 7.859484416283502
# ('model1', 'model2', 'model4'): 7.847344739352154
# ('model1', 'model3', 'model4'): 7.895680222085059
# ('model2', 'model3', 'model4'): 7.8382761146897
# ('model1', 'model2', 'model3', 'model4'): 7.850928927900952

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target = target.flatten()
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=oof_predictions, y=target, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([target.min(), target.max()], [target.min(), target.max()], 'r--')  # 45度線
plt.show()

# %%
# フラット化
target = target.flatten()
oof_predictions = oof_predictions.flatten()

# 対数変換
log_target = np.log1p(target)
log_oof_predictions = np.log1p(oof_predictions)
# 差の計算
diff = abs(log_target - log_oof_predictions)
# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.65
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線の描画
min_val = min(log_target.min(), log_oof_predictions.min())
max_val = max(log_target.max(), log_oof_predictions.max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='y = x')  # 45度線

# 凡例の設定
plt.legend(title='Difference > 0.7')

# プロットの表示
plt.tight_layout()
plt.show()

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
test_preds.shape
# Out:
# (2508,)

# %%
submit [ 1 ]  =  test_preds
submit.to_csv('SMBC_34_6.5.csv', index = False)

# %%
submit
# Out:
#          0             1
# 0     4655  4.527279e+04
# 1     4656  2.975359e+05
# 2     4657  4.075355e+04
# 3     4658  2.904151e+04
# 4     4659  4.795018e+04
# ...    ...           ...
# 2503  7158  5.346565e+05
# 2504  7159  1.028869e+05
# 2505  7160  1.341357e+05
# 2506  7161  2.520045e+05
# 2507  7162  1.233408e+06
#
# [2508 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2503    1
# 2504    1
# 2505    0
# 2506    0
# 2507    1
# Name: num_missing, Length: 2508, dtype: int64

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(oof_predictions, target, "oof_predictions, target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
show_plot(np.log(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(test_preds),
          "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sun Nov 24 05:45:26 2024
