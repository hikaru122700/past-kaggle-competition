# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/076_ipunb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 4.221442e+04  0.015936
# 1                                 5.849961e+04 -0.014376
# 2                                 9.940945e+04  0.002905
# 3                                 5.162331e+04  0.003356
# 4                                 5.063790e+04 -0.008299
# ...                                        ...       ...
# 2503                              5.375020e+05  0.027199
# 2504                              9.933916e+04 -0.009746
# 2505                              1.379589e+05  0.022125
# 2506                              2.612069e+05 -0.005393
# 2507                              1.383562e+06  0.065402
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.154699e+04  0.015936
# 1                  14            1     5.934671e+04 -0.014376
# 2                   9            1     9.912108e+04  0.002905
# 3                  15            1     5.145036e+04  0.003356
# 4                  15            0     5.105989e+04 -0.008299
# ...               ...          ...              ...       ...
# 2503                1            1     5.230794e+05  0.027199
# 2504                9            1     1.003121e+05 -0.009746
# 2505                8            0     1.349400e+05  0.022125
# 2506                8            0     2.626193e+05 -0.005393
# 2507                9            1     1.295969e+06  0.065402
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
epock = 10
import time
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.007070871443793652
# Fold 18 RMSLE for ('model1', 'model3') = 0.007412415044607686
# Fold 18 RMSLE for ('model1', 'model4') = 0.007341925096305861
# Fold 18 RMSLE for ('model2', 'model3') = 0.007220877251297647
# Fold 18 RMSLE for ('model2', 'model4') = 0.007225967586255481
# Fold 18 RMSLE for ('model3', 'model4') = 0.007511378353725395
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.007209813971667718
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.007203181473906241
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.007405435521580524
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.007293322384574145
# Fold 18 RMSLE for all models ensemble = 0.007268251391753084
# Fold 18 best combination: model2 with RMSLE = 0.007008075172623655
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.008752883442204337
# Fold 19 RMSLE for model2 = 0.008670433552998645
# Fold 19 RMSLE for model3 = 0.009082480368300625
# Fold 19 RMSLE for model4 = 0.008906609164643304
# Fold 19 RMSLE for ('model1', 'model2') = 0.008671826425605546
# Fold 19 RMSLE for ('model1', 'model3') = 0.008878112157439574
# Fold 19 RMSLE for ('model1', 'model4') = 0.008818164294647771
# Fold 19 RMSLE for ('model2', 'model3') = 0.008770638400680125
# Fold 19 RMSLE for ('model2', 'model4') = 0.008767199670938013
# Fold 19 RMSLE for ('model3', 'model4') = 0.0089339424487565
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.008752785925439318
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.00874439799879405
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.008864114890134195
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.008802886574324834
# Fold 19 RMSLE for all models ensemble = 0.008783228693069373
# Fold 19 best combination: model2 with RMSLE = 0.008670433552998645
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.008847508382231278
# Fold 20 RMSLE for model2 = 0.008229271098776525
# Fold 20 RMSLE for model3 = 0.00930533241400618
# Fold 20 RMSLE for model4 = 0.008686755095803847
# Fold 20 RMSLE for ('model1', 'model2') = 0.008495151906127898
# Fold 20 RMSLE for ('model1', 'model3') = 0.009033485917402304
# Fold 20 RMSLE for ('model1', 'model4') = 0.008755498056789789
# Fold 20 RMSLE for ('model2', 'model3') = 0.008651874848008043
# Fold 20 RMSLE for ('model2', 'model4') = 0.008430292096744221
# Fold 20 RMSLE for ('model3', 'model4') = 0.008929743888239432
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.008704514339804556
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.008551320147484569
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.00889247140439796
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.008646711181326565
# Fold 20 RMSLE for all models ensemble = 0.00869009770509502
# Fold 20 best combination: model2 with RMSLE = 0.008229271098776525
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.007350484032990481
# Fold 21 RMSLE for model2 = 0.006899640588673374
# Fold 21 RMSLE for model3 = 0.0077453873778195025
# Fold 21 RMSLE for model4 = 0.007223195212111402
# Fold 21 RMSLE for ('model1', 'model2') = 0.007058009481693814
# Fold 21 RMSLE for ('model1', 'model3') = 0.007501253187421617
# Fold 21 RMSLE for ('model1', 'model4') = 0.0072681425326613786
# Fold 21 RMSLE for ('model2', 'model3') = 0.0071897172592024754
# Fold 21 RMSLE for ('model2', 'model4') = 0.007025573967018065
# Fold 21 RMSLE for ('model3', 'model4') = 0.007415537339807298
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.007222492993995734
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.007103920109464024
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.007379734772592311
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.0071832602976019885
# Fold 21 RMSLE for all models ensemble = 0.0072119864799968375
# Fold 21 best combination: model2 with RMSLE = 0.006899640588673374
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.007720011642826528
# Fold 22 RMSLE for model2 = 0.007151147686186258
# Fold 22 RMSLE for model3 = 0.008215508915584185
# Fold 22 RMSLE for model4 = 0.007634020794605714
# Fold 22 RMSLE for ('model1', 'model2') = 0.0073945516396673435
# Fold 22 RMSLE for ('model1', 'model3') = 0.007922083116537592
# Fold 22 RMSLE for ('model1', 'model4') = 0.007662772582364649
# Fold 22 RMSLE for ('model2', 'model3') = 0.007570604607536472
# Fold 22 RMSLE for ('model2', 'model4') = 0.0073674606471636475
# Fold 22 RMSLE for ('model3', 'model4') = 0.007853446369622829
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0076068632560665535
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.007466161065214386
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0077977559373231175
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0075731164002281045
# Fold 22 RMSLE for all models ensemble = 0.007602168318622951
# Fold 22 best combination: model2 with RMSLE = 0.007151147686186258
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.00761237403076142
# Fold 23 RMSLE for model2 = 0.007236095867061008
# Fold 23 RMSLE for model3 = 0.008172585788963453
# Fold 23 RMSLE for model4 = 0.007619270478841902
# Fold 23 RMSLE for ('model1', 'model2') = 0.007382633988291117
# Fold 23 RMSLE for ('model1', 'model3') = 0.007847598777036977
# Fold 23 RMSLE for ('model1', 'model4') = 0.007604996616600182
# Fold 23 RMSLE for ('model2', 'model3') = 0.0075903831974308885
# Fold 23 RMSLE for ('model2', 'model4') = 0.007402521921352839
# Fold 23 RMSLE for ('model3', 'model4') = 0.007826655560952989
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.007584395914405172
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.007454929400868953
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.00774536843484253
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0075826235279088435
# Fold 23 RMSLE for all models ensemble = 0.007583122185883667
# Fold 23 best combination: model2 with RMSLE = 0.007236095867061008
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.00859174383389442
# Fold 24 RMSLE for model2 = 0.008237454404611808
# Fold 24 RMSLE for model3 = 0.009059008249586848
# Fold 24 RMSLE for model4 = 0.008402522755033925
# Fold 24 RMSLE for ('model1', 'model2') = 0.008384162831699585
# Fold 24 RMSLE for ('model1', 'model3') = 0.008783757151928806
# Fold 24 RMSLE for ('model1', 'model4') = 0.00848890522434402
# Fold 24 RMSLE for ('model2', 'model3') = 0.008554558800740557
# Fold 24 RMSLE for ('model2', 'model4') = 0.008298655367148064
# Fold 24 RMSLE for ('model3', 'model4') = 0.008671087781907791
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.008555549605235207
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.008383962275757934
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.008635383142182575
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.008488030839660769
# Fold 24 RMSLE for all models ensemble = 0.008508453741052916
# Fold 24 best combination: model2 with RMSLE = 0.008237454404611808
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.008418210354230226
# Fold 25 RMSLE for model2 = 0.008068826017726242
# Fold 25 RMSLE for model3 = 0.00860545564461884
# Fold 25 RMSLE for model4 = 0.008416764378833238
# Fold 25 RMSLE for ('model1', 'model2') = 0.00819392938236256
# Fold 25 RMSLE for ('model1', 'model3') = 0.008474425712294405
# Fold 25 RMSLE for ('model1', 'model4') = 0.008404242151374515
# Fold 25 RMSLE for ('model2', 'model3') = 0.008217887707794849
# Fold 25 RMSLE for ('model2', 'model4') = 0.008213211663158021
# Fold 25 RMSLE for ('model3', 'model4') = 0.00844675037025953
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.008272673276090364
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.008260349072947338
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.008428898849351524
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.008268754583855797
# Fold 25 RMSLE for all models ensemble = 0.008298972347435464
# Fold 25 best combination: model2 with RMSLE = 0.008068826017726242
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.007727081741001815
# Fold 26 RMSLE for model2 = 0.007395207827223105
# Fold 26 RMSLE for model3 = 0.008166802650926506
# Fold 26 RMSLE for model4 = 0.0076966122310208
# Fold 26 RMSLE for ('model1', 'model2') = 0.007514174034813272
# Fold 26 RMSLE for ('model1', 'model3') = 0.007907316325777687
# Fold 26 RMSLE for ('model1', 'model4') = 0.007701276540944121
# Fold 26 RMSLE for ('model2', 'model3') = 0.007666251068971625
# Fold 26 RMSLE for ('model2', 'model4') = 0.007514895454782154
# Fold 26 RMSLE for ('model3', 'model4') = 0.007872598614602475
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.007673518075663765
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.007567105501612521
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.007814588818400532
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.007661359526873357
# Fold 26 RMSLE for all models ensemble = 0.007670646862722421
# Fold 26 best combination: model2 with RMSLE = 0.007395207827223105
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.007161023305238402
# Fold 27 RMSLE for model2 = 0.006979656874021677
# Fold 27 RMSLE for model3 = 0.007623167411227349
# Fold 27 RMSLE for model4 = 0.007242161762816551
# Fold 27 RMSLE for ('model1', 'model2') = 0.007002352763602044
# Fold 27 RMSLE for ('model1', 'model3') = 0.00733604277226879
# Fold 27 RMSLE for ('model1', 'model4') = 0.007170638556334777
# Fold 27 RMSLE for ('model2', 'model3') = 0.007145242820111563
# Fold 27 RMSLE for ('model2', 'model4') = 0.007076678851463521
# Fold 27 RMSLE for ('model3', 'model4') = 0.007331961983163433
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.007129837968149359
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.007068527809452551
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.007258184244349611
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007151448817727342
# Fold 27 RMSLE for all models ensemble = 0.007139351224085983
# Fold 27 best combination: model2 with RMSLE = 0.006979656874021677
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.008261192419872745
# Fold 28 RMSLE for model2 = 0.007854189831205765
# Fold 28 RMSLE for model3 = 0.008565492371829362
# Fold 28 RMSLE for model4 = 0.008230525360327107
# Fold 28 RMSLE for ('model1', 'model2') = 0.008004373845589094
# Fold 28 RMSLE for ('model1', 'model3') = 0.008374089900346288
# Fold 28 RMSLE for ('model1', 'model4') = 0.008231850221963377
# Fold 28 RMSLE for ('model2', 'model3') = 0.008094381337660472
# Fold 28 RMSLE for ('model2', 'model4') = 0.008012834856887861
# Fold 28 RMSLE for ('model3', 'model4') = 0.008334188812530613
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.008134660465925406
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.008072438561153755
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.008300155712207147
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.008123596864833979
# Fold 28 RMSLE for all models ensemble = 0.008148919750910281
# Fold 28 best combination: model2 with RMSLE = 0.007854189831205765
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.006680982821640004
# Fold 29 RMSLE for model2 = 0.0062449786696447155
# Fold 29 RMSLE for model3 = 0.007081082300012997
# Fold 29 RMSLE for model4 = 0.006660443151203941
# Fold 29 RMSLE for ('model1', 'model2') = 0.006413128803873933
# Fold 29 RMSLE for ('model1', 'model3') = 0.006829689110675399
# Fold 29 RMSLE for ('model1', 'model4') = 0.006656674532236055
# Fold 29 RMSLE for ('model2', 'model3') = 0.006548430790499108
# Fold 29 RMSLE for ('model2', 'model4') = 0.006424437308454994
# Fold 29 RMSLE for ('model3', 'model4') = 0.006803285963698667
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.006573027915524973
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.006488065397636549
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.0067480360505369225
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.006568080843612318
# Fold 29 RMSLE for all models ensemble = 0.006585115237818849
# Fold 29 best combination: model2 with RMSLE = 0.0062449786696447155
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009403666250780698
# Fold 30 RMSLE for model2 = 0.009126364804794397
# Fold 30 RMSLE for model3 = 0.009821034928967357
# Fold 30 RMSLE for model4 = 0.009308065590592938
# Fold 30 RMSLE for ('model1', 'model2') = 0.009216412484977137
# Fold 30 RMSLE for ('model1', 'model3') = 0.00957260874035114
# Fold 30 RMSLE for ('model1', 'model4') = 0.009337860141393461
# Fold 30 RMSLE for ('model2', 'model3') = 0.009358063194687112
# Fold 30 RMSLE for ('model2', 'model4') = 0.00918979088195383
# Fold 30 RMSLE for ('model3', 'model4') = 0.00949876344386936
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.00935966271077305
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009237610511893415
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009455781045251181
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009325145777976315
# Fold 30 RMSLE for all models ensemble = 0.009335666773263043
# Fold 30 best combination: model2 with RMSLE = 0.009126364804794397
# ---------------
#
# OOF RMSLE = 0.007613494606379585
# Sum of RMSLE for each combination:
# ('model1',): 0.23608100636676368
# ('model2',): 0.22736115804906412
# ('model3',): 0.24755225974434567
# ('model4',): 0.23536528951798308
# ('model1', 'model2'): 0.23035861404269825
# ('model1', 'model3'): 0.2404826778274759
# ('model1', 'model4'): 0.2353239859129915
# ('model2', 'model3'): 0.23397068510623484
# ('model2', 'model4'): 0.2305423923921088
# ('model3', 'model4'): 0.2394268225632209
# ('model1', 'model2', 'model3'): 0.2342472972896596
# ('model1', 'model2', 'model4'): 0.23179159097049024
# ('model1', 'model3', 'model4'): 0.2379828121168462
# ('model2', 'model3', 'model4'): 0.2339264794089319
# ('model1', 'model2', 'model3', 'model4'): 0.23422077077147807
#
# 1番目の学習が終わりました。
#
# 推定時間は21
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.006687611579982762
# Fold 1 RMSLE for model2 = 0.006671971336843709
# Fold 1 RMSLE for model3 = 0.0068706467810729635
# Fold 1 RMSLE for model4 = 0.006656628154785494
# Fold 1 RMSLE for ('model1', 'model2') = 0.0066492628242181525
# Fold 1 RMSLE for ('model1', 'model3') = 0.006730562651641017
# Fold 1 RMSLE for ('model1', 'model4') = 0.006661295334035401
# Fold 1 RMSLE for ('model2', 'model3') = 0.006666962444423661
# Fold 1 RMSLE for ('model2', 'model4') = 0.006650460502488113
# Fold 1 RMSLE for ('model3', 'model4') = 0.006688821885998574
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.006661673917687262
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.006647528008016186
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.006678439897950343
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.006646951835335909
# Fold 1 RMSLE for all models ensemble = 0.006650666484052436
# Fold 1 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.006646951835335909
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.005709881353842368
# Fold 2 RMSLE for model2 = 0.005676190408879423
# Fold 2 RMSLE for model3 = 0.0062115489059485895
# Fold 2 RMSLE for model4 = 0.005654928434199466
# Fold 2 RMSLE for ('model1', 'model2') = 0.0056495942558480675
# Fold 2 RMSLE for ('model1', 'model3') = 0.005887911775740978
# Fold 2 RMSLE for ('model1', 'model4') = 0.0056667746547628675
# Fold 2 RMSLE for ('model2', 'model3') = 0.005782502557416143
# Fold 2 RMSLE for ('model2', 'model4') = 0.0056449161888810755
# Fold 2 RMSLE for ('model3', 'model4') = 0.005814299355383153
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.005741523232343128
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.005644871988151279
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.005765600737788681
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.0057121048215885446
# Fold 2 RMSLE for all models ensemble = 0.005703387757824504
# Fold 2 best combination: ('model1', 'model2', 'model4') with RMSLE = 0.005644871988151279
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.006255836780446345
# Fold 3 RMSLE for model2 = 0.006036138513580182
# Fold 3 RMSLE for model3 = 0.006708062713688171
# Fold 3 RMSLE for model4 = 0.006152907347825827
# Fold 3 RMSLE for ('model1', 'model2') = 0.006112974816922328
# Fold 3 RMSLE for ('model1', 'model3') = 0.006429848370716372
# Fold 3 RMSLE for ('model1', 'model4') = 0.006193672807870022
# Fold 3 RMSLE for ('model2', 'model3') = 0.0062525264973284115
# Fold 3 RMSLE for ('model2', 'model4') = 0.006077427154365177
# Fold 3 RMSLE for ('model3', 'model4') = 0.0063445579134110445
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.006241914129992156
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.006121291878080791
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.006305552442109852
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.0061989170360216474
# Fold 3 RMSLE for all models ensemble = 0.006207700853482211
# Fold 3 best combination: model2 with RMSLE = 0.006036138513580182
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.0057986543858168675
# Fold 4 RMSLE for model2 = 0.00559427450102368
# Fold 4 RMSLE for model3 = 0.006354702969202907
# Fold 4 RMSLE for model4 = 0.005797910776367183
# Fold 4 RMSLE for ('model1', 'model2') = 0.005632205983686975
# Fold 4 RMSLE for ('model1', 'model3') = 0.006017601759206488
# Fold 4 RMSLE for ('model1', 'model4') = 0.005778545815057778
# Fold 4 RMSLE for ('model2', 'model3') = 0.0058135880492594045
# Fold 4 RMSLE for ('model2', 'model4') = 0.005667479326848378
# Fold 4 RMSLE for ('model3', 'model4') = 0.00597837920073635
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.0057890872025550075
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.00568036151381766
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.005904368919072225
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.005786407989493379
# Fold 4 RMSLE for all models ensemble = 0.005777647733945141
# Fold 4 best combination: model2 with RMSLE = 0.00559427450102368
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.006675170796620553
# Fold 5 RMSLE for model2 = 0.006220786963859566
# Fold 5 RMSLE for model3 = 0.007303994191227031
# Fold 5 RMSLE for model4 = 0.006520482518663644
# Fold 5 RMSLE for ('model1', 'model2') = 0.006403635413988953
# Fold 5 RMSLE for ('model1', 'model3') = 0.006936809075418884
# Fold 5 RMSLE for ('model1', 'model4') = 0.006580676009710958
# Fold 5 RMSLE for ('model2', 'model3') = 0.006621067611042787
# Fold 5 RMSLE for ('model2', 'model4') = 0.006353251774956505
# Fold 5 RMSLE for ('model3', 'model4') = 0.006815255855825169
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.006626991820738497
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.006437130292419719
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.006758257407729258
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.006566218371787411
# Fold 5 RMSLE for all models ensemble = 0.006586362060073874
# Fold 5 best combination: model2 with RMSLE = 0.006220786963859566
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.006912824951222025
# Fold 6 RMSLE for model2 = 0.006919134662737715
# Fold 6 RMSLE for model3 = 0.007324354400227103
# Fold 6 RMSLE for model4 = 0.006898628388941537
# Fold 6 RMSLE for ('model1', 'model2') = 0.0068717364421709394
# Fold 6 RMSLE for ('model1', 'model3') = 0.007065834937220489
# Fold 6 RMSLE for ('model1', 'model4') = 0.006889684559648791
# Fold 6 RMSLE for ('model2', 'model3') = 0.006986775289811629
# Fold 6 RMSLE for ('model2', 'model4') = 0.00688786166320114
# Fold 6 RMSLE for ('model3', 'model4') = 0.007026669974435945
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.006948537136377507
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.006874041076381569
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.006976524765027871
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.006939543430190468
# Fold 6 RMSLE for all models ensemble = 0.006924537697861441
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.0068717364421709394
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.007559072753592593
# Fold 7 RMSLE for model2 = 0.007196019123197227
# Fold 7 RMSLE for model3 = 0.00806582405746999
# Fold 7 RMSLE for model4 = 0.007377631140816683
# Fold 7 RMSLE for ('model1', 'model2') = 0.007338772730140501
# Fold 7 RMSLE for ('model1', 'model3') = 0.0077583011546481515
# Fold 7 RMSLE for ('model1', 'model4') = 0.007453637106322282
# Fold 7 RMSLE for ('model2', 'model3') = 0.007499572241376347
# Fold 7 RMSLE for ('model2', 'model4') = 0.007263210827068468
# Fold 7 RMSLE for ('model3', 'model4') = 0.007628732091580299
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.007506958500938125
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.007343344514274264
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.0075949942958287164
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.0074349910288466214
# Fold 7 RMSLE for all models ensemble = 0.007459830447541039
# Fold 7 best combination: model2 with RMSLE = 0.007196019123197227
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.007141234544474728
# Fold 8 RMSLE for model2 = 0.006897820513171292
# Fold 8 RMSLE for model3 = 0.007555326711063134
# Fold 8 RMSLE for model4 = 0.007008289955016012
# Fold 8 RMSLE for ('model1', 'model2') = 0.006984610001548521
# Fold 8 RMSLE for ('model1', 'model3') = 0.0072977038873729754
# Fold 8 RMSLE for ('model1', 'model4') = 0.007063650527008883
# Fold 8 RMSLE for ('model2', 'model3') = 0.007115084571733554
# Fold 8 RMSLE for ('model2', 'model4') = 0.006932456093732315
# Fold 8 RMSLE for ('model3', 'model4') = 0.00720458163537272
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.007110263542279112
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.006986194686564028
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.0071727433802599065
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.007059890401607434
# Fold 8 RMSLE for all models ensemble = 0.007073501004703846
# Fold 8 best combination: model2 with RMSLE = 0.006897820513171292
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.006498406110027294
# Fold 9 RMSLE for model2 = 0.0064159948300249155
# Fold 9 RMSLE for model3 = 0.006922261088123933
# Fold 9 RMSLE for model4 = 0.006413872067906994
# Fold 9 RMSLE for ('model1', 'model2') = 0.0064163169168064
# Fold 9 RMSLE for ('model1', 'model3') = 0.006649680879611945
# Fold 9 RMSLE for ('model1', 'model4') = 0.006442975393468141
# Fold 9 RMSLE for ('model2', 'model3') = 0.006528947212274129
# Fold 9 RMSLE for ('model2', 'model4') = 0.006393596031116551
# Fold 9 RMSLE for ('model3', 'model4') = 0.006570130201534923
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.0065042392200827855
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.006409233557004916
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.006534544602661848
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.006467584882963418
# Fold 9 RMSLE for all models ensemble = 0.006468119522221945
# Fold 9 best combination: ('model2', 'model4') with RMSLE = 0.006393596031116551
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.006930684465835576
# Fold 10 RMSLE for model2 = 0.0067118592671618574
# Fold 10 RMSLE for model3 = 0.0073461600666252765
# Fold 10 RMSLE for model4 = 0.006781489708770884
# Fold 10 RMSLE for ('model1', 'model2') = 0.006789692585782373
# Fold 10 RMSLE for ('model1', 'model3') = 0.0070864294634323845
# Fold 10 RMSLE for ('model1', 'model4') = 0.006845422989752775
# Fold 10 RMSLE for ('model2', 'model3') = 0.006918844137131269
# Fold 10 RMSLE for ('model2', 'model4') = 0.006722196227124646
# Fold 10 RMSLE for ('model3', 'model4') = 0.006983771824024567
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.006909749464103545
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.006778385657357302
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.006955512696523207
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.006850156977786585
# Fold 10 RMSLE for all models ensemble = 0.006864575057481334
# Fold 10 best combination: model2 with RMSLE = 0.0067118592671618574
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.006973688343707834
# Fold 11 RMSLE for model2 = 0.007066149199730528
# Fold 11 RMSLE for model3 = 0.007250733686156022
# Fold 11 RMSLE for model4 = 0.007074874198261981
# Fold 11 RMSLE for ('model1', 'model2') = 0.006974484592951013
# Fold 11 RMSLE for ('model1', 'model3') = 0.007068744167823573
# Fold 11 RMSLE for ('model1', 'model4') = 0.007011175524370357
# Fold 11 RMSLE for ('model2', 'model3') = 0.007029368459944675
# Fold 11 RMSLE for ('model2', 'model4') = 0.007046795356617344
# Fold 11 RMSLE for ('model3', 'model4') = 0.007085049830244439
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.006999638628612385
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.007001688137127178
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.007039786266977192
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.007027815046429427
# Fold 11 RMSLE for all models ensemble = 0.0070078447044941315
# Fold 11 best combination: model1 with RMSLE = 0.006973688343707834
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.006000740405910352
# Fold 12 RMSLE for model2 = 0.005557592258097382
# Fold 12 RMSLE for model3 = 0.0065029505002850456
# Fold 12 RMSLE for model4 = 0.005813942474232951
# Fold 12 RMSLE for ('model1', 'model2') = 0.005730833626239759
# Fold 12 RMSLE for ('model1', 'model3') = 0.006185207846049066
# Fold 12 RMSLE for ('model1', 'model4') = 0.005892081749984056
# Fold 12 RMSLE for ('model2', 'model3') = 0.005873918655671353
# Fold 12 RMSLE for ('model2', 'model4') = 0.005662478858978753
# Fold 12 RMSLE for ('model3', 'model4') = 0.006050812792845284
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.00589938415273763
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.00575222998974203
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.006020740620348271
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.0058284605039355545
# Fold 12 RMSLE for all models ensemble = 0.005863057982161309
# Fold 12 best combination: model2 with RMSLE = 0.005557592258097382
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.006990551458666409
# Fold 13 RMSLE for model2 = 0.006707866643542368
# Fold 13 RMSLE for model3 = 0.007565653952956785
# Fold 13 RMSLE for model4 = 0.0069314090165419435
# Fold 13 RMSLE for ('model1', 'model2') = 0.006803405963984857
# Fold 13 RMSLE for ('model1', 'model3') = 0.007230579823092884
# Fold 13 RMSLE for ('model1', 'model4') = 0.0069474129290503644
# Fold 13 RMSLE for ('model2', 'model3') = 0.006999469250988831
# Fold 13 RMSLE for ('model2', 'model4') = 0.006796317586907343
# Fold 13 RMSLE for ('model3', 'model4') = 0.0071640602979140275
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.006985209322772406
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.006839944215822698
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.007097221701402392
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.006958176839446849
# Fold 13 RMSLE for all models ensemble = 0.006960010927171648
# Fold 13 best combination: model2 with RMSLE = 0.006707866643542368
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.006554976703513825
# Fold 14 RMSLE for model2 = 0.006286928610292177
# Fold 14 RMSLE for model3 = 0.00700020068014575
# Fold 14 RMSLE for model4 = 0.006544311905877796
# Fold 14 RMSLE for ('model1', 'model2') = 0.006383039693455307
# Fold 14 RMSLE for ('model1', 'model3') = 0.006729536354579802
# Fold 14 RMSLE for ('model1', 'model4') = 0.006534512492248817
# Fold 14 RMSLE for ('model2', 'model3') = 0.00652823540986267
# Fold 14 RMSLE for ('model2', 'model4') = 0.006393256681226429
# Fold 14 RMSLE for ('model3', 'model4') = 0.006689218658368776
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.006524269659594161
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.006428633098797389
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.006634339038111237
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.00651146544384735
# Fold 14 RMSLE for all models ensemble = 0.006515461117755465
# Fold 14 best combination: model2 with RMSLE = 0.006286928610292177
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.0065573670173276815
# Fold 15 RMSLE for model2 = 0.006415562775166233
# Fold 15 RMSLE for model3 = 0.006862484132136819
# Fold 15 RMSLE for model4 = 0.006551157237918135
# Fold 15 RMSLE for ('model1', 'model2') = 0.006439953211732881
# Fold 15 RMSLE for ('model1', 'model3') = 0.006639332271736149
# Fold 15 RMSLE for ('model1', 'model4') = 0.006535511676871062
# Fold 15 RMSLE for ('model2', 'model3') = 0.006496568718611648
# Fold 15 RMSLE for ('model2', 'model4') = 0.006460193871300254
# Fold 15 RMSLE for ('model3', 'model4') = 0.0065947519966076855
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.006496018832041434
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.006468761613687784
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.006566981276081222
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.006485456037481128
# Fold 15 RMSLE for all models ensemble = 0.006492533759147266
# Fold 15 best combination: model2 with RMSLE = 0.006415562775166233
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.005452106988947992
# Fold 16 RMSLE for model2 = 0.005076507863555982
# Fold 16 RMSLE for model3 = 0.00610444092546642
# Fold 16 RMSLE for model4 = 0.005234098842086767
# Fold 16 RMSLE for ('model1', 'model2') = 0.005220397377582471
# Fold 16 RMSLE for ('model1', 'model3') = 0.005710216826980618
# Fold 16 RMSLE for ('model1', 'model4') = 0.005326861872335138
# Fold 16 RMSLE for ('model2', 'model3') = 0.005439681711169819
# Fold 16 RMSLE for ('model2', 'model4') = 0.0051336722059786375
# Fold 16 RMSLE for ('model3', 'model4') = 0.005555884753209598
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.005426646672785027
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.005217898604531713
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.0055077127335519055
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.005341862029946845
# Fold 16 RMSLE for all models ensemble = 0.005361179186807167
# Fold 16 best combination: model2 with RMSLE = 0.005076507863555982
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.0067826553656906916
# Fold 17 RMSLE for model2 = 0.006461203219490714
# Fold 17 RMSLE for model3 = 0.007308669576777279
# Fold 17 RMSLE for model4 = 0.006650878784501432
# Fold 17 RMSLE for ('model1', 'model2') = 0.006572874015708285
# Fold 17 RMSLE for ('model1', 'model3') = 0.006990431098309909
# Fold 17 RMSLE for ('model1', 'model4') = 0.006698740220529121
# Fold 17 RMSLE for ('model2', 'model3') = 0.006734939985950308
# Fold 17 RMSLE for ('model2', 'model4') = 0.00653607022946339
# Fold 17 RMSLE for ('model3', 'model4') = 0.0068805960565581055
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.006737495867136464
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.0065929110093301485
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.006836764555241693
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.006685730612258497
# Fold 17 RMSLE for all models ensemble = 0.006701920492989335
# Fold 17 best combination: model2 with RMSLE = 0.006461203219490714
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.006022666819759055
# Fold 18 RMSLE for model2 = 0.006013522451962142
# Fold 18 RMSLE for model3 = 0.0064861385317770155
# Fold 18 RMSLE for model4 = 0.006165003929533145
# Fold 18 RMSLE for ('model1', 'model2') = 0.0059756443287250684
# Fold 18 RMSLE for ('model1', 'model3') = 0.0061975047781697625
# Fold 18 RMSLE for ('model1', 'model4') = 0.006074824478636529
# Fold 18 RMSLE for ('model2', 'model3') = 0.006103999604825754
# Fold 18 RMSLE for ('model2', 'model4') = 0.00607032213384203
# Fold 18 RMSLE for ('model3', 'model4') = 0.0062218512363430515
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.006064467054812347
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.006031401829314033
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.006144068327314522
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.006101334101664629
# Fold 18 RMSLE for all models ensemble = 0.006074204075023375
# Fold 18 best combination: ('model1', 'model2') with RMSLE = 0.0059756443287250684
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.007224123326077212
# Fold 19 RMSLE for model2 = 0.007128016170181655
# Fold 19 RMSLE for model3 = 0.007577158111690967
# Fold 19 RMSLE for model4 = 0.00729277007577602
# Fold 19 RMSLE for ('model1', 'model2') = 0.007134147774155642
# Fold 19 RMSLE for ('model1', 'model3') = 0.007345324510544082
# Fold 19 RMSLE for ('model1', 'model4') = 0.0072447346685874095
# Fold 19 RMSLE for ('model2', 'model3') = 0.007221873486440748
# Fold 19 RMSLE for ('model2', 'model4') = 0.00719089454794336
# Fold 19 RMSLE for ('model3', 'model4') = 0.007348148195054958
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.007208107754876954
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.007181641482082992
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.007295015349810953
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.007226743364069305
# Fold 19 RMSLE for all models ensemble = 0.0072180077555727435
# Fold 19 best combination: model2 with RMSLE = 0.007128016170181655
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.007339254278644015
# Fold 20 RMSLE for model2 = 0.006776292733142684
# Fold 20 RMSLE for model3 = 0.00783514352675901
# Fold 20 RMSLE for model4 = 0.0071197999102729954
# Fold 20 RMSLE for ('model1', 'model2') = 0.007007756666370499
# Fold 20 RMSLE for ('model1', 'model3') = 0.007528698319489758
# Fold 20 RMSLE for ('model1', 'model4') = 0.007215321160698165
# Fold 20 RMSLE for ('model2', 'model3') = 0.007156574199579099
# Fold 20 RMSLE for ('model2', 'model4') = 0.006922201481920639
# Fold 20 RMSLE for ('model3', 'model4') = 0.007382731566028811
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.007202266271545302
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.007038554127718219
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.007356341600541616
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.007122370422932831
# Fold 20 RMSLE for all models ensemble = 0.00716863051588394
# Fold 20 best combination: model2 with RMSLE = 0.006776292733142684
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.005929650538118754
# Fold 21 RMSLE for model2 = 0.005679611944661546
# Fold 21 RMSLE for model3 = 0.006349260921542263
# Fold 21 RMSLE for model4 = 0.00592442549287204
# Fold 21 RMSLE for ('model1', 'model2') = 0.0057509811188161414
# Fold 21 RMSLE for ('model1', 'model3') = 0.0060824489903652705
# Fold 21 RMSLE for ('model1', 'model4') = 0.005910823410553991
# Fold 21 RMSLE for ('model2', 'model3') = 0.0058735609055348675
# Fold 21 RMSLE for ('model2', 'model4') = 0.0057759637652865636
# Fold 21 RMSLE for ('model3', 'model4') = 0.00604985513781897
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.005874075699025938
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.0058020679626012905
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0059959836412912925
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.005870594951467337
# Fold 21 RMSLE for all models ensemble = 0.005874812461968603
# Fold 21 best combination: model2 with RMSLE = 0.005679611944661546
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.006494198073218826
# Fold 22 RMSLE for model2 = 0.006123228590477101
# Fold 22 RMSLE for model3 = 0.006904303163071929
# Fold 22 RMSLE for model4 = 0.006401724050409733
# Fold 22 RMSLE for ('model1', 'model2') = 0.006270698697230973
# Fold 22 RMSLE for ('model1', 'model3') = 0.00664452363177853
# Fold 22 RMSLE for ('model1', 'model4') = 0.006430320917496103
# Fold 22 RMSLE for ('model2', 'model3') = 0.006391704482668369
# Fold 22 RMSLE for ('model2', 'model4') = 0.006242225355899524
# Fold 22 RMSLE for ('model3', 'model4') = 0.006562337717870539
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.006411474365596726
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.006306025855270661
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0065270880842889884
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.006371714912080848
# Fold 22 RMSLE for all models ensemble = 0.006394214544976102
# Fold 22 best combination: model2 with RMSLE = 0.006123228590477101
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.006535492581653984
# Fold 23 RMSLE for model2 = 0.00610924082363056
# Fold 23 RMSLE for model3 = 0.007152855007814789
# Fold 23 RMSLE for model4 = 0.006407742042349892
# Fold 23 RMSLE for ('model1', 'model2') = 0.006275469870036049
# Fold 23 RMSLE for ('model1', 'model3') = 0.006790945155860973
# Fold 23 RMSLE for ('model1', 'model4') = 0.006458516195824356
# Fold 23 RMSLE for ('model2', 'model3') = 0.006499872366869092
# Fold 23 RMSLE for ('model2', 'model4') = 0.00623264926933582
# Fold 23 RMSLE for ('model3', 'model4') = 0.006694254078600572
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.0064960532840117186
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.006312816214449649
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.006630187401066594
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.006447082589054188
# Fold 23 RMSLE for all models ensemble = 0.0064612149636680246
# Fold 23 best combination: model2 with RMSLE = 0.00610924082363056
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.007117215397336821
# Fold 24 RMSLE for model2 = 0.00674685821029844
# Fold 24 RMSLE for model3 = 0.007730669941053664
# Fold 24 RMSLE for model4 = 0.006920273363770107
# Fold 24 RMSLE for ('model1', 'model2') = 0.006899665143778021
# Fold 24 RMSLE for ('model1', 'model3') = 0.0073708310619144245
# Fold 24 RMSLE for ('model1', 'model4') = 0.007002504500916283
# Fold 24 RMSLE for ('model2', 'model3') = 0.007130158321736073
# Fold 24 RMSLE for ('model2', 'model4') = 0.006816298001656175
# Fold 24 RMSLE for ('model3', 'model4') = 0.007237226017792425
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.00711146680122747
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.00689882786473128
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.007185312523783167
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.007035943665804537
# Fold 24 RMSLE for all models ensemble = 0.007048651812261455
# Fold 24 best combination: model2 with RMSLE = 0.00674685821029844
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.0071041351756908795
# Fold 25 RMSLE for model2 = 0.006712357791842475
# Fold 25 RMSLE for model3 = 0.007356414118977484
# Fold 25 RMSLE for model4 = 0.007087535980698102
# Fold 25 RMSLE for ('model1', 'model2') = 0.006870500887028643
# Fold 25 RMSLE for ('model1', 'model3') = 0.007178198464619199
# Fold 25 RMSLE for ('model1', 'model4') = 0.007082949740774612
# Fold 25 RMSLE for ('model2', 'model3') = 0.006916403783409569
# Fold 25 RMSLE for ('model2', 'model4') = 0.006880689666905782
# Fold 25 RMSLE for ('model3', 'model4') = 0.00713761115605746
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.006965203326515661
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.006937064293001847
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.007116038867795041
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.0069530037978537546
# Fold 25 RMSLE for all models ensemble = 0.006983682377525623
# Fold 25 best combination: model2 with RMSLE = 0.006712357791842475
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.006449366188261988
# Fold 26 RMSLE for model2 = 0.00628097376254076
# Fold 26 RMSLE for model3 = 0.007002983092665178
# Fold 26 RMSLE for model4 = 0.006426144195879475
# Fold 26 RMSLE for ('model1', 'model2') = 0.006324883995844468
# Fold 26 RMSLE for ('model1', 'model3') = 0.0066730738514001065
# Fold 26 RMSLE for ('model1', 'model4') = 0.0064251138210757505
# Fold 26 RMSLE for ('model2', 'model3') = 0.006509033133984024
# Fold 26 RMSLE for ('model2', 'model4') = 0.0063313213307473444
# Fold 26 RMSLE for ('model3', 'model4') = 0.006626770354213984
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.006476621287672311
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.006352140627896149
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.00655720912922197
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.006460832222036578
# Fold 26 RMSLE for all models ensemble = 0.006451595899409797
# Fold 26 best combination: model2 with RMSLE = 0.00628097376254076
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.00598838228069431
# Fold 27 RMSLE for model2 = 0.005816453841624922
# Fold 27 RMSLE for model3 = 0.00663043354280535
# Fold 27 RMSLE for model4 = 0.00602160921339286
# Fold 27 RMSLE for ('model1', 'model2') = 0.005832351771199729
# Fold 27 RMSLE for ('model1', 'model3') = 0.006241098284250313
# Fold 27 RMSLE for ('model1', 'model4') = 0.0059774659985211386
# Fold 27 RMSLE for ('model2', 'model3') = 0.0060285672512055246
# Fold 27 RMSLE for ('model2', 'model4') = 0.005886792133341552
# Fold 27 RMSLE for ('model3', 'model4') = 0.006201581853401861
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.005996207367430328
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.005884550007532483
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.00611447236537443
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.005997931931142437
# Fold 27 RMSLE for all models ensemble = 0.005983271570495093
# Fold 27 best combination: model2 with RMSLE = 0.005816453841624922
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.006917549034541638
# Fold 28 RMSLE for model2 = 0.0067284427800366605
# Fold 28 RMSLE for model3 = 0.007299596005049915
# Fold 28 RMSLE for model4 = 0.006810473596081183
# Fold 28 RMSLE for ('model1', 'model2') = 0.006782286571744521
# Fold 28 RMSLE for ('model1', 'model3') = 0.007057973138233665
# Fold 28 RMSLE for ('model1', 'model4') = 0.006850524673720582
# Fold 28 RMSLE for ('model2', 'model3') = 0.006890368704887971
# Fold 28 RMSLE for ('model2', 'model4') = 0.006749638298274133
# Fold 28 RMSLE for ('model3', 'model4') = 0.006968781193005175
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.006886038838459674
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.006785932253352139
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.006941943371571666
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.00684313315803317
# Fold 28 RMSLE for all models ensemble = 0.006854692804685641
# Fold 28 best combination: model2 with RMSLE = 0.0067284427800366605
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.005544652413303804
# Fold 29 RMSLE for model2 = 0.0052977573812055204
# Fold 29 RMSLE for model3 = 0.0059673075885632015
# Fold 29 RMSLE for model4 = 0.005491860193214559
# Fold 29 RMSLE for ('model1', 'model2') = 0.005382598448852041
# Fold 29 RMSLE for ('model1', 'model3') = 0.005699091328428593
# Fold 29 RMSLE for ('model1', 'model4') = 0.0055005107238202304
# Fold 29 RMSLE for ('model2', 'model3') = 0.005517421306429155
# Fold 29 RMSLE for ('model2', 'model4') = 0.0053699282665021116
# Fold 29 RMSLE for ('model3', 'model4') = 0.005640990364044648
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.005509160249677536
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.005408702077321617
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.0055947561867389015
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.005482901071924416
# Fold 29 RMSLE for all models ensemble = 0.005489014483635439
# Fold 29 best combination: model2 with RMSLE = 0.0052977573812055204
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.007823382073633579
# Fold 30 RMSLE for model2 = 0.007442310883246138
# Fold 30 RMSLE for model3 = 0.008273603821551578
# Fold 30 RMSLE for model4 = 0.007616733199778275
# Fold 30 RMSLE for ('model1', 'model2') = 0.00759340198938389
# Fold 30 RMSLE for ('model1', 'model3') = 0.007998522756599638
# Fold 30 RMSLE for ('model1', 'model4') = 0.007702055506583912
# Fold 30 RMSLE for ('model2', 'model3') = 0.007737764322875071
# Fold 30 RMSLE for ('model2', 'model4') = 0.00750926301339338
# Fold 30 RMSLE for ('model3', 'model4') = 0.007859991765243178
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.007753068563619836
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.0075929342317069635
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.007836081307826431
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.007676159752882697
# Fold 30 RMSLE for all models ensemble = 0.007705015508865013
# Fold 30 best combination: model2 with RMSLE = 0.007442310883246138
# ---------------
#
# OOF RMSLE = 0.006376425326884317
# Sum of RMSLE for each combination:
# ('model1',): 0.19797153218656074
# ('model2',): 0.19076706805520555
# ('model3',): 0.21182388271189553
# ('model4',): 0.19574953619674312
# ('model1', 'model2'): 0.19307417771593346
# ('model1', 'model3'): 0.20322296661523603
# ('model1', 'model4'): 0.19639829746023585
# ('model2', 'model3'): 0.19726535467444192
# ('model2', 'model4'): 0.1925998278453029
# ('model3', 'model4'): 0.20100770495952633
# ('model1', 'model2', 'model3'): 0.19706381216724847
# ('model1', 'model2', 'model4'): 0.19375710866808596
# ('model1', 'model3', 'model4'): 0.19964458349329142
# ('model2', 'model3', 'model4'): 0.19609147922991382
# ('model1', 'model2', 'model3', 'model4'): 0.19632534556368492
#
# 2番目の学習が終わりました。
#
# 推定時間は18
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.005771625396426047
# Fold 1 RMSLE for model2 = 0.0057370201916442575
# Fold 1 RMSLE for model3 = 0.005911560413438728
# Fold 1 RMSLE for model4 = 0.005754106806541898
# Fold 1 RMSLE for ('model1', 'model2') = 0.005729995705337422
# Fold 1 RMSLE for ('model1', 'model3') = 0.0058047583341937535
# Fold 1 RMSLE for ('model1', 'model4') = 0.005754755593148674
# Fold 1 RMSLE for ('model2', 'model3') = 0.005741814684757433
# Fold 1 RMSLE for ('model2', 'model4') = 0.005732035471586386
# Fold 1 RMSLE for ('model3', 'model4') = 0.005773866132331426
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.005742767596116021
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.005733821373930182
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.005766106852210283
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.0057317739565479935
# Fold 1 RMSLE for all models ensemble = 0.0057373077885070345
# Fold 1 best combination: ('model1', 'model2') with RMSLE = 0.005729995705337422
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.0050304720700826795
# Fold 2 RMSLE for model2 = 0.00500428307763006
# Fold 2 RMSLE for model3 = 0.005381806257799308
# Fold 2 RMSLE for model4 = 0.0050032395571978985
# Fold 2 RMSLE for ('model1', 'model2') = 0.0049831947084204254
# Fold 2 RMSLE for ('model1', 'model3') = 0.005150620630238966
# Fold 2 RMSLE for ('model1', 'model4') = 0.00500464384965654
# Fold 2 RMSLE for ('model2', 'model3') = 0.005069340940541917
# Fold 2 RMSLE for ('model2', 'model4') = 0.004987149637790916
# Fold 2 RMSLE for ('model3', 'model4') = 0.0051015775440313525
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.0050434228047549915
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.004984648654273587
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.005067367177964358
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.0050259857661236465
# Fold 2 RMSLE for all models ensemble = 0.0050207365820814365
# Fold 2 best combination: ('model1', 'model2') with RMSLE = 0.0049831947084204254
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.0055497018891331054
# Fold 3 RMSLE for model2 = 0.0055294512745811845
# Fold 3 RMSLE for model3 = 0.0059082461487837525
# Fold 3 RMSLE for model4 = 0.005457277704767728
# Fold 3 RMSLE for ('model1', 'model2') = 0.0055041636025673244
# Fold 3 RMSLE for ('model1', 'model3') = 0.005688570706987512
# Fold 3 RMSLE for ('model1', 'model4') = 0.0054941795066857976
# Fold 3 RMSLE for ('model2', 'model3') = 0.005609280340587257
# Fold 3 RMSLE for ('model2', 'model4') = 0.005474129018088066
# Fold 3 RMSLE for ('model3', 'model4') = 0.0056142110499993025
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.005579698550997238
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.00548367023570465
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.005585421497881766
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.005543102187404597
# Fold 3 RMSLE for all models ensemble = 0.005539844419433412
# Fold 3 best combination: model4 with RMSLE = 0.005457277704767728
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.00513741908280331
# ...
# Fold 16 RMSLE for model4 = 0.0030538027670302496
# Fold 16 RMSLE for ('model1', 'model2') = 0.003039117337109592
# Fold 16 RMSLE for ('model1', 'model3') = 0.0031201912097244345
# Fold 16 RMSLE for ('model1', 'model4') = 0.0030590337656083667
# Fold 16 RMSLE for ('model2', 'model3') = 0.0030784346802985264
# Fold 16 RMSLE for ('model2', 'model4') = 0.0030367679628407807
# Fold 16 RMSLE for ('model3', 'model4') = 0.0031016675390921457
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.0030706210517453913
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.003042503416960657
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.003087337129033466
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.0030632040858667255
# Fold 16 RMSLE for all models ensemble = 0.003062587019685984
# Fold 16 best combination: model2 with RMSLE = 0.003031831814840718
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.0038538770668448295
# Fold 17 RMSLE for model2 = 0.003828198605614227
# Fold 17 RMSLE for model3 = 0.004007448592631035
# Fold 17 RMSLE for model4 = 0.003849317029546375
# Fold 17 RMSLE for ('model1', 'model2') = 0.003830822585836212
# Fold 17 RMSLE for ('model1', 'model3') = 0.003913140029572512
# Fold 17 RMSLE for ('model1', 'model4') = 0.003848575330408846
# Fold 17 RMSLE for ('model2', 'model3') = 0.003883590307583248
# Fold 17 RMSLE for ('model2', 'model4') = 0.0038330267332074624
# Fold 17 RMSLE for ('model3', 'model4') = 0.003904284787395499
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.003868870690271856
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.003835370417827765
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.003883602170764791
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.003866368363239581
# Fold 17 RMSLE for all models ensemble = 0.0038608621623863098
# Fold 17 best combination: model2 with RMSLE = 0.003828198605614227
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.0030890349265306123
# Fold 18 RMSLE for model2 = 0.0031496074573290557
# Fold 18 RMSLE for model3 = 0.0032341393907771767
# Fold 18 RMSLE for model4 = 0.0031378223457280735
# Fold 18 RMSLE for ('model1', 'model2') = 0.0031083724770587847
# Fold 18 RMSLE for ('model1', 'model3') = 0.003141376945176868
# Fold 18 RMSLE for ('model1', 'model4') = 0.003110221517986516
# Fold 18 RMSLE for ('model2', 'model3') = 0.0031566864591102755
# Fold 18 RMSLE for ('model2', 'model4') = 0.003137234850899132
# Fold 18 RMSLE for ('model3', 'model4') = 0.0031604376333387502
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.0031279700611647043
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.0031163138203328345
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.0031317841678401986
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.0031438740781365533
# Fold 18 RMSLE for all models ensemble = 0.0031271036560718154
# Fold 18 best combination: model1 with RMSLE = 0.0030890349265306123
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.003721890110064332
# Fold 19 RMSLE for model2 = 0.003775816683861236
# Fold 19 RMSLE for model3 = 0.003790066795115975
# Fold 19 RMSLE for model4 = 0.003743740263043101
# Fold 19 RMSLE for ('model1', 'model2') = 0.0037388749631998906
# Fold 19 RMSLE for ('model1', 'model3') = 0.0037393725524303943
# Fold 19 RMSLE for ('model1', 'model4') = 0.003729857253512992
# Fold 19 RMSLE for ('model2', 'model3') = 0.003749603051740436
# Fold 19 RMSLE for ('model2', 'model4') = 0.003754322061843931
# Fold 19 RMSLE for ('model3', 'model4') = 0.0037442022034353023
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.0037359009101778865
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.00373896854888036
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.0037330729955645982
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.0037425042154035568
# Fold 19 RMSLE for all models ensemble = 0.00373506050747639
# Fold 19 best combination: model1 with RMSLE = 0.003721890110064332
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0036247252611322786
# Fold 20 RMSLE for model2 = 0.0035915946751398148
# Fold 20 RMSLE for model3 = 0.0036784609899690427
# Fold 20 RMSLE for model4 = 0.0036213755050191294
# Fold 20 RMSLE for ('model1', 'model2') = 0.003598955234243005
# Fold 20 RMSLE for ('model1', 'model3') = 0.0036337843752867753
# Fold 20 RMSLE for ('model1', 'model4') = 0.003620287505689367
# Fold 20 RMSLE for ('model2', 'model3') = 0.0036036997825670525
# Fold 20 RMSLE for ('model2', 'model4') = 0.003601091256276786
# Fold 20 RMSLE for ('model3', 'model4') = 0.003626722344291541
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.0036056255168145424
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.0036048536489685905
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.0036220294006349815
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.00360378679188669
# Fold 20 RMSLE for all models ensemble = 0.0036065622110674324
# Fold 20 best combination: model2 with RMSLE = 0.0035915946751398148
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.0030887421166619087
# Fold 21 RMSLE for model2 = 0.0032035939817188098
# Fold 21 RMSLE for model3 = 0.003222832857069154
# Fold 21 RMSLE for model4 = 0.003134470723128797
# Fold 21 RMSLE for ('model1', 'model2') = 0.0031292642851049853
# Fold 21 RMSLE for ('model1', 'model3') = 0.0031383443054270642
# Fold 21 RMSLE for ('model1', 'model4') = 0.0031070207775973743
# Fold 21 RMSLE for ('model2', 'model3') = 0.003172433453152178
# Fold 21 RMSLE for ('model2', 'model4') = 0.0031593062407858797
# Fold 21 RMSLE for ('model3', 'model4') = 0.003153300323032905
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.003138176079151866
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.0031283667557972807
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.003127520456549075
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.0031531437349887146
# Fold 21 RMSLE for all models ensemble = 0.003133547535032323
# Fold 21 best combination: model1 with RMSLE = 0.0030887421166619087
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0035025068651297763
# Fold 22 RMSLE for model2 = 0.0035111861782322748
# Fold 22 RMSLE for model3 = 0.0035907655607207863
# Fold 22 RMSLE for model4 = 0.0035167201037727817
# Fold 22 RMSLE for ('model1', 'model2') = 0.003496975673335768
# Fold 22 RMSLE for ('model1', 'model3') = 0.0035292149376010364
# Fold 22 RMSLE for ('model1', 'model4') = 0.0035065171556666326
# Fold 22 RMSLE for ('model2', 'model3') = 0.003519975847475716
# Fold 22 RMSLE for ('model2', 'model4') = 0.003508891270398582
# Fold 22 RMSLE for ('model3', 'model4') = 0.0035308990808840734
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0035088479836487747
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.0035021259333073277
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0035173317517017844
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.003513305486230114
# Fold 22 RMSLE for all models ensemble = 0.003507891302687266
# Fold 22 best combination: ('model1', 'model2') with RMSLE = 0.003496975673335768
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.0033534708122563745
# Fold 23 RMSLE for model2 = 0.0032666406892877193
# Fold 23 RMSLE for model3 = 0.003540863468467469
# Fold 23 RMSLE for model4 = 0.003356766930700674
# Fold 23 RMSLE for ('model1', 'model2') = 0.003299195150136505
# Fold 23 RMSLE for ('model1', 'model3') = 0.003427228112718279
# Fold 23 RMSLE for ('model1', 'model4') = 0.0033513914975427045
# Fold 23 RMSLE for ('model2', 'model3') = 0.0033671529926521605
# Fold 23 RMSLE for ('model2', 'model4') = 0.0033065864495102223
# Fold 23 RMSLE for ('model3', 'model4') = 0.0034208636471936477
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.0033568963806672367
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.0033168847184212934
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.0033939281985501265
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0033568772781415127
# Fold 23 RMSLE for all models ensemble = 0.0033531624755515836
# Fold 23 best combination: model2 with RMSLE = 0.0032666406892877193
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.003621507448403612
# Fold 24 RMSLE for model2 = 0.003604768223696197
# Fold 24 RMSLE for model3 = 0.003804350959213619
# Fold 24 RMSLE for model4 = 0.003629362466765395
# Fold 24 RMSLE for ('model1', 'model2') = 0.003600872489389815
# Fold 24 RMSLE for ('model1', 'model3') = 0.0036972668287441716
# Fold 24 RMSLE for ('model1', 'model4') = 0.003622134861075037
# Fold 24 RMSLE for ('model2', 'model3') = 0.003672239824571306
# Fold 24 RMSLE for ('model2', 'model4') = 0.003609971831723917
# Fold 24 RMSLE for ('model3', 'model4') = 0.003695982592270343
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.003650005839688456
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.0036084810437729794
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.003667258236217068
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.0036525547380016894
# Fold 24 RMSLE for all models ensemble = 0.0036419754518608087
# Fold 24 best combination: ('model1', 'model2') with RMSLE = 0.003600872489389815
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.0038123406150289345
# Fold 25 RMSLE for model2 = 0.0037646912011976264
# Fold 25 RMSLE for model3 = 0.0038867064797261834
# Fold 25 RMSLE for model4 = 0.003799059023141233
# Fold 25 RMSLE for ('model1', 'model2') = 0.0037786471808197754
# Fold 25 RMSLE for ('model1', 'model3') = 0.0038334745059673716
# Fold 25 RMSLE for ('model1', 'model4') = 0.003803472756328952
# Fold 25 RMSLE for ('model2', 'model3') = 0.0037957246851711354
# Fold 25 RMSLE for ('model2', 'model4') = 0.003775697860251112
# Fold 25 RMSLE for ('model3', 'model4') = 0.003822938621347779
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.0037963664004272645
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.0037839163304402203
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.0038156678202100505
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.003791816965801019
# Fold 25 RMSLE for all models ensemble = 0.0037945782851954686
# Fold 25 best combination: model2 with RMSLE = 0.0037646912011976264
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.003320415132325455
# Fold 26 RMSLE for model2 = 0.0033434047342243613
# Fold 26 RMSLE for model3 = 0.0034690283947248104
# Fold 26 RMSLE for model4 = 0.0033257423293019347
# Fold 26 RMSLE for ('model1', 'model2') = 0.0033212133472169214
# Fold 26 RMSLE for ('model1', 'model3') = 0.0033753711470878413
# Fold 26 RMSLE for ('model1', 'model4') = 0.003320004774239714
# Fold 26 RMSLE for ('model2', 'model3') = 0.0033664629946659956
# Fold 26 RMSLE for ('model2', 'model4') = 0.003327933722075474
# Fold 26 RMSLE for ('model3', 'model4') = 0.003370599870327402
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.0033464571054764836
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.003320777297230497
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.003349728771501466
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.003346699244432798
# Fold 26 RMSLE for all models ensemble = 0.003337890938316432
# Fold 26 best combination: ('model1', 'model4') with RMSLE = 0.003320004774239714
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.003226364225212463
# Fold 27 RMSLE for model2 = 0.003261291247177911
# Fold 27 RMSLE for model3 = 0.0033638861925316976
# Fold 27 RMSLE for model4 = 0.003234702288312951
# Fold 27 RMSLE for ('model1', 'model2') = 0.0032279357044143323
# Fold 27 RMSLE for ('model1', 'model3') = 0.003275097649759135
# Fold 27 RMSLE for ('model1', 'model4') = 0.0032252346939524593
# Fold 27 RMSLE for ('model2', 'model3') = 0.0032664915216334364
# Fold 27 RMSLE for ('model2', 'model4') = 0.0032395766123524705
# Fold 27 RMSLE for ('model3', 'model4') = 0.0032689257803780636
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.0032472556711875965
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.003227615423087439
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.0032501053233408737
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.003248721922610602
# Fold 27 RMSLE for all models ensemble = 0.003239846973561548
# Fold 27 best combination: ('model1', 'model4') with RMSLE = 0.0032252346939524593
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.003684995833588684
# Fold 28 RMSLE for model2 = 0.003644516841371039
# Fold 28 RMSLE for model3 = 0.003794742406211861
# Fold 28 RMSLE for model4 = 0.0036836175493478703
# Fold 28 RMSLE for ('model1', 'model2') = 0.003655647997130743
# Fold 28 RMSLE for ('model1', 'model3') = 0.003722400056893794
# Fold 28 RMSLE for ('model1', 'model4') = 0.0036810244295892663
# Fold 28 RMSLE for ('model2', 'model3') = 0.0036861833489301443
# Fold 28 RMSLE for ('model2', 'model4') = 0.0036594142174671334
# Fold 28 RMSLE for ('model3', 'model4') = 0.003715549080786146
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.0036813361322736416
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.0036634732552922092
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.0037013170279818594
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.0036800762233688334
# Fold 28 RMSLE for all models ensemble = 0.0036789647889307426
# Fold 28 best combination: model2 with RMSLE = 0.003644516841371039
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.002991790613627559
# Fold 29 RMSLE for model2 = 0.002935705953721084
# Fold 29 RMSLE for model3 = 0.0030832809858624727
# Fold 29 RMSLE for model4 = 0.002972295775741406
# Fold 29 RMSLE for ('model1', 'model2') = 0.0029515914718678763
# Fold 29 RMSLE for ('model1', 'model3') = 0.0030175433461357387
# Fold 29 RMSLE for ('model1', 'model4') = 0.002978183537131915
# Fold 29 RMSLE for ('model2', 'model3') = 0.0029772485983396513
# Fold 29 RMSLE for ('model2', 'model4') = 0.0029466051415534653
# Fold 29 RMSLE for ('model3', 'model4') = 0.003002793888804048
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.0029748963558213293
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.002956200307649268
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.0029939882313394115
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0029682302171449276
# Fold 29 RMSLE for all models ensemble = 0.002970485115605
# Fold 29 best combination: model2 with RMSLE = 0.002935705953721084
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.003918140411676452
# Fold 30 RMSLE for model2 = 0.0039127502153834546
# Fold 30 RMSLE for model3 = 0.004016174503184081
# Fold 30 RMSLE for model4 = 0.003918684034526284
# Fold 30 RMSLE for ('model1', 'model2') = 0.003906795764212358
# Fold 30 RMSLE for ('model1', 'model3') = 0.003952801818377173
# Fold 30 RMSLE for ('model1', 'model4') = 0.003916093214811403
# Fold 30 RMSLE for ('model2', 'model3') = 0.003938543128810481
# Fold 30 RMSLE for ('model2', 'model4') = 0.003909732874150468
# Fold 30 RMSLE for ('model3', 'model4') = 0.003949113112751531
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.003927229348221613
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.003908990752586244
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.003935396692722927
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.003926818807997929
# Fold 30 RMSLE for all models ensemble = 0.003922483861102221
# Fold 30 best combination: ('model1', 'model2') with RMSLE = 0.003906795764212358
# ---------------
#
# OOF RMSLE = 0.003457237306441411
# Sum of RMSLE for each combination:
# ('model1',): 0.10400454372392892
# ('model2',): 0.10426409914860427
# ('model3',): 0.10712989141506532
# ('model4',): 0.10438260668276653
# ('model1', 'model2'): 0.10379877401638105
# ('model1', 'model3'): 0.10500500953850127
# ('model1', 'model4'): 0.10409116906342235
# ('model2', 'model3'): 0.10461613827987515
# ('model2', 'model4'): 0.10413298608939926
# ('model3', 'model4'): 0.10499450728471633
# ('model1', 'model2', 'model3'): 0.10425089627013018
# ('model1', 'model2', 'model4'): 0.10393782631996684
# ('model1', 'model3', 'model4'): 0.10453599451620597
# ('model2', 'model3', 'model4'): 0.10435227234747436
# ('model1', 'model2', 'model3', 'model4'): 0.10418370233080292
#
# 9番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                        0.000000                     0.000000           221
# 2                        0.000000                     0.000000             4
# 3                        0.000000                     0.000000            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 7158                     0.000000                     0.000000           240
# 7159                     0.000000                     0.000000             4
# 7160                 25069.498286                 24560.172725           132
# 7161                 93118.705227                130326.946431            98
# 7162                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 7158                           110523.066755
# 7159                                0.000000
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42089.796208  0.002956
# 1                  14            1     58715.193366 -0.003678
# 2                   9            1     99455.124306 -0.000459
# 3                  15            1     51700.643032 -0.001497
# 4                  15            0     50753.356090 -0.002277
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42089.796208  0.002956
# 1                  14            1     58715.193366 -0.003678
# 2                   9            1     99455.124306 -0.000459
# 3                  15            1     51700.643032 -0.001497
# 4                  15            0     50753.356090 -0.002277
# ...               ...          ...              ...       ...
# 4650               15            0     49418.623996 -0.003994
# 4651                8            1    169103.512747  0.003133
# 4652                8            0     31777.443708 -0.001925
# 4653                8            0     65619.949619  0.000659
# 4654                9            1    146085.801355 -0.004445
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, -0.00)

# %%
train_df_GHG14
# Out:
# 0        42214.415787
# 1        58499.609696
# 2        99409.449782
# 3        51623.314588
# 4        50637.897032
#             ...
# 4650     49221.615755
# 4651    169634.209493
# 4652     31716.323514
# 4653     65663.219471
# 4654    145437.817997
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.561571e+04  0.011449
# 1                  14            1     2.902851e+05 -0.009013
# 2                   8            0     4.146039e+04  0.004741
# 3                   8            0     2.858531e+04 -0.022208
# 4                   8            0     4.936711e+04  0.016946
# ...               ...          ...              ...       ...
# 2503                1            1     5.550414e+05  0.027199
# 2504                9            1     9.861394e+04 -0.009746
# 2505                8            0     1.408011e+05  0.022125
# 2506                8            0     2.620674e+05 -0.005393
# 2507                9            1     1.474331e+06  0.065402
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232717.38711867065

# %%
print(np.expm1(np.log1p(10)))
# Out:
# 10.000000000000002

# %%
def after_act(preds):
    r = preds.copy()
    r_min = r.min()
    max_w = 10.4-np.log1p(r_min)
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            # print(r[i]-np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w))
            r[i] = np.expm1(np.log1p(r[i])-0.7*(10.4-np.log1p(r[i]))**2/max_w**2)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 190361.82743415618

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_76.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,616
# 1     4656   290,285
# 2     4657    41,460
# 3     4658    27,300
# 4     4659    49,367
# ...    ...       ...
# 2503  7158   555,041
# 2504  7159    98,614
# 2505  7160   140,801
# 2506  7161   262,067
# 2507  7162 1,474,331
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,149,416
# 43    4698 1,194,827
# 110   4765 1,383,826
# 114   4769 1,299,959
# 148   4803 1,737,761
# ...    ...       ...
# 2417  7072 1,243,468
# 2423  7078 1,207,060
# 2466  7121 1,678,414
# 2490  7145 1,426,861
# 2507  7162 1,474,331
#
# [113 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sat Nov 30 12:34:50 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,090     0
# 1                  14            1           58,715    -0
# 2                   9            1           99,455    -0
# 3                  15            1           51,701    -0
# 4                  15            0           50,753    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,419    -0
# 4651                8            1          169,104     0
# 4652                8            0           31,777    -0
# 4653                8            0           65,620     0
# 4654                9            1          146,086    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.004252028357676818

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,090     0
# 1                  14            1           58,715    -0
# 2                   9            1           99,455    -0
# 3                  15            1           51,701    -0
# 4                  15            0           50,753    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,419    -0
# 4651                8            1          169,104     0
# 4652                8            0           31,777    -0
# 4653                8            0           65,620     0
# 4654                9            1          146,086    -0
#
# [4655 rows x 19 columns]
