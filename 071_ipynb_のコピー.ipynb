# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/071_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_079.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_079.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 2503                            1.105231e+05
# 2504                                     NaN
# 2505                            1.665202e+05
# 2506                            7.177380e+04
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                  14            1     5.498668e+04
# 1                   1            1     3.831258e+04
# 2                   8            1     5.862256e+05
# 3                   1            1     4.311746e+04
# 4                   8            0     4.952723e+05
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.312985e+04
# 1                                 3.622895e+04
# 2                                 6.633360e+05
# 3                                 4.085155e+04
# 4                                 4.555892e+05
# ...                                        ...
# 2503                              5.287770e+05
# 2504                              1.098642e+05
# 2505                              1.388429e+05
# 2506                              2.561824e+05
# 2507                              1.375688e+06
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 1

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 2503                            1.105231e+05
# 2504                                     NaN
# 2505                            1.665202e+05
# 2506                            7.177380e+04
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                  14            1     5.498668e+04
# 1                   1            1     3.831258e+04
# 2                   8            1     5.862256e+05
# 3                   1            1     4.311746e+04
# 4                   8            0     4.952723e+05
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.312985e+04
# 1                                 3.622895e+04
# 2                                 6.633360e+05
# 3                                 4.085155e+04
# 4                                 4.555892e+05
# ...                                        ...
# 2503                              5.287770e+05
# 2504                              1.098642e+05
# 2505                              1.388429e+05
# 2506                              2.561824e+05
# 2507                              1.375688e+06
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4654, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 2503                            1.105231e+05
# 2504                                     NaN
# 2505                            1.665202e+05
# 2506                            7.177380e+04
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                  14            1     5.498668e+04
# 1                   1            1     3.831258e+04
# 2                   8            1     5.862256e+05
# 3                   1            1     4.311746e+04
# 4                   8            0     4.952723e+05
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 5.312985e+04 -0.034351
# 1                                 3.622895e+04 -0.055918
# 2                                 6.633360e+05  0.123577
# 3                                 4.085155e+04 -0.053982
# 4                                 4.555892e+05 -0.083516
# ...                                        ...       ...
# 2503                              5.287770e+05  0.010833
# 2504                              1.098642e+05  0.090958
# 2505                              1.388429e+05  0.028513
# 2506                              2.561824e+05 -0.024815
# 2507                              1.375688e+06  0.059695
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 4650                          NaN                          NaN           240
# 4651                          NaN                          NaN            21
# 4652                          NaN                          NaN             3
# 4653                          NaN                          NaN           244
# 4654                          NaN                          NaN           241
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 4650                            2.046407e+06
# 4651                            7.034661e+04
# 4652                            2.083754e+05
# 4653                            5.637561e+05
# 4654                            6.745123e+04
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 4650                           275336.593090
# 4651                            81110.577100
# 4652                            57066.624445
# 4653                           598881.479485
# 4654                            27397.929966
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 4650                            4.630881e+06
# 4651                            5.442830e+04
# 4652                            4.858030e+04
# 4653                            1.665103e+06
# 4654                            3.922795e+04
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 4650                            99464.465641  37.156900  -87.380900
# 4651                            29108.448339  37.220511  -82.018916
# 4652                            26892.366779  42.684900 -109.780000
# 4653                           543206.073134  35.484260  -97.498570
# 4654                            46634.777768  39.404310  -76.319820
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                  14            1     5.498668e+04 -0.034351
# 1                   1            1     3.831258e+04 -0.055918
# 2                   8            1     5.862256e+05  0.123577
# 3                   1            1     4.311746e+04 -0.053982
# 4                   8            0     4.952723e+05 -0.083516
# ...               ...          ...              ...       ...
# 4650                1            1     1.009471e+06  0.043418
# 4651               15            1     5.596748e+04 -0.009960
# 4652                9            1     5.023926e+04 -0.030310
# 4653                5            1     1.089507e+06 -0.000069
# 4654                1            1     4.087778e+04 -0.047170
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 2503                            1.105231e+05
# 2504                                     NaN
# 2505                            1.665202e+05
# 2506                            7.177380e+04
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                  14            1     5.498668e+04 -0.034351
# 1                   1            1     3.831258e+04 -0.055918
# 2                   8            1     5.862256e+05  0.123577
# 3                   1            1     4.311746e+04 -0.053982
# 4                   8            0     4.952723e+05 -0.083516
# ...               ...          ...              ...       ...
# 2503                1            1     5.230794e+05  0.010833
# 2504                9            1     1.003121e+05  0.090958
# 2505                8            0     1.349400e+05  0.028513
# 2506                8            0     2.626193e+05 -0.024815
# 2507                9            1     1.295969e+06  0.059695
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 4650                          NaN                          NaN           240
# 4651                          NaN                          NaN            21
# 4652                          NaN                          NaN             3
# 4653                          NaN                          NaN           244
# 4654                          NaN                          NaN           241
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 4650                            2.046407e+06
# 4651                            7.034661e+04
# 4652                            2.083754e+05
# 4653                            5.637561e+05
# 4654                            6.745123e+04
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 4650                           275336.593090
# 4651                            81110.577100
# 4652                            57066.624445
# 4653                           598881.479485
# 4654                            27397.929966
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 4650                            4.630881e+06
# 4651                            5.442830e+04
# 4652                            4.858030e+04
# 4653                            1.665103e+06
# 4654                            3.922795e+04
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 4650                            99464.465641  37.156900  -87.380900
# 4651                            29108.448339  37.220511  -82.018916
# 4652                            26892.366779  42.684900 -109.780000
# 4653                           543206.073134  35.484260  -97.498570
# 4654                            46634.777768  39.404310  -76.319820
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                  14            1     5.498668e+04 -0.034351
# 1                   1            1     3.831258e+04 -0.055918
# 2                   8            1     5.862256e+05  0.123577
# 3                   1            1     4.311746e+04 -0.053982
# 4                   8            0     4.952723e+05 -0.083516
# ...               ...          ...              ...       ...
# 4650                1            1     1.009471e+06  0.043418
# 4651               15            1     5.596748e+04 -0.009960
# 4652                9            1     5.023926e+04 -0.030310
# 4653                5            1     1.089507e+06 -0.000069
# 4654                1            1     4.087778e+04 -0.047170
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
import time
epock = 10
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.029325033170675644
# Fold 18 RMSLE for ('model1', 'model3') = 0.029783205113639914
# Fold 18 RMSLE for ('model1', 'model4') = 0.029807235881355188
# Fold 18 RMSLE for ('model2', 'model3') = 0.02915365703143831
# Fold 18 RMSLE for ('model2', 'model4') = 0.029383184536601072
# Fold 18 RMSLE for ('model3', 'model4') = 0.029696365656799662
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.029365962502743898
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.029466397647546803
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.029733757220006467
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.02935217898563101
# Fold 18 RMSLE for all models ensemble = 0.029457014244999594
# Fold 18 best combination: model2 with RMSLE = 0.02910157218497836
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.02424624337616052
# Fold 19 RMSLE for model2 = 0.02359553999170524
# Fold 19 RMSLE for model3 = 0.024307875049075722
# Fold 19 RMSLE for model4 = 0.02451663862339853
# Fold 19 RMSLE for ('model1', 'model2') = 0.023797423130761615
# Fold 19 RMSLE for ('model1', 'model3') = 0.024187844344976006
# Fold 19 RMSLE for ('model1', 'model4') = 0.02434107516592122
# Fold 19 RMSLE for ('model2', 'model3') = 0.023679331524256716
# Fold 19 RMSLE for ('model2', 'model4') = 0.023968317997776475
# Fold 19 RMSLE for ('model3', 'model4') = 0.024244120554617252
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.023834654969899293
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.024007977441337185
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.02422452812593021
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.023905335750014002
# Fold 19 RMSLE for all models ensemble = 0.02397155293472679
# Fold 19 best combination: model2 with RMSLE = 0.02359553999170524
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.026439677531233982
# Fold 20 RMSLE for model2 = 0.026898826901807303
# Fold 20 RMSLE for model3 = 0.02558003190580525
# Fold 20 RMSLE for model4 = 0.027480127269547436
# Fold 20 RMSLE for ('model1', 'model2') = 0.02643107596098372
# Fold 20 RMSLE for ('model1', 'model3') = 0.02587817611191595
# Fold 20 RMSLE for ('model1', 'model4') = 0.026863417484922925
# Fold 20 RMSLE for ('model2', 'model3') = 0.025604271519785646
# Fold 20 RMSLE for ('model2', 'model4') = 0.027077535743581172
# Fold 20 RMSLE for ('model3', 'model4') = 0.02617822773960421
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.025859665103514343
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.02674154245962289
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.02624233062037728
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.026168774358034868
# Fold 20 RMSLE for all models ensemble = 0.026210431187964327
# Fold 20 best combination: model3 with RMSLE = 0.02558003190580525
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.01995052516244018
# Fold 21 RMSLE for model2 = 0.019759904108637653
# Fold 21 RMSLE for model3 = 0.020020392991385978
# Fold 21 RMSLE for model4 = 0.019960207694613475
# Fold 21 RMSLE for ('model1', 'model2') = 0.019712548111796978
# Fold 21 RMSLE for ('model1', 'model3') = 0.019929111432272367
# Fold 21 RMSLE for ('model1', 'model4') = 0.019922702706809174
# Fold 21 RMSLE for ('model2', 'model3') = 0.019629249002556446
# Fold 21 RMSLE for ('model2', 'model4') = 0.019730142431474508
# Fold 21 RMSLE for ('model3', 'model4') = 0.019927527135199807
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.019706040839878182
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.019754666032297592
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.019909545826149656
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.01971206415950179
# Fold 21 RMSLE for all models ensemble = 0.01975163757861333
# Fold 21 best combination: ('model2', 'model3') with RMSLE = 0.019629249002556446
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.02411756584121975
# Fold 22 RMSLE for model2 = 0.024067168761268687
# Fold 22 RMSLE for model3 = 0.024293048641057694
# Fold 22 RMSLE for model4 = 0.02415543481773216
# Fold 22 RMSLE for ('model1', 'model2') = 0.02395385464529381
# Fold 22 RMSLE for ('model1', 'model3') = 0.024169253874180893
# Fold 22 RMSLE for ('model1', 'model4') = 0.024109341781640824
# Fold 22 RMSLE for ('model2', 'model3') = 0.02397625561892488
# Fold 22 RMSLE for ('model2', 'model4') = 0.024002146840819354
# Fold 22 RMSLE for ('model3', 'model4') = 0.024174247794933594
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.023991122125618596
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.023991275359545226
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.024138341044576378
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0240105687747862
# Fold 22 RMSLE for all models ensemble = 0.024017166101608787
# Fold 22 best combination: ('model1', 'model2') with RMSLE = 0.02395385464529381
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.029530478310459806
# Fold 23 RMSLE for model2 = 0.029850178257570723
# Fold 23 RMSLE for model3 = 0.029195661159140518
# Fold 23 RMSLE for model4 = 0.030136030535766693
# Fold 23 RMSLE for ('model1', 'model2') = 0.029517160688669893
# Fold 23 RMSLE for ('model1', 'model3') = 0.029301750960573754
# Fold 23 RMSLE for ('model1', 'model4') = 0.029757969222419543
# Fold 23 RMSLE for ('model2', 'model3') = 0.02921013503442709
# Fold 23 RMSLE for ('model2', 'model4') = 0.029906940638025157
# Fold 23 RMSLE for ('model3', 'model4') = 0.029474143959223324
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.029281925732687016
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.029690319774956217
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.029474663129113544
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.02946547676285028
# Fold 23 RMSLE for all models ensemble = 0.02945313963277602
# Fold 23 best combination: model3 with RMSLE = 0.029195661159140518
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.024009421806348515
# Fold 24 RMSLE for model2 = 0.02292285499622032
# Fold 24 RMSLE for model3 = 0.02457342262188335
# Fold 24 RMSLE for model4 = 0.02391484513242187
# Fold 24 RMSLE for ('model1', 'model2') = 0.023312462609460807
# Fold 24 RMSLE for ('model1', 'model3') = 0.024242407719251305
# Fold 24 RMSLE for ('model1', 'model4') = 0.02389950542572994
# Fold 24 RMSLE for ('model2', 'model3') = 0.023521105442431384
# Fold 24 RMSLE for ('model2', 'model4') = 0.023285491212741913
# Fold 24 RMSLE for ('model3', 'model4') = 0.02412412845994507
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.023645220023700786
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.023460738028937972
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.024062861681605673
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.023590228924938856
# Fold 24 RMSLE for all models ensemble = 0.023669286079962066
# Fold 24 best combination: model2 with RMSLE = 0.02292285499622032
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.019642273916511646
# Fold 25 RMSLE for model2 = 0.01839162850952837
# Fold 25 RMSLE for model3 = 0.01953355811006986
# Fold 25 RMSLE for model4 = 0.019448882465573636
# Fold 25 RMSLE for ('model1', 'model2') = 0.018851024144648443
# Fold 25 RMSLE for ('model1', 'model3') = 0.019487426448767855
# Fold 25 RMSLE for ('model1', 'model4') = 0.019499674301036423
# Fold 25 RMSLE for ('model2', 'model3') = 0.018693527194429484
# Fold 25 RMSLE for ('model2', 'model4') = 0.018771253979986576
# Fold 25 RMSLE for ('model3', 'model4') = 0.019367912302327
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.018952116927203742
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.019001472421062694
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.019421679216732605
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.01888451725259197
# Fold 25 RMSLE for all models ensemble = 0.019041646713047415
# Fold 25 best combination: model2 with RMSLE = 0.01839162850952837
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.02493763630880805
# Fold 26 RMSLE for model2 = 0.024408139970282662
# Fold 26 RMSLE for model3 = 0.025261961732650863
# Fold 26 RMSLE for model4 = 0.02509371390117266
# Fold 26 RMSLE for ('model1', 'model2') = 0.024600150189855913
# Fold 26 RMSLE for ('model1', 'model3') = 0.025063438879636246
# Fold 26 RMSLE for ('model1', 'model4') = 0.02496709314617206
# Fold 26 RMSLE for ('model2', 'model3') = 0.02470871592972354
# Fold 26 RMSLE for ('model2', 'model4') = 0.024693125088352114
# Fold 26 RMSLE for ('model3', 'model4') = 0.025108916975686523
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.024764774014414688
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.024733595564232554
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.025029340084809577
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.024808817070912634
# Fold 26 RMSLE for all models ensemble = 0.024822750571625894
# Fold 26 best combination: model2 with RMSLE = 0.024408139970282662
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.02377085273004092
# Fold 27 RMSLE for model2 = 0.02423430410187555
# Fold 27 RMSLE for model3 = 0.024027831064523303
# Fold 27 RMSLE for model4 = 0.023891549857815834
# Fold 27 RMSLE for ('model1', 'model2') = 0.023869936931507494
# Fold 27 RMSLE for ('model1', 'model3') = 0.023829245456984532
# Fold 27 RMSLE for ('model1', 'model4') = 0.02378703092911631
# Fold 27 RMSLE for ('model2', 'model3') = 0.023921703129930104
# Fold 27 RMSLE for ('model2', 'model4') = 0.023962052979926193
# Fold 27 RMSLE for ('model3', 'model4') = 0.02385048191102888
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.02382745203818962
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.023841946603913373
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.023797312660198782
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.02386454620136672
# Fold 27 RMSLE for all models ensemble = 0.023814145703352
# Fold 27 best combination: model1 with RMSLE = 0.02377085273004092
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.01961078834243645
# Fold 28 RMSLE for model2 = 0.019628256631803755
# Fold 28 RMSLE for model3 = 0.019719405703115787
# Fold 28 RMSLE for model4 = 0.019778553114981254
# Fold 28 RMSLE for ('model1', 'model2') = 0.019443894385260153
# Fold 28 RMSLE for ('model1', 'model3') = 0.019632842383635028
# Fold 28 RMSLE for ('model1', 'model4') = 0.01964632826786135
# Fold 28 RMSLE for ('model2', 'model3') = 0.0194506605890156
# Fold 28 RMSLE for ('model2', 'model4') = 0.01961603884826632
# Fold 28 RMSLE for ('model3', 'model4') = 0.019670734016704425
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.01946124486576807
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.019534261218984585
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.019632254697057785
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.01953602152661899
# Fold 28 RMSLE for all models ensemble = 0.01952304981430459
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.019443894385260153
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.022066323184372603
# Fold 29 RMSLE for model2 = 0.020459030076138047
# Fold 29 RMSLE for model3 = 0.022703620017363955
# Fold 29 RMSLE for model4 = 0.02167560557632586
# Fold 29 RMSLE for ('model1', 'model2') = 0.021186056765651166
# Fold 29 RMSLE for ('model1', 'model3') = 0.022353367914337032
# Fold 29 RMSLE for ('model1', 'model4') = 0.021842309149404267
# Fold 29 RMSLE for ('model2', 'model3') = 0.021461601220591674
# Fold 29 RMSLE for ('model2', 'model4') = 0.021000104032631743
# Fold 29 RMSLE for ('model3', 'model4') = 0.022133484191089868
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.021642398327468098
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.02132404211972342
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.022096741176482543
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.021504844736920492
# Fold 29 RMSLE for all models ensemble = 0.021631654821179912
# Fold 29 best combination: model2 with RMSLE = 0.020459030076138047
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.025505265017366722
# Fold 30 RMSLE for model2 = 0.023064480686028534
# Fold 30 RMSLE for model3 = 0.02622492578623339
# Fold 30 RMSLE for model4 = 0.025407420781191497
# Fold 30 RMSLE for ('model1', 'model2') = 0.024083168379574926
# Fold 30 RMSLE for ('model1', 'model3') = 0.025803506219694763
# Fold 30 RMSLE for ('model1', 'model4') = 0.025314683759930106
# Fold 30 RMSLE for ('model2', 'model3') = 0.02440937550720309
# Fold 30 RMSLE for ('model2', 'model4') = 0.024064563764600987
# Fold 30 RMSLE for ('model3', 'model4') = 0.025655818400313526
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.024712377991950123
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.024430663622460373
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.025551034664710145
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.024647094500673306
# Fold 30 RMSLE for all models ensemble = 0.02480881253528563
# Fold 30 best combination: model2 with RMSLE = 0.023064480686028534
# ---------------
#
# OOF RMSLE = 0.025609209815901406
# Sum of RMSLE for each combination:
# ('model1',): 0.7796612031615429
# ('model2',): 0.760969132013653
# ('model3',): 0.7826599716072047
# ('model4',): 0.783804864041394
# ('model1', 'model2'): 0.7662160691761529
# ('model1', 'model3'): 0.7795195735348109
# ('model1', 'model4'): 0.7799792014018669
# ('model2', 'model3'): 0.7650571118235425
# ('model2', 'model4'): 0.7693421529092003
# ('model3', 'model4'): 0.7798819737888876
# ('model1', 'model2', 'model3'): 0.7688900613583216
# ('model1', 'model2', 'model4'): 0.7708647301443887
# ('model1', 'model3', 'model4'): 0.7790417105826869
# ('model2', 'model3', 'model4'): 0.7699759219962649
# ('model1', 'model2', 'model3', 'model4'): 0.7716247264743853
#
# 1番目の学習が終わりました。
#
# 推定時間は21
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.01975755346346387
# Fold 1 RMSLE for model2 = 0.018334140294872247
# Fold 1 RMSLE for model3 = 0.020275162146138805
# Fold 1 RMSLE for model4 = 0.019480322847099465
# Fold 1 RMSLE for ('model1', 'model2') = 0.01896226280121926
# Fold 1 RMSLE for ('model1', 'model3') = 0.019978382827979348
# Fold 1 RMSLE for ('model1', 'model4') = 0.01960491390874698
# Fold 1 RMSLE for ('model2', 'model3') = 0.019130170654347925
# Fold 1 RMSLE for ('model2', 'model4') = 0.018850722688078126
# Fold 1 RMSLE for ('model3', 'model4') = 0.019815527411359564
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.019324948358949837
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.019122687589056542
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.01978677484365227
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.01923297899222715
# Fold 1 RMSLE for all models ensemble = 0.01935517206920176
# Fold 1 best combination: model2 with RMSLE = 0.018334140294872247
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.020424268435833982
# Fold 2 RMSLE for model2 = 0.01999044501658849
# Fold 2 RMSLE for model3 = 0.02070160471964215
# Fold 2 RMSLE for model4 = 0.02038838172058138
# Fold 2 RMSLE for ('model1', 'model2') = 0.02010464478148875
# Fold 2 RMSLE for ('model1', 'model3') = 0.020529451805213747
# Fold 2 RMSLE for ('model1', 'model4') = 0.020388187391951387
# Fold 2 RMSLE for ('model2', 'model3') = 0.020161949838309892
# Fold 2 RMSLE for ('model2', 'model4') = 0.020112752687065905
# Fold 2 RMSLE for ('model3', 'model4') = 0.020485248262076886
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.020230099537004463
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.020180122915594696
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.0204551938580526
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.020217784563916343
# Fold 2 RMSLE for all models ensemble = 0.020257715605131857
# Fold 2 best combination: model2 with RMSLE = 0.01999044501658849
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.020130819227156448
# Fold 3 RMSLE for model2 = 0.018975314262776856
# Fold 3 RMSLE for model3 = 0.020788043878163673
# Fold 3 RMSLE for model4 = 0.020181862532065938
# Fold 3 RMSLE for ('model1', 'model2') = 0.019421040234013844
# Fold 3 RMSLE for ('model1', 'model3') = 0.02043140621936196
# Fold 3 RMSLE for ('model1', 'model4') = 0.020132095639329602
# Fold 3 RMSLE for ('model2', 'model3') = 0.019680459723458076
# Fold 3 RMSLE for ('model2', 'model4') = 0.019485125262482837
# Fold 3 RMSLE for ('model3', 'model4') = 0.02042578432807208
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.01980545221109117
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.019652460210696214
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.020317275019278647
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.0198250687891144
# Fold 3 RMSLE for all models ensemble = 0.01988556208284132
# Fold 3 best combination: model2 with RMSLE = 0.018975314262776856
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.01880597195068535
# Fold 4 RMSLE for model2 = 0.017424069629464564
# Fold 4 RMSLE for model3 = 0.019000251596236434
# Fold 4 RMSLE for model4 = 0.018675420819988398
# Fold 4 RMSLE for ('model1', 'model2') = 0.01798279993936186
# Fold 4 RMSLE for ('model1', 'model3') = 0.01885783601713041
# Fold 4 RMSLE for ('model1', 'model4') = 0.018713978843874584
# Fold 4 RMSLE for ('model2', 'model3') = 0.01799028603309418
# Fold 4 RMSLE for ('model2', 'model4') = 0.017950389014564326
# Fold 4 RMSLE for ('model3', 'model4') = 0.018757975080933995
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.018234050910260268
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.018187932898683465
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.018759664073655247
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.018188930821544345
# Fold 4 RMSLE for all models ensemble = 0.018326338423005004
# Fold 4 best combination: model2 with RMSLE = 0.017424069629464564
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.02043277056936112
# Fold 5 RMSLE for model2 = 0.019882463702046698
# Fold 5 RMSLE for model3 = 0.021160199862468126
# Fold 5 RMSLE for model4 = 0.0205600789656144
# Fold 5 RMSLE for ('model1', 'model2') = 0.01999864674002572
# Fold 5 RMSLE for ('model1', 'model3') = 0.020763937475506592
# Fold 5 RMSLE for ('model1', 'model4') = 0.02043383723383042
# Fold 5 RMSLE for ('model2', 'model3') = 0.020268297758572473
# Fold 5 RMSLE for ('model2', 'model4') = 0.020111296005738098
# Fold 5 RMSLE for ('model3', 'model4') = 0.020756633968555586
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.02029504297403746
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.02014469846764232
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.02062930388499775
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.020326885947504127
# Fold 5 RMSLE for all models ensemble = 0.020329129092925755
# Fold 5 best combination: model2 with RMSLE = 0.019882463702046698
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.0205813264649371
# Fold 6 RMSLE for model2 = 0.019380813567651204
# Fold 6 RMSLE for model3 = 0.02128569274431226
# Fold 6 RMSLE for model4 = 0.019989874591675772
# Fold 6 RMSLE for ('model1', 'model2') = 0.019843226696039874
# Fold 6 RMSLE for ('model1', 'model3') = 0.020904319541660728
# Fold 6 RMSLE for ('model1', 'model4') = 0.020238001828488547
# Fold 6 RMSLE for ('model2', 'model3') = 0.020115471202963447
# Fold 6 RMSLE for ('model2', 'model4') = 0.019574372709135552
# Fold 6 RMSLE for ('model3', 'model4') = 0.020546775986522367
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.020246310946644062
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.019852634034344847
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.0205444839500835
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.02003203343568244
# Fold 6 RMSLE for all models ensemble = 0.020151537308869046
# Fold 6 best combination: model2 with RMSLE = 0.019380813567651204
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.018781847768222327
# Fold 7 RMSLE for model2 = 0.01815980045335031
# Fold 7 RMSLE for model3 = 0.019096106704275567
# Fold 7 RMSLE for model4 = 0.01866284378064339
# Fold 7 RMSLE for ('model1', 'model2') = 0.01834859852845583
# Fold 7 RMSLE for ('model1', 'model3') = 0.018911967454616235
# Fold 7 RMSLE for ('model1', 'model4') = 0.018700018725317562
# Fold 7 RMSLE for ('model2', 'model3') = 0.018431255302627614
# Fold 7 RMSLE for ('model2', 'model4') = 0.018322819014879498
# Fold 7 RMSLE for ('model3', 'model4') = 0.01881570193412255
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.018526202354309105
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.018431591128265364
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.01879661487262356
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.0184846141728687
# Fold 7 RMSLE for all models ensemble = 0.01854549942497946
# Fold 7 best combination: model2 with RMSLE = 0.01815980045335031
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.02587278790895215
# Fold 8 RMSLE for model2 = 0.024828527293422942
# Fold 8 RMSLE for model3 = 0.026101030315267854
# Fold 8 RMSLE for model4 = 0.025679664016627312
# Fold 8 RMSLE for ('model1', 'model2') = 0.025188906603192764
# Fold 8 RMSLE for ('model1', 'model3') = 0.025963944320847154
# Fold 8 RMSLE for ('model1', 'model4') = 0.02575496709590094
# Fold 8 RMSLE for ('model2', 'model3') = 0.02522899837052721
# Fold 8 RMSLE for ('model2', 'model4') = 0.025138648668970098
# Fold 8 RMSLE for ('model3', 'model4') = 0.025835300297652172
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.025415040186886586
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.02532829323933601
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.02584036424882681
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.0253563543066553
# Fold 8 RMSLE for all models ensemble = 0.02546840975842216
# Fold 8 best combination: model2 with RMSLE = 0.024828527293422942
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.019165163485179708
# Fold 9 RMSLE for model2 = 0.018920751777217124
# Fold 9 RMSLE for model3 = 0.019433128279232853
# Fold 9 RMSLE for model4 = 0.019117523919714333
# Fold 9 RMSLE for ('model1', 'model2') = 0.018925012013303072
# Fold 9 RMSLE for ('model1', 'model3') = 0.01926579256064212
# Fold 9 RMSLE for ('model1', 'model4') = 0.019120489735443464
# Fold 9 RMSLE for ('model2', 'model3') = 0.018989032274693923
# Fold 9 RMSLE for ('model2', 'model4') = 0.018932388393469148
# Fold 9 RMSLE for ('model3', 'model4') = 0.019213300837916857
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.019022489452208795
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.01896769209525192
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.019186886705776184
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.01900747625144229
# Fold 9 RMSLE for all models ensemble = 0.01903206051216218
# Fold 9 best combination: model2 with RMSLE = 0.018920751777217124
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.019458346716783086
# Fold 10 RMSLE for model2 = 0.018341408254430033
# Fold 10 RMSLE for model3 = 0.020041378356899536
# Fold 10 RMSLE for model4 = 0.019417598604471897
# Fold 10 RMSLE for ('model1', 'model2') = 0.018815661952539236
# Fold 10 RMSLE for ('model1', 'model3') = 0.019716729874309363
# Fold 10 RMSLE for ('model1', 'model4') = 0.019416179968502683
# Fold 10 RMSLE for ('model2', 'model3') = 0.01904379458075288
# Fold 10 RMSLE for ('model2', 'model4') = 0.018823860876507278
# Fold 10 RMSLE for ('model3', 'model4') = 0.019669903893228615
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.019163296446110343
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.019001000035225833
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.01958810059787657
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.019150075831700725
# Fold 10 RMSLE for all models ensemble = 0.019214632043378907
# Fold 10 best combination: model2 with RMSLE = 0.018341408254430033
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.02861867165129067
# Fold 11 RMSLE for model2 = 0.0272027652510942
# Fold 11 RMSLE for model3 = 0.0287964525341516
# Fold 11 RMSLE for model4 = 0.028373270441740244
# Fold 11 RMSLE for ('model1', 'model2') = 0.027824175950230144
# Fold 11 RMSLE for ('model1', 'model3') = 0.028684151299083572
# Fold 11 RMSLE for ('model1', 'model4') = 0.028476767321977237
# Fold 11 RMSLE for ('model2', 'model3') = 0.027850370407120476
# Fold 11 RMSLE for ('model2', 'model4') = 0.0277253790928852
# Fold 11 RMSLE for ('model3', 'model4') = 0.02853331460763446
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.028091476078169673
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.02799041399619145
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.02855427755061853
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.028007321838736506
# Fold 11 RMSLE for all models ensemble = 0.02815019058772168
# Fold 11 best combination: model2 with RMSLE = 0.0272027652510942
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.028657296132196995
# Fold 12 RMSLE for model2 = 0.027342669832399035
# Fold 12 RMSLE for model3 = 0.029202438775258976
# Fold 12 RMSLE for model4 = 0.028505193135577138
# Fold 12 RMSLE for ('model1', 'model2') = 0.027918440354053057
# Fold 12 RMSLE for ('model1', 'model3') = 0.028903841409814356
# Fold 12 RMSLE for ('model1', 'model4') = 0.028565846095539634
# Fold 12 RMSLE for ('model2', 'model3') = 0.02812025408816562
# Fold 12 RMSLE for ('model2', 'model4') = 0.02786560245762518
# Fold 12 RMSLE for ('model3', 'model4') = 0.028796007881918526
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.028285912378599804
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.028099716191260633
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.028744138793636388
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.028230897536203867
# Fold 12 RMSLE for all models ensemble = 0.028329464088299998
# Fold 12 best combination: model2 with RMSLE = 0.027342669832399035
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.021021091262785223
# Fold 13 RMSLE for model2 = 0.019792017990348385
# Fold 13 RMSLE for model3 = 0.021369135093287608
# Fold 13 RMSLE for model4 = 0.020548655054986358
# Fold 13 RMSLE for ('model1', 'model2') = 0.020317925754022602
# Fold 13 RMSLE for ('model1', 'model3') = 0.021166251810028198
# Fold 13 RMSLE for ('model1', 'model4') = 0.020747570025304054
# Fold 13 RMSLE for ('model2', 'model3') = 0.020424844446279674
# Fold 13 RMSLE for ('model2', 'model4') = 0.020094085028645278
# Fold 13 RMSLE for ('model3', 'model4') = 0.020877173566669335
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.020606795482423956
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.020364322313463783
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.02091394955525999
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.020430370813977663
# Fold 13 RMSLE for all models ensemble = 0.0205660167321197
# Fold 13 best combination: model2 with RMSLE = 0.019792017990348385
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.01770770093868083
# Fold 14 RMSLE for model2 = 0.017221803059631093
# Fold 14 RMSLE for model3 = 0.017797478932562893
# Fold 14 RMSLE for model4 = 0.017480394041414753
# Fold 14 RMSLE for ('model1', 'model2') = 0.01735767440416025
# Fold 14 RMSLE for ('model1', 'model3') = 0.017713879914265856
# Fold 14 RMSLE for ('model1', 'model4') = 0.01756949095990352
# Fold 14 RMSLE for ('model2', 'model3') = 0.017291778099563514
# Fold 14 RMSLE for ('model2', 'model4') = 0.01727339514000363
# Fold 14 RMSLE for ('model3', 'model4') = 0.01755267816255754
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.017414555014691153
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.017377082170660824
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.017595400765323812
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.017330077219547817
# Fold 14 RMSLE for all models ensemble = 0.017414045279174468
# Fold 14 best combination: model2 with RMSLE = 0.017221803059631093
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.022454529259628923
# Fold 15 RMSLE for model2 = 0.02237134800457925
# Fold 15 RMSLE for model3 = 0.022650680740949447
# Fold 15 RMSLE for model4 = 0.02282650365687781
# Fold 15 RMSLE for ('model1', 'model2') = 0.02226484445727974
# Fold 15 RMSLE for ('model1', 'model3') = 0.022527944932451954
# Fold 15 RMSLE for ('model1', 'model4') = 0.022596919195729707
# Fold 15 RMSLE for ('model2', 'model3') = 0.02230838417702916
# Fold 15 RMSLE for ('model2', 'model4') = 0.02249607847914062
# Fold 15 RMSLE for ('model3', 'model4') = 0.022652599645705727
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.022325486165200928
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.022420075443743685
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.02257522937783913
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.02244234952590243
# Fold 15 RMSLE for all models ensemble = 0.022423967812815297
# Fold 15 best combination: ('model1', 'model2') with RMSLE = 0.02226484445727974
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.02269667195375883
# Fold 16 RMSLE for model2 = 0.021554604574086412
# Fold 16 RMSLE for model3 = 0.023215047506695632
# Fold 16 RMSLE for model4 = 0.02252108949846987
# Fold 16 RMSLE for ('model1', 'model2') = 0.022003462967779466
# Fold 16 RMSLE for ('model1', 'model3') = 0.02293109797591234
# Fold 16 RMSLE for ('model1', 'model4') = 0.022574772123561
# Fold 16 RMSLE for ('model2', 'model3') = 0.02219649331673898
# Fold 16 RMSLE for ('model2', 'model4') = 0.021949354940057158
# Fold 16 RMSLE for ('model3', 'model4') = 0.022798154788408326
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.022340818358488963
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.022149111436501823
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.02275367855656634
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.02227634160349906
# Fold 16 RMSLE for all models ensemble = 0.022365617774517583
# Fold 16 best combination: model2 with RMSLE = 0.021554604574086412
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.022184191126771925
# Fold 17 RMSLE for model2 = 0.019779833744505093
# Fold 17 RMSLE for model3 = 0.022890617823439086
# Fold 17 RMSLE for model4 = 0.02195100688309692
# Fold 17 RMSLE for ('model1', 'model2') = 0.02081416552352981
# Fold 17 RMSLE for ('model1', 'model3') = 0.022509141354603097
# Fold 17 RMSLE for ('model1', 'model4') = 0.022042511871759218
# Fold 17 RMSLE for ('model2', 'model3') = 0.02110398926745507
# Fold 17 RMSLE for ('model2', 'model4') = 0.02074378617562625
# Fold 17 RMSLE for ('model3', 'model4') = 0.022357910813590842
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.021431328663972918
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.02116705790121214
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.022290193107685097
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.02135719474118733
# Fold 17 RMSLE for all models ensemble = 0.021544830248487506
# Fold 17 best combination: model2 with RMSLE = 0.019779833744505093
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.02487527611817334
# Fold 18 RMSLE for model2 = 0.02363500318973195
# Fold 18 RMSLE for model3 = 0.025294008096360072
# Fold 18 RMSLE for model4 = 0.024899930170681615
# Fold 18 RMSLE for ('model1', 'model2') = 0.024146107340789084
# Fold 18 RMSLE for ('model1', 'model3') = 0.025058025751609134
# Fold 18 RMSLE for ('model1', 'model4') = 0.024862709982805004
# Fold 18 RMSLE for ('model2', 'model3') = 0.02427732617008507
# Fold 18 RMSLE for ('model2', 'model4') = 0.02419671918688449
# Fold 18 RMSLE for ('model3', 'model4') = 0.02502884864584885
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.024458880006142086
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.024379593030521958
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.024969840340887325
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.02446504412375524
# Fold 18 RMSLE for all models ensemble = 0.024555108937106454
# Fold 18 best combination: model2 with RMSLE = 0.02363500318973195
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.018583575736230627
# Fold 19 RMSLE for model2 = 0.018187585393689063
# Fold 19 RMSLE for model3 = 0.018995025621836546
# Fold 19 RMSLE for model4 = 0.018309334923707815
# Fold 19 RMSLE for ('model1', 'model2') = 0.01820200828834476
# Fold 19 RMSLE for ('model1', 'model3') = 0.018762761581543694
# Fold 19 RMSLE for ('model1', 'model4') = 0.01841026915836474
# Fold 19 RMSLE for ('model2', 'model3') = 0.018315250630505552
# Fold 19 RMSLE for ('model2', 'model4') = 0.018115724613114097
# Fold 19 RMSLE for ('model3', 'model4') = 0.018569286103689266
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.018373478427161142
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.01820364152500178
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.018564597265620087
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.018278566911649686
# Fold 19 RMSLE for all models ensemble = 0.018334724308537435
# Fold 19 best combination: ('model2', 'model4') with RMSLE = 0.018115724613114097
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0203287499022926
# Fold 20 RMSLE for model2 = 0.01983048403333618
# Fold 20 RMSLE for model3 = 0.021010819879583274
# Fold 20 RMSLE for model4 = 0.020984227483536472
# Fold 20 RMSLE for ('model1', 'model2') = 0.01995257123801901
# Fold 20 RMSLE for ('model1', 'model3') = 0.020639988035477407
# Fold 20 RMSLE for ('model1', 'model4') = 0.02059687961526732
# Fold 20 RMSLE for ('model2', 'model3') = 0.020203538191583856
# Fold 20 RMSLE for ('model2', 'model4') = 0.020306090265344974
# Fold 20 RMSLE for ('model3', 'model4') = 0.020867358423879805
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.02022437451818514
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.0202535358514297
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.020676606179232893
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.020409222227996373
# Fold 20 RMSLE for all models ensemble = 0.020372550759952344
# Fold 20 best combination: model2 with RMSLE = 0.01983048403333618
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.0181167819882105
# Fold 21 RMSLE for model2 = 0.01693288258691515
# Fold 21 RMSLE for model3 = 0.018726243137197715
# Fold 21 RMSLE for model4 = 0.01784999420991347
# Fold 21 RMSLE for ('model1', 'model2') = 0.0173852831482003
# Fold 21 RMSLE for ('model1', 'model3') = 0.018391861854704327
# Fold 21 RMSLE for ('model1', 'model4') = 0.017960955246355336
# Fold 21 RMSLE for ('model2', 'model3') = 0.017617628165869224
# Fold 21 RMSLE for ('model2', 'model4') = 0.01729072959956863
# Fold 21 RMSLE for ('model3', 'model4') = 0.018228923069147907
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.017757456696744674
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.01751726341754123
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.018181456559403945
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.017671565880812024
# Fold 21 RMSLE for all models ensemble = 0.017766759452223002
# Fold 21 best combination: model2 with RMSLE = 0.01693288258691515
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.022225703707398244
# Fold 22 RMSLE for model2 = 0.02140305743040878
# Fold 22 RMSLE for model3 = 0.02272663766548417
# Fold 22 RMSLE for model4 = 0.022073036554991144
# Fold 22 RMSLE for ('model1', 'model2') = 0.021728153888377493
# Fold 22 RMSLE for ('model1', 'model3') = 0.02244977886076926
# Fold 22 RMSLE for ('model1', 'model4') = 0.02213351106772646
# Fold 22 RMSLE for ('model2', 'model3') = 0.021922468296256666
# Fold 22 RMSLE for ('model2', 'model4') = 0.02166835754972933
# Fold 22 RMSLE for ('model3', 'model4') = 0.02235257115431482
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.02200562201651688
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.021824550636901183
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.022301939065674816
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.02195244663545485
# Fold 22 RMSLE for all models ensemble = 0.02201051702942096
# Fold 22 best combination: model2 with RMSLE = 0.02140305743040878
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.022921135824606368
# Fold 23 RMSLE for model2 = 0.02245830195118785
# Fold 23 RMSLE for model3 = 0.023041073077445497
# Fold 23 RMSLE for model4 = 0.022725441633660925
# Fold 23 RMSLE for ('model1', 'model2') = 0.02257467033721956
# Fold 23 RMSLE for ('model1', 'model3') = 0.022947609854772403
# Fold 23 RMSLE for ('model1', 'model4') = 0.02280401836273636
# Fold 23 RMSLE for ('model2', 'model3') = 0.022547835665349118
# Fold 23 RMSLE for ('model2', 'model4') = 0.02251355971446093
# Fold 23 RMSLE for ('model3', 'model4') = 0.02281849094664759
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.022651487281456623
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.02260727014305431
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.022843630543865973
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.022588303513657145
# Fold 23 RMSLE for all models ensemble = 0.022658526625525695
# Fold 23 best combination: model2 with RMSLE = 0.02245830195118785
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.020625113433418378
# Fold 24 RMSLE for model2 = 0.019423559148415263
# Fold 24 RMSLE for model3 = 0.021397285009823633
# Fold 24 RMSLE for model4 = 0.02031950135044874
# Fold 24 RMSLE for ('model1', 'model2') = 0.019939836578706224
# Fold 24 RMSLE for ('model1', 'model3') = 0.020982599789619274
# Fold 24 RMSLE for ('model1', 'model4') = 0.020444159213932642
# Fold 24 RMSLE for ('model2', 'model3') = 0.020272463635240125
# Fold 24 RMSLE for ('model2', 'model4') = 0.0198017627848813
# Fold 24 RMSLE for ('model3', 'model4') = 0.020797902518937716
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.02037112246092948
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.02004198388741644
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.020728462208657403
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.020260911383355933
# Fold 24 RMSLE for all models ensemble = 0.020339417489260846
# Fold 24 best combination: model2 with RMSLE = 0.019423559148415263
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.01706758325789411
# Fold 25 RMSLE for model2 = 0.016464823696709298
# Fold 25 RMSLE for model3 = 0.01786237716379856
# Fold 25 RMSLE for model4 = 0.01729405660740188
# Fold 25 RMSLE for ('model1', 'model2') = 0.016613830295895592
# Fold 25 RMSLE for ('model1', 'model3') = 0.017421058807726632
# Fold 25 RMSLE for ('model1', 'model4') = 0.01715132998942037
# Fold 25 RMSLE for ('model2', 'model3') = 0.01688543802081479
# Fold 25 RMSLE for ('model2', 'model4') = 0.016764799960672414
# Fold 25 RMSLE for ('model3', 'model4') = 0.017489252359397918
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.016921601319756757
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.016811063715911064
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.01733554512622754
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.016993340527727805
# Fold 25 RMSLE for all models ensemble = 0.016996031784001584
# Fold 25 best combination: model2 with RMSLE = 0.016464823696709298
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.021142483896466318
# Fold 26 RMSLE for model2 = 0.020393468625850952
# Fold 26 RMSLE for model3 = 0.021572325728551653
# Fold 26 RMSLE for model4 = 0.021186995398370517
# Fold 26 RMSLE for ('model1', 'model2') = 0.02066165427763595
# Fold 26 RMSLE for ('model1', 'model3') = 0.021321934409705957
# Fold 26 RMSLE for ('model1', 'model4') = 0.02114075236033073
# Fold 26 RMSLE for ('model2', 'model3') = 0.020794730286806437
# Fold 26 RMSLE for ('model2', 'model4') = 0.020706908368976294
# Fold 26 RMSLE for ('model3', 'model4') = 0.021313746478112017
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.02089001671072885
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.02081308009211133
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.021244789448949357
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.020901204190186637
# Fold 26 RMSLE for all models ensemble = 0.020948489241896958
# Fold 26 best combination: model2 with RMSLE = 0.020393468625850952
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.02056791787913475
# Fold 27 RMSLE for model2 = 0.020580575479907423
# Fold 27 RMSLE for model3 = 0.020416310020732215
# Fold 27 RMSLE for model4 = 0.020761323343116606
# Fold 27 RMSLE for ('model1', 'model2') = 0.020468772966527892
# Fold 27 RMSLE for ('model1', 'model3') = 0.0204596184672922
# Fold 27 RMSLE for ('model1', 'model4') = 0.020642155533313878
# Fold 27 RMSLE for ('model2', 'model3') = 0.020318834988183213
# Fold 27 RMSLE for ('model2', 'model4') = 0.020588717499652354
# Fold 27 RMSLE for ('model3', 'model4') = 0.0205301121605188
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.020380442126369427
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.020543250528430295
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.020531338661054648
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.02044375766345781
# Fold 27 RMSLE for all models ensemble = 0.02046138003091753
# Fold 27 best combination: ('model2', 'model3') with RMSLE = 0.020318834988183213
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.016636483310601115
# Fold 28 RMSLE for model2 = 0.0160739947826683
# Fold 28 RMSLE for model3 = 0.017445161787153905
# Fold 28 RMSLE for model4 = 0.01707119904297022
# Fold 28 RMSLE for ('model1', 'model2') = 0.01611958028373794
# Fold 28 RMSLE for ('model1', 'model3') = 0.017003219557156793
# Fold 28 RMSLE for ('model1', 'model4') = 0.016804112587745713
# Fold 28 RMSLE for ('model2', 'model3') = 0.016443136494036156
# Fold 28 RMSLE for ('model2', 'model4') = 0.01643608117677211
# Fold 28 RMSLE for ('model3', 'model4') = 0.017152259178445595
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.01645812454522101
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.016407598542402823
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.016964730070963597
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.016615766186647812
# Fold 28 RMSLE for all models ensemble = 0.016587625998636186
# Fold 28 best combination: model2 with RMSLE = 0.0160739947826683
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.01766067274553476
# Fold 29 RMSLE for model2 = 0.01703636484136778
# Fold 29 RMSLE for model3 = 0.018182451769596094
# Fold 29 RMSLE for model4 = 0.017642328149531653
# Fold 29 RMSLE for ('model1', 'model2') = 0.017220342745537385
# Fold 29 RMSLE for ('model1', 'model3') = 0.017886920443664148
# Fold 29 RMSLE for ('model1', 'model4') = 0.017626638460547624
# Fold 29 RMSLE for ('model2', 'model3') = 0.017389600788204666
# Fold 29 RMSLE for ('model2', 'model4') = 0.0172354496680415
# Fold 29 RMSLE for ('model3', 'model4') = 0.0178429151998826
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.017457194408070097
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.017332719285405786
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.017771034670970163
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.01744586303318561
# Fold 29 RMSLE for all models ensemble = 0.017485807690071676
# Fold 29 best combination: model2 with RMSLE = 0.01703636484136778
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.02176182107712885
# Fold 30 RMSLE for model2 = 0.02057309921146487
# Fold 30 RMSLE for model3 = 0.022205844433211632
# Fold 30 RMSLE for model4 = 0.021230529536506837
# Fold 30 RMSLE for ('model1', 'model2') = 0.021068877517649496
# Fold 30 RMSLE for ('model1', 'model3') = 0.021958157939644903
# Fold 30 RMSLE for ('model1', 'model4') = 0.0214719922986979
# Fold 30 RMSLE for ('model2', 'model3') = 0.021227564898535632
# Fold 30 RMSLE for ('model2', 'model4') = 0.020830779156551425
# Fold 30 RMSLE for ('model3', 'model4') = 0.021659198813343557
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.02138728191134691
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.021102651232682342
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.02168435282078668
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.02120670684673116
# Fold 30 RMSLE for all models ensemble = 0.0213332160485259
# Fold 30 best combination: model2 with RMSLE = 0.02057309921146487
# ---------------
#
# OOF RMSLE = 0.020263647988633688
# Sum of RMSLE for each combination:
# ('model1',): 0.6292643071927786
# ('model2',): 0.6024959770801169
# ('model3',): 0.6426800133997573
# ('model4',): 0.6267075829154832
# ('model1', 'model2'): 0.6121731786073361
# ('model1', 'model3'): 0.6350436121471131
# ('model1', 'model4'): 0.6271260318424046
# ('model2', 'model3'): 0.6165516457731705
# ('model2', 'model4'): 0.611905736179524
# ('model3', 'model4'): 0.632540856519092
# ('model1', 'model2', 'model3'): 0.6200963879476785
# ('model1', 'model2', 'model4'): 0.6162750939559417
# ('model1', 'model3', 'model4'): 0.6311298527240468
# ('model2', 'model3', 'model4'): 0.6191294555163287
# ('model1', 'model2', 'model3', 'model4'): 0.6212103442401303
#
# 2番目の学習が終わりました。
#
# 推定時間は19
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.017059098070162898
# Fold 1 RMSLE for model2 = 0.01570961173212522
# Fold 1 RMSLE for model3 = 0.017815533623152715
# Fold 1 RMSLE for model4 = 0.016577036885240527
# Fold 1 RMSLE for ('model1', 'model2') = 0.016249148622123108
# Fold 1 RMSLE for ('model1', 'model3') = 0.017379822453470802
# Fold 1 RMSLE for ('model1', 'model4') = 0.016778971031534536
# Fold 1 RMSLE for ('model2', 'model3') = 0.016484435468733575
# Fold 1 RMSLE for ('model2', 'model4') = 0.01607521409841938
# Fold 1 RMSLE for ('model3', 'model4') = 0.017049733351865874
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.01665373072686998
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.016341229223747658
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.017042227955900227
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.016480246838307587
# Fold 1 RMSLE for all models ensemble = 0.01660926998795898
# Fold 1 best combination: model2 with RMSLE = 0.01570961173212522
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.01663691691061097
# Fold 2 RMSLE for model2 = 0.016532136289891034
# Fold 2 RMSLE for model3 = 0.017211404478973014
# Fold 2 RMSLE for model4 = 0.01646643570431309
# Fold 2 RMSLE for ('model1', 'model2') = 0.016414924257527098
# Fold 2 RMSLE for ('model1', 'model3') = 0.016880544660510217
# Fold 2 RMSLE for ('model1', 'model4') = 0.016504607708948547
# Fold 2 RMSLE for ('model2', 'model3') = 0.016570156191348225
# Fold 2 RMSLE for ('model2', 'model4') = 0.016404044738736325
# Fold 2 RMSLE for ('model3', 'model4') = 0.016703053155777067
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.016564887327515966
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.016406421343777462
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.016670747627448874
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.01649892757333973
# Fold 2 RMSLE for all models ensemble = 0.016513041092156646
# Fold 2 best combination: ('model2', 'model4') with RMSLE = 0.016404044738736325
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.01570384133841152
# Fold 3 RMSLE for model2 = 0.015036334333160756
# Fold 3 RMSLE for model3 = 0.01638568420362822
# Fold 3 RMSLE for model4 = 0.015247038395141486
# Fold 3 RMSLE for ('model1', 'model2') = 0.015228696245995953
# Fold 3 RMSLE for ('model1', 'model3') = 0.01599746332654879
# Fold 3 RMSLE for ('model1', 'model4') = 0.015434610043396788
# Fold 3 RMSLE for ('model2', 'model3') = 0.015464435390820729
# Fold 3 RMSLE for ('model2', 'model4') = 0.015068691596943243
# Fold 3 RMSLE for ('model3', 'model4') = 0.015699633498857283
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.015516050856297233
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.015215668858010905
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.01568766178120895
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.015361266964435275
# Fold 3 RMSLE for all models ensemble = 0.015426596555715832
# Fold 3 best combination: model2 with RMSLE = 0.015036334333160756
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.015879317672673594
# Fold 4 RMSLE for model2 = 0.014669684353803312
# Fold 4 RMSLE for model3 = 0.01626357170101011
# Fold 4 RMSLE for model4 = 0.015524690619829144
# Fold 4 RMSLE for ('model1', 'model2') = 0.015126255155056742
# Fold 4 RMSLE for ('model1', 'model3') = 0.016011944133833878
# Fold 4 RMSLE for ('model1', 'model4') = 0.015657932313225435
# Fold 4 RMSLE for ('model2', 'model3') = 0.015161611636208112
# ...
# Fold 16 RMSLE for model1 = 0.008306159473445443
# Fold 16 RMSLE for model2 = 0.008334594153738191
# Fold 16 RMSLE for model3 = 0.008613236044431512
# Fold 16 RMSLE for model4 = 0.008350678101361225
# Fold 16 RMSLE for ('model1', 'model2') = 0.008287536597954752
# Fold 16 RMSLE for ('model1', 'model3') = 0.00842824748423017
# Fold 16 RMSLE for ('model1', 'model4') = 0.00831829648681418
# Fold 16 RMSLE for ('model2', 'model3') = 0.008384520603816814
# Fold 16 RMSLE for ('model2', 'model4') = 0.008322902851989819
# Fold 16 RMSLE for ('model3', 'model4') = 0.008424477767805246
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.008349515201747513
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.008302613745724169
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.008379147436284751
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.008358520427163332
# Fold 16 RMSLE for all models ensemble = 0.008340648893055623
# Fold 16 best combination: ('model1', 'model2') with RMSLE = 0.008287536597954752
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.009084704492323497
# Fold 17 RMSLE for model2 = 0.009016787499154029
# Fold 17 RMSLE for model3 = 0.009402260703521728
# Fold 17 RMSLE for model4 = 0.009043129021537562
# Fold 17 RMSLE for ('model1', 'model2') = 0.00902229879333825
# Fold 17 RMSLE for ('model1', 'model3') = 0.009206705582519207
# Fold 17 RMSLE for ('model1', 'model4') = 0.00905681765636474
# Fold 17 RMSLE for ('model2', 'model3') = 0.009116548452788932
# Fold 17 RMSLE for ('model2', 'model4') = 0.009014775359558563
# Fold 17 RMSLE for ('model3', 'model4') = 0.009164926170222201
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.009097436859332675
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.009025663967099293
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.009131316305394065
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.009079958780387599
# Fold 17 RMSLE for all models ensemble = 0.009076855881268489
# Fold 17 best combination: ('model2', 'model4') with RMSLE = 0.009014775359558563
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.00935333533725871
# Fold 18 RMSLE for model2 = 0.009343202645805982
# Fold 18 RMSLE for model3 = 0.009655354957778046
# Fold 18 RMSLE for model4 = 0.009349793235998962
# Fold 18 RMSLE for ('model1', 'model2') = 0.009313202884405963
# Fold 18 RMSLE for ('model1', 'model3') = 0.009476532704529906
# Fold 18 RMSLE for ('model1', 'model4') = 0.009342258246475749
# Fold 18 RMSLE for ('model2', 'model3') = 0.009409996588190882
# Fold 18 RMSLE for ('model2', 'model4') = 0.009329772779169571
# Fold 18 RMSLE for ('model3', 'model4') = 0.009451589569604403
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.009382890022000842
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.00932162263959923
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.009413528277786885
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.0093794160951557
# Fold 18 RMSLE for all models ensemble = 0.009367911123178804
# Fold 18 best combination: ('model1', 'model2') with RMSLE = 0.009313202884405963
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.007808028956630347
# Fold 19 RMSLE for model2 = 0.007672033628810854
# Fold 19 RMSLE for model3 = 0.008159528836516921
# Fold 19 RMSLE for model4 = 0.007680815645430253
# Fold 19 RMSLE for ('model1', 'model2') = 0.007701545465442283
# Fold 19 RMSLE for ('model1', 'model3') = 0.007943988824581067
# Fold 19 RMSLE for ('model1', 'model4') = 0.007734062479002562
# Fold 19 RMSLE for ('model2', 'model3') = 0.007802056101273352
# Fold 19 RMSLE for ('model2', 'model4') = 0.007656432030684073
# Fold 19 RMSLE for ('model3', 'model4') = 0.007848919565027052
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.007794357180195987
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.0076896868924498174
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.007828542654993874
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.007745689388513839
# Fold 19 RMSLE for all models ensemble = 0.00775622209311018
# Fold 19 best combination: ('model2', 'model4') with RMSLE = 0.007656432030684073
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.008406680337868488
# Fold 20 RMSLE for model2 = 0.008178355741521637
# Fold 20 RMSLE for model3 = 0.00893854539684159
# Fold 20 RMSLE for model4 = 0.008437360277561113
# Fold 20 RMSLE for ('model1', 'model2') = 0.008247858098071747
# Fold 20 RMSLE for ('model1', 'model3') = 0.008629645802855702
# Fold 20 RMSLE for ('model1', 'model4') = 0.008410741827280889
# Fold 20 RMSLE for ('model2', 'model3') = 0.008424047607909206
# Fold 20 RMSLE for ('model2', 'model4') = 0.008285054042332917
# Fold 20 RMSLE for ('model3', 'model4') = 0.008610788002968753
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.008408955152892963
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.008305905674816611
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.00853534626190654
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.008413199481023386
# Fold 20 RMSLE for all models ensemble = 0.008406376848933831
# Fold 20 best combination: model2 with RMSLE = 0.008178355741521637
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.008654983899889118
# Fold 21 RMSLE for model2 = 0.008532417092201547
# Fold 21 RMSLE for model3 = 0.008894154824425456
# Fold 21 RMSLE for model4 = 0.008627886356058623
# Fold 21 RMSLE for ('model1', 'model2') = 0.008565721670993636
# Fold 21 RMSLE for ('model1', 'model3') = 0.0087455579924968
# Fold 21 RMSLE for ('model1', 'model4') = 0.00863440386366021
# Fold 21 RMSLE for ('model2', 'model3') = 0.008635604117011758
# Fold 21 RMSLE for ('model2', 'model4') = 0.008562956490879705
# Fold 21 RMSLE for ('model3', 'model4') = 0.008717753209352815
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.008633933349402649
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.008581916750716017
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.008690304839025696
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.008623223546197894
# Fold 21 RMSLE for all models ensemble = 0.008626670207365711
# Fold 21 best combination: model2 with RMSLE = 0.008532417092201547
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.009716202008679809
# Fold 22 RMSLE for model2 = 0.009658351519793995
# Fold 22 RMSLE for model3 = 0.009929123949119132
# Fold 22 RMSLE for model4 = 0.00981498632718206
# Fold 22 RMSLE for ('model1', 'model2') = 0.009664431808653076
# Fold 22 RMSLE for ('model1', 'model3') = 0.009793135081493036
# Fold 22 RMSLE for ('model1', 'model4') = 0.009759978603416247
# Fold 22 RMSLE for ('model2', 'model3') = 0.009718277127085704
# Fold 22 RMSLE for ('model2', 'model4') = 0.009720534079013132
# Fold 22 RMSLE for ('model3', 'model4') = 0.009825727689624818
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.00971099463301732
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.009710055138085035
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.009783798207052979
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.009739434491017331
# Fold 22 RMSLE for all models ensemble = 0.009730591447564869
# Fold 22 best combination: model2 with RMSLE = 0.009658351519793995
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.008389805998893302
# Fold 23 RMSLE for model2 = 0.008430057364040037
# Fold 23 RMSLE for model3 = 0.008700350087851303
# Fold 23 RMSLE for model4 = 0.008462503270173687
# Fold 23 RMSLE for ('model1', 'model2') = 0.008376081924945863
# Fold 23 RMSLE for ('model1', 'model3') = 0.008508177843659948
# Fold 23 RMSLE for ('model1', 'model4') = 0.008417112737024078
# Fold 23 RMSLE for ('model2', 'model3') = 0.008458487036029331
# Fold 23 RMSLE for ('model2', 'model4') = 0.008427212537155518
# Fold 23 RMSLE for ('model3', 'model4') = 0.008518114511196955
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.008427630235573634
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.008399927989721126
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.008468777356708736
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.008446648482181464
# Fold 23 RMSLE for all models ensemble = 0.008428158632604234
# Fold 23 best combination: ('model1', 'model2') with RMSLE = 0.008376081924945863
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.00824885427781909
# Fold 24 RMSLE for model2 = 0.008191837926672909
# Fold 24 RMSLE for model3 = 0.008788892640662835
# Fold 24 RMSLE for model4 = 0.008129894687323797
# Fold 24 RMSLE for ('model1', 'model2') = 0.008179456316292875
# Fold 24 RMSLE for ('model1', 'model3') = 0.008475025357130305
# Fold 24 RMSLE for ('model1', 'model4') = 0.008177182355537741
# Fold 24 RMSLE for ('model2', 'model3') = 0.008360104789539954
# Fold 24 RMSLE for ('model2', 'model4') = 0.008141491701082701
# Fold 24 RMSLE for ('model3', 'model4') = 0.008378901988629384
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.008313905428165028
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.008157953331007668
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.008328065271920537
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.008266928227655256
# Fold 24 RMSLE for all models ensemble = 0.008257304282867996
# Fold 24 best combination: model4 with RMSLE = 0.008129894687323797
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.00824830548368049
# Fold 25 RMSLE for model2 = 0.008084543359357977
# Fold 25 RMSLE for model3 = 0.008714657154498652
# Fold 25 RMSLE for model4 = 0.008154820331238327
# Fold 25 RMSLE for ('model1', 'model2') = 0.008135248035240118
# Fold 25 RMSLE for ('model1', 'model3') = 0.008445171039486634
# Fold 25 RMSLE for ('model1', 'model4') = 0.008194870715914244
# Fold 25 RMSLE for ('model2', 'model3') = 0.008308266988355151
# Fold 25 RMSLE for ('model2', 'model4') = 0.008099229484979091
# Fold 25 RMSLE for ('model3', 'model4') = 0.008379761490827645
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.008278367159891243
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.008136660933132598
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.008328718743643054
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.008243345462241022
# Fold 25 RMSLE for all models ensemble = 0.008239901963958957
# Fold 25 best combination: model2 with RMSLE = 0.008084543359357977
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.009638574735848586
# Fold 26 RMSLE for model2 = 0.00979310959913365
# Fold 26 RMSLE for model3 = 0.009673694340179983
# Fold 26 RMSLE for model4 = 0.009767407328103155
# Fold 26 RMSLE for ('model1', 'model2') = 0.009688440105478867
# Fold 26 RMSLE for ('model1', 'model3') = 0.009623693443119221
# Fold 26 RMSLE for ('model1', 'model4') = 0.009697295301093182
# Fold 26 RMSLE for ('model2', 'model3') = 0.00965951976102965
# Fold 26 RMSLE for ('model2', 'model4') = 0.009763882830596895
# Fold 26 RMSLE for ('model3', 'model4') = 0.009673916005447673
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.009642286472181818
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.009711035524268568
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.009655544859450175
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.009683949605026627
# Fold 26 RMSLE for all models ensemble = 0.009667579851618589
# Fold 26 best combination: ('model1', 'model3') with RMSLE = 0.009623693443119221
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.008442097097839555
# Fold 27 RMSLE for model2 = 0.008627668386901852
# Fold 27 RMSLE for model3 = 0.008346732021662032
# Fold 27 RMSLE for model4 = 0.008523924397855355
# Fold 27 RMSLE for ('model1', 'model2') = 0.008500293794959831
# Fold 27 RMSLE for ('model1', 'model3') = 0.008356804401966617
# Fold 27 RMSLE for ('model1', 'model4') = 0.008476396483655231
# Fold 27 RMSLE for ('model2', 'model3') = 0.008388629350045307
# Fold 27 RMSLE for ('model2', 'model4') = 0.008554212552853052
# Fold 27 RMSLE for ('model3', 'model4') = 0.00838009082227099
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.00839621281470349
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.008503283189768044
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.008393458905470167
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.008421641588914607
# Fold 27 RMSLE for all models ensemble = 0.00842161808788239
# Fold 27 best combination: model3 with RMSLE = 0.008346732021662032
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.007597070772490809
# Fold 28 RMSLE for model2 = 0.007482123471090969
# Fold 28 RMSLE for model3 = 0.008019873931925926
# Fold 28 RMSLE for model4 = 0.007611180485589075
# Fold 28 RMSLE for ('model1', 'model2') = 0.007503246668719028
# Fold 28 RMSLE for ('model1', 'model3') = 0.00776959791473478
# Fold 28 RMSLE for ('model1', 'model4') = 0.007580121698703764
# Fold 28 RMSLE for ('model2', 'model3') = 0.007638881677584693
# Fold 28 RMSLE for ('model2', 'model4') = 0.007517859355999917
# Fold 28 RMSLE for ('model3', 'model4') = 0.007731627065127515
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.0076161777276157385
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.007523835716489421
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.007677151414731807
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.007603833102930101
# Fold 28 RMSLE for all models ensemble = 0.007596040676514668
# Fold 28 best combination: model2 with RMSLE = 0.007482123471090969
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.007450661380081191
# Fold 29 RMSLE for model2 = 0.007353000300689718
# Fold 29 RMSLE for model3 = 0.007625602201419113
# Fold 29 RMSLE for model4 = 0.007483797852403371
# Fold 29 RMSLE for ('model1', 'model2') = 0.007370108680793258
# Fold 29 RMSLE for ('model1', 'model3') = 0.007505035122502782
# Fold 29 RMSLE for ('model1', 'model4') = 0.00746018576164282
# Fold 29 RMSLE for ('model2', 'model3') = 0.007411958112604423
# Fold 29 RMSLE for ('model2', 'model4') = 0.007397182153679138
# Fold 29 RMSLE for ('model3', 'model4') = 0.0075071896175250745
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.007413170948740503
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.007402540936134418
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.007480952738280725
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.007422410799380806
# Fold 29 RMSLE for all models ensemble = 0.00742367403629567
# Fold 29 best combination: model2 with RMSLE = 0.007353000300689718
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009105266819036253
# Fold 30 RMSLE for model2 = 0.009029477700368597
# Fold 30 RMSLE for model3 = 0.009549029731844185
# Fold 30 RMSLE for model4 = 0.009082646698213306
# Fold 30 RMSLE for ('model1', 'model2') = 0.00903297701130269
# Fold 30 RMSLE for ('model1', 'model3') = 0.00928817366730969
# Fold 30 RMSLE for ('model1', 'model4') = 0.00908662096292494
# Fold 30 RMSLE for ('model2', 'model3') = 0.009180661187373354
# Fold 30 RMSLE for ('model2', 'model4') = 0.009036122719732722
# Fold 30 RMSLE for ('model3', 'model4') = 0.009255011276877927
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.009146804022295174
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009045070171306808
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009197729271927921
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009135737166075634
# Fold 30 RMSLE for all models ensemble = 0.009123663136196664
# Fold 30 best combination: model2 with RMSLE = 0.009029477700368597
# ---------------
#
# OOF RMSLE = 0.008599758085173095
# Sum of RMSLE for each combination:
# ('model1',): 0.25912958774391154
# ('model2',): 0.2579209205598585
# ('model3',): 0.2676582522216644
# ('model4',): 0.2591145872843349
# ('model1', 'model2'): 0.2575537312374202
# ('model1', 'model3'): 0.2623131410364692
# ('model1', 'model4'): 0.2588650698755675
# ('model2', 'model3'): 0.2599195261365253
# ('model2', 'model4'): 0.25793180769930674
# ('model3', 'model4'): 0.2616262273158133
# ('model1', 'model2', 'model3'): 0.25937701908800886
# ('model1', 'model2', 'model4'): 0.25791549074664544
# ('model1', 'model3', 'model4'): 0.2605848494715367
# ('model2', 'model3', 'model4'): 0.2592367960055969
# ('model1', 'model2', 'model3', 'model4'): 0.2590662354463441
#
# 9番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                        0.000000                     0.000000           221
# 1                        0.000000                     0.000000           240
# 2                        0.000000                     0.000000            80
# 3                        0.000000                     0.000000           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 7158                     0.000000                     0.000000           240
# 7159                     0.000000                     0.000000             4
# 7160                 25069.498286                 24560.172725           132
# 7161                 93118.705227                130326.946431            98
# 7162                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 7158                            1.105231e+05
# 7159                            0.000000e+00
# 7160                            1.665202e+05
# 7161                            7.177380e+04
# 7162                            0.000000e+00
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                            0.000000                         0.000000
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                            0.000000                          0.000000
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                             0.000000                          0.000000
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                  14            1     53526.303400 -0.007434
# 1                   1            1     36068.833647  0.004429
# 2                   8            1    655997.270646  0.011125
# 3                   1            1     41267.665237 -0.010134
# 4                   8            0    456444.996682 -0.001877
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                    85503.349289                103787.620581            95
# ...                           ...                          ...           ...
# 4650                          NaN                          NaN           240
# 4651                          NaN                          NaN            21
# 4652                          NaN                          NaN             3
# 4653                          NaN                          NaN           244
# 4654                          NaN                          NaN           241
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               9.803362e+04
# 1                               4.652013e+04
# 2                               2.972544e+06
# 3                               1.197903e+04
# 4                               3.251417e+06
# ...                                      ...
# 4650                            2.046407e+06
# 4651                            7.034661e+04
# 4652                            2.083754e+05
# 4653                            5.637561e+05
# 4654                            6.745123e+04
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               49591.258795
# 1                               39261.527827
# 2                              908113.540089
# 3                               37278.738945
# 4                              432916.880509
# ...                                      ...
# 4650                           275336.593090
# 4651                            81110.577100
# 4652                            57066.624445
# 4653                           598881.479485
# 4654                            27397.929966
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               5.839936e+04
# 1                               4.922304e+04
# 2                               3.375397e+05
# 3                               5.316759e+04
# 4                               2.980333e+05
# ...                                      ...
# 4650                            4.630881e+06
# 4651                            5.442830e+04
# 4652                            4.858030e+04
# 4653                            1.665103e+06
# 4654                            3.922795e+04
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               55458.787269  39.366690  -97.799430
# 1                               28222.699429  41.037617  -85.208453
# 2                              329206.449634  33.416151  -81.896431
# 3                               60125.001392  38.622463  -78.586795
# 4                              601347.581361  41.681417  -83.457722
# ...                                      ...        ...         ...
# 4650                            99464.465641  37.156900  -87.380900
# 4651                            29108.448339  37.220511  -82.018916
# 4652                            26892.366779  42.684900 -109.780000
# 4653                           543206.073134  35.484260  -97.498570
# 4654                            46634.777768  39.404310  -76.319820
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        97947.895703                    -91413.590035
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        18284.271292                          1.240333
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                            -0.516703                          0.213843
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                  14            1     5.352630e+04 -0.007434
# 1                   1            1     3.606883e+04  0.004429
# 2                   8            1     6.559973e+05  0.011125
# 3                   1            1     4.126767e+04 -0.010134
# 4                   8            0     4.564450e+05 -0.001877
# ...               ...          ...              ...       ...
# 4650                1            1     1.045988e+06  0.007883
# 4651               15            1     5.510087e+04  0.005645
# 4652                9            1     4.882884e+04 -0.001835
# 4653                5            1     1.084493e+06  0.004543
# 4654                1            1     3.907942e+04 -0.002180
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.41, -0.00)

# %%
train_df_GHG14
# Out:
# 0       5.312985e+04
# 1       3.622895e+04
# 2       6.633360e+05
# 3       4.085155e+04
# 4       4.555892e+05
#             ...
# 4650    1.054266e+06
# 4651    5.541281e+04
# 4652    4.873934e+04
# 4653    1.089432e+06
# 4654    3.899430e+04
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.103729e+04 -0.037111
# 1                  14            1     3.037899e+05  0.010529
# 2                   8            0     3.793270e+04 -0.037336
# 3                   8            0     2.319435e+04 -0.093594
# 4                   8            0     5.007304e+04  0.029659
# ...               ...          ...              ...       ...
# 2503                1            1     5.271353e+05  0.010833
# 2504                9            1     1.241900e+05  0.090958
# 2505                8            0     1.401332e+05  0.028513
# 2506                8            0     2.463018e+05 -0.024815
# 2507                9            1     1.423290e+06  0.059695
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 203000.7738173111

# %%
print(np.expm1(np.log1p(10)))
# Out:
# 10.000000000000002

# %%
def after_act(preds):
    r = preds.copy()
    r_min = r.min()
    max_w = 10.4-np.log1p(r_min)
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            # print(r[i]-np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w))
            r[i] = np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 176137.11528313844

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_080.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    41,037
# 1     4656   303,790
# 2     4657    37,933
# 3     4658    18,801
# 4     4659    50,073
# ...    ...       ...
# 2503  7158   527,135
# 2504  7159   124,190
# 2505  7160   140,133
# 2506  7161   246,302
# 2507  7162 1,423,290
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 43    4698 1,214,652
# 110   4765 1,319,557
# 114   4769 1,305,777
# 148   4803 1,716,249
# 178   4833 1,521,698
# ...    ...       ...
# 2417  7072 1,247,621
# 2423  7078 1,201,948
# 2466  7121 1,656,232
# 2490  7145 1,358,483
# 2507  7162 1,423,290
#
# [114 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sun Dec  1 05:54:29 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                          85,503                      103,788            95
# ...                           ...                          ...           ...
# 4650                          NaN                          NaN           240
# 4651                          NaN                          NaN            21
# 4652                          NaN                          NaN             3
# 4653                          NaN                          NaN           244
# 4654                          NaN                          NaN           241
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     98,034
# 1                                     46,520
# 2                                  2,972,544
# 3                                     11,979
# 4                                  3,251,417
# ...                                      ...
# 4650                               2,046,407
# 4651                                  70,347
# 4652                                 208,375
# 4653                                 563,756
# 4654                                  67,451
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     49,591
# 1                                     39,262
# 2                                    908,114
# 3                                     37,279
# 4                                    432,917
# ...                                      ...
# 4650                                 275,337
# 4651                                  81,111
# 4652                                  57,067
# 4653                                 598,881
# 4654                                  27,398
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     58,399
# 1                                     49,223
# 2                                    337,540
# 3                                     53,168
# 4                                    298,033
# ...                                      ...
# 4650                               4,630,881
# 4651                                  54,428
# 4652                                  48,580
# 4653                               1,665,103
# 4654                                  39,228
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     55,459        39        -98
# 1                                     28,223        41        -85
# 2                                    329,206        33        -82
# 3                                     60,125        39        -79
# 4                                    601,348        42        -83
# ...                                      ...       ...        ...
# 4650                                  99,464        37        -87
# 4651                                  29,108        37        -82
# 4652                                  26,892        43       -110
# 4653                                 543,206        35        -97
# 4654                                  46,635        39        -76
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              97,948                          -91,414
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              18,284                                 1
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                   -1                                 0
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                  14            1           53,526    -0
# 1                   1            1           36,069     0
# 2                   8            1          655,997     0
# 3                   1            1           41,268    -0
# 4                   8            0          456,445    -0
# ...               ...          ...              ...   ...
# 4650                1            1        1,045,988     0
# 4651               15            1           55,101     0
# 4652                9            1           48,829    -0
# 4653                5            1        1,084,493     0
# 4654                1            1           39,079    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.010591499189785367

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN           221
# 1                             NaN                          NaN           240
# 2                             NaN                          NaN            80
# 3                             NaN                          NaN           240
# 4                          85,503                      103,788            95
# ...                           ...                          ...           ...
# 4650                          NaN                          NaN           240
# 4651                          NaN                          NaN            21
# 4652                          NaN                          NaN             3
# 4653                          NaN                          NaN           244
# 4654                          NaN                          NaN           241
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     98,034
# 1                                     46,520
# 2                                  2,972,544
# 3                                     11,979
# 4                                  3,251,417
# ...                                      ...
# 4650                               2,046,407
# 4651                                  70,347
# 4652                                 208,375
# 4653                                 563,756
# 4654                                  67,451
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     49,591
# 1                                     39,262
# 2                                    908,114
# 3                                     37,279
# 4                                    432,917
# ...                                      ...
# 4650                                 275,337
# 4651                                  81,111
# 4652                                  57,067
# 4653                                 598,881
# 4654                                  27,398
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     58,399
# 1                                     49,223
# 2                                    337,540
# 3                                     53,168
# 4                                    298,033
# ...                                      ...
# 4650                               4,630,881
# 4651                                  54,428
# 4652                                  48,580
# 4653                               1,665,103
# 4654                                  39,228
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     55,459        39        -98
# 1                                     28,223        41        -85
# 2                                    329,206        33        -82
# 3                                     60,125        39        -79
# 4                                    601,348        42        -83
# ...                                      ...       ...        ...
# 4650                                  99,464        37        -87
# 4651                                  29,108        37        -82
# 4652                                  26,892        43       -110
# 4653                                 543,206        35        -97
# 4654                                  46,635        39        -76
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              97,948                          -91,414
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              18,284                                 1
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                   -1                                 0
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                  14            1           53,526    -0
# 1                   1            1           36,069     0
# 2                   8            1          655,997     0
# 3                   1            1           41,268    -0
# 4                   8            0          456,445    -0
# ...               ...          ...              ...   ...
# 4650                1            1        1,045,988     0
# 4651               15            1           55,101     0
# 4652                9            1           48,829    -0
# 4653                5            1        1,084,493     0
# 4654                1            1           39,079    -0
#
# [4655 rows x 19 columns]
