# %%
import gc
import os
import time
import math
from math import exp, log
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch
import heapq
from tqdm import tqdm

import random
import statistics
from collections import Counter
from dataclasses import dataclass
from typing import Any, Callable, List, Optional, Tuple, Union

import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from pprint import pprint

# %%
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class HuggingFaceModelLoader:
    def __init__(self, model_path: str, load_in_8bit: bool, device_map: str):
        self.model_path = model_path
        self.load_in_8bit = load_in_8bit
        self.device_map = device_map

    def load_model(self) -> transformers.PreTrainedModel:
        if self.load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires a CUDA device')

            quantization_config = transformers.BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_quant_type="fp4",
                bnb_4bit_use_double_quant=False,
                bnb_4bit_compute_dtype=torch.float16,
            )

            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                quantization_config=quantization_config,
                device_map=self.device_map
            )
        else:
            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=self.device_map
            )

        model.eval()
        return model


class HuggingFaceTokenizer:
    def __init__(self, model_path: str):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path, padding_side="right")
        self.bos_token = self.tokenizer.bos_token or self.tokenizer.cls_token
        self.eos_token = self.tokenizer.eos_token or self.tokenizer.sep_token
        if self.bos_token is None:
            self.bos_token = ""
        if self.eos_token is None:
            self.eos_token = ""

    def tokenize(self, texts: List[str]) -> dict:
        processed_texts = []

        for text in texts:
            combined_text = f"{self.bos_token}{text}{self.eos_token}"
            processed_texts.append(combined_text)

        model_inputs = self.tokenizer(
            processed_texts,
            return_tensors='pt',
            add_special_tokens=False,
            padding=True
        )

        if 'token_type_ids' in model_inputs:
            model_inputs.pop('token_type_ids')

        return model_inputs


class PerplexityCalculator:
    def __init__(self, model_loader, tokenizer, exp_mode=False):
        self.model = model_loader.load_model()
        self.tokenizer = tokenizer
        self.exp_mode = exp_mode
        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

    def get_perplexity(
        self,
        input_texts: Union[str, List[str]],
        batch_size: int = 32
    ) -> Union[float, List[float]]:

        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        num_texts = len(input_texts)
        batches = num_texts // batch_size + (num_texts % batch_size != 0)
        with torch.no_grad():
            for j in range(batches):
                start_idx = j * batch_size
                end_idx = (j + 1) * batch_size
                input_batch = input_texts[start_idx:end_idx]

                with torch.no_grad():
                    model_inputs = self.tokenizer.tokenize(input_batch)
                    model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                    output = self.model(**model_inputs, use_cache=False)
                    logits = output['logits']

                    label = model_inputs['input_ids']
                    if hasattr(self.model.config, 'pad_token_id') and self.model.config.pad_token_id is not None:
                        label[label == self.model.config.pad_token_id] = PAD_TOKEN_LABEL_ID

                    shift_logits = logits[..., :-1, :].contiguous()
                    shift_labels = label[..., 1:].contiguous()

                    token_loss = self.loss_fct(
                        shift_logits.view(-1, shift_logits.size(-1)),
                        shift_labels.view(-1)
                    ).view(len(logits), -1)

                    valid_length = (shift_labels != PAD_TOKEN_LABEL_ID).sum(dim=-1)
                    sequence_loss = torch.sum(token_loss, -1) / valid_length
                    loss_list.extend(sequence_loss.cpu().tolist())

        if self.exp_mode:
            ppl = [exp(i) for i in loss_list]
        else:
            ppl = loss_list

        return ppl[0] if single_input else ppl

# %%
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, cost_fn, neighbor_fn, random_state):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        self.cost_fn = cost_fn
        self.neighbor_fn = neighbor_fn
        random.seed(random_state)

    def _acceptance_probability(self, diff, temperature):
        if diff <= 0:
            return 1.0
        return exp(-diff/temperature)

    def _lower_temperature(self, temperature, iteration):
        t1 = self.end_temp + self.start_temp/(1 + math.log(iteration+1))
        t2 = self.start_temp + (self.end_temp - self.start_temp)*(iteration/self.max_iterations)
        return max(t1, t2)

    def _print_progress(
        self,
        iteration: int,
        best_solutions: List[List[str]],
        best_energies: List[float],
        current_solutions: List[List[str]],
        current_energies: List[float],
        temperature: float,
        start_time: float,
        spend_minute: int
    ) -> int:
        current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        elapsed_time = time.time() - start_time

        # Check if 60 seconds have passed since the last update
        if elapsed_time - 60 * spend_minute > 60:
            spend_minute += 1
            progress = iteration / self.max_iterations * 100  # Progress as percentage

            # Print progress in a structured format
            print("===== Simulated Annealing Progress =====")
            print(f"Time: {current_time}")
            print(f"Iteration: {iteration}/{self.max_iterations} ({progress:.2f}%)")
            print(f"Temperature: {temperature:.4f}")
            print(f"Elapsed Time: {elapsed_time:.2f} seconds")

            # Print best solutions and energies
            print("\nBest Solutions:")
            idx_items = np.argsort(best_energies)[:5]

            for i, idx in enumerate(idx_items):
                print(f"  Solution {i+1}: {best_solutions[idx]}")
            print("\nBest Energies:")
            print("  " + ", ".join(f"{best_energies[idx]:.4f}" for idx in idx_items))

            # Print current solutions and energies
            print("\nCurrent Solutions:")
            for i, solution in enumerate(current_solutions[:5]):
                print(f"  Solution {i+1}: {solution}")
            print("\nCurrent Energies:")
            print("  " + ", ".join(f"{energy:.4f}" for energy in current_energies[:5]))

            print("========================================\n")

        return spend_minute


    def solve_batch(self, text_list, max_minute=60):
        """
        Perform Simulated Annealing for multiple texts at once.
        """
        solutions = text_list[:]
        current_energies = self.cost_fn(solutions)

        best_solutions = solutions[:]
        best_energies = current_energies[:]

        log_energies = [[] for _ in range(len(text_list))]
        for i in range(len(text_list)):
            log_energies[i].append(current_energies[i])

        temperature = self.start_temp
        start_time = time.time()
        spend_minute = 0

        for iteration in range(self.max_iterations):
            # 1) Generate neighbors
            new_solutions = [self.neighbor_fn(sol) for sol in solutions]

            # 2) Calculate new energies in batch
            new_energies = self.cost_fn(new_solutions)

            # 3) Acceptance and update
            for i in range(len(text_list)):

                diff = new_energies[i] - current_energies[i]
                ap = self._acceptance_probability(diff, temperature)

                if random.random() < ap:
                    solutions[i] = new_solutions[i]
                    current_energies[i] = new_energies[i]

                if current_energies[i] < best_energies[i]:
                    best_solutions[i] = solutions[i][:]
                    best_energies[i] = current_energies[i]

            # 4) Lower temperature
            temperature = self._lower_temperature(temperature, iteration)

            # 5) Log current energies
            for i in range(len(text_list)):
                log_energies[i].append(current_energies[i])

            # 6) Print progress (extracted into separate method)
            spend_minute = self._print_progress(
                iteration,
                best_solutions,
                best_energies,
                solutions,
                current_energies,
                temperature,
                start_time,
                spend_minute
            )

            # 7) Early stop if temperature is below threshold
            if temperature <= self.end_temp or spend_minute >= max_minute:
                print("Exiting.")
                break

        print(f"Execution time: {time.time() - start_time:.4f}s")

        # Convert best solutions back to strings
        return best_solutions, best_energies, log_energies

# %%
import random
from typing import List

class TSPListOperations:
    @staticmethod
    def two_rotation(item: List[str]) -> List[str]:
        i, j = random.sample(range(len(item)), 2)
        # Rotate two elements: (i, j) -> (j, i)
        item[i], item[j] = item[j], item[i]
        return item
    
    @staticmethod
    def random_rotation(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item

        start_idx, end_idx = sorted(random.sample(range(len(item)), 2))

        shift = random.randint(1, len(item) - 1)
        sublist = item[start_idx:end_idx + 1]

        shift = shift % len(sublist)  # Normalize shift within sublist length
        sublist = sublist[shift:] + sublist[:shift]

        item[start_idx:end_idx + 1] = sublist

        return item

    @staticmethod
    def random_insertion(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item
        
        size = random.randint(2, min(8, len(item)))
        start = random.randint(0, len(item)-size-1)
        end = start + size

        if random.random() < 0.5:
            elem = item.pop(end)
            item.insert(start, elem)
        else:
            elem = item.pop(start)
            item.insert(end, elem)
        return item

    @staticmethod
    def shuffle_sublist(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item

        size = random.randint(2, min(8, len(item)))
        start = random.randint(0, len(item) - size-1)
        end = start + size - 1
        random.shuffle(item[start:end + 1])
        return item

    @staticmethod
    def double_bridge_move(item: List[str]) -> List[str]:
        n = len(item)
        
        size_B = random.randint(1, 4)  
        size_C = random.randint(1, 2)  
        size_D = random.randint(1, 4)  
        
        size_A = random.randint(0, n - (size_B + size_C + size_D))
        size_E = n - (size_A + size_B + size_C + size_D)
        
        # (3) a, b, c, d 계산
        a = size_A
        b = a + size_B
        c = b + size_C
        d = c + size_D
     
        A = item[:a]
        B = item[a:b]
        C = item[b:c]
        D = item[c:d]
        E = item[d:]

        if random.choice([True, False]):
            B = B[::-1]
        if random.choice([True, False]):
            D = D[::-1]

        return A + D + C + B + E

# %%
def cost_fn(sols, batch_size=10):
  return scorer.get_perplexity(sols, batch_size=batch_size)

def neighbor_fn(arr: str, prefix: int = 0, suffix: int = 0) -> str:
    item = arr.split()
    operations = [
        TSPListOperations.two_rotation,
        TSPListOperations.random_rotation,
        TSPListOperations.random_insertion,
        TSPListOperations.shuffle_sublist,
        TSPListOperations.double_bridge_move,
    ]

    op = random.choice(operations)
    item_modified = item[:prefix] + op(item[prefix:len(item)-suffix]) + item[len(item)-suffix:]
    return ' '.join(item_modified)

# %%
model_path = "/kaggle/input/gemma-2/transformers/gemma-2-9b/2"
model_loader = HuggingFaceModelLoader(model_path=model_path, load_in_8bit=False, device_map='auto')
tokenizer = HuggingFaceTokenizer(model_path)
scorer = PerplexityCalculator(model_loader, tokenizer, exp_mode=True)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
def average_increment(current_T0, uphill_diffs, p0):
    epsilon = 1e-12

    total_temperatures = []
    for diff in uphill_diffs:
        exponent = -diff / (current_T0 + epsilon)
        exponent = max(min(exponent, 700), -700)
        temperature = math.exp(exponent)
        total_temperatures.append(temperature)
        
    avg_exp = sum(total_temperatures) / len(total_temperatures)
    return avg_exp - p0

def estimate_initial_temperature(uphill_diffs, p0=0.1):
    
    num_uphill_diffs = len(uphill_diffs)
    if num_uphill_diffs == 0:
        return -1.0 / math.log(p0 + 1e-12)

    epsilon = 1e-12
    max_uphill_diff = max(uphill_diffs)
    low = epsilon
    high = max_uphill_diff * 100.0

    for _ in range(500):
        mid = (low + high) / 2.0
        val = average_increment(current_T0=mid, 
                                 uphill_diffs=uphill_diffs, 
                                 p0=p0)
        if val > 0:
            high = mid
        else:
            low = mid

    return (low + high) / 2.0

# %%
torch.cuda.empty_cache()

# %%
PREFIX_LENGTH = 0
SUFFIX_LENGTH = 0

sa_params = {
    'start_temp': 0.5,             # Initial temperature
    'end_temp': 0.01,          # Final temperature, decreasing linearly
    'max_iterations': 40000,    
    'random_state': 42,          # Seed for the random number generator to ensure reproducibility
    "cost_fn": cost_fn,
    "neighbor_fn": lambda x: neighbor_fn(x, prefix=PREFIX_LENGTH, suffix=SUFFIX_LENGTH)
}

# Initialize the SimulatedAnnealing optimizer with the specified parameters
sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
def shuffle_middle_words(seqs, prefix_length, suffix_length):
    words = seqs.split()
    total_length = len(words)
    
    if total_length < prefix_length + suffix_length:
        raise ValueError("単語数が先頭と末尾の長さの合計より少ないです。")
    
    # 先頭の単語を取得
    prefix = words[:prefix_length]
    
    # 末尾の単語を取得
    suffix = words[-suffix_length:] if suffix_length > 0 else []
    
    # 先頭と末尾以外の単語を取得
    middle = words[prefix_length:-suffix_length] if suffix_length > 0 else words[prefix_length:]
    
    # 中間の単語をシャッフル
    random.shuffle(middle)
    
    # 全体を結合
    shuffled_words = prefix + middle + suffix
    
    # リストを文字列に戻す
    return ' '.join(shuffled_words)

# %%
seqs = ['the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping']
print(cost_fn(seqs[0]))
# Out:
# 31.12816306397628

# %%
best_solutions, best_energies, log_scores = sa_optimizer.solve_batch(seqs, max_minute=60*5)
# Out:
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 08:59:19
# Iteration: 401/40000 (1.00%)
# Temperature: 0.4951
# Elapsed Time: 60.07 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the the of of and and to in is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   31.5242
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:00:19
# Iteration: 781/40000 (1.95%)
# Temperature: 0.4904
# Elapsed Time: 120.03 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard bow candy cheer chimney chimney believe elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia sleigh snowglobe stocking star wreath wonder workshop workshop reindeer wrapping
#
# Current Energies:
#   34.6332
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:01:19
# Iteration: 1168/40000 (2.92%)
# Temperature: 0.4857
# Elapsed Time: 180.07 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace give gifts game greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard bow candy cheer chimney chimney believe elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia sleigh snowglobe stocking star wreath wonder workshop workshop reindeer wrapping
#
# Current Energies:
#   35.9243
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:02:19
# Iteration: 1555/40000 (3.89%)
# Temperature: 0.4810
# Elapsed Time: 240.14 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and to in and is and you that it we with have from not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace give gifts game greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard bow candy cheer chimney chimney believe elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi gingerbread milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia sleigh snowglobe stocking star wreath wonder workshop workshop reindeer wrapping
#
# Current Energies:
#   40.8889
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:03:19
# Iteration: 1942/40000 (4.86%)
# Temperature: 0.4762
# Elapsed Time: 300.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and to in and is from and you that it we with have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace gifts game greeting give holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi gingerbread milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe stocking star wreath wonder workshop workshop wrapping
#
# Current Energies:
#   37.3123
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:04:19
# Iteration: 2330/40000 (5.83%)
# Temperature: 0.4715
# Elapsed Time: 360.14 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and to in and is from and you that it we with have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace greeting gifts game give hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace gingerbread fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   38.0975
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:05:19
# Iteration: 2717/40000 (6.79%)
# Temperature: 0.4667
# Elapsed Time: 420.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and to in is from and you that it we with have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace greeting give gifts game hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace gingerbread fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   38.2544
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:06:19
# Iteration: 3105/40000 (7.76%)
# Temperature: 0.4620
# Elapsed Time: 480.08 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and to in and is from and you that it we with have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace greeting give gifts game hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace gingerbread fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   38.5555
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:07:19
# Iteration: 3494/40000 (8.73%)
# Temperature: 0.4572
# Elapsed Time: 540.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and to in is from and you that it we with have not as advent card carol candle cheer chimney cookie decorations doll dream drive eat family fireplace greeting give gifts game hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chocolate chimney elf eggnog fireplace gingerbread fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   39.5587
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:08:19
# Iteration: 3881/40000 (9.70%)
# Temperature: 0.4525
# Elapsed Time: 600.12 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and to in is from and you that it we with have not as advent card carol candle chocolate cheer chimney decorations doll dream drive eat family fireplace gifts game give greeting hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer cookie chimney elf eggnog fireplace gingerbread fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   38.5539
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:09:19
# Iteration: 4268/40000 (10.67%)
# Temperature: 0.4477
# Elapsed Time: 660.00 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and to in is from and you that it we with have not as advent card carol candle chocolate cheer cookie decorations doll dream drive eat family fireplace gingerbread gifts game greeting give hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Current Energies:
#   36.7439
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:10:19
# Iteration: 4655/40000 (11.64%)
# Temperature: 0.4430
# Elapsed Time: 720.00 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and and to in is with from you that it we have not as advent card carol candle cheer cheer cookie decorations doll dream drive eat family fireplace gingerbread gifts game greeting give hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle night magi milk naughty nice mistletoe nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath workshop wonder workshop wrapping
#
# Current Energies:
#   41.2916
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:11:19
# Iteration: 5043/40000 (12.61%)
# Temperature: 0.4382
# Elapsed Time: 780.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the the of of and and and to with in is from you that it we have not as advent card carol candle cheer cheer cookie decorations doll dream drive eat family fireplace gingerbread gifts game greeting give hope holiday joy laugh merry night ornament peace puzzle relax scrooge season sing visit sleep toy unwrap walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice mistletoe nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath workshop wonder workshop wrapping
#
# Current Energies:
#   43.2618
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:12:19
# Iteration: 5431/40000 (13.58%)
# Temperature: 0.4335
# Elapsed Time: 840.07 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the the of of and and and from to with in is you that it we have not as advent card carol candle cheer cookie decorations doll dream drive eat family fireplace give greeting gifts game holiday gingerbread hope joy laugh merry night ornament peace cheer puzzle relax scrooge season sing stocking sleep toy unwrap walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice mistletoe nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star visit wrapping wreath wonder workshop workshop
#
# Current Energies:
#   45.8000
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:13:19
# Iteration: 5818/40000 (14.54%)
# Temperature: 0.4287
# Elapsed Time: 900.11 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the the of the of and and and from to with in is you that it we have not as advent card carol candle cheer cookie decorations doll dream drive eat family fireplace game holiday gifts give gingerbread greeting hope joy laugh cheer merry night ornament peace puzzle relax scrooge season sing stocking sleep toy unwrap walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice mistletoe nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star visit wrapping wreath wonder workshop workshop
#
# Current Energies:
#   44.3369
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:14:19
# Iteration: 6205/40000 (15.51%)
# Temperature: 0.4240
# Elapsed Time: 960.10 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: of the of the and from the to with and in and is you that it we have not as advent card carol candle cheer cookie decorations doll dream drive eat family fireplace game holiday gifts give gingerbread greeting hope joy laugh merry night ornament peace puzzle relax scrooge cheer season sleep sing stocking toy unwrap walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star visit wrapping wreath wonder workshop workshop
#
# Current Energies:
#   44.1133
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:15:19
# Iteration: 6593/40000 (16.48%)
# Temperature: 0.4192
# Elapsed Time: 1020.07 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: of the of and the and from the with in and to is you that it we have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gifts give gingerbread greeting hope joy laugh merry night ornament peace puzzle relax scrooge cheer season sleep sing stocking toy unwrap walk wish yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star holiday wrapping wreath wonder workshop workshop
#
# Current Energies:
#   47.8157
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:16:19
# Iteration: 6981/40000 (17.45%)
# Temperature: 0.4145
# Elapsed Time: 1080.08 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the of and of and from the and the with in to is you that it we have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax holiday scrooge cheer season sleep sing stocking toy walk wish yuletide angel bake beard believe bow candy chimney chocolate chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wrapping wonder workshop workshop
#
# Current Energies:
#   47.3321
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:17:19
# Iteration: 7368/40000 (18.42%)
# Temperature: 0.4097
# Elapsed Time: 1140.01 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: the of of and and from the and the with in to is you that it we have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax holiday scrooge season sleep sing stocking cheer toy walk wish yuletide angel bake beard believe bow candy chimney chocolate chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk naughty nice mistletoe night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wrapping wonder workshop workshop
#
# Current Energies:
#   47.4606
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:18:19
# Iteration: 7756/40000 (19.39%)
# Temperature: 0.4050
# Elapsed Time: 1200.08 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of the of and with in is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax scrooge season sleep sing holiday stocking cheer toy walk wish yuletide angel bake beard believe bow candy chimney chocolate chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice nutcracker ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wrapping wonder workshop workshop
#
# Current Energies:
#   47.0699
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:19:19
# Iteration: 8144/40000 (20.36%)
# Temperature: 0.4002
# Elapsed Time: 1260.08 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and of the with in is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax scrooge season sleep sing holiday stocking cheer toy walk wish yuletide angel bake beard believe bow candy chimney chocolate chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night nutcracker naughty nice ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wrapping wonder workshop workshop
#
# Current Energies:
#   47.8313
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:20:19
# Iteration: 8532/40000 (21.33%)
# Temperature: 0.3955
# Elapsed Time: 1320.15 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and of the with in is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax scrooge season sleep sing holiday stocking cheer toy walk wrapping yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night nutcracker naughty nice ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   48.5808
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:21:19
# Iteration: 8920/40000 (22.30%)
# Temperature: 0.3907
# Elapsed Time: 1380.12 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and of the with in is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax scrooge season sleep stocking sing holiday cheer toy walk wrapping yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night nutcracker naughty nice ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   48.3387
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:22:19
# Iteration: 9308/40000 (23.27%)
# Temperature: 0.3860
# Elapsed Time: 1440.15 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from the and and the of and the with in of is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry night ornament peace puzzle relax scrooge season sleep stocking sing holiday cheer toy walk wrapping yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night nutcracker naughty nice ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   48.8401
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:23:19
# Iteration: 9695/40000 (24.24%)
# Temperature: 0.3812
# Elapsed Time: 1500.11 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from the and and the of and the with in of is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy laugh merry holiday night ornament peace puzzle relax scrooge season sleep stocking cheer toy walk wrapping yuletide sing angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice nutcracker ornament mistletoe paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   48.6075
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:24:19
# Iteration: 10083/40000 (25.21%)
# Temperature: 0.3765
# Elapsed Time: 1560.13 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and the with in of is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope joy holiday laugh merry night ornament peace puzzle relax scrooge season sleep stocking cheer toy walk wrapping yuletide sing angel beard believe bake bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice ornament mistletoe nutcracker paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   50.7791
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:25:19
# Iteration: 10470/40000 (26.17%)
# Temperature: 0.3717
# Elapsed Time: 1620.15 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and the with in of is you that it we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope holiday laugh merry joy night ornament peace puzzle relax scrooge season cheer sleep stocking toy walk wrapping yuletide sing angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice ornament mistletoe nutcracker paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   49.6993
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:26:19
# Iteration: 10857/40000 (27.14%)
# Temperature: 0.3670
# Elapsed Time: 1680.10 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the the with in is you that it of we to have not as advent card visit carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope holiday laugh merry night ornament peace joy puzzle relax scrooge sing season cheer sleep stocking toy walk wrapping yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi milk night naughty nice ornament mistletoe nutcracker paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   51.1699
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:27:19
# Iteration: 11245/40000 (28.11%)
# Temperature: 0.3622
# Elapsed Time: 1740.15 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the the of in is you that it with we to have not as advent card cheer carol candle cheer cookie decorations doll dream drive eat family fireplace game gingerbread gifts give greeting hope holiday laugh merry night ornament peace puzzle relax scrooge sing season sleep stocking toy visit walk wrapping joy yuletide angel bake beard believe bow candy chocolate chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi mistletoe milk night naughty nice ornament nutcracker paper peppermint polar poinsettia reindeer sleigh snowglobe star unwrap wreath wish wonder workshop workshop
#
# Current Energies:
#   49.1653
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:28:19
# Iteration: 11632/40000 (29.08%)
# Temperature: 0.3575
# Elapsed Time: 1800.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the the of in is you that it with we to have not as advent card chocolate candle cheer cookie decorations doll cheer dream drive eat family fireplace game gingerbread gifts give greeting hope holiday laugh merry night ornament peace puzzle relax scrooge sing season sleep star toy visit walk wrapping joy yuletide angel bake beard believe bow candy carol chimney chimney elf eggnog fireplace fruitcake grinch holly hohoho jingle jump kaggle magi mistletoe milk naughty nice night nutcracker paper ornament peppermint polar poinsettia reindeer sleigh snowglobe stocking unwrap wreath wish workshop workshop wonder
#
# Current Energies:
#   49.8182
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 09:29:19
# Iteration: 12020/40000 (30.05%)
# Temperature: 0.3528
# Elapsed Time: 1860.14 seconds
#
# Best Solutions:
# ...
#
# Current Energies:
#   36.5034
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:32:19
# Iteration: 36449/40000 (91.12%)
# Temperature: 0.0535
# Elapsed Time: 5640.04 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.3957
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:33:19
# Iteration: 36838/40000 (92.09%)
# Temperature: 0.0534
# Elapsed Time: 5700.12 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.3957
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:34:19
# Iteration: 37225/40000 (93.06%)
# Temperature: 0.0534
# Elapsed Time: 5760.13 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.3957
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:35:19
# Iteration: 37612/40000 (94.03%)
# Temperature: 0.0533
# Elapsed Time: 5820.05 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.3957
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:36:19
# Iteration: 38001/40000 (95.00%)
# Temperature: 0.0533
# Elapsed Time: 5880.15 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of of the the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.5434
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:37:19
# Iteration: 38388/40000 (95.97%)
# Temperature: 0.0533
# Elapsed Time: 5940.10 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of of the the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.5434
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:38:19
# Iteration: 38775/40000 (96.94%)
# Temperature: 0.0532
# Elapsed Time: 6000.07 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and of the of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.3957
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:39:19
# Iteration: 39163/40000 (97.91%)
# Temperature: 0.0532
# Elapsed Time: 6060.08 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and and the and the of of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.6322
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:40:19
# Iteration: 39550/40000 (98.88%)
# Temperature: 0.0532
# Elapsed Time: 6120.06 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.4111
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-15 10:41:19
# Iteration: 39938/40000 (99.84%)
# Temperature: 0.0531
# Elapsed Time: 6180.11 seconds
#
# Best Solutions:
#   Solution 1: the the the of of and to in and is and you that it we with from have not as advent card carol candle cheer chocolate cookie decorations doll dream drive eat family fireplace game gifts give greeting holiday hope joy laugh merry night ornament peace puzzle relax scrooge season sing sleep toy unwrap visit walk wish yuletide angel bake beard believe bow candy cheer chimney chimney elf eggnog fireplace fruitcake gingerbread grinch holly hohoho jingle jump kaggle magi milk mistletoe naughty nice night nutcracker ornament paper peppermint polar poinsettia reindeer sleigh snowglobe star stocking wreath wonder workshop workshop wrapping
#
# Best Energies:
#   31.1282
#
# Current Solutions:
#   Solution 1: from and the and the of and of the to in is you that it we have not with as advent card chocolate candle cheer cookie decorations doll dream drive eat family fireplace game give gifts holiday hope laugh magi night ornament peace puzzle relax scrooge season sing sleep star stocking visit wreath wish workshop joy angel bake beard believe bow candy carol cheer chimney chimney elf eggnog fireplace fruitcake gingerbread greeting grinch holly hohoho jingle jump kaggle merry milk mistletoe naughty nice night nutcracker ornament paper peppermint poinsettia polar reindeer sleigh snowglobe toy unwrap walk wonder workshop wrapping yuletide
#
# Current Energies:
#   36.4111
# ========================================
#
# Execution time: 6189.5762s

# %%
# print(best_solutions)

# %%
# To visualize whether the scores decreased appropriately, you can use matplotlib to create a plot.

import matplotlib.pyplot as plt
for idx, elem in enumerate(log_scores):
    plt.plot(elem, label=f'element_{idx}', alpha=0.5)
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()
