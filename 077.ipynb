# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/077.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 4.221442e+04  0.015936
# 1                                 5.849961e+04 -0.014376
# 2                                 9.940945e+04  0.002905
# 3                                 5.162331e+04  0.003356
# 4                                 5.063790e+04 -0.008299
# ...                                        ...       ...
# 2503                              5.375020e+05  0.027199
# 2504                              9.933916e+04 -0.009746
# 2505                              1.379589e+05  0.022125
# 2506                              2.612069e+05 -0.005393
# 2507                              1.383562e+06  0.065402
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.154699e+04  0.015936
# 1                  14            1     5.934671e+04 -0.014376
# 2                   9            1     9.912108e+04  0.002905
# 3                  15            1     5.145036e+04  0.003356
# 4                  15            0     5.105989e+04 -0.008299
# ...               ...          ...              ...       ...
# 2503                1            1     5.230794e+05  0.027199
# 2504                9            1     1.003121e+05 -0.009746
# 2505                8            0     1.349400e+05  0.022125
# 2506                8            0     2.626193e+05 -0.005393
# 2507                9            1     1.295969e+06  0.065402
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
import time
epock = 10
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.009269093151382931
# Fold 18 RMSLE for ('model1', 'model3') = 0.009333115516386754
# Fold 18 RMSLE for ('model1', 'model4') = 0.009343033615431597
# Fold 18 RMSLE for ('model2', 'model3') = 0.009287752557345267
# Fold 18 RMSLE for ('model2', 'model4') = 0.0093284920014041
# Fold 18 RMSLE for ('model3', 'model4') = 0.00937740894195307
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.009284479310421565
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.0093047184151829
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.009343768080151188
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.009317485131547329
# Fold 18 RMSLE for all models ensemble = 0.00930734299965064
# Fold 18 best combination: ('model1', 'model2') with RMSLE = 0.009269093151382931
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.01192126964832347
# Fold 19 RMSLE for model2 = 0.012205431855319818
# Fold 19 RMSLE for model3 = 0.01199707017841717
# Fold 19 RMSLE for model4 = 0.01232251657069514
# Fold 19 RMSLE for ('model1', 'model2') = 0.012002963633745463
# Fold 19 RMSLE for ('model1', 'model3') = 0.011945842955150113
# Fold 19 RMSLE for ('model1', 'model4') = 0.01210232222828938
# Fold 19 RMSLE for ('model2', 'model3') = 0.01200064278939763
# Fold 19 RMSLE for ('model2', 'model4') = 0.012233992075027655
# Fold 19 RMSLE for ('model3', 'model4') = 0.012120167447954529
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.011963555673194173
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.012100954756505144
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.012047962146625154
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.012099545994202017
# Fold 19 RMSLE for all models ensemble = 0.012045676396725942
# Fold 19 best combination: model1 with RMSLE = 0.01192126964832347
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.01035040784555727
# Fold 20 RMSLE for model2 = 0.010010738153843284
# Fold 20 RMSLE for model3 = 0.010601170742703728
# Fold 20 RMSLE for model4 = 0.010241164726785499
# Fold 20 RMSLE for ('model1', 'model2') = 0.010149780354511344
# Fold 20 RMSLE for ('model1', 'model3') = 0.010461304232014065
# Fold 20 RMSLE for ('model1', 'model4') = 0.010287523963170085
# Fold 20 RMSLE for ('model2', 'model3') = 0.010246201951809062
# Fold 20 RMSLE for ('model2', 'model4') = 0.010096078855184968
# Fold 20 RMSLE for ('model3', 'model4') = 0.010402595961260992
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.010274216301938066
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.010170221887864601
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.010379182874980493
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.010236300911844859
# Fold 20 RMSLE for all models ensemble = 0.010260525006923545
# Fold 20 best combination: model2 with RMSLE = 0.010010738153843284
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.009421551778886135
# Fold 21 RMSLE for model2 = 0.00880202541874614
# Fold 21 RMSLE for model3 = 0.009655956112801234
# Fold 21 RMSLE for model4 = 0.009284094573172254
# Fold 21 RMSLE for ('model1', 'model2') = 0.009063248568219282
# Fold 21 RMSLE for ('model1', 'model3') = 0.00952123044771545
# Fold 21 RMSLE for ('model1', 'model4') = 0.009339748322059341
# Fold 21 RMSLE for ('model2', 'model3') = 0.009144194850718879
# Fold 21 RMSLE for ('model2', 'model4') = 0.009010211599288723
# Fold 21 RMSLE for ('model3', 'model4') = 0.009439757418455456
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.009226601850396912
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.00912745214621311
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.009426778958702859
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.009181680907815052
# Fold 21 RMSLE for all models ensemble = 0.0092344442206485
# Fold 21 best combination: model2 with RMSLE = 0.00880202541874614
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.009478809784113439
# Fold 22 RMSLE for model2 = 0.009027725852057406
# Fold 22 RMSLE for model3 = 0.009781578516597429
# Fold 22 RMSLE for model4 = 0.009585488373305927
# Fold 22 RMSLE for ('model1', 'model2') = 0.009215070453221319
# Fold 22 RMSLE for ('model1', 'model3') = 0.00961554658899797
# Fold 22 RMSLE for ('model1', 'model4') = 0.009522364251625667
# Fold 22 RMSLE for ('model2', 'model3') = 0.00933418795181075
# Fold 22 RMSLE for ('model2', 'model4') = 0.009273014887486955
# Fold 22 RMSLE for ('model3', 'model4') = 0.009656822868987554
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.009374826519378831
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.009327961201975305
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.009592501932154393
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.009406969586984663
# Fold 22 RMSLE for all models ensemble = 0.009420290747621516
# Fold 22 best combination: model2 with RMSLE = 0.009027725852057406
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.009269471407544522
# Fold 23 RMSLE for model2 = 0.009161700610850995
# Fold 23 RMSLE for model3 = 0.009592053749723222
# Fold 23 RMSLE for model4 = 0.009295626698697072
# Fold 23 RMSLE for ('model1', 'model2') = 0.009165808520047655
# Fold 23 RMSLE for ('model1', 'model3') = 0.009409182396470522
# Fold 23 RMSLE for ('model1', 'model4') = 0.009269681735344936
# Fold 23 RMSLE for ('model2', 'model3') = 0.009277698747605858
# Fold 23 RMSLE for ('model2', 'model4') = 0.009195770014291576
# Fold 23 RMSLE for ('model3', 'model4') = 0.009407116310194114
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.009265314407358251
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.00919985743758116
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.009353994568267195
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0092746604668634
# Fold 23 RMSLE for all models ensemble = 0.009266410599516873
# Fold 23 best combination: model2 with RMSLE = 0.009161700610850995
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.011141038049901467
# Fold 24 RMSLE for model2 = 0.01031492916451547
# Fold 24 RMSLE for model3 = 0.011441502694108324
# Fold 24 RMSLE for model4 = 0.010985930650958459
# Fold 24 RMSLE for ('model1', 'model2') = 0.010688138416099419
# Fold 24 RMSLE for ('model1', 'model3') = 0.011272295872276105
# Fold 24 RMSLE for ('model1', 'model4') = 0.011048777344266514
# Fold 24 RMSLE for ('model2', 'model3') = 0.010805611088900732
# Fold 24 RMSLE for ('model2', 'model4') = 0.010619879273731625
# Fold 24 RMSLE for ('model3', 'model4') = 0.011185895024617268
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.010907796781206664
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.010776328548196398
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.01116211919831666
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.010855990856787769
# Fold 24 RMSLE for all models ensemble = 0.010919983719717283
# Fold 24 best combination: model2 with RMSLE = 0.01031492916451547
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.009781060156233872
# Fold 25 RMSLE for model2 = 0.009498726976754177
# Fold 25 RMSLE for model3 = 0.01001549008316491
# Fold 25 RMSLE for model4 = 0.009699610137881787
# Fold 25 RMSLE for ('model1', 'model2') = 0.009594352495332623
# Fold 25 RMSLE for ('model1', 'model3') = 0.00987936232869458
# Fold 25 RMSLE for ('model1', 'model4') = 0.009721281856315996
# Fold 25 RMSLE for ('model2', 'model3') = 0.009679378759500132
# Fold 25 RMSLE for ('model2', 'model4') = 0.009569689899780002
# Fold 25 RMSLE for ('model3', 'model4') = 0.00982412633934235
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.00970206219940093
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.009618027940999701
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.009800298752750021
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.00967535754438336
# Fold 25 RMSLE for all models ensemble = 0.00969272667786213
# Fold 25 best combination: model2 with RMSLE = 0.009498726976754177
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.009442239992909534
# Fold 26 RMSLE for model2 = 0.009075886731550234
# Fold 26 RMSLE for model3 = 0.009640548661262523
# Fold 26 RMSLE for model4 = 0.009479077570957669
# Fold 26 RMSLE for ('model1', 'model2') = 0.009215382524618329
# Fold 26 RMSLE for ('model1', 'model3') = 0.009520907888512517
# Fold 26 RMSLE for ('model1', 'model4') = 0.009451533559707223
# Fold 26 RMSLE for ('model2', 'model3') = 0.009281120993338927
# Fold 26 RMSLE for ('model2', 'model4') = 0.009245306047524271
# Fold 26 RMSLE for ('model3', 'model4') = 0.009534114451895932
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.009323643074511796
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.00929480891457965
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.00949599367085383
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.009338641982516707
# Fold 26 RMSLE for all models ensemble = 0.0093575681255729
# Fold 26 best combination: model2 with RMSLE = 0.009075886731550234
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.008985421392195785
# Fold 27 RMSLE for model2 = 0.00876096989019928
# Fold 27 RMSLE for model3 = 0.009275896280592747
# Fold 27 RMSLE for model4 = 0.00911170292613827
# Fold 27 RMSLE for ('model1', 'model2') = 0.008809288117017972
# Fold 27 RMSLE for ('model1', 'model3') = 0.009110140720332262
# Fold 27 RMSLE for ('model1', 'model4') = 0.009018713998121049
# Fold 27 RMSLE for ('model2', 'model3') = 0.008925531279134757
# Fold 27 RMSLE for ('model2', 'model4') = 0.008903276113360522
# Fold 27 RMSLE for ('model3', 'model4') = 0.009147283787677181
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.008928846359930355
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.008896446345533415
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.009081210685261649
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.008972829133877909
# Fold 27 RMSLE for all models ensemble = 0.008961902303347515
# Fold 27 best combination: model2 with RMSLE = 0.00876096989019928
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.010939370514871897
# Fold 28 RMSLE for model2 = 0.01085658907238858
# Fold 28 RMSLE for model3 = 0.011135527491588946
# Fold 28 RMSLE for model4 = 0.011065638286214506
# Fold 28 RMSLE for ('model1', 'model2') = 0.010844398489239501
# Fold 28 RMSLE for ('model1', 'model3') = 0.011020366862282176
# Fold 28 RMSLE for ('model1', 'model4') = 0.010965439668781636
# Fold 28 RMSLE for ('model2', 'model3') = 0.01089769792788355
# Fold 28 RMSLE for ('model2', 'model4') = 0.010936913156266517
# Fold 28 RMSLE for ('model3', 'model4') = 0.011034606865441937
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.010902098737179703
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.010902843442645848
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.010993379097424615
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.010935365173376744
# Fold 28 RMSLE for all models ensemble = 0.01092516511665565
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.010844398489239501
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.008251495238334872
# Fold 29 RMSLE for model2 = 0.008307230832792556
# Fold 29 RMSLE for model3 = 0.008507319590419775
# Fold 29 RMSLE for model4 = 0.008424781434059194
# Fold 29 RMSLE for ('model1', 'model2') = 0.00822356878081851
# Fold 29 RMSLE for ('model1', 'model3') = 0.008361515228533305
# Fold 29 RMSLE for ('model1', 'model4') = 0.00832475250523042
# Fold 29 RMSLE for ('model2', 'model3') = 0.008319631920245167
# Fold 29 RMSLE for ('model2', 'model4') = 0.008334165309981953
# Fold 29 RMSLE for ('model3', 'model4') = 0.008436698468978777
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.008283594485042213
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.008283003995679395
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.008367521114574178
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.008346977883583195
# Fold 29 RMSLE for all models ensemble = 0.008313718318594043
# Fold 29 best combination: ('model1', 'model2') with RMSLE = 0.00822356878081851
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.012106368758376968
# Fold 30 RMSLE for model2 = 0.012348346017804256
# Fold 30 RMSLE for model3 = 0.012213553740731067
# Fold 30 RMSLE for model4 = 0.012335979021281503
# Fold 30 RMSLE for ('model1', 'model2') = 0.012184431407763496
# Fold 30 RMSLE for ('model1', 'model3') = 0.012142845386521953
# Fold 30 RMSLE for ('model1', 'model4') = 0.012213007562962298
# Fold 30 RMSLE for ('model2', 'model3') = 0.012200322767077295
# Fold 30 RMSLE for ('model2', 'model4') = 0.012311349574075788
# Fold 30 RMSLE for ('model3', 'model4') = 0.012249104788779214
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.012160094320201187
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.012227141079906937
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.012195973041587071
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.012238382997598501
# Fold 30 RMSLE for all models ensemble = 0.01219967053850741
# Fold 30 best combination: model1 with RMSLE = 0.012106368758376968
# ---------------
#
# OOF RMSLE = 0.009611195264868637
# Sum of RMSLE for each combination:
# ('model1',): 0.29359241051951046
# ('model2',): 0.2870666982365986
# ('model3',): 0.2992107492299956
# ('model4',): 0.2954831765850859
# ('model1', 'model2'): 0.28899099244855936
# ('model1', 'model3'): 0.29587380594627216
# ('model1', 'model4'): 0.29406320605372605
# ('model2', 'model3'): 0.2907958710464146
# ('model2', 'model4'): 0.2903619979000415
# ('model3', 'model4'): 0.2963780489433059
# ('model1', 'model2', 'model3'): 0.29142305649198125
# ('model1', 'model2', 'model4'): 0.29083856624240845
# ('model1', 'model3', 'model4'): 0.2952179265041598
# ('model2', 'model3', 'model4'): 0.2920438578894455
# ('model1', 'model2', 'model3', 'model4'): 0.2921995845347544
#
# 1番目の学習が終わりました。
#
# 推定時間は17
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.008137823694542589
# Fold 1 RMSLE for model2 = 0.008015780941103117
# Fold 1 RMSLE for model3 = 0.008178510992995871
# Fold 1 RMSLE for model4 = 0.008126884522705909
# Fold 1 RMSLE for ('model1', 'model2') = 0.008044704476705076
# Fold 1 RMSLE for ('model1', 'model3') = 0.008120064769129706
# Fold 1 RMSLE for ('model1', 'model4') = 0.008124806634913589
# Fold 1 RMSLE for ('model2', 'model3') = 0.008016702675233937
# Fold 1 RMSLE for ('model2', 'model4') = 0.008049856598552481
# Fold 1 RMSLE for ('model3', 'model4') = 0.008105010082707722
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.008043741635498692
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.008066367806402129
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.008106225489077199
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.008040512474828952
# Fold 1 RMSLE for all models ensemble = 0.008057892097838353
# Fold 1 best combination: model2 with RMSLE = 0.008015780941103117
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.006721955626340647
# Fold 2 RMSLE for model2 = 0.006701381313828625
# Fold 2 RMSLE for model3 = 0.007112611918834713
# Fold 2 RMSLE for model4 = 0.006768992965238015
# Fold 2 RMSLE for ('model1', 'model2') = 0.006662779947662639
# Fold 2 RMSLE for ('model1', 'model3') = 0.00686079843131132
# Fold 2 RMSLE for ('model1', 'model4') = 0.006736439378517011
# Fold 2 RMSLE for ('model2', 'model3') = 0.0067743596944388074
# Fold 2 RMSLE for ('model2', 'model4') = 0.006701950984029308
# Fold 2 RMSLE for ('model3', 'model4') = 0.006866479322797485
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.00673909091380158
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.0066903008716242
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.006805240092189966
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.006753678114140411
# Fold 2 RMSLE for all models ensemble = 0.006736998318253351
# Fold 2 best combination: ('model1', 'model2') with RMSLE = 0.006662779947662639
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.007060853879490355
# Fold 3 RMSLE for model2 = 0.006910683726557809
# Fold 3 RMSLE for model3 = 0.007420623342957559
# Fold 3 RMSLE for model4 = 0.006982499434544812
# Fold 3 RMSLE for ('model1', 'model2') = 0.0069428521953204085
# Fold 3 RMSLE for ('model1', 'model3') = 0.007196015792300164
# Fold 3 RMSLE for ('model1', 'model4') = 0.007010792077412835
# Fold 3 RMSLE for ('model2', 'model3') = 0.007050107596208254
# Fold 3 RMSLE for ('model2', 'model4') = 0.006922558596340561
# Fold 3 RMSLE for ('model3', 'model4') = 0.007134873479625046
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.0070402065215851226
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.006950110896675205
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.007099956710426637
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.007012294901833959
# Fold 3 RMSLE for all models ensemble = 0.007016983356423446
# Fold 3 best combination: model2 with RMSLE = 0.006910683726557809
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.006662464478513101
# Fold 4 RMSLE for model2 = 0.006343403245709568
# Fold 4 RMSLE for model3 = 0.007160083959850845
# Fold 4 RMSLE for model4 = 0.006684822710183153
# Fold 4 RMSLE for ('model1', 'model2') = 0.00645262787163727
# Fold 4 RMSLE for ('model1', 'model3') = 0.006863308375185329
# Fold 4 RMSLE for ('model1', 'model4') = 0.0066597850363144554
# Fold 4 RMSLE for ('model2', 'model3') = 0.006625552130147489
# Fold 4 RMSLE for ('model2', 'model4') = 0.006481598050598313
# Fold 4 RMSLE for ('model3', 'model4') = 0.006852269621731441
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.006622045649740589
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.006520795567902259
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.00677662043134818
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.00662703378790683
# Fold 4 RMSLE for all models ensemble = 0.006626959540053974
# Fold 4 best combination: model2 with RMSLE = 0.006343403245709568
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.007915144486074808
# Fold 5 RMSLE for model2 = 0.007545750480765658
# Fold 5 RMSLE for model3 = 0.008416589801389101
# Fold 5 RMSLE for model4 = 0.007805563667379314
# Fold 5 RMSLE for ('model1', 'model2') = 0.007691261221192822
# Fold 5 RMSLE for ('model1', 'model3') = 0.008121835357458897
# Fold 5 RMSLE for ('model1', 'model4') = 0.007850016864063294
# Fold 5 RMSLE for ('model2', 'model3') = 0.007874378400219659
# Fold 5 RMSLE for ('model2', 'model4') = 0.007651223067549181
# Fold 5 RMSLE for ('model3', 'model4') = 0.008044550254653584
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.007874539346293341
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.007722717043124349
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.007991604846562281
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.007833994265076223
# Fold 5 RMSLE for all models ensemble = 0.007847411621269215
# Fold 5 best combination: model2 with RMSLE = 0.007545750480765658
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.008221694783686728
# Fold 6 RMSLE for model2 = 0.00819883561971506
# Fold 6 RMSLE for model3 = 0.008499426290003817
# Fold 6 RMSLE for model4 = 0.008207613813011085
# Fold 6 RMSLE for ('model1', 'model2') = 0.008167428049347943
# Fold 6 RMSLE for ('model1', 'model3') = 0.008318230477748906
# Fold 6 RMSLE for ('model1', 'model4') = 0.0081985227287827
# Fold 6 RMSLE for ('model2', 'model3') = 0.008234064877769056
# Fold 6 RMSLE for ('model2', 'model4') = 0.008175450697759443
# Fold 6 RMSLE for ('model3', 'model4') = 0.008293636757903053
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.008217469435418507
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.008170818705136043
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.008256789376891945
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.008211528748571438
# Fold 6 RMSLE for all models ensemble = 0.008205587605667202
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.008167428049347943
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.009273934958370308
# Fold 7 RMSLE for model2 = 0.008963047156511736
# Fold 7 RMSLE for model3 = 0.009692929749135687
# Fold 7 RMSLE for model4 = 0.009128451368617023
# Fold 7 RMSLE for ('model1', 'model2') = 0.009081301574000106
# Fold 7 RMSLE for ('model1', 'model3') = 0.009438457189219285
# Fold 7 RMSLE for ('model1', 'model4') = 0.00918928292873126
# Fold 7 RMSLE for ('model2', 'model3') = 0.00921021927307895
# Fold 7 RMSLE for ('model2', 'model4') = 0.009021291893895673
# Fold 7 RMSLE for ('model3', 'model4') = 0.00934119322157098
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.009220964260738845
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.009089163006919367
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.00930862063934113
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.009166734686671311
# Fold 7 RMSLE for all models ensemble = 0.009187700654835493
# Fold 7 best combination: model2 with RMSLE = 0.008963047156511736
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.008586233526581595
# Fold 8 RMSLE for model2 = 0.008318134990774667
# Fold 8 RMSLE for model3 = 0.008923038437164573
# Fold 8 RMSLE for model4 = 0.008475473046902993
# Fold 8 RMSLE for ('model1', 'model2') = 0.00841988636895468
# Fold 8 RMSLE for ('model1', 'model3') = 0.008715133730860873
# Fold 8 RMSLE for ('model1', 'model4') = 0.008522371424801008
# Fold 8 RMSLE for ('model2', 'model3') = 0.008527594661447273
# Fold 8 RMSLE for ('model2', 'model4') = 0.008375862652889853
# Fold 8 RMSLE for ('model3', 'model4') = 0.008645617575843242
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.00853578260070083
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.008432563114546371
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.008616177490882936
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.008497326171517126
# Fold 8 RMSLE for all models ensemble = 0.008513459771413818
# Fold 8 best combination: model2 with RMSLE = 0.008318134990774667
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.007761343732916098
# Fold 9 RMSLE for model2 = 0.007456144973635363
# Fold 9 RMSLE for model3 = 0.008049751970910379
# Fold 9 RMSLE for model4 = 0.007666848099944216
# Fold 9 RMSLE for ('model1', 'model2') = 0.007575797376075109
# Fold 9 RMSLE for ('model1', 'model3') = 0.00785881707687687
# Fold 9 RMSLE for ('model1', 'model4') = 0.007705914049164412
# Fold 9 RMSLE for ('model2', 'model3') = 0.0076452993011243316
# Fold 9 RMSLE for ('model2', 'model4') = 0.007542127192554091
# Fold 9 RMSLE for ('model3', 'model4') = 0.0077922316514811435
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.007672361591093332
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.007601292909210446
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.0077719327080488
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.007637913240047679
# Fold 9 RMSLE for all models ensemble = 0.007662933033490152
# Fold 9 best combination: model2 with RMSLE = 0.007456144973635363
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.008277395656292558
# Fold 10 RMSLE for model2 = 0.007960347518173642
# Fold 10 RMSLE for model3 = 0.008631082387408054
# Fold 10 RMSLE for model4 = 0.008135096137522125
# Fold 10 RMSLE for ('model1', 'model2') = 0.008080018774420336
# Fold 10 RMSLE for ('model1', 'model3') = 0.008411937242259778
# Fold 10 RMSLE for ('model1', 'model4') = 0.008195125725900941
# Fold 10 RMSLE for ('model2', 'model3') = 0.008188660492598934
# Fold 10 RMSLE for ('model2', 'model4') = 0.008015754253528129
# Fold 10 RMSLE for ('model3', 'model4') = 0.008322295347032395
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.008205880111901768
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.008087948652281091
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.008296818968306197
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.008152884984142605
# Fold 10 RMSLE for all models ensemble = 0.008177647315103911
# Fold 10 best combination: model2 with RMSLE = 0.007960347518173642
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.00843854241563156
# Fold 11 RMSLE for model2 = 0.008532450237369642
# Fold 11 RMSLE for model3 = 0.008574148828994117
# Fold 11 RMSLE for model4 = 0.008531189397141117
# Fold 11 RMSLE for ('model1', 'model2') = 0.008441934402748898
# Fold 11 RMSLE for ('model1', 'model3') = 0.008472005872704224
# Fold 11 RMSLE for ('model1', 'model4') = 0.00847512531548757
# Fold 11 RMSLE for ('model2', 'model3') = 0.00845398917839398
# Fold 11 RMSLE for ('model2', 'model4') = 0.008505976649655526
# Fold 11 RMSLE for ('model3', 'model4') = 0.00850360806084517
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.008436142875399818
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.00846554900542047
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.008473158356170078
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.008468449678769169
# Fold 11 RMSLE for all models ensemble = 0.008453510339250344
# Fold 11 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.008436142875399818
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.007038190498278386
# Fold 12 RMSLE for model2 = 0.006406514898276635
# Fold 12 RMSLE for model3 = 0.007487517329431384
# Fold 12 RMSLE for model4 = 0.006936570299990388
# Fold 12 RMSLE for ('model1', 'model2') = 0.006682500948625195
# Fold 12 RMSLE for ('model1', 'model3') = 0.007211071436034418
# Fold 12 RMSLE for ('model1', 'model4') = 0.006978499158383166
# Fold 12 RMSLE for ('model2', 'model3') = 0.006827168447705553
# Fold 12 RMSLE for ('model2', 'model4') = 0.006639293117368787
# Fold 12 RMSLE for ('model3', 'model4') = 0.0071402071361995004
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.006883312524875981
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.0067580927944245845
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.007094686505405346
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.006843241952718347
# Fold 12 RMSLE for all models ensemble = 0.006885647748174728
# Fold 12 best combination: model2 with RMSLE = 0.006406514898276635
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.008289560556835149
# Fold 13 RMSLE for model2 = 0.0079918168613656
# Fold 13 RMSLE for model3 = 0.008722941833538297
# Fold 13 RMSLE for model4 = 0.008384796132554526
# Fold 13 RMSLE for ('model1', 'model2') = 0.008101845893484066
# Fold 13 RMSLE for ('model1', 'model3') = 0.008468200812095587
# Fold 13 RMSLE for ('model1', 'model4') = 0.008324927625881764
# Fold 13 RMSLE for ('model2', 'model3') = 0.008252497746057847
# Fold 13 RMSLE for ('model2', 'model4') = 0.008164505178686138
# Fold 13 RMSLE for ('model3', 'model4') = 0.008486475200844909
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.008253891601536268
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.008188902582339107
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.00841314507984966
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.008278948159322548
# Fold 13 RMSLE for all models ensemble = 0.008275681867873221
# Fold 13 best combination: model2 with RMSLE = 0.0079918168613656
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.007927301565270519
# Fold 14 RMSLE for model2 = 0.007534517239155552
# Fold 14 RMSLE for model3 = 0.008314773982525761
# Fold 14 RMSLE for model4 = 0.007973941685374101
# Fold 14 RMSLE for ('model1', 'model2') = 0.007679937837694372
# Fold 14 RMSLE for ('model1', 'model3') = 0.008080539124845965
# Fold 14 RMSLE for ('model1', 'model4') = 0.007937044893011646
# Fold 14 RMSLE for ('model2', 'model3') = 0.007809692439343037
# Fold 14 RMSLE for ('model2', 'model4') = 0.007723764345430679
# Fold 14 RMSLE for ('model3', 'model4') = 0.008079092820631057
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.007833864444013305
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.007769912367713275
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.008018678321202182
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.00784708103870219
# Fold 14 RMSLE for all models ensemble = 0.007858557052005208
# Fold 14 best combination: model2 with RMSLE = 0.007534517239155552
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.007847458645346595
# Fold 15 RMSLE for model2 = 0.007643514761279496
# Fold 15 RMSLE for model3 = 0.00811884567592115
# Fold 15 RMSLE for model4 = 0.00786614764555126
# Fold 15 RMSLE for ('model1', 'model2') = 0.007699238061168782
# Fold 15 RMSLE for ('model1', 'model3') = 0.007930853048733633
# Fold 15 RMSLE for ('model1', 'model4') = 0.007838774332960095
# Fold 15 RMSLE for ('model2', 'model3') = 0.007769152818840238
# Fold 15 RMSLE for ('model2', 'model4') = 0.007731288060703389
# Fold 15 RMSLE for ('model3', 'model4') = 0.007914294573502742
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.007776204075213917
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.007746738779747979
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.007877880038263754
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.0077807396462749884
# Fold 15 RMSLE for all models ensemble = 0.007786089508992493
# Fold 15 best combination: model2 with RMSLE = 0.007643514761279496
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.006362968543283368
# Fold 16 RMSLE for model2 = 0.0061100520135162675
# Fold 16 RMSLE for model3 = 0.006903237457384734
# Fold 16 RMSLE for model4 = 0.006350971909237534
# Fold 16 RMSLE for ('model1', 'model2') = 0.006176961748520142
# Fold 16 RMSLE for ('model1', 'model3') = 0.006577696657119779
# Fold 16 RMSLE for ('model1', 'model4') = 0.006340483654093765
# Fold 16 RMSLE for ('model2', 'model3') = 0.006353475137121687
# Fold 16 RMSLE for ('model2', 'model4') = 0.006198911682555712
# Fold 16 RMSLE for ('model3', 'model4') = 0.006534213742167458
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.006339256813574782
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.006226979233339171
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.0064651046368937185
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.006330123214397424
# Fold 16 RMSLE for all models ensemble = 0.006328644530257134
# Fold 16 best combination: model2 with RMSLE = 0.0061100520135162675
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.007802551056672425
# Fold 17 RMSLE for model2 = 0.007627439675778476
# Fold 17 RMSLE for model3 = 0.008213026235681698
# Fold 17 RMSLE for model4 = 0.00782067796194932
# Fold 17 RMSLE for ('model1', 'model2') = 0.007655958263043393
# Fold 17 RMSLE for ('model1', 'model3') = 0.00796483451950289
# Fold 17 RMSLE for ('model1', 'model4') = 0.007793127536612077
# Fold 17 RMSLE for ('model2', 'model3') = 0.007778858951884936
# Fold 17 RMSLE for ('model2', 'model4') = 0.007691459096690853
# Fold 17 RMSLE for ('model3', 'model4') = 0.007941432782547626
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.007772746469531727
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.007701368307497843
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.007884263602836027
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.007775656723506372
# Fold 17 RMSLE for all models ensemble = 0.00777308569886613
# Fold 17 best combination: model2 with RMSLE = 0.007627439675778476
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.007228426004964452
# Fold 18 RMSLE for model2 = 0.007008075172623655
# Fold 18 RMSLE for model3 = 0.007689781128374743
# Fold 18 RMSLE for model4 = 0.007491802744301504
# Fold 18 RMSLE for ('model1', 'model2') = 0.007070871443793652
# Fold 18 RMSLE for ('model1', 'model3') = 0.007412415044607686
# Fold 18 RMSLE for ('model1', 'model4') = 0.007341925096305861
# Fold 18 RMSLE for ('model2', 'model3') = 0.007220877251297647
# Fold 18 RMSLE for ('model2', 'model4') = 0.007225967586255481
# Fold 18 RMSLE for ('model3', 'model4') = 0.007511378353725395
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.007209813971667718
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.007203181473906241
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.007405435521580524
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.007293322384574145
# Fold 18 RMSLE for all models ensemble = 0.007268251391753084
# Fold 18 best combination: model2 with RMSLE = 0.007008075172623655
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.008752883442204337
# Fold 19 RMSLE for model2 = 0.008670433552998645
# Fold 19 RMSLE for model3 = 0.009082480368300625
# Fold 19 RMSLE for model4 = 0.008906609164643304
# Fold 19 RMSLE for ('model1', 'model2') = 0.008671826425605546
# Fold 19 RMSLE for ('model1', 'model3') = 0.008878112157439574
# Fold 19 RMSLE for ('model1', 'model4') = 0.008818164294647771
# Fold 19 RMSLE for ('model2', 'model3') = 0.008770638400680125
# Fold 19 RMSLE for ('model2', 'model4') = 0.008767199670938013
# Fold 19 RMSLE for ('model3', 'model4') = 0.0089339424487565
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.008752785925439318
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.00874439799879405
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.008864114890134195
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.008802886574324834
# Fold 19 RMSLE for all models ensemble = 0.008783228693069373
# Fold 19 best combination: model2 with RMSLE = 0.008670433552998645
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.008847508382231278
# Fold 20 RMSLE for model2 = 0.008229271098776525
# Fold 20 RMSLE for model3 = 0.00930533241400618
# Fold 20 RMSLE for model4 = 0.008686755095803847
# Fold 20 RMSLE for ('model1', 'model2') = 0.008495151906127898
# Fold 20 RMSLE for ('model1', 'model3') = 0.009033485917402304
# Fold 20 RMSLE for ('model1', 'model4') = 0.008755498056789789
# Fold 20 RMSLE for ('model2', 'model3') = 0.008651874848008043
# Fold 20 RMSLE for ('model2', 'model4') = 0.008430292096744221
# Fold 20 RMSLE for ('model3', 'model4') = 0.008929743888239432
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.008704514339804556
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.008551320147484569
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.00889247140439796
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.008646711181326565
# Fold 20 RMSLE for all models ensemble = 0.00869009770509502
# Fold 20 best combination: model2 with RMSLE = 0.008229271098776525
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.007350484032990481
# Fold 21 RMSLE for model2 = 0.006899640588673374
# Fold 21 RMSLE for model3 = 0.0077453873778195025
# Fold 21 RMSLE for model4 = 0.007223195212111402
# Fold 21 RMSLE for ('model1', 'model2') = 0.007058009481693814
# Fold 21 RMSLE for ('model1', 'model3') = 0.007501253187421617
# Fold 21 RMSLE for ('model1', 'model4') = 0.0072681425326613786
# Fold 21 RMSLE for ('model2', 'model3') = 0.0071897172592024754
# Fold 21 RMSLE for ('model2', 'model4') = 0.007025573967018065
# Fold 21 RMSLE for ('model3', 'model4') = 0.007415537339807298
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.007222492993995734
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.007103920109464024
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.007379734772592311
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.0071832602976019885
# Fold 21 RMSLE for all models ensemble = 0.0072119864799968375
# Fold 21 best combination: model2 with RMSLE = 0.006899640588673374
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.007720011642826528
# Fold 22 RMSLE for model2 = 0.007151147686186258
# Fold 22 RMSLE for model3 = 0.008215508915584185
# Fold 22 RMSLE for model4 = 0.007634020794605714
# Fold 22 RMSLE for ('model1', 'model2') = 0.0073945516396673435
# Fold 22 RMSLE for ('model1', 'model3') = 0.007922083116537592
# Fold 22 RMSLE for ('model1', 'model4') = 0.007662772582364649
# Fold 22 RMSLE for ('model2', 'model3') = 0.007570604607536472
# Fold 22 RMSLE for ('model2', 'model4') = 0.0073674606471636475
# Fold 22 RMSLE for ('model3', 'model4') = 0.007853446369622829
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0076068632560665535
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.007466161065214386
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0077977559373231175
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0075731164002281045
# Fold 22 RMSLE for all models ensemble = 0.007602168318622951
# Fold 22 best combination: model2 with RMSLE = 0.007151147686186258
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.00761237403076142
# Fold 23 RMSLE for model2 = 0.007236095867061008
# Fold 23 RMSLE for model3 = 0.008172585788963453
# Fold 23 RMSLE for model4 = 0.007619270478841902
# Fold 23 RMSLE for ('model1', 'model2') = 0.007382633988291117
# Fold 23 RMSLE for ('model1', 'model3') = 0.007847598777036977
# Fold 23 RMSLE for ('model1', 'model4') = 0.007604996616600182
# Fold 23 RMSLE for ('model2', 'model3') = 0.0075903831974308885
# Fold 23 RMSLE for ('model2', 'model4') = 0.007402521921352839
# Fold 23 RMSLE for ('model3', 'model4') = 0.007826655560952989
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.007584395914405172
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.007454929400868953
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.00774536843484253
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0075826235279088435
# Fold 23 RMSLE for all models ensemble = 0.007583122185883667
# Fold 23 best combination: model2 with RMSLE = 0.007236095867061008
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.00859174383389442
# Fold 24 RMSLE for model2 = 0.008237454404611808
# Fold 24 RMSLE for model3 = 0.009059008249586848
# Fold 24 RMSLE for model4 = 0.008402522755033925
# Fold 24 RMSLE for ('model1', 'model2') = 0.008384162831699585
# Fold 24 RMSLE for ('model1', 'model3') = 0.008783757151928806
# Fold 24 RMSLE for ('model1', 'model4') = 0.00848890522434402
# Fold 24 RMSLE for ('model2', 'model3') = 0.008554558800740557
# Fold 24 RMSLE for ('model2', 'model4') = 0.008298655367148064
# Fold 24 RMSLE for ('model3', 'model4') = 0.008671087781907791
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.008555549605235207
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.008383962275757934
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.008635383142182575
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.008488030839660769
# Fold 24 RMSLE for all models ensemble = 0.008508453741052916
# Fold 24 best combination: model2 with RMSLE = 0.008237454404611808
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.008418210354230226
# Fold 25 RMSLE for model2 = 0.008068826017726242
# Fold 25 RMSLE for model3 = 0.00860545564461884
# Fold 25 RMSLE for model4 = 0.008416764378833238
# Fold 25 RMSLE for ('model1', 'model2') = 0.00819392938236256
# Fold 25 RMSLE for ('model1', 'model3') = 0.008474425712294405
# Fold 25 RMSLE for ('model1', 'model4') = 0.008404242151374515
# Fold 25 RMSLE for ('model2', 'model3') = 0.008217887707794849
# Fold 25 RMSLE for ('model2', 'model4') = 0.008213211663158021
# Fold 25 RMSLE for ('model3', 'model4') = 0.00844675037025953
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.008272673276090364
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.008260349072947338
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.008428898849351524
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.008268754583855797
# Fold 25 RMSLE for all models ensemble = 0.008298972347435464
# Fold 25 best combination: model2 with RMSLE = 0.008068826017726242
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.007727081741001815
# Fold 26 RMSLE for model2 = 0.007395207827223105
# Fold 26 RMSLE for model3 = 0.008166802650926506
# Fold 26 RMSLE for model4 = 0.0076966122310208
# Fold 26 RMSLE for ('model1', 'model2') = 0.007514174034813272
# Fold 26 RMSLE for ('model1', 'model3') = 0.007907316325777687
# Fold 26 RMSLE for ('model1', 'model4') = 0.007701276540944121
# Fold 26 RMSLE for ('model2', 'model3') = 0.007666251068971625
# Fold 26 RMSLE for ('model2', 'model4') = 0.007514895454782154
# Fold 26 RMSLE for ('model3', 'model4') = 0.007872598614602475
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.007673518075663765
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.007567105501612521
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.007814588818400532
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.007661359526873357
# Fold 26 RMSLE for all models ensemble = 0.007670646862722421
# Fold 26 best combination: model2 with RMSLE = 0.007395207827223105
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.007161023305238402
# Fold 27 RMSLE for model2 = 0.006979656874021677
# Fold 27 RMSLE for model3 = 0.007623167411227349
# Fold 27 RMSLE for model4 = 0.007242161762816551
# Fold 27 RMSLE for ('model1', 'model2') = 0.007002352763602044
# Fold 27 RMSLE for ('model1', 'model3') = 0.00733604277226879
# Fold 27 RMSLE for ('model1', 'model4') = 0.007170638556334777
# Fold 27 RMSLE for ('model2', 'model3') = 0.007145242820111563
# Fold 27 RMSLE for ('model2', 'model4') = 0.007076678851463521
# Fold 27 RMSLE for ('model3', 'model4') = 0.007331961983163433
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.007129837968149359
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.007068527809452551
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.007258184244349611
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007151448817727342
# Fold 27 RMSLE for all models ensemble = 0.007139351224085983
# Fold 27 best combination: model2 with RMSLE = 0.006979656874021677
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.008261192419872745
# Fold 28 RMSLE for model2 = 0.007854189831205765
# Fold 28 RMSLE for model3 = 0.008565492371829362
# Fold 28 RMSLE for model4 = 0.008230525360327107
# Fold 28 RMSLE for ('model1', 'model2') = 0.008004373845589094
# Fold 28 RMSLE for ('model1', 'model3') = 0.008374089900346288
# Fold 28 RMSLE for ('model1', 'model4') = 0.008231850221963377
# Fold 28 RMSLE for ('model2', 'model3') = 0.008094381337660472
# Fold 28 RMSLE for ('model2', 'model4') = 0.008012834856887861
# Fold 28 RMSLE for ('model3', 'model4') = 0.008334188812530613
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.008134660465925406
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.008072438561153755
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.008300155712207147
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.008123596864833979
# Fold 28 RMSLE for all models ensemble = 0.008148919750910281
# Fold 28 best combination: model2 with RMSLE = 0.007854189831205765
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.006680982821640004
# Fold 29 RMSLE for model2 = 0.0062449786696447155
# Fold 29 RMSLE for model3 = 0.007081082300012997
# Fold 29 RMSLE for model4 = 0.006660443151203941
# Fold 29 RMSLE for ('model1', 'model2') = 0.006413128803873933
# Fold 29 RMSLE for ('model1', 'model3') = 0.006829689110675399
# Fold 29 RMSLE for ('model1', 'model4') = 0.006656674532236055
# Fold 29 RMSLE for ('model2', 'model3') = 0.006548430790499108
# Fold 29 RMSLE for ('model2', 'model4') = 0.006424437308454994
# Fold 29 RMSLE for ('model3', 'model4') = 0.006803285963698667
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.006573027915524973
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.006488065397636549
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.0067480360505369225
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.006568080843612318
# Fold 29 RMSLE for all models ensemble = 0.006585115237818849
# Fold 29 best combination: model2 with RMSLE = 0.0062449786696447155
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009403666250780698
# Fold 30 RMSLE for model2 = 0.009126364804794397
# Fold 30 RMSLE for model3 = 0.009821034928967357
# Fold 30 RMSLE for model4 = 0.009308065590592938
# Fold 30 RMSLE for ('model1', 'model2') = 0.009216412484977137
# Fold 30 RMSLE for ('model1', 'model3') = 0.00957260874035114
# Fold 30 RMSLE for ('model1', 'model4') = 0.009337860141393461
# Fold 30 RMSLE for ('model2', 'model3') = 0.009358063194687112
# Fold 30 RMSLE for ('model2', 'model4') = 0.00918979088195383
# Fold 30 RMSLE for ('model3', 'model4') = 0.00949876344386936
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.00935966271077305
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009237610511893415
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009455781045251181
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009325145777976315
# Fold 30 RMSLE for all models ensemble = 0.009335666773263043
# Fold 30 best combination: model2 with RMSLE = 0.009126364804794397
# ---------------
#
# OOF RMSLE = 0.007613494606379585
# Sum of RMSLE for each combination:
# ('model1',): 0.23608100636676368
# ('model2',): 0.22736115804906412
# ('model3',): 0.24755225974434567
# ('model4',): 0.23536528951798308
# ('model1', 'model2'): 0.23035861404269825
# ('model1', 'model3'): 0.2404826778274759
# ('model1', 'model4'): 0.2353239859129915
# ('model2', 'model3'): 0.23397068510623484
# ('model2', 'model4'): 0.2305423923921088
# ('model3', 'model4'): 0.2394268225632209
# ('model1', 'model2', 'model3'): 0.2342472972896596
# ('model1', 'model2', 'model4'): 0.23179159097049024
# ('model1', 'model3', 'model4'): 0.2379828121168462
# ('model2', 'model3', 'model4'): 0.2339264794089319
# ('model1', 'model2', 'model3', 'model4'): 0.23422077077147807
#
# 2番目の学習が終わりました。
#
# 推定時間は16
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.006687611579982762
# Fold 1 RMSLE for model2 = 0.006671971336843709
# Fold 1 RMSLE for model3 = 0.0068706467810729635
# Fold 1 RMSLE for model4 = 0.006656628154785494
# Fold 1 RMSLE for ('model1', 'model2') = 0.0066492628242181525
# Fold 1 RMSLE for ('model1', 'model3') = 0.006730562651641017
# Fold 1 RMSLE for ('model1', 'model4') = 0.006661295334035401
# Fold 1 RMSLE for ('model2', 'model3') = 0.006666962444423661
# Fold 1 RMSLE for ('model2', 'model4') = 0.006650460502488113
# Fold 1 RMSLE for ('model3', 'model4') = 0.006688821885998574
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.006661673917687262
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.006647528008016186
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.006678439897950343
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.006646951835335909
# Fold 1 RMSLE for all models ensemble = 0.006650666484052436
# Fold 1 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.006646951835335909
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.005709881353842368
# Fold 2 RMSLE for model2 = 0.005676190408879423
# Fold 2 RMSLE for model3 = 0.0062115489059485895
# Fold 2 RMSLE for model4 = 0.005654928434199466
# Fold 2 RMSLE for ('model1', 'model2') = 0.0056495942558480675
# Fold 2 RMSLE for ('model1', 'model3') = 0.005887911775740978
# Fold 2 RMSLE for ('model1', 'model4') = 0.0056667746547628675
# Fold 2 RMSLE for ('model2', 'model3') = 0.005782502557416143
# Fold 2 RMSLE for ('model2', 'model4') = 0.0056449161888810755
# Fold 2 RMSLE for ('model3', 'model4') = 0.005814299355383153
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.005741523232343128
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.005644871988151279
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.005765600737788681
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.0057121048215885446
# Fold 2 RMSLE for all models ensemble = 0.005703387757824504
# Fold 2 best combination: ('model1', 'model2', 'model4') with RMSLE = 0.005644871988151279
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.006255836780446345
# Fold 3 RMSLE for model2 = 0.006036138513580182
# Fold 3 RMSLE for model3 = 0.006708062713688171
# Fold 3 RMSLE for model4 = 0.006152907347825827
# Fold 3 RMSLE for ('model1', 'model2') = 0.006112974816922328
# Fold 3 RMSLE for ('model1', 'model3') = 0.006429848370716372
# Fold 3 RMSLE for ('model1', 'model4') = 0.006193672807870022
# Fold 3 RMSLE for ('model2', 'model3') = 0.0062525264973284115
# Fold 3 RMSLE for ('model2', 'model4') = 0.006077427154365177
# Fold 3 RMSLE for ('model3', 'model4') = 0.0063445579134110445
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.006241914129992156
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.006121291878080791
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.006305552442109852
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.0061989170360216474
# Fold 3 RMSLE for all models ensemble = 0.006207700853482211
# Fold 3 best combination: model2 with RMSLE = 0.006036138513580182
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.0057986543858168675
# Fold 4 RMSLE for model2 = 0.00559427450102368
# Fold 4 RMSLE for model3 = 0.006354702969202907
# ...
# Fold 16 RMSLE for model3 = 0.0033804955022043027
# Fold 16 RMSLE for model4 = 0.0031904655052853808
# Fold 16 RMSLE for ('model1', 'model2') = 0.0031759527317220962
# Fold 16 RMSLE for ('model1', 'model3') = 0.0032717185534746414
# Fold 16 RMSLE for ('model1', 'model4') = 0.003198102909340046
# Fold 16 RMSLE for ('model2', 'model3') = 0.003223666069491243
# Fold 16 RMSLE for ('model2', 'model4') = 0.0031694938370546086
# Fold 16 RMSLE for ('model3', 'model4') = 0.003247532962682321
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.003213889962521158
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.0031783998527489202
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.0032313097646605444
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.0032028271588176046
# Fold 16 RMSLE for all models ensemble = 0.0032026764901972884
# Fold 16 best combination: model2 with RMSLE = 0.003163384509275099
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.004035146016278624
# Fold 17 RMSLE for model2 = 0.003974375069841919
# Fold 17 RMSLE for model3 = 0.004226044068714746
# Fold 17 RMSLE for model4 = 0.004028736167015157
# Fold 17 RMSLE for ('model1', 'model2') = 0.003993208907689457
# Fold 17 RMSLE for ('model1', 'model3') = 0.004108569269590913
# Fold 17 RMSLE for ('model1', 'model4') = 0.004028762266431625
# Fold 17 RMSLE for ('model2', 'model3') = 0.004058040219001438
# Fold 17 RMSLE for ('model2', 'model4') = 0.003995131249659446
# Fold 17 RMSLE for ('model3', 'model4') = 0.004098117498847233
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.00404471517869172
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.004003360952661184
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.004072274392089454
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.0040415550342201255
# Fold 17 RMSLE for all models ensemble = 0.004037208295869329
# Fold 17 best combination: model2 with RMSLE = 0.003974375069841919
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.003258327767000364
# Fold 18 RMSLE for model2 = 0.0033362398939124904
# Fold 18 RMSLE for model3 = 0.003442930506339115
# Fold 18 RMSLE for model4 = 0.0033055465404711252
# Fold 18 RMSLE for ('model1', 'model2') = 0.0032847071823157684
# Fold 18 RMSLE for ('model1', 'model3') = 0.0033252773975880885
# Fold 18 RMSLE for ('model1', 'model4') = 0.0032786186946280223
# Fold 18 RMSLE for ('model2', 'model3') = 0.003346175609879282
# Fold 18 RMSLE for ('model2', 'model4') = 0.0033145906582014097
# Fold 18 RMSLE for ('model3', 'model4') = 0.003342826916781725
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.003309475994039504
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.0032901667941655985
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.00330871073100308
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.003325334935915068
# Fold 18 RMSLE for all models ensemble = 0.003304928267775798
# Fold 18 best combination: model1 with RMSLE = 0.003258327767000364
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.00394165762617206
# Fold 19 RMSLE for model2 = 0.003982325601742631
# Fold 19 RMSLE for model3 = 0.004022773928164156
# Fold 19 RMSLE for model4 = 0.003956891730139119
# Fold 19 RMSLE for ('model1', 'model2') = 0.00395078816103759
# Fold 19 RMSLE for ('model1', 'model3') = 0.003961070069735461
# Fold 19 RMSLE for ('model1', 'model4') = 0.0039458939594306085
# Fold 19 RMSLE for ('model2', 'model3') = 0.003963314764595449
# Fold 19 RMSLE for ('model2', 'model4') = 0.003963611971849623
# Fold 19 RMSLE for ('model3', 'model4') = 0.003961222053413384
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.003950363926913846
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.003951139500604339
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.003950096687217062
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.003954446671967851
# Fold 19 RMSLE for all models ensemble = 0.003948436530654706
# Fold 19 best combination: model1 with RMSLE = 0.00394165762617206
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0038091136244340607
# Fold 20 RMSLE for model2 = 0.0037553156073436857
# Fold 20 RMSLE for model3 = 0.003888755892515411
# Fold 20 RMSLE for model4 = 0.0037991568505377276
# Fold 20 RMSLE for ('model1', 'model2') = 0.0037720123898265464
# Fold 20 RMSLE for ('model1', 'model3') = 0.0038264615985419766
# Fold 20 RMSLE for ('model1', 'model4') = 0.003801164383403678
# Fold 20 RMSLE for ('model2', 'model3') = 0.0037815296974331317
# Fold 20 RMSLE for ('model2', 'model4') = 0.003771026869575179
# Fold 20 RMSLE for ('model3', 'model4') = 0.0038149463631637283
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.0037851353491955317
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.003779255547933606
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.0038080694649496043
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.003780642134647547
# Fold 20 RMSLE for all models ensemble = 0.003785144787088173
# Fold 20 best combination: model2 with RMSLE = 0.0037553156073436857
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.0032464076455983168
# Fold 21 RMSLE for model2 = 0.0033286322154125842
# Fold 21 RMSLE for model3 = 0.0034120698629098887
# Fold 21 RMSLE for model4 = 0.003301321353102113
# Fold 21 RMSLE for ('model1', 'model2') = 0.00327195766600544
# Fold 21 RMSLE for ('model1', 'model3') = 0.0033076267094022845
# Fold 21 RMSLE for ('model1', 'model4') = 0.0032685425909192204
# Fold 21 RMSLE for ('model2', 'model3') = 0.00332700434840711
# Fold 21 RMSLE for ('model2', 'model4') = 0.0033060880643666912
# Fold 21 RMSLE for ('model3', 'model4') = 0.003325658944037807
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.003293074578794661
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.003278880330593911
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0032940178791865727
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.00331018627692691
# Fold 21 RMSLE for all models ensemble = 0.0032904675388215647
# Fold 21 best combination: model1 with RMSLE = 0.0032464076455983168
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0036667421684521665
# Fold 22 RMSLE for model2 = 0.003669015671530293
# Fold 22 RMSLE for model3 = 0.0037778446632039113
# Fold 22 RMSLE for model4 = 0.003674076219927299
# Fold 22 RMSLE for ('model1', 'model2') = 0.0036580687948423
# Fold 22 RMSLE for ('model1', 'model3') = 0.003700423059528759
# Fold 22 RMSLE for ('model1', 'model4') = 0.003667132994371673
# Fold 22 RMSLE for ('model2', 'model3') = 0.003687945174330986
# Fold 22 RMSLE for ('model2', 'model4') = 0.0036657618861339904
# Fold 22 RMSLE for ('model3', 'model4') = 0.0036975981069779307
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0036745879050459995
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.0036615579175246714
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0036823447141605676
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.003675917178589644
# Fold 22 RMSLE for all models ensemble = 0.0036706482341360633
# Fold 22 best combination: ('model1', 'model2') with RMSLE = 0.0036580687948423
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.0035275179844987225
# Fold 23 RMSLE for model2 = 0.0034293786262343043
# Fold 23 RMSLE for model3 = 0.003755381219896198
# Fold 23 RMSLE for model4 = 0.0035284909449593543
# Fold 23 RMSLE for ('model1', 'model2') = 0.003465644661150723
# Fold 23 RMSLE for ('model1', 'model3') = 0.00361653926618824
# Fold 23 RMSLE for ('model1', 'model4') = 0.0035235734814580543
# Fold 23 RMSLE for ('model2', 'model3') = 0.0035457295549925594
# Fold 23 RMSLE for ('model2', 'model4') = 0.003472658919118523
# Fold 23 RMSLE for ('model3', 'model4') = 0.0036077437488215803
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.0035330515615330945
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.003484700252035504
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.0035753235379475646
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.003532007892810602
# Fold 23 RMSLE for all models ensemble = 0.0035275492054565585
# Fold 23 best combination: model2 with RMSLE = 0.0034293786262343043
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.003830283396173977
# Fold 24 RMSLE for model2 = 0.0038181257823618124
# Fold 24 RMSLE for model3 = 0.004042678126375363
# Fold 24 RMSLE for model4 = 0.0038140247004987585
# Fold 24 RMSLE for ('model1', 'model2') = 0.0038115644907919626
# Fold 24 RMSLE for ('model1', 'model3') = 0.003916944467519893
# Fold 24 RMSLE for ('model1', 'model4') = 0.0038190965057993626
# Fold 24 RMSLE for ('model2', 'model3') = 0.00389531434867473
# Fold 24 RMSLE for ('model2', 'model4') = 0.0038076699158699837
# Fold 24 RMSLE for ('model3', 'model4') = 0.0039042521373874603
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.0038670029319687244
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.0038100969498342896
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.00387475369365443
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.003861374538261444
# Fold 24 RMSLE for all models ensemble = 0.0038503698416251712
# Fold 24 best combination: ('model2', 'model4') with RMSLE = 0.0038076699158699837
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.004018477903001129
# Fold 25 RMSLE for model2 = 0.0039174320948036365
# Fold 25 RMSLE for model3 = 0.004107638099141864
# Fold 25 RMSLE for model4 = 0.004003672897704503
# Fold 25 RMSLE for ('model1', 'model2') = 0.003958768733704423
# Fold 25 RMSLE for ('model1', 'model3') = 0.0040428961320345
# Fold 25 RMSLE for ('model1', 'model4') = 0.004008534588704955
# Fold 25 RMSLE for ('model2', 'model3') = 0.0039771732864715805
# Fold 25 RMSLE for ('model2', 'model4') = 0.003955534280995941
# Fold 25 RMSLE for ('model3', 'model4') = 0.004030730418886522
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.003985695755142
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.003972432336178031
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.004022027314988269
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.003980444201778441
# Fold 25 RMSLE for all models ensemble = 0.003987414322969982
# Fold 25 best combination: model2 with RMSLE = 0.0039174320948036365
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.0035060681993960867
# Fold 26 RMSLE for model2 = 0.003456289767770207
# Fold 26 RMSLE for model3 = 0.0036957271094779785
# Fold 26 RMSLE for model4 = 0.003514620865995579
# Fold 26 RMSLE for ('model1', 'model2') = 0.003469566903166141
# Fold 26 RMSLE for ('model1', 'model3') = 0.0035766712618122043
# Fold 26 RMSLE for ('model1', 'model4') = 0.00350726691399802
# Fold 26 RMSLE for ('model2', 'model3') = 0.0035284879645546977
# Fold 26 RMSLE for ('model2', 'model4') = 0.0034786610563100314
# Fold 26 RMSLE for ('model3', 'model4') = 0.0035734232061434557
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.003515457050194835
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.0034827923148552857
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.0035457006013807886
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.0035170340444026413
# Fold 26 RMSLE for all models ensemble = 0.0035116716299081596
# Fold 26 best combination: model2 with RMSLE = 0.003456289767770207
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.003401539487775584
# Fold 27 RMSLE for model2 = 0.0033856861600279333
# Fold 27 RMSLE for model3 = 0.003568121814511451
# Fold 27 RMSLE for model4 = 0.0034114500148709156
# Fold 27 RMSLE for ('model1', 'model2') = 0.0033736584953022106
# Fold 27 RMSLE for ('model1', 'model3') = 0.0034596597700497595
# Fold 27 RMSLE for ('model1', 'model4') = 0.003399998524659947
# Fold 27 RMSLE for ('model2', 'model3') = 0.00342044033869818
# Fold 27 RMSLE for ('model2', 'model4') = 0.00338943462031615
# Fold 27 RMSLE for ('model3', 'model4') = 0.0034525687550097223
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.003406465795835561
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.0033837517271511426
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.003429575798565945
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.003409126401536571
# Fold 27 RMSLE for all models ensemble = 0.003402840887554348
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.0033736584953022106
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.0038841190195826798
# Fold 28 RMSLE for model2 = 0.003870869457699729
# Fold 28 RMSLE for model3 = 0.004020372098364536
# Fold 28 RMSLE for model4 = 0.003872568773687358
# Fold 28 RMSLE for ('model1', 'model2') = 0.0038665316981987287
# Fold 28 RMSLE for ('model1', 'model3') = 0.00393005435270208
# Fold 28 RMSLE for ('model1', 'model4') = 0.0038747038074710667
# Fold 28 RMSLE for ('model2', 'model3') = 0.0039057587985591824
# Fold 28 RMSLE for ('model2', 'model4') = 0.0038654596648950226
# Fold 28 RMSLE for ('model3', 'model4') = 0.0039172626172302065
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.003892556755114832
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.0038665790469263905
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.003901108840186813
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.0038876284605914983
# Fold 28 RMSLE for all models ensemble = 0.0038837901913090253
# Fold 28 best combination: ('model2', 'model4') with RMSLE = 0.0038654596648950226
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.003145099992063015
# Fold 29 RMSLE for model2 = 0.0031010952182952156
# Fold 29 RMSLE for model3 = 0.003262016007353802
# Fold 29 RMSLE for model4 = 0.0031202066573998446
# Fold 29 RMSLE for ('model1', 'model2') = 0.0031081139337229384
# Fold 29 RMSLE for ('model1', 'model3') = 0.0031789888010383695
# Fold 29 RMSLE for ('model1', 'model4') = 0.003128811291570078
# Fold 29 RMSLE for ('model2', 'model3') = 0.0031402330260258513
# Fold 29 RMSLE for ('model2', 'model4') = 0.003101559285157019
# Fold 29 RMSLE for ('model3', 'model4') = 0.003161873677876741
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.0031333409213762826
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.003109731574563251
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.003150016017871653
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0031255130223817253
# Fold 29 RMSLE for all models ensemble = 0.0031261613428146084
# Fold 29 best combination: model2 with RMSLE = 0.0031010952182952156
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.004145949312567442
# Fold 30 RMSLE for model2 = 0.004084483262943639
# Fold 30 RMSLE for model3 = 0.0042674776368356515
# Fold 30 RMSLE for model4 = 0.004145831370418003
# Fold 30 RMSLE for ('model1', 'model2') = 0.0041062669750952605
# Fold 30 RMSLE for ('model1', 'model3') = 0.00418866780185393
# Fold 30 RMSLE for ('model1', 'model4') = 0.004143280416475875
# Fold 30 RMSLE for ('model2', 'model3') = 0.00414570349814484
# Fold 30 RMSLE for ('model2', 'model4') = 0.004109316578982529
# Fold 30 RMSLE for ('model3', 'model4') = 0.004184685115656773
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.004140445910496098
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.004117697823985003
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.004167400221545981
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.004140013853627122
# Fold 30 RMSLE for all models ensemble = 0.0041389152445076354
# Fold 30 best combination: model2 with RMSLE = 0.004084483262943639
# ---------------
#
# OOF RMSLE = 0.003632187911965194
# Sum of RMSLE for each combination:
# ('model1',): 0.10951729173187652
# ('model2',): 0.10945717062418761
# ('model3',): 0.11344206030262942
# ('model4',): 0.10983612011267621
# ('model1', 'model2'): 0.10911225369984745
# ('model1', 'model3'): 0.11077361732832079
# ('model1', 'model4'): 0.10956344094166819
# ('model2', 'model3'): 0.11014546340219196
# ('model2', 'model4'): 0.10944098941272795
# ('model3', 'model4'): 0.11070394972109131
# ('model1', 'model2', 'model3'): 0.10974169389372232
# ('model1', 'model2', 'model4'): 0.10929519829126357
# ('model1', 'model3', 'model4'): 0.11014841755113172
# ('model2', 'model3', 'model4'): 0.10982048315817576
# ('model1', 'model2', 'model3', 'model4'): 0.10964843803147796
#
# 9番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                        0.000000                     0.000000           221
# 2                        0.000000                     0.000000             4
# 3                        0.000000                     0.000000            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 7158                     0.000000                     0.000000           240
# 7159                     0.000000                     0.000000             4
# 7160                 25069.498286                 24560.172725           132
# 7161                 93118.705227                130326.946431            98
# 7162                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 7158                           110523.066755
# 7159                                0.000000
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42084.822159  0.003075
# 1                  14            1     58731.922180 -0.003963
# 2                   9            1     99437.469364 -0.000282
# 3                  15            1     51724.977682 -0.001967
# 4                  15            0     50754.110213 -0.002292
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42084.822159  0.003075
# 1                  14            1     58731.922180 -0.003963
# 2                   9            1     99437.469364 -0.000282
# 3                  15            1     51724.977682 -0.001967
# 4                  15            0     50754.110213 -0.002292
# ...               ...          ...              ...       ...
# 4650               15            0     49428.302401 -0.004190
# 4651                8            1    169131.698207  0.002967
# 4652                8            0     31775.482248 -0.001863
# 4653                8            0     65618.855936  0.000676
# 4654                9            1    146188.387226 -0.005147
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, -0.00)

# %%
train_df_GHG14
# Out:
# 0        42214.415787
# 1        58499.609696
# 2        99409.449782
# 3        51623.314588
# 4        50637.897032
#             ...
# 4650     49221.615755
# 4651    169634.209493
# 4652     31716.323514
# 4653     65663.219471
# 4654    145437.817997
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.561501e+04  0.011449
# 1                  14            1     2.904356e+05 -0.009013
# 2                   8            0     4.145595e+04  0.004741
# 3                   8            0     2.858402e+04 -0.022208
# 4                   8            0     4.936320e+04  0.016946
# ...               ...          ...              ...       ...
# 2503                1            1     5.550540e+05  0.027199
# 2504                9            1     9.862652e+04 -0.009746
# 2505                8            0     1.407886e+05  0.022125
# 2506                8            0     2.620755e+05 -0.005393
# 2507                9            1     1.474355e+06  0.065402
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232750.55231418277

# %%
print(np.expm1(np.log1p(10)))
# Out:
# 10.000000000000002

# %%
def after_act(preds):
    c = 10.6
    r = preds.copy()
    r_min = r.min()
    max_w = c-np.log1p(r_min)
    for i in range(len(r)):
        if r[i] < np.expm1(c):
            r[i] = np.expm1(np.log1p(r[i])-0.5*(c-np.log1p(r[i]))/max_w)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.6), np.expm1(10.6)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 191085.98489606022

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_77.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,615
# 1     4656   290,436
# 2     4657    41,456
# 3     4658    22,749
# 4     4659    49,363
# ...    ...       ...
# 2503  7158   555,054
# 2504  7159    98,627
# 2505  7160   140,789
# 2506  7161   262,076
# 2507  7162 1,474,355
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,149,374
# 43    4698 1,194,933
# 110   4765 1,383,851
# 114   4769 1,300,161
# 148   4803 1,738,379
# ...    ...       ...
# 2417  7072 1,243,502
# 2423  7078 1,207,478
# 2466  7121 1,678,719
# 2490  7145 1,427,037
# 2507  7162 1,474,355
#
# [113 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sat Nov 30 15:56:01 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,085     0
# 1                  14            1           58,732    -0
# 2                   9            1           99,437    -0
# 3                  15            1           51,725    -0
# 4                  15            0           50,754    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,428    -0
# 4651                8            1          169,132     0
# 4652                8            0           31,775    -0
# 4653                8            0           65,619     0
# 4654                9            1          146,188    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.004489653268783815

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,085     0
# 1                  14            1           58,732    -0
# 2                   9            1           99,437    -0
# 3                  15            1           51,725    -0
# 4                  15            0           50,754    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,428    -0
# 4651                8            1          169,132     0
# 4652                8            0           31,775    -0
# 4653                8            0           65,619     0
# 4654                9            1          146,188    -0
#
# [4655 rows x 19 columns]
