# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/054.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     3.868125e+04
# 1                  14            1     6.421108e+04
# 2                   9            1     1.092220e+05
# 3                  15            1     5.115422e+04
# 4                  15            0     5.271591e+04
# ...               ...          ...              ...
# 4650                9            1     2.220249e+05
# 4651                9            1     5.036959e+04
# 4652                5            1     1.211018e+06
# 4653                1            1     3.996303e+04
# 4654                9            1     7.176402e+04
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.297314e+04
# 1                                 5.591007e+04
# 2                                 5.567954e+04
# 3                                 6.141190e+04
# 4                                 4.310047e+04
# ...                                        ...
# 4650                              2.451197e+06
# 4651                              3.573974e+04
# 4652                              9.783592e+05
# 4653                              2.723434e+04
# 4654                              1.948221e+05
#
# [4655 rows x 20 columns]

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = abs(np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions']))

# 2. 条件を満たす行のマスクを作成
mask = diff > 0.72
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
train_df = train_all_df.copy()
# 4. 条件を満たさない行だけを保持
train_not_mask_df = train_all_df[~mask].reset_index(drop=True)
train_mask_df = train_all_df[mask].reset_index(drop=True)

# 5. 'oof_predictions' 列を削除
train_not_mask_df.drop('oof_predictions', axis=1, inplace=True)
train_mask_df.drop('oof_predictions', axis=1, inplace=True)
train_df.drop('oof_predictions', axis=1, inplace=True)
# 6. 結果の表示
print(f"除外された行数: {exclude_num}")
# Out:
# 除外された行数: 1118

# %%
train_not_mask_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 23592.402994                 25069.498286
# 6043                140816.449347                 93118.705227
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 6040                          NaN           240
# 6041                          NaN             4
# 6042                 24560.172725           132
# 6043                130326.946431            98
# 6044                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                   9            1                              5.567954e+04
# 3                  15            1                              6.141190e+04
# 4                  15            0                              4.310047e+04
# ...               ...          ...                                       ...
# 6040                1            1                              5.497954e+05
# 6041                9            1                              1.137684e+05
# 6042                8            0                              1.412656e+05
# 6043                8            0                              2.599965e+05
# 6044                9            1                              1.293278e+06
#
# [6045 rows x 19 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)
    final_train_predictions = np.expm1(train_eval_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_not_mask_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 23592.402994                 25069.498286
# 6043                140816.449347                 93118.705227
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 6040                          NaN           240
# 6041                          NaN             4
# 6042                 24560.172725           132
# 6043                130326.946431            98
# 6044                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                   9            1                              5.567954e+04
# 3                  15            1                              6.141190e+04
# 4                  15            0                              4.310047e+04
# ...               ...          ...                                       ...
# 6040                1            1                              5.497954e+05
# 6041                9            1                              1.137684e+05
# 6042                8            0                              1.412656e+05
# 6043                8            0                              2.599965e+05
# 6044                9            1                              1.293278e+06
#
# [6045 rows x 19 columns]

# %%
train_not_mask = train_not_mask_df.iloc[:, :-1].values
train_mask = train_mask_df.iloc[:, :-1].values
train_not_mask_target = train_not_mask_df.iloc[:, -1].values
train_mask_target = train_mask_df.iloc[:, -1].values
test = test_df.values

# %%
oof_predictions,test_preds, train_mask_preds = get_models_trained(train_not_mask,test,train_not_mask_target,30, train_mask)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.28887469493953233
# Fold 1 RMSLE for model2 = 0.2798689812987604
# Fold 1 RMSLE for model3 = 0.28697679521152775
# Fold 1 RMSLE for model4 = 0.28401873203735073
# Fold 1 RMSLE for ('model1', 'model2') = 0.28184710620111536
# Fold 1 RMSLE for ('model1', 'model3') = 0.2875125978421929
# Fold 1 RMSLE for ('model1', 'model4') = 0.2846132430338378
# Fold 1 RMSLE for ('model2', 'model3') = 0.2810387181297564
# Fold 1 RMSLE for ('model2', 'model4') = 0.2805575452372724
# Fold 1 RMSLE for ('model3', 'model4') = 0.28345753562896536
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.28286192068492516
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.2817313058753606
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.28469379756749486
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.2810556054226778
# Fold 1 RMSLE for all models ensemble = 0.28229487476972676
# Fold 1 best combination: model2 with RMSLE = 0.2798689812987604
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.2951678160546631
# Fold 2 RMSLE for model2 = 0.2938308487475748
# Fold 2 RMSLE for model3 = 0.2953167165298698
# Fold 2 RMSLE for model4 = 0.2925551001248571
# Fold 2 RMSLE for ('model1', 'model2') = 0.29273068277780184
# Fold 2 RMSLE for ('model1', 'model3') = 0.29485648814517773
# Fold 2 RMSLE for ('model1', 'model4') = 0.2926482779982496
# Fold 2 RMSLE for ('model2', 'model3') = 0.29276992048104333
# Fold 2 RMSLE for ('model2', 'model4') = 0.2922134669657372
# Fold 2 RMSLE for ('model3', 'model4') = 0.29232659909487557
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.2930046671413434
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.292086057992609
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.29291581438117853
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.2919472209526912
# Fold 2 RMSLE for all models ensemble = 0.29226994313751714
# Fold 2 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.2919472209526912
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.2824382572226752
# Fold 3 RMSLE for model2 = 0.2833262248532652
# Fold 3 RMSLE for model3 = 0.28358752748023497
# Fold 3 RMSLE for model4 = 0.2863482632892851
# Fold 3 RMSLE for ('model1', 'model2') = 0.2806971272957833
# Fold 3 RMSLE for ('model1', 'model3') = 0.28236922482020016
# Fold 3 RMSLE for ('model1', 'model4') = 0.2827716683436031
# Fold 3 RMSLE for ('model2', 'model3') = 0.280450243790538
# Fold 3 RMSLE for ('model2', 'model4') = 0.2834982413053225
# Fold 3 RMSLE for ('model3', 'model4') = 0.2819966955267177
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.2805110480144372
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.28174644906210855
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.2817621060536188
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.2811875535237038
# Fold 3 RMSLE for all models ensemble = 0.28096892658511813
# Fold 3 best combination: ('model2', 'model3') with RMSLE = 0.280450243790538
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.286750766510318
# Fold 4 RMSLE for model2 = 0.28918887401705085
# Fold 4 RMSLE for model3 = 0.2824682447188657
# Fold 4 RMSLE for model4 = 0.28640107000389553
# Fold 4 RMSLE for ('model1', 'model2') = 0.28494214744417895
# Fold 4 RMSLE for ('model1', 'model3') = 0.2842225102314577
# Fold 4 RMSLE for ('model1', 'model4') = 0.28457258299920424
# Fold 4 RMSLE for ('model2', 'model3') = 0.28289290643516496
# Fold 4 RMSLE for ('model2', 'model4') = 0.2866691205780776
# Fold 4 RMSLE for ('model3', 'model4') = 0.2823857028075099
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.28322545427409235
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.2847730850303605
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.28320728794446065
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.2833274432606945
# Fold 4 RMSLE for all models ensemble = 0.2833122548125021
# Fold 4 best combination: ('model3', 'model4') with RMSLE = 0.2823857028075099
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.27261267766450115
# Fold 5 RMSLE for model2 = 0.2686228073337859
# Fold 5 RMSLE for model3 = 0.27499332471218896
# Fold 5 RMSLE for model4 = 0.26921847143785366
# Fold 5 RMSLE for ('model1', 'model2') = 0.2684024082311031
# Fold 5 RMSLE for ('model1', 'model3') = 0.2735045278726589
# Fold 5 RMSLE for ('model1', 'model4') = 0.269317995587418
# Fold 5 RMSLE for ('model2', 'model3') = 0.26937129269765525
# Fold 5 RMSLE for ('model2', 'model4') = 0.2676251298578796
# Fold 5 RMSLE for ('model3', 'model4') = 0.2702110837748147
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.2698767259977821
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.2678828567344563
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.27057878228890664
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.2684479606367423
# Fold 5 RMSLE for all models ensemble = 0.268925498110496
# Fold 5 best combination: ('model2', 'model4') with RMSLE = 0.2676251298578796
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.3139331416726678
# Fold 6 RMSLE for model2 = 0.3173222785053209
# Fold 6 RMSLE for model3 = 0.3198779119843223
# Fold 6 RMSLE for model4 = 0.31676661020409835
# Fold 6 RMSLE for ('model1', 'model2') = 0.31345871752138826
# Fold 6 RMSLE for ('model1', 'model3') = 0.31624188051181196
# Fold 6 RMSLE for ('model1', 'model4') = 0.31385802392344175
# Fold 6 RMSLE for ('model2', 'model3') = 0.31596505449471124
# Fold 6 RMSLE for ('model2', 'model4') = 0.3158632685500348
# Fold 6 RMSLE for ('model3', 'model4') = 0.31594594328114506
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.3145943798827565
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.3138679885626572
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.31483979391148564
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.31525719748210834
# Fold 6 RMSLE for all models ensemble = 0.3143501329417979
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.31345871752138826
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.3052665325074619
# Fold 7 RMSLE for model2 = 0.3077800841278512
# Fold 7 RMSLE for model3 = 0.30284116143218387
# Fold 7 RMSLE for model4 = 0.3028135099506126
# Fold 7 RMSLE for ('model1', 'model2') = 0.304824855850328
# Fold 7 RMSLE for ('model1', 'model3') = 0.3036230301948192
# Fold 7 RMSLE for ('model1', 'model4') = 0.303203333829543
# Fold 7 RMSLE for ('model2', 'model3') = 0.30349491687687385
# Fold 7 RMSLE for ('model2', 'model4') = 0.30422703605415874
# Fold 7 RMSLE for ('model3', 'model4') = 0.3016324181544842
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.30354585135259593
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.3036850639731053
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.3025490041831232
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.3026651183431738
# Fold 7 RMSLE for all models ensemble = 0.30291678382828086
# Fold 7 best combination: ('model3', 'model4') with RMSLE = 0.3016324181544842
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.2629777360043135
# Fold 8 RMSLE for model2 = 0.26212743682113526
# Fold 8 RMSLE for model3 = 0.2618245478218314
# Fold 8 RMSLE for model4 = 0.2676613755516396
# Fold 8 RMSLE for ('model1', 'model2') = 0.2594228198418298
# Fold 8 RMSLE for ('model1', 'model3') = 0.2618263736468933
# Fold 8 RMSLE for ('model1', 'model4') = 0.263697779116739
# Fold 8 RMSLE for ('model2', 'model3') = 0.258595582799948
# Fold 8 RMSLE for ('model2', 'model4') = 0.26334384725762494
# Fold 8 RMSLE for ('model3', 'model4') = 0.2623306138360215
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.25913278654772115
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.2614893155486501
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.2620824145955866
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.26063998683828166
# Fold 8 RMSLE for all models ensemble = 0.26049096467733013
# Fold 8 best combination: ('model2', 'model3') with RMSLE = 0.258595582799948
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.29405936208003114
# Fold 9 RMSLE for model2 = 0.285292541131832
# Fold 9 RMSLE for model3 = 0.29293360996441403
# Fold 9 RMSLE for model4 = 0.2851197084914621
# Fold 9 RMSLE for ('model1', 'model2') = 0.2867904375926166
# Fold 9 RMSLE for ('model1', 'model3') = 0.29308003393762966
# Fold 9 RMSLE for ('model1', 'model4') = 0.28656262454644316
# Fold 9 RMSLE for ('model2', 'model3') = 0.28646015790177637
# Fold 9 RMSLE for ('model2', 'model4') = 0.2840994235096006
# Fold 9 RMSLE for ('model3', 'model4') = 0.2860629539826743
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.2880546273687369
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.28512139629180777
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.2877713203726072
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.28484733844378135
# Fold 9 RMSLE for all models ensemble = 0.2860903987670068
# Fold 9 best combination: ('model2', 'model4') with RMSLE = 0.2840994235096006
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.24669403424544006
# Fold 10 RMSLE for model2 = 0.24756315377447155
# Fold 10 RMSLE for model3 = 0.24366635318811442
# Fold 10 RMSLE for model4 = 0.25625327911736095
# Fold 10 RMSLE for ('model1', 'model2') = 0.2450432672374745
# Fold 10 RMSLE for ('model1', 'model3') = 0.24457126667141035
# Fold 10 RMSLE for ('model1', 'model4') = 0.25008222593078605
# Fold 10 RMSLE for ('model2', 'model3') = 0.24332364894882072
# Fold 10 RMSLE for ('model2', 'model4') = 0.25021611665854493
# Fold 10 RMSLE for ('model3', 'model4') = 0.24785701900646095
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.24375284311181825
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.2478667698310763
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.24702910765590927
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.2464497741074036
# Fold 10 RMSLE for all models ensemble = 0.245985175563504
# Fold 10 best combination: ('model2', 'model3') with RMSLE = 0.24332364894882072
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.28772140458666423
# Fold 11 RMSLE for model2 = 0.29041928952738066
# Fold 11 RMSLE for model3 = 0.28617582078739845
# Fold 11 RMSLE for model4 = 0.28579718340645255
# Fold 11 RMSLE for ('model1', 'model2') = 0.2872411776941386
# Fold 11 RMSLE for ('model1', 'model3') = 0.286077872777159
# Fold 11 RMSLE for ('model1', 'model4') = 0.28553943409980964
# Fold 11 RMSLE for ('model2', 'model3') = 0.2857549989275496
# Fold 11 RMSLE for ('model2', 'model4') = 0.28701188198235017
# Fold 11 RMSLE for ('model3', 'model4') = 0.2837884373658425
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.2858016281602304
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.28613401993127163
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.28467745890341145
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.28488381448900857
# Fold 11 RMSLE for all models ensemble = 0.28511223263875346
# Fold 11 best combination: ('model3', 'model4') with RMSLE = 0.2837884373658425
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.2912549672882349
# Fold 12 RMSLE for model2 = 0.28000966269795097
# Fold 12 RMSLE for model3 = 0.29001347002988326
# Fold 12 RMSLE for model4 = 0.2856962268795061
# Fold 12 RMSLE for ('model1', 'model2') = 0.28223283933279314
# Fold 12 RMSLE for ('model1', 'model3') = 0.2901846212590429
# Fold 12 RMSLE for ('model1', 'model4') = 0.28681432141121366
# Fold 12 RMSLE for ('model2', 'model3') = 0.2818856913514803
# Fold 12 RMSLE for ('model2', 'model4') = 0.28160648805568583
# Fold 12 RMSLE for ('model3', 'model4') = 0.2862797735626762
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.28395784100181365
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.2828564044588944
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.28734732935263874
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.2825972572184736
# Fold 12 RMSLE for all models ensemble = 0.28386842298399306
# Fold 12 best combination: model2 with RMSLE = 0.28000966269795097
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.3003676269657235
# Fold 13 RMSLE for model2 = 0.2965195996604807
# Fold 13 RMSLE for model3 = 0.29920781230469207
# Fold 13 RMSLE for model4 = 0.29620776838626517
# Fold 13 RMSLE for ('model1', 'model2') = 0.29544170131016567
# Fold 13 RMSLE for ('model1', 'model3') = 0.29912151897106143
# Fold 13 RMSLE for ('model1', 'model4') = 0.2962373420556811
# Fold 13 RMSLE for ('model2', 'model3') = 0.29458081591785296
# Fold 13 RMSLE for ('model2', 'model4') = 0.2950786187615422
# Fold 13 RMSLE for ('model3', 'model4') = 0.2950301744198871
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.2955690713923312
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.294891689892425
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.29618898107040925
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.29411039017875873
# Fold 13 RMSLE for all models ensemble = 0.29482911238079473
# Fold 13 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.29411039017875873
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.31231396234889186
# Fold 14 RMSLE for model2 = 0.30427121114010436
# Fold 14 RMSLE for model3 = 0.30914048207461636
# Fold 14 RMSLE for model4 = 0.3069315168815605
# Fold 14 RMSLE for ('model1', 'model2') = 0.30610633467315934
# Fold 14 RMSLE for ('model1', 'model3') = 0.3104093201524324
# Fold 14 RMSLE for ('model1', 'model4') = 0.30819258169866726
# Fold 14 RMSLE for ('model2', 'model3') = 0.3045220775838954
# Fold 14 RMSLE for ('model2', 'model4') = 0.3041897804977792
# Fold 14 RMSLE for ('model3', 'model4') = 0.3061304423415611
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.30644792815936384
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.30563276853267607
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.3078147748290509
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.304349613698543
# Fold 14 RMSLE for all models ensemble = 0.3057969202354254
# Fold 14 best combination: ('model2', 'model4') with RMSLE = 0.3041897804977792
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.28111878204266805
# Fold 15 RMSLE for model2 = 0.27577529797386335
# Fold 15 RMSLE for model3 = 0.2809219612041688
# Fold 15 RMSLE for model4 = 0.2773264376048328
# Fold 15 RMSLE for ('model1', 'model2') = 0.27583400078433856
# Fold 15 RMSLE for ('model1', 'model3') = 0.2806609851376214
# Fold 15 RMSLE for ('model1', 'model4') = 0.2774948799918968
# Fold 15 RMSLE for ('model2', 'model3') = 0.27576486397950917
# Fold 15 RMSLE for ('model2', 'model4') = 0.27543799381571454
# Fold 15 RMSLE for ('model3', 'model4') = 0.27725303176003735
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.2767744614110367
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.27567425385576405
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.2780147695893644
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.2755446081748381
# Fold 15 RMSLE for all models ensemble = 0.2762175548713819
# Fold 15 best combination: ('model2', 'model4') with RMSLE = 0.27543799381571454
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.2951479380955072
# Fold 16 RMSLE for model2 = 0.2905247147779465
# Fold 16 RMSLE for model3 = 0.29800483528484695
# Fold 16 RMSLE for model4 = 0.2963652895394422
# Fold 16 RMSLE for ('model1', 'model2') = 0.29109563919180576
# Fold 16 RMSLE for ('model1', 'model3') = 0.29606707448890085
# Fold 16 RMSLE for ('model1', 'model4') = 0.29476194173235454
# Fold 16 RMSLE for ('model2', 'model3') = 0.2923010435333555
# Fold 16 RMSLE for ('model2', 'model4') = 0.2923229607711312
# Fold 16 RMSLE for ('model3', 'model4') = 0.2956072864631238
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.29269229886349957
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.2922977896103329
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.29513519627345747
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.2928967066753609
# Fold 16 RMSLE for all models ensemble = 0.29303745484960936
# Fold 16 best combination: model2 with RMSLE = 0.2905247147779465
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.31254348734750653
# Fold 17 RMSLE for model2 = 0.30728501748528964
# Fold 17 RMSLE for model3 = 0.31512344771001394
# Fold 17 RMSLE for model4 = 0.3086740380637022
# Fold 17 RMSLE for ('model1', 'model2') = 0.30792349820200365
# Fold 17 RMSLE for ('model1', 'model3') = 0.313418137431481
# Fold 17 RMSLE for ('model1', 'model4') = 0.3091302965935114
# Fold 17 RMSLE for ('model2', 'model3') = 0.30890190729735867
# Fold 17 RMSLE for ('model2', 'model4') = 0.3070183269632326
# Fold 17 RMSLE for ('model3', 'model4') = 0.30984866647940373
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.3095583347695643
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.3075411767773433
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.310345991081744
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.3080176191472585
# Fold 17 RMSLE for all models ensemble = 0.30861321696183247
# Fold 17 best combination: ('model2', 'model4') with RMSLE = 0.3070183269632326
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.29189304678614253
# Fold 18 RMSLE for model2 = 0.2818460482684517
# Fold 18 RMSLE for model3 = 0.2889491477283602
# Fold 18 RMSLE for model4 = 0.2927508590513083
# Fold 18 RMSLE for ('model1', 'model2') = 0.28367114627107975
# Fold 18 RMSLE for ('model1', 'model3') = 0.28986258837583123
# Fold 18 RMSLE for ('model1', 'model4') = 0.2904169477969076
# Fold 18 RMSLE for ('model2', 'model3') = 0.2819462022475766
# Fold 18 RMSLE for ('model2', 'model4') = 0.2858230159393714
# Fold 18 RMSLE for ('model3', 'model4') = 0.2884089605560848
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.2843141016938849
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.2859403170798809
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.28898982997145917
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.284597199181019
# Fold 18 RMSLE for all models ensemble = 0.2855981999061594
# Fold 18 best combination: model2 with RMSLE = 0.2818460482684517
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.3089174293445519
# Fold 19 RMSLE for model2 = 0.3150640306786046
# Fold 19 RMSLE for model3 = 0.3089945832080162
# Fold 19 RMSLE for model4 = 0.31414610127473264
# Fold 19 RMSLE for ('model1', 'model2') = 0.3098123366511196
# Fold 19 RMSLE for ('model1', 'model3') = 0.3083740767197914
# Fold 19 RMSLE for ('model1', 'model4') = 0.3102786148209513
# Fold 19 RMSLE for ('model2', 'model3') = 0.30908311551220385
# Fold 19 RMSLE for ('model2', 'model4') = 0.31371918102512597
# Fold 19 RMSLE for ('model3', 'model4') = 0.30939460019164244
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.3084417640774231
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.3108013309372435
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.3088904810943429
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.3101084831253343
# Fold 19 RMSLE for all models ensemble = 0.309287400469444
# Fold 19 best combination: ('model1', 'model3') with RMSLE = 0.3083740767197914
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.2874622002057096
# Fold 20 RMSLE for model2 = 0.2854982797964835
# Fold 20 RMSLE for model3 = 0.28502296810468786
# Fold 20 RMSLE for model4 = 0.28918469396563756
# Fold 20 RMSLE for ('model1', 'model2') = 0.2839312839874088
# Fold 20 RMSLE for ('model1', 'model3') = 0.28577389501873124
# Fold 20 RMSLE for ('model1', 'model4') = 0.28651325318460324
# Fold 20 RMSLE for ('model2', 'model3') = 0.2829152643955328
# Fold 20 RMSLE for ('model2', 'model4') = 0.2859546568199929
# Fold 20 RMSLE for ('model3', 'model4') = 0.2853642255379975
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.283589803123047
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.28483870713766
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.28543134586925917
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.2841313312343
# Fold 20 RMSLE for all models ensemble = 0.28420836286161083
# Fold 20 best combination: ('model2', 'model3') with RMSLE = 0.2829152643955328
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.25879677883901125
# Fold 21 RMSLE for model2 = 0.2588670358444741
# Fold 21 RMSLE for model3 = 0.2578354858328725
# Fold 21 RMSLE for model4 = 0.256936869259229
# Fold 21 RMSLE for ('model1', 'model2') = 0.2564254298960698
# Fold 21 RMSLE for ('model1', 'model3') = 0.25789286931257005
# Fold 21 RMSLE for ('model1', 'model4') = 0.2563114054102861
# Fold 21 RMSLE for ('model2', 'model3') = 0.2557920327689652
# Fold 21 RMSLE for ('model2', 'model4') = 0.2564296368381397
# Fold 21 RMSLE for ('model3', 'model4') = 0.25541069321396936
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.25611186098368904
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.25577675337365746
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.2561043420438386
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.2552013684489674
# Fold 21 RMSLE for all models ensemble = 0.2555093236705111
# Fold 21 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.2552013684489674
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.28048841257065227
# Fold 22 RMSLE for model2 = 0.2823040454466524
# Fold 22 RMSLE for model3 = 0.2786412452804996
# Fold 22 RMSLE for model4 = 0.28336778616810526
# Fold 22 RMSLE for ('model1', 'model2') = 0.2795329614646376
# Fold 22 RMSLE for ('model1', 'model3') = 0.279269199086428
# Fold 22 RMSLE for ('model1', 'model4') = 0.28052122654586703
# Fold 22 RMSLE for ('model2', 'model3') = 0.27858315659926924
# Fold 22 RMSLE for ('model2', 'model4') = 0.28194166650155666
# Fold 22 RMSLE for ('model3', 'model4') = 0.27930739771398894
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.27867149282614967
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.2802098307263295
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.27930808296451587
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.27945941443258443
# Fold 22 RMSLE for all models ensemble = 0.27918899101700284
# Fold 22 best combination: ('model2', 'model3') with RMSLE = 0.27858315659926924
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.27314066473705406
# Fold 23 RMSLE for model2 = 0.26907504088537626
# Fold 23 RMSLE for model3 = 0.27563413654142477
# Fold 23 RMSLE for model4 = 0.26831565960018605
# Fold 23 RMSLE for ('model1', 'model2') = 0.2689845814301697
# Fold 23 RMSLE for ('model1', 'model3') = 0.2740602916883869
# Fold 23 RMSLE for ('model1', 'model4') = 0.269445597964447
# Fold 23 RMSLE for ('model2', 'model3') = 0.27014546517007426
# Fold 23 RMSLE for ('model2', 'model4') = 0.2675128311822855
# Fold 23 RMSLE for ('model3', 'model4') = 0.27032967516687745
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.27053971911000774
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.26814821138221867
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.2709113945178342
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.2687732334387063
# Fold 23 RMSLE for all models ensemble = 0.2693503248934745
# Fold 23 best combination: ('model2', 'model4') with RMSLE = 0.2675128311822855
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.3161205589982249
# Fold 24 RMSLE for model2 = 0.3241205628009536
# Fold 24 RMSLE for model3 = 0.31379190345127805
# Fold 24 RMSLE for model4 = 0.3222593313585483
# Fold 24 RMSLE for ('model1', 'model2') = 0.31740123020111216
# Fold 24 RMSLE for ('model1', 'model3') = 0.31443933249808625
# Fold 24 RMSLE for ('model1', 'model4') = 0.31792061499416674
# Fold 24 RMSLE for ('model2', 'model3') = 0.3161815351816703
# Fold 24 RMSLE for ('model2', 'model4') = 0.3219222354442644
# Fold 24 RMSLE for ('model3', 'model4') = 0.31663934530664056
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.3152903208898083
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.3185230277169794
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.3159710362893137
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.3176517972240877
# Fold 24 RMSLE for all models ensemble = 0.31657990436349237
# Fold 24 best combination: model3 with RMSLE = 0.31379190345127805
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.2919257338792407
# Fold 25 RMSLE for model2 = 0.2899720113973714
# Fold 25 RMSLE for model3 = 0.2930124752490687
# Fold 25 RMSLE for model4 = 0.2919148971876671
# Fold 25 RMSLE for ('model1', 'model2') = 0.28839103296638213
# Fold 25 RMSLE for ('model1', 'model3') = 0.2920634193676172
# Fold 25 RMSLE for ('model1', 'model4') = 0.29006841578470405
# Fold 25 RMSLE for ('model2', 'model3') = 0.2892021860036973
# Fold 25 RMSLE for ('model2', 'model4') = 0.28941903444661293
# Fold 25 RMSLE for ('model3', 'model4') = 0.29042482737779285
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.28926506279526176
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.2886378736735595
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.29034433543633537
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.2890063243398356
# Fold 25 RMSLE for all models ensemble = 0.28900269472678836
# Fold 25 best combination: ('model1', 'model2') with RMSLE = 0.28839103296638213
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.29524623649773657
# Fold 26 RMSLE for model2 = 0.28037612741689455
# Fold 26 RMSLE for model3 = 0.2994181957871589
# Fold 26 RMSLE for model4 = 0.284252771548869
# Fold 26 RMSLE for ('model1', 'model2') = 0.28525489797478853
# Fold 26 RMSLE for ('model1', 'model3') = 0.29666761977921147
# Fold 26 RMSLE for ('model1', 'model4') = 0.2876919718776625
# Fold 26 RMSLE for ('model2', 'model3') = 0.28619860119041063
# Fold 26 RMSLE for ('model2', 'model4') = 0.2811347422737296
# Fold 26 RMSLE for ('model3', 'model4') = 0.28822560215187354
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.28858065402585825
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.28407033937724757
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.2901301217269427
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.2843178436061488
# Fold 26 RMSLE for all models ensemble = 0.28640237460601375
# Fold 26 best combination: model2 with RMSLE = 0.28037612741689455
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.2660869855882363
# Fold 27 RMSLE for model2 = 0.2685557633071874
# Fold 27 RMSLE for model3 = 0.2662457562443311
# Fold 27 RMSLE for model4 = 0.2690226572271901
# Fold 27 RMSLE for ('model1', 'model2') = 0.26445567094041045
# Fold 27 RMSLE for ('model1', 'model3') = 0.2657928295799383
# Fold 27 RMSLE for ('model1', 'model4') = 0.2654357864848613
# Fold 27 RMSLE for ('model2', 'model3') = 0.2645510538485695
# Fold 27 RMSLE for ('model2', 'model4') = 0.2677577719615486
# Fold 27 RMSLE for ('model3', 'model4') = 0.2654594929797091
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.2642242174893867
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.2652378034030758
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.2650116711443011
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.2652667169673108
# Fold 27 RMSLE for all models ensemble = 0.26461613172245374
# Fold 27 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.2642242174893867
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.28435680612502956
# Fold 28 RMSLE for model2 = 0.2862639861170357
# Fold 28 RMSLE for model3 = 0.286604676745657
# Fold 28 RMSLE for model4 = 0.2919447947796368
# Fold 28 RMSLE for ('model1', 'model2') = 0.2835399489742977
# Fold 28 RMSLE for ('model1', 'model3') = 0.2848674428531899
# Fold 28 RMSLE for ('model1', 'model4') = 0.28685958262850053
# Fold 28 RMSLE for ('model2', 'model3') = 0.283946235689356
# Fold 28 RMSLE for ('model2', 'model4') = 0.28807288483042603
# Fold 28 RMSLE for ('model3', 'model4') = 0.2870520757359588
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.28357095436471236
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.2857069842442016
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.28579714452665783
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.2857399414638887
# Fold 28 RMSLE for all models ensemble = 0.2849450019622155
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.2835399489742977
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.27880178773967595
# Fold 29 RMSLE for model2 = 0.28434576047465826
# Fold 29 RMSLE for model3 = 0.2813212301974583
# Fold 29 RMSLE for model4 = 0.2829319402728172
# Fold 29 RMSLE for ('model1', 'model2') = 0.2795966667438303
# Fold 29 RMSLE for ('model1', 'model3') = 0.2796908471547857
# Fold 29 RMSLE for ('model1', 'model4') = 0.27960477250454113
# Fold 29 RMSLE for ('model2', 'model3') = 0.2808374788761755
# Fold 29 RMSLE for ('model2', 'model4') = 0.28216032493795884
# Fold 29 RMSLE for ('model3', 'model4') = 0.28048624761479174
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.27954873333826047
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.27993515980880385
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.27955992285682746
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.28060207775028956
# Fold 29 RMSLE for all models ensemble = 0.279669357049858
# Fold 29 best combination: model1 with RMSLE = 0.27880178773967595
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.291305138113584
# Fold 30 RMSLE for model2 = 0.2881556311973994
# Fold 30 RMSLE for model3 = 0.2892581522031463
# Fold 30 RMSLE for model4 = 0.28516061625589184
# Fold 30 RMSLE for ('model1', 'model2') = 0.2880020884950625
# Fold 30 RMSLE for ('model1', 'model3') = 0.2897940924849758
# Fold 30 RMSLE for ('model1', 'model4') = 0.2872072447905237
# Fold 30 RMSLE for ('model2', 'model3') = 0.28657337917564235
# Fold 30 RMSLE for ('model2', 'model4') = 0.2856870507114528
# Fold 30 RMSLE for ('model3', 'model4') = 0.2855253767950131
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.2876440584447348
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.28654248428479134
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.2871616235096043
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.28539578391042875
# Fold 30 RMSLE for all models ensemble = 0.286463796845495
# Fold 30 best combination: model4 with RMSLE = 0.28516061625589184
# ---------------
#
# OOF RMSLE = 0.2840452456080063
# Sum of RMSLE for each combination:
# ('model1',): 8.65378496700165
# ('model2',): 8.594172347505607
# ('model3',): 8.647803979013132
# ('model4',): 8.636343558919997
# ('model1', 'model2'): 8.553034037178392
# ('model1', 'model3'): 8.636295968011492
# ('model1', 'model4'): 8.597773987680421
# ('model2', 'model3'): 8.544029547806433
# ('model2', 'model4'): 8.578514279734154
# ('model3', 'model4'): 8.580172897828541
# ('model1', 'model2', 'model3'): 8.559154611296274
# ('model1', 'model2', 'model4'): 8.55964721510655
# ('model1', 'model3', 'model4'): 8.590565262005681
# ('model2', 'model3', 'model4'): 8.548476723716401
# ('model1', 'model2', 'model3', 'model4'): 8.55590173220959

# %%
train_df = train_df.reset_index(drop=True)
train_df.iloc[:, -1]
# Out:
# 0       5.297314e+04
# 1       5.591007e+04
# 2       5.567954e+04
# 3       6.141190e+04
# 4       4.310047e+04
#             ...
# 7158    5.497954e+05
# 7159    1.137684e+05
# 7160    1.412656e+05
# 7161    2.599965e+05
# 7162    1.293278e+06
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 7163, dtype: float64

# %%
# print(type(train_not_mask_df), type(oof_predictions))
# oof_predictions_series = pd.Series(oof_predictions, name='oof_predictions')
# train_not_mask_all_df = pd.concat([train_not_mask_df, oof_predictions], axis=1)
# train_not_mask_all_df.iloc[:, -1]

train_not_mask_df["oof_predictions"] = oof_predictions
train_mask_df["oof_predictions"] = train_mask_preds
train_all_df = pd.concat([train_not_mask_df, train_mask_df], axis=0)
test_df["test_preds"] = test_preds
train_all_df = train_all_df[:4655]
train_all_df.to_csv("train_all_df_054.csv")
test_df.to_csv("test_all_df_054.csv")

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                 24101.026379                 19191.516543
# 4651                          NaN                          NaN
# 4652                 24256.968166                 25344.483061
# 4653                 25345.077827                 15031.292599
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                 26927.123407            20
# 4651                          NaN            92
# 4652                 25052.338495            80
# 4653                 15796.850949            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                              52973.139946
# 1                  14            1                              55910.066617
# 2                   9            1                              55679.543214
# 3                  15            1                              61411.902782
# 4                  15            0                              43100.469774
# ...               ...          ...                                       ...
# 4650               15            0                              45924.929057
# 4651                8            1                             180682.212598
# 4652                8            0                              30585.982393
# 4653                8            0                              64874.704338
# 4654                9            1                             131885.201103
#
#       oof_predictions
# 0        41546.989638
# 1        59346.709274
# 2        99121.078125
# 3        51450.356554
# 4        51059.886013
# ...               ...
# 4650     46740.289062
# 4651    170354.516977
# 4652     31492.170648
# 4653     66290.436080
# 4654    146419.312500
#
# [4655 rows x 20 columns]

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(train_target)
log_oof_predictions = np.log1p(train_preds)
# 差の計算
diff = abs(log_target - log_oof_predictions)
# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.72
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線の描画
min_val = min(log_target.min(), log_oof_predictions.min())
max_val = max(log_target.max(), log_oof_predictions.max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='y = x')  # 45度線


# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)
# 凡例の設定
plt.legend(title='Difference > 0.7')

# プロットの表示
plt.tight_layout()
plt.show()

# %%
test_preds.max()
# Out:
# 2234827.139324744

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
after_test_preds = after_times(test_preds)
after_train_preds = after_times(train_preds)
after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
len(oof_predictions), len(target)
# Out:
# (6045, 6045)

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return np.array(bin_centers), np.array(y_means)
x = after_oof_predictions
y = target
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 243194.2458847204

# %%
x = after_test_preds
y = after_test_preds
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 216700.41469395973

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,178,469
# 110   4765 1,541,546
# 114   4769 1,152,868
# 148   4803 2,008,581
# 178   4833 1,656,522
# ...    ...       ...
# 2417  7072 1,186,077
# 2423  7078 1,398,070
# 2466  7121 1,774,377
# 2490  7145 1,598,339
# 2507  7162 1,493,957
#
# [104 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2503    1
# 2504    1
# 2505    0
# 2506    0
# 2507    1
# Name: num_missing, Length: 2508, dtype: int64

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                       23,592                       25,069
# 6043                      140,816                       93,119
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 6040                          NaN           240
# 6041                          NaN             4
# 6042                       24,560           132
# 6043                      130,327            98
# 6044                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 6040                                 110,523
# 6041                                     NaN
# 6042                                 166,520
# 6043                                  71,774
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 6040                                  98,955
# 6041                                     NaN
# 6042                                 469,733
# 6043                                 936,032
# 6044                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 6040                               3,467,008
# 6041                                     NaN
# 6042                                  82,559
# 6043                                 336,961
# 6044                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 6040                                 147,802        39        -76
# 6041                                     NaN        31       -102
# 6042                                  85,775        41        -96
# 6043                                 156,640        39        -93
# 6044                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                              636                            1,477
# 6043                           16,356                          -47,698
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                             -509                                 0
# 6043                           37,208                                 0
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                                 0                                -0
# 6043                                -0                                 0
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 6040                1            1                                   549,795
# 6041                9            1                                   113,768
# 6042                8            0                                   141,266
# 6043                8            0                                   259,996
# 6044                9            1                                 1,293,278
#
# [6045 rows x 19 columns]

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(oof_predictions, target, "oof_predictions, target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
          "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Tue Nov 26 10:25:50 2024
