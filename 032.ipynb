# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/032.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Collecting pygeohash
#   Downloading pygeohash-1.2.0.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pygeohash
#   Building wheel for pygeohash (setup.py) ... done
#   Created wheel for pygeohash: filename=pygeohash-1.2.0-py2.py3-none-any.whl size=6153 sha256=a8a03dbca1591ecc7497cd6a5079839294520a6aa12840c3a5852d8ada49d8d4
#   Stored in directory: /root/.cache/pip/wheels/28/ec/b6/beadf7295a623f528507691fb0d471b50d064ae9bbad420b8f
# Successfully built pygeohash
# Installing collected packages: pygeohash
# Successfully installed pygeohash-1.2.0
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 18.3 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 14.9 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)
train_all_df.drop('oof_predictions', axis=1, inplace=True)
test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                   9            1                              5.567954e+04
# 3                  15            1                              6.141190e+04
# 4                  15            0                              4.310047e+04
# ...               ...          ...                                       ...
# 2503                1            1                              5.497954e+05
# 2504                9            1                              1.137684e+05
# 2505                8            0                              1.412656e+05
# 2506                8            0                              2.599965e+05
# 2507                9            1                              1.293278e+06
#
# [7163 rows x 19 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)

        test_predictions += test_preds / kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     3.868125e+04
# 1                  14            1     6.421108e+04
# 2                   9            1     1.092220e+05
# 3                  15            1     5.115422e+04
# 4                  15            0     5.271591e+04
# ...               ...          ...              ...
# 4650                9            1     2.220249e+05
# 4651                9            1     5.036959e+04
# 4652                5            1     1.211018e+06
# 4653                1            1     3.996303e+04
# 4654                9            1     7.176402e+04
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.297314e+04
# 1                                 5.591007e+04
# 2                                 5.567954e+04
# 3                                 6.141190e+04
# 4                                 4.310047e+04
# ...                                        ...
# 4650                              2.451197e+06
# 4651                              3.573974e+04
# 4652                              9.783592e+05
# 4653                              2.723434e+04
# 4654                              1.948221e+05
#
# [4655 rows x 20 columns]

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    32075.140635                 26445.792090
# 3                    42503.897432                 43906.102080
# 4                    39897.800897                 40203.428231
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                    23385.161510           130
# 3                    42958.306538            82
# 4                    39437.099224           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing
# 0                   9            1
# 1                  14            1
# 2                   8            0
# 3                   8            0
# 4                   8            0
# ...               ...          ...
# 2503                1            1
# 2504                9            1
# 2505                8            0
# 2506                8            0
# 2507                9            1
#
# [2508 rows x 18 columns]

# %%
train = train_all_df.iloc[:, :-1].values
test = test_df.values
target = train_all_df.iloc[:, -1].values

# %%
oof_predictions,test_preds = get_models_trained(train,test,target,30)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.6130223161378392
# Fold 1 RMSLE for model2 = 0.6183717547512363
# Fold 1 RMSLE for model3 = 0.6088835266809677
# Fold 1 RMSLE for model4 = 0.6137970214788199
# Fold 1 RMSLE for ('model1', 'model2') = 0.6138844238590944
# Fold 1 RMSLE for ('model1', 'model3') = 0.610549771344124
# Fold 1 RMSLE for ('model1', 'model4') = 0.6120752856816601
# Fold 1 RMSLE for ('model2', 'model3') = 0.6112412332610399
# Fold 1 RMSLE for ('model2', 'model4') = 0.6149030830165808
# Fold 1 RMSLE for ('model3', 'model4') = 0.6096856927625899
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.6113681738864158
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.6131162056126579
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.6104009039892386
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.6113561764490689
# Fold 1 RMSLE for all models ensemble = 0.6113117206218575
# Fold 1 best combination: model3 with RMSLE = 0.6088835266809677
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.7183527585736044
# Fold 2 RMSLE for model2 = 0.7180104507872218
# Fold 2 RMSLE for model3 = 0.7105426910412349
# Fold 2 RMSLE for model4 = 0.7165463739015592
# Fold 2 RMSLE for ('model1', 'model2') = 0.7159736727580495
# Fold 2 RMSLE for ('model1', 'model3') = 0.7141315237321071
# Fold 2 RMSLE for ('model1', 'model4') = 0.7164720866250527
# Fold 2 RMSLE for ('model2', 'model3') = 0.7122603913114506
# Fold 2 RMSLE for ('model2', 'model4') = 0.7159952565526719
# Fold 2 RMSLE for ('model3', 'model4') = 0.7122283041168902
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.7135770362351311
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.7156718080963717
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.7139743184276535
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.713000569387225
# Fold 2 RMSLE for all models ensemble = 0.713829852639733
# Fold 2 best combination: model3 with RMSLE = 0.7105426910412349
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.5700019570637197
# Fold 3 RMSLE for model2 = 0.5875473309329612
# Fold 3 RMSLE for model3 = 0.5717417654365284
# Fold 3 RMSLE for model4 = 0.5829627846833209
# Fold 3 RMSLE for ('model1', 'model2') = 0.5759658456548779
# Fold 3 RMSLE for ('model1', 'model3') = 0.5705885903728245
# Fold 3 RMSLE for ('model1', 'model4') = 0.5743533167866484
# Fold 3 RMSLE for ('model2', 'model3') = 0.5769553822102147
# Fold 3 RMSLE for ('model2', 'model4') = 0.5835232960060783
# Fold 3 RMSLE for ('model3', 'model4') = 0.5751694751035333
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.5737876583094879
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.577254792812084
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.5728056711951905
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.577858484906961
# Fold 3 RMSLE for all models ensemble = 0.575101058016213
# Fold 3 best combination: model1 with RMSLE = 0.5700019570637197
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.6179054683166038
# Fold 4 RMSLE for model2 = 0.6228913238694969
# Fold 4 RMSLE for model3 = 0.622021107018049
# Fold 4 RMSLE for model4 = 0.6207884566540315
# Fold 4 RMSLE for ('model1', 'model2') = 0.6187690773860939
# Fold 4 RMSLE for ('model1', 'model3') = 0.6196879144502784
# Fold 4 RMSLE for ('model1', 'model4') = 0.618180579067467
# Fold 4 RMSLE for ('model2', 'model3') = 0.6207003484212065
# Fold 4 RMSLE for ('model2', 'model4') = 0.6209664344371053
# Fold 4 RMSLE for ('model3', 'model4') = 0.6198947083316132
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.6192886600406146
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.6189118930245728
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.6189139997409829
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.6200811818348682
# Fold 4 RMSLE for all models ensemble = 0.6191004917459008
# Fold 4 best combination: model1 with RMSLE = 0.6179054683166038
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.6356406635891532
# Fold 5 RMSLE for model2 = 0.6300589910476309
# Fold 5 RMSLE for model3 = 0.631018386291089
# Fold 5 RMSLE for model4 = 0.627038946780293
# Fold 5 RMSLE for ('model1', 'model2') = 0.6308693561712875
# Fold 5 RMSLE for ('model1', 'model3') = 0.6331355688017575
# Fold 5 RMSLE for ('model1', 'model4') = 0.6302288783716566
# Fold 5 RMSLE for ('model2', 'model3') = 0.6288933156839899
# Fold 5 RMSLE for ('model2', 'model4') = 0.6275514065369667
# Fold 5 RMSLE for ('model3', 'model4') = 0.6279523127426904
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.630572214379328
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.629074180452273
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.6301836129339583
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.6277011629633888
# Fold 5 RMSLE for all models ensemble = 0.629190359883861
# Fold 5 best combination: model4 with RMSLE = 0.627038946780293
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.6082615938774484
# Fold 6 RMSLE for model2 = 0.6039112795477714
# Fold 6 RMSLE for model3 = 0.6090723941600628
# Fold 6 RMSLE for model4 = 0.5992304690669888
# Fold 6 RMSLE for ('model1', 'model2') = 0.6038479837260418
# Fold 6 RMSLE for ('model1', 'model3') = 0.608187443213075
# Fold 6 RMSLE for ('model1', 'model4') = 0.6024602770861464
# Fold 6 RMSLE for ('model2', 'model3') = 0.6039837790454112
# Fold 6 RMSLE for ('model2', 'model4') = 0.5998028735490961
# Fold 6 RMSLE for ('model3', 'model4') = 0.6020679188954576
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.6047592011394772
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.6014257515625216
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.6038051429676592
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.6012354629140874
# Fold 6 RMSLE for all models ensemble = 0.6025122529369896
# Fold 6 best combination: model4 with RMSLE = 0.5992304690669888
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.630848135734147
# Fold 7 RMSLE for model2 = 0.63192737861513
# Fold 7 RMSLE for model3 = 0.6314092147853705
# Fold 7 RMSLE for model4 = 0.6184489020295513
# Fold 7 RMSLE for ('model1', 'model2') = 0.6291731009092673
# Fold 7 RMSLE for ('model1', 'model3') = 0.6308649759986285
# Fold 7 RMSLE for ('model1', 'model4') = 0.6231653443055983
# Fold 7 RMSLE for ('model2', 'model3') = 0.6296985476598455
# Fold 7 RMSLE for ('model2', 'model4') = 0.6236502434800958
# Fold 7 RMSLE for ('model3', 'model4') = 0.6232702488401338
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.6293774846333071
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.6247183242461585
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.6253562890991207
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.6249206903498827
# Fold 7 RMSLE for all models ensemble = 0.6258141045718898
# Fold 7 best combination: model4 with RMSLE = 0.6184489020295513
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.5695421672231409
# Fold 8 RMSLE for model2 = 0.5742209521634484
# Fold 8 RMSLE for model3 = 0.5724142222194843
# Fold 8 RMSLE for model4 = 0.5645405817417938
# Fold 8 RMSLE for ('model1', 'model2') = 0.5689847714359425
# Fold 8 RMSLE for ('model1', 'model3') = 0.5706066939360103
# Fold 8 RMSLE for ('model1', 'model4') = 0.5659348447889088
# Fold 8 RMSLE for ('model2', 'model3') = 0.5704771734315858
# Fold 8 RMSLE for ('model2', 'model4') = 0.5666323307471697
# Fold 8 RMSLE for ('model3', 'model4') = 0.567132489501829
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.5693484935102142
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.5664560129411363
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.5675693425169671
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.5673378773542207
# Fold 8 RMSLE for all models ensemble = 0.5673719156193804
# Fold 8 best combination: model4 with RMSLE = 0.5645405817417938
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.7002437169325892
# Fold 9 RMSLE for model2 = 0.68662679722384
# Fold 9 RMSLE for model3 = 0.6948513813926314
# Fold 9 RMSLE for model4 = 0.7001120946393327
# Fold 9 RMSLE for ('model1', 'model2') = 0.6916766366955889
# Fold 9 RMSLE for ('model1', 'model3') = 0.6972042711423331
# Fold 9 RMSLE for ('model1', 'model4') = 0.6991848740490738
# Fold 9 RMSLE for ('model2', 'model3') = 0.6892439811235989
# Fold 9 RMSLE for ('model2', 'model4') = 0.6925978950462455
# Fold 9 RMSLE for ('model3', 'model4') = 0.69646453348302
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.692302881408229
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.6941005933029757
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.6973524967951442
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.6924012022141747
# Fold 9 RMSLE for all models ensemble = 0.6938618431597964
# Fold 9 best combination: model2 with RMSLE = 0.68662679722384
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.5566918204729521
# Fold 10 RMSLE for model2 = 0.5655845259414005
# Fold 10 RMSLE for model3 = 0.558923312680811
# Fold 10 RMSLE for model4 = 0.5576945955347529
# Fold 10 RMSLE for ('model1', 'model2') = 0.5585194953875304
# Fold 10 RMSLE for ('model1', 'model3') = 0.5573609306282555
# Fold 10 RMSLE for ('model1', 'model4') = 0.555320041591647
# Fold 10 RMSLE for ('model2', 'model3') = 0.5589403886076737
# Fold 10 RMSLE for ('model2', 'model4') = 0.5604125984445653
# Fold 10 RMSLE for ('model3', 'model4') = 0.5558680260242094
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.5575321685701189
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.5574699835239956
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.5556347216245963
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.5576851802340906
# Fold 10 RMSLE for all models ensemble = 0.5567554272579549
# Fold 10 best combination: ('model1', 'model4') with RMSLE = 0.555320041591647
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.6391349866753634
# Fold 11 RMSLE for model2 = 0.6423770489461224
# Fold 11 RMSLE for model3 = 0.6403371680026222
# Fold 11 RMSLE for model4 = 0.635332613859932
# Fold 11 RMSLE for ('model1', 'model2') = 0.6391680410637465
# Fold 11 RMSLE for ('model1', 'model3') = 0.6395488924593152
# Fold 11 RMSLE for ('model1', 'model4') = 0.6364739665531685
# Fold 11 RMSLE for ('model2', 'model3') = 0.6400667845863203
# Fold 11 RMSLE for ('model2', 'model4') = 0.6377091253424438
# Fold 11 RMSLE for ('model3', 'model4') = 0.6370278227486186
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.6392548354053815
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.6373865404295719
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.6374943112524535
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.6378971740992267
# Fold 11 RMSLE for all models ensemble = 0.6378457615099438
# Fold 11 best combination: model4 with RMSLE = 0.635332613859932
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.6413795325276592
# Fold 12 RMSLE for model2 = 0.6476462094544495
# Fold 12 RMSLE for model3 = 0.6408188350358061
# Fold 12 RMSLE for model4 = 0.6443639519628804
# Fold 12 RMSLE for ('model1', 'model2') = 0.6412816190949198
# Fold 12 RMSLE for ('model1', 'model3') = 0.6409189956366023
# Fold 12 RMSLE for ('model1', 'model4') = 0.6412738181466774
# Fold 12 RMSLE for ('model2', 'model3') = 0.6411712791029773
# Fold 12 RMSLE for ('model2', 'model4') = 0.6444165596982923
# Fold 12 RMSLE for ('model3', 'model4') = 0.6409907834308533
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.640334759707509
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.6416724199645049
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.6406199482669335
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.6415418545078178
# Fold 12 RMSLE for all models ensemble = 0.6407329564828269
# Fold 12 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.640334759707509
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.5797106548058936
# Fold 13 RMSLE for model2 = 0.5937014208683552
# Fold 13 RMSLE for model3 = 0.5763650115504211
# Fold 13 RMSLE for model4 = 0.589508853247718
# Fold 13 RMSLE for ('model1', 'model2') = 0.5844767881090317
# Fold 13 RMSLE for ('model1', 'model3') = 0.5775570062586448
# Fold 13 RMSLE for ('model1', 'model4') = 0.5827759629498898
# Fold 13 RMSLE for ('model2', 'model3') = 0.5832353051453931
# Fold 13 RMSLE for ('model2', 'model4') = 0.5897519027242858
# Fold 13 RMSLE for ('model3', 'model4') = 0.5809771981245455
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.581243111206572
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.5849876334341925
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.5799021298447318
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.584000186222646
# Fold 13 RMSLE for all models ensemble = 0.5822304441626205
# Fold 13 best combination: model3 with RMSLE = 0.5763650115504211
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.498181686274086
# Fold 14 RMSLE for model2 = 0.4903103136961681
# Fold 14 RMSLE for model3 = 0.4927725262718317
# Fold 14 RMSLE for model4 = 0.49146505250357725
# Fold 14 RMSLE for ('model1', 'model2') = 0.4918039122299428
# Fold 14 RMSLE for ('model1', 'model3') = 0.49511196693256104
# Fold 14 RMSLE for ('model1', 'model4') = 0.49335147644498195
# Fold 14 RMSLE for ('model2', 'model3') = 0.4890355186260253
# Fold 14 RMSLE for ('model2', 'model4') = 0.4896596696566351
# Fold 14 RMSLE for ('model3', 'model4') = 0.4905138789280534
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.49134697133828237
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.49103908796841905
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.49259892513953424
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.489132751745792
# Fold 14 RMSLE for all models ensemble = 0.4907528642669382
# Fold 14 best combination: ('model2', 'model3') with RMSLE = 0.4890355186260253
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.6217688339160428
# Fold 15 RMSLE for model2 = 0.6408627993532078
# Fold 15 RMSLE for model3 = 0.6213653994767186
# Fold 15 RMSLE for model4 = 0.6259047337110097
# Fold 15 RMSLE for ('model1', 'model2') = 0.6289843668071996
# Fold 15 RMSLE for ('model1', 'model3') = 0.6213334395952448
# Fold 15 RMSLE for ('model1', 'model4') = 0.6229943996512187
# Fold 15 RMSLE for ('model2', 'model3') = 0.628876680038333
# Fold 15 RMSLE for ('model2', 'model4') = 0.6318245905879512
# Fold 15 RMSLE for ('model3', 'model4') = 0.6225801014741686
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.625898615219315
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.627446229104444
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.6220611585093027
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.6272589403769149
# Fold 15 RMSLE for all models ensemble = 0.6254537924166234
# Fold 15 best combination: ('model1', 'model3') with RMSLE = 0.6213334395952448
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.5828822931391795
# Fold 16 RMSLE for model2 = 0.5783851517812243
# Fold 16 RMSLE for model3 = 0.5831007953949728
# Fold 16 RMSLE for model4 = 0.5821408562111707
# Fold 16 RMSLE for ('model1', 'model2') = 0.5788217444209942
# Fold 16 RMSLE for ('model1', 'model3') = 0.5827253187250675
# Fold 16 RMSLE for ('model1', 'model4') = 0.5815593202523506
# Fold 16 RMSLE for ('model2', 'model3') = 0.5792966767154885
# Fold 16 RMSLE for ('model2', 'model4') = 0.578848777465888
# Fold 16 RMSLE for ('model3', 'model4') = 0.5814082651874706
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.5798761686338734
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.5792845516332766
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.5816190110855659
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.5793969324044606
# Fold 16 RMSLE for all models ensemble = 0.5798444074003344
# Fold 16 best combination: model2 with RMSLE = 0.5783851517812243
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.5643462755426211
# Fold 17 RMSLE for model2 = 0.563995554982334
# Fold 17 RMSLE for model3 = 0.5620217738913549
# Fold 17 RMSLE for model4 = 0.5597742727562828
# Fold 17 RMSLE for ('model1', 'model2') = 0.5621627039898947
# Fold 17 RMSLE for ('model1', 'model3') = 0.5628784965312615
# Fold 17 RMSLE for ('model1', 'model4') = 0.5610299608473195
# Fold 17 RMSLE for ('model2', 'model3') = 0.5612668911258976
# Fold 17 RMSLE for ('model2', 'model4') = 0.5605293316063383
# Fold 17 RMSLE for ('model3', 'model4') = 0.559893301937994
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.5616505738032596
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.5607263838312418
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.5610176982781256
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.5600857892059463
# Fold 17 RMSLE for all models ensemble = 0.5606568065040187
# Fold 17 best combination: model4 with RMSLE = 0.5597742727562828
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.6765428632880047
# Fold 18 RMSLE for model2 = 0.6859641874705478
# Fold 18 RMSLE for model3 = 0.678526096908468
# Fold 18 RMSLE for model4 = 0.6800576154392535
# Fold 18 RMSLE for ('model1', 'model2') = 0.6796589338768693
# Fold 18 RMSLE for ('model1', 'model3') = 0.6772974918370889
# Fold 18 RMSLE for ('model1', 'model4') = 0.6771976719394045
# Fold 18 RMSLE for ('model2', 'model3') = 0.6806873743312915
# Fold 18 RMSLE for ('model2', 'model4') = 0.682050514782994
# Fold 18 RMSLE for ('model3', 'model4') = 0.6779663082102493
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.6787717095979587
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.6792625828290723
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.6771577497041958
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.6798292292686006
# Fold 18 RMSLE for all models ensemble = 0.6785659886705784
# Fold 18 best combination: model1 with RMSLE = 0.6765428632880047
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.5178287828790068
# Fold 19 RMSLE for model2 = 0.5146179435407315
# Fold 19 RMSLE for model3 = 0.5205508977586293
# Fold 19 RMSLE for model4 = 0.5175978318197425
# Fold 19 RMSLE for ('model1', 'model2') = 0.5136280954078823
# Fold 19 RMSLE for ('model1', 'model3') = 0.5189317006989753
# Fold 19 RMSLE for ('model1', 'model4') = 0.516795420321023
# Fold 19 RMSLE for ('model2', 'model3') = 0.5149648121984388
# Fold 19 RMSLE for ('model2', 'model4') = 0.5141501802043115
# Fold 19 RMSLE for ('model3', 'model4') = 0.5179756485209694
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.5152168260873521
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.5142272356742698
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.5176502814974744
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.5150384094274495
# Fold 19 RMSLE for all models ensemble = 0.5152590329088533
# Fold 19 best combination: ('model1', 'model2') with RMSLE = 0.5136280954078823
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.5439518341975849
# Fold 20 RMSLE for model2 = 0.5532369221866341
# Fold 20 RMSLE for model3 = 0.545216760115996
# Fold 20 RMSLE for model4 = 0.552377434748552
# Fold 20 RMSLE for ('model1', 'model2') = 0.5462113650147387
# Fold 20 RMSLE for ('model1', 'model3') = 0.5442961727222088
# Fold 20 RMSLE for ('model1', 'model4') = 0.5465360880509205
# Fold 20 RMSLE for ('model2', 'model3') = 0.5465873427682194
# Fold 20 RMSLE for ('model2', 'model4') = 0.5510659391081134
# Fold 20 RMSLE for ('model3', 'model4') = 0.5468403559171887
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.5450225035950015
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.5473375396878439
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.545423570372596
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.5474974989399579
# Fold 20 RMSLE for all models ensemble = 0.5460246419433081
# Fold 20 best combination: model1 with RMSLE = 0.5439518341975849
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.5765034528997611
# Fold 21 RMSLE for model2 = 0.589612919480225
# Fold 21 RMSLE for model3 = 0.5754853628097633
# Fold 21 RMSLE for model4 = 0.5775658947713885
# Fold 21 RMSLE for ('model1', 'model2') = 0.5806867297043364
# Fold 21 RMSLE for ('model1', 'model3') = 0.5757086937958855
# Fold 21 RMSLE for ('model1', 'model4') = 0.5757366102466522
# Fold 21 RMSLE for ('model2', 'model3') = 0.5802101907351563
# Fold 21 RMSLE for ('model2', 'model4') = 0.582352567436343
# Fold 21 RMSLE for ('model3', 'model4') = 0.5749017255870487
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.5782185222271049
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.5790623376952596
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.5750682378590329
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.5785953818255625
# Fold 21 RMSLE for all models ensemble = 0.5774700468659827
# Fold 21 best combination: ('model3', 'model4') with RMSLE = 0.5749017255870487
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.6056259626749254
# Fold 22 RMSLE for model2 = 0.6076921958869912
# Fold 22 RMSLE for model3 = 0.6035506169350061
# Fold 22 RMSLE for model4 = 0.6047010540131459
# Fold 22 RMSLE for ('model1', 'model2') = 0.6042486783754308
# Fold 22 RMSLE for ('model1', 'model3') = 0.604267786208552
# Fold 22 RMSLE for ('model1', 'model4') = 0.6042238558750046
# Fold 22 RMSLE for ('model2', 'model3') = 0.6028758760151818
# Fold 22 RMSLE for ('model2', 'model4') = 0.6047020017471673
# Fold 22 RMSLE for ('model3', 'model4') = 0.6028715668988431
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.6031971243919396
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.6038707981057744
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.6035033913269773
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.6029047545250285
# Fold 22 RMSLE for all models ensemble = 0.603123871250052
# Fold 22 best combination: ('model3', 'model4') with RMSLE = 0.6028715668988431
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.5975510584803112
# Fold 23 RMSLE for model2 = 0.6153987896684728
# Fold 23 RMSLE for model3 = 0.5962449868625348
# Fold 23 RMSLE for model4 = 0.6080805741883868
# Fold 23 RMSLE for ('model1', 'model2') = 0.6035094300990622
# Fold 23 RMSLE for ('model1', 'model3') = 0.5963948601367889
# Fold 23 RMSLE for ('model1', 'model4') = 0.6011012884134153
# Fold 23 RMSLE for ('model2', 'model3') = 0.603045123185783
# Fold 23 RMSLE for ('model2', 'model4') = 0.6104075969014762
# Fold 23 RMSLE for ('model3', 'model4') = 0.6006391018615332
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.6003030027733571
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.604329014744641
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.5989662993849216
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.6040768220330702
# Fold 23 RMSLE for all models ensemble = 0.6016231983729455
# Fold 23 best combination: model3 with RMSLE = 0.5962449868625348
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.6520968542338934
# Fold 24 RMSLE for model2 = 0.6555100990458427
# Fold 24 RMSLE for model3 = 0.6497180045639046
# Fold 24 RMSLE for model4 = 0.6461410448042925
# Fold 24 RMSLE for ('model1', 'model2') = 0.6516688926823428
# Fold 24 RMSLE for ('model1', 'model3') = 0.6505470421658185
# Fold 24 RMSLE for ('model1', 'model4') = 0.6476976574737723
# Fold 24 RMSLE for ('model2', 'model3') = 0.6506574203475258
# Fold 24 RMSLE for ('model2', 'model4') = 0.649205388461302
# Fold 24 RMSLE for ('model3', 'model4') = 0.6461626054462422
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.6504519632151593
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.6489507730506195
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.6477163950228846
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.6480817511534452
# Fold 24 RMSLE for all models ensemble = 0.6485358823102103
# Fold 24 best combination: model4 with RMSLE = 0.6461410448042925
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.5606158395058699
# Fold 25 RMSLE for model2 = 0.5744874092528509
# Fold 25 RMSLE for model3 = 0.5580927253941085
# Fold 25 RMSLE for model4 = 0.5665336061340036
# Fold 25 RMSLE for ('model1', 'model2') = 0.5649242336880609
# Fold 25 RMSLE for ('model1', 'model3') = 0.5590537587582403
# Fold 25 RMSLE for ('model1', 'model4') = 0.5620755243530767
# Fold 25 RMSLE for ('model2', 'model3') = 0.5640768787209172
# Fold 25 RMSLE for ('model2', 'model4') = 0.5688136235210849
# Fold 25 RMSLE for ('model3', 'model4') = 0.5609686975358243
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.5620805966386668
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.564605913784251
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.5603450761293655
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.5640239756349996
# Fold 25 RMSLE for all models ensemble = 0.5624855593139083
# Fold 25 best combination: model3 with RMSLE = 0.5580927253941085
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.5873159222171459
# Fold 26 RMSLE for model2 = 0.5896542207354435
# Fold 26 RMSLE for model3 = 0.5860476459676537
# Fold 26 RMSLE for model4 = 0.5894200839804508
# Fold 26 RMSLE for ('model1', 'model2') = 0.5868065680428066
# Fold 26 RMSLE for ('model1', 'model3') = 0.5864631434106974
# Fold 26 RMSLE for ('model1', 'model4') = 0.5871835255519567
# Fold 26 RMSLE for ('model2', 'model3') = 0.5863781189612843
# Fold 26 RMSLE for ('model2', 'model4') = 0.5886114601342478
# Fold 26 RMSLE for ('model3', 'model4') = 0.5864737732518694
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.5861786055204203
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.5871082769432785
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.586413426642214
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.5867422094029108
# Fold 26 RMSLE for all models ensemble = 0.5864233806802547
# Fold 26 best combination: model3 with RMSLE = 0.5860476459676537
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.6348819104796782
# Fold 27 RMSLE for model2 = 0.6358338677007551
# Fold 27 RMSLE for model3 = 0.6381693934074169
# Fold 27 RMSLE for model4 = 0.6318609413682194
# Fold 27 RMSLE for ('model1', 'model2') = 0.6337967542915072
# Fold 27 RMSLE for ('model1', 'model3') = 0.6360999398095644
# Fold 27 RMSLE for ('model1', 'model4') = 0.6325639687225679
# Fold 27 RMSLE for ('model2', 'model3') = 0.6353436485420129
# Fold 27 RMSLE for ('model2', 'model4') = 0.6325486207498218
# Fold 27 RMSLE for ('model3', 'model4') = 0.6336719647350733
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.634675122035059
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.6325660221966524
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.6338277239335767
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.6333817501465029
# Fold 27 RMSLE for all models ensemble = 0.6334176637531678
# Fold 27 best combination: model4 with RMSLE = 0.6318609413682194
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.6358357185881123
# Fold 28 RMSLE for model2 = 0.6378501209262333
# Fold 28 RMSLE for model3 = 0.6325652433985682
# Fold 28 RMSLE for model4 = 0.6274601951996611
# Fold 28 RMSLE for ('model1', 'model2') = 0.6340924786916878
# Fold 28 RMSLE for ('model1', 'model3') = 0.633814227156302
# Fold 28 RMSLE for ('model1', 'model4') = 0.6298974798936757
# Fold 28 RMSLE for ('model2', 'model3') = 0.6328717534680761
# Fold 28 RMSLE for ('model2', 'model4') = 0.6312980895699071
# Fold 28 RMSLE for ('model3', 'model4') = 0.6283148813039953
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.6329471979862864
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.6311490577800551
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.6302408507419663
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.6302467094658744
# Fold 28 RMSLE for all models ensemble = 0.6308638935587744
# Fold 28 best combination: model4 with RMSLE = 0.6274601951996611
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.613652769546604
# Fold 29 RMSLE for model2 = 0.613568681056825
# Fold 29 RMSLE for model3 = 0.6080320855021544
# Fold 29 RMSLE for model4 = 0.6116299269180171
# Fold 29 RMSLE for ('model1', 'model2') = 0.6097333947349697
# Fold 29 RMSLE for ('model1', 'model3') = 0.6104868986175771
# Fold 29 RMSLE for ('model1', 'model4') = 0.6110279618984721
# Fold 29 RMSLE for ('model2', 'model3') = 0.6069735304418156
# Fold 29 RMSLE for ('model2', 'model4') = 0.6102662352295943
# Fold 29 RMSLE for ('model3', 'model4') = 0.6079575295608728
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.6081541386438373
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.6095121063720792
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.6093585157838795
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.6075578900429148
# Fold 29 RMSLE for all models ensemble = 0.6082708516858221
# Fold 29 best combination: ('model2', 'model3') with RMSLE = 0.6069735304418156
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.629392226247062
# Fold 30 RMSLE for model2 = 0.6327036417878137
# Fold 30 RMSLE for model3 = 0.6291205533117556
# Fold 30 RMSLE for model4 = 0.6373584779867245
# Fold 30 RMSLE for ('model1', 'model2') = 0.6287621946148618
# Fold 30 RMSLE for ('model1', 'model3') = 0.6287292796607138
# Fold 30 RMSLE for ('model1', 'model4') = 0.6322482342835134
# Fold 30 RMSLE for ('model2', 'model3') = 0.6285923132571977
# Fold 30 RMSLE for ('model2', 'model4') = 0.6335746820625402
# Fold 30 RMSLE for ('model3', 'model4') = 0.631583568978016
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.6281206910190372
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.6309954639055859
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.6304898713631206
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.6306619088439865
# Fold 30 RMSLE for all models ensemble = 0.629810931712647
# Fold 30 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.6281206910190372
# ---------------
#
# OOF RMSLE = 0.6035847422562198
# Sum of RMSLE for each combination:
# ('model1',): 18.179710056040005
# ('model2',): 18.302560282701368
# ('model3',): 18.148979884265916
# ('model4',): 18.18043524213485
# ('model1', 'model2'): 18.172091288924058
# ('model1', 'model3'): 18.154482794736506
# ('model1', 'model4'): 18.14111972022292
# ('model2', 'model3'): 18.158608059069355
# ('model2', 'model4'): 18.197822274807315
# ('model3', 'model4'): 18.1194527894414
# ('model1', 'model2', 'model3'): 18.144857011157697
# ('model1', 'model2', 'model4'): 18.153719514709778
# ('model1', 'model3', 'model4'): 18.127471071429365
# ('model2', 'model3', 'model4'): 18.141529907881075
# ('model1', 'model2', 'model3', 'model4'): 18.134241002223387

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target = target.flatten()
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=oof_predictions, y=target, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([target.min(), target.max()], [target.min(), target.max()], 'r--')  # 45度線
plt.show()

# %%
# train_all = np.concatenate((train, test), axis=0)
# target_all = np.concatenate((target, test_preds), axis=0)
# oof_predictions,test_preds = get_models_trained(train_all,test,target_all,30)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
test_preds.shape
# Out:
# (2508,)

# %%
submit [ 1 ]  =  test_preds
submit.to_csv('SMBC_32.csv', index = False)

# %%
submit
# Out:
#          0             1
# 0     4655  4.320118e+04
# 1     4656  3.188999e+05
# 2     4657  4.017595e+04
# 3     4658  2.917296e+04
# 4     4659  4.662400e+04
# ...    ...           ...
# 2503  7158  5.310257e+05
# 2504  7159  1.111169e+05
# 2505  7160  1.392918e+05
# 2506  7161  2.570949e+05
# 2507  7162  1.267473e+06
#
# [2508 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2503    1
# 2504    1
# 2505    0
# 2506    0
# 2507    1
# Name: num_missing, Length: 2508, dtype: int64

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(oof_predictions, target, "oof_predictions, target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Fri Nov 22 15:07:48 2024
