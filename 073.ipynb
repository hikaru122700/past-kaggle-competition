# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/073.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
train_df.shape
# Out:
# (4655, 20)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     38681.250000
# 1                  14            1     64211.078125
# 2                   9            1    109221.968750
# 3                  15            1     51154.222656
# 4                  15            0     52715.906250
# ...               ...          ...              ...
# 2503                1            1              NaN
# 2504                9            1              NaN
# 2505                8            0              NaN
# 2506                8            0              NaN
# 2507                9            1              NaN
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.297314e+04
# 1                                 5.591007e+04
# 2                                 5.567954e+04
# 3                                 6.141190e+04
# 4                                 4.310047e+04
# ...                                        ...
# 2503                              5.497954e+05
# 2504                              1.137684e+05
# 2505                              1.412656e+05
# 2506                              2.599965e+05
# 2507                              1.293278e+06
#
# [7163 rows x 20 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     3.868125e+04
# 1                  14            1     6.421108e+04
# 2                   9            1     1.092220e+05
# 3                  15            1     5.115422e+04
# 4                  15            0     5.271591e+04
# ...               ...          ...              ...
# 4650                9            1     2.220249e+05
# 4651                9            1     5.036959e+04
# 4652                5            1     1.211018e+06
# 4653                1            1     3.996303e+04
# 4654                9            1     7.176402e+04
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 5.297314e+04
# 1                                 5.591007e+04
# 2                                 5.567954e+04
# 3                                 6.141190e+04
# 4                                 4.310047e+04
# ...                                        ...
# 4650                              2.451197e+06
# 4651                              3.573974e+04
# 4652                              9.783592e+05
# 4653                              2.723434e+04
# 4654                              1.948221e+05
#
# [4655 rows x 20 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_all_df["diff"].fillna(0, inplace=True)
for i in range(len(train_all_df)):
    if abs(train_all_df.iloc[i]["diff"]) > 0.75:
        train_all_df.iloc[i]["diff"] = train_all_df.iloc[i]["diff"]/abs(train_all_df.iloc[i]["diff"])*0.75
        train_all_df.iloc[i]["oof_predictions"] = np.expm1(np.log1p(train_all_df.iloc[i]["GHG_Direct_Emissions_14_in_metric_tons.1"]) -train_all_df.iloc[i]["diff"])
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     38681.250000
# 1                  14            1     64211.078125
# 2                   9            1    109221.968750
# 3                  15            1     51154.222656
# 4                  15            0     52715.906250
# ...               ...          ...              ...
# 2503                1            1              NaN
# 2504                9            1              NaN
# 2505                8            0              NaN
# 2506                8            0              NaN
# 2507                9            1              NaN
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 5.297314e+04  0.314423
# 1                                 5.591007e+04 -0.138429
# 2                                 5.567954e+04 -0.673761
# 3                                 6.141190e+04  0.182755
# 4                                 4.310047e+04 -0.201379
# ...                                        ...       ...
# 2503                              5.497954e+05  0.000000
# 2504                              1.137684e+05  0.000000
# 2505                              1.412656e+05  0.000000
# 2506                              2.599965e+05  0.000000
# 2507                              1.293278e+06  0.000000
#
# [7163 rows x 21 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                # print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     3.868125e+04  0.314423
# 1                  14            1     6.421108e+04 -0.138429
# 2                   9            1     1.092220e+05 -0.673761
# 3                  15            1     5.115422e+04  0.182755
# 4                  15            0     5.271591e+04 -0.201379
# ...               ...          ...              ...       ...
# 4650                9            1     2.220249e+05  2.401538
# 4651                9            1     5.036959e+04 -0.343116
# 4652                5            1     1.211018e+06 -0.213340
# 4653                1            1     3.996303e+04 -0.383464
# 4654                9            1     7.176402e+04  0.998695
#
# [4655 rows x 20 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     3.868125e+04  0.314423
# 1                  14            1     6.421108e+04 -0.138429
# 2                   9            1     1.092220e+05 -0.673761
# 3                  15            1     5.115422e+04  0.182755
# 4                  15            0     5.271591e+04 -0.201379
# ...               ...          ...              ...       ...
# 2503                1            1     5.497954e+05  0.000000
# 2504                9            1     1.137684e+05  0.000000
# 2505                8            0     1.412656e+05  0.000000
# 2506                8            0     2.599965e+05  0.000000
# 2507                9            1     1.293278e+06  0.000000
#
# [7163 rows x 20 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     3.868125e+04  0.314423
# 1                  14            1     6.421108e+04 -0.138429
# 2                   9            1     1.092220e+05 -0.673761
# 3                  15            1     5.115422e+04  0.182755
# 4                  15            0     5.271591e+04 -0.201379
# ...               ...          ...              ...       ...
# 4650                9            1     2.220249e+05  2.401538
# 4651                9            1     5.036959e+04 -0.343116
# 4652                5            1     1.211018e+06 -0.213340
# 4653                1            1     3.996303e+04 -0.383464
# 4654                9            1     7.176402e+04  0.998695
#
# [4655 rows x 20 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
import time
epock = 10
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_target = train_df.iloc[:, -1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train, test, train_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+oof_predictions)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+oof_predictions)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    for j in range(len(train_df)):
        if abs(train_df.iloc[j]["diff"]) > 0.75:
            train_df.iloc[j]["diff"] = train_df.iloc[j]["diff"]/abs(train_df.iloc[j]["diff"])*(0.75-0.07*(1+j))
            train_df.iloc[j]["oof_predictions"] = np.expm1(np.log1p(train_df_GHG14[j]) -train_df.iloc[j]["diff"])
    print(f"{i}回目の推論が終了しました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.7702358552396825
# Fold 18 RMSLE for ('model1', 'model3') = 0.7778299563067891
# Fold 18 RMSLE for ('model1', 'model4') = 0.7717554746404411
# Fold 18 RMSLE for ('model2', 'model3') = 0.7723790803189864
# Fold 18 RMSLE for ('model2', 'model4') = 0.767417326484665
# Fold 18 RMSLE for ('model3', 'model4') = 0.7739502426834789
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.7731139118697525
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.7693954424365965
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.7743147313646833
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.7709063371859921
# Fold 18 RMSLE for all models ensemble = 0.7717684011831564
# Fold 18 best combination: ('model2', 'model4') with RMSLE = 0.767417326484665
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.8026153170580339
# Fold 19 RMSLE for model2 = 0.7901773599119956
# Fold 19 RMSLE for model3 = 0.802027261016857
# Fold 19 RMSLE for model4 = 0.80339241595907
# Fold 19 RMSLE for ('model1', 'model2') = 0.7946376229030433
# Fold 19 RMSLE for ('model1', 'model3') = 0.8020925633750895
# Fold 19 RMSLE for ('model1', 'model4') = 0.8023854645623516
# Fold 19 RMSLE for ('model2', 'model3') = 0.7946249221590825
# Fold 19 RMSLE for ('model2', 'model4') = 0.7955597002558984
# Fold 19 RMSLE for ('model3', 'model4') = 0.8021492064703137
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.7967365004516481
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.7971292595074854
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.8020525477793876
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.797083715843219
# Fold 19 RMSLE for all models ensemble = 0.7980886329628074
# Fold 19 best combination: model2 with RMSLE = 0.7901773599119956
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.819932596490441
# Fold 20 RMSLE for model2 = 0.8542848831078094
# Fold 20 RMSLE for model3 = 0.8210141236168446
# Fold 20 RMSLE for model4 = 0.8250747180353478
# Fold 20 RMSLE for ('model1', 'model2') = 0.8346749719352844
# Fold 20 RMSLE for ('model1', 'model3') = 0.8201940553563578
# Fold 20 RMSLE for ('model1', 'model4') = 0.8214951265168877
# Fold 20 RMSLE for ('model2', 'model3') = 0.8358032840031484
# Fold 20 RMSLE for ('model2', 'model4') = 0.8383952778237758
# Fold 20 RMSLE for ('model3', 'model4') = 0.8223318661740183
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.8297064133985583
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.8309922020986116
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.8211175970617534
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.8317450687951622
# Fold 20 RMSLE for all models ensemble = 0.8281766126305521
# Fold 20 best combination: model1 with RMSLE = 0.819932596490441
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.808023799744456
# Fold 21 RMSLE for model2 = 0.7969811692492581
# Fold 21 RMSLE for model3 = 0.803072344816934
# Fold 21 RMSLE for model4 = 0.8074751595481623
# Fold 21 RMSLE for ('model1', 'model2') = 0.8007547525581205
# Fold 21 RMSLE for ('model1', 'model3') = 0.8051736822013071
# Fold 21 RMSLE for ('model1', 'model4') = 0.8068587774162637
# Fold 21 RMSLE for ('model2', 'model3') = 0.7984146397695348
# Fold 21 RMSLE for ('model2', 'model4') = 0.8006745525642576
# Fold 21 RMSLE for ('model3', 'model4') = 0.8045529997332337
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.8010346394154096
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.8022979787162428
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.8053074853787686
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.8007832633375016
# Fold 21 RMSLE for all models ensemble = 0.8021648427849833
# Fold 21 best combination: model2 with RMSLE = 0.7969811692492581
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.7319161048164411
# Fold 22 RMSLE for model2 = 0.7408234114564419
# Fold 22 RMSLE for model3 = 0.7325311482386571
# Fold 22 RMSLE for model4 = 0.7367729649922109
# Fold 22 RMSLE for ('model1', 'model2') = 0.734484142162049
# Fold 22 RMSLE for ('model1', 'model3') = 0.7320111540021318
# Fold 22 RMSLE for ('model1', 'model4') = 0.7335836200456348
# Fold 22 RMSLE for ('model2', 'model3') = 0.735157961945777
# Fold 22 RMSLE for ('model2', 'model4') = 0.7378695187878618
# Fold 22 RMSLE for ('model3', 'model4') = 0.734095598352825
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.7334799596208438
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.7349148343989704
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.7330597178636451
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.735373253760198
# Fold 22 RMSLE for all models ensemble = 0.7340433940474914
# Fold 22 best combination: model1 with RMSLE = 0.7319161048164411
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.8397880083144735
# Fold 23 RMSLE for model2 = 0.819420363118504
# Fold 23 RMSLE for model3 = 0.8404979918380402
# Fold 23 RMSLE for model4 = 0.8348717853198078
# Fold 23 RMSLE for ('model1', 'model2') = 0.8276077143323134
# Fold 23 RMSLE for ('model1', 'model3') = 0.8397057163433792
# Fold 23 RMSLE for ('model1', 'model4') = 0.8365756431664585
# Fold 23 RMSLE for ('model2', 'model3') = 0.8285469388653248
# Fold 23 RMSLE for ('model2', 'model4') = 0.8259906288558558
# Fold 23 RMSLE for ('model3', 'model4') = 0.8372325479555522
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.8315307497143135
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.8296258118876748
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.837655436490212
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.8302568577901146
# Fold 23 RMSLE for all models ensemble = 0.8320963304046025
# Fold 23 best combination: model2 with RMSLE = 0.819420363118504
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.7463112202719628
# Fold 24 RMSLE for model2 = 0.7523871039013047
# Fold 24 RMSLE for model3 = 0.7452740158311771
# Fold 24 RMSLE for model4 = 0.7472184579570038
# Fold 24 RMSLE for ('model1', 'model2') = 0.7473249834876848
# Fold 24 RMSLE for ('model1', 'model3') = 0.7456419239687933
# Fold 24 RMSLE for ('model1', 'model4') = 0.7461490708565605
# Fold 24 RMSLE for ('model2', 'model3') = 0.7469774835241539
# Fold 24 RMSLE for ('model2', 'model4') = 0.7485325356907756
# Fold 24 RMSLE for ('model3', 'model4') = 0.7456518607872982
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.7461983151223621
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.7468998058610966
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.7456629284680034
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.7466396516541025
# Fold 24 RMSLE for all models ensemble = 0.7461685756666836
# Fold 24 best combination: model3 with RMSLE = 0.7452740158311771
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.7887431788225622
# Fold 25 RMSLE for model2 = 0.7987426651243765
# Fold 25 RMSLE for model3 = 0.7895393878457809
# Fold 25 RMSLE for model4 = 0.8019191948858834
# Fold 25 RMSLE for ('model1', 'model2') = 0.7924924618699452
# Fold 25 RMSLE for ('model1', 'model3') = 0.7890078670405091
# Fold 25 RMSLE for ('model1', 'model4') = 0.794736926841324
# Fold 25 RMSLE for ('model2', 'model3') = 0.7930402375298556
# Fold 25 RMSLE for ('model2', 'model4') = 0.7992435598449004
# Fold 25 RMSLE for ('model3', 'model4') = 0.7951605952063341
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.7912356051904362
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.7951649283487023
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.7928233399006644
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.795508024170655
# Fold 25 RMSLE for all models ensemble = 0.7935508354808768
# Fold 25 best combination: model1 with RMSLE = 0.7887431788225622
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.8026578264704773
# Fold 26 RMSLE for model2 = 0.7916779579211389
# Fold 26 RMSLE for model3 = 0.8081934111118791
# Fold 26 RMSLE for model4 = 0.8039179255571335
# Fold 26 RMSLE for ('model1', 'model2') = 0.7959668083682551
# Fold 26 RMSLE for ('model1', 'model3') = 0.8052084796136028
# Fold 26 RMSLE for ('model1', 'model4') = 0.8027505910644516
# Fold 26 RMSLE for ('model2', 'model3') = 0.7989292375137157
# Fold 26 RMSLE for ('model2', 'model4') = 0.796793707697926
# Fold 26 RMSLE for ('model3', 'model4') = 0.8055773539406288
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.7997678109746366
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.7982000535883875
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.8043752657600548
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.8001581398974994
# Fold 26 RMSLE for all models ensemble = 0.8005026985046809
# Fold 26 best combination: model2 with RMSLE = 0.7916779579211389
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.7678947779475922
# Fold 27 RMSLE for model2 = 0.7585819790468756
# Fold 27 RMSLE for model3 = 0.7673552851269996
# Fold 27 RMSLE for model4 = 0.7650489841648446
# Fold 27 RMSLE for ('model1', 'model2') = 0.7616253348852682
# Fold 27 RMSLE for ('model1', 'model3') = 0.7674751065429866
# Fold 27 RMSLE for ('model1', 'model4') = 0.7657262613235732
# Fold 27 RMSLE for ('model2', 'model3') = 0.761468381609972
# Fold 27 RMSLE for ('model2', 'model4') = 0.7608114636745682
# Fold 27 RMSLE for ('model3', 'model4') = 0.7654780788472759
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.763162863162962
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.7623477485889475
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.766046797986242
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.7622276397992624
# Fold 27 RMSLE for all models ensemble = 0.7632874983193595
# Fold 27 best combination: model2 with RMSLE = 0.7585819790468756
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.7924087961706063
# Fold 28 RMSLE for model2 = 0.7881494298886753
# Fold 28 RMSLE for model3 = 0.7873863245167514
# Fold 28 RMSLE for model4 = 0.7769267058923394
# Fold 28 RMSLE for ('model1', 'model2') = 0.7889419588549359
# Fold 28 RMSLE for ('model1', 'model3') = 0.7896948538724847
# Fold 28 RMSLE for ('model1', 'model4') = 0.7839963814692162
# Fold 28 RMSLE for ('model2', 'model3') = 0.786731930121842
# Fold 28 RMSLE for ('model2', 'model4') = 0.7815189552954961
# Fold 28 RMSLE for ('model3', 'model4') = 0.7816683889731867
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.7881701436317988
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.7844814382003702
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.7849692848884736
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.7830230631283966
# Fold 28 RMSLE for all models ensemble = 0.7850287261021488
# Fold 28 best combination: model4 with RMSLE = 0.7769267058923394
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.8288185372173779
# Fold 29 RMSLE for model2 = 0.8183614428541202
# Fold 29 RMSLE for model3 = 0.8232650627768311
# Fold 29 RMSLE for model4 = 0.8198576319743583
# Fold 29 RMSLE for ('model1', 'model2') = 0.8216810687738335
# Fold 29 RMSLE for ('model1', 'model3') = 0.825767116085727
# Fold 29 RMSLE for ('model1', 'model4') = 0.8235542819428268
# Fold 29 RMSLE for ('model2', 'model3') = 0.8193466770401293
# Fold 29 RMSLE for ('model2', 'model4') = 0.8174990704189202
# Fold 29 RMSLE for ('model3', 'model4') = 0.8208100358018172
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.8218609887263411
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.8204336591368317
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.8231765258531638
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.8187934169859741
# Fold 29 RMSLE for all models ensemble = 0.8208778574103287
# Fold 29 best combination: ('model2', 'model4') with RMSLE = 0.8174990704189202
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.7798431911342759
# Fold 30 RMSLE for model2 = 0.7849119170617112
# Fold 30 RMSLE for model3 = 0.7793430267187117
# Fold 30 RMSLE for model4 = 0.7805857712543248
# Fold 30 RMSLE for ('model1', 'model2') = 0.7803567797092873
# Fold 30 RMSLE for ('model1', 'model3') = 0.7791563624578733
# Fold 30 RMSLE for ('model1', 'model4') = 0.779431789437228
# Fold 30 RMSLE for ('model2', 'model3') = 0.7806591765127102
# Fold 30 RMSLE for ('model2', 'model4') = 0.7818421001648808
# Fold 30 RMSLE for ('model3', 'model4') = 0.7794489801859958
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.7796197568414365
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.7801306503020654
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.7791528129195847
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.7803282579631052
# Fold 30 RMSLE for all models ensemble = 0.7796370753395128
# Fold 30 best combination: ('model1', 'model3', 'model4') with RMSLE = 0.7791528129195847
# ---------------
#
# OOF RMSLE = 0.7844591615910894
# Sum of RMSLE for each combination:
# ('model1',): 23.663543958881192
# ('model2',): 23.6482705867039
# ('model3',): 23.62826414765551
# ('model4',): 23.6569118309006
# ('model1', 'model2'): 23.59992223065584
# ('model1', 'model3'): 23.638135877314415
# ('model1', 'model4'): 23.63739433324621
# ('model2', 'model3'): 23.590791628911848
# ('model2', 'model4'): 23.61581609225555
# ('model3', 'model4'): 23.623120804733063
# ('model1', 'model2', 'model3'): 23.597244767099852
# ('model1', 'model2', 'model4'): 23.604851575988587
# ('model1', 'model3', 'model4'): 23.627315492160538
# ('model2', 'model3', 'model4'): 23.598375922521
# ('model1', 'model2', 'model3', 'model4'): 23.60165370535688
#
# 1回目の推論が終了しました。
#
# 推定時間は24
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.7143144288382091
# Fold 1 RMSLE for model2 = 0.7122928601326396
# Fold 1 RMSLE for model3 = 0.7131966119650399
# Fold 1 RMSLE for model4 = 0.7136639184338422
# Fold 1 RMSLE for ('model1', 'model2') = 0.7107872906991958
# Fold 1 RMSLE for ('model1', 'model3') = 0.7135404194659565
# Fold 1 RMSLE for ('model1', 'model4') = 0.7133723650181638
# Fold 1 RMSLE for ('model2', 'model3') = 0.7105922634877073
# Fold 1 RMSLE for ('model2', 'model4') = 0.7114542173299581
# Fold 1 RMSLE for ('model3', 'model4') = 0.7127869644545206
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.7110980431166076
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.7113540154970535
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.7130693104631286
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.7111311947670363
# Fold 1 RMSLE for all models ensemble = 0.7114503584714664
# Fold 1 best combination: ('model2', 'model3') with RMSLE = 0.7105922634877073
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.7978555526828547
# Fold 2 RMSLE for model2 = 0.8023376443163284
# Fold 2 RMSLE for model3 = 0.7896194348740118
# Fold 2 RMSLE for model4 = 0.7985550535661127
# Fold 2 RMSLE for ('model1', 'model2') = 0.7980799264084878
# Fold 2 RMSLE for ('model1', 'model3') = 0.7932629100240023
# Fold 2 RMSLE for ('model1', 'model4') = 0.7971835413703197
# Fold 2 RMSLE for ('model2', 'model3') = 0.7944076168696861
# Fold 2 RMSLE for ('model2', 'model4') = 0.7992759549310032
# Fold 2 RMSLE for ('model3', 'model4') = 0.7934801126947146
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.7947960095587479
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.7977114158491958
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.7944075935349311
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.7953482878909804
# Fold 2 RMSLE for all models ensemble = 0.7953743322249424
# Fold 2 best combination: model3 with RMSLE = 0.7896194348740118
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.6588903260995882
# Fold 3 RMSLE for model2 = 0.6728714230034516
# Fold 3 RMSLE for model3 = 0.6650532446697484
# Fold 3 RMSLE for model4 = 0.6674555410408753
# Fold 3 RMSLE for ('model1', 'model2') = 0.6640716704038806
# Fold 3 RMSLE for ('model1', 'model3') = 0.6616935143523037
# Fold 3 RMSLE for ('model1', 'model4') = 0.6623786593050852
# Fold 3 RMSLE for ('model2', 'model3') = 0.667532550241111
# Fold 3 RMSLE for ('model2', 'model4') = 0.6688999255121851
# Fold 3 RMSLE for ('model3', 'model4') = 0.6654426180626248
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.6640388669848021
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.6646858752954542
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.6629614965454818
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.6669011342900316
# Fold 3 RMSLE for all models ensemble = 0.6644684166518906
# Fold 3 best combination: model1 with RMSLE = 0.6588903260995882
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.7550898295951972
# Fold 4 RMSLE for model2 = 0.7424098965617985
# Fold 4 RMSLE for model3 = 0.7499291027981483
# Fold 4 RMSLE for model4 = 0.7517616810547362
# Fold 4 RMSLE for ('model1', 'model2') = 0.7475172403462919
# Fold 4 RMSLE for ('model1', 'model3') = 0.7523000197042704
# Fold 4 RMSLE for ('model1', 'model4') = 0.7528214396549945
# Fold 4 RMSLE for ('model2', 'model3') = 0.7450812306122773
# Fold 4 RMSLE for ('model2', 'model4') = 0.7458421221896687
# Fold 4 RMSLE for ('model3', 'model4') = 0.7503904672654369
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.7480201104960932
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.7483857986829555
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.7516962473806686
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.7467959501456102
# Fold 4 RMSLE for all models ensemble = 0.7485909486769942
# Fold 4 best combination: model2 with RMSLE = 0.7424098965617985
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.8883262611847881
# Fold 5 RMSLE for model2 = 0.8794255007322108
# Fold 5 RMSLE for model3 = 0.8845532838308239
# Fold 5 RMSLE for model4 = 0.880282937267802
# Fold 5 RMSLE for ('model1', 'model2') = 0.8826468476852191
# Fold 5 RMSLE for ('model1', 'model3') = 0.8862698203630865
# Fold 5 RMSLE for ('model1', 'model4') = 0.8838856920219494
# Fold 5 RMSLE for ('model2', 'model3') = 0.8809649280893515
# Fold 5 RMSLE for ('model2', 'model4') = 0.8791092533893656
# Fold 5 RMSLE for ('model3', 'model4') = 0.8820672676997174
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.8830256166527534
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.8816146177103348
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.8839700217957991
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.880478280490735
# Fold 5 RMSLE for all models ensemble = 0.882162946644612
# Fold 5 best combination: ('model2', 'model4') with RMSLE = 0.8791092533893656
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.8569584865568053
# Fold 6 RMSLE for model2 = 0.8600708501473069
# Fold 6 RMSLE for model3 = 0.8474471837204942
# Fold 6 RMSLE for model4 = 0.8523745171679155
# Fold 6 RMSLE for ('model1', 'model2') = 0.8565609132815998
# Fold 6 RMSLE for ('model1', 'model3') = 0.8518908159029073
# Fold 6 RMSLE for ('model1', 'model4') = 0.853799609151035
# Fold 6 RMSLE for ('model2', 'model3') = 0.8521768685895806
# Fold 6 RMSLE for ('model2', 'model4') = 0.8548997195441457
# Fold 6 RMSLE for ('model3', 'model4') = 0.8493856451216357
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.8531128268398179
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.8546249061838397
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.8515021981077079
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.8517712764137678
# Fold 6 RMSLE for all models ensemble = 0.8525694798478956
# Fold 6 best combination: model3 with RMSLE = 0.8474471837204942
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.7724805081155929
# Fold 7 RMSLE for model2 = 0.7550351954907378
# Fold 7 RMSLE for model3 = 0.7601144641219499
# Fold 7 RMSLE for model4 = 0.7696712714682282
# Fold 7 RMSLE for ('model1', 'model2') = 0.7619583050763826
# Fold 7 RMSLE for ('model1', 'model3') = 0.7659577427238032
# Fold 7 RMSLE for ('model1', 'model4') = 0.7700399029103244
# Fold 7 RMSLE for ('model2', 'model3') = 0.7552825126454675
# Fold 7 RMSLE for ('model2', 'model4') = 0.7612927599637691
# Fold 7 RMSLE for ('model3', 'model4') = 0.7636394807960417
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.7605783840785189
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.7639979756021241
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.7662533588645104
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.7595618895511306
# Fold 7 RMSLE for all models ensemble = 0.7623828923429853
# Fold 7 best combination: model2 with RMSLE = 0.7550351954907378
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.7609185566990933
# Fold 8 RMSLE for model2 = 0.7669177099490205
# Fold 8 RMSLE for model3 = 0.7607336499258367
# Fold 8 RMSLE for model4 = 0.7591369552299497
# Fold 8 RMSLE for ('model1', 'model2') = 0.7612977025184057
# Fold 8 RMSLE for ('model1', 'model3') = 0.7602741551486416
# Fold 8 RMSLE for ('model1', 'model4') = 0.7584791168565392
# Fold 8 RMSLE for ('model2', 'model3') = 0.7618139358602934
# Fold 8 RMSLE for ('model2', 'model4') = 0.7615936860567478
# Fold 8 RMSLE for ('model3', 'model4') = 0.7591623525534796
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.7605502622195094
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.7598325897690923
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.75898599777321
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.7603861734838878
# Fold 8 RMSLE for all models ensemble = 0.759689448570515
# Fold 8 best combination: ('model1', 'model4') with RMSLE = 0.7584791168565392
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.8652144007436373
# Fold 9 RMSLE for model2 = 0.852817496582408
# Fold 9 RMSLE for model3 = 0.865021146550765
# Fold 9 RMSLE for model4 = 0.8639348837523996
# Fold 9 RMSLE for ('model1', 'model2') = 0.8576503784571946
# Fold 9 RMSLE for ('model1', 'model3') = 0.8649717915350553
# Fold 9 RMSLE for ('model1', 'model4') = 0.8640875492385593
# Fold 9 RMSLE for ('model2', 'model3') = 0.8578331409895609
# Fold 9 RMSLE for ('model2', 'model4') = 0.8574063932080858
# Fold 9 RMSLE for ('model3', 'model4') = 0.8640396892899337
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.8598654321742776
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.859402352091805
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.8642473465408029
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.8594836481172273
# Fold 9 RMSLE for all models ensemble = 0.860625690367199
# Fold 9 best combination: model2 with RMSLE = 0.852817496582408
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.9064105834294476
# Fold 10 RMSLE for model2 = 0.9134708805092798
# Fold 10 RMSLE for model3 = 0.9027117595818773
# Fold 10 RMSLE for model4 = 0.903473879938659
# Fold 10 RMSLE for ('model1', 'model2') = 0.9080722653951548
# Fold 10 RMSLE for ('model1', 'model3') = 0.9043757930699459
# Fold 10 RMSLE for ('model1', 'model4') = 0.9040997517261903
# Fold 10 RMSLE for ('model2', 'model3') = 0.9062707612880903
# Fold 10 RMSLE for ('model2', 'model4') = 0.9076197424096996
# Fold 10 RMSLE for ('model3', 'model4') = 0.9022773898424339
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.905806719156866
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.9062000356329023
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.9033795793464252
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.9050007052812755
# Fold 10 RMSLE for all models ensemble = 0.9049185832508053
# Fold 10 best combination: ('model3', 'model4') with RMSLE = 0.9022773898424339
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.7498416593654181
# Fold 11 RMSLE for model2 = 0.7470668254073239
# Fold 11 RMSLE for model3 = 0.7536657613556047
# Fold 11 RMSLE for model4 = 0.7505880513280428
# Fold 11 RMSLE for ('model1', 'model2') = 0.7458874004366336
# Fold 11 RMSLE for ('model1', 'model3') = 0.751527724506477
# Fold 11 RMSLE for ('model1', 'model4') = 0.7491557336725868
# Fold 11 RMSLE for ('model2', 'model3') = 0.7480008949201085
# Fold 11 RMSLE for ('model2', 'model4') = 0.7470264264597261
# Fold 11 RMSLE for ('model3', 'model4') = 0.7510364829284736
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.7479011862609831
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.7467536748765573
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.7503095001941047
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.7481039093765164
# Fold 11 RMSLE for all models ensemble = 0.7480145283420184
# Fold 11 best combination: ('model1', 'model2') with RMSLE = 0.7458874004366336
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.8818438084617336
# Fold 12 RMSLE for model2 = 0.8673905008847141
# Fold 12 RMSLE for model3 = 0.8837023911971842
# Fold 12 RMSLE for model4 = 0.8699748673212767
# Fold 12 RMSLE for ('model1', 'model2') = 0.8727568953679384
# Fold 12 RMSLE for ('model1', 'model3') = 0.8825308098236512
# Fold 12 RMSLE for ('model1', 'model4') = 0.875334495309754
# Fold 12 RMSLE for ('model2', 'model3') = 0.8739912092991272
# Fold 12 RMSLE for ('model2', 'model4') = 0.8673834175383741
# Fold 12 RMSLE for ('model3', 'model4') = 0.8762516990582745
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.8760237662104772
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.8714104293315428
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.8778836867840313
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.8721604211011186
# Fold 12 RMSLE for all models ensemble = 0.8742006190873387
# Fold 12 best combination: ('model2', 'model4') with RMSLE = 0.8673834175383741
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.7369285308081325
# Fold 13 RMSLE for model2 = 0.7309720193706434
# Fold 13 RMSLE for model3 = 0.7347310408680615
# Fold 13 RMSLE for model4 = 0.7446975260760839
# Fold 13 RMSLE for ('model1', 'model2') = 0.7312626548796962
# Fold 13 RMSLE for ('model1', 'model3') = 0.7356697732702455
# Fold 13 RMSLE for ('model1', 'model4') = 0.7397485931724287
# Fold 13 RMSLE for ('model2', 'model3') = 0.7305955750486943
# Fold 13 RMSLE for ('model2', 'model4') = 0.7363592804873446
# Fold 13 RMSLE for ('model3', 'model4') = 0.7387361665855254
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.7319446294710037
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.7352122904276506
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.7378052072148765
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.734709302406703
# Fold 13 RMSLE for all models ensemble = 0.7346793764674683
# Fold 13 best combination: ('model2', 'model3') with RMSLE = 0.7305955750486943
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.9075913411254732
# Fold 14 RMSLE for model2 = 0.8726360493640078
# Fold 14 RMSLE for model3 = 0.8981469060482055
# Fold 14 RMSLE for model4 = 0.8968855626111861
# Fold 14 RMSLE for ('model1', 'model2') = 0.8882172521904629
# Fold 14 RMSLE for ('model1', 'model3') = 0.9025997785890347
# Fold 14 RMSLE for ('model1', 'model4') = 0.9015385914286642
# Fold 14 RMSLE for ('model2', 'model3') = 0.883784673562695
# Fold 14 RMSLE for ('model2', 'model4') = 0.883509337182969
# Fold 14 RMSLE for ('model3', 'model4') = 0.8969071943809723
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.8911218150801282
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.8906640744534284
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.9001733912883602
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.8876849542408771
# Fold 14 RMSLE for all models ensemble = 0.8922375027568716
# Fold 14 best combination: model2 with RMSLE = 0.8726360493640078
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.6779635469072037
# Fold 15 RMSLE for model2 = 0.6696170695764054
# Fold 15 RMSLE for model3 = 0.6751467523944091
# Fold 15 RMSLE for model4 = 0.673983795016182
# Fold 15 RMSLE for ('model1', 'model2') = 0.6718307791108168
# Fold 15 RMSLE for ('model1', 'model3') = 0.6762654285069417
# Fold 15 RMSLE for ('model1', 'model4') = 0.675386032989917
# Fold 15 RMSLE for ('model2', 'model3') = 0.6707839150736414
# Fold 15 RMSLE for ('model2', 'model4') = 0.6706987099093832
# Fold 15 RMSLE for ('model3', 'model4') = 0.6738579179473939
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.6725346431952578
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.6722336604702397
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.6749939097032217
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.6714019281426401
# Fold 15 RMSLE for all models ensemble = 0.6726181477614535
# Fold 15 best combination: model2 with RMSLE = 0.6696170695764054
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.6997799337596315
# Fold 16 RMSLE for model2 = 0.7053250875961196
# Fold 16 RMSLE for model3 = 0.703739036373545
# Fold 16 RMSLE for model4 = 0.6942240638091253
# Fold 16 RMSLE for ('model1', 'model2') = 0.7010455224326341
# Fold 16 RMSLE for ('model1', 'model3') = 0.7014134696024887
# Fold 16 RMSLE for ('model1', 'model4') = 0.696283917854091
# Fold 16 RMSLE for ('model2', 'model3') = 0.703082306386007
# Fold 16 RMSLE for ('model2', 'model4') = 0.6984901663176274
# Fold 16 RMSLE for ('model3', 'model4') = 0.698365959168227
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.7014791967900587
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.6982148697653731
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.6985016513643888
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.6996057507547224
# Fold 16 RMSLE for all models ensemble = 0.6992852906064678
# Fold 16 best combination: model4 with RMSLE = 0.6942240638091253
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.8082574278220078
# Fold 17 RMSLE for model2 = 0.8003137373122894
# Fold 17 RMSLE for model3 = 0.8041796929912643
# Fold 17 RMSLE for model4 = 0.8156121145405062
# Fold 17 RMSLE for ('model1', 'model2') = 0.8028807201381277
# Fold 17 RMSLE for ('model1', 'model3') = 0.8059911032387397
# Fold 17 RMSLE for ('model1', 'model4') = 0.8111858254023622
# Fold 17 RMSLE for ('model2', 'model3') = 0.8010862143434985
# Fold 17 RMSLE for ('model2', 'model4') = 0.8068994240512413
# Fold 17 RMSLE for ('model3', 'model4') = 0.8091385233486419
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.8030100181097065
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.8066323015685766
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.8085782335739248
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.8053773191018707
# Fold 17 RMSLE for all models ensemble = 0.8057507961852172
# Fold 17 best combination: model2 with RMSLE = 0.8003137373122894
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.7654350966339906
# Fold 18 RMSLE for model2 = 0.7599799597390646
# Fold 18 RMSLE for model3 = 0.7678784442306942
# Fold 18 RMSLE for model4 = 0.7600214667625699
# Fold 18 RMSLE for ('model1', 'model2') = 0.7610970645497843
# Fold 18 RMSLE for ('model1', 'model3') = 0.7664305784794149
# Fold 18 RMSLE for ('model1', 'model4') = 0.7620301846384943
# Fold 18 RMSLE for ('model2', 'model3') = 0.7626306001532366
# Fold 18 RMSLE for ('model2', 'model4') = 0.7590497472389589
# Fold 18 RMSLE for ('model3', 'model4') = 0.7634373430942093
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.7630394114083876
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.7603630707830752
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.7638068996971932
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.7613989053313763
# Fold 18 RMSLE for all models ensemble = 0.7620052366356252
# Fold 18 best combination: ('model2', 'model4') with RMSLE = 0.7590497472389589
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.79803484279379
# Fold 19 RMSLE for model2 = 0.7883063093539656
# Fold 19 RMSLE for model3 = 0.793899954026735
# Fold 19 RMSLE for model4 = 0.7923145161072539
# Fold 19 RMSLE for ('model1', 'model2') = 0.7917616638450903
# Fold 19 RMSLE for ('model1', 'model3') = 0.795693956324421
# Fold 19 RMSLE for ('model1', 'model4') = 0.7946603872807824
# Fold 19 RMSLE for ('model2', 'model3') = 0.7895542272732838
# Fold 19 RMSLE for ('model2', 'model4') = 0.7892548523958685
# Fold 19 RMSLE for ('model3', 'model4') = 0.7924967514945277
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.7919793448244287
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.7915618037075817
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.7941285494175945
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.7900783742455534
# Fold 19 RMSLE for all models ensemble = 0.7917871869699503
# Fold 19 best combination: model2 with RMSLE = 0.7883063093539656
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.8286477897907149
# Fold 20 RMSLE for model2 = 0.8392012571227239
# Fold 20 RMSLE for model3 = 0.8289287759922368
# Fold 20 RMSLE for model4 = 0.8355489963742198
# Fold 20 RMSLE for ('model1', 'model2') = 0.8301639343029162
# Fold 20 RMSLE for ('model1', 'model3') = 0.8284704009755588
# Fold 20 RMSLE for ('model1', 'model4') = 0.830845271096071
# Fold 20 RMSLE for ('model2', 'model3') = 0.8312120556262662
# Fold 20 RMSLE for ('model2', 'model4') = 0.8356686132652912
# Fold 20 RMSLE for ('model3', 'model4') = 0.831287269324132
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.8291733870026092
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.8314788818888091
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.8299196864532634
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.832109258054219
# Fold 20 RMSLE for all models ensemble = 0.8303678083741841
# Fold 20 best combination: ('model1', 'model3') with RMSLE = 0.8284704009755588
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.8074497652877337
# Fold 21 RMSLE for model2 = 0.8045887472919145
# Fold 21 RMSLE for model3 = 0.8024480184975733
# Fold 21 RMSLE for model4 = 0.8014370992146648
# Fold 21 RMSLE for ('model1', 'model2') = 0.8043673816263499
# Fold 21 RMSLE for ('model1', 'model3') = 0.8046519533013808
# Fold 21 RMSLE for ('model1', 'model4') = 0.8034945020716282
# Fold 21 RMSLE for ('model2', 'model3') = 0.801897475483077
# Fold 21 RMSLE for ('model2', 'model4') = 0.8017872516388636
# Fold 21 RMSLE for ('model3', 'model4') = 0.8010251976206004
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.8032423079975755
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.8027904656583711
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.8028171800723706
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.8011510887149506
# Fold 21 RMSLE for all models ensemble = 0.802315022216561
# Fold 21 best combination: ('model3', 'model4') with RMSLE = 0.8010251976206004
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.7355390147815445
# Fold 22 RMSLE for model2 = 0.7404441091843821
# Fold 22 RMSLE for model3 = 0.7346390678749332
# Fold 22 RMSLE for model4 = 0.7376002447944279
# Fold 22 RMSLE for ('model1', 'model2') = 0.7361353029453623
# Fold 22 RMSLE for ('model1', 'model3') = 0.7348798407417628
# Fold 22 RMSLE for ('model1', 'model4') = 0.736084179547444
# Fold 22 RMSLE for ('model2', 'model3') = 0.7360655766472192
# Fold 22 RMSLE for ('model2', 'model4') = 0.7378981957672099
# Fold 22 RMSLE for ('model3', 'model4') = 0.7357469996002658
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.7352984813635044
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.7363201418422661
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.7354515971457259
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.7362392086705394
# Fold 22 RMSLE for all models ensemble = 0.7356734178351152
# Fold 22 best combination: model3 with RMSLE = 0.7346390678749332
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.8316375178269384
# Fold 23 RMSLE for model2 = 0.8178160520701742
# Fold 23 RMSLE for model3 = 0.835407660974779
# Fold 23 RMSLE for model4 = 0.8260166004122103
# Fold 23 RMSLE for ('model1', 'model2') = 0.8231498937510001
# Fold 23 RMSLE for ('model1', 'model3') = 0.8332275247933307
# Fold 23 RMSLE for ('model1', 'model4') = 0.8282060905654508
# Fold 23 RMSLE for ('model2', 'model3') = 0.8254264242086611
# Fold 23 RMSLE for ('model2', 'model4') = 0.8208548262513264
# Fold 23 RMSLE for ('model3', 'model4') = 0.8302489301826673
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.8269314451531209
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.823708916157131
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.8304079684330754
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.8252101668551728
# Fold 23 RMSLE for all models ensemble = 0.8264210757702036
# Fold 23 best combination: model2 with RMSLE = 0.8178160520701742
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.7541652829900052
# Fold 24 RMSLE for model2 = 0.7508109255778598
# Fold 24 RMSLE for model3 = 0.7531989639112683
# Fold 24 RMSLE for model4 = 0.7485109581992824
# Fold 24 RMSLE for ('model1', 'model2') = 0.7499363390627366
# Fold 24 RMSLE for ('model1', 'model3') = 0.7535279621502677
# Fold 24 RMSLE for ('model1', 'model4') = 0.7506518660470523
# Fold 24 RMSLE for ('model2', 'model3') = 0.7495796732080966
# Fold 24 RMSLE for ('model2', 'model4') = 0.7479494381038847
# Fold 24 RMSLE for ('model3', 'model4') = 0.7501497280932946
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.7504460419150253
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.7489617569118042
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.7512719810468984
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.7486874642608425
# Fold 24 RMSLE for all models ensemble = 0.7496132273607078
# Fold 24 best combination: ('model2', 'model4') with RMSLE = 0.7479494381038847
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.7930926158043776
# Fold 25 RMSLE for model2 = 0.7899215487217541
# Fold 25 RMSLE for model3 = 0.7926300480894736
# Fold 25 RMSLE for model4 = 0.7974911706967245
# Fold 25 RMSLE for ('model1', 'model2') = 0.7895892488920585
# Fold 25 RMSLE for ('model1', 'model3') = 0.7927177309845757
# Fold 25 RMSLE for ('model1', 'model4') = 0.7946791782094526
# Fold 25 RMSLE for ('model2', 'model3') = 0.7896163146020128
# Fold 25 RMSLE for ('model2', 'model4') = 0.7925797356342982
# Fold 25 RMSLE for ('model3', 'model4') = 0.7944978288337308
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.790228636789389
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.7918775960839461
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.7938179424368579
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.7918601751552912
# Fold 25 RMSLE for all models ensemble = 0.7917792756658947
# Fold 25 best combination: ('model1', 'model2') with RMSLE = 0.7895892488920585
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.8027129513937489
# Fold 26 RMSLE for model2 = 0.8149001861845591
# Fold 26 RMSLE for model3 = 0.8118982850799829
# Fold 26 RMSLE for model4 = 0.8051453695102647
# Fold 26 RMSLE for ('model1', 'model2') = 0.8072186484721809
# Fold 26 RMSLE for ('model1', 'model3') = 0.8070006243874416
# Fold 26 RMSLE for ('model1', 'model4') = 0.8030834225105016
# Fold 26 RMSLE for ('model2', 'model3') = 0.8119266727135743
# Fold 26 RMSLE for ('model2', 'model4') = 0.808886127720587
# Fold 26 RMSLE for ('model3', 'model4') = 0.8077476663662411
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.8083397444043828
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.8059981615957977
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.8057302526113735
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.809143011889557
# Fold 26 RMSLE for all models ensemble = 0.8071320796062328
# Fold 26 best combination: model1 with RMSLE = 0.8027129513937489
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.7684344993983893
# Fold 27 RMSLE for model2 = 0.7872264003394556
# Fold 27 RMSLE for model3 = 0.769024252600894
# Fold 27 RMSLE for model4 = 0.7710500158272315
# Fold 27 RMSLE for ('model1', 'model2') = 0.7759109621180924
# Fold 27 RMSLE for ('model1', 'model3') = 0.7685444176605386
# Fold 27 RMSLE for ('model1', 'model4') = 0.7689624978655442
# Fold 27 RMSLE for ('model2', 'model3') = 0.7761188662215361
# Fold 27 RMSLE for ('model2', 'model4') = 0.7777712955351582
# Fold 27 RMSLE for ('model3', 'model4') = 0.7691370070594269
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.7730617384654962
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.7737600990189311
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.7686737723179518
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.7738647484311844
# Fold 27 RMSLE for all models ensemble = 0.772139135405475
# Fold 27 best combination: model1 with RMSLE = 0.7684344993983893
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.7915706798257877
# Fold 28 RMSLE for model2 = 0.779131764918911
# Fold 28 RMSLE for model3 = 0.7880383794148439
# Fold 28 RMSLE for model4 = 0.7761334602127824
# Fold 28 RMSLE for ('model1', 'model2') = 0.7838477232246521
# Fold 28 RMSLE for ('model1', 'model3') = 0.7895456361617985
# Fold 28 RMSLE for ('model1', 'model4') = 0.7832462411173379
# Fold 28 RMSLE for ('model2', 'model3') = 0.7821630951368246
# Fold 28 RMSLE for ('model2', 'model4') = 0.776340920547962
# Fold 28 RMSLE for ('model3', 'model4') = 0.7816116831687041
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.784834005948519
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.7807670738914594
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.7846530343370922
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.7796844575218347
# Fold 28 RMSLE for all models ensemble = 0.7823308686965837
# Fold 28 best combination: model4 with RMSLE = 0.7761334602127824
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.8284873735348315
# Fold 29 RMSLE for model2 = 0.7987910038802171
# Fold 29 RMSLE for model3 = 0.8222091363930377
# Fold 29 RMSLE for model4 = 0.8079616717395629
# Fold 29 RMSLE for ('model1', 'model2') = 0.8116972463329671
# Fold 29 RMSLE for ('model1', 'model3') = 0.8250895321416146
# Fold 29 RMSLE for ('model1', 'model4') = 0.8173769264535558
# Fold 29 RMSLE for ('model2', 'model3') = 0.8090222040652428
# Fold 29 RMSLE for ('model2', 'model4') = 0.8017437882418685
# Fold 29 RMSLE for ('model3', 'model4') = 0.8144893586875342
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.8148675469799469
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.8097833583649685
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.8187973234991924
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.8080095421213654
# Fold 29 RMSLE for all models ensemble = 0.8126790539370435
# Fold 29 best combination: model2 with RMSLE = 0.7987910038802171
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.778446782407416
# Fold 30 RMSLE for model2 = 0.7722863012009784
# Fold 30 RMSLE for model3 = 0.773874447705157
# Fold 30 RMSLE for model4 = 0.7764065454424308
# Fold 30 RMSLE for ('model1', 'model2') = 0.7716971377298568
# Fold 30 RMSLE for ('model1', 'model3') = 0.7757602455867929
# Fold 30 RMSLE for ('model1', 'model4') = 0.7763574658034855
# Fold 30 RMSLE for ('model2', 'model3') = 0.7706701569399425
# Fold 30 RMSLE for ('model2', 'model4') = 0.7727218331366119
# Fold 30 RMSLE for ('model3', 'model4') = 0.7744243967930179
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.7719905370729624
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.7728858637967823
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.7752708417567266
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.7720782745701361
# Fold 30 RMSLE for all models ensemble = 0.7727821265296168
# Fold 30 best combination: ('model2', 'model3') with RMSLE = 0.7706701569399425
# ---------------
#
# OOF RMSLE = 0.784247240812403
# Sum of RMSLE for each combination:
# ('model1',): 23.722319394664076
# ('model2',): 23.594375312522644
# ('model3',): 23.66576689805858
# ('model4',): 23.64191473491655
# ('model1', 'model2'): 23.599096311681176
# ('model1', 'model3'): 23.686075473516443
# ('model1', 'model4'): 23.658459030289762
# ('model2', 'model3'): 23.57916393958588
# ('model2', 'model4'): 23.580267161959185
# ('model3', 'model4'): 23.6332660915164
# ('model1', 'model2', 'model3'): 23.608340155720956
# ('model1', 'model2', 'model4'): 23.599188072909055
# ('model1', 'model3', 'model4'): 23.65346575970089
# ('model2', 'model3', 'model4'): 23.58541680137815
# ('model1', 'model2', 'model3', 'model4'): 23.606044873259332
#
# 2回目の推論が終了しました。
#
# 推定時間は22
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.7140405524061081
# Fold 1 RMSLE for model2 = 0.7164132620438735
# Fold 1 RMSLE for model3 = 0.7132898782051429
# Fold 1 RMSLE for model4 = 0.705776948459507
# Fold 1 RMSLE for ('model1', 'model2') = 0.7136743289702229
# Fold 1 RMSLE for ('model1', 'model3') = 0.7134525435877079
# Fold 1 RMSLE for ('model1', 'model4') = 0.7092099388441655
# Fold 1 RMSLE for ('model2', 'model3') = 0.7133501417345852
# Fold 1 RMSLE for ('model2', 'model4') = 0.7100485624047025
# Fold 1 RMSLE for ('model3', 'model4') = 0.7088579471399983
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.7131286073597818
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.7106094419696793
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.7103312195267902
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.7103924100475123
# Fold 1 RMSLE for all models ensemble = 0.710956851763227
# Fold 1 best combination: model4 with RMSLE = 0.705776948459507
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.8001660080230265
# Fold 2 RMSLE for model2 = 0.7909672823314343
# Fold 2 RMSLE for model3 = 0.789411719311282
# Fold 2 RMSLE for model4 = 0.7943220014310077
# Fold 2 RMSLE for ('model1', 'model2') = 0.7920072115697874
# Fold 2 RMSLE for ('model1', 'model3') = 0.7943412963135519
# Fold 2 RMSLE for ('model1', 'model4') = 0.7960309108881328
# Fold 2 RMSLE for ('model2', 'model3') = 0.7874109319301225
# Fold 2 RMSLE for ('model2', 'model4') = 0.7909698587408746
# Fold 2 RMSLE for ('model3', 'model4') = 0.7911921913796748
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.7904999986470074
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.7922859670841609
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.7935944678109619
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.7892887065915777
# Fold 2 RMSLE for all models ensemble = 0.7911299692148311
# Fold 2 best combination: ('model2', 'model3') with RMSLE = 0.7874109319301225
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.6658584064246229
# Fold 3 RMSLE for model2 = 0.6758602948950583
# Fold 3 RMSLE for model3 = 0.6676385080331372
# Fold 3 RMSLE for model4 = 0.6741486770064258
# Fold 3 RMSLE for ('model1', 'model2') = 0.6689577650348045
# Fold 3 RMSLE for ('model1', 'model3') = 0.6664675328983237
# Fold 3 RMSLE for ('model1', 'model4') = 0.6687977636980377
# Fold 3 RMSLE for ('model2', 'model3') = 0.6701530336842721
# Fold 3 RMSLE for ('model2', 'model4') = 0.6739126026029629
# Fold 3 RMSLE for ('model3', 'model4') = 0.6698044982758798
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.6681033251327302
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.6700896747590609
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.6680689348756391
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.6708701354146864
# Fold 3 RMSLE for all models ensemble = 0.6690831744527251
# Fold 3 best combination: model1 with RMSLE = 0.6658584064246229
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.7476489139968582
# Fold 4 RMSLE for model2 = 0.7400115509283474
# Fold 4 RMSLE for model3 = 0.7453921979533256
# Fold 4 RMSLE for model4 = 0.7552210912027288
# Fold 4 RMSLE for ('model1', 'model2') = 0.7424220712555464
# Fold 4 RMSLE for ('model1', 'model3') = 0.7463284694516799
# Fold 4 RMSLE for ('model1', 'model4') = 0.7509119040418164
# Fold 4 RMSLE for ('model2', 'model3') = 0.7412872389935722
# Fold 4 RMSLE for ('model2', 'model4') = 0.7465356358316894
# Fold 4 RMSLE for ('model3', 'model4') = 0.7497917054168035
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.7430125186219886
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.7462903672042975
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.7488734183660056
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.7455388647905173
# Fold 4 RMSLE for all models ensemble = 0.7457870041200171
# Fold 4 best combination: model2 with RMSLE = 0.7400115509283474
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.885791071765999
# Fold 5 RMSLE for model2 = 0.8668820208021085
# Fold 5 RMSLE for model3 = 0.8832184154731949
# Fold 5 RMSLE for model4 = 0.8736565812060808
# Fold 5 RMSLE for ('model1', 'model2') = 0.8751137051679354
# Fold 5 RMSLE for ('model1', 'model3') = 0.8842876709591191
# Fold 5 RMSLE for ('model1', 'model4') = 0.8792241019700651
# Fold 5 RMSLE for ('model2', 'model3') = 0.8741506377335501
# Fold 5 RMSLE for ('model2', 'model4') = 0.8693920980574458
# Fold 5 RMSLE for ('model3', 'model4') = 0.8780596957646758
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.8775931129911465
# ...
# Fold 15 RMSLE for ('model3', 'model4') = 0.6905192326727043
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.691740296467852
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.6904595800833624
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.691367543933077
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.6902887797630141
# Fold 15 RMSLE for all models ensemble = 0.690808504774017
# Fold 15 best combination: model4 with RMSLE = 0.6888330014314592
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.6858218254144111
# Fold 16 RMSLE for model2 = 0.6947511658194646
# Fold 16 RMSLE for model3 = 0.691226941291955
# Fold 16 RMSLE for model4 = 0.6834103496876761
# Fold 16 RMSLE for ('model1', 'model2') = 0.6882402912781909
# Fold 16 RMSLE for ('model1', 'model3') = 0.6882326177712514
# Fold 16 RMSLE for ('model1', 'model4') = 0.6833647907862147
# Fold 16 RMSLE for ('model2', 'model3') = 0.6911764090391156
# Fold 16 RMSLE for ('model2', 'model4') = 0.6877580003031345
# Fold 16 RMSLE for ('model3', 'model4') = 0.6860965690918241
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.6887532383508139
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.6859391248128589
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.685591742480394
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.6878577063136283
# Fold 16 RMSLE for all models ensemble = 0.6868138567183499
# Fold 16 best combination: ('model1', 'model4') with RMSLE = 0.6833647907862147
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.8172866805043798
# Fold 17 RMSLE for model2 = 0.8143305586115029
# Fold 17 RMSLE for model3 = 0.8090302424317775
# Fold 17 RMSLE for model4 = 0.8178174279303565
# Fold 17 RMSLE for ('model1', 'model2') = 0.8143303767608423
# Fold 17 RMSLE for ('model1', 'model3') = 0.8129747960763797
# Fold 17 RMSLE for ('model1', 'model4') = 0.8170043290078991
# Fold 17 RMSLE for ('model2', 'model3') = 0.8101295355522175
# Fold 17 RMSLE for ('model2', 'model4') = 0.8153045758387409
# Fold 17 RMSLE for ('model3', 'model4') = 0.812756117791271
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.8121210688491074
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.8152361094814292
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.8140893755479572
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.8123987905356957
# Fold 17 RMSLE for all models ensemble = 0.8133170430945961
# Fold 17 best combination: model3 with RMSLE = 0.8090302424317775
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.764470963758815
# Fold 18 RMSLE for model2 = 0.7693276639485386
# Fold 18 RMSLE for model3 = 0.7688914914856196
# Fold 18 RMSLE for model4 = 0.760510739122069
# Fold 18 RMSLE for ('model1', 'model2') = 0.7657370581278371
# Fold 18 RMSLE for ('model1', 'model3') = 0.7664059580582356
# Fold 18 RMSLE for ('model1', 'model4') = 0.7618510067822529
# Fold 18 RMSLE for ('model2', 'model3') = 0.7681110544547711
# Fold 18 RMSLE for ('model2', 'model4') = 0.7641469834946302
# Fold 18 RMSLE for ('model3', 'model4') = 0.7641167299166577
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.7664803160515271
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.763624817067369
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.7639583424854187
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.7651958762069331
# Fold 18 RMSLE for all models ensemble = 0.7646914514288845
# Fold 18 best combination: model4 with RMSLE = 0.760510739122069
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.8319730395467372
# Fold 19 RMSLE for model2 = 0.7996107207510662
# Fold 19 RMSLE for model3 = 0.8302267621560856
# Fold 19 RMSLE for model4 = 0.8182777981136259
# Fold 19 RMSLE for ('model1', 'model2') = 0.8140022313133131
# Fold 19 RMSLE for ('model1', 'model3') = 0.8307697454070242
# Fold 19 RMSLE for ('model1', 'model4') = 0.8242564605605304
# Fold 19 RMSLE for ('model2', 'model3') = 0.8134059322553983
# Fold 19 RMSLE for ('model2', 'model4') = 0.8078133924137
# Fold 19 RMSLE for ('model3', 'model4') = 0.8234426776890487
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.818996400253393
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.8149375089285928
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.8259341872169242
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.8145050158700857
# Fold 19 RMSLE for all models ensemble = 0.8184162310417595
# Fold 19 best combination: model2 with RMSLE = 0.7996107207510662
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.8280094099215994
# Fold 20 RMSLE for model2 = 0.8384355471400503
# Fold 20 RMSLE for model3 = 0.8318524306777872
# Fold 20 RMSLE for model4 = 0.8332873006248585
# Fold 20 RMSLE for ('model1', 'model2') = 0.83163634210777
# Fold 20 RMSLE for ('model1', 'model3') = 0.8297712182821672
# Fold 20 RMSLE for ('model1', 'model4') = 0.8299498056879221
# Fold 20 RMSLE for ('model2', 'model3') = 0.8337474654936906
# Fold 20 RMSLE for ('model2', 'model4') = 0.8348996397146317
# Fold 20 RMSLE for ('model3', 'model4') = 0.8320264442226686
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.8313672974550151
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.8318006505618679
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.8304265342639717
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.8332347031951993
# Fold 20 RMSLE for all models ensemble = 0.831558211719635
# Fold 20 best combination: model1 with RMSLE = 0.8280094099215994
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.8104182440761636
# Fold 21 RMSLE for model2 = 0.7983458215473376
# Fold 21 RMSLE for model3 = 0.8036035088162624
# Fold 21 RMSLE for model4 = 0.8028357729853839
# Fold 21 RMSLE for ('model1', 'model2') = 0.8024837414233308
# Fold 21 RMSLE for ('model1', 'model3') = 0.8067421702762129
# Fold 21 RMSLE for ('model1', 'model4') = 0.8061441543320678
# Fold 21 RMSLE for ('model2', 'model3') = 0.7989848159241365
# Fold 21 RMSLE for ('model2', 'model4') = 0.7991279403427416
# Fold 21 RMSLE for ('model3', 'model4') = 0.8027004102097849
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.8022777921910337
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.802159378171564
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.8050545526124137
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.799830584152386
# Fold 21 RMSLE for all models ensemble = 0.8021475553913624
# Fold 21 best combination: model2 with RMSLE = 0.7983458215473376
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.7349595568745019
# Fold 22 RMSLE for model2 = 0.7429045796789032
# Fold 22 RMSLE for model3 = 0.7388565580384061
# Fold 22 RMSLE for model4 = 0.7413244276771014
# Fold 22 RMSLE for ('model1', 'model2') = 0.7371154335028757
# Fold 22 RMSLE for ('model1', 'model3') = 0.7366388505273259
# Fold 22 RMSLE for ('model1', 'model4') = 0.737337024577654
# Fold 22 RMSLE for ('model2', 'model3') = 0.7395171998670472
# Fold 22 RMSLE for ('model2', 'model4') = 0.7412627235843213
# Fold 22 RMSLE for ('model3', 'model4') = 0.7396164216348843
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.737372573684502
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.7381860071348617
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.7376919012302883
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.7398330237119056
# Fold 22 RMSLE for all models ensemble = 0.7381156022650959
# Fold 22 best combination: model1 with RMSLE = 0.7349595568745019
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.8541938765394915
# Fold 23 RMSLE for model2 = 0.8396625526923036
# Fold 23 RMSLE for model3 = 0.8557604269609028
# Fold 23 RMSLE for model4 = 0.8523639747651334
# Fold 23 RMSLE for ('model1', 'model2') = 0.8448552390402065
# Fold 23 RMSLE for ('model1', 'model3') = 0.8546152858463688
# Fold 23 RMSLE for ('model1', 'model4') = 0.852705848729957
# Fold 23 RMSLE for ('model2', 'model3') = 0.8463453283643911
# Fold 23 RMSLE for ('model2', 'model4') = 0.8446534796482091
# Fold 23 RMSLE for ('model3', 'model4') = 0.8536805913068208
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.8481866943883717
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.8469621422542001
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.8535210067304143
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.8478835358819171
# Fold 23 RMSLE for all models ensemble = 0.8489699753552487
# Fold 23 best combination: model2 with RMSLE = 0.8396625526923036
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.7376881528457104
# Fold 24 RMSLE for model2 = 0.7453148631382068
# Fold 24 RMSLE for model3 = 0.7401793985525953
# Fold 24 RMSLE for model4 = 0.7363526037129006
# Fold 24 RMSLE for ('model1', 'model2') = 0.739150567625457
# Fold 24 RMSLE for ('model1', 'model3') = 0.7387750427600164
# Fold 24 RMSLE for ('model1', 'model4') = 0.7364865530344868
# Fold 24 RMSLE for ('model2', 'model3') = 0.7405669296404526
# Fold 24 RMSLE for ('model2', 'model4') = 0.7393147589598645
# Fold 24 RMSLE for ('model3', 'model4') = 0.7377060245397874
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.7389739443297481
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.7378253373478142
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.7375168722728034
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.7387202545761821
# Fold 24 RMSLE for all models ensemble = 0.7380550554720128
# Fold 24 best combination: model4 with RMSLE = 0.7363526037129006
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.7864739949974852
# Fold 25 RMSLE for model2 = 0.7824296028078435
# Fold 25 RMSLE for model3 = 0.7842339354230218
# Fold 25 RMSLE for model4 = 0.792611863790488
# Fold 25 RMSLE for ('model1', 'model2') = 0.7814837723261284
# Fold 25 RMSLE for ('model1', 'model3') = 0.7851972662744912
# Fold 25 RMSLE for ('model1', 'model4') = 0.7888622645675761
# Fold 25 RMSLE for ('model2', 'model3') = 0.7807719903377098
# Fold 25 RMSLE for ('model2', 'model4') = 0.7857580581739753
# Fold 25 RMSLE for ('model3', 'model4') = 0.7878619452664314
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.7818543373286534
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.7847698986634102
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.7871510994110398
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.7842573111819056
# Fold 25 RMSLE for all models ensemble = 0.7842680420820529
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.7807719903377098
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.8042282603088173
# Fold 26 RMSLE for model2 = 0.8016091692289957
# Fold 26 RMSLE for model3 = 0.808437112727893
# Fold 26 RMSLE for model4 = 0.8003276671514091
# Fold 26 RMSLE for ('model1', 'model2') = 0.801143979341031
# Fold 26 RMSLE for ('model1', 'model3') = 0.8060522388936122
# Fold 26 RMSLE for ('model1', 'model4') = 0.8017291279181594
# Fold 26 RMSLE for ('model2', 'model3') = 0.803651109742644
# Fold 26 RMSLE for ('model2', 'model4') = 0.7996456825033532
# Fold 26 RMSLE for ('model3', 'model4') = 0.8039266295785135
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.8032363049801048
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.800434133680858
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.803760142083478
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.802057991647694
# Fold 26 RMSLE for all models ensemble = 0.8022125940327545
# Fold 26 best combination: ('model2', 'model4') with RMSLE = 0.7996456825033532
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.7826573007643526
# Fold 27 RMSLE for model2 = 0.7841536201841995
# Fold 27 RMSLE for model3 = 0.7849073435510586
# Fold 27 RMSLE for model4 = 0.784857961437309
# Fold 27 RMSLE for ('model1', 'model2') = 0.7819963742667401
# Fold 27 RMSLE for ('model1', 'model3') = 0.7835672723421668
# Fold 27 RMSLE for ('model1', 'model4') = 0.7833580354144697
# Fold 27 RMSLE for ('model2', 'model3') = 0.7832866063931915
# Fold 27 RMSLE for ('model2', 'model4') = 0.7833681112014586
# Fold 27 RMSLE for ('model3', 'model4') = 0.7842170943976836
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.7826313692644269
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.7825800338573177
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.7835717172394026
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.7832852019646698
# Fold 27 RMSLE for all models ensemble = 0.7828761578094766
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.7819963742667401
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.7837261047209639
# Fold 28 RMSLE for model2 = 0.7973058864407824
# Fold 28 RMSLE for model3 = 0.7831888851876492
# Fold 28 RMSLE for model4 = 0.7817253340183697
# Fold 28 RMSLE for ('model1', 'model2') = 0.7881574372462996
# Fold 28 RMSLE for ('model1', 'model3') = 0.7831027552393753
# Fold 28 RMSLE for ('model1', 'model4') = 0.7813544585913893
# Fold 28 RMSLE for ('model2', 'model3') = 0.7886156549170691
# Fold 28 RMSLE for ('model2', 'model4') = 0.7881610539595754
# Fold 28 RMSLE for ('model3', 'model4') = 0.7816001393522352
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.7861381542051573
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.7853238079277672
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.7817322672612972
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.7856963719244218
# Fold 28 RMSLE for all models ensemble = 0.7845009292228744
# Fold 28 best combination: ('model1', 'model4') with RMSLE = 0.7813544585913893
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.8200669925577059
# Fold 29 RMSLE for model2 = 0.8127933916580699
# Fold 29 RMSLE for model3 = 0.8163484101208377
# Fold 29 RMSLE for model4 = 0.8121185425705558
# Fold 29 RMSLE for ('model1', 'model2') = 0.8148387429013292
# Fold 29 RMSLE for ('model1', 'model3') = 0.8180025089607943
# Fold 29 RMSLE for ('model1', 'model4') = 0.8149453014939084
# Fold 29 RMSLE for ('model2', 'model3') = 0.8130971734601229
# Fold 29 RMSLE for ('model2', 'model4') = 0.8112666449707632
# Fold 29 RMSLE for ('model3', 'model4') = 0.8131943079681161
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.8149506790941167
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.8132463659389341
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.8151158472952912
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.8121075400568052
# Fold 29 RMSLE for all models ensemble = 0.8136706304626874
# Fold 29 best combination: ('model2', 'model4') with RMSLE = 0.8112666449707632
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.7854883118120997
# Fold 30 RMSLE for model2 = 0.7916240139452249
# Fold 30 RMSLE for model3 = 0.7920450525844323
# Fold 30 RMSLE for model4 = 0.7889055192895585
# Fold 30 RMSLE for ('model1', 'model2') = 0.7871093820897949
# Fold 30 RMSLE for ('model1', 'model3') = 0.7882450559117349
# Fold 30 RMSLE for ('model1', 'model4') = 0.7864512169293092
# Fold 30 RMSLE for ('model2', 'model3') = 0.7907330565737309
# Fold 30 RMSLE for ('model2', 'model4') = 0.7891329470543509
# Fold 30 RMSLE for ('model3', 'model4') = 0.7898436368349013
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.7883544763826814
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.7871945707967222
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.7879689679088873
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.7895845826896755
# Fold 30 RMSLE for all models ensemble = 0.7881204911024964
# Fold 30 best combination: model1 with RMSLE = 0.7854883118120997
# ---------------
#
# OOF RMSLE = 0.7874470016172134
# Sum of RMSLE for each combination:
# ('model1',): 23.7764472801649
# ('model2',): 23.750001711676024
# ('model3',): 23.780376758697088
# ('model4',): 23.759655750672305
# ('model1', 'model2'): 23.705667834045286
# ('model1', 'model3'): 23.770289673588714
# ('model1', 'model4'): 23.744464856744415
# ('model2', 'model3'): 23.71564789505827
# ('model2', 'model4'): 23.717626067056543
# ('model3', 'model4'): 23.748872719782
# ('model1', 'model2', 'model3'): 23.717737576113052
# ('model1', 'model2', 'model4'): 23.709432300078763
# ('model1', 'model3', 'model4'): 23.748666277510846
# ('model2', 'model3', 'model4'): 23.715394490053388
# ('model1', 'model2', 'model3', 'model4'): 23.71733099603262
#
# 9回目の推論が終了しました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 7158                     0.000000                     0.000000
# 7159                     0.000000                     0.000000
# 7160                 23592.402994                 25069.498286
# 7161                140816.449347                 93118.705227
# 7162                     0.000000                     0.000000
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                        0.000000           221
# 2                        0.000000             4
# 3                        0.000000            21
# 4                    25153.901905            21
# ...                           ...           ...
# 7158                     0.000000           240
# 7159                     0.000000             4
# 7160                 24560.172725           132
# 7161                130326.946431            98
# 7162                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 7158                           110523.066755
# 7159                                0.000000
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     39415.008265  0.295632
# 1                  14            1     60441.115332 -0.077924
# 2                   9            1    115195.904346 -0.727012
# 3                  15            1     54937.106202  0.111413
# 4                  15            0     54433.002360 -0.233432
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 20 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            54978.841280
# 4651                           208375.435367
# 4652                           563756.090695
# 4653                            67451.225733
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            56463.765036
# 4651                            57066.624445
# 4652                           598881.479485
# 4653                            27397.929966
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 4650                            3.522786e+06
# 4651                            4.858030e+04
# 4652                            1.665103e+06
# 4653                            3.922795e+04
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            76642.640670  32.523334  -97.102556
# 4651                            26892.366779  42.684900 -109.780000
# 4652                           543206.073134  35.484260  -97.498570
# 4653                            46634.777768  39.404310  -76.319820
# 4654                                     NaN        NaN         NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     3.941501e+04  0.295632
# 1                  14            1     6.044112e+04 -0.077924
# 2                   9            1     1.151959e+05 -0.727012
# 3                  15            1     5.493711e+04  0.111413
# 4                  15            0     5.443300e+04 -0.233432
# ...               ...          ...              ...       ...
# 4650                9            1     3.487120e+05  1.950083
# 4651                9            1     4.869719e+04 -0.309351
# 4652                5            1     1.192982e+06 -0.198334
# 4653                1            1     3.734855e+04 -0.315806
# 4654                9            1     7.581548e+04  0.943776
#
# [4655 rows x 20 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.42, -0.00)

# %%
train_df_GHG14
# Out:
# 0         52,973
# 1         55,910
# 2         55,680
# 3         61,412
# 4         43,100
#           ...
# 4650   2,451,197
# 4651      35,740
# 4652     978,359
# 4653      27,234
# 4654     194,822
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                          32,075                       26,446
# 3                          42,504                       43,906
# 4                          39,898                       40,203
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                          23,385           130
# 3                          42,958            82
# 4                          39,437           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           32,876     0
# 1                  14            1          410,900     0
# 2                   8            0           99,701     0
# 3                   8            0           18,062     0
# 4                   8            0           42,950     0
# ...               ...          ...              ...   ...
# 2503                1            1          868,875     0
# 2504                9            1          165,430     0
# 2505                8            0          118,302     0
# 2506                8            0          785,131     0
# 2507                9            1        3,366,301     0
#
# [2508 rows x 20 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 11.44)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 139007.09110181325

# %%
def after_act(preds):
    r = preds.copy()
    r_min = r.min()
    w_min = 10.4-np.log1p(r_min)
    r_max = r.max()
    w_max = np.log1p(r_max)-14.4
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            # print(r[i]-np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w))
            r[i] = np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/w_min)
        # if r[i] > np.expm1(14.4):
            # r[i] = np.expm1(np.log1p(r[i])+0.3*(np.log1p(r[i])-14.4)/w_max)
    return r
after_train_preds = after_act(train_df["oof_predictions"])
after_test_preds = after_act(test_df["oof_predictions"])

# %%
x = train_df["oof_predictions"]
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 285709.86097456433

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_73.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    32,876
# 1     4656   410,900
# 2     4657    99,701
# 3     4658    15,904
# 4     4659    42,950
# ...    ...       ...
# 2503  7158   868,875
# 2504  7159   165,430
# 2505  7160   118,302
# 2506  7161   785,131
# 2507  7162 3,366,301
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 43    4698 4,895,778
# 73    4728 2,158,237
# 114   4769 3,671,704
# 129   4784 1,393,251
# 151   4806 1,152,772
# ...    ...       ...
# 2472  7127 2,522,464
# 2486  7141 2,584,254
# 2490  7145 2,450,965
# 2500  7155 1,330,287
# 2507  7162 3,366,301
#
# [132 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sat Nov 30 06:17:58 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  54,979
# 4651                                 208,375
# 4652                                 563,756
# 4653                                  67,451
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  56,464
# 4651                                  57,067
# 4652                                 598,881
# 4653                                  27,398
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                               3,522,786
# 4651                                  48,580
# 4652                               1,665,103
# 4653                                  39,228
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  76,643        33        -97
# 4651                                  26,892        43       -110
# 4652                                 543,206        35        -97
# 4653                                  46,635        39        -76
# 4654                                     NaN       NaN        NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           39,415     0
# 1                  14            1           60,441    -0
# 2                   9            1          115,196    -1
# 3                  15            1           54,937     0
# 4                  15            0           54,433    -0
# ...               ...          ...              ...   ...
# 4650                9            1          348,712     2
# 4651                9            1           48,697    -0
# 4652                5            1        1,192,982    -0
# 4653                1            1           37,349    -0
# 4654                9            1           75,815     1
#
# [4655 rows x 20 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.7874470016172134

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                          NaN                          NaN
# 4651                          NaN                          NaN
# 4652                          NaN                          NaN
# 4653                          NaN                          NaN
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                          NaN             3
# 4651                          NaN             3
# 4652                          NaN           244
# 4653                          NaN           241
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  54,979
# 4651                                 208,375
# 4652                                 563,756
# 4653                                  67,451
# 4654                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  56,464
# 4651                                  57,067
# 4652                                 598,881
# 4653                                  27,398
# 4654                                     NaN
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                               3,522,786
# 4651                                  48,580
# 4652                               1,665,103
# 4653                                  39,228
# 4654                                     NaN
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  76,643        33        -97
# 4651                                  26,892        43       -110
# 4652                                 543,206        35        -97
# 4653                                  46,635        39        -76
# 4654                                     NaN       NaN        NaN
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                              NaN                              NaN
# 4651                              NaN                              NaN
# 4652                              NaN                              NaN
# 4653                              NaN                              NaN
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                              NaN                               NaN
# 4651                              NaN                               NaN
# 4652                              NaN                               NaN
# 4653                              NaN                               NaN
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                               NaN                               NaN
# 4651                               NaN                               NaN
# 4652                               NaN                               NaN
# 4653                               NaN                               NaN
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           39,415     0
# 1                  14            1           60,441    -0
# 2                   9            1          115,196    -1
# 3                  15            1           54,937     0
# 4                  15            0           54,433    -0
# ...               ...          ...              ...   ...
# 4650                9            1          348,712     2
# 4651                9            1           48,697    -0
# 4652                5            1        1,192,982    -0
# 4653                1            1           37,349    -0
# 4654                9            1           75,815     1
#
# [4655 rows x 20 columns]
