# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/056.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_054.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_054.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions',
#        'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   523,079
# 2504                9            1                                   100,312
# 2505                8            0                                   134,940
# 2506                8            0                                   262,619
# 2507                9            1                                 1,295,969
#
#       oof_predictions
# 0              41,547
# 1              59,347
# 2              99,121
# 3              51,450
# 4              51,060
# ...               ...
# 2503              NaN
# 2504              NaN
# 2505              NaN
# 2506              NaN
# 2507              NaN
#
# [7163 rows x 20 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 1

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   523,079
# 2504                9            1                                   100,312
# 2505                8            0                                   134,940
# 2506                8            0                                   262,619
# 2507                9            1                                 1,295,969
#
#       oof_predictions
# 0              41,547
# 1              59,347
# 2              99,121
# 3              51,450
# 4              51,060
# ...               ...
# 2503              NaN
# 2504              NaN
# 2505              NaN
# 2506              NaN
# 2507              NaN
#
# [7163 rows x 20 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4654, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   523,079
# 2504                9            1                                   100,312
# 2505                8            0                                   134,940
# 2506                8            0                                   262,619
# 2507                9            1                                 1,295,969
#
#       oof_predictions  diff
# 0              41,547     0
# 1              59,347    -0
# 2              99,121    -1
# 3              51,450     0
# 4              51,060    -0
# ...               ...   ...
# 2503              NaN   NaN
# 2504              NaN   NaN
# 2505              NaN   NaN
# 2506              NaN   NaN
# 2507              NaN   NaN
#
# [7163 rows x 21 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                       24,101                       19,192
# 4651                          NaN                          NaN
# 4652                       24,257                       25,344
# 4653                       25,345                       15,031
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           41,547     0
# 1                  14            1           59,347    -0
# 2                   9            1           99,121    -1
# 3                  15            1           51,450     0
# 4                  15            0           51,060    -0
# ...               ...          ...              ...   ...
# 4650               15            0           46,740    -0
# 4651                8            1          170,355     0
# 4652                8            0           31,492    -0
# 4653                8            0           66,290    -0
# 4654                9            1          146,419    -0
#
# [4655 rows x 20 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
oof_predictions,test_preds, _ = get_models_trained(train_all, test, train_all_target, 30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.2430057272262351
# Fold 1 RMSLE for model2 = 0.244827122671894
# Fold 1 RMSLE for model3 = 0.24267935452880482
# Fold 1 RMSLE for model4 = 0.2418586186431331
# Fold 1 RMSLE for ('model1', 'model2') = 0.24356276097990323
# Fold 1 RMSLE for ('model1', 'model3') = 0.2427874956933994
# Fold 1 RMSLE for ('model1', 'model4') = 0.2423339998672801
# Fold 1 RMSLE for ('model2', 'model3') = 0.24346439243925067
# Fold 1 RMSLE for ('model2', 'model4') = 0.24309973407149668
# Fold 1 RMSLE for ('model3', 'model4') = 0.24216299743406322
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.2431937077360788
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.24292124285256841
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.2423993874922263
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.24283786386725506
# Fold 1 RMSLE for all models ensemble = 0.2428060854412716
# Fold 1 best combination: model4 with RMSLE = 0.2418586186431331
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.2449110091904992
# Fold 2 RMSLE for model2 = 0.24800993514031291
# Fold 2 RMSLE for model3 = 0.24528703047716563
# Fold 2 RMSLE for model4 = 0.24491480954387876
# Fold 2 RMSLE for ('model1', 'model2') = 0.24602468075550873
# Fold 2 RMSLE for ('model1', 'model3') = 0.24491631386123885
# Fold 2 RMSLE for ('model1', 'model4') = 0.24481546475108176
# Fold 2 RMSLE for ('model2', 'model3') = 0.24636846231650536
# Fold 2 RMSLE for ('model2', 'model4') = 0.2462065904697346
# Fold 2 RMSLE for ('model3', 'model4') = 0.2449630544437469
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.24566965095985865
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.2455941023012821
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.24485180299148582
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.24577091651618305
# Fold 2 RMSLE for all models ensemble = 0.24543283082434472
# Fold 2 best combination: ('model1', 'model4') with RMSLE = 0.24481546475108176
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.2421993403914424
# Fold 3 RMSLE for model2 = 0.24531649106872758
# Fold 3 RMSLE for model3 = 0.24393463883850117
# Fold 3 RMSLE for model4 = 0.24310619276816903
# Fold 3 RMSLE for ('model1', 'model2') = 0.2434489746067523
# Fold 3 RMSLE for ('model1', 'model3') = 0.2429877132132159
# Fold 3 RMSLE for ('model1', 'model4') = 0.2425094799061504
# Fold 3 RMSLE for ('model2', 'model3') = 0.24439253622612309
# Fold 3 RMSLE for ('model2', 'model4') = 0.2440087459259153
# Fold 3 RMSLE for ('model3', 'model4') = 0.24338207560838157
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.24354049760587096
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.24324947286468343
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.24291964741036723
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.24386388474299386
# Fold 3 RMSLE for all models ensemble = 0.2433625789307887
# Fold 3 best combination: model1 with RMSLE = 0.2421993403914424
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.2480989436447594
# Fold 4 RMSLE for model2 = 0.2515857716314319
# Fold 4 RMSLE for model3 = 0.24846460305445578
# Fold 4 RMSLE for model4 = 0.24812597211786497
# Fold 4 RMSLE for ('model1', 'model2') = 0.24934442290760797
# Fold 4 RMSLE for ('model1', 'model3') = 0.24814844145605247
# Fold 4 RMSLE for ('model1', 'model4') = 0.2479231255624714
# Fold 4 RMSLE for ('model2', 'model3') = 0.24941644862269816
# Fold 4 RMSLE for ('model2', 'model4') = 0.24958146334489456
# Fold 4 RMSLE for ('model3', 'model4') = 0.24796639342966442
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.24883110627246907
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.2488423670412487
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.24794022286048137
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.2488530709608886
# Fold 4 RMSLE for all models ensemble = 0.24855992673829627
# Fold 4 best combination: ('model1', 'model4') with RMSLE = 0.2479231255624714
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.25450586123033603
# Fold 5 RMSLE for model2 = 0.2551969936464153
# Fold 5 RMSLE for model3 = 0.25344126555372554
# Fold 5 RMSLE for model4 = 0.2552645773252784
# Fold 5 RMSLE for ('model1', 'model2') = 0.25451118401892125
# Fold 5 RMSLE for ('model1', 'model3') = 0.2538935453357623
# Fold 5 RMSLE for ('model1', 'model4') = 0.25477970316661647
# Fold 5 RMSLE for ('model2', 'model3') = 0.2540020497119979
# Fold 5 RMSLE for ('model2', 'model4') = 0.2549716902808999
# Fold 5 RMSLE for ('model3', 'model4') = 0.25416200287631496
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.25405346146864344
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.2546758435782217
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.2542365696003865
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.25429329657483785
# Fold 5 RMSLE for all models ensemble = 0.25427882867746343
# Fold 5 best combination: model3 with RMSLE = 0.25344126555372554
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.27239435250083527
# Fold 6 RMSLE for model2 = 0.274600801942137
# Fold 6 RMSLE for model3 = 0.2720260954105544
# Fold 6 RMSLE for model4 = 0.2730002672852609
# Fold 6 RMSLE for ('model1', 'model2') = 0.27314875801362226
# Fold 6 RMSLE for ('model1', 'model3') = 0.27207886557398436
# Fold 6 RMSLE for ('model1', 'model4') = 0.27255482240331314
# Fold 6 RMSLE for ('model2', 'model3') = 0.27289122870381466
# Fold 6 RMSLE for ('model2', 'model4') = 0.2735228618833037
# Fold 6 RMSLE for ('model3', 'model4') = 0.27214494370907805
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.2726056620719584
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.272989844160026
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.27218817367730586
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.2727343137971276
# Fold 6 RMSLE for all models ensemble = 0.27258242802405774
# Fold 6 best combination: model3 with RMSLE = 0.2720260954105544
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.2759522975061023
# Fold 7 RMSLE for model2 = 0.279765634833713
# Fold 7 RMSLE for model3 = 0.2760559341948245
# Fold 7 RMSLE for model4 = 0.27720028792030793
# Fold 7 RMSLE for ('model1', 'model2') = 0.2774428614944588
# Fold 7 RMSLE for ('model1', 'model3') = 0.27591537552252837
# Fold 7 RMSLE for ('model1', 'model4') = 0.2764786874583769
# Fold 7 RMSLE for ('model2', 'model3') = 0.2776129757421859
# Fold 7 RMSLE for ('model2', 'model4') = 0.27820442760353953
# Fold 7 RMSLE for ('model3', 'model4') = 0.2765237790136649
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.27690067227562654
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.2772869267360887
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.27627363422423845
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.27737110799099735
# Fold 7 RMSLE for all models ensemble = 0.2769222313941148
# Fold 7 best combination: ('model1', 'model3') with RMSLE = 0.27591537552252837
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.2730296686966007
# Fold 8 RMSLE for model2 = 0.27467345719725356
# Fold 8 RMSLE for model3 = 0.2736134797836106
# Fold 8 RMSLE for model4 = 0.2729129044998295
# Fold 8 RMSLE for ('model1', 'model2') = 0.2735499443568799
# Fold 8 RMSLE for ('model1', 'model3') = 0.273258917724902
# Fold 8 RMSLE for ('model1', 'model4') = 0.2728863246709238
# Fold 8 RMSLE for ('model2', 'model3') = 0.273902093235025
# Fold 8 RMSLE for ('model2', 'model4') = 0.2735540714015325
# Fold 8 RMSLE for ('model3', 'model4') = 0.2731857973279743
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.27350287733295126
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.27326040315702255
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.27308534667197415
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.2734851952588407
# Fold 8 RMSLE for all models ensemble = 0.27330540243939144
# Fold 8 best combination: ('model1', 'model4') with RMSLE = 0.2728863246709238
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.2754919261670386
# Fold 9 RMSLE for model2 = 0.27631536773007265
# Fold 9 RMSLE for model3 = 0.274852395400015
# Fold 9 RMSLE for model4 = 0.2761513620408937
# Fold 9 RMSLE for ('model1', 'model2') = 0.2755655809642505
# Fold 9 RMSLE for ('model1', 'model3') = 0.27510590876371155
# Fold 9 RMSLE for ('model1', 'model4') = 0.2757255229385753
# Fold 9 RMSLE for ('model2', 'model3') = 0.27527482901164635
# Fold 9 RMSLE for ('model2', 'model4') = 0.2760025063137976
# Fold 9 RMSLE for ('model3', 'model4') = 0.2754231406969624
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.2752360006915925
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.2756906053752574
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.2753913801812854
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.2754980316895
# Fold 9 RMSLE for all models ensemble = 0.27542287348078415
# Fold 9 best combination: model3 with RMSLE = 0.274852395400015
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.2602150450694204
# Fold 10 RMSLE for model2 = 0.26154660203591384
# Fold 10 RMSLE for model3 = 0.26158695289350875
# Fold 10 RMSLE for model4 = 0.25928772315048554
# Fold 10 RMSLE for ('model1', 'model2') = 0.2604636417583264
# Fold 10 RMSLE for ('model1', 'model3') = 0.2607752632155232
# Fold 10 RMSLE for ('model1', 'model4') = 0.25966798694091764
# Fold 10 RMSLE for ('model2', 'model3') = 0.2611870048905991
# Fold 10 RMSLE for ('model2', 'model4') = 0.26003208667662275
# Fold 10 RMSLE for ('model3', 'model4') = 0.2602588304235351
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.26070599952539364
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.259955811371397
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.2601908943601375
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.26038763911116597
# Fold 10 RMSLE for all models ensemble = 0.2602663685690172
# Fold 10 best combination: model4 with RMSLE = 0.25928772315048554
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.26267202170646037
# Fold 11 RMSLE for model2 = 0.26113550124058593
# Fold 11 RMSLE for model3 = 0.26039679104465024
# Fold 11 RMSLE for model4 = 0.26204344591878964
# Fold 11 RMSLE for ('model1', 'model2') = 0.2614149887312511
# Fold 11 RMSLE for ('model1', 'model3') = 0.2614656280764199
# Fold 11 RMSLE for ('model1', 'model4') = 0.26222449377293633
# Fold 11 RMSLE for ('model2', 'model3') = 0.26032238529736457
# Fold 11 RMSLE for ('model2', 'model4') = 0.26126439008722097
# Fold 11 RMSLE for ('model3', 'model4') = 0.26104862398365086
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.2609564526284262
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.2615295061826776
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.2615380848337876
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.26077402589848675
# Fold 11 RMSLE for all models ensemble = 0.261154249154038
# Fold 11 best combination: ('model2', 'model3') with RMSLE = 0.26032238529736457
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.26306996001857325
# Fold 12 RMSLE for model2 = 0.2646921904650755
# Fold 12 RMSLE for model3 = 0.2627594533321735
# Fold 12 RMSLE for model4 = 0.26311668616780765
# Fold 12 RMSLE for ('model1', 'model2') = 0.26349795872896214
# Fold 12 RMSLE for ('model1', 'model3') = 0.2628505216714984
# Fold 12 RMSLE for ('model1', 'model4') = 0.26298539074526756
# Fold 12 RMSLE for ('model2', 'model3') = 0.263469958574977
# Fold 12 RMSLE for ('model2', 'model4') = 0.263646560020397
# Fold 12 RMSLE for ('model3', 'model4') = 0.262829130665631
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.26319440861102655
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.2632932130500849
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.26285710800409606
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.26324585928696853
# Fold 12 RMSLE for all models ensemble = 0.2631148162749301
# Fold 12 best combination: model3 with RMSLE = 0.2627594533321735
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.26697526449359066
# Fold 13 RMSLE for model2 = 0.26696806376848375
# Fold 13 RMSLE for model3 = 0.26541814205761793
# Fold 13 RMSLE for model4 = 0.2680272740725316
# Fold 13 RMSLE for ('model1', 'model2') = 0.2665582860244588
# Fold 13 RMSLE for ('model1', 'model3') = 0.2661178585483521
# Fold 13 RMSLE for ('model1', 'model4') = 0.26736683530352545
# Fold 13 RMSLE for ('model2', 'model3') = 0.2657596066740119
# Fold 13 RMSLE for ('model2', 'model4') = 0.26718562011981867
# Fold 13 RMSLE for ('model3', 'model4') = 0.2665226820978933
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.26604224454653613
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.2669414504466099
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.2666231455310805
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.26638428799003183
# Fold 13 RMSLE for all models ensemble = 0.26645409967835565
# Fold 13 best combination: model3 with RMSLE = 0.26541814205761793
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.24857349609051524
# Fold 14 RMSLE for model2 = 0.24851666169241587
# Fold 14 RMSLE for model3 = 0.24847678862101857
# Fold 14 RMSLE for model4 = 0.2490307871057103
# Fold 14 RMSLE for ('model1', 'model2') = 0.248165869437192
# Fold 14 RMSLE for ('model1', 'model3') = 0.2484383524079494
# Fold 14 RMSLE for ('model1', 'model4') = 0.24864783196558055
# Fold 14 RMSLE for ('model2', 'model3') = 0.2481168395699437
# Fold 14 RMSLE for ('model2', 'model4') = 0.2485045269307686
# Fold 14 RMSLE for ('model3', 'model4') = 0.2485497880670343
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.2481463480621976
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.24835022872621074
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.24849582946474114
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.2482955841503503
# Fold 14 RMSLE for all models ensemble = 0.24828106070205438
# Fold 14 best combination: ('model2', 'model3') with RMSLE = 0.2481168395699437
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.27969699998393055
# Fold 15 RMSLE for model2 = 0.27772418793638026
# Fold 15 RMSLE for model3 = 0.27980886507253455
# Fold 15 RMSLE for model4 = 0.2796119078817634
# Fold 15 RMSLE for ('model1', 'model2') = 0.2782835569469325
# Fold 15 RMSLE for ('model1', 'model3') = 0.2796502200713007
# Fold 15 RMSLE for ('model1', 'model4') = 0.2795297087978382
# Fold 15 RMSLE for ('model2', 'model3') = 0.27823407782909193
# Fold 15 RMSLE for ('model2', 'model4') = 0.2783989393480927
# Fold 15 RMSLE for ('model3', 'model4') = 0.2794223325366864
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.27860497831860925
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.2786463922044335
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.27947680137962483
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.2785640762305828
# Fold 15 RMSLE for all models ensemble = 0.27877471862402864
# Fold 15 best combination: model2 with RMSLE = 0.27772418793638026
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.24703536220974817
# Fold 16 RMSLE for model2 = 0.2481070114185632
# Fold 16 RMSLE for model3 = 0.24785864754398285
# Fold 16 RMSLE for model4 = 0.24620053727367505
# Fold 16 RMSLE for ('model1', 'model2') = 0.247065541266281
# Fold 16 RMSLE for ('model1', 'model3') = 0.24733534300737273
# Fold 16 RMSLE for ('model1', 'model4') = 0.24651760445846096
# Fold 16 RMSLE for ('model2', 'model3') = 0.24748317356149857
# Fold 16 RMSLE for ('model2', 'model4') = 0.2468117228550098
# Fold 16 RMSLE for ('model3', 'model4') = 0.24680938646601333
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.24717039348562495
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.24669258563379562
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.24683940213501399
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.24691644585401445
# Fold 16 RMSLE for all models ensemble = 0.2468551282575313
# Fold 16 best combination: model4 with RMSLE = 0.24620053727367505
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.26206467116245546
# Fold 17 RMSLE for model2 = 0.26355264916393756
# Fold 17 RMSLE for model3 = 0.26120227407695873
# Fold 17 RMSLE for model4 = 0.2611686958196051
# Fold 17 RMSLE for ('model1', 'model2') = 0.26244103542492386
# Fold 17 RMSLE for ('model1', 'model3') = 0.26155884678272084
# Fold 17 RMSLE for ('model1', 'model4') = 0.26145951933600986
# Fold 17 RMSLE for ('model2', 'model3') = 0.262018456658193
# Fold 17 RMSLE for ('model2', 'model4') = 0.2621437595869998
# Fold 17 RMSLE for ('model3', 'model4') = 0.2609940822744556
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.2619167546333641
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.26193212302214475
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.26129048937518257
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.261633335174017
# Fold 17 RMSLE for all models ensemble = 0.26165508675872867
# Fold 17 best combination: ('model3', 'model4') with RMSLE = 0.2609940822744556
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.2411728279344764
# Fold 18 RMSLE for model2 = 0.24180469134637278
# Fold 18 RMSLE for model3 = 0.241043351439048
# Fold 18 RMSLE for model4 = 0.24237988454305145
# Fold 18 RMSLE for ('model1', 'model2') = 0.24103332800253485
# Fold 18 RMSLE for ('model1', 'model3') = 0.24101736460299325
# Fold 18 RMSLE for ('model1', 'model4') = 0.2416415610930801
# Fold 18 RMSLE for ('model2', 'model3') = 0.24109227486053686
# Fold 18 RMSLE for ('model2', 'model4') = 0.24177832106726552
# Fold 18 RMSLE for ('model3', 'model4') = 0.24156595708068732
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.24094995836204205
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.24138397559172678
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.24136700135493344
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.2413908766945303
# Fold 18 RMSLE for all models ensemble = 0.24123202457767273
# Fold 18 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.24094995836204205
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.27214507226410706
# Fold 19 RMSLE for model2 = 0.27319134241032905
# Fold 19 RMSLE for model3 = 0.27129057632451337
# Fold 19 RMSLE for model4 = 0.27213783398113056
# Fold 19 RMSLE for ('model1', 'model2') = 0.272327779742735
# Fold 19 RMSLE for ('model1', 'model3') = 0.2716053271338261
# Fold 19 RMSLE for ('model1', 'model4') = 0.2720186789283009
# Fold 19 RMSLE for ('model2', 'model3') = 0.27196005443816673
# Fold 19 RMSLE for ('model2', 'model4') = 0.27242036166555433
# Fold 19 RMSLE for ('model3', 'model4') = 0.2715564123997105
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.271882644487537
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.27217688048041544
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.27168312509093107
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.2719029549198327
# Fold 19 RMSLE for all models ensemble = 0.27187636485531314
# Fold 19 best combination: model3 with RMSLE = 0.27129057632451337
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.2655097592319665
# Fold 20 RMSLE for model2 = 0.26698134590755646
# Fold 20 RMSLE for model3 = 0.26599887743209955
# Fold 20 RMSLE for model4 = 0.2661738063395069
# Fold 20 RMSLE for ('model1', 'model2') = 0.26584920472807794
# Fold 20 RMSLE for ('model1', 'model3') = 0.2656858834050556
# Fold 20 RMSLE for ('model1', 'model4') = 0.2657106201744737
# Fold 20 RMSLE for ('model2', 'model3') = 0.26617833979545696
# Fold 20 RMSLE for ('model2', 'model4') = 0.2663415637931759
# Fold 20 RMSLE for ('model3', 'model4') = 0.2659414647235502
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.26581800652074145
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.2658821963945079
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.2657410204619175
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.26607673544768184
# Fold 20 RMSLE for all models ensemble = 0.26584362750904456
# Fold 20 best combination: model1 with RMSLE = 0.2655097592319665
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.23397496269399712
# Fold 21 RMSLE for model2 = 0.23306893908466053
# Fold 21 RMSLE for model3 = 0.23491142390547612
# Fold 21 RMSLE for model4 = 0.23407618261905033
# Fold 21 RMSLE for ('model1', 'model2') = 0.23304300459812813
# Fold 21 RMSLE for ('model1', 'model3') = 0.23435069621882015
# Fold 21 RMSLE for ('model1', 'model4') = 0.23389230748121967
# Fold 21 RMSLE for ('model2', 'model3') = 0.23358511030752663
# Fold 21 RMSLE for ('model2', 'model4') = 0.23323272881277735
# Fold 21 RMSLE for ('model3', 'model4') = 0.2342846531809825
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.23355141894464035
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.23328370051140518
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.23412753328477406
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.23359486922043618
# Fold 21 RMSLE for all models ensemble = 0.233593389044321
# Fold 21 best combination: ('model1', 'model2') with RMSLE = 0.23304300459812813
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.2509568681206582
# Fold 22 RMSLE for model2 = 0.25193621791137727
# Fold 22 RMSLE for model3 = 0.2505050118265588
# Fold 22 RMSLE for model4 = 0.25029801219637454
# Fold 22 RMSLE for ('model1', 'model2') = 0.2510661034744391
# Fold 22 RMSLE for ('model1', 'model3') = 0.2506726610714551
# Fold 22 RMSLE for ('model1', 'model4') = 0.2505430078752639
# Fold 22 RMSLE for ('model2', 'model3') = 0.2509223777112722
# Fold 22 RMSLE for ('model2', 'model4') = 0.2508649140536139
# Fold 22 RMSLE for ('model3', 'model4') = 0.2503008685129161
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.25080494310738655
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.25074477204846335
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.25047848008328233
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.25062352561289397
# Fold 22 RMSLE for all models ensemble = 0.2506302096427207
# Fold 22 best combination: model4 with RMSLE = 0.25029801219637454
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.2471716304560414
# Fold 23 RMSLE for model2 = 0.24654233144490512
# Fold 23 RMSLE for model3 = 0.24643273384957734
# Fold 23 RMSLE for model4 = 0.24702777114489788
# Fold 23 RMSLE for ('model1', 'model2') = 0.24644724690004818
# Fold 23 RMSLE for ('model1', 'model3') = 0.24673296550021268
# Fold 23 RMSLE for ('model1', 'model4') = 0.24697791343856626
# Fold 23 RMSLE for ('model2', 'model3') = 0.24616188905446956
# Fold 23 RMSLE for ('model2', 'model4') = 0.24652743202839564
# Fold 23 RMSLE for ('model3', 'model4') = 0.24660323314155505
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.24635797827740621
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.24656321796537797
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.24673602074670886
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.24635193583825724
# Fold 23 RMSLE for all models ensemble = 0.24646588120429921
# Fold 23 best combination: ('model2', 'model3') with RMSLE = 0.24616188905446956
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.27316293145509024
# Fold 24 RMSLE for model2 = 0.2731839677611146
# Fold 24 RMSLE for model3 = 0.2723892030424185
# Fold 24 RMSLE for model4 = 0.27179752256687717
# Fold 24 RMSLE for ('model1', 'model2') = 0.272839103043198
# Fold 24 RMSLE for ('model1', 'model3') = 0.2726945051373956
# Fold 24 RMSLE for ('model1', 'model4') = 0.27234610267541337
# Fold 24 RMSLE for ('model2', 'model3') = 0.2724714901412182
# Fold 24 RMSLE for ('model2', 'model4') = 0.272223607349617
# Fold 24 RMSLE for ('model3', 'model4') = 0.27190447361864223
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.272587067354278
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.2723877367375476
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.27227012401411715
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.27211405717270254
# Fold 24 RMSLE for all models ensemble = 0.2723030011556938
# Fold 24 best combination: model4 with RMSLE = 0.27179752256687717
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.27144665486855046
# Fold 25 RMSLE for model2 = 0.27145799582925206
# Fold 25 RMSLE for model3 = 0.27083528714849914
# Fold 25 RMSLE for model4 = 0.27049011299335934
# Fold 25 RMSLE for ('model1', 'model2') = 0.27106613724494144
# Fold 25 RMSLE for ('model1', 'model3') = 0.2710664677746599
# Fold 25 RMSLE for ('model1', 'model4') = 0.2708431641981277
# Fold 25 RMSLE for ('model2', 'model3') = 0.2708202949785162
# Fold 25 RMSLE for ('model2', 'model4') = 0.2707372567889475
# Fold 25 RMSLE for ('model3', 'model4') = 0.2705195170434655
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.2708967759083774
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.2707989207067133
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.270771632786133
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.2706137707873088
# Fold 25 RMSLE for all models ensemble = 0.2707343309468072
# Fold 25 best combination: model4 with RMSLE = 0.27049011299335934
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.2620275430909463
# Fold 26 RMSLE for model2 = 0.2643839814306491
# Fold 26 RMSLE for model3 = 0.26225922354942166
# Fold 26 RMSLE for model4 = 0.2604702596182981
# Fold 26 RMSLE for ('model1', 'model2') = 0.26266692970883065
# Fold 26 RMSLE for ('model1', 'model3') = 0.26205227324906294
# Fold 26 RMSLE for ('model1', 'model4') = 0.26102264798705677
# Fold 26 RMSLE for ('model2', 'model3') = 0.26287261829576347
# Fold 26 RMSLE for ('model2', 'model4') = 0.2620946554445856
# Fold 26 RMSLE for ('model3', 'model4') = 0.2610995106632708
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.2624102110847834
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.26180554900935243
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.2613268695415136
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.26190557229744116
# Fold 26 RMSLE for all models ensemble = 0.2618089566965069
# Fold 26 best combination: model4 with RMSLE = 0.2604702596182981
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.23706165186109276
# Fold 27 RMSLE for model2 = 0.23927983477668102
# Fold 27 RMSLE for model3 = 0.237872836846366
# Fold 27 RMSLE for model4 = 0.23744786349734043
# Fold 27 RMSLE for ('model1', 'model2') = 0.2378005356663542
# Fold 27 RMSLE for ('model1', 'model3') = 0.23731969277338763
# Fold 27 RMSLE for ('model1', 'model4') = 0.23712832563527605
# Fold 27 RMSLE for ('model2', 'model3') = 0.23819566013154564
# Fold 27 RMSLE for ('model2', 'model4') = 0.23808455009941681
# Fold 27 RMSLE for ('model3', 'model4') = 0.23747862839586403
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.23767182385990582
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.23758465352562644
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.23725820724406316
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.2378258662845001
# Fold 27 RMSLE for all models ensemble = 0.23754372141876173
# Fold 27 best combination: model1 with RMSLE = 0.23706165186109276
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.2659906806186041
# Fold 28 RMSLE for model2 = 0.2668503805775274
# Fold 28 RMSLE for model3 = 0.26537375014668174
# Fold 28 RMSLE for model4 = 0.26490603598976464
# Fold 28 RMSLE for ('model1', 'model2') = 0.265995858134578
# Fold 28 RMSLE for ('model1', 'model3') = 0.2655499254633102
# Fold 28 RMSLE for ('model1', 'model4') = 0.26520077125766733
# Fold 28 RMSLE for ('model2', 'model3') = 0.26571732875819143
# Fold 28 RMSLE for ('model2', 'model4') = 0.26557498537261076
# Fold 28 RMSLE for ('model3', 'model4') = 0.2649325967026217
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.26564839710233457
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.2654819303769757
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.26516252746704083
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.2653075048210798
# Fold 28 RMSLE for all models ensemble = 0.26535248232188435
# Fold 28 best combination: model4 with RMSLE = 0.26490603598976464
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.24688472906882208
# Fold 29 RMSLE for model2 = 0.24888164170779592
# Fold 29 RMSLE for model3 = 0.24655320695054594
# Fold 29 RMSLE for model4 = 0.24776866717254856
# Fold 29 RMSLE for ('model1', 'model2') = 0.24747689923399566
# Fold 29 RMSLE for ('model1', 'model3') = 0.2466285618627984
# Fold 29 RMSLE for ('model1', 'model4') = 0.24722655251299763
# Fold 29 RMSLE for ('model2', 'model3') = 0.24740790723970976
# Fold 29 RMSLE for ('model2', 'model4') = 0.24802171962590527
# Fold 29 RMSLE for ('model3', 'model4') = 0.24701568190885653
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.24708116480429684
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.24748485382465352
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.24691959685172205
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.2473973197667756
# Fold 29 RMSLE for all models ensemble = 0.24718295645515295
# Fold 29 best combination: model3 with RMSLE = 0.24655320695054594
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.2722509327426559
# Fold 30 RMSLE for model2 = 0.27089187906480233
# Fold 30 RMSLE for model3 = 0.2705864232566885
# Fold 30 RMSLE for model4 = 0.2724235623033673
# Fold 30 RMSLE for ('model1', 'model2') = 0.27106163738004535
# Fold 30 RMSLE for ('model1', 'model3') = 0.27134517607867187
# Fold 30 RMSLE for ('model1', 'model4') = 0.27221647541769983
# Fold 30 RMSLE for ('model2', 'model3') = 0.2702851396082043
# Fold 30 RMSLE for ('model2', 'model4') = 0.27130054319359986
# Fold 30 RMSLE for ('model3', 'model4') = 0.27137233954853457
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.27078213818698654
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.2714167038419691
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.27160830925966817
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.2708812639672986
# Fold 30 RMSLE for all models ensemble = 0.27112640885672107
# Fold 30 best combination: ('model2', 'model3') with RMSLE = 0.2702851396082043
# ---------------
#
# OOF RMSLE = 0.25817361144428164
# Sum of RMSLE for each combination:
# ('model1',): 7.759648191695553
# ('model2',): 7.790988992836338
# ('model3',): 7.753914617601996
# ('model4',): 7.758419564500553
# ('model1', 'model2'): 7.76316381427414
# ('model1', 'model3'): 7.754006111197582
# ('model1', 'model4'): 7.75517463072047
# ('model2', 'model3'): 7.761587004385507
# ('model2', 'model4'): 7.76634233621551
# ('model3', 'model4'): 7.750924377975408
# ('model1', 'model2', 'model3'): 7.756713744226944
# ('model1', 'model2', 'model4'): 7.75884720971849
# ('model1', 'model3', 'model4'): 7.75204836838022
# ('model2', 'model3', 'model4'): 7.756895187924981
# ('model1', 'model2', 'model3', 'model4'): 7.754922068654095

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                          32,075                       26,446
# 3                          42,504                       43,906
# 4                          39,898                       40,203
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                          23,385           130
# 3                          42,958            82
# 4                          39,437           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff  \
# 0                   9            1           44,594     0
# 1                  14            1          296,645     0
# 2                   8            0           41,032     0
# 3                   8            0           30,125     0
# 4                   8            0           47,570     0
# ...               ...          ...              ...   ...
# 2503                1            1          523,079     0
# 2504                9            1          100,312     0
# 2505                8            0          134,940     0
# 2506                8            0          262,619     0
# 2507                9            1        1,295,969     0
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       45,108
# 1                                      293,984
# 2                                       41,227
# 3                                       29,464
# 4                                       48,383
# ...                                        ...
# 2503                                   537,502
# 2504                                    99,339
# 2505                                   137,959
# 2506                                   261,207
# 2507                                 1,383,562
#
# [2508 rows x 21 columns]

# %%
test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
train_df["preds"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                       24,101                       19,192
# 4651                          NaN                          NaN
# 4652                       24,257                       25,344
# 4653                       25,345                       15,031
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           41,547     0  52,532
# 1                  14            1           59,347    -0  71,904
# 2                   9            1           99,121    -1 133,308
# 3                  15            1           51,450     0  63,268
# 4                  15            0           51,060    -0  61,622
# ...               ...          ...              ...   ...     ...
# 4650               15            0           46,740    -0  56,730
# 4651                8            1          170,355     0 223,558
# 4652                8            0           31,492    -0  38,669
# 4653                8            0           66,290    -0  80,772
# 4654                9            1          146,419    -0 197,422
#
# [4655 rows x 21 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 0.00)

# %%
# 対数変換
log_target = np.log1p(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
log_oof_predictions = np.log1p(train_df["preds"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GHG_Direct_Emissions_14_in_metric_tons.1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-456-db083bdef1c1> in <cell line: 2>()
#       1 # 対数変換
# ----> 2 log_target = np.log1p(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
#       3 log_oof_predictions = np.log1p(train_df["preds"])
#       4
#       5 # 差の計算
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'GHG_Direct_Emissions_14_in_metric_tons.1'

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)
# after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return np.array(bin_centers), np.array(y_means)
x = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
y = train_df["preds"]
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GHG_Direct_Emissions_14_in_metric_tons.1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-460-13b36fcacbf0> in <cell line: 34>()
#      32
#      33     return np.array(bin_centers), np.array(y_means)
# ---> 34 x = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
#      35 y = train_df["preds"]
#      36 # ビンに分けて平均を計算
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'GHG_Direct_Emissions_14_in_metric_tons.1'

# %%
# x = after_test_preds
# y = after_test_preds
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 169665.0318368913

# %%
submit [ 1 ]  =  test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
submit.to_csv('SMBC_56.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,108
# 1     4656   293,984
# 2     4657    41,227
# 3     4658    29,464
# 4     4659    48,383
# ...    ...       ...
# 2503  7158   537,502
# 2504  7159    99,339
# 2505  7160   137,959
# 2506  7161   261,207
# 2507  7162 1,383,562
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())

# %%
train_df

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], train_df["preds"])

# %%
train_df
