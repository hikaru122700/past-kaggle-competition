# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/070.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   537,502
# 2504                                    99,339
# 2505                                   137,959
# 2506                                   261,207
# 2507                                 1,383,562
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   537,502
# 2504                                    99,339
# 2505                                   137,959
# 2506                                   261,207
# 2507                                 1,383,562
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           41,547
# 1                  14            1           59,347
# 2                   9            1           99,121
# 3                  15            1           51,450
# 4                  15            0           51,060
# ...               ...          ...              ...
# 2503                1            1          523,079
# 2504                9            1          100,312
# 2505                8            0          134,940
# 2506                8            0          262,619
# 2507                9            1        1,295,969
#
#       GHG_Direct_Emissions_14_in_metric_tons.1  diff
# 0                                       42,214     0
# 1                                       58,500    -0
# 2                                       99,409     0
# 3                                       51,623     0
# 4                                       50,638    -0
# ...                                        ...   ...
# 2503                                   537,502     0
# 2504                                    99,339    -0
# 2505                                   137,959     0
# 2506                                   261,207    -0
# 2507                                 1,383,562     0
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_df_diff_ave = train_all_df["diff"].mean()
train_all_df["diff"].fillna(train_df_diff_ave, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           41,547     0
# 1                  14            1           59,347    -0
# 2                   9            1           99,121     0
# 3                  15            1           51,450     0
# 4                  15            0           51,060    -0
# ...               ...          ...              ...   ...
# 4650               15            0           46,740     0
# 4651                8            1          170,355    -0
# 4652                8            0           31,492     0
# 4653                8            0           66,290    -0
# 4654                9            1          146,419    -0
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           41,547     0
# 1                  14            1           59,347    -0
# 2                   9            1           99,121     0
# 3                  15            1           51,450     0
# 4                  15            0           51,060    -0
# ...               ...          ...              ...   ...
# 2503                1            1          523,079     0
# 2504                9            1          100,312    -0
# 2505                8            0          134,940     0
# 2506                8            0          262,619    -0
# 2507                9            1        1,295,969     0
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           41,547     0
# 1                  14            1           59,347    -0
# 2                   9            1           99,121     0
# 3                  15            1           51,450     0
# 4                  15            0           51,060    -0
# ...               ...          ...              ...   ...
# 4650               15            0           46,740     0
# 4651                8            1          170,355    -0
# 4652                8            0           31,492     0
# 4653                8            0           66,290    -0
# 4654                9            1          146,419    -0
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
import time
epock = 10
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_df_diff_ave = train_all_df["diff"].mean()
    train_all_df["diff"].fillna(train_df_diff_ave, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.009078341465104103
# Fold 18 RMSLE for ('model1', 'model3') = 0.009280319746152567
# Fold 18 RMSLE for ('model1', 'model4') = 0.00926100293536917
# Fold 18 RMSLE for ('model2', 'model3') = 0.00914074588340232
# Fold 18 RMSLE for ('model2', 'model4') = 0.009165450309378315
# Fold 18 RMSLE for ('model3', 'model4') = 0.009347180392972661
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.009151092659351998
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.009158660425607734
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.009289035560654902
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.009203478936758776
# Fold 18 RMSLE for all models ensemble = 0.009194775000056008
# Fold 18 best combination: model2 with RMSLE = 0.009036257568819966
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.011942698790281933
# Fold 19 RMSLE for model2 = 0.0116288673119548
# Fold 19 RMSLE for model3 = 0.011998099148196545
# Fold 19 RMSLE for model4 = 0.011955759627099978
# Fold 19 RMSLE for ('model1', 'model2') = 0.011741197963009311
# Fold 19 RMSLE for ('model1', 'model3') = 0.011953514158681537
# Fold 19 RMSLE for ('model1', 'model4') = 0.01193343565260635
# Fold 19 RMSLE for ('model2', 'model3') = 0.011739579763439024
# Fold 19 RMSLE for ('model2', 'model4') = 0.011766889846965526
# Fold 19 RMSLE for ('model3', 'model4') = 0.01195130955805732
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.011796547804063879
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.011804379852848013
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.011939598557995928
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.011805459156165937
# Fold 19 RMSLE for all models ensemble = 0.011830931453682652
# Fold 19 best combination: model2 with RMSLE = 0.0116288673119548
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.010298471214618011
# Fold 20 RMSLE for model2 = 0.010013989393702438
# Fold 20 RMSLE for model3 = 0.010600108495732214
# Fold 20 RMSLE for model4 = 0.010270042294062622
# Fold 20 RMSLE for ('model1', 'model2') = 0.010099044869627934
# Fold 20 RMSLE for ('model1', 'model3') = 0.010429431247935356
# Fold 20 RMSLE for ('model1', 'model4') = 0.010271042033015756
# Fold 20 RMSLE for ('model2', 'model3') = 0.010223808120588526
# Fold 20 RMSLE for ('model2', 'model4') = 0.010102544974610514
# Fold 20 RMSLE for ('model3', 'model4') = 0.010417986002458688
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.010233166071189424
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.010145461191476027
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.010367216027910919
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.010232694587947804
# Fold 20 RMSLE for all models ensemble = 0.010238320989932064
# Fold 20 best combination: model2 with RMSLE = 0.010013989393702438
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.009407553092701118
# Fold 21 RMSLE for model2 = 0.008878682103001485
# Fold 21 RMSLE for model3 = 0.009654686984752333
# Fold 21 RMSLE for model4 = 0.009350704539119334
# Fold 21 RMSLE for ('model1', 'model2') = 0.009105524075316316
# Fold 21 RMSLE for ('model1', 'model3') = 0.00950815390408981
# Fold 21 RMSLE for ('model1', 'model4') = 0.00935823663080877
# Fold 21 RMSLE for ('model2', 'model3') = 0.009204446011450719
# Fold 21 RMSLE for ('model2', 'model4') = 0.009078751646879192
# Fold 21 RMSLE for ('model3', 'model4') = 0.009480631840124229
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.009259250696053047
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.009170452827207213
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.009441663830707023
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.009241405013957493
# Fold 21 RMSLE for all models ensemble = 0.00927266461848791
# Fold 21 best combination: model2 with RMSLE = 0.008878682103001485
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.009470138390965024
# Fold 22 RMSLE for model2 = 0.008839047659653813
# Fold 22 RMSLE for model3 = 0.00977940537770401
# Fold 22 RMSLE for model4 = 0.009428556496996148
# Fold 22 RMSLE for ('model1', 'model2') = 0.00912279963424934
# Fold 22 RMSLE for ('model1', 'model3') = 0.009608321079432398
# Fold 22 RMSLE for ('model1', 'model4') = 0.009437803179435046
# Fold 22 RMSLE for ('model2', 'model3') = 0.00925570325484626
# Fold 22 RMSLE for ('model2', 'model4') = 0.009113543417380495
# Fold 22 RMSLE for ('model3', 'model4') = 0.009584545084712431
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.009317870197598981
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.009217779560735778
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.009538249902315207
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.009307641261556126
# Fold 22 RMSLE for all models ensemble = 0.009341202959017716
# Fold 22 best combination: model2 with RMSLE = 0.008839047659653813
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.0091960322379394
# Fold 23 RMSLE for model2 = 0.0087631025041962
# Fold 23 RMSLE for model3 = 0.009594082014534929
# Fold 23 RMSLE for model4 = 0.009228147315257958
# Fold 23 RMSLE for ('model1', 'model2') = 0.008937884400092012
# Fold 23 RMSLE for ('model1', 'model3') = 0.00937190700339463
# Fold 23 RMSLE for ('model1', 'model4') = 0.00919484244554699
# Fold 23 RMSLE for ('model2', 'model3') = 0.009103057435806515
# Fold 23 RMSLE for ('model2', 'model4') = 0.008968080800717678
# Fold 23 RMSLE for ('model3', 'model4') = 0.00938504318749831
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.009122200686297589
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.009024114830656021
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.009309822142228204
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.009137757907369422
# Fold 23 RMSLE for all models ensemble = 0.009142656425702623
# Fold 23 best combination: model2 with RMSLE = 0.0087631025041962
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.011036051265965293
# Fold 24 RMSLE for model2 = 0.010605549200185537
# Fold 24 RMSLE for model3 = 0.011441543142815019
# Fold 24 RMSLE for model4 = 0.011098822235996704
# Fold 24 RMSLE for ('model1', 'model2') = 0.010787225887073494
# Fold 24 RMSLE for ('model1', 'model3') = 0.011218406074306578
# Fold 24 RMSLE for ('model1', 'model4') = 0.011051102659898544
# Fold 24 RMSLE for ('model2', 'model3') = 0.01096881725333787
# Fold 24 RMSLE for ('model2', 'model4') = 0.010826657982944285
# Fold 24 RMSLE for ('model3', 'model4') = 0.011250995544526224
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.010979507707597596
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.010880025455766997
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.01116726580576182
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.011004519600227811
# Fold 24 RMSLE for all models ensemble = 0.011003155115339773
# Fold 24 best combination: model2 with RMSLE = 0.010605549200185537
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.009728365243438905
# Fold 25 RMSLE for model2 = 0.009514112887716007
# Fold 25 RMSLE for model3 = 0.010018255859257709
# Fold 25 RMSLE for model4 = 0.009702948361803396
# Fold 25 RMSLE for ('model1', 'model2') = 0.009560614680329005
# Fold 25 RMSLE for ('model1', 'model3') = 0.009852806861814233
# Fold 25 RMSLE for ('model1', 'model4') = 0.009690290008726496
# Fold 25 RMSLE for ('model2', 'model3') = 0.00967247660701891
# Fold 25 RMSLE for ('model2', 'model4') = 0.009576818940552172
# Fold 25 RMSLE for ('model3', 'model4') = 0.009827822729556785
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.009676058394661477
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.009596200040146021
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.009781551483115424
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.009674723400781031
# Fold 25 RMSLE for all models ensemble = 0.009674802259557696
# Fold 25 best combination: model2 with RMSLE = 0.009514112887716007
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.009455771245413951
# Fold 26 RMSLE for model2 = 0.009184885962852399
# Fold 26 RMSLE for model3 = 0.009640004013052138
# Fold 26 RMSLE for model4 = 0.009472928847122655
# Fold 26 RMSLE for ('model1', 'model2') = 0.009245244058288091
# Fold 26 RMSLE for ('model1', 'model3') = 0.009521363314591951
# Fold 26 RMSLE for ('model1', 'model4') = 0.009433635173084622
# Fold 26 RMSLE for ('model2', 'model3') = 0.009297988713805255
# Fold 26 RMSLE for ('model2', 'model4') = 0.00929000242832824
# Fold 26 RMSLE for ('model3', 'model4') = 0.009518614407672968
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.009331133950985079
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.009306977672926743
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.009480610274044262
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.009347696385649144
# Fold 26 RMSLE for all models ensemble = 0.009357687080031223
# Fold 26 best combination: model2 with RMSLE = 0.009184885962852399
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.00894454741325303
# Fold 27 RMSLE for model2 = 0.00904213865617976
# Fold 27 RMSLE for model3 = 0.00927516232846117
# Fold 27 RMSLE for model4 = 0.009216624896363853
# Fold 27 RMSLE for ('model1', 'model2') = 0.008931199299250151
# Fold 27 RMSLE for ('model1', 'model3') = 0.009087938620796649
# Fold 27 RMSLE for ('model1', 'model4') = 0.009052123482982007
# Fold 27 RMSLE for ('model2', 'model3') = 0.009064971003852727
# Fold 27 RMSLE for ('model2', 'model4') = 0.009096553698863745
# Fold 27 RMSLE for ('model3', 'model4') = 0.009211912919611919
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.009008198476285582
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.009012995705558748
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.00910789578671466
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.00910669003391891
# Fold 27 RMSLE for all models ensemble = 0.009051356412687327
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.008931199299250151
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.010910948617389902
# Fold 28 RMSLE for model2 = 0.010643216277034602
# Fold 28 RMSLE for model3 = 0.011139242386467546
# Fold 28 RMSLE for model4 = 0.010730249777967122
# Fold 28 RMSLE for ('model1', 'model2') = 0.01071576581157881
# Fold 28 RMSLE for ('model1', 'model3') = 0.011001305996975096
# Fold 28 RMSLE for ('model1', 'model4') = 0.01077028647942347
# Fold 28 RMSLE for ('model2', 'model3') = 0.01079165164090097
# Fold 28 RMSLE for ('model2', 'model4') = 0.01065031207629841
# Fold 28 RMSLE for ('model3', 'model4') = 0.010877668754354555
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.010815908496791487
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.010695577007194161
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.010868589539307366
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.010751492123837747
# Fold 28 RMSLE for all models ensemble = 0.010773742323095891
# Fold 28 best combination: model2 with RMSLE = 0.010643216277034602
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.008243000236265077
# Fold 29 RMSLE for model2 = 0.00800859130425236
# Fold 29 RMSLE for model3 = 0.008505598012946628
# Fold 29 RMSLE for model4 = 0.008416213450407493
# Fold 29 RMSLE for ('model1', 'model2') = 0.008081547659543952
# Fold 29 RMSLE for ('model1', 'model3') = 0.008352310638848951
# Fold 29 RMSLE for ('model1', 'model4') = 0.008308934463082661
# Fold 29 RMSLE for ('model2', 'model3') = 0.008187587554045143
# Fold 29 RMSLE for ('model2', 'model4') = 0.008178934042444769
# Fold 29 RMSLE for ('model3', 'model4') = 0.008435021534423428
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.008192181889726872
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.008178982752609462
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.008357773451121648
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.008253007399116241
# Fold 29 RMSLE for all models ensemble = 0.00823955127451896
# Fold 29 best combination: model2 with RMSLE = 0.00800859130425236
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.012124343156632675
# Fold 30 RMSLE for model2 = 0.012136083301229986
# Fold 30 RMSLE for model3 = 0.01221204607744873
# Fold 30 RMSLE for model4 = 0.012321654946468927
# Fold 30 RMSLE for ('model1', 'model2') = 0.012079693669626778
# Fold 30 RMSLE for ('model1', 'model3') = 0.012149360876814846
# Fold 30 RMSLE for ('model1', 'model4') = 0.01220481060176634
# Fold 30 RMSLE for ('model2', 'model3') = 0.012096034641532971
# Fold 30 RMSLE for ('model2', 'model4') = 0.012202147883642695
# Fold 30 RMSLE for ('model3', 'model4') = 0.012238492470377574
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.012091970740766365
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.012151670485580525
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.012190266295148302
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.012164186468535839
# Fold 30 RMSLE for all models ensemble = 0.012143411827600708
# Fold 30 best combination: ('model1', 'model2') with RMSLE = 0.012079693669626778
# ---------------
#
# OOF RMSLE = 0.009576979060640037
# Sum of RMSLE for each combination:
# ('model1',): 0.29273555350409414
# ('model2',): 0.2860986558830343
# ('model3',): 0.2992065022072999
# ('model4',): 0.29494598806254785
# ('model1', 'model2'): 0.28786754039399504
# ('model1', 'model3'): 0.29536995233764557
# ('model1', 'model4'): 0.29312812073833594
# ('model2', 'model3'): 0.2902704825373614
# ('model2', 'model4'): 0.289579861623405
# ('model3', 'model4'): 0.2961313469092809
# ('model1', 'model2', 'model3'): 0.2906692959982762
# ('model1', 'model2', 'model4'): 0.2898378442232608
# ('model1', 'model3', 'model4'): 0.2946247255664867
# ('model2', 'model3', 'model4'): 0.2915209254258011
# ('model1', 'model2', 'model3', 'model4'): 0.29146609644616506
#
# 1番目の学習が終わりました。
#
# 推定時間は21
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.00779293404765291
# Fold 1 RMSLE for model2 = 0.00760765561177125
# Fold 1 RMSLE for model3 = 0.007872607076722488
# Fold 1 RMSLE for model4 = 0.00778542690336792
# Fold 1 RMSLE for ('model1', 'model2') = 0.007683090693619148
# Fold 1 RMSLE for ('model1', 'model3') = 0.00782465901128389
# Fold 1 RMSLE for ('model1', 'model4') = 0.007781941724283529
# Fold 1 RMSLE for ('model2', 'model3') = 0.007710341260969873
# Fold 1 RMSLE for ('model2', 'model4') = 0.007680898683597348
# Fold 1 RMSLE for ('model3', 'model4') = 0.007819250306994274
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.007733289849980599
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.0077108848010153845
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.007805821819928731
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.007730730388718258
# Fold 1 RMSLE for all models ensemble = 0.007742762764515781
# Fold 1 best combination: model2 with RMSLE = 0.00760765561177125
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.005878382838368623
# Fold 2 RMSLE for model2 = 0.005982521542174516
# Fold 2 RMSLE for model3 = 0.005981150180675606
# Fold 2 RMSLE for model4 = 0.005944254666234934
# Fold 2 RMSLE for ('model1', 'model2') = 0.005892969270434608
# Fold 2 RMSLE for ('model1', 'model3') = 0.005918331273320824
# Fold 2 RMSLE for ('model1', 'model4') = 0.005900059020716014
# Fold 2 RMSLE for ('model2', 'model3') = 0.005924329646484235
# Fold 2 RMSLE for ('model2', 'model4') = 0.00594095921579136
# Fold 2 RMSLE for ('model3', 'model4') = 0.00594595520290085
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.005899958082153965
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.005903398327908695
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.005917048751676438
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.005926300707972274
# Fold 2 RMSLE for all models ensemble = 0.005907291148930798
# Fold 2 best combination: model1 with RMSLE = 0.005878382838368623
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.006598396835620726
# Fold 3 RMSLE for model2 = 0.006577841090398621
# Fold 3 RMSLE for model3 = 0.006726377963280599
# Fold 3 RMSLE for model4 = 0.006600572269479429
# Fold 3 RMSLE for ('model1', 'model2') = 0.006562220926426234
# Fold 3 RMSLE for ('model1', 'model3') = 0.006651560880440609
# Fold 3 RMSLE for ('model1', 'model4') = 0.006589647183999092
# Fold 3 RMSLE for ('model2', 'model3') = 0.006614151926045101
# Fold 3 RMSLE for ('model2', 'model4') = 0.006572314046982783
# Fold 3 RMSLE for ('model3', 'model4') = 0.006649790564276526
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.006601018866104293
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.006568879772757098
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.006626505290146718
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.0066044464864109505
# Fold 3 RMSLE for all models ensemble = 0.006597010939210227
# Fold 3 best combination: ('model1', 'model2') with RMSLE = 0.006562220926426234
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.0064573535786705966
# Fold 4 RMSLE for model2 = 0.006538610924922414
# Fold 4 RMSLE for model3 = 0.006609991100029732
# Fold 4 RMSLE for model4 = 0.006600076917334059
# Fold 4 RMSLE for ('model1', 'model2') = 0.006440911732981013
# Fold 4 RMSLE for ('model1', 'model3') = 0.006521549596969488
# Fold 4 RMSLE for ('model1', 'model4') = 0.00650537819174048
# Fold 4 RMSLE for ('model2', 'model3') = 0.006499132605885378
# Fold 4 RMSLE for ('model2', 'model4') = 0.006540107028899312
# Fold 4 RMSLE for ('model3', 'model4') = 0.006578662954984628
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.006471097112611817
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.006483322998227604
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.006528289128674822
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.006524787718384221
# Fold 4 RMSLE for all models ensemble = 0.006495662139543299
# Fold 4 best combination: ('model1', 'model2') with RMSLE = 0.006440911732981013
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.007470477362735879
# Fold 5 RMSLE for model2 = 0.007287143734195383
# Fold 5 RMSLE for model3 = 0.0077375599747040264
# Fold 5 RMSLE for model4 = 0.007568963667253393
# Fold 5 RMSLE for ('model1', 'model2') = 0.0073527884911692805
# Fold 5 RMSLE for ('model1', 'model3') = 0.007595667248366179
# Fold 5 RMSLE for ('model1', 'model4') = 0.007508255220061439
# Fold 5 RMSLE for ('model2', 'model3') = 0.007473186266224841
# Fold 5 RMSLE for ('model2', 'model4') = 0.007412641378359906
# Fold 5 RMSLE for ('model3', 'model4') = 0.007639571876941099
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.0074658061992658046
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.007418736656244293
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.007577432766954542
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.007500916872742149
# Fold 5 RMSLE for all models ensemble = 0.0074875832054110344
# Fold 5 best combination: model2 with RMSLE = 0.007287143734195383
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.007971422954282133
# Fold 6 RMSLE for model2 = 0.007966349968602685
# Fold 6 RMSLE for model3 = 0.008040086942325515
# Fold 6 RMSLE for model4 = 0.008019437149127095
# Fold 6 RMSLE for ('model1', 'model2') = 0.007938038754775261
# Fold 6 RMSLE for ('model1', 'model3') = 0.007994604292973663
# Fold 6 RMSLE for ('model1', 'model4') = 0.0079858484578804
# Fold 6 RMSLE for ('model2', 'model3') = 0.0079606699216327
# Fold 6 RMSLE for ('model2', 'model4') = 0.007974922458541337
# Fold 6 RMSLE for ('model3', 'model4') = 0.008016056211399704
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.007955042963020596
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.007959793439601133
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.007995002384386997
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.007975644466957643
# Fold 6 RMSLE for all models ensemble = 0.007967879276823983
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.007938038754775261
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.009022485190280458
# Fold 7 RMSLE for model2 = 0.00871125188565721
# Fold 7 RMSLE for model3 = 0.0091752846319987
# Fold 7 RMSLE for model4 = 0.00906748379373804
# Fold 7 RMSLE for ('model1', 'model2') = 0.00883029504238648
# Fold 7 RMSLE for ('model1', 'model3') = 0.009090466132946557
# Fold 7 RMSLE for ('model1', 'model4') = 0.00903588287374996
# Fold 7 RMSLE for ('model2', 'model3') = 0.008894428241093376
# Fold 7 RMSLE for ('model2', 'model4') = 0.008867985880182536
# Fold 7 RMSLE for ('model3', 'model4') = 0.009107460940566843
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.008928164914806165
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.008904053027728821
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.00907443322418383
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.008947379930092805
# Fold 7 RMSLE for all models ensemble = 0.008959737817609299
# Fold 7 best combination: model2 with RMSLE = 0.00871125188565721
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.008312785669441073
# Fold 8 RMSLE for model2 = 0.008148953213532192
# Fold 8 RMSLE for model3 = 0.008381511920379099
# Fold 8 RMSLE for model4 = 0.008319201745023867
# Fold 8 RMSLE for ('model1', 'model2') = 0.008203676979267018
# Fold 8 RMSLE for ('model1', 'model3') = 0.008337957008419909
# Fold 8 RMSLE for ('model1', 'model4') = 0.008307686182206708
# Fold 8 RMSLE for ('model2', 'model3') = 0.008227716244448856
# Fold 8 RMSLE for ('model2', 'model4') = 0.008217828507470557
# Fold 8 RMSLE for ('model3', 'model4') = 0.008337846569496076
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.008248306522956515
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.008237352072552797
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.00832448986377211
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.008253797263166421
# Fold 8 RMSLE for all models ensemble = 0.00826292693667729
# Fold 8 best combination: model2 with RMSLE = 0.008148953213532192
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.007547326795803598
# Fold 9 RMSLE for model2 = 0.007303084550832985
# Fold 9 RMSLE for model3 = 0.00765223530501181
# Fold 9 RMSLE for model4 = 0.007612876235308956
# Fold 9 RMSLE for ('model1', 'model2') = 0.007393424793686615
# Fold 9 RMSLE for ('model1', 'model3') = 0.007588435339259489
# Fold 9 RMSLE for ('model1', 'model4') = 0.007570946312622073
# Fold 9 RMSLE for ('model2', 'model3') = 0.007431429849274156
# Fold 9 RMSLE for ('model2', 'model4') = 0.007434613537798317
# Fold 9 RMSLE for ('model3', 'model4') = 0.007621314346755738
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.007461300391588195
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.0074592871012232245
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.007590032307122443
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.007486941283466169
# Fold 9 RMSLE for all models ensemble = 0.007495756830363939
# Fold 9 best combination: model2 with RMSLE = 0.007303084550832985
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.008080792949095352
# Fold 10 RMSLE for model2 = 0.008180288070002538
# Fold 10 RMSLE for model3 = 0.008275973649184422
# Fold 10 RMSLE for model4 = 0.008165850034262278
# Fold 10 RMSLE for ('model1', 'model2') = 0.008103133898786525
# Fold 10 RMSLE for ('model1', 'model3') = 0.008168369711987906
# Fold 10 RMSLE for ('model1', 'model4') = 0.008112415194590376
# Fold 10 RMSLE for ('model2', 'model3') = 0.008185731652597979
# Fold 10 RMSLE for ('model2', 'model4') = 0.008152368476752488
# Fold 10 RMSLE for ('model3', 'model4') = 0.008208513042039216
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.008143497162383186
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.008116069449834904
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.00815939036633944
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.008173793106898263
# Fold 10 RMSLE for all models ensemble = 0.008144733524758424
# Fold 10 best combination: model1 with RMSLE = 0.008080792949095352
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.008064438892627415
# Fold 11 RMSLE for model2 = 0.008166611695531019
# Fold 11 RMSLE for model3 = 0.008161618102613689
# Fold 11 RMSLE for model4 = 0.008289172055807025
# Fold 11 RMSLE for ('model1', 'model2') = 0.008076301052959917
# Fold 11 RMSLE for ('model1', 'model3') = 0.008103778196823232
# Fold 11 RMSLE for ('model1', 'model4') = 0.008163557313571433
# Fold 11 RMSLE for ('model2', 'model3') = 0.008110191691216979
# Fold 11 RMSLE for ('model2', 'model4') = 0.008204718175042251
# Fold 11 RMSLE for ('model3', 'model4') = 0.008209567215674769
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.008085319651092444
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.008139831649625638
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.008154684908519842
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.008164574452175655
# Fold 11 RMSLE for all models ensemble = 0.008131813741257921
# Fold 11 best combination: model1 with RMSLE = 0.008064438892627415
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.006647600551679262
# Fold 12 RMSLE for model2 = 0.006441688137415286
# Fold 12 RMSLE for model3 = 0.006889026680661822
# Fold 12 RMSLE for model4 = 0.006765345637967794
# Fold 12 RMSLE for ('model1', 'model2') = 0.006509298660274805
# Fold 12 RMSLE for ('model1', 'model3') = 0.0067551583185923485
# Fold 12 RMSLE for ('model1', 'model4') = 0.006694334946216118
# Fold 12 RMSLE for ('model2', 'model3') = 0.006612750905937882
# Fold 12 RMSLE for ('model2', 'model4') = 0.006576786672006006
# Fold 12 RMSLE for ('model3', 'model4') = 0.0068139369380612
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.0066146453855549375
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.006585345756921814
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.006750184360855193
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.006657705644238902
# Fold 12 RMSLE for all models ensemble = 0.0066477876527387845
# Fold 12 best combination: model2 with RMSLE = 0.006441688137415286
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.007775586686604227
# Fold 13 RMSLE for model2 = 0.007759178743040372
# Fold 13 RMSLE for model3 = 0.007911943934398171
# Fold 13 RMSLE for model4 = 0.008011917837588456
# Fold 13 RMSLE for ('model1', 'model2') = 0.007722836507891242
# Fold 13 RMSLE for ('model1', 'model3') = 0.007831934452889338
# Fold 13 RMSLE for ('model1', 'model4') = 0.007877456755962263
# Fold 13 RMSLE for ('model2', 'model3') = 0.00777347270354373
# Fold 13 RMSLE for ('model2', 'model4') = 0.0078637400054739
# Fold 13 RMSLE for ('model3', 'model4') = 0.007937599321895923
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.007762943711291997
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.0078122717683984655
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.007876452869569993
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.007846361732546941
# Fold 13 RMSLE for all models ensemble = 0.007819516449420338
# Fold 13 best combination: ('model1', 'model2') with RMSLE = 0.007722836507891242
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.007579488974426644
# Fold 14 RMSLE for model2 = 0.007366673417903286
# Fold 14 RMSLE for model3 = 0.007795104605316392
# Fold 14 RMSLE for model4 = 0.007546659800979627
# Fold 14 RMSLE for ('model1', 'model2') = 0.007424534966751965
# Fold 14 RMSLE for ('model1', 'model3') = 0.007677168445702429
# Fold 14 RMSLE for ('model1', 'model4') = 0.007550631921026549
# Fold 14 RMSLE for ('model2', 'model3') = 0.007515961909280555
# Fold 14 RMSLE for ('model2', 'model4') = 0.00743112031386241
# Fold 14 RMSLE for ('model3', 'model4') = 0.007655006365504905
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.0075257268884761945
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.0074592272423903505
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.007623326320996562
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.007522247099116593
# Fold 14 RMSLE for all models ensemble = 0.007527763646395974
# Fold 14 best combination: model2 with RMSLE = 0.007366673417903286
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.007521988807749794
# Fold 15 RMSLE for model2 = 0.007531162348189683
# Fold 15 RMSLE for model3 = 0.007755559986404809
# Fold 15 RMSLE for model4 = 0.007667118482333947
# Fold 15 RMSLE for ('model1', 'model2') = 0.007488674644065825
# Fold 15 RMSLE for ('model1', 'model3') = 0.00762710259656433
# Fold 15 RMSLE for ('model1', 'model4') = 0.007581963760784884
# Fold 15 RMSLE for ('model2', 'model3') = 0.007593079791339217
# Fold 15 RMSLE for ('model2', 'model4') = 0.00757883751663199
# Fold 15 RMSLE for ('model3', 'model4') = 0.007696166540940229
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.007558540262150666
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.007542011036198819
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.007630681195435204
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.007613195052367244
# Fold 15 RMSLE for all models ensemble = 0.007582012685306013
# Fold 15 best combination: ('model1', 'model2') with RMSLE = 0.007488674644065825
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.005984045752234783
# Fold 16 RMSLE for model2 = 0.00578921225410401
# Fold 16 RMSLE for model3 = 0.006098212244422644
# Fold 16 RMSLE for model4 = 0.006044296619743277
# Fold 16 RMSLE for ('model1', 'model2') = 0.005855988195550524
# Fold 16 RMSLE for ('model1', 'model3') = 0.0060284479151687265
# Fold 16 RMSLE for ('model1', 'model4') = 0.00599968507380109
# Fold 16 RMSLE for ('model2', 'model3') = 0.005898074266830181
# Fold 16 RMSLE for ('model2', 'model4') = 0.005894750954413267
# Fold 16 RMSLE for ('model3', 'model4') = 0.006048545493883007
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.00591773486742128
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.005909411763052714
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.006019991820195996
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.005937118578384238
# Fold 16 RMSLE for all models ensemble = 0.005941980442646569
# Fold 16 best combination: model2 with RMSLE = 0.00578921225410401
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.007601303947756759
# Fold 17 RMSLE for model2 = 0.007471515883877362
# Fold 17 RMSLE for model3 = 0.007700065154945731
# Fold 17 RMSLE for model4 = 0.007613813214414407
# Fold 17 RMSLE for ('model1', 'model2') = 0.00750396913038435
# Fold 17 RMSLE for ('model1', 'model3') = 0.007637424876438833
# Fold 17 RMSLE for ('model1', 'model4') = 0.0075974625523082435
# Fold 17 RMSLE for ('model2', 'model3') = 0.007532598380094143
# Fold 17 RMSLE for ('model2', 'model4') = 0.007520097132180484
# Fold 17 RMSLE for ('model3', 'model4') = 0.007642627900247894
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.007547074669031006
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.0075333177013883566
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.007621642080561462
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.0075551449516358775
# Fold 17 RMSLE for all models ensemble = 0.007560268612303772
# Fold 17 best combination: model2 with RMSLE = 0.007471515883877362
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.0070942467051213366
# Fold 18 RMSLE for model2 = 0.007048021699577695
# Fold 18 RMSLE for model3 = 0.007281414511829063
# Fold 18 RMSLE for model4 = 0.007212013152703255
# Fold 18 RMSLE for ('model1', 'model2') = 0.007046676698741641
# Fold 18 RMSLE for ('model1', 'model3') = 0.0071768721767581254
# Fold 18 RMSLE for ('model1', 'model4') = 0.007143273512267675
# Fold 18 RMSLE for ('model2', 'model3') = 0.007125607645899939
# Fold 18 RMSLE for ('model2', 'model4') = 0.007114786090609916
# Fold 18 RMSLE for ('model3', 'model4') = 0.0072308106806492425
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.007108115711929918
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.007096107543541436
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.007179549877045512
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.007149278232923493
# Fold 18 RMSLE for all models ensemble = 0.007130060538823403
# Fold 18 best combination: ('model1', 'model2') with RMSLE = 0.007046676698741641
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.00857864206430686
# Fold 19 RMSLE for model2 = 0.008520389943059908
# Fold 19 RMSLE for model3 = 0.008694968866986914
# Fold 19 RMSLE for model4 = 0.008716431414885057
# Fold 19 RMSLE for ('model1', 'model2') = 0.008526501837968038
# Fold 19 RMSLE for ('model1', 'model3') = 0.008627618554354032
# Fold 19 RMSLE for ('model1', 'model4') = 0.008638205742119124
# Fold 19 RMSLE for ('model2', 'model3') = 0.008567773701282675
# Fold 19 RMSLE for ('model2', 'model4') = 0.008605097554110321
# Fold 19 RMSLE for ('model3', 'model4') = 0.00869095530037733
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.008565969483885917
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.008584895150770747
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.008648549381957887
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.008613767478681696
# Fold 19 RMSLE for all models ensemble = 0.008600267230914244
# Fold 19 best combination: model2 with RMSLE = 0.008520389943059908
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.00828010880525714
# Fold 20 RMSLE for model2 = 0.007977682307012237
# Fold 20 RMSLE for model3 = 0.00843450643153862
# Fold 20 RMSLE for model4 = 0.00828384491647362
# Fold 20 RMSLE for ('model1', 'model2') = 0.008090865431100408
# Fold 20 RMSLE for ('model1', 'model3') = 0.008348614272431533
# Fold 20 RMSLE for ('model1', 'model4') = 0.008272451062655005
# Fold 20 RMSLE for ('model2', 'model3') = 0.008150487967494437
# Fold 20 RMSLE for ('model2', 'model4') = 0.008106292016595176
# Fold 20 RMSLE for ('model3', 'model4') = 0.008344395009400905
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.00818550993251877
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.008148649360799686
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.008318144508560514
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.008189960042112102
# Fold 20 RMSLE for all models ensemble = 0.0082064450532673
# Fold 20 best combination: model2 with RMSLE = 0.007977682307012237
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.006929903162303736
# Fold 21 RMSLE for model2 = 0.0064991180713696185
# Fold 21 RMSLE for model3 = 0.0070708383309458405
# Fold 21 RMSLE for model4 = 0.006863367076211831
# Fold 21 RMSLE for ('model1', 'model2') = 0.006674453657454813
# Fold 21 RMSLE for ('model1', 'model3') = 0.006986186647707756
# Fold 21 RMSLE for ('model1', 'model4') = 0.006885319238275087
# Fold 21 RMSLE for ('model2', 'model3') = 0.006726848003791982
# Fold 21 RMSLE for ('model2', 'model4') = 0.006653027604574316
# Fold 21 RMSLE for ('model3', 'model4') = 0.006952650043278977
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.006783670180109876
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.0067289343271796035
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0069369297553658945
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.006766496828408956
# Fold 21 RMSLE for all models ensemble = 0.00679950423881243
# Fold 21 best combination: model2 with RMSLE = 0.0064991180713696185
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.007347893550259175
# Fold 22 RMSLE for model2 = 0.0069248418714271814
# Fold 22 RMSLE for model3 = 0.0076321349268802996
# Fold 22 RMSLE for model4 = 0.007290964638282367
# Fold 22 RMSLE for ('model1', 'model2') = 0.0071111494306429135
# Fold 22 RMSLE for ('model1', 'model3') = 0.007480579246891585
# Fold 22 RMSLE for ('model1', 'model4') = 0.007310480328461183
# Fold 22 RMSLE for ('model2', 'model3') = 0.007240185778528238
# Fold 22 RMSLE for ('model2', 'model4') = 0.007089807213843001
# Fold 22 RMSLE for ('model3', 'model4') = 0.007450691351853909
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.007269393606631344
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.0071647640949142315
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.007410658779714774
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.007252836597478814
# Fold 22 RMSLE for all models ensemble = 0.007271395688668475
# Fold 22 best combination: model2 with RMSLE = 0.0069248418714271814
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.007051559210328178
# Fold 23 RMSLE for model2 = 0.007045738476212137
# Fold 23 RMSLE for model3 = 0.0072936413698374445
# Fold 23 RMSLE for model4 = 0.00720981563589979
# Fold 23 RMSLE for ('model1', 'model2') = 0.00701922266334535
# Fold 23 RMSLE for ('model1', 'model3') = 0.007160344962465702
# Fold 23 RMSLE for ('model1', 'model4') = 0.007121550662023249
# Fold 23 RMSLE for ('model2', 'model3') = 0.00711853220480598
# Fold 23 RMSLE for ('model2', 'model4') = 0.007104358365782907
# Fold 23 RMSLE for ('model3', 'model4') = 0.007238642801369193
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.007089036822349731
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.007074862811389286
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.007169664182013084
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.007144168997425092
# Fold 23 RMSLE for all models ensemble = 0.007115600585662061
# Fold 23 best combination: ('model1', 'model2') with RMSLE = 0.00701922266334535
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.008259624622960317
# Fold 24 RMSLE for model2 = 0.008171261752479161
# Fold 24 RMSLE for model3 = 0.008473498149033908
# Fold 24 RMSLE for model4 = 0.00830043873114605
# Fold 24 RMSLE for ('model1', 'model2') = 0.008182705077037748
# Fold 24 RMSLE for ('model1', 'model3') = 0.00835420555147713
# Fold 24 RMSLE for ('model1', 'model4') = 0.008262841628163747
# Fold 24 RMSLE for ('model2', 'model3') = 0.008268988703466434
# Fold 24 RMSLE for ('model2', 'model4') = 0.008209525130773394
# Fold 24 RMSLE for ('model3', 'model4') = 0.008368815371551534
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.008257732130476479
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.008209898276684264
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.008323318239900507
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.008271579309480087
# Fold 24 RMSLE for all models ensemble = 0.0082611943228568
# Fold 24 best combination: model2 with RMSLE = 0.008171261752479161
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.007870217958569204
# Fold 25 RMSLE for model2 = 0.0075403087937957955
# Fold 25 RMSLE for model3 = 0.00813015859677598
# Fold 25 RMSLE for model4 = 0.007877828816676972
# Fold 25 RMSLE for ('model1', 'model2') = 0.007674303424387817
# Fold 25 RMSLE for ('model1', 'model3') = 0.007990639309550136
# Fold 25 RMSLE for ('model1', 'model4') = 0.007861031023027695
# Fold 25 RMSLE for ('model2', 'model3') = 0.007789910731785672
# Fold 25 RMSLE for ('model2', 'model4') = 0.007690718634004402
# Fold 25 RMSLE for ('model3', 'model4') = 0.007986150279125116
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.0078089391012674874
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.007735163614745487
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.007941444662127652
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.007813221785396415
# Fold 25 RMSLE for all models ensemble = 0.00782098763567813
# Fold 25 best combination: model2 with RMSLE = 0.0075403087937957955
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.007642127243372274
# Fold 26 RMSLE for model2 = 0.007597154967062602
# Fold 26 RMSLE for model3 = 0.007806921050482047
# Fold 26 RMSLE for model4 = 0.007704495946770794
# Fold 26 RMSLE for ('model1', 'model2') = 0.007589490451814644
# Fold 26 RMSLE for ('model1', 'model3') = 0.007712013192548657
# Fold 26 RMSLE for ('model1', 'model4') = 0.007661646902101586
# Fold 26 RMSLE for ('model2', 'model3') = 0.007651882521450343
# Fold 26 RMSLE for ('model2', 'model4') = 0.0076264945575099646
# Fold 26 RMSLE for ('model3', 'model4') = 0.0077420270844251685
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.007640828830084438
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.007618547113126302
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.007701013450249933
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.0076637008557607
# Fold 26 RMSLE for all models ensemble = 0.007652074580134516
# Fold 26 best combination: ('model1', 'model2') with RMSLE = 0.007589490451814644
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.006954630301534254
# Fold 27 RMSLE for model2 = 0.006989001777024437
# Fold 27 RMSLE for model3 = 0.00710299655223106
# Fold 27 RMSLE for model4 = 0.007069275005658121
# Fold 27 RMSLE for ('model1', 'model2') = 0.006933034192753854
# Fold 27 RMSLE for ('model1', 'model3') = 0.007016373353595423
# Fold 27 RMSLE for ('model1', 'model4') = 0.006999574793170147
# Fold 27 RMSLE for ('model2', 'model3') = 0.006988598441110201
# Fold 27 RMSLE for ('model2', 'model4') = 0.007008642020183918
# Fold 27 RMSLE for ('model3', 'model4') = 0.007068460547757853
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.006967243013025989
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.006972490515548841
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.007023394364568743
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007011304107951988
# Fold 27 RMSLE for all models ensemble = 0.006989189729460927
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.006933034192753854
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.008222261131985592
# Fold 28 RMSLE for model2 = 0.00820698028745709
# Fold 28 RMSLE for model3 = 0.00833939272242832
# Fold 28 RMSLE for model4 = 0.008284755890800693
# Fold 28 RMSLE for ('model1', 'model2') = 0.008176217964264619
# Fold 28 RMSLE for ('model1', 'model3') = 0.008269548411359429
# Fold 28 RMSLE for ('model1', 'model4') = 0.00823234095990985
# Fold 28 RMSLE for ('model2', 'model3') = 0.00821689397403121
# Fold 28 RMSLE for ('model2', 'model4') = 0.008223442950963961
# Fold 28 RMSLE for ('model3', 'model4') = 0.008287190579249452
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.00820912565638291
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.00820156274849224
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.00825664282084173
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.008230987360729265
# Fold 28 RMSLE for all models ensemble = 0.0082197311348941
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.008176217964264619
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.006394245138363768
# Fold 29 RMSLE for model2 = 0.00617945981468879
# Fold 29 RMSLE for model3 = 0.00660222192615381
# Fold 29 RMSLE for model4 = 0.006417737067043418
# Fold 29 RMSLE for ('model1', 'model2') = 0.006253684723018451
# Fold 29 RMSLE for ('model1', 'model3') = 0.006487553234346029
# Fold 29 RMSLE for ('model1', 'model4') = 0.006391508547235001
# Fold 29 RMSLE for ('model2', 'model3') = 0.006345247317732341
# Fold 29 RMSLE for ('model2', 'model4') = 0.006282096155727661
# Fold 29 RMSLE for ('model3', 'model4') = 0.006492599712008936
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.006352382786042542
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.006302021733661327
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.006452486718312114
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0063644898511477305
# Fold 29 RMSLE for all models ensemble = 0.006364052537129503
# Fold 29 best combination: model2 with RMSLE = 0.00617945981468879
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.008925409827241843
# Fold 30 RMSLE for model2 = 0.008745093400441502
# Fold 30 RMSLE for model3 = 0.009099793514676168
# Fold 30 RMSLE for model4 = 0.00900504886585825
# Fold 30 RMSLE for ('model1', 'model2') = 0.008801452383144715
# Fold 30 RMSLE for ('model1', 'model3') = 0.009000218666189486
# Fold 30 RMSLE for ('model1', 'model4') = 0.008948865941337354
# Fold 30 RMSLE for ('model2', 'model3') = 0.008872246409964589
# Fold 30 RMSLE for ('model2', 'model4') = 0.00885480479524159
# Fold 30 RMSLE for ('model3', 'model4') = 0.009034893884343448
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.008880685563462243
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.008860592094332535
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.008989510511341383
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.00891092164843268
# Fold 30 RMSLE for all models ensemble = 0.008906275321933154
# Fold 30 best combination: model2 with RMSLE = 0.008745093400441502
# ---------------
#
# OOF RMSLE = 0.007429538399101233
# Sum of RMSLE for each combination:
# ('model1',): 0.22585768155663394
# ('model2',): 0.22227479623375898
# ('model3',): 0.2307267964028748
# ('model4',): 0.22785848418837473
# ('model1', 'model2'): 0.22306191167708586
# ('model1', 'model3'): 0.22796338287782278
# ('model1', 'model4'): 0.22649224302626733
# ('model2', 'model3'): 0.22502045066424323
# ('model2', 'model4'): 0.2244337830739068
# ('model3', 'model4'): 0.22881615443795397
# ('model1', 'model2', 'model3'): 0.22503810031805727
# ('model1', 'model2', 'model4'): 0.22444168395025604
# ('model1', 'model3', 'model4'): 0.2276267167113201
# ('model2', 'model3', 'model4'): 0.22580379883120363
# ('model1', 'model2', 'model3', 'model4'): 0.22560926641214846
#
# 2番目の学習が終わりました。
#
# 推定時間は18
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.006414211545978631
# Fold 1 RMSLE for model2 = 0.006337193842806959
# Fold 1 RMSLE for model3 = 0.006407779327192089
# Fold 1 RMSLE for model4 = 0.0064236106438469755
# Fold 1 RMSLE for ('model1', 'model2') = 0.006359720776312323
# Fold 1 RMSLE for ('model1', 'model3') = 0.00640666988154932
# Fold 1 RMSLE for ('model1', 'model4') = 0.006414870524074162
# Fold 1 RMSLE for ('model2', 'model3') = 0.006350690756124973
# Fold 1 RMSLE for ('model2', 'model4') = 0.006368772037447147
# Fold 1 RMSLE for ('model3', 'model4') = 0.00641064442248491
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.006367706635779414
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.006377622062697308
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.006409236906996367
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.006372450545684064
# Fold 1 RMSLE for all models ensemble = 0.006380020588678341
# Fold 1 best combination: model2 with RMSLE = 0.006337193842806959
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.004891402235670773
# Fold 2 RMSLE for model2 = 0.005021138855780778
# Fold 2 RMSLE for model3 = 0.004915010665158272
# Fold 2 RMSLE for model4 = 0.004985507805671274
# Fold 2 RMSLE for ('model1', 'model2') = 0.004933470804080535
# Fold 2 RMSLE for ('model1', 'model3') = 0.004898568321409501
# Fold 2 RMSLE for ('model1', 'model4') = 0.0049340994422697885
# Fold 2 RMSLE for ('model2', 'model3') = 0.00493833036980113
# Fold 2 RMSLE for ('model2', 'model4') = 0.004986192096693704
# Fold 2 RMSLE for ('model3', 'model4') = 0.004943854628461241
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.004917021110663252
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.004946304940768587
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.004923792534026239
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.004950187593382406
# Fold 2 RMSLE for all models ensemble = 0.004931942456195377
# Fold 2 best combination: model1 with RMSLE = 0.004891402235670773
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.0056187433333825705
# Fold 3 RMSLE for model2 = 0.005579831272489985
# Fold 3 RMSLE for model3 = 0.005639666569874584
# Fold 3 RMSLE for model4 = 0.005651414954038065
# Fold 3 RMSLE for ('model1', 'model2') = 0.005582264509948943
# Fold 3 RMSLE for ('model1', 'model3') = 0.005624172039542346
# Fold 3 RMSLE for ('model1', 'model4') = 0.0056295953403473434
# Fold 3 RMSLE for ('model2', 'model3') = 0.0055878775750314
# Fold 3 RMSLE for ('model2', 'model4') = 0.005603899393944362
# Fold 3 RMSLE for ('model3', 'model4') = 0.0056396688098499775
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.005593238211975938
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.005601463618571001
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.005629322732334738
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.005606116371642579
# Fold 3 RMSLE for all models ensemble = 0.005605682352508989
# Fold 3 best combination: model2 with RMSLE = 0.005579831272489985
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.005514831751024455
# Fold 4 RMSLE for model2 = 0.005570576214120541
# Fold 4 RMSLE for model3 = 0.005564516350002067
# ...
# Fold 16 RMSLE for model2 = 0.0040525518378148806
# Fold 16 RMSLE for model3 = 0.003929896659043217
# Fold 16 RMSLE for model4 = 0.0039945568188455
# Fold 16 RMSLE for ('model1', 'model2') = 0.003988958651140413
# Fold 16 RMSLE for ('model1', 'model3') = 0.003938388526529362
# Fold 16 RMSLE for ('model1', 'model4') = 0.003966968038885643
# Fold 16 RMSLE for ('model2', 'model3') = 0.003977173434702626
# Fold 16 RMSLE for ('model2', 'model4') = 0.004014704241077692
# Fold 16 RMSLE for ('model3', 'model4') = 0.003957117618052266
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.003965071546489615
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.003987302433777777
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.0039528679601853085
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.003979871658128963
# Fold 16 RMSLE for all models ensemble = 0.0039699711945219785
# Fold 16 best combination: model3 with RMSLE = 0.003929896659043217
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.005164547535588347
# Fold 17 RMSLE for model2 = 0.005164850798754014
# Fold 17 RMSLE for model3 = 0.0051537389110139185
# Fold 17 RMSLE for model4 = 0.005204545742270307
# Fold 17 RMSLE for ('model1', 'model2') = 0.005153436729073268
# Fold 17 RMSLE for ('model1', 'model3') = 0.005158055474679292
# Fold 17 RMSLE for ('model1', 'model4') = 0.005182127129468205
# Fold 17 RMSLE for ('model2', 'model3') = 0.005145743515953229
# Fold 17 RMSLE for ('model2', 'model4') = 0.0051760352663538034
# Fold 17 RMSLE for ('model3', 'model4') = 0.005176145475986051
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.005149533216578452
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.005168056154409344
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.005171384588030022
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.005163181541524594
# Fold 17 RMSLE for all models ensemble = 0.005161930581185885
# Fold 17 best combination: ('model2', 'model3') with RMSLE = 0.005145743515953229
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.004475222919985032
# Fold 18 RMSLE for model2 = 0.004526585526149068
# Fold 18 RMSLE for model3 = 0.00447426894987789
# Fold 18 RMSLE for model4 = 0.004496867923241813
# Fold 18 RMSLE for ('model1', 'model2') = 0.004490650492240299
# Fold 18 RMSLE for ('model1', 'model3') = 0.004473755728468295
# Fold 18 RMSLE for ('model1', 'model4') = 0.004483815784323842
# Fold 18 RMSLE for ('model2', 'model3') = 0.004488915370574656
# Fold 18 RMSLE for ('model2', 'model4') = 0.0045036009458860864
# Fold 18 RMSLE for ('model3', 'model4') = 0.004483151075979237
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.004481895607405292
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.004490390374217668
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.004479613420427094
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.004489429866495301
# Fold 18 RMSLE for all models ensemble = 0.0044843397555295855
# Fold 18 best combination: ('model1', 'model3') with RMSLE = 0.004473755728468295
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.005071357586324863
# Fold 19 RMSLE for model2 = 0.0052580776712843405
# Fold 19 RMSLE for model3 = 0.005054137937442648
# Fold 19 RMSLE for model4 = 0.005162074765721937
# Fold 19 RMSLE for ('model1', 'model2') = 0.005152620420403412
# Fold 19 RMSLE for ('model1', 'model3') = 0.005061829265660863
# Fold 19 RMSLE for ('model1', 'model4') = 0.005112802900328828
# Fold 19 RMSLE for ('model2', 'model3') = 0.005142036705018502
# Fold 19 RMSLE for ('model2', 'model4') = 0.0052017836798823455
# Fold 19 RMSLE for ('model3', 'model4') = 0.005104147795749338
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.005115751904092441
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.005153015860575681
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.005091941138179648
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.0051463792193124965
# Fold 19 RMSLE for all models ensemble = 0.005125551152991426
# Fold 19 best combination: model3 with RMSLE = 0.005054137937442648
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.004956476296363965
# Fold 20 RMSLE for model2 = 0.004991078774622149
# Fold 20 RMSLE for model3 = 0.004944849920303329
# Fold 20 RMSLE for model4 = 0.0050141151302551526
# Fold 20 RMSLE for ('model1', 'model2') = 0.0049629318217810385
# Fold 20 RMSLE for ('model1', 'model3') = 0.0049497468993555975
# Fold 20 RMSLE for ('model1', 'model4') = 0.004980728730744072
# Fold 20 RMSLE for ('model2', 'model3') = 0.0049554944699032885
# Fold 20 RMSLE for ('model2', 'model4') = 0.004996964143746082
# Fold 20 RMSLE for ('model3', 'model4') = 0.004974656656919966
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.004953353330413361
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.00497787472826625
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.0049672247905279505
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.00497316556005211
# Fold 20 RMSLE for all models ensemble = 0.004966812919950831
# Fold 20 best combination: model3 with RMSLE = 0.004944849920303329
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.004384700199419128
# Fold 21 RMSLE for model2 = 0.004344156462104024
# Fold 21 RMSLE for model3 = 0.004345724353769024
# Fold 21 RMSLE for model4 = 0.004394181445836582
# Fold 21 RMSLE for ('model1', 'model2') = 0.004353612315991584
# Fold 21 RMSLE for ('model1', 'model3') = 0.004363816866631482
# Fold 21 RMSLE for ('model1', 'model4') = 0.004386129463032819
# Fold 21 RMSLE for ('model2', 'model3') = 0.00433252151523768
# Fold 21 RMSLE for ('model2', 'model4') = 0.004361166856724549
# Fold 21 RMSLE for ('model3', 'model4') = 0.004366732835073172
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.004347255976461301
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.004364519460395798
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0043713434659784335
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.004350857548106902
# Fold 21 RMSLE for all models ensemble = 0.004357411020946124
# Fold 21 best combination: ('model2', 'model3') with RMSLE = 0.00433252151523768
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0046124254825600985
# Fold 22 RMSLE for model2 = 0.004638396351428832
# Fold 22 RMSLE for model3 = 0.00463709960575998
# Fold 22 RMSLE for model4 = 0.004627664952330949
# Fold 22 RMSLE for ('model1', 'model2') = 0.004614208035089233
# Fold 22 RMSLE for ('model1', 'model3') = 0.004623824602257445
# Fold 22 RMSLE for ('model1', 'model4') = 0.004616714645505817
# Fold 22 RMSLE for ('model2', 'model3') = 0.004625257388371999
# Fold 22 RMSLE for ('model2', 'model4') = 0.00462538024613739
# Fold 22 RMSLE for ('model3', 'model4') = 0.004629033225737936
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.004618354929803405
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.004616299345985573
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.004622344068803646
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0046239436194469115
# Fold 22 RMSLE for all models ensemble = 0.004619151388345858
# Fold 22 best combination: model1 with RMSLE = 0.0046124254825600985
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.004329539147238091
# Fold 23 RMSLE for model2 = 0.004415826483081307
# Fold 23 RMSLE for model3 = 0.00433376903967055
# Fold 23 RMSLE for model4 = 0.004386860125242758
# Fold 23 RMSLE for ('model1', 'model2') = 0.004359114347285043
# Fold 23 RMSLE for ('model1', 'model3') = 0.004330547146034487
# Fold 23 RMSLE for ('model1', 'model4') = 0.004353773544730139
# Fold 23 RMSLE for ('model2', 'model3') = 0.004359992715940674
# Fold 23 RMSLE for ('model2', 'model4') = 0.004393575079186598
# Fold 23 RMSLE for ('model3', 'model4') = 0.004355967743655652
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.004346572404228308
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.004365953138614461
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.004345658695810015
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.004366849288760859
# Fold 23 RMSLE for all models ensemble = 0.004354971001486301
# Fold 23 best combination: model1 with RMSLE = 0.004329539147238091
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.005155305017883081
# Fold 24 RMSLE for model2 = 0.0051806595902174095
# Fold 24 RMSLE for model3 = 0.005118960595866832
# Fold 24 RMSLE for model4 = 0.005182675105494439
# Fold 24 RMSLE for ('model1', 'model2') = 0.00515512199750725
# Fold 24 RMSLE for ('model1', 'model3') = 0.005135720682969968
# Fold 24 RMSLE for ('model1', 'model4') = 0.005160390630373237
# Fold 24 RMSLE for ('model2', 'model3') = 0.005134041155867172
# Fold 24 RMSLE for ('model2', 'model4') = 0.005171751543256114
# Fold 24 RMSLE for ('model3', 'model4') = 0.005142246560355975
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.0051382767551447685
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.00515893171869442
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.005144044924177556
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.005145540211250368
# Fold 24 RMSLE for all models ensemble = 0.0051451067110994
# Fold 24 best combination: model3 with RMSLE = 0.005118960595866832
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.005169177288084564
# Fold 25 RMSLE for model2 = 0.005204907330616992
# Fold 25 RMSLE for model3 = 0.005160816290374074
# Fold 25 RMSLE for model4 = 0.005193448832482323
# Fold 25 RMSLE for ('model1', 'model2') = 0.005177687838941119
# Fold 25 RMSLE for ('model1', 'model3') = 0.0051640462396959986
# Fold 25 RMSLE for ('model1', 'model4') = 0.005178779040271219
# Fold 25 RMSLE for ('model2', 'model3') = 0.005171807301194212
# Fold 25 RMSLE for ('model2', 'model4') = 0.005193420863945698
# Fold 25 RMSLE for ('model3', 'model4') = 0.005174109863798899
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.005168797235910194
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.005181333279406621
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.005171587181556016
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.005177574504799417
# Fold 25 RMSLE for all models ensemble = 0.005173913082149004
# Fold 25 best combination: model3 with RMSLE = 0.005160816290374074
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.004812197979141234
# Fold 26 RMSLE for model2 = 0.004866103854620686
# Fold 26 RMSLE for model3 = 0.004799608089407117
# Fold 26 RMSLE for model4 = 0.0048500631732441655
# Fold 26 RMSLE for ('model1', 'model2') = 0.004830654925768101
# Fold 26 RMSLE for ('model1', 'model3') = 0.004804764651025213
# Fold 26 RMSLE for ('model1', 'model4') = 0.004827689446871933
# Fold 26 RMSLE for ('model2', 'model3') = 0.004822326907849609
# Fold 26 RMSLE for ('model2', 'model4') = 0.004851434071592575
# Fold 26 RMSLE for ('model3', 'model4') = 0.004820699359966268
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.004816993699937603
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.004834523657269862
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.004816745838715426
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.004829115969076645
# Fold 26 RMSLE for all models ensemble = 0.004823385327718681
# Fold 26 best combination: model3 with RMSLE = 0.004799608089407117
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.004303247834479433
# Fold 27 RMSLE for model2 = 0.004401773507374458
# Fold 27 RMSLE for model3 = 0.004275901300766821
# Fold 27 RMSLE for model4 = 0.004350838661293791
# Fold 27 RMSLE for ('model1', 'model2') = 0.0043384291613900935
# Fold 27 RMSLE for ('model1', 'model3') = 0.004288281382632
# Fold 27 RMSLE for ('model1', 'model4') = 0.0043228383755662125
# Fold 27 RMSLE for ('model2', 'model3') = 0.004322609718931074
# Fold 27 RMSLE for ('model2', 'model4') = 0.004367490572209433
# Fold 27 RMSLE for ('model3', 'model4') = 0.00430849601650836
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.0043128778028498
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.004339894307983911
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.0043053795307498935
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.0043295307343673645
# Fold 27 RMSLE for all models ensemble = 0.004320531870282558
# Fold 27 best combination: model3 with RMSLE = 0.004275901300766821
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.0052196946745651325
# Fold 28 RMSLE for model2 = 0.005268079021293188
# Fold 28 RMSLE for model3 = 0.005178947377585673
# Fold 28 RMSLE for model4 = 0.005251759566404779
# Fold 28 RMSLE for ('model1', 'model2') = 0.005230346695773186
# Fold 28 RMSLE for ('model1', 'model3') = 0.005198226402644713
# Fold 28 RMSLE for ('model1', 'model4') = 0.005226374200155299
# Fold 28 RMSLE for ('model2', 'model3') = 0.005208411107745491
# Fold 28 RMSLE for ('model2', 'model4') = 0.005251270245906177
# Fold 28 RMSLE for ('model3', 'model4') = 0.005205887245583351
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.005209000301036119
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.005232490001271953
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.005207937757042199
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.005218167609936345
# Fold 28 RMSLE for all models ensemble = 0.005215303137679835
# Fold 28 best combination: model3 with RMSLE = 0.005178947377585673
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.003995555273026192
# Fold 29 RMSLE for model2 = 0.004016559544553528
# Fold 29 RMSLE for model3 = 0.004003505903368574
# Fold 29 RMSLE for model4 = 0.0040813499348253445
# Fold 29 RMSLE for ('model1', 'model2') = 0.0039930560828882735
# Fold 29 RMSLE for ('model1', 'model3') = 0.003998380777366658
# Fold 29 RMSLE for ('model1', 'model4') = 0.004033918238392448
# Fold 29 RMSLE for ('model2', 'model3') = 0.003995981794442632
# Fold 29 RMSLE for ('model2', 'model4') = 0.004040257414563732
# Fold 29 RMSLE for ('model3', 'model4') = 0.004037929150839263
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.003992665398739513
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.004019508856661244
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.004022267593666951
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.004021711380257811
# Fold 29 RMSLE for all models ensemble = 0.00401276462438343
# Fold 29 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.003992665398739513
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.005371642579963356
# Fold 30 RMSLE for model2 = 0.005511191074949094
# Fold 30 RMSLE for model3 = 0.005368880704890072
# Fold 30 RMSLE for model4 = 0.0054242371783609
# Fold 30 RMSLE for ('model1', 'model2') = 0.00542778359058136
# Fold 30 RMSLE for ('model1', 'model3') = 0.005369090681301673
# Fold 30 RMSLE for ('model1', 'model4') = 0.005394825866891839
# Fold 30 RMSLE for ('model2', 'model3') = 0.005423581281407546
# Fold 30 RMSLE for ('model2', 'model4') = 0.005458808936846891
# Fold 30 RMSLE for ('model3', 'model4') = 0.005393048891541206
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.0054032928473308674
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.005424268341429302
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.0053847857264428135
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.005421918121346791
# Fold 30 RMSLE for all models ensemble = 0.005407250244322816
# Fold 30 best combination: model3 with RMSLE = 0.005368880704890072
# ---------------
#
# OOF RMSLE = 0.00473247070103378
# Sum of RMSLE for each combination:
# ('model1',): 0.14214705487077858
# ('model2',): 0.14393523124771992
# ('model3',): 0.1415699171022934
# ('model4',): 0.1433373620673708
# ('model1', 'model2'): 0.14269023519423557
# ('model1', 'model3'): 0.14182482766885202
# ('model1', 'model4'): 0.14261918656793462
# ('model2', 'model3'): 0.14235042145217544
# ('model2', 'model4'): 0.14339923134860225
# ('model3', 'model4'): 0.14232521078238994
# ('model1', 'model2', 'model3'): 0.14220031897030608
# ('model1', 'model2', 'model4'): 0.1428237120403476
# ('model1', 'model3', 'model4'): 0.14222457003538413
# ('model2', 'model3', 'model4'): 0.14260620172311314
# ('model1', 'model2', 'model3', 'model4'): 0.14242807210950217
#
# 9番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 7158                          NaN                          NaN           240
# 7159                          NaN                          NaN             4
# 7160                       25,069                       24,560           132
# 7161                       93,119                      130,327            98
# 7162                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 7158                                 110,523
# 7159                                     NaN
# 7160                                 166,520
# 7161                                  71,774
# 7162                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 7158                                  98,955
# 7159                                     NaN
# 7160                                 469,733
# 7161                                 936,032
# 7162                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 7158                               3,467,008
# 7159                                     NaN
# 7160                                  82,559
# 7161                                 336,961
# 7162                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 7158                                 147,802        39        -76
# 7159                                     NaN        31       -102
# 7160                                  85,775        41        -96
# 7161                                 156,640        39        -93
# 7162                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 7158                              NaN                              NaN
# 7159                              NaN                              NaN
# 7160                              636                            1,477
# 7161                           16,356                          -47,698
# 7162                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 7158                              NaN                               NaN
# 7159                              NaN                               NaN
# 7160                             -509                                 0
# 7161                           37,208                                 0
# 7162                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 7158                               NaN                               NaN
# 7159                               NaN                               NaN
# 7160                                 0                                -0
# 7161                                -0                                 0
# 7162                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,077     0
# 1                  14            1           58,419     0
# 2                   9            1           99,027     0
# 3                  15            1           51,624    -0
# 4                  15            0           50,750    -0
# ...               ...          ...              ...   ...
# 7158                1            1              NaN     0
# 7159                9            1              NaN     0
# 7160                8            0              NaN     0
# 7161                8            0              NaN     0
# 7162                9            1              NaN     0
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,077     0
# 1                  14            1           58,419     0
# 2                   9            1           99,027     0
# 3                  15            1           51,624    -0
# 4                  15            0           50,750    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,565    -0
# 4651                8            1          169,509     0
# 4652                8            0           31,755    -0
# 4653                8            0           65,607     0
# 4654                9            1          145,827    -0
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, -0.00)

# %%
train_df_GHG14
# Out:
# 0       42,214
# 1       58,500
# 2       99,409
# 3       51,623
# 4       50,638
#          ...
# 4650    49,222
# 4651   169,634
# 4652    31,716
# 4653    65,663
# 4654   145,438
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                          26,446                       23,385           130
# 3                          43,906                       42,958            82
# 4                          40,203                       39,437           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           45,552     0
# 1                  14            1          290,210    -0
# 2                   8            0           41,312     0
# 3                   8            0           28,568    -0
# 4                   8            0           49,042     0
# ...               ...          ...              ...   ...
# 2503                1            1          552,418     0
# 2504                9            1           98,450    -0
# 2505                8            0          141,511     0
# 2506                8            0          260,575    -0
# 2507                9            1        1,473,196     0
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**4, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**4, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232567.6312974383

# %%
def after_act(preds):
    r = preds.copy()
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            r[i] = np.expm1(np.log1p(r[i])*100/102)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**4, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**4, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 229156.6695619464

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_70.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,552
# 1     4656   290,210
# 2     4657    41,312
# 3     4658    23,362
# 4     4659    49,042
# ...    ...       ...
# 2503  7158   552,418
# 2504  7159    98,450
# 2505  7160   141,511
# 2506  7161   260,575
# 2507  7162 1,473,196
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,154,496
# 43    4698 1,193,294
# 110   4765 1,381,919
# 114   4769 1,302,297
# 148   4803 1,741,301
# ...    ...       ...
# 2417  7072 1,242,508
# 2423  7078 1,205,260
# 2466  7121 1,677,227
# 2490  7145 1,421,060
# 2507  7162 1,473,196
#
# [112 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Fri Nov 29 04:04:57 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,077     0
# 1                  14            1           58,419     0
# 2                   9            1           99,027     0
# 3                  15            1           51,624    -0
# 4                  15            0           50,750    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,565    -0
# 4651                8            1          169,509     0
# 4652                8            0           31,755    -0
# 4653                8            0           65,607     0
# 4654                9            1          145,827    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.005808778221662193

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,077     0
# 1                  14            1           58,419     0
# 2                   9            1           99,027     0
# 3                  15            1           51,624    -0
# 4                  15            0           50,750    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,565    -0
# 4651                8            1          169,509     0
# 4652                8            0           31,755    -0
# 4653                8            0           65,607     0
# 4654                9            1          145,827    -0
#
# [4655 rows x 19 columns]
