# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/034_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = abs(np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions']))

# 2. 条件を満たす行のマスクを作成
mask = diff > 1.00

# 3. 除外する行の数をカウント
exclude_num = mask.sum()

# 4. 条件を満たさない行だけを保持
train_all_df = train_all_df[~mask].reset_index(drop=True)

# 5. 'oof_predictions' 列を削除
train_all_df.drop('oof_predictions', axis=1, inplace=True)

# 6. 結果の表示
print(f"除外された行数: {exclude_num}")
# Out:
# 除外された行数: 658

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 6500                          NaN                          NaN
# 6501                          NaN                          NaN
# 6502                 23592.402994                 25069.498286
# 6503                140816.449347                 93118.705227
# 6504                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 6500                          NaN           240
# 6501                          NaN             4
# 6502                 24560.172725           132
# 6503                130326.946431            98
# 6504                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6500                           110523.066755
# 6501                                     NaN
# 6502                           166520.232511
# 6503                            71773.803649
# 6504                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6500                            98954.793233
# 6501                                     NaN
# 6502                           469732.826538
# 6503                           936031.894142
# 6504                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6500                            3.467008e+06
# 6501                                     NaN
# 6502                            8.255855e+04
# 6503                            3.369613e+05
# 6504                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6500                           147802.356027  38.651945  -75.914445
# 6501                                     NaN  31.361795 -101.776403
# 6502                            85775.307153  41.005565  -96.154917
# 6503                           156640.371706  39.364417  -93.449361
# 6504                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6500                              NaN                              NaN
# 6501                              NaN                              NaN
# 6502                       636.277440                      1477.095292
# 6503                     16355.554326                    -47697.744120
# 6504                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6500                              NaN                               NaN
# 6501                              NaN                               NaN
# 6502                      -509.325561                          0.027717
# 6503                     37208.241204                          0.131411
# 6504                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6500                               NaN                               NaN
# 6501                               NaN                               NaN
# 6502                          0.062609                         -0.020317
# 6503                         -0.338723                          0.399579
# 6504                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                   9            1                              5.567954e+04
# 3                  15            1                              6.141190e+04
# 4                  15            0                              4.310047e+04
# ...               ...          ...                                       ...
# 6500                1            1                              5.497954e+05
# 6501                9            1                              1.137684e+05
# 6502                8            0                              1.412656e+05
# 6503                8            0                              2.599965e+05
# 6504                9            1                              1.293278e+06
#
# [6505 rows x 19 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)

        test_predictions += test_preds / kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                    26644.986107                 23410.379903
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    28337.832145                 30840.825454
# ...                           ...                          ...
# 6500                          NaN                          NaN
# 6501                          NaN                          NaN
# 6502                 23592.402994                 25069.498286
# 6503                140816.449347                 93118.705227
# 6504                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    31809.857564           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                    25153.901905            21
# ...                           ...           ...
# 6500                          NaN           240
# 6501                          NaN             4
# 6502                 24560.172725           132
# 6503                130326.946431            98
# 6504                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6500                           110523.066755
# 6501                                     NaN
# 6502                           166520.232511
# 6503                            71773.803649
# 6504                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6500                            98954.793233
# 6501                                     NaN
# 6502                           469732.826538
# 6503                           936031.894142
# 6504                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6500                            3.467008e+06
# 6501                                     NaN
# 6502                            8.255855e+04
# 6503                            3.369613e+05
# 6504                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6500                           147802.356027  38.651945  -75.914445
# 6501                                     NaN  31.361795 -101.776403
# 6502                            85775.307153  41.005565  -96.154917
# 6503                           156640.371706  39.364417  -93.449361
# 6504                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6500                              NaN                              NaN
# 6501                              NaN                              NaN
# 6502                       636.277440                      1477.095292
# 6503                     16355.554326                    -47697.744120
# 6504                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6500                              NaN                               NaN
# 6501                              NaN                               NaN
# 6502                      -509.325561                          0.027717
# 6503                     37208.241204                          0.131411
# 6504                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6500                               NaN                               NaN
# 6501                               NaN                               NaN
# 6502                          0.062609                         -0.020317
# 6503                         -0.338723                          0.399579
# 6504                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                              5.297314e+04
# 1                  14            1                              5.591007e+04
# 2                   9            1                              5.567954e+04
# 3                  15            1                              6.141190e+04
# 4                  15            0                              4.310047e+04
# ...               ...          ...                                       ...
# 6500                1            1                              5.497954e+05
# 6501                9            1                              1.137684e+05
# 6502                8            0                              1.412656e+05
# 6503                8            0                              2.599965e+05
# 6504                9            1                              1.293278e+06
#
# [6505 rows x 19 columns]

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    32075.140635                 26445.792090
# 3                    42503.897432                 43906.102080
# 4                    39897.800897                 40203.428231
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 23592.402994                 25069.498286
# 2506                140816.449347                 93118.705227
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                    23385.161510           130
# 3                    42958.306538            82
# 4                    39437.099224           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                 24560.172725           132
# 2506                130326.946431            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing
# 0                   9            1
# 1                  14            1
# 2                   8            0
# 3                   8            0
# 4                   8            0
# ...               ...          ...
# 2503                1            1
# 2504                9            1
# 2505                8            0
# 2506                8            0
# 2507                9            1
#
# [2508 rows x 18 columns]

# %%
train = train_all_df.iloc[:, :-1].values
test = test_df.values
target = train_all_df.iloc[:, -1].values

# %%
oof_predictions,test_preds = get_models_trained(train,test,target,30)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.3520915118124541
# Fold 1 RMSLE for model2 = 0.34318476045531265
# Fold 1 RMSLE for model3 = 0.3483316511818036
# Fold 1 RMSLE for model4 = 0.34663490820347853
# Fold 1 RMSLE for ('model1', 'model2') = 0.34583713678004363
# Fold 1 RMSLE for ('model1', 'model3') = 0.349789223699428
# Fold 1 RMSLE for ('model1', 'model4') = 0.3482869230857094
# Fold 1 RMSLE for ('model2', 'model3') = 0.34345340130746804
# Fold 1 RMSLE for ('model2', 'model4') = 0.344019803962848
# Fold 1 RMSLE for ('model3', 'model4') = 0.34574176724308764
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.34584845808032194
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.3456235631163863
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.3475789688877126
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.34385728051066583
# Fold 1 RMSLE for all models ensemble = 0.3454960896170914
# Fold 1 best combination: model2 with RMSLE = 0.34318476045531265
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.3342855663814994
# Fold 2 RMSLE for model2 = 0.33151444202895275
# Fold 2 RMSLE for model3 = 0.33606376745737265
# Fold 2 RMSLE for model4 = 0.3348516053149913
# Fold 2 RMSLE for ('model1', 'model2') = 0.33120359963741264
# Fold 2 RMSLE for ('model1', 'model3') = 0.3347315320859342
# Fold 2 RMSLE for ('model1', 'model4') = 0.3335009338141788
# Fold 2 RMSLE for ('model2', 'model3') = 0.33183511795574994
# Fold 2 RMSLE for ('model2', 'model4') = 0.332267293363449
# Fold 2 RMSLE for ('model3', 'model4') = 0.33400260550581445
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.3321477579359474
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.3318999766368879
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.333758723279184
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.3322108602827566
# Fold 2 RMSLE for all models ensemble = 0.3322953116342974
# Fold 2 best combination: ('model1', 'model2') with RMSLE = 0.33120359963741264
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.3582896542920043
# Fold 3 RMSLE for model2 = 0.3526890080353303
# Fold 3 RMSLE for model3 = 0.35423826175776507
# Fold 3 RMSLE for model4 = 0.3524439759177829
# Fold 3 RMSLE for ('model1', 'model2') = 0.353394324853457
# Fold 3 RMSLE for ('model1', 'model3') = 0.3556145914758849
# Fold 3 RMSLE for ('model1', 'model4') = 0.3539556521936548
# Fold 3 RMSLE for ('model2', 'model3') = 0.35057598337449464
# Fold 3 RMSLE for ('model2', 'model4') = 0.3516941766079085
# Fold 3 RMSLE for ('model3', 'model4') = 0.3509689944502108
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.35255928213328086
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.35254691534553906
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.35301304835048775
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.35044947145118677
# Fold 3 RMSLE for all models ensemble = 0.3518660959885976
# Fold 3 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.35044947145118677
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.4087472056729569
# Fold 4 RMSLE for model2 = 0.4208287068856736
# Fold 4 RMSLE for model3 = 0.4082422684425717
# Fold 4 RMSLE for model4 = 0.41234073019052175
# Fold 4 RMSLE for ('model1', 'model2') = 0.4129383693564551
# Fold 4 RMSLE for ('model1', 'model3') = 0.4080735915946752
# Fold 4 RMSLE for ('model1', 'model4') = 0.40951574111496103
# Fold 4 RMSLE for ('model2', 'model3') = 0.412537006098369
# Fold 4 RMSLE for ('model2', 'model4') = 0.41585983446695557
# Fold 4 RMSLE for ('model3', 'model4') = 0.40899014414208557
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.4106790251613172
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.4123749775552381
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.40855310425600444
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.412015219801351
# Fold 4 RMSLE for all models ensemble = 0.4106980761714023
# Fold 4 best combination: ('model1', 'model3') with RMSLE = 0.4080735915946752
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.3866456442504987
# Fold 5 RMSLE for model2 = 0.3726023550792689
# Fold 5 RMSLE for model3 = 0.38819801943185894
# Fold 5 RMSLE for model4 = 0.37973342646855696
# Fold 5 RMSLE for ('model1', 'model2') = 0.377510718815699
# Fold 5 RMSLE for ('model1', 'model3') = 0.38711604677788564
# Fold 5 RMSLE for ('model1', 'model4') = 0.3816659696999416
# Fold 5 RMSLE for ('model2', 'model3') = 0.37837512777415633
# Fold 5 RMSLE for ('model2', 'model4') = 0.37513393099387726
# Fold 5 RMSLE for ('model3', 'model4') = 0.3822393215354524
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.3804691098913065
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.3776036199676129
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.3832471482595092
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.3780531592400506
# Fold 5 RMSLE for all models ensemble = 0.3795942617163553
# Fold 5 best combination: model2 with RMSLE = 0.3726023550792689
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.3310539540617891
# Fold 6 RMSLE for model2 = 0.3349390039563507
# Fold 6 RMSLE for model3 = 0.3315676278088496
# Fold 6 RMSLE for model4 = 0.3359272814470418
# Fold 6 RMSLE for ('model1', 'model2') = 0.33066757019047055
# Fold 6 RMSLE for ('model1', 'model3') = 0.33091024860085205
# Fold 6 RMSLE for ('model1', 'model4') = 0.33211645315735366
# Fold 6 RMSLE for ('model2', 'model3') = 0.330790688335978
# Fold 6 RMSLE for ('model2', 'model4') = 0.33387897577240877
# Fold 6 RMSLE for ('model3', 'model4') = 0.3319504652244739
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.3302232680766779
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.33162814978277133
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.3312612890750304
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.33155684878271247
# Fold 6 RMSLE for all models ensemble = 0.33089172363357233
# Fold 6 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.3302232680766779
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.36641468971559715
# Fold 7 RMSLE for model2 = 0.3679542302369388
# Fold 7 RMSLE for model3 = 0.3664884858234727
# Fold 7 RMSLE for model4 = 0.3617299185052736
# Fold 7 RMSLE for ('model1', 'model2') = 0.3654854482857572
# Fold 7 RMSLE for ('model1', 'model3') = 0.3660333699117594
# Fold 7 RMSLE for ('model1', 'model4') = 0.3629540243084971
# Fold 7 RMSLE for ('model2', 'model3') = 0.3655636971920258
# Fold 7 RMSLE for ('model2', 'model4') = 0.3633891300469784
# Fold 7 RMSLE for ('model3', 'model4') = 0.3624587159290672
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.365273361231307
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.36346153489844546
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.36345875780120257
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.36326451110622676
# Fold 7 RMSLE for all models ensemble = 0.3636389608648552
# Fold 7 best combination: model4 with RMSLE = 0.3617299185052736
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.3528440802788182
# Fold 8 RMSLE for model2 = 0.3453205217982482
# Fold 8 RMSLE for model3 = 0.3481632877807148
# Fold 8 RMSLE for model4 = 0.3505867580259993
# Fold 8 RMSLE for ('model1', 'model2') = 0.3476987429100229
# Fold 8 RMSLE for ('model1', 'model3') = 0.35005609954146955
# Fold 8 RMSLE for ('model1', 'model4') = 0.3507296326723394
# Fold 8 RMSLE for ('model2', 'model3') = 0.3449542873274196
# Fold 8 RMSLE for ('model2', 'model4') = 0.3471190800688069
# Fold 8 RMSLE for ('model3', 'model4') = 0.34775079172038503
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.3471712488216542
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.3481567919192764
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.3491700559001926
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.3461410011034735
# Fold 8 RMSLE for all models ensemble = 0.34746438547923947
# Fold 8 best combination: ('model2', 'model3') with RMSLE = 0.3449542873274196
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.3987864635746703
# Fold 9 RMSLE for model2 = 0.39270329177170527
# Fold 9 RMSLE for model3 = 0.38975949491684636
# Fold 9 RMSLE for model4 = 0.39459190771736213
# Fold 9 RMSLE for ('model1', 'model2') = 0.3941598777729082
# Fold 9 RMSLE for ('model1', 'model3') = 0.39393977860022716
# Fold 9 RMSLE for ('model1', 'model4') = 0.39573696744362574
# Fold 9 RMSLE for ('model2', 'model3') = 0.3896959674511994
# Fold 9 RMSLE for ('model2', 'model4') = 0.39273950051469053
# Fold 9 RMSLE for ('model3', 'model4') = 0.3909054652311434
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.3922183697600852
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.39382024088699097
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.39324807009781493
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.39069130064065294
# Fold 9 RMSLE for all models ensemble = 0.39231024059298447
# Fold 9 best combination: ('model2', 'model3') with RMSLE = 0.3896959674511994
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.33946633354347366
# Fold 10 RMSLE for model2 = 0.3524668793531586
# Fold 10 RMSLE for model3 = 0.34435303533643186
# Fold 10 RMSLE for model4 = 0.3443050205149121
# Fold 10 RMSLE for ('model1', 'model2') = 0.3439706484924695
# Fold 10 RMSLE for ('model1', 'model3') = 0.34155812217833587
# Fold 10 RMSLE for ('model1', 'model4') = 0.3406411523287249
# Fold 10 RMSLE for ('model2', 'model3') = 0.3465659777940201
# Fold 10 RMSLE for ('model2', 'model4') = 0.3469873279866327
# Fold 10 RMSLE for ('model3', 'model4') = 0.34281437815707877
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.34353963655378084
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.3433385771072828
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.3413085008206882
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.34490128915906315
# Fold 10 RMSLE for all models ensemble = 0.3430255663910834
# Fold 10 best combination: model1 with RMSLE = 0.33946633354347366
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.38939881082871985
# Fold 11 RMSLE for model2 = 0.3782016536174566
# Fold 11 RMSLE for model3 = 0.38965098095001116
# Fold 11 RMSLE for model4 = 0.3823395256382833
# Fold 11 RMSLE for ('model1', 'model2') = 0.3805513275029349
# Fold 11 RMSLE for ('model1', 'model3') = 0.38929285738253777
# Fold 11 RMSLE for ('model1', 'model4') = 0.3836094871619841
# Fold 11 RMSLE for ('model2', 'model3') = 0.3806902219503968
# Fold 11 RMSLE for ('model2', 'model4') = 0.3790516642323764
# Fold 11 RMSLE for ('model3', 'model4') = 0.38343127017922657
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.38258868659104595
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.3804177929005919
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.38477877362067653
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.3803717150882741
# Fold 11 RMSLE for all models ensemble = 0.3816835055348917
# Fold 11 best combination: model2 with RMSLE = 0.3782016536174566
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.3454046345831124
# Fold 12 RMSLE for model2 = 0.35102731648363256
# Fold 12 RMSLE for model3 = 0.34367350985415945
# Fold 12 RMSLE for model4 = 0.35317207407941903
# Fold 12 RMSLE for ('model1', 'model2') = 0.3464331379548406
# Fold 12 RMSLE for ('model1', 'model3') = 0.3440797442238249
# Fold 12 RMSLE for ('model1', 'model4') = 0.3482730534118271
# Fold 12 RMSLE for ('model2', 'model3') = 0.345356085481392
# Fold 12 RMSLE for ('model2', 'model4') = 0.3509427232536842
# Fold 12 RMSLE for ('model3', 'model4') = 0.34687788060158653
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.3448199985949026
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.3481134264626455
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.3460648442886555
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.3472163009702747
# Fold 12 RMSLE for all models ensemble = 0.3463341144101654
# Fold 12 best combination: model3 with RMSLE = 0.34367350985415945
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.32632385070351305
# Fold 13 RMSLE for model2 = 0.3314448353714069
# Fold 13 RMSLE for model3 = 0.3268521181546608
# Fold 13 RMSLE for model4 = 0.33127972732098343
# Fold 13 RMSLE for ('model1', 'model2') = 0.3267312181229464
# Fold 13 RMSLE for ('model1', 'model3') = 0.32622212321940663
# Fold 13 RMSLE for ('model1', 'model4') = 0.3273324817140043
# Fold 13 RMSLE for ('model2', 'model3') = 0.3266909165896412
# Fold 13 RMSLE for ('model2', 'model4') = 0.33028568711617107
# Fold 13 RMSLE for ('model3', 'model4') = 0.32708903349760543
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.32597578667949206
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.3275897344247974
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.326447204265646
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.32740651636594076
# Fold 13 RMSLE for all models ensemble = 0.3265847585533835
# Fold 13 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.32597578667949206
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.36478493374246285
# Fold 14 RMSLE for model2 = 0.3589969995140309
# Fold 14 RMSLE for model3 = 0.3635829246142138
# Fold 14 RMSLE for model4 = 0.36101261023209624
# Fold 14 RMSLE for ('model1', 'model2') = 0.3590653236470287
# Fold 14 RMSLE for ('model1', 'model3') = 0.36378518019608885
# Fold 14 RMSLE for ('model1', 'model4') = 0.3613020719734189
# Fold 14 RMSLE for ('model2', 'model3') = 0.3582590361784075
# Fold 14 RMSLE for ('model2', 'model4') = 0.35872361616694115
# Fold 14 RMSLE for ('model3', 'model4') = 0.36040761283263395
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.3596271006517383
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.35907853705041975
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.36137776393909343
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.3584426527102417
# Fold 14 RMSLE for all models ensemble = 0.35931854985584544
# Fold 14 best combination: ('model2', 'model3') with RMSLE = 0.3582590361784075
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.35437772656723643
# Fold 15 RMSLE for model2 = 0.3536924275092252
# Fold 15 RMSLE for model3 = 0.3563145434041029
# Fold 15 RMSLE for model4 = 0.35726890538972567
# Fold 15 RMSLE for ('model1', 'model2') = 0.3518326605328308
# Fold 15 RMSLE for ('model1', 'model3') = 0.3548781390426815
# Fold 15 RMSLE for ('model1', 'model4') = 0.3546880931784198
# Fold 15 RMSLE for ('model2', 'model3') = 0.35283482230000246
# Fold 15 RMSLE for ('model2', 'model4') = 0.3544900662639077
# Fold 15 RMSLE for ('model3', 'model4') = 0.35514379826451287
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.3526198268017875
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.35320003862405686
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.3545381616684981
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.3536299183508782
# Fold 15 RMSLE for all models ensemble = 0.35325650476128284
# Fold 15 best combination: ('model1', 'model2') with RMSLE = 0.3518326605328308
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.3311450670983952
# Fold 16 RMSLE for model2 = 0.3353068172829726
# Fold 16 RMSLE for model3 = 0.33360595364740125
# Fold 16 RMSLE for model4 = 0.3329411602588876
# Fold 16 RMSLE for ('model1', 'model2') = 0.3309387276739715
# Fold 16 RMSLE for ('model1', 'model3') = 0.33182229152426956
# Fold 16 RMSLE for ('model1', 'model4') = 0.3307052861782171
# Fold 16 RMSLE for ('model2', 'model3') = 0.33192043631216817
# Fold 16 RMSLE for ('model2', 'model4') = 0.3328327680177892
# Fold 16 RMSLE for ('model3', 'model4') = 0.3313424618164837
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.330963161184646
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.330927398337318
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.3308690217685899
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.3313752280354135
# Fold 16 RMSLE for all models ensemble = 0.330752614938714
# Fold 16 best combination: ('model1', 'model4') with RMSLE = 0.3307052861782171
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.3828701577854135
# Fold 17 RMSLE for model2 = 0.37792320548205705
# Fold 17 RMSLE for model3 = 0.3840033997459404
# Fold 17 RMSLE for model4 = 0.38068914750014166
# Fold 17 RMSLE for ('model1', 'model2') = 0.37855600524284505
# Fold 17 RMSLE for ('model1', 'model3') = 0.3830019651771344
# Fold 17 RMSLE for ('model1', 'model4') = 0.38067378668811125
# Fold 17 RMSLE for ('model2', 'model3') = 0.3783234934103457
# Fold 17 RMSLE for ('model2', 'model4') = 0.37820395844185867
# Fold 17 RMSLE for ('model3', 'model4') = 0.3804127466904022
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.37940164235969653
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.3787076839952399
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.3809758441930882
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.37837718893057143
# Fold 17 RMSLE for all models ensemble = 0.3791191937223517
# Fold 17 best combination: model2 with RMSLE = 0.37792320548205705
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.30335851241062356
# Fold 18 RMSLE for model2 = 0.29605585516502375
# Fold 18 RMSLE for model3 = 0.30120870100023905
# Fold 18 RMSLE for model4 = 0.2985849968778724
# Fold 18 RMSLE for ('model1', 'model2') = 0.2971438805686625
# Fold 18 RMSLE for ('model1', 'model3') = 0.3016919717466875
# Fold 18 RMSLE for ('model1', 'model4') = 0.29964541978303944
# Fold 18 RMSLE for ('model2', 'model3') = 0.2957914072839756
# Fold 18 RMSLE for ('model2', 'model4') = 0.29564035920037945
# Fold 18 RMSLE for ('model3', 'model4') = 0.29820250072176996
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.2975399937921939
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.29686174104411533
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.2994491675274751
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.29585950661581784
# Fold 18 RMSLE for all models ensemble = 0.297131950892676
# Fold 18 best combination: ('model2', 'model4') with RMSLE = 0.29564035920037945
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.38250666336577244
# Fold 19 RMSLE for model2 = 0.3853473260988799
# Fold 19 RMSLE for model3 = 0.3815294957326365
# Fold 19 RMSLE for model4 = 0.38721990762311786
# Fold 19 RMSLE for ('model1', 'model2') = 0.3819252880218744
# Fold 19 RMSLE for ('model1', 'model3') = 0.38164048474069895
# Fold 19 RMSLE for ('model1', 'model4') = 0.38376232896105605
# Fold 19 RMSLE for ('model2', 'model3') = 0.38112318728849837
# Fold 19 RMSLE for ('model2', 'model4') = 0.38508026598621564
# Fold 19 RMSLE for ('model3', 'model4') = 0.38280126350992183
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.38102894063250375
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.3831265334502099
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.38238618736105273
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.3824599264031838
# Fold 19 RMSLE for all models ensemble = 0.3820159904652377
# Fold 19 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.38102894063250375
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.331160920441194
# Fold 20 RMSLE for model2 = 0.3239273542347862
# Fold 20 RMSLE for model3 = 0.3294165458017718
# Fold 20 RMSLE for model4 = 0.32891317312405527
# Fold 20 RMSLE for ('model1', 'model2') = 0.3248806359192428
# Fold 20 RMSLE for ('model1', 'model3') = 0.3298422233697508
# Fold 20 RMSLE for ('model1', 'model4') = 0.32868092708921975
# Fold 20 RMSLE for ('model2', 'model3') = 0.32409321915456485
# Fold 20 RMSLE for ('model2', 'model4') = 0.32507928086472365
# Fold 20 RMSLE for ('model3', 'model4') = 0.32759000958949874
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.32559922154618154
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.3256356944272261
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.3283220720797211
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.3249813443801199
# Fold 20 RMSLE for all models ensemble = 0.32585427717648224
# Fold 20 best combination: model2 with RMSLE = 0.3239273542347862
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.33197950007948535
# Fold 21 RMSLE for model2 = 0.32606375747623184
# Fold 21 RMSLE for model3 = 0.3296903009049779
# Fold 21 RMSLE for model4 = 0.330829481019024
# Fold 21 RMSLE for ('model1', 'model2') = 0.3266982989118053
# Fold 21 RMSLE for ('model1', 'model3') = 0.33023212595657464
# Fold 21 RMSLE for ('model1', 'model4') = 0.3299139158139151
# Fold 21 RMSLE for ('model2', 'model3') = 0.32563939740061026
# Fold 21 RMSLE for ('model2', 'model4') = 0.3269522294472954
# Fold 21 RMSLE for ('model3', 'model4') = 0.32839136383232614
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.32692490526782453
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.3272784163451608
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.32906398473922766
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.3263760822004573
# Fold 21 RMSLE for all models ensemble = 0.3271308500277299
# Fold 21 best combination: ('model2', 'model3') with RMSLE = 0.32563939740061026
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.3755315000579759
# Fold 22 RMSLE for model2 = 0.3649952018934306
# Fold 22 RMSLE for model3 = 0.3758191265536089
# Fold 22 RMSLE for model4 = 0.37061146269416223
# Fold 22 RMSLE for ('model1', 'model2') = 0.36784785240616014
# Fold 22 RMSLE for ('model1', 'model3') = 0.37533061617710217
# Fold 22 RMSLE for ('model1', 'model4') = 0.37174072911122186
# Fold 22 RMSLE for ('model2', 'model3') = 0.3684589624036553
# Fold 22 RMSLE for ('model2', 'model4') = 0.3667825758929122
# Fold 22 RMSLE for ('model3', 'model4') = 0.37199969318121634
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.37002373854342546
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.36827000544996047
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.3726966769647936
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.368613867225339
# Fold 22 RMSLE for all models ensemble = 0.369672251678331
# Fold 22 best combination: model2 with RMSLE = 0.3649952018934306
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.36039827505822886
# Fold 23 RMSLE for model2 = 0.35557495846328135
# Fold 23 RMSLE for model3 = 0.3615528113899132
# Fold 23 RMSLE for model4 = 0.35689430342269673
# Fold 23 RMSLE for ('model1', 'model2') = 0.3556905295523326
# Fold 23 RMSLE for ('model1', 'model3') = 0.36065902817010176
# Fold 23 RMSLE for ('model1', 'model4') = 0.3572731505098606
# Fold 23 RMSLE for ('model2', 'model3') = 0.3561629823351529
# Fold 23 RMSLE for ('model2', 'model4') = 0.35519763823437817
# Fold 23 RMSLE for ('model3', 'model4') = 0.3574739369529027
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.35688908743967723
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.35556189689066225
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.35805250623939017
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.35573523731869205
# Fold 23 RMSLE for all models ensemble = 0.35630322399450587
# Fold 23 best combination: ('model2', 'model4') with RMSLE = 0.35519763823437817
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.3626103247567295
# Fold 24 RMSLE for model2 = 0.35530622746615853
# Fold 24 RMSLE for model3 = 0.36231174413647615
# Fold 24 RMSLE for model4 = 0.36140467601848913
# Fold 24 RMSLE for ('model1', 'model2') = 0.3576116634345642
# Fold 24 RMSLE for ('model1', 'model3') = 0.3621110496057241
# Fold 24 RMSLE for ('model1', 'model4') = 0.3611088855090914
# Fold 24 RMSLE for ('model2', 'model3') = 0.3573251208242704
# Fold 24 RMSLE for ('model2', 'model4') = 0.35738649855443455
# Fold 24 RMSLE for ('model3', 'model4') = 0.3608685478794536
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.3586673755323874
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.3583515365352487
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.36111261716074944
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.35815078519936666
# Fold 24 RMSLE for all models ensemble = 0.358905773305002
# Fold 24 best combination: model2 with RMSLE = 0.35530622746615853
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.3814444372972211
# Fold 25 RMSLE for model2 = 0.38361432519056304
# Fold 25 RMSLE for model3 = 0.3795191565985027
# Fold 25 RMSLE for model4 = 0.38374855673709807
# Fold 25 RMSLE for ('model1', 'model2') = 0.38064531149898334
# Fold 25 RMSLE for ('model1', 'model3') = 0.38015875768247076
# Fold 25 RMSLE for ('model1', 'model4') = 0.38170030263918975
# Fold 25 RMSLE for ('model2', 'model3') = 0.3793900250447581
# Fold 25 RMSLE for ('model2', 'model4') = 0.3825726554881907
# Fold 25 RMSLE for ('model3', 'model4') = 0.3802501868190692
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.3795926693219693
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.3812127385600413
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.3804143791867543
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.38022851952292475
# Fold 25 RMSLE for all models ensemble = 0.3801518645429331
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.3793900250447581
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.33319923467066387
# Fold 26 RMSLE for model2 = 0.3281744143540978
# Fold 26 RMSLE for model3 = 0.33190093634992934
# Fold 26 RMSLE for model4 = 0.3255828787566007
# Fold 26 RMSLE for ('model1', 'model2') = 0.3282269280989036
# Fold 26 RMSLE for ('model1', 'model3') = 0.3318682363437348
# Fold 26 RMSLE for ('model1', 'model4') = 0.3278777852983075
# Fold 26 RMSLE for ('model2', 'model3') = 0.3268922414101377
# Fold 26 RMSLE for ('model2', 'model4') = 0.32567582279462703
# Fold 26 RMSLE for ('model3', 'model4') = 0.326562154120944
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.3282869747326095
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.3267022749243935
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.3282794413818455
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.32567229288435673
# Fold 26 RMSLE for all models ensemble = 0.32693015702902245
# Fold 26 best combination: model4 with RMSLE = 0.3255828787566007
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.3475493813182764
# Fold 27 RMSLE for model2 = 0.3450915224772903
# Fold 27 RMSLE for model3 = 0.348598095333838
# Fold 27 RMSLE for model4 = 0.343361900395578
# Fold 27 RMSLE for ('model1', 'model2') = 0.3447184309028606
# Fold 27 RMSLE for ('model1', 'model3') = 0.3477208864116002
# Fold 27 RMSLE for ('model1', 'model4') = 0.34413370389230613
# Fold 27 RMSLE for ('model2', 'model3') = 0.34509845578049997
# Fold 27 RMSLE for ('model2', 'model4') = 0.3431613075854221
# Fold 27 RMSLE for ('model3', 'model4') = 0.3441292363037082
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.34544125983101914
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.3435563831963217
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.3449372649698682
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.3436142372755188
# Fold 27 RMSLE for all models ensemble = 0.34416846130020956
# Fold 27 best combination: ('model2', 'model4') with RMSLE = 0.3431613075854221
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.35753039063245806
# Fold 28 RMSLE for model2 = 0.35300483784919756
# Fold 28 RMSLE for model3 = 0.3583506079602753
# Fold 28 RMSLE for model4 = 0.3520936651767039
# Fold 28 RMSLE for ('model1', 'model2') = 0.35305339253496615
# Fold 28 RMSLE for ('model1', 'model3') = 0.35767337462083637
# Fold 28 RMSLE for ('model1', 'model4') = 0.35358889265227206
# Fold 28 RMSLE for ('model2', 'model3') = 0.35338688327446083
# Fold 28 RMSLE for ('model2', 'model4') = 0.35170467441265185
# Fold 28 RMSLE for ('model3', 'model4') = 0.35382279402924577
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.3541441634203879
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.3523238841059133
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.3546921580422764
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.35248818236787205
# Fold 28 RMSLE for all models ensemble = 0.353182969198787
# Fold 28 best combination: ('model2', 'model4') with RMSLE = 0.35170467441265185
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.3272673190929375
# Fold 29 RMSLE for model2 = 0.3275996937101528
# Fold 29 RMSLE for model3 = 0.3282730387542789
# Fold 29 RMSLE for model4 = 0.33017838389763626
# Fold 29 RMSLE for ('model1', 'model2') = 0.32525093397534716
# Fold 29 RMSLE for ('model1', 'model3') = 0.32729428944119876
# Fold 29 RMSLE for ('model1', 'model4') = 0.3272055985253884
# Fold 29 RMSLE for ('model2', 'model3') = 0.32534337650297956
# Fold 29 RMSLE for ('model2', 'model4') = 0.3277454155494889
# Fold 29 RMSLE for ('model3', 'model4') = 0.3269426678394543
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.3253809870998051
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.3261931802145792
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.3266605407411708
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.32602057535657814
# Fold 29 RMSLE for all models ensemble = 0.3257818566745229
# Fold 29 best combination: ('model1', 'model2') with RMSLE = 0.32525093397534716
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.35336399312083644
# Fold 30 RMSLE for model2 = 0.3535568163937051
# Fold 30 RMSLE for model3 = 0.3530602744127495
# Fold 30 RMSLE for model4 = 0.35052562371036045
# Fold 30 RMSLE for ('model1', 'model2') = 0.3504290237498079
# Fold 30 RMSLE for ('model1', 'model3') = 0.35291775458272745
# Fold 30 RMSLE for ('model1', 'model4') = 0.35057927629632374
# Fold 30 RMSLE for ('model2', 'model3') = 0.35040007374518045
# Fold 30 RMSLE for ('model2', 'model4') = 0.350499528195247
# Fold 30 RMSLE for ('model3', 'model4') = 0.35032144783819974
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.35051325021406854
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.3498482220385487
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.35092029408888603
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.34974406834901606
# Fold 30 RMSLE for all models ensemble = 0.3499550119929887
# Fold 30 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.34974406834901606
# ---------------
#
# OOF RMSLE = 0.3512952845176517
# Sum of RMSLE for each combination:
# ('model1',): 10.67083073719502
# ('model2',): 10.599108745634522
# ('model3',): 10.654320165237378
# ('model4',): 10.631797692178852
# ('model1', 'model2'): 10.571097007347602
# ('model1', 'model3'): 10.650045704081602
# ('model1', 'model4'): 10.61289862620616
# ('model2', 'model3'): 10.557527599281977
# ('model2', 'model4'): 10.581097789483252
# ('model3', 'model4'): 10.59188325563896
# ('model1', 'model2', 'model3'): 10.576158287883043
# ('model1', 'model2', 'model4'): 10.573411466193884
# ('model1', 'model3', 'model4'): 10.606636570955285
# ('model2', 'model3', 'model4'): 10.559905087628977
# ('model1', 'model2', 'model3', 'model4'): 10.57151459214454

# %%
import seaborn as sns
import matplotlib.pyplot as plt
target = target.flatten()
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=oof_predictions, y=target, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([target.min(), target.max()], [target.min(), target.max()], 'r--')  # 45度線
plt.show()

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
test_preds.shape
# Out:
# (2508,)

# %%
submit [ 1 ]  =  test_preds
submit.to_csv('SMBC_34.csv', index = False)

# %%
submit
# Out:
#          0             1
# 0     4655  4.388449e+04
# 1     4656  2.952435e+05
# 2     4657  4.044300e+04
# 3     4658  3.090965e+04
# 4     4659  4.641123e+04
# ...    ...           ...
# 2503  7158  5.075950e+05
# 2504  7159  1.003275e+05
# 2505  7160  1.332195e+05
# 2506  7161  2.553612e+05
# 2507  7162  1.352602e+06
#
# [2508 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2503    1
# 2504    1
# 2505    0
# 2506    0
# 2507    1
# Name: num_missing, Length: 2508, dtype: int64

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(oof_predictions, target, "oof_predictions, target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
show_plot(np.log(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(test_preds),
          "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Fri Nov 22 16:49:06 2024
