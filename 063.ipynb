# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/063.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 4.221442e+04  0.015936
# 1                                 5.849961e+04 -0.014376
# 2                                 9.940945e+04  0.002905
# 3                                 5.162331e+04  0.003356
# 4                                 5.063790e+04 -0.008299
# ...                                        ...       ...
# 2503                              5.375020e+05  0.027199
# 2504                              9.933916e+04 -0.009746
# 2505                              1.379589e+05  0.022125
# 2506                              2.612069e+05 -0.005393
# 2507                              1.383562e+06  0.065402
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.154699e+04  0.015936
# 1                  14            1     5.934671e+04 -0.014376
# 2                   9            1     9.912108e+04  0.002905
# 3                  15            1     5.145036e+04  0.003356
# 4                  15            0     5.105989e+04 -0.008299
# ...               ...          ...              ...       ...
# 2503                1            1     5.230794e+05  0.027199
# 2504                9            1     1.003121e+05 -0.009746
# 2505                8            0     1.349400e+05  0.022125
# 2506                8            0     2.626193e+05 -0.005393
# 2507                9            1     1.295969e+06  0.065402
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
for i in range(10):
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_target = train_df.iloc[:, -1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train, test, train_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+oof_predictions)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+oof_predictions)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}回目の推論が終了しました。\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 17 RMSLE for ('model1', 'model3') = 0.02036715292935932
# Fold 17 RMSLE for ('model1', 'model4') = 0.02021691846770268
# Fold 17 RMSLE for ('model2', 'model3') = 0.019548109969000645
# Fold 17 RMSLE for ('model2', 'model4') = 0.019459217463759268
# Fold 17 RMSLE for ('model3', 'model4') = 0.020346164730018535
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.01976351724056819
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.01968788458865075
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.020301046539116366
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.019760530930269717
# Fold 17 RMSLE for all models ensemble = 0.01986829482926891
# Fold 17 best combination: model2 with RMSLE = 0.01882975869405746
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.019626350260187563
# Fold 18 RMSLE for model2 = 0.01911250265946104
# Fold 18 RMSLE for model3 = 0.01941440382724805
# Fold 18 RMSLE for model4 = 0.01940085783359308
# Fold 18 RMSLE for ('model1', 'model2') = 0.01920543706324229
# Fold 18 RMSLE for ('model1', 'model3') = 0.019482819051199144
# Fold 18 RMSLE for ('model1', 'model4') = 0.01940207178450046
# Fold 18 RMSLE for ('model2', 'model3') = 0.019057205955545536
# Fold 18 RMSLE for ('model2', 'model4') = 0.019151688825652182
# Fold 18 RMSLE for ('model3', 'model4') = 0.019273354688628983
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.019203657469523936
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.019210618827617074
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.019354658728698015
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.019111095730220563
# Fold 18 RMSLE for all models ensemble = 0.019198952145118128
# Fold 18 best combination: ('model2', 'model3') with RMSLE = 0.019057205955545536
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.015697441318285512
# Fold 19 RMSLE for model2 = 0.015211760906909738
# Fold 19 RMSLE for model3 = 0.015782607074422632
# Fold 19 RMSLE for model4 = 0.015608052101913615
# Fold 19 RMSLE for ('model1', 'model2') = 0.015281730794782903
# Fold 19 RMSLE for ('model1', 'model3') = 0.015653471324555357
# Fold 19 RMSLE for ('model1', 'model4') = 0.015594606424077308
# Fold 19 RMSLE for ('model2', 'model3') = 0.01528238789936443
# Fold 19 RMSLE for ('model2', 'model4') = 0.015274830915773526
# Fold 19 RMSLE for ('model3', 'model4') = 0.015643247294703167
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.015353455429008261
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.015343313405013439
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.015608490423786259
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.01535589808861274
# Fold 19 RMSLE for all models ensemble = 0.015395474825353507
# Fold 19 best combination: model2 with RMSLE = 0.015211760906909738
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.01556778306311248
# Fold 20 RMSLE for model2 = 0.014423927910174689
# Fold 20 RMSLE for model3 = 0.015388646090362968
# Fold 20 RMSLE for model4 = 0.015179999906623947
# Fold 20 RMSLE for ('model1', 'model2') = 0.014903290287999521
# Fold 20 RMSLE for ('model1', 'model3') = 0.015436443801120263
# Fold 20 RMSLE for ('model1', 'model4') = 0.015293839397414525
# Fold 20 RMSLE for ('model2', 'model3') = 0.014813106450510594
# Fold 20 RMSLE for ('model2', 'model4') = 0.01473160430055437
# Fold 20 RMSLE for ('model3', 'model4') = 0.015232905570076817
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.015026139931571933
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.014949102677412727
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.015301809030214641
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.014902148533905098
# Fold 20 RMSLE for all models ensemble = 0.015032954520946471
# Fold 20 best combination: model2 with RMSLE = 0.014423927910174689
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.01630388821250801
# Fold 21 RMSLE for model2 = 0.01663938020573021
# Fold 21 RMSLE for model3 = 0.01611305725680212
# Fold 21 RMSLE for model4 = 0.01654861325624846
# Fold 21 RMSLE for ('model1', 'model2') = 0.016393050880561998
# Fold 21 RMSLE for ('model1', 'model3') = 0.01617375757832449
# Fold 21 RMSLE for ('model1', 'model4') = 0.01640800450650612
# Fold 21 RMSLE for ('model2', 'model3') = 0.016245413589825508
# Fold 21 RMSLE for ('model2', 'model4') = 0.016540885683370445
# Fold 21 RMSLE for ('model3', 'model4') = 0.01629316682875813
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.01624338394078471
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.016430595335844615
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.016281609730777028
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.01633527335526655
# Fold 21 RMSLE for all models ensemble = 0.01631288088084943
# Fold 21 best combination: model3 with RMSLE = 0.01611305725680212
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.016806424678981767
# Fold 22 RMSLE for model2 = 0.016067254404846607
# Fold 22 RMSLE for model3 = 0.017340932016933208
# Fold 22 RMSLE for model4 = 0.017233877728678976
# Fold 22 RMSLE for ('model1', 'model2') = 0.016368405004386008
# Fold 22 RMSLE for ('model1', 'model3') = 0.017042745469724913
# Fold 22 RMSLE for ('model1', 'model4') = 0.01697109539787257
# Fold 22 RMSLE for ('model2', 'model3') = 0.016625028058789168
# Fold 22 RMSLE for ('model2', 'model4') = 0.016566507813897704
# Fold 22 RMSLE for ('model3', 'model4') = 0.017216597982007212
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.01665921552157368
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.0166130760212468
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.017059919296505806
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.016776759095768444
# Fold 22 RMSLE for all models ensemble = 0.016766681246039215
# Fold 22 best combination: model2 with RMSLE = 0.016067254404846607
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.02209471554052409
# Fold 23 RMSLE for model2 = 0.022562083225292517
# Fold 23 RMSLE for model3 = 0.022568211842394246
# Fold 23 RMSLE for model4 = 0.022640979576280956
# Fold 23 RMSLE for ('model1', 'model2') = 0.022280022101066815
# Fold 23 RMSLE for ('model1', 'model3') = 0.022311818575908582
# Fold 23 RMSLE for ('model1', 'model4') = 0.022352902651662496
# Fold 23 RMSLE for ('model2', 'model3') = 0.02249806990089463
# Fold 23 RMSLE for ('model2', 'model4') = 0.022569260142719122
# Fold 23 RMSLE for ('model3', 'model4') = 0.022582134661235025
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.022348181353961428
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.022390113319693757
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.022409260602236494
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.02253630180805062
# Fold 23 RMSLE for all models ensemble = 0.022415258476209128
# Fold 23 best combination: model1 with RMSLE = 0.02209471554052409
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.018542613939594648
# Fold 24 RMSLE for model2 = 0.019109445243138606
# Fold 24 RMSLE for model3 = 0.01643089679272784
# Fold 24 RMSLE for model4 = 0.020537298687779416
# Fold 24 RMSLE for ('model1', 'model2') = 0.018684926905924836
# Fold 24 RMSLE for ('model1', 'model3') = 0.017413637273299278
# Fold 24 RMSLE for ('model1', 'model4') = 0.01944640470020061
# Fold 24 RMSLE for ('model2', 'model3') = 0.017547516974939333
# Fold 24 RMSLE for ('model2', 'model4') = 0.019744795372127838
# Fold 24 RMSLE for ('model3', 'model4') = 0.018323109941528574
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.017832967708373594
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.019257911238759133
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.01835741318199896
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.018490564297934532
# Fold 24 RMSLE for all models ensemble = 0.01846385217476367
# Fold 24 best combination: model3 with RMSLE = 0.01643089679272784
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.01711220488712423
# Fold 25 RMSLE for model2 = 0.016383691385390788
# Fold 25 RMSLE for model3 = 0.017011772478275875
# Fold 25 RMSLE for model4 = 0.017054747447251658
# Fold 25 RMSLE for ('model1', 'model2') = 0.0165548549707935
# Fold 25 RMSLE for ('model1', 'model3') = 0.016918319522515927
# Fold 25 RMSLE for ('model1', 'model4') = 0.01691167175730207
# Fold 25 RMSLE for ('model2', 'model3') = 0.01634463813274695
# Fold 25 RMSLE for ('model2', 'model4') = 0.016632525307789726
# Fold 25 RMSLE for ('model3', 'model4') = 0.016770355631932313
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.016529793013504553
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.016649049827341895
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.016802194466335404
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.016504011399760737
# Fold 25 RMSLE for all models ensemble = 0.016587430974482047
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.01634463813274695
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.015325076031327383
# Fold 26 RMSLE for model2 = 0.015701122846758165
# Fold 26 RMSLE for model3 = 0.014054456853136518
# Fold 26 RMSLE for model4 = 0.01677099988131314
# Fold 26 RMSLE for ('model1', 'model2') = 0.015359000766353619
# Fold 26 RMSLE for ('model1', 'model3') = 0.014472829958074016
# Fold 26 RMSLE for ('model1', 'model4') = 0.015907408328419886
# Fold 26 RMSLE for ('model2', 'model3') = 0.01439886161532229
# Fold 26 RMSLE for ('model2', 'model4') = 0.01618979021092141
# Fold 26 RMSLE for ('model3', 'model4') = 0.014880975194255953
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.014650918580930587
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.015781725558141113
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.014989460472908077
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.015048810692716495
# Fold 26 RMSLE for all models ensemble = 0.015076460066165713
# Fold 26 best combination: model3 with RMSLE = 0.014054456853136518
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.01569345524215439
# Fold 27 RMSLE for model2 = 0.015651835905758738
# Fold 27 RMSLE for model3 = 0.0152777176062842
# Fold 27 RMSLE for model4 = 0.015883478317893704
# Fold 27 RMSLE for ('model1', 'model2') = 0.015546267381318934
# Fold 27 RMSLE for ('model1', 'model3') = 0.015429204653355535
# Fold 27 RMSLE for ('model1', 'model4') = 0.01574153549727216
# Fold 27 RMSLE for ('model2', 'model3') = 0.015281111914583147
# Fold 27 RMSLE for ('model2', 'model4') = 0.01569232771731227
# Fold 27 RMSLE for ('model3', 'model4') = 0.015473216985010476
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.015378063412716973
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.01563250419205008
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.015524635919989947
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.015441842116800957
# Fold 27 RMSLE for all models ensemble = 0.015477771790382826
# Fold 27 best combination: model3 with RMSLE = 0.0152777176062842
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.024524215611382412
# Fold 28 RMSLE for model2 = 0.024908806739503603
# Fold 28 RMSLE for model3 = 0.02550979978328874
# Fold 28 RMSLE for model4 = 0.024140526462825756
# Fold 28 RMSLE for ('model1', 'model2') = 0.024641057669035443
# Fold 28 RMSLE for ('model1', 'model3') = 0.024984553633684688
# Fold 28 RMSLE for ('model1', 'model4') = 0.024287546028757774
# Fold 28 RMSLE for ('model2', 'model3') = 0.025062631534046725
# Fold 28 RMSLE for ('model2', 'model4') = 0.024474935272030988
# Fold 28 RMSLE for ('model3', 'model4') = 0.024739340509170142
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.02486752652714662
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.024448825157935172
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.02465233608348732
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.024726971650785752
# Fold 28 RMSLE for all models ensemble = 0.024661645860612817
# Fold 28 best combination: model4 with RMSLE = 0.024140526462825756
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.0154708508390778
# Fold 29 RMSLE for model2 = 0.0161363322380909
# Fold 29 RMSLE for model3 = 0.015492848081938702
# Fold 29 RMSLE for model4 = 0.016416639948877466
# Fold 29 RMSLE for ('model1', 'model2') = 0.015709652982320032
# Fold 29 RMSLE for ('model1', 'model3') = 0.015417072520430794
# Fold 29 RMSLE for ('model1', 'model4') = 0.015886652645725745
# Fold 29 RMSLE for ('model2', 'model3') = 0.015696402654444285
# Fold 29 RMSLE for ('model2', 'model4') = 0.016213694239800278
# Fold 29 RMSLE for ('model3', 'model4') = 0.01585961858343143
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.015576580452284574
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.015913016087663902
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.01569683549599671
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.015892829019603795
# Fold 29 RMSLE for all models ensemble = 0.01575612632157253
# Fold 29 best combination: ('model1', 'model3') with RMSLE = 0.015417072520430794
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.023423851317314275
# Fold 30 RMSLE for model2 = 0.025478331037087024
# Fold 30 RMSLE for model3 = 0.02283735001338516
# Fold 30 RMSLE for model4 = 0.024060583810320047
# Fold 30 RMSLE for ('model1', 'model2') = 0.02434552556030003
# Fold 30 RMSLE for ('model1', 'model3') = 0.023101316393959372
# Fold 30 RMSLE for ('model1', 'model4') = 0.02370094776970014
# Fold 30 RMSLE for ('model2', 'model3') = 0.024018160783720214
# Fold 30 RMSLE for ('model2', 'model4') = 0.024688467451214505
# Fold 30 RMSLE for ('model3', 'model4') = 0.023410968431743524
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.02378987461505779
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.02421915221025465
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.023392267692933275
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.024009863853505734
# Fold 30 RMSLE for all models ensemble = 0.023840286642762214
# Fold 30 best combination: model3 with RMSLE = 0.02283735001338516
# ---------------
#
# OOF RMSLE = 0.017872693532567947
# Sum of RMSLE for each combination:
# ('model1',): 0.5515304643611412
# ('model2',): 0.5521015859811024
# ('model3',): 0.5390037812350592
# ('model4',): 0.5629808121229347
# ('model1', 'model2'): 0.5481747771513331
# ('model1', 'model3'): 0.5433418611820273
# ('model1', 'model4'): 0.555070087071718
# ('model2', 'model3'): 0.5398188065491029
# ('model2', 'model4'): 0.5553777192383994
# ('model3', 'model4'): 0.5474864706746867
# ('model1', 'model2', 'model3'): 0.5425202604457796
# ('model1', 'model2', 'model4'): 0.5519888763082532
# ('model1', 'model3', 'model4'): 0.5477813383394736
# ('model2', 'model3', 'model4'): 0.5463160100103476
# ('model1', 'model2', 'model3', 'model4'): 0.5466219943265938
#
# 1回目の推論が終了しました。
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.018987933666912815
# Fold 1 RMSLE for model2 = 0.018814190467621002
# Fold 1 RMSLE for model3 = 0.017408406172810826
# Fold 1 RMSLE for model4 = 0.01948025160182524
# Fold 1 RMSLE for ('model1', 'model2') = 0.01883892904324115
# Fold 1 RMSLE for ('model1', 'model3') = 0.018162543980541707
# Fold 1 RMSLE for ('model1', 'model4') = 0.019194574626526215
# Fold 1 RMSLE for ('model2', 'model3') = 0.018028279909732874
# Fold 1 RMSLE for ('model2', 'model4') = 0.019069193865620785
# Fold 1 RMSLE for ('model3', 'model4') = 0.018356896946310774
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.018323150256550215
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.019014289359833614
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.018553427430476957
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.01845718232933014
# Fold 1 RMSLE for all models ensemble = 0.018576325963287933
# Fold 1 best combination: model3 with RMSLE = 0.017408406172810826
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.020198189969382507
# Fold 2 RMSLE for model2 = 0.0214774581770612
# Fold 2 RMSLE for model3 = 0.019205998011607942
# Fold 2 RMSLE for model4 = 0.020708361770528632
# Fold 2 RMSLE for ('model1', 'model2') = 0.02079599539876309
# Fold 2 RMSLE for ('model1', 'model3') = 0.019666372316909247
# Fold 2 RMSLE for ('model1', 'model4') = 0.020409369471162276
# Fold 2 RMSLE for ('model2', 'model3') = 0.02025783578128099
# Fold 2 RMSLE for ('model2', 'model4') = 0.021049038522935028
# Fold 2 RMSLE for ('model3', 'model4') = 0.019866182304280538
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.02022198939344155
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.02073704924712018
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.019961689873207043
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.020367295991162587
# Fold 2 RMSLE for all models ensemble = 0.020312630138965733
# Fold 2 best combination: model3 with RMSLE = 0.019205998011607942
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.025546883912308097
# Fold 3 RMSLE for model2 = 0.026869227617052228
# Fold 3 RMSLE for model3 = 0.024170683607420817
# Fold 3 RMSLE for model4 = 0.026719991859320055
# Fold 3 RMSLE for ('model1', 'model2') = 0.026150689235275557
# Fold 3 RMSLE for ('model1', 'model3') = 0.024805937147497216
# Fold 3 RMSLE for ('model1', 'model4') = 0.026114528028724472
# Fold 3 RMSLE for ('model2', 'model3') = 0.025394084730045747
# Fold 3 RMSLE for ('model2', 'model4') = 0.026758688051000904
# Fold 3 RMSLE for ('model3', 'model4') = 0.02537048031797791
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.02542393841756529
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.02632882112414929
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.025414419060405605
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.02581570900840668
# Fold 3 RMSLE for all models ensemble = 0.025735775419826627
# Fold 3 best combination: model3 with RMSLE = 0.024170683607420817
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.01848602628474027
# Fold 4 RMSLE for model2 = 0.01923992940457292
# Fold 4 RMSLE for model3 = 0.01831246510265137
# Fold 4 RMSLE for model4 = 0.020798185669847726
# Fold 4 RMSLE for ('model1', 'model2') = 0.01875715223058786
# Fold 4 RMSLE for ('model1', 'model3') = 0.01838773870383823
# Fold 4 RMSLE for ('model1', 'model4') = 0.01955771779320428
# Fold 4 RMSLE for ('model2', 'model3') = 0.018627172568817473
# Fold 4 RMSLE for ('model2', 'model4') = 0.01996520693618835
# Fold 4 RMSLE for ('model3', 'model4') = 0.019433721417061182
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.018560383675371828
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.019400188183191083
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.01910057322777689
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.01930721369888828
# Fold 4 RMSLE for all models ensemble = 0.019077376099464683
# Fold 4 best combination: model3 with RMSLE = 0.01831246510265137
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.020750424984977395
# Fold 5 RMSLE for model2 = 0.020966951732731207
# Fold 5 RMSLE for model3 = 0.01918976308552469
# Fold 5 RMSLE for model4 = 0.02073330001345562
# Fold 5 RMSLE for ('model1', 'model2') = 0.020780954060778643
# Fold 5 RMSLE for ('model1', 'model3') = 0.019895907787348743
# Fold 5 RMSLE for ('model1', 'model4') = 0.020642568319725184
# Fold 5 RMSLE for ('model2', 'model3') = 0.019979555775334026
# Fold 5 RMSLE for ('model2', 'model4') = 0.020804556418552847
# Fold 5 RMSLE for ('model3', 'model4') = 0.019906957711927947
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.02019095281850039
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.020717974090324023
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.020122685051336235
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.02020854309636417
# Fold 5 RMSLE for all models ensemble = 0.02029750624011924
# Fold 5 best combination: model3 with RMSLE = 0.01918976308552469
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.015099066482505566
# Fold 6 RMSLE for model2 = 0.01709174018158362
# Fold 6 RMSLE for model3 = 0.0129440079519607
# Fold 6 RMSLE for model4 = 0.014587920465020969
# Fold 6 RMSLE for ('model1', 'model2') = 0.01599655115199543
# Fold 6 RMSLE for ('model1', 'model3') = 0.013941164172784421
# Fold 6 RMSLE for ('model1', 'model4') = 0.014813663713903032
# Fold 6 RMSLE for ('model2', 'model3') = 0.014802161830793968
# Fold 6 RMSLE for ('model2', 'model4') = 0.01575255578197451
# Fold 6 RMSLE for ('model3', 'model4') = 0.013723482571038136
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.014868841684293994
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.015495491694300667
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.014142929477168557
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.014719003520914797
# Fold 6 RMSLE for all models ensemble = 0.014790531130695539
# Fold 6 best combination: model3 with RMSLE = 0.0129440079519607
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.016803531557934858
# Fold 7 RMSLE for model2 = 0.017059730117780936
# Fold 7 RMSLE for model3 = 0.016487619708925184
# Fold 7 RMSLE for model4 = 0.016503034560021404
# Fold 7 RMSLE for ('model1', 'model2') = 0.016840348255764633
# Fold 7 RMSLE for ('model1', 'model3') = 0.016612907041162098
# Fold 7 RMSLE for ('model1', 'model4') = 0.016627627409269735
# Fold 7 RMSLE for ('model2', 'model3') = 0.016656646505348698
# Fold 7 RMSLE for ('model2', 'model4') = 0.016707777260804683
# Fold 7 RMSLE for ('model3', 'model4') = 0.016458660206962256
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.016676280100441452
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.016703816464559113
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.016555852444438968
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.016582114237901287
# Fold 7 RMSLE for all models ensemble = 0.016618910792013292
# Fold 7 best combination: ('model3', 'model4') with RMSLE = 0.016458660206962256
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.015385128812416679
# Fold 8 RMSLE for model2 = 0.015389097052704043
# Fold 8 RMSLE for model3 = 0.014403845938960096
# Fold 8 RMSLE for model4 = 0.01586128352360984
# Fold 8 RMSLE for ('model1', 'model2') = 0.01527372592830578
# Fold 8 RMSLE for ('model1', 'model3') = 0.014848185429807918
# Fold 8 RMSLE for ('model1', 'model4') = 0.015538388038861876
# Fold 8 RMSLE for ('model2', 'model3') = 0.014736765253606163
# Fold 8 RMSLE for ('model2', 'model4') = 0.015530458801470972
# Fold 8 RMSLE for ('model3', 'model4') = 0.015045703877480441
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.014917227108118138
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.01541495167745768
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.015119450280301216
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.015066840052927362
# Fold 8 RMSLE for all models ensemble = 0.015113310588715031
# Fold 8 best combination: model3 with RMSLE = 0.014403845938960096
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.024026153748511424
# Fold 9 RMSLE for model2 = 0.023884022828722585
# Fold 9 RMSLE for model3 = 0.02183829918017259
# Fold 9 RMSLE for model4 = 0.023796548523482897
# Fold 9 RMSLE for ('model1', 'model2') = 0.023817051009897314
# Fold 9 RMSLE for ('model1', 'model3') = 0.02289154425751316
# Fold 9 RMSLE for ('model1', 'model4') = 0.023791504239312374
# Fold 9 RMSLE for ('model2', 'model3') = 0.022731796244161415
# Fold 9 RMSLE for ('model2', 'model4') = 0.023757816199770052
# Fold 9 RMSLE for ('model3', 'model4') = 0.02269929523707497
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.02311186128768918
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.023750806679579392
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.023095990056536994
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.02302672843582707
# Fold 9 RMSLE for all models ensemble = 0.023228710494912617
# Fold 9 best combination: model3 with RMSLE = 0.02183829918017259
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.021040296204153805
# Fold 10 RMSLE for model2 = 0.021488755200171277
# Fold 10 RMSLE for model3 = 0.020541416645448812
# Fold 10 RMSLE for model4 = 0.021482200185683357
# Fold 10 RMSLE for ('model1', 'model2') = 0.021157134303446307
# Fold 10 RMSLE for ('model1', 'model3') = 0.020707260528232102
# Fold 10 RMSLE for ('model1', 'model4') = 0.0211776423827567
# Fold 10 RMSLE for ('model2', 'model3') = 0.020877325706615022
# Fold 10 RMSLE for ('model2', 'model4') = 0.021406275818769995
# Fold 10 RMSLE for ('model3', 'model4') = 0.020932806090210424
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.020877154803563197
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.02121696507722018
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.020911807929426734
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.02103936430420685
# Fold 10 RMSLE for all models ensemble = 0.020995437347946504
# Fold 10 best combination: model3 with RMSLE = 0.020541416645448812
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.013865780419412218
# Fold 11 RMSLE for model2 = 0.014941502470236134
# Fold 11 RMSLE for model3 = 0.013620248624932852
# Fold 11 RMSLE for model4 = 0.014923180634490179
# Fold 11 RMSLE for ('model1', 'model2') = 0.014253682250571985
# Fold 11 RMSLE for ('model1', 'model3') = 0.013718278391406168
# Fold 11 RMSLE for ('model1', 'model4') = 0.014254758783915515
# Fold 11 RMSLE for ('model2', 'model3') = 0.014061275073909148
# Fold 11 RMSLE for ('model2', 'model4') = 0.014843222572225239
# Fold 11 RMSLE for ('model3', 'model4') = 0.014086431105193673
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.01396540475902217
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.014408862107547896
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.013979330162090589
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.014276678840113938
# Fold 11 RMSLE for all models ensemble = 0.014134749682362212
# Fold 11 best combination: model3 with RMSLE = 0.013620248624932852
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.022118041662630532
# Fold 12 RMSLE for model2 = 0.02244784539258132
# Fold 12 RMSLE for model3 = 0.02075722177810731
# Fold 12 RMSLE for model4 = 0.02153062363811569
# Fold 12 RMSLE for ('model1', 'model2') = 0.0221851833620973
# Fold 12 RMSLE for ('model1', 'model3') = 0.021391478780214464
# Fold 12 RMSLE for ('model1', 'model4') = 0.021771563699790948
# Fold 12 RMSLE for ('model2', 'model3') = 0.02150864583832272
# Fold 12 RMSLE for ('model2', 'model4') = 0.021937762101084533
# Fold 12 RMSLE for ('model3', 'model4') = 0.02109948065285598
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.021668262759553525
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.021942130269784095
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.02140482801265127
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.021494096268326376
# Fold 12 RMSLE for all models ensemble = 0.021616442104317266
# Fold 12 best combination: model3 with RMSLE = 0.02075722177810731
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.013125183087923667
# Fold 13 RMSLE for model2 = 0.015105570126852404
# Fold 13 RMSLE for model3 = 0.012412069207987986
# Fold 13 RMSLE for model4 = 0.014586441561408144
# Fold 13 RMSLE for ('model1', 'model2') = 0.013899322568895946
# Fold 13 RMSLE for ('model1', 'model3') = 0.012668577467661153
# Fold 13 RMSLE for ('model1', 'model4') = 0.01374238388085725
# Fold 13 RMSLE for ('model2', 'model3') = 0.013345094447898671
# Fold 13 RMSLE for ('model2', 'model4') = 0.014785219863865372
# Fold 13 RMSLE for ('model3', 'model4') = 0.013250104331175832
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.013218649000894171
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.014100335215599467
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.013167935666213252
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.013719556843455922
# Fold 13 RMSLE for all models ensemble = 0.01351998950538857
# Fold 13 best combination: model3 with RMSLE = 0.012412069207987986
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.019589169750613016
# Fold 14 RMSLE for model2 = 0.020033986503068972
# Fold 14 RMSLE for model3 = 0.019176407024121392
# Fold 14 RMSLE for model4 = 0.020186399224425496
# Fold 14 RMSLE for ('model1', 'model2') = 0.01974490161486536
# Fold 14 RMSLE for ('model1', 'model3') = 0.01935761359167944
# Fold 14 RMSLE for ('model1', 'model4') = 0.019851820579315848
# Fold 14 RMSLE for ('model2', 'model3') = 0.019502707656440826
# Fold 14 RMSLE for ('model2', 'model4') = 0.020067031501227788
# Fold 14 RMSLE for ('model3', 'model4') = 0.019606303914683078
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.019513257673821525
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.019871754921915202
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.019590007878569352
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.019701122738416364
# Fold 14 RMSLE for all models ensemble = 0.019659354599256145
# Fold 14 best combination: model3 with RMSLE = 0.019176407024121392
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.0174536676118516
# Fold 15 RMSLE for model2 = 0.019803672597776014
# Fold 15 RMSLE for model3 = 0.017052023495190326
# Fold 15 RMSLE for model4 = 0.019671808964241123
# Fold 15 RMSLE for ('model1', 'model2') = 0.018495291208592474
# Fold 15 RMSLE for ('model1', 'model3') = 0.01719663138021498
# Fold 15 RMSLE for ('model1', 'model4') = 0.018484813604839473
# Fold 15 RMSLE for ('model2', 'model3') = 0.018139358350805945
# Fold 15 RMSLE for ('model2', 'model4') = 0.019681937323224166
# Fold 15 RMSLE for ('model3', 'model4') = 0.01816756930808984
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.017887790775242832
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.018858464416619057
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.0179118522865148
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.01860694371401314
# Fold 15 RMSLE for all models ensemble = 0.018293988405064358
# Fold 15 best combination: model3 with RMSLE = 0.017052023495190326
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.013510906658655569
# Fold 16 RMSLE for model2 = 0.01387837902466726
# Fold 16 RMSLE for model3 = 0.013200912422259273
# Fold 16 RMSLE for model4 = 0.01378370935045839
# Fold 16 RMSLE for ('model1', 'model2') = 0.013624648300392141
# Fold 16 RMSLE for ('model1', 'model3') = 0.013330982555355999
# Fold 16 RMSLE for ('model1', 'model4') = 0.013616984434731678
# Fold 16 RMSLE for ('model2', 'model3') = 0.013444433195772976
# Fold 16 RMSLE for ('model2', 'model4') = 0.013771808441012808
# Fold 16 RMSLE for ('model3', 'model4') = 0.013468282712077125
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.01344527010059321
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.013653324422258965
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.013463236649682886
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.013541608254337858
# Fold 16 RMSLE for all models ensemble = 0.013517342245450805
# Fold 16 best combination: model3 with RMSLE = 0.013200912422259273
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.018887636377267144
# Fold 17 RMSLE for model2 = 0.018748542474723597
# Fold 17 RMSLE for model3 = 0.018831601113558652
# Fold 17 RMSLE for model4 = 0.01929468667068701
# Fold 17 RMSLE for ('model1', 'model2') = 0.01873429593146937
# Fold 17 RMSLE for ('model1', 'model3') = 0.018841534793057155
# Fold 17 RMSLE for ('model1', 'model4') = 0.019028202779993578
# Fold 17 RMSLE for ('model2', 'model3') = 0.018686316103256124
# Fold 17 RMSLE for ('model2', 'model4') = 0.018963100746436347
# Fold 17 RMSLE for ('model3', 'model4') = 0.01901090277203303
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.01873126588263055
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.018885757577395346
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.018945255905843256
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.018863091873948815
# Fold 17 RMSLE for all models ensemble = 0.018845817894762203
# Fold 17 best combination: ('model2', 'model3') with RMSLE = 0.018686316103256124
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.019396460379241726
# Fold 18 RMSLE for model2 = 0.019659640276088172
# Fold 18 RMSLE for model3 = 0.019058835285027335
# Fold 18 RMSLE for model4 = 0.019753168575965437
# Fold 18 RMSLE for ('model1', 'model2') = 0.019423625869896984
# Fold 18 RMSLE for ('model1', 'model3') = 0.019198406990529885
# Fold 18 RMSLE for ('model1', 'model4') = 0.019485906111379465
# Fold 18 RMSLE for ('model2', 'model3') = 0.019207524266342726
# Fold 18 RMSLE for ('model2', 'model4') = 0.019658889177843523
# Fold 18 RMSLE for ('model3', 'model4') = 0.019292687697581554
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.019244557415969442
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.019496116452795444
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.019299680823589103
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.019352021186382202
# Fold 18 RMSLE for all models ensemble = 0.019333195670491164
# Fold 18 best combination: model3 with RMSLE = 0.019058835285027335
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.01553760832122986
# Fold 19 RMSLE for model2 = 0.015726452219080617
# Fold 19 RMSLE for model3 = 0.01521219863666865
# Fold 19 RMSLE for model4 = 0.015500395543683423
# Fold 19 RMSLE for ('model1', 'model2') = 0.015529152481499142
# Fold 19 RMSLE for ('model1', 'model3') = 0.015318558448101973
# Fold 19 RMSLE for ('model1', 'model4') = 0.015490217023552282
# Fold 19 RMSLE for ('model2', 'model3') = 0.015348477521090918
# Fold 19 RMSLE for ('model2', 'model4') = 0.015525651210933957
# Fold 19 RMSLE for ('model3', 'model4') = 0.015327497720215341
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.015367370657373224
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.015490456378264655
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.015366118749601632
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.015373934028585631
# Fold 19 RMSLE for all models ensemble = 0.01538755598376952
# Fold 19 best combination: model3 with RMSLE = 0.01521219863666865
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.014922035001234412
# Fold 20 RMSLE for model2 = 0.014822428558157952
# Fold 20 RMSLE for model3 = 0.014424227045446459
# Fold 20 RMSLE for model4 = 0.014556253724802442
# Fold 20 RMSLE for ('model1', 'model2') = 0.01477921686393452
# Fold 20 RMSLE for ('model1', 'model3') = 0.01464527261667582
# Fold 20 RMSLE for ('model1', 'model4') = 0.01466496504716404
# Fold 20 RMSLE for ('model2', 'model3') = 0.014535881718041623
# Fold 20 RMSLE for ('model2', 'model4') = 0.014637684694639726
# Fold 20 RMSLE for ('model3', 'model4') = 0.014446225118055683
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.01463016150555259
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.014669458132919007
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.014569162803766111
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.014519493127391836
# Fold 20 RMSLE for all models ensemble = 0.014586469492671282
# Fold 20 best combination: model3 with RMSLE = 0.014424227045446459
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.016349691478324494
# Fold 21 RMSLE for model2 = 0.016506840699567055
# Fold 21 RMSLE for model3 = 0.01611303306346784
# Fold 21 RMSLE for model4 = 0.016745985725075126
# Fold 21 RMSLE for ('model1', 'model2') = 0.01635762726295529
# Fold 21 RMSLE for ('model1', 'model3') = 0.01620745529867167
# Fold 21 RMSLE for ('model1', 'model4') = 0.01652743601360503
# Fold 21 RMSLE for ('model2', 'model3') = 0.016214688515682498
# Fold 21 RMSLE for ('model2', 'model4') = 0.016583903253684567
# Fold 21 RMSLE for ('model3', 'model4') = 0.01640428837354022
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.01623870810173807
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.016474895355320755
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.01637200666063982
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.016383043161323364
# Fold 21 RMSLE for all models ensemble = 0.0163594722506281
# Fold 21 best combination: model3 with RMSLE = 0.01611303306346784
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0160065360438578
# Fold 22 RMSLE for model2 = 0.01621864998527204
# Fold 22 RMSLE for model3 = 0.01606781073200038
# Fold 22 RMSLE for model4 = 0.016607302575508163
# Fold 22 RMSLE for ('model1', 'model2') = 0.016048261892674692
# Fold 22 RMSLE for ('model1', 'model3') = 0.016006507110195287
# Fold 22 RMSLE for ('model1', 'model4') = 0.016263784015113615
# Fold 22 RMSLE for ('model2', 'model3') = 0.016036060922334523
# Fold 22 RMSLE for ('model2', 'model4') = 0.01635511544526653
# Fold 22 RMSLE for ('model3', 'model4') = 0.016251919770727517
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.016007680702544776
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.01620402015850106
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.016156144720118875
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.016186613610461184
# Fold 22 RMSLE for all models ensemble = 0.01612777244039162
# Fold 22 best combination: ('model1', 'model3') with RMSLE = 0.016006507110195287
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.021841145405681404
# Fold 23 RMSLE for model2 = 0.023009102259153157
# Fold 23 RMSLE for model3 = 0.022095666676060936
# Fold 23 RMSLE for model4 = 0.022822410283903225
# Fold 23 RMSLE for ('model1', 'model2') = 0.022368924687022413
# Fold 23 RMSLE for ('model1', 'model3') = 0.02195847705565658
# Fold 23 RMSLE for ('model1', 'model4') = 0.022319812658193
# Fold 23 RMSLE for ('model2', 'model3') = 0.02249044205303221
# Fold 23 RMSLE for ('model2', 'model4') = 0.02287999478509938
# Fold 23 RMSLE for ('model3', 'model4') = 0.022445117055510517
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.02225803489055986
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.022511308589969862
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.0222371350964039
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.022592747152746968
# Fold 23 RMSLE for all models ensemble = 0.0223944597494297
# Fold 23 best combination: model1 with RMSLE = 0.021841145405681404
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.018355064400152783
# Fold 24 RMSLE for model2 = 0.018926682120667237
# Fold 24 RMSLE for model3 = 0.01643857002954978
# Fold 24 RMSLE for model4 = 0.020751163551090017
# Fold 24 RMSLE for ('model1', 'model2') = 0.01856145432059654
# Fold 24 RMSLE for ('model1', 'model3') = 0.017334315635541313
# Fold 24 RMSLE for ('model1', 'model4') = 0.01947436468338048
# Fold 24 RMSLE for ('model2', 'model3') = 0.017562154446973136
# Fold 24 RMSLE for ('model2', 'model4') = 0.01978932105009069
# Fold 24 RMSLE for ('model3', 'model4') = 0.018434524555694737
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.017790094438606067
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.01925225615005847
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.01838023856992708
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.01856057978833506
# Fold 24 RMSLE for all models ensemble = 0.018480750975800913
# Fold 24 best combination: model3 with RMSLE = 0.01643857002954978
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.01694379624787941
# Fold 25 RMSLE for model2 = 0.01674351804528589
# Fold 25 RMSLE for model3 = 0.016362944275677183
# Fold 25 RMSLE for model4 = 0.017653719490975325
# Fold 25 RMSLE for ('model1', 'model2') = 0.01669829850351913
# Fold 25 RMSLE for ('model1', 'model3') = 0.016543554729405874
# Fold 25 RMSLE for ('model1', 'model4') = 0.017114417659498934
# Fold 25 RMSLE for ('model2', 'model3') = 0.016344568750273274
# Fold 25 RMSLE for ('model2', 'model4') = 0.017076607292912816
# Fold 25 RMSLE for ('model3', 'model4') = 0.016742477359129544
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.016477208634745673
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.016912508473521857
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.01673691921007763
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.01665505867694117
# Fold 25 RMSLE for all models ensemble = 0.0166663805851356
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.016344568750273274
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.015021292394980172
# Fold 26 RMSLE for model2 = 0.015793915072048578
# Fold 26 RMSLE for model3 = 0.014066181253811233
# Fold 26 RMSLE for model4 = 0.015946478834880838
# Fold 26 RMSLE for ('model1', 'model2') = 0.015230082683508651
# Fold 26 RMSLE for ('model1', 'model3') = 0.014405558973528892
# Fold 26 RMSLE for ('model1', 'model4') = 0.015316282846742876
# Fold 26 RMSLE for ('model2', 'model3') = 0.0144385002026335
# Fold 26 RMSLE for ('model2', 'model4') = 0.015777875865155323
# Fold 26 RMSLE for ('model3', 'model4') = 0.014655892310408345
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.014601517840486987
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.015393231040034334
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.014718953945762713
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.014859459918884757
# Fold 26 RMSLE for all models ensemble = 0.0148547432808854
# Fold 26 best combination: model3 with RMSLE = 0.014066181253811233
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.015709495623570748
# Fold 27 RMSLE for model2 = 0.016183190777888934
# Fold 27 RMSLE for model3 = 0.015280269684452088
# Fold 27 RMSLE for model4 = 0.01588852785843603
# Fold 27 RMSLE for ('model1', 'model2') = 0.015803260080811288
# Fold 27 RMSLE for ('model1', 'model3') = 0.015460872435731394
# Fold 27 RMSLE for ('model1', 'model4') = 0.01574044424913245
# Fold 27 RMSLE for ('model2', 'model3') = 0.015603753025070808
# Fold 27 RMSLE for ('model2', 'model4') = 0.01585414631388893
# Fold 27 RMSLE for ('model3', 'model4') = 0.015472075898264371
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.015587973631434226
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.015756145343350948
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.015534981901444847
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.015595715803292467
# Fold 27 RMSLE for all models ensemble = 0.015600091739869416
# Fold 27 best combination: model3 with RMSLE = 0.015280269684452088
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.02386005931881696
# Fold 28 RMSLE for model2 = 0.025666519725846538
# Fold 28 RMSLE for model3 = 0.02414574016618443
# Fold 28 RMSLE for model4 = 0.0241916421058053
# Fold 28 RMSLE for ('model1', 'model2') = 0.024703877999794455
# Fold 28 RMSLE for ('model1', 'model3') = 0.023975801505237676
# Fold 28 RMSLE for ('model1', 'model4') = 0.023993474898075066
# Fold 28 RMSLE for ('model2', 'model3') = 0.024800850440854647
# Fold 28 RMSLE for ('model2', 'model4') = 0.024863745366493394
# Fold 28 RMSLE for ('model3', 'model4') = 0.02409443090908352
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.02447157508399838
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.02450258223340355
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.024006284458873095
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.024558990020634695
# Fold 28 RMSLE for all models ensemble = 0.024374549282032223
# Fold 28 best combination: model1 with RMSLE = 0.02386005931881696
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.015510153307771632
# Fold 29 RMSLE for model2 = 0.015281611868510772
# Fold 29 RMSLE for model3 = 0.015420789405222082
# Fold 29 RMSLE for model4 = 0.016263115994398065
# Fold 29 RMSLE for ('model1', 'model2') = 0.015289371439983839
# Fold 29 RMSLE for ('model1', 'model3') = 0.015427158586240301
# Fold 29 RMSLE for ('model1', 'model4') = 0.015833194940356572
# Fold 29 RMSLE for ('model2', 'model3') = 0.015259028178242975
# Fold 29 RMSLE for ('model2', 'model4') = 0.01570087548514815
# Fold 29 RMSLE for ('model3', 'model4') = 0.015785301962907942
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.015298899401502412
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.015582426959093572
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.015665239743349067
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.015557446987756319
# Fold 29 RMSLE for all models ensemble = 0.015514446904194462
# Fold 29 best combination: ('model2', 'model3') with RMSLE = 0.015259028178242975
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.02351129397497883
# Fold 30 RMSLE for model2 = 0.024481546868159558
# Fold 30 RMSLE for model3 = 0.022837448669509267
# Fold 30 RMSLE for model4 = 0.024743047555554502
# Fold 30 RMSLE for ('model1', 'model2') = 0.023925017771310144
# Fold 30 RMSLE for ('model1', 'model3') = 0.023147563572421644
# Fold 30 RMSLE for ('model1', 'model4') = 0.024041430064246864
# Fold 30 RMSLE for ('model2', 'model3') = 0.023565955993452032
# Fold 30 RMSLE for ('model2', 'model4') = 0.0245359059836572
# Fold 30 RMSLE for ('model3', 'model4') = 0.023704931123422524
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.0235244687817479
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.02414144565667925
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.023608724529814922
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.023907324062430832
# Fold 30 RMSLE for all models ensemble = 0.023783124192227088
# Fold 30 best combination: model3 with RMSLE = 0.022837448669509267
# ---------------
#
# OOF RMSLE = 0.017839330525151985
# Sum of RMSLE for each combination:
# ('model1',): 0.5478386530899174
# ('model2',): 0.5662606998456332
# ('model3',): 0.5270767039947185
# ('model4',): 0.5660711400366998
# ('model1', 'model2'): 0.5540640277124476
# ('model1', 'model3'): 0.5360541612831626
# ('model1', 'model4'): 0.5548838419973311
# ('model2', 'model3'): 0.5421873410061675
# ('model2', 'model4'): 0.5640913661309787
# ('model3', 'model4'): 0.543540631330975
# ('model1', 'model2', 'model3'): 0.5430999315835526
# ('model1', 'model2', 'model4'): 0.556887833452768
# ('model1', 'model3', 'model4'): 0.5440928626060096
# ('model2', 'model3', 'model4'): 0.5488955207337081
# ('model1', 'model2', 'model3', 'model4'): 0.5477972112000753
#
# 2回目の推論が終了しました。
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.019014770852854655
# Fold 1 RMSLE for model2 = 0.018190290522146962
# Fold 1 RMSLE for model3 = 0.017408408751977803
# Fold 1 RMSLE for model4 = 0.0197843487194388
# Fold 1 RMSLE for ('model1', 'model2') = 0.018521868802825955
# Fold 1 RMSLE for ('model1', 'model3') = 0.01817220423749914
# Fold 1 RMSLE for ('model1', 'model4') = 0.01935618442710438
# Fold 1 RMSLE for ('model2', 'model3') = 0.01766895479120347
# Fold 1 RMSLE for ('model2', 'model4') = 0.018960493304668195
# Fold 1 RMSLE for ('model3', 'model4') = 0.01849672162382467
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.01809364990275225
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.01892974904279015
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.01865488828528644
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.018348248791970688
# Fold 1 RMSLE for all models ensemble = 0.018495342806754415
# Fold 1 best combination: model3 with RMSLE = 0.017408408751977803
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.019717660597181656
# Fold 2 RMSLE for model2 = 0.021380134710893655
# Fold 2 RMSLE for model3 = 0.019207332811896658
# Fold 2 RMSLE for model4 = 0.0207896246192307
# Fold 2 RMSLE for ('model1', 'model2') = 0.020481230947320312
# Fold 2 RMSLE for ('model1', 'model3') = 0.019435658397353745
# Fold 2 RMSLE for ('model1', 'model4') = 0.020215210251498018
# Fold 2 RMSLE for ('model2', 'model3') = 0.020207339975311375
# Fold 2 RMSLE for ('model2', 'model4') = 0.02104756226060367
# Fold 2 RMSLE for ('model3', 'model4') = 0.01994194468748724
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.02002063096010635
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.020565442706650682
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.019850571048482007
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.020379265633456902
# Fold 2 RMSLE for all models ensemble = 0.02019520224815404
# Fold 2 best combination: model3 with RMSLE = 0.019207332811896658
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.02556990798144043
# Fold 3 RMSLE for model2 = 0.025716546831297198
# Fold 3 RMSLE for model3 = 0.024172641928822538
# Fold 3 RMSLE for model4 = 0.02768694735455775
# Fold 3 RMSLE for ('model1', 'model2') = 0.025593764732628217
# Fold 3 RMSLE for ('model1', 'model3') = 0.024823805943843424
# Fold 3 RMSLE for ('model1', 'model4') = 0.02658000773899817
# Fold 3 RMSLE for ('model2', 'model3') = 0.024874981505332922
# ...
# Fold 15 RMSLE for all models ensemble = 0.01831110290021488
# Fold 15 best combination: model3 with RMSLE = 0.01707655217357826
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.013430049120269932
# Fold 16 RMSLE for model2 = 0.013238549693399364
# Fold 16 RMSLE for model3 = 0.01322115136526534
# Fold 16 RMSLE for model4 = 0.013582374691699425
# Fold 16 RMSLE for ('model1', 'model2') = 0.013287323131499672
# Fold 16 RMSLE for ('model1', 'model3') = 0.013305942094368901
# Fold 16 RMSLE for ('model1', 'model4') = 0.013485600620793996
# Fold 16 RMSLE for ('model2', 'model3') = 0.013162881407583146
# Fold 16 RMSLE for ('model2', 'model4') = 0.013372974449525116
# Fold 16 RMSLE for ('model3', 'model4') = 0.013383105277713544
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.013237261093590323
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.013370352705832261
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.013384992172685068
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.0132927827290471
# Fold 16 RMSLE for all models ensemble = 0.013315548177903393
# Fold 16 best combination: ('model2', 'model3') with RMSLE = 0.013162881407583146
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.018744913316181968
# Fold 17 RMSLE for model2 = 0.01873377274496738
# Fold 17 RMSLE for model3 = 0.018530099792247873
# Fold 17 RMSLE for model4 = 0.019006205015627824
# Fold 17 RMSLE for ('model1', 'model2') = 0.018677686501134865
# Fold 17 RMSLE for ('model1', 'model3') = 0.018624261376272017
# Fold 17 RMSLE for ('model1', 'model4') = 0.018855398603658546
# Fold 17 RMSLE for ('model2', 'model3') = 0.018553694765514137
# Fold 17 RMSLE for ('model2', 'model4') = 0.018821480410471592
# Fold 17 RMSLE for ('model3', 'model4') = 0.018750451955828838
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.01860150556300827
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.01877042227646057
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.018737669324166414
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.018692583147985276
# Fold 17 RMSLE for all models ensemble = 0.01869390998672999
# Fold 17 best combination: model3 with RMSLE = 0.018530099792247873
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.019404172270267
# Fold 18 RMSLE for model2 = 0.01938463623403649
# Fold 18 RMSLE for model3 = 0.019074265599242062
# Fold 18 RMSLE for model4 = 0.01972638779536781
# Fold 18 RMSLE for ('model1', 'model2') = 0.01929471844746921
# Fold 18 RMSLE for ('model1', 'model3') = 0.01921037036410763
# Fold 18 RMSLE for ('model1', 'model4') = 0.019472514818412213
# Fold 18 RMSLE for ('model2', 'model3') = 0.019080483458472963
# Fold 18 RMSLE for ('model2', 'model4') = 0.019508463978806657
# Fold 18 RMSLE for ('model3', 'model4') = 0.019280821918220004
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.019164329489867085
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.01939863752849611
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.019294182031884047
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.019255182082074815
# Fold 18 RMSLE for all models ensemble = 0.019263154136718908
# Fold 18 best combination: model3 with RMSLE = 0.019074265599242062
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.015736594638835158
# Fold 19 RMSLE for model2 = 0.016045815305911974
# Fold 19 RMSLE for model3 = 0.0151174308521943
# Fold 19 RMSLE for model4 = 0.015219910451524134
# Fold 19 RMSLE for ('model1', 'model2') = 0.015836009308206923
# Fold 19 RMSLE for ('model1', 'model3') = 0.015381818967837357
# Fold 19 RMSLE for ('model1', 'model4') = 0.015442722363819484
# Fold 19 RMSLE for ('model2', 'model3') = 0.015525749638892401
# Fold 19 RMSLE for ('model2', 'model4') = 0.015586102367726477
# Fold 19 RMSLE for ('model3', 'model4') = 0.015150836113075047
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.01556373446816904
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.015606193690400382
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.01531404821698192
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.015407223113467748
# Fold 19 RMSLE for all models ensemble = 0.015465566986900636
# Fold 19 best combination: model3 with RMSLE = 0.0151174308521943
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.014640994695127288
# Fold 20 RMSLE for model2 = 0.015167759399422895
# Fold 20 RMSLE for model3 = 0.01388301875640776
# Fold 20 RMSLE for model4 = 0.014225257889997478
# Fold 20 RMSLE for ('model1', 'model2') = 0.014803276192796814
# Fold 20 RMSLE for ('model1', 'model3') = 0.014233073119246575
# Fold 20 RMSLE for ('model1', 'model4') = 0.014348572347315782
# Fold 20 RMSLE for ('model2', 'model3') = 0.01442615412957863
# Fold 20 RMSLE for ('model2', 'model4') = 0.014624941505571873
# Fold 20 RMSLE for ('model3', 'model4') = 0.01400428443850277
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.01446131720426871
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.014563470667898475
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.014176947754970234
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.014326875217803103
# Fold 20 RMSLE for all models ensemble = 0.014369792911573908
# Fold 20 best combination: model3 with RMSLE = 0.01388301875640776
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.016292393792229257
# Fold 21 RMSLE for model2 = 0.016329919637853362
# Fold 21 RMSLE for model3 = 0.016113149938486792
# Fold 21 RMSLE for model4 = 0.016686536792316763
# Fold 21 RMSLE for ('model1', 'model2') = 0.016226789592073826
# Fold 21 RMSLE for ('model1', 'model3') = 0.01618551964982133
# Fold 21 RMSLE for ('model1', 'model4') = 0.01647169577799583
# Fold 21 RMSLE for ('model2', 'model3') = 0.01612761146979847
# Fold 21 RMSLE for ('model2', 'model4') = 0.016446154543757443
# Fold 21 RMSLE for ('model3', 'model4') = 0.01637940692748802
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.01615816416654687
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.016363431333992467
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.01633936933369703
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.0162982715604939
# Fold 21 RMSLE for all models ensemble = 0.01628163144574282
# Fold 21 best combination: model3 with RMSLE = 0.016113149938486792
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.01610732938644655
# Fold 22 RMSLE for model2 = 0.016976535470524724
# Fold 22 RMSLE for model3 = 0.015981473955666462
# Fold 22 RMSLE for model4 = 0.01739586081184455
# Fold 22 RMSLE for ('model1', 'model2') = 0.016435733452129522
# Fold 22 RMSLE for ('model1', 'model3') = 0.016016285622957087
# Fold 22 RMSLE for ('model1', 'model4') = 0.016660922146225155
# Fold 22 RMSLE for ('model2', 'model3') = 0.016323557709268237
# Fold 22 RMSLE for ('model2', 'model4') = 0.017110830375911205
# Fold 22 RMSLE for ('model3', 'model4') = 0.016534776615299274
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.01622548330316863
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.016705740590754976
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.01637259476931635
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.016614335579963457
# Fold 22 RMSLE for all models ensemble = 0.016462402667168415
# Fold 22 best combination: model3 with RMSLE = 0.015981473955666462
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.02153233664574358
# Fold 23 RMSLE for model2 = 0.02282064765566501
# Fold 23 RMSLE for model3 = 0.02141821060382659
# Fold 23 RMSLE for model4 = 0.022271578311954716
# Fold 23 RMSLE for ('model1', 'model2') = 0.022131456997365708
# Fold 23 RMSLE for ('model1', 'model3') = 0.021466653989489493
# Fold 23 RMSLE for ('model1', 'model4') = 0.021887316604382537
# Fold 23 RMSLE for ('model2', 'model3') = 0.02206927700164793
# Fold 23 RMSLE for ('model2', 'model4') = 0.022516254658926316
# Fold 23 RMSLE for ('model3', 'model4') = 0.021828627051426117
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.02187724137885513
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.022168306410464616
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.021723102949043723
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.022127282745681345
# Fold 23 RMSLE for all models ensemble = 0.021969317851314046
# Fold 23 best combination: model3 with RMSLE = 0.02141821060382659
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.018644983198496685
# Fold 24 RMSLE for model2 = 0.019829953680069217
# Fold 24 RMSLE for model3 = 0.01650970647559997
# Fold 24 RMSLE for model4 = 0.020365571473719306
# Fold 24 RMSLE for ('model1', 'model2') = 0.019118614335463732
# Fold 24 RMSLE for ('model1', 'model3') = 0.01750682547476789
# Fold 24 RMSLE for ('model1', 'model4') = 0.019456627296343742
# Fold 24 RMSLE for ('model2', 'model3') = 0.01794059489001139
# Fold 24 RMSLE for ('model2', 'model4') = 0.02003451729151617
# Fold 24 RMSLE for ('model3', 'model4') = 0.01828852503004441
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.018141628986490833
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.019511351707168
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.018388146603736725
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.018709219151201512
# Fold 24 RMSLE for all models ensemble = 0.018669446889943
# Fold 24 best combination: model3 with RMSLE = 0.01650970647559997
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.0176050923380603
# Fold 25 RMSLE for model2 = 0.01881139493768799
# Fold 25 RMSLE for model3 = 0.01647979191548837
# Fold 25 RMSLE for model4 = 0.018696244939101263
# Fold 25 RMSLE for ('model1', 'model2') = 0.018109614005783238
# Fold 25 RMSLE for ('model1', 'model3') = 0.016969727963210012
# Fold 25 RMSLE for ('model1', 'model4') = 0.017944283899396476
# Fold 25 RMSLE for ('model2', 'model3') = 0.017456301057070953
# Fold 25 RMSLE for ('model2', 'model4') = 0.01860021752971174
# Fold 25 RMSLE for ('model3', 'model4') = 0.017369252571146715
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.01747130196743167
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.018166931846555743
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.017370368481503584
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.017746749932842407
# Fold 25 RMSLE for all models ensemble = 0.01766237595808865
# Fold 25 best combination: model3 with RMSLE = 0.01647979191548837
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.015074321304761064
# Fold 26 RMSLE for model2 = 0.015838639436687275
# Fold 26 RMSLE for model3 = 0.014174570425358626
# Fold 26 RMSLE for model4 = 0.016293547963298526
# Fold 26 RMSLE for ('model1', 'model2') = 0.015178073567019204
# Fold 26 RMSLE for ('model1', 'model3') = 0.014496492423929903
# Fold 26 RMSLE for ('model1', 'model4') = 0.015541050632865037
# Fold 26 RMSLE for ('model2', 'model3') = 0.014595850180737419
# Fold 26 RMSLE for ('model2', 'model4') = 0.015965779770131788
# Fold 26 RMSLE for ('model3', 'model4') = 0.014858625876044475
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.01466374251821348
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.015504980616824806
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.014892846633758424
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.015046720813605923
# Fold 26 RMSLE for all models ensemble = 0.014987680666165164
# Fold 26 best combination: model3 with RMSLE = 0.014174570425358626
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.01598398272521656
# Fold 27 RMSLE for model2 = 0.016408739212969394
# Fold 27 RMSLE for model3 = 0.015263706519394706
# Fold 27 RMSLE for model4 = 0.01586613181437851
# Fold 27 RMSLE for ('model1', 'model2') = 0.016071401156222145
# Fold 27 RMSLE for ('model1', 'model3') = 0.015595329126512373
# Fold 27 RMSLE for ('model1', 'model4') = 0.015903709259161448
# Fold 27 RMSLE for ('model2', 'model3') = 0.0157178515744911
# Fold 27 RMSLE for ('model2', 'model4') = 0.01602807221209979
# Fold 27 RMSLE for ('model3', 'model4') = 0.015521615436912316
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.015763900993710944
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.015972196132207267
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.01566329267775535
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.015725140567755272
# Fold 27 RMSLE for all models ensemble = 0.01576846572584469
# Fold 27 best combination: model3 with RMSLE = 0.015263706519394706
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.024278888834032206
# Fold 28 RMSLE for model2 = 0.02641865840442994
# Fold 28 RMSLE for model3 = 0.023880729748747023
# Fold 28 RMSLE for model4 = 0.024361588316951784
# Fold 28 RMSLE for ('model1', 'model2') = 0.025262584531073554
# Fold 28 RMSLE for ('model1', 'model3') = 0.024058591799200304
# Fold 28 RMSLE for ('model1', 'model4') = 0.024293489870266707
# Fold 28 RMSLE for ('model2', 'model3') = 0.025008476835444337
# Fold 28 RMSLE for ('model2', 'model4') = 0.02534334821687681
# Fold 28 RMSLE for ('model3', 'model4') = 0.024061223937183174
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.02474773280917884
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.02494823878041884
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.02412579823842246
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.024776523585301767
# Fold 28 RMSLE for all models ensemble = 0.02463861948111001
# Fold 28 best combination: model3 with RMSLE = 0.023880729748747023
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.015336055690472847
# Fold 29 RMSLE for model2 = 0.01625040048968163
# Fold 29 RMSLE for model3 = 0.015220462691548671
# Fold 29 RMSLE for model4 = 0.016212800100614305
# Fold 29 RMSLE for ('model1', 'model2') = 0.01565953105987627
# Fold 29 RMSLE for ('model1', 'model3') = 0.015253988702304985
# Fold 29 RMSLE for ('model1', 'model4') = 0.01568442923681488
# Fold 29 RMSLE for ('model2', 'model3') = 0.015641973789945095
# Fold 29 RMSLE for ('model2', 'model4') = 0.016120368911994032
# Fold 29 RMSLE for ('model3', 'model4') = 0.015621186422542257
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.01548968513008329
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.01578406053275779
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.015495934422086072
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.015760864065728603
# Fold 29 RMSLE for all models ensemble = 0.015617072085263414
# Fold 29 best combination: model3 with RMSLE = 0.015220462691548671
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.02335698665660039
# Fold 30 RMSLE for model2 = 0.02543922485337039
# Fold 30 RMSLE for model3 = 0.022838623876984866
# Fold 30 RMSLE for model4 = 0.024934123631311127
# Fold 30 RMSLE for ('model1', 'model2') = 0.024332997608175637
# Fold 30 RMSLE for ('model1', 'model3') = 0.023072732819534255
# Fold 30 RMSLE for ('model1', 'model4') = 0.024094993596133252
# Fold 30 RMSLE for ('model2', 'model3') = 0.024045270239912944
# Fold 30 RMSLE for ('model2', 'model4') = 0.025143817041091292
# Fold 30 RMSLE for ('model3', 'model4') = 0.023812155135442378
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.02379583867812116
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.024506431331599857
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.023642926369362674
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.024310842873560518
# Fold 30 RMSLE for all models ensemble = 0.02405416623421756
# Fold 30 best combination: model3 with RMSLE = 0.022838623876984866
# ---------------
#
# OOF RMSLE = 0.017809307889499002
# Sum of RMSLE for each combination:
# ('model1',): 0.5497626098677708
# ('model2',): 0.5733784926777078
# ('model3',): 0.525247549588161
# ('model4',): 0.5683343984128008
# ('model1', 'model2'): 0.5585750191537323
# ('model1', 'model3'): 0.5362701537299315
# ('model1', 'model4'): 0.557171334662279
# ('model2', 'model3'): 0.5451443991213105
# ('model2', 'model4'): 0.5689342479802592
# ('model3', 'model4'): 0.5439515371663572
# ('model1', 'model2', 'model3'): 0.5457105604553775
# ('model1', 'model2', 'model4'): 0.5608062746436394
# ('model1', 'model3', 'model4'): 0.5451272796729061
# ('model2', 'model3', 'model4'): 0.5517042207273205
# ('model1', 'model2', 'model3', 'model4'): 0.5504179168770742
#
# 9回目の推論が終了しました。

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                        0.000000                     0.000000           221
# 2                        0.000000                     0.000000             4
# 3                        0.000000                     0.000000            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 7158                     0.000000                     0.000000           240
# 7159                     0.000000                     0.000000             4
# 7160                 25069.498286                 24560.172725           132
# 7161                 93118.705227                130326.946431            98
# 7162                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 7158                           110523.066755
# 7159                                0.000000
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42219.232340 -0.000114
# 1                  14            1     58457.422333  0.000721
# 2                   9            1     98346.648836  0.010749
# 3                  15            1     51700.140507 -0.001487
# 4                  15            0     51081.483712 -0.008722
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42219.232340 -0.000114
# 1                  14            1     58457.422333  0.000721
# 2                   9            1     98346.648836  0.010749
# 3                  15            1     51700.140507 -0.001487
# 4                  15            0     51081.483712 -0.008722
# ...               ...          ...              ...       ...
# 4650               15            0     49624.426026 -0.008150
# 4651                8            1    168978.826179  0.003871
# 4652                8            0     31739.968362 -0.000745
# 4653                8            0     65541.473863  0.001856
# 4654                9            1    145875.699765 -0.003006
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 0.00)

# %%
train_df_GHG14
# Out:
# 0        42214.415787
# 1        58499.609696
# 2        99409.449782
# 3        51623.314588
# 4        50637.897032
#             ...
# 4650     49221.615755
# 4651    169634.209493
# 4652     31716.323514
# 4653     65663.219471
# 4654    145437.817997
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.552993e+04  0.011449
# 1                  14            1     2.929165e+05 -0.009013
# 2                   8            0     4.123899e+04  0.004741
# 3                   8            0     2.848235e+04 -0.022208
# 4                   8            0     4.886757e+04  0.016946
# ...               ...          ...              ...       ...
# 2503                1            1     5.514237e+05  0.027199
# 2504                9            1     9.824133e+04 -0.009746
# 2505                8            0     1.424681e+05  0.022125
# 2506                8            0     2.589255e+05 -0.005393
# 2507                9            1     1.457911e+06  0.065402
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)
# after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232700.8253474508

# %%
# def adjust_predictions(test_x, bins, bin_centers, y_means):
#     """
#     テストデータの予測値をビン平均で補正します。

#     Parameters:
#     - test_x: テストデータの予測値の配列
#     - bins: トレーニングデータで使用したビンの境界
#     - bin_centers: 各ビンの中心値
#     - y_means: 各ビン内の y の平均値

#     Returns:
#     - adjusted_predictions: 補正後の予測値
#     """
#     # テストデータをビンに割り当て
#     bin_indices = np.digitize(test_x, bins)

#     # 補正後の予測値を初期化
#     adjusted_predictions = np.copy(test_x)

#     for i in range(1, len(bins)):
#         mask = bin_indices == i
#         if np.any(mask):
#             # 補正係数を計算（y_mean / bin_center）
#             correction_factor = np.log1p(y_means[i-1]) / np.log1p(bin_centers[i-1])
#             adjusted_predictions[mask] = test_x[mask] / correction_factor

#     # ビンの範囲外のデータを処理（例えば、最小ビンより小さい値や最大ビンより大きい値）
#     # 最小ビンより小さい値は最初のビンに、
#     # 最大ビンより大きい値は最後のビンに割り当て
#     adjusted_predictions[bin_indices == 0] = y_means[0]
#     adjusted_predictions[bin_indices > len(y_means)] = y_means[-1]

#     return adjusted_predictions

# # テストデータの定義（例）
# # test_x = test_df["GHG_Direct_Emissions_14_in_metric_tons"]

# # 実際のデータに合わせて定義してください
# x_test = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]  # テストデータの予測値

# # 予測値を調整

# # 調整後の予測値をデータフレームに追加
# test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = adjust_predictions(x_test, bins, bin_centers, y_means)
# train_df["preds"] = adjust_predictions(train_df["preds"], bins, bin_centers, y_means)

# %%
def after_act(preds):
    r = preds.copy()
    # for i in range(len(r)):
    #     if r[i] < np.expm1(10.4):
    #         r[i] = np.expm1(np.log1p(r[i])*100/102)
    return r

# after_test_preds = after_act(test_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
# after_train_preds = after_act(train_df["preds"])

# %%
x = train_df["oof_predictions"]
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232895.9013100866

# %%
submit [ 1 ]  =  test_df["oof_predictions"]
submit.to_csv('SMBC_63.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,530
# 1     4656   292,917
# 2     4657    41,239
# 3     4658    28,482
# 4     4659    48,868
# ...    ...       ...
# 2503  7158   551,424
# 2504  7159    98,241
# 2505  7160   142,468
# 2506  7161   258,925
# 2507  7162 1,457,911
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,160,160
# 43    4698 1,192,480
# 110   4765 1,373,603
# 114   4769 1,296,814
# 148   4803 1,738,851
# ...    ...       ...
# 2417  7072 1,239,285
# 2423  7078 1,206,848
# 2466  7121 1,678,847
# 2490  7145 1,424,470
# 2507  7162 1,457,911
#
# [113 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Thu Nov 28 01:09:39 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,219    -0
# 1                  14            1           58,457     0
# 2                   9            1           98,347     0
# 3                  15            1           51,700    -0
# 4                  15            0           51,081    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,624    -0
# 4651                8            1          168,979     0
# 4652                8            0           31,740    -0
# 4653                8            0           65,541     0
# 4654                9            1          145,876    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.017809307889499002

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,219    -0
# 1                  14            1           58,457     0
# 2                   9            1           98,347     0
# 3                  15            1           51,700    -0
# 4                  15            0           51,081    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,624    -0
# 4651                8            1          168,979     0
# 4652                8            0           31,740    -0
# 4653                8            0           65,541     0
# 4654                9            1          145,876    -0
#
# [4655 rows x 19 columns]
