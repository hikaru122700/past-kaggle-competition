# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/santa_2024/santa2024_beam_and_sa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# このノートブックは以下のノートブックを参考にして作成されました。
#
# この場を借りてノートブックを共有してくださったことに感謝したいと思います。
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# また、以下のノートブックを利用してid4以外の答えを作成しています。ありがとうございます。
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# This notebook was created with reference to the following notebook:
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# I would like to take this opportunity to express my gratitude to the author for sharing their notebook.
#
# Additionally, I used the following notebook to generate answers other than id4. Thank you very much.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# 이 노트북은 다음 노트북을 참고하여 작성되었습니다.
#
# 이 자리를 빌려 노트북을 공유해 주신 것에 대해 감사드립니다.
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# 또한, 아래 노트북을 사용하여 id4 이외의 답변을 작성했습니다. 감사합니다.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# このノートブックはGPU環境下で実行に3時間程度かかります。実行される際は注意してください。
#
# 元ノートブックからの変更点として、ビーム幅を可変にしています。
#
# これにより、重要な局面で多くの情報を残すことができます。

# %% [markdown]
# This notebook takes approximately 3 hours to run in a GPU environment. Please be cautious when executing it.
#
# As a modification from the original notebook, the beam width has been made adjustable.
#
# This allows for retaining more information during critical stages.

# %% [markdown]
# 이 노트북은 GPU 환경에서 실행하는 데 약 3시간 정도 소요됩니다. 실행 시 유의하시기 바랍니다.
#
# 원본 노트북에서의 변경점으로, 빔 폭을 가변적으로 설정하였습니다.
#
# 이를 통해 중요한 국면에서 더 많은 정보를 남길 수 있습니다.

# %%
print("Yes")
# Out:
# Yes

# %%
# !pip install accelerate peft bitsandbytes transformers
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 33.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
import gc
import os
import time
import math
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch
import heapq
from tqdm import tqdm

import random
import statistics
from collections import Counter
from dataclasses import dataclass
from typing import Any, Callable, List, Optional, Tuple, Union

import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import bitsandbytes
from pprint import pprint

# %%
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class HuggingFaceModelLoader:
    def __init__(self, model_path: str, load_in_8bit: bool, device_map: str):
        self.model_path = model_path
        self.load_in_8bit = load_in_8bit
        self.device_map = device_map

    def load_model(self) -> transformers.PreTrainedModel:
        if self.load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires a CUDA device')

            quantization_config = transformers.BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_quant_type="fp4",
                bnb_4bit_use_double_quant=False,
                bnb_4bit_compute_dtype=torch.float16,
            )

            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                quantization_config=quantization_config,
                device_map=self.device_map
            )
        else:
            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=self.device_map
            )

        model.eval()
        return model


class HuggingFaceTokenizer:
    def __init__(self, model_path: str):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path, padding_side="right")
        self.bos_token = self.tokenizer.bos_token or self.tokenizer.cls_token
        self.eos_token = self.tokenizer.eos_token or self.tokenizer.sep_token
        if self.bos_token is None:
            self.bos_token = ""
        if self.eos_token is None:
            self.eos_token = ""

    def tokenize(self, texts: List[str]) -> dict:
        processed_texts = []

        for text in texts:
            combined_text = f"{self.bos_token}{text}{self.eos_token}"
            processed_texts.append(combined_text)

        model_inputs = self.tokenizer(
            processed_texts,
            return_tensors='pt',
            add_special_tokens=False,
            padding=True
        )

        if 'token_type_ids' in model_inputs:
            model_inputs.pop('token_type_ids')

        return model_inputs


class PerplexityCalculator:
    def __init__(self, model_loader, tokenizer, exp_mode=False):
        self.model = model_loader.load_model()
        self.tokenizer = tokenizer
        self.exp_mode = exp_mode
        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

    def get_perplexity(
        self,
        input_texts: Union[str, List[str]],
        batch_size: int = 32
    ) -> Union[float, List[float]]:

        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        num_texts = len(input_texts)
        batches = num_texts // batch_size + (num_texts % batch_size != 0)
        with torch.no_grad():
            for j in range(batches):
                start_idx = j * batch_size
                end_idx = (j + 1) * batch_size
                input_batch = input_texts[start_idx:end_idx]

                with torch.no_grad():
                    model_inputs = self.tokenizer.tokenize(input_batch)
                    model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                    output = self.model(**model_inputs, use_cache=False)
                    logits = output['logits']

                    label = model_inputs['input_ids']
                    if hasattr(self.model.config, 'pad_token_id') and self.model.config.pad_token_id is not None:
                        label[label == self.model.config.pad_token_id] = PAD_TOKEN_LABEL_ID

                    shift_logits = logits[..., :-1, :].contiguous()
                    shift_labels = label[..., 1:].contiguous()

                    token_loss = self.loss_fct(
                        shift_logits.view(-1, shift_logits.size(-1)),
                        shift_labels.view(-1)
                    ).view(len(logits), -1)

                    valid_length = (shift_labels != PAD_TOKEN_LABEL_ID).sum(dim=-1)
                    sequence_loss = torch.sum(token_loss, -1) / valid_length
                    loss_list.extend(sequence_loss.cpu().tolist())

        if self.exp_mode:
            ppl = [exp(i) for i in loss_list]
        else:
            ppl = loss_list

        return ppl[0] if single_input else ppl

# %%
import os
from google.colab import userdata
import os

# Hugging Faceのトークンを環境変数に設定
os.environ["HF_TOKEN"] = "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"

# %%
from huggingface_hub import HfApi, hf_hub_download
import os
from multiprocessing import Pool

# Specify your model repository
model_name = "google/gemma-2-9b"

# Create a directory to store the downloaded model files
download_dir = "/content/model"
os.makedirs(download_dir, exist_ok=True)

# Initialize API
api = HfApi()

# Get the list of all files in the repository
files = api.list_repo_files(model_name)

# **Your Hugging Face token**
hf_token = "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"  # ここにあなたのHugging Faceトークンを入力してください

def download_file(file_path):
    try:
        # Download each file to the specified directory with token
        hf_hub_download(
            repo_id=model_name,
            filename=file_path,
            local_dir=download_dir,
            token=hf_token
        )
        print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {file_path}: {e}")

# Use multiprocessing to download files in parallel
if __name__ == "__main__":
    with Pool(processes=8) as pool:  # Adjust the number of processes based on Colab limits
        pool.map(download_file, files)
# Out:
# Downloaded README.md
# Downloaded generation_config.json
# Downloaded .gitattributes
# Downloaded config.json
# model-00005-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/2.38G [00:00<?, ?B/s]
# Downloaded model-00008-of-00008.safetensors
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Downloaded model.safetensors.index.json
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloaded special_tokens_map.json
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Downloaded tokenizer.json
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# Downloaded tokenizer.model
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# Downloaded tokenizer_config.json
# (…)ransformers-4.42.0.dev0-py3-none-any.whl:   0%|          | 0.00/9.21M [00:00<?, ?B/s]
# Downloaded transformers/transformers-4.42.0.dev0-py3-none-any.whl
# Downloaded model-00004-of-00008.safetensors
# Downloaded model-00005-of-00008.safetensors
# Downloaded model-00001-of-00008.safetensors
# Downloaded model-00002-of-00008.safetensors
# Downloaded model-00007-of-00008.safetensors
# Downloaded model-00006-of-00008.safetensors
# Downloaded model-00003-of-00008.safetensors

# %%
model_path = "/content/model"
model_loader = HuggingFaceModelLoader(model_path=model_path, load_in_8bit=False, device_map='auto')
tokenizer = HuggingFaceTokenizer(model_path)
scorer = PerplexityCalculator(model_loader, tokenizer, exp_mode=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
class BeamSearch:
    def __init__(self, beam_width, scorer: PerplexityCalculator):
        self.beam_width = beam_width
        self.scorer = scorer

    def _make_candidates_adding_word(self, intermediate_solution, words):
        """
        Make candidate text so that word duplication does not occur
        """
        candidates = []
        not_used_words = words.copy()

        for used_word in intermediate_solution.split():
            if used_word in not_used_words:
                not_used_words.remove(used_word)

        # Generate candidates by adding unused words to the end
        candidates += [(intermediate_solution + ' ' + word).strip() for word in not_used_words]

        # Generate candidates by adding unused words to the beginning
        candidates += [(word + ' ' + intermediate_solution).strip() for word in not_used_words]

        # Remove duplicates
        candidates = list(set(candidates))

        return candidates

    def _select_new_intermediate_solutions(self, scored_candidates):
        """
        Select top candidates based on beam width while ensuring diversity.
        Include candidates with scores within a diversity threshold (e.g., 1.1 times the best score).
        """

        # Best (lowest) score among all candidates
        best_score = scored_candidates[0][0]

        # To track unique candidates and their scores
        seen = set()
        new_intermediate_solutions = []
        selected_scores = []

        for score, candidate in scored_candidates:
            if candidate in seen:
                continue

            # Add candidate if it meets the diversity threshold
            if score > 1.1 * best_score:
                break  # Stop adding candidates if diversity threshold is exceeded

            # Add the candidate and its score
            new_intermediate_solutions.append(candidate)
            selected_scores.append(score)
            seen.add(candidate)

            # Stop when beam width is reached
            if len(new_intermediate_solutions) >= self.beam_width:
                break

        return new_intermediate_solutions, selected_scores

    def _print_progress(self, intermediate_solutions, current_scores, start_time, words):
        """
        Print progress during the beam search process.
        """
        # Best (lowest) score in current iteration
        best_score = exp(min(current_scores))

        # Count of used and remaining words
        used_word_count = len(intermediate_solutions[0].split())
        remaining_word_count = len(words) - used_word_count

        # Time elapsed for this iteration
        elapsed = time.time() - start_time
        estimated_remaining_time = remaining_word_count * elapsed

        # Print progress
        print("===== Beam Search Progress =====")
        print(f"Best Score (Perplexity): {best_score:.4f}")
        print(f"Intermediate Solutions: {intermediate_solutions}")
        print(f"Words Processed: {used_word_count}/{len(words)}")
        print(f"Estimated Remaining Time: {estimated_remaining_time:.2f} seconds")
        print("================================\n")

    def solve(self, text, batch_size=32):
        words = text.split()
        intermediate_solutions = ['']
        eval_cnt = 0

        # Loop until all words are used in the intermediate solution
        while len(intermediate_solutions[0].split()) < len(words):
            start_time = time.time()
            candidates = []

            for intermediate_solution in intermediate_solutions:
                new_candidates = self._make_candidates_adding_word(intermediate_solution, words)
                for candidate in new_candidates:
                    candidates.append(candidate)

           # Remove duplicate candidates
            candidates = list(set(candidates))
            scores = self.scorer.get_perplexity(candidates, batch_size=batch_size)

            eval_cnt += len(scores)
            scored_candidates = sorted(zip(scores, candidates), key=lambda x: x[0] )

            intermediate_solutions, current_scores = self._select_new_intermediate_solutions(scored_candidates)

            self._print_progress(intermediate_solutions, current_scores, start_time, words)

        return current_scores, intermediate_solutions, eval_cnt

# %%
params = {
    'beam_width': 20,
    'scorer': scorer
}
optimizer = BeamSearch(**params)

# %%
Score = float
Solution = str

# Timer start
start_time = time.time()

# Initialize lists to store results
scores: List[Score] = []
solutions: List[Solution] = []
eval_cnts: List[int] = []

'''
The following code is executed only once.
Since my beam search does not involve randomness, running it multiple times will not produce new solutions.

아래 코드는 한 번만 실행됩니다.
제 빔 서치는 무작위성이 없기 때문에 몇 번 실행해도 새로운 해답이 생성되지 않습니다.
'''
text: str = "sleigh of the magi yuletide cheer is unwrap gifts relax and eat cheer decorations carol sing chimney visit workshop grinch holiday holly jingle naughty nice nutcracker polar beard ornament stocking"
score_results, solution_results, eval_cnt = optimizer.solve(text, batch_size=10)  #
scores.extend(score_results)
solutions.extend(solution_results)
eval_cnts.append(eval_cnt)

# Print the results
print("Scores:", [exp(i) for i in scores])
print("Solutions:", solutions)
print("Evaluation Counts:", eval_cnts)

# Measure and print execution time
execute_time: float = time.time() - start_time
print(f"Execution Time: {execute_time:.2f} seconds")
# Out:
# ===== Beam Search Progress =====
# Best Score (Perplexity): 9110.5421
# Intermediate Solutions: ['yuletide']
# Words Processed: 1/30
# Estimated Remaining Time: 54.36 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 1338.3847
# Intermediate Solutions: ['ornament yuletide', 'sleigh yuletide', 'jingle yuletide', 'magi yuletide']
# Words Processed: 2/30
# Estimated Remaining Time: 17.34 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 629.7434
# Intermediate Solutions: ['ornament yuletide holiday', 'ornament yuletide decorations', 'ornament yuletide nutcracker', 'ornament yuletide unwrap', 'ornament yuletide gifts', 'ornament yuletide holly', 'sleigh yuletide holiday', 'ornament yuletide of']
# Words Processed: 3/30
# Estimated Remaining Time: 64.92 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 434.5099
# Intermediate Solutions: ['ornament yuletide holiday decorations', 'ornament yuletide decorations holiday', 'ornament yuletide holiday gifts', 'ornament yuletide holiday nutcracker', 'ornament yuletide of the', 'ornament yuletide nutcracker holiday', 'ornament yuletide holiday holly', 'ornament yuletide gifts holiday', 'ornament yuletide holiday unwrap', 'sleigh yuletide holiday decorations', 'ornament yuletide holiday cheer', 'ornament yuletide unwrap holiday', 'ornament yuletide decorations gifts', 'ornament yuletide of decorations', 'sleigh yuletide holiday ornament', 'ornament yuletide holly and', 'ornament yuletide of holiday', 'ornament yuletide decorations nutcracker', 'ornament yuletide nutcracker grinch', 'ornament yuletide unwrap gifts']
# Words Processed: 4/30
# Estimated Remaining Time: 119.70 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 367.3261
# Intermediate Solutions: ['ornament yuletide of the nutcracker', 'ornament yuletide decorations holiday gifts', 'ornament yuletide of the holiday', 'ornament yuletide gifts holiday decorations', 'ornament yuletide holiday gifts decorations', 'ornament yuletide holiday decorations gifts', 'ornament yuletide of decorations holiday', 'ornament yuletide holly and nutcracker', 'ornament yuletide nutcracker holiday gifts', 'ornament yuletide nutcracker holiday decorations', 'ornament yuletide decorations gifts holiday', 'ornament yuletide decorations holiday nutcracker', 'ornament yuletide holiday decorations nutcracker', 'ornament yuletide holiday holly nutcracker', 'ornament yuletide holiday unwrap gifts', 'ornament yuletide decorations holiday cheer', 'ornament yuletide holiday gifts and', 'ornament yuletide of holiday decorations', 'ornament yuletide of the decorations', 'ornament yuletide of the holly']
# Words Processed: 5/30
# Estimated Remaining Time: 282.55 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 244.6919
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations', 'ornament yuletide of the holiday decorations', 'ornament yuletide of the nutcracker holiday', 'ornament yuletide of the nutcracker and', 'ornament yuletide of the decorations holiday', 'ornament yuletide of decorations holiday and', 'ornament yuletide holiday gifts and grinch', 'ornament yuletide of the holly and', 'ornament yuletide holiday decorations gifts and', 'ornament yuletide holly and nutcracker holiday', 'ornament yuletide nutcracker holiday decorations gifts', 'ornament yuletide of the holiday and', 'ornament yuletide holiday gifts and stocking', 'ornament yuletide decorations holiday gifts unwrap', 'ornament yuletide decorations holiday gifts and', 'ornament yuletide of the decorations and', 'ornament yuletide of the holiday gifts', 'ornament yuletide nutcracker holiday gifts decorations', 'ornament yuletide decorations holiday gifts nutcracker']
# Words Processed: 6/30
# Estimated Remaining Time: 266.82 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 256.4349
# Intermediate Solutions: ['ornament yuletide of the nutcracker and gifts', 'ornament yuletide of the nutcracker and sleigh', 'ornament yuletide of the decorations and holiday', 'ornament yuletide of the holiday and decorations', 'ornament yuletide of the nutcracker and decorations', 'ornament yuletide of the decorations and gifts', 'ornament yuletide of the decorations holiday and', 'ornament yuletide of the holiday decorations and', 'ornament yuletide of the nutcracker holiday gifts', 'ornament yuletide of the nutcracker and holiday', 'ornament yuletide of the nutcracker holiday decorations', 'ornament yuletide holiday gifts and decorations of', 'ornament yuletide of decorations holiday and gifts', 'ornament yuletide of the holiday and gifts', 'ornament yuletide of the nutcracker holiday and', 'ornament yuletide decorations holiday gifts and stocking', 'ornament yuletide of the holly and nutcracker', 'ornament yuletide holly and nutcracker holiday decorations', 'ornament yuletide of the nutcracker and grinch', 'ornament yuletide holiday gifts and stocking decorations']
# Words Processed: 7/30
# Estimated Remaining Time: 253.87 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 194.3249
# Intermediate Solutions: ['ornament yuletide of the holiday decorations and gifts', 'ornament yuletide holiday gifts and decorations of the', 'ornament yuletide of the nutcracker and holiday gifts', 'ornament yuletide of the nutcracker and holiday decorations', 'ornament yuletide of the decorations and holiday gifts', 'ornament yuletide of the nutcracker holiday and gifts', 'ornament yuletide of the decorations and gifts holiday', 'ornament yuletide of the decorations holiday and gifts', 'ornament yuletide of the nutcracker and decorations holiday', 'ornament yuletide of the nutcracker holiday and decorations', 'ornament yuletide holiday gifts and decorations of holly', 'ornament yuletide of the nutcracker and gifts holiday', 'ornament yuletide holiday gifts and decorations of nutcracker', 'ornament yuletide of the nutcracker holiday gifts and', 'ornament yuletide of the nutcracker and sleigh holiday', 'ornament yuletide of the decorations and gifts unwrap', 'ornament yuletide of the nutcracker and gifts unwrap', 'ornament yuletide of the nutcracker holiday gifts decorations', 'ornament yuletide of the holiday and gifts unwrap', 'ornament yuletide of the holiday decorations and holly']
# Words Processed: 8/30
# Estimated Remaining Time: 252.56 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 169.4931
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker', 'ornament yuletide of the nutcracker holiday gifts and decorations', 'ornament yuletide holiday gifts and decorations of the holly', 'ornament yuletide holiday gifts and decorations of the grinch', 'ornament yuletide of the holiday decorations and gifts unwrap', 'ornament yuletide of the nutcracker holiday gifts and stocking', 'ornament yuletide of the holiday decorations and gifts is', 'ornament yuletide of the nutcracker and gifts holiday decorations', 'ornament yuletide of the nutcracker and decorations holiday gifts', 'ornament yuletide of the nutcracker and sleigh holiday decorations', 'ornament yuletide holiday gifts and decorations of the sleigh', 'ornament yuletide of the nutcracker holiday and gifts decorations', 'ornament yuletide of the decorations and gifts unwrap holiday', 'ornament yuletide of the nutcracker and sleigh holiday gifts', 'ornament yuletide of the nutcracker and holiday gifts unwrap', 'ornament yuletide of the decorations and holiday gifts unwrap', 'ornament yuletide of the nutcracker and holiday gifts decorations', 'ornament yuletide of the nutcracker holiday gifts and grinch', 'ornament yuletide of the nutcracker holiday and gifts unwrap', 'ornament yuletide of the nutcracker holiday and decorations gifts']
# Words Processed: 9/30
# Estimated Remaining Time: 232.88 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 206.0513
# Intermediate Solutions: ['ornament yuletide of the holiday decorations and gifts is unwrap', 'ornament yuletide holiday gifts and decorations of the holly nutcracker', 'ornament yuletide of the nutcracker holiday gifts and stocking decorations', 'ornament yuletide holiday gifts and decorations of the nutcracker is', 'ornament yuletide of the holiday decorations and gifts is nice', 'ornament yuletide holiday gifts and decorations of the nutcracker carol', 'ornament yuletide holiday gifts and decorations of the holly jingle', 'ornament yuletide of the nutcracker holiday gifts and decorations unwrap', 'ornament yuletide of the nutcracker holiday gifts and decorations stocking', 'ornament yuletide of the nutcracker holiday gifts and grinch decorations', 'ornament yuletide holiday gifts and decorations of the nutcracker grinch', 'ornament yuletide holiday gifts and decorations of the holly unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly', 'ornament yuletide holiday gifts and decorations of the grinch nutcracker', 'ornament yuletide holiday gifts and decorations of the grinch unwrap', 'ornament yuletide holiday gifts and decorations of the holly cheer', 'ornament yuletide holiday gifts and decorations of the holly stocking', 'ornament yuletide of the holiday decorations and gifts unwrap stocking', 'ornament yuletide of the nutcracker and sleigh holiday decorations gifts']
# Words Processed: 10/30
# Estimated Remaining Time: 216.82 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 211.7632
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker is nice', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker', 'ornament yuletide of the holiday decorations and gifts is unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch', 'ornament yuletide holiday gifts and decorations of the nutcracker is unwrap', 'ornament yuletide of the nutcracker holiday gifts and decorations unwrap stocking', 'ornament yuletide holiday gifts and decorations of the grinch unwrap stocking', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol', 'ornament yuletide holiday gifts and decorations of the holly nutcracker grinch', 'ornament yuletide holiday gifts and decorations of the holly unwrap stocking', 'ornament yuletide holiday gifts and decorations of the holly jingle nutcracker', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle', 'ornament yuletide holiday gifts and decorations of the holly cheer cheer', 'ornament yuletide holiday gifts and decorations of the holly unwrap nutcracker', 'ornament yuletide holiday gifts and decorations of the holly nutcracker sleigh', 'ornament yuletide of the nutcracker holiday gifts and grinch decorations stocking', 'ornament yuletide holiday gifts and decorations of the holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker is grinch', 'ornament yuletide holiday gifts and decorations of the nutcracker carol sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker grinch naughty']
# Words Processed: 11/30
# Estimated Remaining Time: 199.90 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 229.8668
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the grinch holly nutcracker stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker grinch naughty nice', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker carol', 'ornament yuletide holiday gifts and decorations of the holly jingle sleigh nutcracker', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol sleigh', 'ornament yuletide holiday gifts and decorations of the grinch unwrap stocking nutcracker', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the holly unwrap stocking nutcracker', 'ornament yuletide holiday gifts and decorations of the holly jingle nutcracker sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty', 'ornament yuletide holiday gifts and decorations of the nutcracker is nice stocking', 'ornament yuletide holiday gifts and decorations of the holly unwrap nutcracker stocking', 'ornament yuletide holiday gifts and decorations of the holly jingle nutcracker carol', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol sing', 'ornament yuletide holiday gifts and decorations of the holly jingle nutcracker stocking']
# Words Processed: 12/30
# Estimated Remaining Time: 181.08 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 225.4208
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker grinch naughty nice stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker sleigh stocking', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch sleigh', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh holly', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh jingle', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker stocking sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker carol', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker carol sleigh', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly stocking', 'ornament yuletide holiday gifts and decorations of the holly jingle sleigh nutcracker stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker sleigh carol', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker grinch naughty nice sleigh']
# Words Processed: 13/30
# Estimated Remaining Time: 163.19 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 214.2594
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch jingle sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker sleigh stocking', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh holly jingle', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker carol', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker stocking sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker carol sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh holly stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker sleigh carol', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the grinch holly nutcracker carol sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly stocking sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney']
# Words Processed: 14/30
# Estimated Remaining Time: 148.02 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 221.0607
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle unwrap stocking', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking carol', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh jingle', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking chimney', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker carol sleigh stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker carol sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh chimney', 'ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch jingle sleigh stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch sleigh holly stocking jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice beard stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker stocking sleigh carol', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly stocking sleigh jingle', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking unwrap']
# Words Processed: 15/30
# Estimated Remaining Time: 133.02 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 218.4853
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh chimney stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle unwrap stocking sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking chimney carol', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking carol sing', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker carol sing stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh jingle', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle nutcracker carol sleigh stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle unwrap stocking cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle sleigh stocking cheer', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking carol cheer']
# Words Processed: 16/30
# Estimated Remaining Time: 117.63 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 221.9259
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly stocking jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly', 'ornament yuletide holiday gifts and decorations of the grinch holly jingle sleigh nutcracker stocking carol cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly jingle unwrap stocking cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh polar', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh unwrap']
# Words Processed: 17/30
# Estimated Remaining Time: 105.38 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 213.4241
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh chimney stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh beard stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly sleigh jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly unwrap stocking jingle', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle sleigh unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle sleigh beard']
# Words Processed: 18/30
# Estimated Remaining Time: 109.75 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 224.5419
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh beard stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap cheer stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle sleigh unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer cheer unwrap']
# Words Processed: 19/30
# Estimated Remaining Time: 96.08 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 221.9259
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle sleigh unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer cheer unwrap stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap cheer cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap cheer stocking cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap cheer cheer stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer sleigh cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking cheer chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap sleigh sing']
# Words Processed: 20/30
# Estimated Remaining Time: 82.45 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 227.1888
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh cheer cheer unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking cheer cheer chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap cheer cheer sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer sleigh cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer cheer unwrap stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh sing stocking', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap sleigh sing cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh holly jingle unwrap stocking cheer chimney cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice stocking holly jingle unwrap cheer cheer sleigh chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard unwrap cheer']
# Words Processed: 21/30
# Estimated Remaining Time: 69.72 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 239.0236
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap sleigh sing cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer sleigh sing cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle unwrap cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh unwrap cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh chimney sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh sing chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh cheer cheer unwrap sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking sleigh holly jingle unwrap cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh chimney beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh sing stocking chimney', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh unwrap cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle sleigh cheer cheer unwrap stocking chimney sing']
# Words Processed: 22/30
# Estimated Remaining Time: 54.68 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 242.7877
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer unwrap cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar unwrap cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard unwrap cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar unwrap cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh sing chimney visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap sleigh sing cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh sing chimney beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh beard unwrap cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh sing visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap stocking cheer cheer sleigh chimney beard sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit polar', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice holly jingle unwrap cheer cheer sleigh sing stocking chimney visit']
# Words Processed: 23/30
# Estimated Remaining Time: 43.24 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 253.4474
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer sing cheer', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar beard sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit polar beard', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer unwrap cheer sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit polar sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar beard visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar beard workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer eat', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap relax', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh visit polar workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle unwrap cheer cheer sleigh polar beard is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer unwrap cheer is']
# Words Processed: 24/30
# Estimated Remaining Time: 32.71 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 274.0420
# ...
# Words Processed: 28/30
# Estimated Remaining Time: 4.91 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 345.0709
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax visit sing workshop is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing visit workshop relax is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit is workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard unwrap cheer cheer eat sing relax visit workshop is', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit sing eat relax workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing is workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi']
# Words Processed: 29/30
# Estimated Remaining Time: 1.61 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 460.7301
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer che ...
# Words Processed: 30/30
# Estimated Remaining Time: 0.00 seconds
# ================================
#
# Scores: [460.7301436924908, 466.1610848325832, 475.3552883908416, 479.0835461252901, 484.7308313654974, 490.4446850170856, 498.16806499462353, 504.04031250414465, 511.9777924614019, 518.012824668342, 524.1189959252079, 524.1189959252079, 524.1189959252079, 532.3726691377844, 534.4563168515505, 536.5481197318883, 549.27199171561, 549.27199171561, 551.4217815078388, 555.7466361419574]
# Solutions: ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi', 'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax', 'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap  ...
# Evaluation Counts: [14121]
# Execution Time: 210.40 seconds

# %%
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, cost_fn, random_state, alpha):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        self.cost_fn = cost_fn
        random.seed(random_state)
        self.alpha = alpha

    def _generate_neighbor(self, solution):
        """
        Generate a neighboring solution by randomly modifying the word sequence.
        """
        neighbor = solution.split()
        if len(neighbor) < 2:
            return solution  # No meaningful modification possible

        r = random.choice(range(4))  # Randomly choose a modification type

        if r == 0:  # Swap two words
            i, j = random.sample(range(len(neighbor)), 2)
            neighbor[i], neighbor[j] = neighbor[j], neighbor[i]

        elif r == 1:  # Move one word to a new position
            i = random.randrange(len(neighbor))
            elem = neighbor.pop(i)
            j = random.randrange(len(neighbor) + 1)
            neighbor.insert(j, elem)

        elif r == 2:  # Reverse a random subsequence
            start = random.randint(0, len(neighbor) - 2)
            end = random.randint(start + 1, min(start + 5, len(neighbor)))
            neighbor[start:end + 1] = reversed(neighbor[start:end + 1])

        elif r == 3:  # Move a block of words
            block_size = random.choice(range(2, min(5, len(neighbor)) + 1))  # Block size: 2 to min(5, len(neighbor))
            start = random.randrange(len(neighbor) - block_size + 1)
            block = neighbor[start:start + block_size]
            del neighbor[start:start + block_size]
            insert_pos = random.randrange(len(neighbor) + 1)
            neighbor = neighbor[:insert_pos] + block + neighbor[insert_pos:]

        neighbor_solution = ' '.join(neighbor)
        return neighbor_solution

    def _acceptance_probability(self, diff, temperature):
        if diff <= 0:
            return 1.0
        return math.exp(- diff/ temperature)

    def _lower_temperature(self, temperature, iteration):
        t1 = self.end_temp + self.start_temp/(1 + math.log(iteration+1))
        t2 = self.start_temp + (self.end_temp - self.start_temp)*(iteration/self.max_iterations)
        return max(t1, t2)

    def _print_progress(
        self,
        iteration: int,
        best_solutions: List[List[str]],
        best_energies: List[float],
        current_solutions: List[List[str]],
        current_energies: List[float],
        temperature: float,
        start_time: float,
        spend_minute: int
    ) -> int:
        current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        elapsed_time = time.time() - start_time

        # Check if 60 seconds have passed since the last update
        if elapsed_time - 60 * spend_minute > 60:
            spend_minute += 1
            progress = iteration / self.max_iterations * 100  # Progress as percentage

            # Print progress in a structured format
            print("===== Simulated Annealing Progress =====")
            print(f"Time: {current_time}")
            print(f"Iteration: {iteration}/{self.max_iterations} ({progress:.2f}%)")
            print(f"Temperature: {temperature:.4f}")
            print(f"Elapsed Time: {elapsed_time:.2f} seconds")

            # Print best solutions and energies
            print("\nBest Solutions:")
            for i, solution in enumerate(best_solutions):
                print(f"  Solution {i+1}: {solution}")
            print("\nBest Energies:")
            print("  " + ", ".join(f"{exp(energy):.4f}" for energy in best_energies))

            # Print current solutions and energies
            print("\nCurrent Solutions:")
            for i, solution in enumerate(current_solutions):
                print(f"  Solution {i+1}: {solution}")
            print("\nCurrent Energies:")
            print("  " + ", ".join(f"{exp(energy):.4f}" for energy in current_energies))

            print("========================================\n")

        return spend_minute

    def solve_batch(self, text_list):
        """
        Perform Simulated Annealing for multiple texts at once.
        """
        solutions = text_list[:]
        current_energies = self.cost_fn(solutions)

        best_solutions = solutions[:]
        best_energies = current_energies[:]

        log_energies = [[] for _ in range(len(text_list))]
        for i in range(len(text_list)):
            log_energies[i].append(current_energies[i])

        temperature = self.start_temp
        start_time = time.time()
        spend_minute = 0

        for iteration in range(self.max_iterations):
            # 1) Generate neighbors
            new_solutions = [self._generate_neighbor(sol) for sol in solutions]

            # 2) Calculate new energies in batch
            new_energies = self.cost_fn(new_solutions)

            # 3) Acceptance and update
            for i in range(len(text_list)):

                diff = new_energies[i] - current_energies[i]
                ap = self._acceptance_probability(diff, temperature)

                if random.random() < ap:
                    solutions[i] = new_solutions[i]
                    current_energies[i] = new_energies[i]

                if current_energies[i] < best_energies[i]:
                    best_solutions[i] = solutions[i][:]
                    best_energies[i] = current_energies[i]

            # 4) Lower temperature
            temperature = self._lower_temperature(temperature, iteration)

            # 5) Log current energies
            for i in range(len(text_list)):
                log_energies[i].append(current_energies[i])

            # 6) Print progress (extracted into separate method)
            spend_minute = self._print_progress(
                iteration,
                best_solutions,
                best_energies,
                solutions,
                current_energies,
                temperature,
                start_time,
                spend_minute
            )

            # 7) Early stop if temperature is below threshold
            if temperature <= self.end_temp:
                print("Reached the minimum temperature. Exiting.")
                break

        print(f"Execution time: {time.time() - start_time:.4f}s")

        # Convert best solutions back to strings
        return best_solutions, best_energies, log_energies

# %%
def cost_fn(sol):
    return scorer.get_perplexity(sol, batch_size=20)

# %%
torch.cuda.empty_cache()

# %%
sa_params = {
    'start_temp': 0.03,             # Initial temperature
    'end_temp': 0.003,          # Final temperature, decreasing linearly
    'max_iterations': 4500,    #45000 Number of iterations (approximately 4 hours for 100,000 iterations)
    'random_state': 42,          # Seed for the random number generator to ensure reproducibility
    "alpha": 0.9999,             # Exponential decay rate for temperature reduction
    "cost_fn": cost_fn
}

# Initialize the SimulatedAnnealing optimizer with the specified parameters
sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
best_solutions, best_energies, log_scores = sa_optimizer.solve_batch(solutions)

# %%
print(best_solutions)

# %%
# To visualize whether the scores decreased appropriately, you can use matplotlib to create a plot.

import matplotlib.pyplot as plt
plt.plot(log_scores[0])
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()

# %%
# To visualize whether the scores decreased appropriately, you can use matplotlib to create a plot.

import matplotlib.pyplot as plt

for score in log_scores:
    plt.plot(score)
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()

# %%
print(scorer.get_perplexity(best_solutions), best_solutions)
