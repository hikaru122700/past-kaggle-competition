# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/075_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_060.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_060.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.221442e+04
# 1                                 5.849961e+04
# 2                                 9.940945e+04
# 3                                 5.162331e+04
# 4                                 5.063790e+04
# ...                                        ...
# 2503                              5.375020e+05
# 2504                              9.933916e+04
# 2505                              1.379589e+05
# 2506                              2.612069e+05
# 2507                              1.383562e+06
#
# [7163 rows x 19 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.154699e+04
# 1                  14            1     5.934671e+04
# 2                   9            1     9.912108e+04
# 3                  15            1     5.145036e+04
# 4                  15            0     5.105989e+04
# ...               ...          ...              ...
# 2503                1            1     5.230794e+05
# 2504                9            1     1.003121e+05
# 2505                8            0     1.349400e+05
# 2506                8            0     2.626193e+05
# 2507                9            1     1.295969e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1      diff
# 0                                 4.221442e+04  0.015936
# 1                                 5.849961e+04 -0.014376
# 2                                 9.940945e+04  0.002905
# 3                                 5.162331e+04  0.003356
# 4                                 5.063790e+04 -0.008299
# ...                                        ...       ...
# 2503                              5.375020e+05  0.027199
# 2504                              9.933916e+04 -0.009746
# 2505                              1.379589e+05  0.022125
# 2506                              2.612069e+05 -0.005393
# 2507                              1.383562e+06  0.065402
#
# [7163 rows x 20 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.154699e+04  0.015936
# 1                  14            1     5.934671e+04 -0.014376
# 2                   9            1     9.912108e+04  0.002905
# 3                  15            1     5.145036e+04  0.003356
# 4                  15            0     5.105989e+04 -0.008299
# ...               ...          ...              ...       ...
# 2503                1            1     5.230794e+05  0.027199
# 2504                9            1     1.003121e+05 -0.009746
# 2505                8            0     1.349400e+05  0.022125
# 2506                8            0     2.626193e+05 -0.005393
# 2507                9            1     1.295969e+06  0.065402
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     41546.989638  0.015936
# 1                  14            1     59346.709274 -0.014376
# 2                   9            1     99121.078125  0.002905
# 3                  15            1     51450.356554  0.003356
# 4                  15            0     51059.886013 -0.008299
# ...               ...          ...              ...       ...
# 4650               15            0     46740.289062  0.051725
# 4651                8            1    170354.516977 -0.004237
# 4652                8            0     31492.170648  0.007092
# 4653                8            0     66290.436080 -0.009507
# 4654                9            1    146419.312500 -0.006726
#
# [4655 rows x 19 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
import time
epock = 20
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.002745741729707132
# Fold 18 RMSLE for ('model1', 'model3') = 0.002752089829289585
# Fold 18 RMSLE for ('model1', 'model4') = 0.0027351985218199096
# Fold 18 RMSLE for ('model2', 'model3') = 0.002774556112823576
# Fold 18 RMSLE for ('model2', 'model4') = 0.002767536936549933
# Fold 18 RMSLE for ('model3', 'model4') = 0.0027657068197604476
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.0027523338414960036
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.0027476496174485246
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.0027474922067963633
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.002764177534764034
# Fold 18 RMSLE for all models ensemble = 0.0027509609735143215
# Fold 18 best combination: model1 with RMSLE = 0.0027202036260907995
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.003220112521634075
# Fold 19 RMSLE for model2 = 0.003226914083162076
# Fold 19 RMSLE for model3 = 0.00326467219611991
# Fold 19 RMSLE for model4 = 0.0032373943157002726
# Fold 19 RMSLE for ('model1', 'model2') = 0.0032173915119316425
# Fold 19 RMSLE for ('model1', 'model3') = 0.0032319471855222176
# Fold 19 RMSLE for ('model1', 'model4') = 0.003226388782699599
# Fold 19 RMSLE for ('model2', 'model3') = 0.003225502576667932
# Fold 19 RMSLE for ('model2', 'model4') = 0.0032284753190247027
# Fold 19 RMSLE for ('model3', 'model4') = 0.0032365486663098915
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.003220828857573991
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.003222734541201897
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.0032285759958074613
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.0032258829472562025
# Fold 19 RMSLE for all models ensemble = 0.0032229020122152533
# Fold 19 best combination: ('model1', 'model2') with RMSLE = 0.0032173915119316425
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0031942500321616627
# Fold 20 RMSLE for model2 = 0.0031853854870097023
# Fold 20 RMSLE for model3 = 0.0032144850673130362
# Fold 20 RMSLE for model4 = 0.0031870929288483106
# Fold 20 RMSLE for ('model1', 'model2') = 0.003181895007879857
# Fold 20 RMSLE for ('model1', 'model3') = 0.0031934357220380918
# Fold 20 RMSLE for ('model1', 'model4') = 0.0031885444228103117
# Fold 20 RMSLE for ('model2', 'model3') = 0.0031773080088470956
# Fold 20 RMSLE for ('model2', 'model4') = 0.0031808661329072005
# Fold 20 RMSLE for ('model3', 'model4') = 0.003185656842492791
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.003179592334215757
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.0031820546755829586
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.0031860689500520945
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.003176463161385959
# Fold 20 RMSLE for all models ensemble = 0.0031792575140916833
# Fold 20 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.003176463161385959
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.002727243815729606
# Fold 21 RMSLE for model2 = 0.002812460327758941
# Fold 21 RMSLE for model3 = 0.002822137839409445
# Fold 21 RMSLE for model4 = 0.0027784766879954985
# Fold 21 RMSLE for ('model1', 'model2') = 0.0027591309921234405
# Fold 21 RMSLE for ('model1', 'model3') = 0.0027642101829201643
# Fold 21 RMSLE for ('model1', 'model4') = 0.002748946583942135
# Fold 21 RMSLE for ('model2', 'model3') = 0.002791911747595925
# Fold 21 RMSLE for ('model2', 'model4') = 0.0027905215652352573
# Fold 21 RMSLE for ('model3', 'model4') = 0.002782904204705263
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.0027664955365994956
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.0027640220775174964
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0027617673640704236
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.002783104236366184
# Fold 21 RMSLE for all models ensemble = 0.00276679477943772
# Fold 21 best combination: model1 with RMSLE = 0.002727243815729606
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.003114942344564506
# Fold 22 RMSLE for model2 = 0.0031307257900461813
# Fold 22 RMSLE for model3 = 0.0031603113277180917
# Fold 22 RMSLE for model4 = 0.0031321150525241447
# Fold 22 RMSLE for ('model1', 'model2') = 0.003115634927407125
# Fold 22 RMSLE for ('model1', 'model3') = 0.003127084410073809
# Fold 22 RMSLE for ('model1', 'model4') = 0.0031210443929722783
# Fold 22 RMSLE for ('model2', 'model3') = 0.0031258630024159195
# Fold 22 RMSLE for ('model2', 'model4') = 0.003127499924001211
# Fold 22 RMSLE for ('model3', 'model4') = 0.003131657136201328
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0031186812066584793
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.003119881853692047
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.003123509911987994
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0031240829845656203
# Fold 22 RMSLE for all models ensemble = 0.003119907716272127
# Fold 22 best combination: model1 with RMSLE = 0.003114942344564506
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.0029483719292078404
# Fold 23 RMSLE for model2 = 0.002933498449422898
# Fold 23 RMSLE for model3 = 0.0030691496247860915
# Fold 23 RMSLE for model4 = 0.0029515669894269033
# Fold 23 RMSLE for ('model1', 'model2') = 0.0029301122947044747
# Fold 23 RMSLE for ('model1', 'model3') = 0.0029970150589353362
# Fold 23 RMSLE for ('model1', 'model4') = 0.0029469496717171523
# Fold 23 RMSLE for ('model2', 'model3') = 0.0029736874225917676
# Fold 23 RMSLE for ('model2', 'model4') = 0.002937188787215597
# Fold 23 RMSLE for ('model3', 'model4') = 0.0029927713426794126
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.002961304277526568
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.0029359559434525054
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.0029752468356595402
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.002962158755014637
# Fold 23 RMSLE for all models ensemble = 0.002956512988529109
# Fold 23 best combination: ('model1', 'model2') with RMSLE = 0.0029301122947044747
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.0031591834111715793
# Fold 24 RMSLE for model2 = 0.003177299064987044
# Fold 24 RMSLE for model3 = 0.0032751990867333144
# Fold 24 RMSLE for model4 = 0.003165855134774745
# Fold 24 RMSLE for ('model1', 'model2') = 0.0031607207674910205
# Fold 24 RMSLE for ('model1', 'model3') = 0.0032070438997928944
# Fold 24 RMSLE for ('model1', 'model4') = 0.0031590527209591573
# Fold 24 RMSLE for ('model2', 'model3') = 0.003207251374936043
# Fold 24 RMSLE for ('model2', 'model4') = 0.0031666634112637953
# Fold 24 RMSLE for ('model3', 'model4') = 0.003205864546409365
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.0031875520502470476
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.0031603762115744753
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.003187462261177527
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.003188910419777266
# Fold 24 RMSLE for all models ensemble = 0.0031793894061287885
# Fold 24 best combination: ('model1', 'model4') with RMSLE = 0.0031590527209591573
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.003334643158529712
# Fold 25 RMSLE for model2 = 0.003282297205886996
# Fold 25 RMSLE for model3 = 0.0033768432435869206
# Fold 25 RMSLE for model4 = 0.003324833836010046
# Fold 25 RMSLE for ('model1', 'model2') = 0.003301790201381388
# Fold 25 RMSLE for ('model1', 'model3') = 0.003345879412906305
# Fold 25 RMSLE for ('model1', 'model4') = 0.0033277740428893678
# Fold 25 RMSLE for ('model2', 'model3') = 0.0033104016385409915
# Fold 25 RMSLE for ('model2', 'model4') = 0.0032999037357124734
# Fold 25 RMSLE for ('model3', 'model4') = 0.0033378352970276
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.0033153775733414698
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.003308460755533745
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.0033343848179555246
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.003312032059986737
# Fold 25 RMSLE for all models ensemble = 0.003316045108995119
# Fold 25 best combination: model2 with RMSLE = 0.003282297205886996
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.002890231968699427
# Fold 26 RMSLE for model2 = 0.0028954554692068642
# Fold 26 RMSLE for model3 = 0.0029815383834012723
# Fold 26 RMSLE for model4 = 0.002899501857824517
# Fold 26 RMSLE for ('model1', 'model2') = 0.002884445671997944
# Fold 26 RMSLE for ('model1', 'model3') = 0.00292392527953082
# Fold 26 RMSLE for ('model1', 'model4') = 0.0028923119118871004
# Fold 26 RMSLE for ('model2', 'model3') = 0.0029110892727726065
# Fold 26 RMSLE for ('model2', 'model4') = 0.002892595932670742
# Fold 26 RMSLE for ('model3', 'model4') = 0.002923182606013018
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.0029011214720123905
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.0028880252924723513
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.0029095454423309804
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.002903366811862578
# Fold 26 RMSLE for all models ensemble = 0.0028984689888188904
# Fold 26 best combination: ('model1', 'model2') with RMSLE = 0.002884445671997944
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.0028032620256056556
# Fold 27 RMSLE for model2 = 0.0028308420392097423
# Fold 27 RMSLE for model3 = 0.002892506627687317
# Fold 27 RMSLE for model4 = 0.0028229357558900723
# Fold 27 RMSLE for ('model1', 'model2') = 0.002803002629622488
# Fold 27 RMSLE for ('model1', 'model3') = 0.002835438599765925
# Fold 27 RMSLE for ('model1', 'model4') = 0.0028090359197888086
# Fold 27 RMSLE for ('model2', 'model3') = 0.00282794356424798
# Fold 27 RMSLE for ('model2', 'model4') = 0.0028199835569948256
# Fold 27 RMSLE for ('model3', 'model4') = 0.0028368527516863156
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.002815367810539146
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.0028078925329858566
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.0028228959657955214
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.00282134709495929
# Fold 27 RMSLE for all models ensemble = 0.002814283720682541
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.002803002629622488
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.003242443841077016
# Fold 28 RMSLE for model2 = 0.003237165425675943
# Fold 28 RMSLE for model3 = 0.003309250636774283
# Fold 28 RMSLE for model4 = 0.0032498040161059428
# Fold 28 RMSLE for ('model1', 'model2') = 0.003232650296973052
# Fold 28 RMSLE for ('model1', 'model3') = 0.003265146781038487
# Fold 28 RMSLE for ('model1', 'model4') = 0.0032440920594707778
# Fold 28 RMSLE for ('model2', 'model3') = 0.0032507604591787355
# Fold 28 RMSLE for ('model2', 'model4') = 0.0032393531161971157
# Fold 28 RMSLE for ('model3', 'model4') = 0.0032647219446604258
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.0032450098130385337
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.0032372205358266633
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.0032548954015229293
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.003246971927607013
# Fold 28 RMSLE for all models ensemble = 0.0032443058692525864
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.003232650296973052
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.002637312010604188
# Fold 29 RMSLE for model2 = 0.0026222731771794548
# Fold 29 RMSLE for model3 = 0.0026902129697244587
# Fold 29 RMSLE for model4 = 0.002633877626705964
# Fold 29 RMSLE for ('model1', 'model2') = 0.002621864677967879
# Fold 29 RMSLE for ('model1', 'model3') = 0.0026513899111030395
# Fold 29 RMSLE for ('model1', 'model4') = 0.002632693462818586
# Fold 29 RMSLE for ('model2', 'model3') = 0.0026348337280240053
# Fold 29 RMSLE for ('model2', 'model4') = 0.0026229746030834327
# Fold 29 RMSLE for ('model3', 'model4') = 0.002645623840160452
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.0026313619073005472
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.0026240752339138852
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.002639678083983437
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0026296557948569965
# Fold 29 RMSLE for all models ensemble = 0.0026293365865408453
# Fold 29 best combination: ('model1', 'model2') with RMSLE = 0.002621864677967879
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.0033833744038631857
# Fold 30 RMSLE for model2 = 0.003402637251628039
# Fold 30 RMSLE for model3 = 0.0034340225606284106
# Fold 30 RMSLE for model4 = 0.003397977106170655
# Fold 30 RMSLE for ('model1', 'model2') = 0.003386595961377208
# Fold 30 RMSLE for ('model1', 'model3') = 0.003399958430469913
# Fold 30 RMSLE for ('model1', 'model4') = 0.003388810876534715
# Fold 30 RMSLE for ('model2', 'model3') = 0.003401584736707908
# Fold 30 RMSLE for ('model2', 'model4') = 0.0033961728020716142
# Fold 30 RMSLE for ('model3', 'model4') = 0.0034043150023466413
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.0033924825307269932
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.003389146618567475
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.0033952006454488147
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.003397054551026009
# Fold 30 RMSLE for all models ensemble = 0.0033920847854628402
# Fold 30 best combination: model1 with RMSLE = 0.0033833744038631857
# ---------------
#
# OOF RMSLE = 0.0030422460756022855
# Sum of RMSLE for each combination:
# ('model1',): 0.09137085861589883
# ('model2',): 0.09192121060654425
# ('model3',): 0.0931779268375014
# ('model4',): 0.09177548420266049
# ('model1', 'model2'): 0.09138228304855403
# ('model1', 'model3'): 0.09193323761121021
# ('model1', 'model4'): 0.09149053932636826
# ('model2', 'model3'): 0.09181721491468145
# ('model2', 'model4'): 0.09170377196990456
# ('model3', 'model4'): 0.09198600817324759
# ('model1', 'model2', 'model3'): 0.09156117943956643
# ('model1', 'model2', 'model4'): 0.09147093681223044
# ('model1', 'model3', 'model4'): 0.09170070191092355
# ('model2', 'model3', 'model4'): 0.09168253925387523
# ('model1', 'model2', 'model3', 'model4'): 0.09154621828734005
#
# 11番目の学習が終わりました。
#
# 推定時間は19
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.0028376249939759774
# Fold 1 RMSLE for model2 = 0.0028295782228990505
# Fold 1 RMSLE for model3 = 0.0028513576332101767
# Fold 1 RMSLE for model4 = 0.0028550532515606675
# Fold 1 RMSLE for ('model1', 'model2') = 0.0028266498850594546
# Fold 1 RMSLE for ('model1', 'model3') = 0.0028371415247674847
# Fold 1 RMSLE for ('model1', 'model4') = 0.00284402877245212
# Fold 1 RMSLE for ('model2', 'model3') = 0.002824933348040713
# Fold 1 RMSLE for ('model2', 'model4') = 0.002837305314729271
# Fold 1 RMSLE for ('model3', 'model4') = 0.002842283731959987
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.002826254120759652
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.002834412444027932
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.0028388594923928067
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.0028313409541945523
# Fold 1 RMSLE for all models ensemble = 0.0028313799182229566
# Fold 1 best combination: ('model2', 'model3') with RMSLE = 0.002824933348040713
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.002589795721696501
# Fold 2 RMSLE for model2 = 0.0026104041914309342
# Fold 2 RMSLE for model3 = 0.0025851789019406585
# Fold 2 RMSLE for model4 = 0.0025954741264904864
# Fold 2 RMSLE for ('model1', 'model2') = 0.0025914711256059685
# Fold 2 RMSLE for ('model1', 'model3') = 0.0025767762574653765
# Fold 2 RMSLE for ('model1', 'model4') = 0.002590116616116289
# Fold 2 RMSLE for ('model2', 'model3') = 0.0025751990949518582
# Fold 2 RMSLE for ('model2', 'model4') = 0.0025981969409091268
# Fold 2 RMSLE for ('model3', 'model4') = 0.0025755691046649085
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.0025764789399583977
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.0025914920247842553
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.002577713606878606
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.0025783174919189796
# Fold 2 RMSLE for all models ensemble = 0.002579224330576746
# Fold 2 best combination: ('model2', 'model3') with RMSLE = 0.0025751990949518582
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.0029167398557533608
# Fold 3 RMSLE for model2 = 0.00292251733533764
# Fold 3 RMSLE for model3 = 0.0029683570572400903
# Fold 3 RMSLE for model4 = 0.0029283585723004256
# Fold 3 RMSLE for ('model1', 'model2') = 0.0029104018940026934
# Fold 3 RMSLE for ('model1', 'model3') = 0.0029349200127834706
# Fold 3 RMSLE for ('model1', 'model4') = 0.0029198360323801943
# Fold 3 RMSLE for ('model2', 'model3') = 0.0029231440756280363
# Fold 3 RMSLE for ('model2', 'model4') = 0.0029211034579675224
# Fold 3 RMSLE for ('model3', 'model4') = 0.002935468229825023
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.0029184516669903226
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.0029153072131146633
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.002927473079705944
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.002922153440848854
# Fold 3 RMSLE for all models ensemble = 0.002919193993448049
# Fold 3 best combination: ('model1', 'model2') with RMSLE = 0.0029104018940026934
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.003022321774729973
# Fold 4 RMSLE for model2 = 0.003107224663521844
# Fold 4 RMSLE for model3 = 0.0030551092923033723
# Fold 4 RMSLE for model4 = 0.0030772997610790357
# Fold 4 RMSLE for ('model1', 'model2') = 0.0030542643151613984
# Fold 4 RMSLE for ('model1', 'model3') = 0.0030312063362976415
# Fold 4 RMSLE for ('model1', 'model4') = 0.0030467807707112394
# Fold 4 RMSLE for ('model2', 'model3') = 0.0030609142935329693
# Fold 4 RMSLE for ('model2', 'model4') = 0.0030871752845129303
# Fold 4 RMSLE for ('model3', 'model4') = 0.0030550346496009038
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.003044499373136154
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.0030606675269849934
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.0030419180902581805
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.003063658403547451
# Fold 4 RMSLE for all models ensemble = 0.0030510788819287094
# Fold 4 best combination: model1 with RMSLE = 0.003022321774729973
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.0029274411814572696
# Fold 5 RMSLE for model2 = 0.0029219600513348425
# Fold 5 RMSLE for model3 = 0.0029996129793779824
# Fold 5 RMSLE for model4 = 0.0029147611624667186
# Fold 5 RMSLE for ('model1', 'model2') = 0.00291367868647747
# Fold 5 RMSLE for ('model1', 'model3') = 0.002954927779005997
# Fold 5 RMSLE for ('model1', 'model4') = 0.0029181415912775555
# Fold 5 RMSLE for ('model2', 'model3') = 0.002935178532232525
# Fold 5 RMSLE for ('model2', 'model4') = 0.002912593362330215
# Fold 5 RMSLE for ('model3', 'model4') = 0.0029426636718915644
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.002929545627836433
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.0029126067108644765
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.0029356477515677377
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.00292498070616775
# Fold 5 RMSLE for all models ensemble = 0.002923772309350616
# Fold 5 best combination: ('model2', 'model4') with RMSLE = 0.002912593362330215
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.0030879626586817798
# Fold 6 RMSLE for model2 = 0.0031370100226024
# Fold 6 RMSLE for model3 = 0.0031634536730809487
# Fold 6 RMSLE for model4 = 0.0031359770545127535
# Fold 6 RMSLE for ('model1', 'model2') = 0.003103800080680664
# Fold 6 RMSLE for ('model1', 'model3') = 0.0031173861255245003
# Fold 6 RMSLE for ('model1', 'model4') = 0.003109424129866147
# Fold 6 RMSLE for ('model2', 'model3') = 0.0031292112043831465
# Fold 6 RMSLE for ('model2', 'model4') = 0.0031323444078574006
# Fold 6 RMSLE for ('model3', 'model4') = 0.0031369127763139996
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.0031125329343083532
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.0031134832592184026
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.0031185830317338936
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.0031285857820184237
# Fold 6 RMSLE for all models ensemble = 0.0031166844314772404
# Fold 6 best combination: model1 with RMSLE = 0.0030879626586817798
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.0030737267385462876
# Fold 7 RMSLE for model2 = 0.0030981449327199383
# Fold 7 RMSLE for model3 = 0.003075993765194802
# Fold 7 RMSLE for model4 = 0.0030954506480641627
# Fold 7 RMSLE for ('model1', 'model2') = 0.0030776379817613686
# Fold 7 RMSLE for ('model1', 'model3') = 0.003066108038948492
# Fold 7 RMSLE for ('model1', 'model4') = 0.003081882446246171
# Fold 7 RMSLE for ('model2', 'model3') = 0.0030654341127226456
# Fold 7 RMSLE for ('model2', 'model4') = 0.0030921830175052257
# Fold 7 RMSLE for ('model3', 'model4') = 0.0030721040518279664
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.0030654165142943945
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.003082165369599744
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.0030705775144565127
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.003072153918517113
# Fold 7 RMSLE for all models ensemble = 0.003070922241575106
# Fold 7 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.0030654165142943945
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.0029758754935172113
# Fold 8 RMSLE for model2 = 0.0030085528840368167
# Fold 8 RMSLE for model3 = 0.003022702530449765
# Fold 8 RMSLE for model4 = 0.0029838014849487664
# Fold 8 RMSLE for ('model1', 'model2') = 0.002984131489082474
# Fold 8 RMSLE for ('model1', 'model3') = 0.002991564484979427
# Fold 8 RMSLE for ('model1', 'model4') = 0.002977606660840308
# Fold 8 RMSLE for ('model2', 'model3') = 0.002996053861858097
# Fold 8 RMSLE for ('model2', 'model4') = 0.0029910902062913708
# Fold 8 RMSLE for ('model3', 'model4') = 0.002991453254198931
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.0029866256359463977
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.0029825588279827446
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.0029844398581809466
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.002988790454056275
# Fold 8 RMSLE for all models ensemble = 0.002984077685059861
# Fold 8 best combination: model1 with RMSLE = 0.0029758754935172113
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.0029332341725391816
# Fold 9 RMSLE for model2 = 0.002940425390213556
# Fold 9 RMSLE for model3 = 0.002951412176479269
# Fold 9 RMSLE for model4 = 0.0029392741341275896
# Fold 9 RMSLE for ('model1', 'model2') = 0.0029301216552273077
# Fold 9 RMSLE for ('model1', 'model3') = 0.0029336512844956486
# Fold 9 RMSLE for ('model1', 'model4') = 0.002934396140583908
# Fold 9 RMSLE for ('model2', 'model3') = 0.002927335275440335
# Fold 9 RMSLE for ('model2', 'model4') = 0.002935726775148891
# Fold 9 RMSLE for ('model3', 'model4') = 0.002933800770411635
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.002926584287474392
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.00293200433281118
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.0029314895934656783
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.002928473514916209
# Fold 9 RMSLE for all models ensemble = 0.0029282037466141432
# Fold 9 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.002926584287474392
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.0030872728642055
# Fold 10 RMSLE for model2 = 0.0031310815823844106
# Fold 10 RMSLE for model3 = 0.0031154059944025684
# Fold 10 RMSLE for model4 = 0.0031062913298080643
# Fold 10 RMSLE for ('model1', 'model2') = 0.0031004310611065073
# Fold 10 RMSLE for ('model1', 'model3') = 0.003092815489493589
# Fold 10 RMSLE for ('model1', 'model4') = 0.0030938255760768075
# Fold 10 RMSLE for ('model2', 'model3') = 0.0031016373792826287
# Fold 10 RMSLE for ('model2', 'model4') = 0.0031139067258520157
# Fold 10 RMSLE for ('model3', 'model4') = 0.003097352152353759
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.0030939485608625244
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.0031008852999214864
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.003091877616160635
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.0030998596264113012
# Fold 10 RMSLE for all models ensemble = 0.0030949650249766313
# Fold 10 best combination: model1 with RMSLE = 0.0030872728642055
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.0031836233615251354
# Fold 11 RMSLE for model2 = 0.003204191806214382
# Fold 11 RMSLE for model3 = 0.0031543185842199217
# Fold 11 RMSLE for model4 = 0.0032036048538562362
# Fold 11 RMSLE for ('model1', 'model2') = 0.003184920807042483
# Fold 11 RMSLE for ('model1', 'model3') = 0.003161021028520165
# Fold 11 RMSLE for ('model1', 'model4') = 0.0031909687435299444
# Fold 11 RMSLE for ('model2', 'model3') = 0.0031573103685551933
# Fold 11 RMSLE for ('model2', 'model4') = 0.0031988238802172315
# Fold 11 RMSLE for ('model3', 'model4') = 0.003166022898091627
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.0031634282461300294
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.0031897146902217814
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.0031700662155493987
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.003169638622298217
# Fold 11 RMSLE for all models ensemble = 0.003171564427129147
# Fold 11 best combination: model3 with RMSLE = 0.0031543185842199217
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.002900791865731599
# Fold 12 RMSLE for model2 = 0.002959316729058233
# Fold 12 RMSLE for model3 = 0.002945158511016023
# Fold 12 RMSLE for model4 = 0.0029280596737111357
# Fold 12 RMSLE for ('model1', 'model2') = 0.002921991792079448
# Fold 12 RMSLE for ('model1', 'model3') = 0.0029141301373544915
# Fold 12 RMSLE for ('model1', 'model4') = 0.0029121478701089982
# Fold 12 RMSLE for ('model2', 'model3') = 0.0029330185927028767
# Fold 12 RMSLE for ('model2', 'model4') = 0.0029389084724685366
# Fold 12 RMSLE for ('model3', 'model4') = 0.0029244645414627235
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.002918999954665464
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.0029226626869581647
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.002914311898244293
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.0029281023074327352
# Fold 12 RMSLE for all models ensemble = 0.0029194712324218434
# Fold 12 best combination: model1 with RMSLE = 0.002900791865731599
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.0030810456612086643
# Fold 13 RMSLE for model2 = 0.0030937126320292564
# Fold 13 RMSLE for model3 = 0.003156346881797704
# Fold 13 RMSLE for model4 = 0.0031022346623277167
# Fold 13 RMSLE for ('model1', 'model2') = 0.0030796130964312464
# Fold 13 RMSLE for ('model1', 'model3') = 0.0031119895223479764
# Fold 13 RMSLE for ('model1', 'model4') = 0.003089646893220786
# Fold 13 RMSLE for ('model2', 'model3') = 0.003107447229046203
# Fold 13 RMSLE for ('model2', 'model4') = 0.0030932699933527556
# Fold 13 RMSLE for ('model3', 'model4') = 0.003119172850673938
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.0030960991532514395
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.0030859044394531037
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.00310482270059049
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.0031030039895756285
# Fold 13 RMSLE for all models ensemble = 0.0030960885589936937
# Fold 13 best combination: ('model1', 'model2') with RMSLE = 0.0030796130964312464
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.0028637028724179023
# Fold 14 RMSLE for model2 = 0.002899342053204269
# Fold 14 RMSLE for model3 = 0.0029347319343578245
# Fold 14 RMSLE for model4 = 0.0028773755522142177
# Fold 14 RMSLE for ('model1', 'model2') = 0.002872108892294055
# Fold 14 RMSLE for ('model1', 'model3') = 0.0028914397438218266
# Fold 14 RMSLE for ('model1', 'model4') = 0.002868225149570655
# Fold 14 RMSLE for ('model2', 'model3') = 0.002895507358762931
# Fold 14 RMSLE for ('model2', 'model4') = 0.0028827809867017604
# Fold 14 RMSLE for ('model3', 'model4') = 0.002893975652454558
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.0028820123099475787
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.0028724425593135133
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.002882055628122654
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.0028863627765226244
# Fold 14 RMSLE for all models ensemble = 0.0028790698547600142
# Fold 14 best combination: model1 with RMSLE = 0.0028637028724179023
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.002970043828036031
# Fold 15 RMSLE for model2 = 0.003003215860205652
# Fold 15 RMSLE for model3 = 0.002964302374150192
# Fold 15 RMSLE for model4 = 0.003001737211937198
# Fold 15 RMSLE for ('model1', 'model2') = 0.002977471909605322
# Fold 15 RMSLE for ('model1', 'model3') = 0.0029580613423526247
# Fold 15 RMSLE for ('model1', 'model4') = 0.0029835639852973704
# Fold 15 RMSLE for ('model2', 'model3') = 0.0029621927882740096
# Fold 15 RMSLE for ('model2', 'model4') = 0.0029977829006573
# Fold 15 RMSLE for ('model3', 'model4') = 0.002969250781510212
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.002961468358557873
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.0029844763034432417
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.002967495192245517
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.0029719827686353257
# Fold 15 RMSLE for all models ensemble = 0.0029696745704506844
# Fold 15 best combination: ('model1', 'model3') with RMSLE = 0.0029580613423526247
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.0026710297961084484
# Fold 16 RMSLE for model2 = 0.002664331572108861
# Fold 16 RMSLE for model3 = 0.0027226889154930334
# Fold 16 RMSLE for model4 = 0.0026649619690001366
# Fold 16 RMSLE for ('model1', 'model2') = 0.00265949299771279
# Fold 16 RMSLE for ('model1', 'model3') = 0.002687669777044926
# Fold 16 RMSLE for ('model1', 'model4') = 0.002664871742692996
# Fold 16 RMSLE for ('model2', 'model3') = 0.002671433810387153
# Fold 16 RMSLE for ('model2', 'model4') = 0.0026607148153097956
# Fold 16 RMSLE for ('model3', 'model4') = 0.0026778730619535333
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.0026684582310352507
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.0026599980317271697
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.002673636727132479
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.002665294320158
# Fold 16 RMSLE for all models ensemble = 0.00266509471024948
# Fold 16 best combination: ('model1', 'model2') with RMSLE = 0.00265949299771279
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.0033246154960759147
# Fold 17 RMSLE for model2 = 0.003309050978234266
# Fold 17 RMSLE for model3 = 0.0033940868477890128
# Fold 17 RMSLE for model4 = 0.0033276304649652744
# Fold 17 RMSLE for ('model1', 'model2') = 0.0033089220872010833
# Fold 17 RMSLE for ('model1', 'model3') = 0.00335223738900774
# Fold 17 RMSLE for ('model1', 'model4') = 0.0033238690210099725
# Fold 17 RMSLE for ('model2', 'model3') = 0.003333649268640105
# Fold 17 RMSLE for ('model2', 'model4') = 0.0033141786426651985
# Fold 17 RMSLE for ('model3', 'model4') = 0.0033499002696354596
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.0033279289736906797
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.0033140675210937146
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.0033397224134483557
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.003328872831170965
# Fold 17 RMSLE for all models ensemble = 0.00332623951334621
# Fold 17 best combination: ('model1', 'model2') with RMSLE = 0.0033089220872010833
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.002645784382509649
# Fold 18 RMSLE for model2 = 0.002668629939362069
# Fold 18 RMSLE for model3 = 0.0027090583629178627
# Fold 18 RMSLE for model4 = 0.0026824749164389133
# Fold 18 RMSLE for ('model1', 'model2') = 0.0026507804047474102
# Fold 18 RMSLE for ('model1', 'model3') = 0.0026686430858240085
# Fold 18 RMSLE for ('model1', 'model4') = 0.002661535470023139
# Fold 18 RMSLE for ('model2', 'model3') = 0.002672444933243727
# Fold 18 RMSLE for ('model2', 'model4') = 0.0026722621789687312
# Fold 18 RMSLE for ('model3', 'model4') = 0.0026835918144883135
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.0026604147635993025
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.0026601616373781974
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.002668614375030984
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.002672539237012518
# Fold 18 RMSLE for all models ensemble = 0.002664041150929897
# Fold 18 best combination: model1 with RMSLE = 0.002645784382509649
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.0031179255702961347
# Fold 19 RMSLE for model2 = 0.0031228700442069764
# Fold 19 RMSLE for model3 = 0.0031501858312922787
# Fold 19 RMSLE for model4 = 0.0031390065594806937
# Fold 19 RMSLE for ('model1', 'model2') = 0.0031141590805796
# Fold 19 RMSLE for ('model1', 'model3') = 0.0031265527281988227
# Fold 19 RMSLE for ('model1', 'model4') = 0.003126458709677872
# Fold 19 RMSLE for ('model2', 'model3') = 0.0031207709882117864
# Fold 19 RMSLE for ('model2', 'model4') = 0.003127574002930123
# Fold 19 RMSLE for ('model3', 'model4') = 0.003133767257871917
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.00311720446813588
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.003121443052851443
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.003126656009173004
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.003124035165892067
# Fold 19 RMSLE for all models ensemble = 0.0031210609443397294
# Fold 19 best combination: ('model1', 'model2') with RMSLE = 0.0031141590805796
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0030980902251498766
# Fold 20 RMSLE for model2 = 0.003081276847988574
# Fold 20 RMSLE for model3 = 0.0031055272618379357
# Fold 20 RMSLE for model4 = 0.003095836243984932
# Fold 20 RMSLE for ('model1', 'model2') = 0.003080591784082693
# Fold 20 RMSLE for ('model1', 'model3') = 0.0030940222513099846
# Fold 20 RMSLE for ('model1', 'model4') = 0.0030948312693134133
# Fold 20 RMSLE for ('model2', 'model3') = 0.0030727987303939774
# Fold 20 RMSLE for ('model2', 'model4') = 0.003083070407468121
# Fold 20 RMSLE for ('model3', 'model4') = 0.003089023869408689
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.0030783061045066146
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.003084310939535472
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.003090225204239906
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.0030774297703916047
# Fold 20 RMSLE for all models ensemble = 0.0030809908236019814
# Fold 20 best combination: ('model2', 'model3') with RMSLE = 0.0030727987303939774
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.0026522259233306305
# Fold 21 RMSLE for model2 = 0.0027220666292635544
# Fold 21 RMSLE for model3 = 0.0027223569712537337
# Fold 21 RMSLE for model4 = 0.0027050949431836687
# Fold 21 RMSLE for ('model1', 'model2') = 0.0026784139041724575
# Fold 21 RMSLE for ('model1', 'model3') = 0.0026796670893176775
# Fold 21 RMSLE for ('model1', 'model4') = 0.002675078815499243
# Fold 21 RMSLE for ('model2', 'model3') = 0.0027017016154592976
# Fold 21 RMSLE for ('model2', 'model4') = 0.0027100211806681917
# Fold 21 RMSLE for ('model3', 'model4') = 0.0027003953119962665
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.002682446166284243
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.002686078560721196
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.0026822900745073906
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.002699871440850186
# Fold 21 RMSLE for all models ensemble = 0.002686063433374531
# Fold 21 best combination: model1 with RMSLE = 0.0026522259233306305
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0030264170411630686
# Fold 22 RMSLE for model2 = 0.0030733757294345017
# Fold 22 RMSLE for model3 = 0.003052496345028757
# Fold 22 RMSLE for model4 = 0.003048410997840791
# Fold 22 RMSLE for ('model1', 'model2') = 0.0030413830539410963
# Fold 22 RMSLE for ('model1', 'model3') = 0.003032108919773227
# Fold 22 RMSLE for ('model1', 'model4') = 0.003035264413870921
# Fold 22 RMSLE for ('model2', 'model3') = 0.0030439404406006894
# Fold 22 RMSLE for ('model2', 'model4') = 0.003055958447902519
# Fold 22 RMSLE for ('model3', 'model4') = 0.003039579920836324
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0030352466993418133
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.003042463253129611
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0030333791018060173
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0030426199277574753
# Fold 22 RMSLE for all models ensemble = 0.003036953076911741
# Fold 22 best combination: model1 with RMSLE = 0.0030264170411630686
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.00285918577334004
# Fold 23 RMSLE for model2 = 0.0028243559597509456
# Fold 23 RMSLE for model3 = 0.0029515561132168527
# Fold 23 RMSLE for model4 = 0.0028564465329922782
# Fold 23 RMSLE for ('model1', 'model2') = 0.002832987425795152
# Fold 23 RMSLE for ('model1', 'model3') = 0.0028972341656166444
# Fold 23 RMSLE for ('model1', 'model4') = 0.002854900514920197
# Fold 23 RMSLE for ('model2', 'model3') = 0.0028669767542081784
# Fold 23 RMSLE for ('model2', 'model4') = 0.002836110965489372
# Fold 23 RMSLE for ('model3', 'model4') = 0.0028906891987978164
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.0028615020095301555
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.002839561464260166
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.002878196072146213
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0028602389910722466
# Fold 23 RMSLE for all models ensemble = 0.0028582317786824993
# Fold 23 best combination: model2 with RMSLE = 0.0028243559597509456
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.00305794593904608
# Fold 24 RMSLE for model2 = 0.0030544479923164396
# Fold 24 RMSLE for model3 = 0.0031450045390935726
# Fold 24 RMSLE for model4 = 0.003062243274992932
# Fold 24 RMSLE for ('model1', 'model2') = 0.0030466402742300954
# Fold 24 RMSLE for ('model1', 'model3') = 0.0030940749224029145
# Fold 24 RMSLE for ('model1', 'model4') = 0.003056433527147916
# Fold 24 RMSLE for ('model2', 'model3') = 0.0030817258476904504
# Fold 24 RMSLE for ('model2', 'model4') = 0.0030525570474749164
# Fold 24 RMSLE for ('model3', 'model4') = 0.0030919113077562893
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.0030702454421980886
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.0030497651967717134
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.0030782495650153174
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.003071412579287494
# Fold 24 RMSLE for all models ensemble = 0.003065844911569303
# Fold 24 best combination: ('model1', 'model2') with RMSLE = 0.0030466402742300954
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.0032338306381819158
# Fold 25 RMSLE for model2 = 0.0031803804272555326
# Fold 25 RMSLE for model3 = 0.0032634571657304055
# Fold 25 RMSLE for model4 = 0.0032275839927100414
# Fold 25 RMSLE for ('model1', 'model2') = 0.0031997840783037513
# Fold 25 RMSLE for ('model1', 'model3') = 0.0032415989369685852
# Fold 25 RMSLE for ('model1', 'model4') = 0.0032289054383574747
# Fold 25 RMSLE for ('model2', 'model3') = 0.003205914903885903
# Fold 25 RMSLE for ('model2', 'model4') = 0.0031999798578774023
# Fold 25 RMSLE for ('model3', 'model4') = 0.003235983986270407
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.003212393634731264
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.003208106045373444
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.003233443876020077
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.0032106618307010245
# Fold 25 RMSLE for all models ensemble = 0.0032148794797529573
# Fold 25 best combination: model2 with RMSLE = 0.0031803804272555326
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.0028052144418717
# Fold 26 RMSLE for model2 = 0.002816232448343862
# Fold 26 RMSLE for model3 = 0.0028754439008155824
# Fold 26 RMSLE for model4 = 0.002816450009438508
# Fold 26 RMSLE for ('model1', 'model2') = 0.002802661300404125
# Fold 26 RMSLE for ('model1', 'model3') = 0.0028319410370982114
# Fold 26 RMSLE for ('model1', 'model4') = 0.0028083912837928897
# Fold 26 RMSLE for ('model2', 'model3') = 0.002823823855967417
# Fold 26 RMSLE for ('model2', 'model4') = 0.002812038602214972
# Fold 26 RMSLE for ('model3', 'model4') = 0.002832296082740006
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.0028151683466795334
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.0028060519585828376
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.002821457751751243
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.002818235066199732
# Fold 26 RMSLE for all models ensemble = 0.0028135753320885893
# Fold 26 best combination: ('model1', 'model2') with RMSLE = 0.002802661300404125
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.0027145262979170067
# Fold 27 RMSLE for model2 = 0.0027158444694440863
# Fold 27 RMSLE for model3 = 0.0027794160682499676
# Fold 27 RMSLE for model4 = 0.002729231186678788
# Fold 27 RMSLE for ('model1', 'model2') = 0.0027021460021991834
# Fold 27 RMSLE for ('model1', 'model3') = 0.0027378813010426155
# Fold 27 RMSLE for ('model1', 'model4') = 0.0027184906456019903
# Fold 27 RMSLE for ('model2', 'model3') = 0.0027190923664951036
# Fold 27 RMSLE for ('model2', 'model4') = 0.002716079350911655
# Fold 27 RMSLE for ('model3', 'model4') = 0.002738248266213107
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.0027140495255126313
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.0027097010642190317
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.0027283337675816097
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.0027187527346316273
# Fold 27 RMSLE for all models ensemble = 0.002715564948235586
# Fold 27 best combination: ('model1', 'model2') with RMSLE = 0.0027021460021991834
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.003141087243491824
# Fold 28 RMSLE for model2 = 0.003151717546524906
# Fold 28 RMSLE for model3 = 0.003187434061613274
# Fold 28 RMSLE for model4 = 0.0031480440035629113
# Fold 28 RMSLE for ('model1', 'model2') = 0.00313941980899067
# Fold 28 RMSLE for ('model1', 'model3') = 0.0031566926958788255
# Fold 28 RMSLE for ('model1', 'model4') = 0.0031427056871662037
# Fold 28 RMSLE for ('model2', 'model3') = 0.00315115458477382
# Fold 28 RMSLE for ('model2', 'model4') = 0.003145666832197159
# Fold 28 RMSLE for ('model3', 'model4') = 0.003156727765354873
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.0031454071348428164
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.0031411457350073195
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.003149754944717054
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.003147423292595973
# Fold 28 RMSLE for all models ensemble = 0.0031445331529168347
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.00313941980899067
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.0025646982013995036
# Fold 29 RMSLE for model2 = 0.0025443420329586855
# Fold 29 RMSLE for model3 = 0.002597225541399488
# Fold 29 RMSLE for model4 = 0.0025599814489028253
# Fold 29 RMSLE for ('model1', 'model2') = 0.002545718256217475
# Fold 29 RMSLE for ('model1', 'model3') = 0.002572321451742779
# Fold 29 RMSLE for ('model1', 'model4') = 0.002559803681886071
# Fold 29 RMSLE for ('model2', 'model3') = 0.002551826553221547
# Fold 29 RMSLE for ('model2', 'model4') = 0.002547117599628003
# Fold 29 RMSLE for ('model3', 'model4') = 0.002566337249641047
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.0025525677193281226
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.002549062557992116
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.002563533050335591
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0025510366716193595
# Fold 29 RMSLE for all models ensemble = 0.0025524795934617674
# Fold 29 best combination: model2 with RMSLE = 0.0025443420329586855
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.003263773819539588
# Fold 30 RMSLE for model2 = 0.003271476112309784
# Fold 30 RMSLE for model3 = 0.0032956868622448328
# Fold 30 RMSLE for model4 = 0.003268494283069818
# Fold 30 RMSLE for ('model1', 'model2') = 0.003261590852165115
# Fold 30 RMSLE for ('model1', 'model3') = 0.003273397016061076
# Fold 30 RMSLE for ('model1', 'model4') = 0.0032645082636099097
# Fold 30 RMSLE for ('model2', 'model3') = 0.003270086145815481
# Fold 30 RMSLE for ('model2', 'model4') = 0.00326605648076527
# Fold 30 RMSLE for ('model3', 'model4') = 0.003273410799941407
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.0032654749159937175
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.00326276341168423
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.003268581337510319
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.0032669398471022117
# Fold 30 RMSLE for all models ensemble = 0.0032648213035807528
# Fold 30 best combination: ('model1', 'model2') with RMSLE = 0.003261590852165115
# ---------------
#
# OOF RMSLE = 0.0029509020675979798
# Sum of RMSLE for each combination:
# ('model1',): 0.08862755383344376
# ('model2',): 0.08906707708669627
# ('model3',): 0.08989506707719788
# ('model4',): 0.08907664430664768
# ('model1', 'model2'): 0.08859338598236058
# ('model1', 'model3'): 0.08901918187544676
# ('model1', 'model4'): 0.08877663986284871
# ('model2', 'model3'): 0.08888185831440877
# ('model2', 'model4'): 0.08893257813897297
# ('model3', 'model4'): 0.0891152652801472
# ('model1', 'model2', 'model3'): 0.08870915981952951
# ('model1', 'model2', 'model4'): 0.08871546411902734
# ('model1', 'model3', 'model4'): 0.08889340553996887
# ('model2', 'model3', 'model4'): 0.08885276846350393
# ('model1', 'model2', 'model3', 'model4'): 0.08874574536002733
#
# 12番目の学習が終わりました。
#
# 推定時間は17
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.0027473808919357065
# Fold 1 RMSLE for model2 = 0.0027480781695788077
# Fold 1 RMSLE for model3 = 0.00275770864339107
# Fold 1 RMSLE for model4 = 0.0027669580675603054
# Fold 1 RMSLE for ('model1', 'model2') = 0.0027419489759565622
# Fold 1 RMSLE for ('model1', 'model3') = 0.002746032843750833
# Fold 1 RMSLE for ('model1', 'model4') = 0.0027548834443480055
# Fold 1 RMSLE for ('model2', 'model3') = 0.0027384842726975033
# Fold 1 RMSLE for ('model2', 'model4') = 0.002753880870223795
# Fold 1 RMSLE for ('model3', 'model4') = 0.002752604110226397
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.002739183056695161
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.002748939491779411
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.0027491113425840773
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.0027452381773159927
# Fold 1 RMSLE for all models ensemble = 0.0027444409292015403
# Fold 1 best combination: ('model2', 'model3') with RMSLE = 0.0027384842726975033
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.0025048383814407294
# Fold 2 RMSLE for model2 = 0.002535368088728783
# Fold 2 RMSLE for model3 = 0.0024965889216969897
# Fold 2 RMSLE for model4 = 0.002514843982865238
# Fold 2 RMSLE for ('model1', 'model2') = 0.0025120421945703975
# Fold 2 RMSLE for ('model1', 'model3') = 0.002491511931208844
# Fold 2 RMSLE for ('model1', 'model4') = 0.0025074627820300156
# Fold 2 RMSLE for ('model2', 'model3') = 0.002495271675187153
# Fold 2 RMSLE for ('model2', 'model4') = 0.0025208801542672427
# Fold 2 RMSLE for ('model3', 'model4') = 0.002492633198498556
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.0024953781895588867
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.0025118276314346722
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.0024944666419106374
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.002498716629309037
# Fold 2 RMSLE for all models ensemble = 0.002498496720885516
# Fold 2 best combination: ('model1', 'model3') with RMSLE = 0.002491511931208844
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.002828967780298287
# Fold 3 RMSLE for model2 = 0.00284302277220101
# Fold 3 RMSLE for model3 = 0.0028727369189096084
# Fold 3 RMSLE for model4 = 0.0028384656568975013
# Fold 3 RMSLE for ('model1', 'model2') = 0.002826796376269135
# Fold 3 RMSLE for ('model1', 'model3') = 0.0028442575134427052
# Fold 3 RMSLE for ('model1', 'model4') = 0.002831085884804112
# Fold 3 RMSLE for ('model2', 'model3') = 0.002837856148717425
# ...
# Fold 16 RMSLE for ('model1', 'model3') = 0.0023056180002495198
# Fold 16 RMSLE for ('model1', 'model4') = 0.0022938298642554236
# Fold 16 RMSLE for ('model2', 'model3') = 0.00228783921136614
# Fold 16 RMSLE for ('model2', 'model4') = 0.00228613865317215
# Fold 16 RMSLE for ('model3', 'model4') = 0.0022975398432907475
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.002290053949211367
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.002286784569513905
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.002297316788180546
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.002287651201898552
# Fold 16 RMSLE for all models ensemble = 0.0022893691366250917
# Fold 16 best combination: model2 with RMSLE = 0.0022843026732544697
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.00284100711095401
# Fold 17 RMSLE for model2 = 0.0028457792675419006
# Fold 17 RMSLE for model3 = 0.002861459240015267
# Fold 17 RMSLE for model4 = 0.0028478012387385242
# Fold 17 RMSLE for ('model1', 'model2') = 0.002838118470712365
# Fold 17 RMSLE for ('model1', 'model3') = 0.0028487209340848727
# Fold 17 RMSLE for ('model1', 'model4') = 0.002842369974541465
# Fold 17 RMSLE for ('model2', 'model3') = 0.0028439482353057968
# Fold 17 RMSLE for ('model2', 'model4') = 0.0028437466222875052
# Fold 17 RMSLE for ('model3', 'model4') = 0.002849237828006548
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.002841653389740391
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.002840261345008732
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.002845669119640909
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.0028436281588541724
# Fold 17 RMSLE for all models ensemble = 0.0028420255163319973
# Fold 17 best combination: ('model1', 'model2') with RMSLE = 0.002838118470712365
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.0022636794672835463
# Fold 18 RMSLE for model2 = 0.002315924875595625
# Fold 18 RMSLE for model3 = 0.0022856172937488527
# Fold 18 RMSLE for model4 = 0.0022909664216306195
# Fold 18 RMSLE for ('model1', 'model2') = 0.00228448967292407
# Fold 18 RMSLE for ('model1', 'model3') = 0.0022715924635563463
# Fold 18 RMSLE for ('model1', 'model4') = 0.002275443336286855
# Fold 18 RMSLE for ('model2', 'model3') = 0.002290975098139528
# Fold 18 RMSLE for ('model2', 'model4') = 0.0023006391487058217
# Fold 18 RMSLE for ('model3', 'model4') = 0.002282672558860825
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.00228031601021039
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.002285743833090094
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.0022753914566437288
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.0022894037076009437
# Fold 18 RMSLE for all models ensemble = 0.0022819183817428734
# Fold 18 best combination: model1 with RMSLE = 0.0022636794672835463
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.0025974845020518547
# Fold 19 RMSLE for model2 = 0.00260724613739959
# Fold 19 RMSLE for model3 = 0.0026126805492940903
# Fold 19 RMSLE for model4 = 0.0026115050654500573
# Fold 19 RMSLE for ('model1', 'model2') = 0.0025973215033901747
# Fold 19 RMSLE for ('model1', 'model3') = 0.0026024088193892852
# Fold 19 RMSLE for ('model1', 'model4') = 0.0026031256028532838
# Fold 19 RMSLE for ('model2', 'model3') = 0.0026001311607567116
# Fold 19 RMSLE for ('model2', 'model4') = 0.0026066224847523327
# Fold 19 RMSLE for ('model3', 'model4') = 0.0026070644678595095
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.0025979995086019866
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.002601338839705064
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.0026031889573529384
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.0026026482475100493
# Fold 19 RMSLE for all models ensemble = 0.002600551060373643
# Fold 19 best combination: ('model1', 'model2') with RMSLE = 0.0025973215033901747
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.0026361618770034297
# Fold 20 RMSLE for model2 = 0.002620980606061911
# Fold 20 RMSLE for model3 = 0.002628029392019976
# Fold 20 RMSLE for model4 = 0.0026343854881620814
# Fold 20 RMSLE for ('model1', 'model2') = 0.0026217875270810693
# Fold 20 RMSLE for ('model1', 'model3') = 0.0026291170090492508
# Fold 20 RMSLE for ('model1', 'model4') = 0.00263309824150253
# Fold 20 RMSLE for ('model2', 'model3') = 0.0026125612199869265
# Fold 20 RMSLE for ('model2', 'model4') = 0.002623957657772755
# Fold 20 RMSLE for ('model3', 'model4') = 0.002624911804372292
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.0026187482503158277
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.002624873419721111
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.002627770992116928
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.0026180379182356084
# Fold 20 RMSLE for all models ensemble = 0.0026214174243331147
# Fold 20 best combination: ('model2', 'model3') with RMSLE = 0.0026125612199869265
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.002286095782608827
# Fold 21 RMSLE for model2 = 0.0023448812043331455
# Fold 21 RMSLE for model3 = 0.0023178965294796076
# Fold 21 RMSLE for model4 = 0.002334140708082615
# Fold 21 RMSLE for ('model1', 'model2') = 0.0023077384515962974
# Fold 21 RMSLE for ('model1', 'model3') = 0.0022993032958020295
# Fold 21 RMSLE for ('model1', 'model4') = 0.002307490410887651
# Fold 21 RMSLE for ('model2', 'model3') = 0.0023187395687779746
# Fold 21 RMSLE for ('model2', 'model4') = 0.002335930018540449
# Fold 21 RMSLE for ('model3', 'model4') = 0.0023191731241602957
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.002305998850147183
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.0023155041831701586
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.002307292675138264
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.0023220541635876582
# Fold 21 RMSLE for all models ensemble = 0.0023117023567780504
# Fold 21 best combination: model1 with RMSLE = 0.002286095782608827
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.0025934382946575163
# Fold 22 RMSLE for model2 = 0.0026394085117143044
# Fold 22 RMSLE for model3 = 0.0025968003285146094
# Fold 22 RMSLE for model4 = 0.002630060388421134
# Fold 22 RMSLE for ('model1', 'model2') = 0.0026107296052759704
# Fold 22 RMSLE for ('model1', 'model3') = 0.002592481230786573
# Fold 22 RMSLE for ('model1', 'model4') = 0.0026097397290356697
# Fold 22 RMSLE for ('model2', 'model3') = 0.0026086271112201044
# Fold 22 RMSLE for ('model2', 'model4') = 0.0026319952066410526
# Fold 22 RMSLE for ('model3', 'model4') = 0.00260783643424274
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.0026019531594510276
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.002616328641545977
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0026022113078435385
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.0026141816922132465
# Fold 22 RMSLE for all models ensemble = 0.0026078851564970387
# Fold 22 best combination: ('model1', 'model3') with RMSLE = 0.002592481230786573
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.0024365602175616245
# Fold 23 RMSLE for model2 = 0.002426561972671934
# Fold 23 RMSLE for model3 = 0.0024727903558862093
# Fold 23 RMSLE for model4 = 0.002441041366825922
# Fold 23 RMSLE for ('model1', 'model2') = 0.0024237997104777837
# Fold 23 RMSLE for ('model1', 'model3') = 0.0024518618249904055
# Fold 23 RMSLE for ('model1', 'model4') = 0.002436645341265915
# Fold 23 RMSLE for ('model2', 'model3') = 0.00243669196354699
# Fold 23 RMSLE for ('model2', 'model4') = 0.002429954756480901
# Fold 23 RMSLE for ('model3', 'model4') = 0.0024505314412248446
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.002434836883372963
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.002428607077709363
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.0024450786012731175
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.0024364689989779128
# Fold 23 RMSLE for all models ensemble = 0.0024352475363368926
# Fold 23 best combination: ('model1', 'model2') with RMSLE = 0.0024237997104777837
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.002573556694073595
# Fold 24 RMSLE for model2 = 0.0025701935402481267
# Fold 24 RMSLE for model3 = 0.0026184418133422893
# Fold 24 RMSLE for model4 = 0.0025824533845158343
# Fold 24 RMSLE for ('model1', 'model2') = 0.0025659507530752653
# Fold 24 RMSLE for ('model1', 'model3') = 0.0025933797537912523
# Fold 24 RMSLE for ('model1', 'model4') = 0.002575474950886481
# Fold 24 RMSLE for ('model2', 'model3') = 0.002584795129937089
# Fold 24 RMSLE for ('model2', 'model4') = 0.0025728254320367106
# Fold 24 RMSLE for ('model3', 'model4') = 0.0025945529148901267
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.002579367370515102
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.0025700900632555234
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.0025865696141426833
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.0025819460304023737
# Fold 24 RMSLE for all models ensemble = 0.002578657522804717
# Fold 24 best combination: ('model1', 'model2') with RMSLE = 0.0025659507530752653
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.0027473285880454876
# Fold 25 RMSLE for model2 = 0.0027211591901977338
# Fold 25 RMSLE for model3 = 0.002755898499899008
# Fold 25 RMSLE for model4 = 0.0027466069725309546
# Fold 25 RMSLE for ('model1', 'model2') = 0.0027278079666631276
# Fold 25 RMSLE for ('model1', 'model3') = 0.002749053062719845
# Fold 25 RMSLE for ('model1', 'model4') = 0.0027449859074968547
# Fold 25 RMSLE for ('model2', 'model3') = 0.0027276227111744113
# Fold 25 RMSLE for ('model2', 'model4') = 0.002730958171349085
# Fold 25 RMSLE for ('model3', 'model4') = 0.002745727532742297
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.00273262430943239
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.0027333271200209205
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.0027454689836364974
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.002732617340110001
# Fold 25 RMSLE for all models ensemble = 0.002735168207520063
# Fold 25 best combination: model2 with RMSLE = 0.0027211591901977338
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.0023794633262922953
# Fold 26 RMSLE for model2 = 0.0023907347658766467
# Fold 26 RMSLE for model3 = 0.002409581338260135
# Fold 26 RMSLE for model4 = 0.0023846672219243596
# Fold 26 RMSLE for ('model1', 'model2') = 0.0023791761686344716
# Fold 26 RMSLE for ('model1', 'model3') = 0.0023913923949715698
# Fold 26 RMSLE for ('model1', 'model4') = 0.0023801145171567202
# Fold 26 RMSLE for ('model2', 'model3') = 0.0023874986930419013
# Fold 26 RMSLE for ('model2', 'model4') = 0.002384486801418533
# Fold 26 RMSLE for ('model3', 'model4') = 0.0023902883581296687
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.0023836015393008934
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.002380025920680709
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.0023859346838720073
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.002384889708512548
# Fold 26 RMSLE for all models ensemble = 0.0023826717398865364
# Fold 26 best combination: ('model1', 'model2') with RMSLE = 0.0023791761686344716
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.002269802717161296
# Fold 27 RMSLE for model2 = 0.002337475847449797
# Fold 27 RMSLE for model3 = 0.0022980481819899683
# Fold 27 RMSLE for model4 = 0.0022906990050178128
# Fold 27 RMSLE for ('model1', 'model2') = 0.002294741678352701
# Fold 27 RMSLE for ('model1', 'model3') = 0.0022805466856026927
# Fold 27 RMSLE for ('model1', 'model4') = 0.00227754106696023
# Fold 27 RMSLE for ('model2', 'model3') = 0.002301883338385642
# Fold 27 RMSLE for ('model2', 'model4') = 0.002309916949830278
# Fold 27 RMSLE for ('model3', 'model4') = 0.002285689014443039
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.0022892205048640458
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.002292303459280317
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.0022796079418996988
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.0022959604439545746
# Fold 27 RMSLE for all models ensemble = 0.002288046154023067
# Fold 27 best combination: model1 with RMSLE = 0.002269802717161296
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.00265312314303823
# Fold 28 RMSLE for model2 = 0.002657499027514723
# Fold 28 RMSLE for model3 = 0.002672069500495938
# Fold 28 RMSLE for model4 = 0.002663399357142551
# Fold 28 RMSLE for ('model1', 'model2') = 0.0026499991933870977
# Fold 28 RMSLE for ('model1', 'model3') = 0.0026599149517790863
# Fold 28 RMSLE for ('model1', 'model4') = 0.002656746293771281
# Fold 28 RMSLE for ('model2', 'model3') = 0.0026545068237922107
# Fold 28 RMSLE for ('model2', 'model4') = 0.0026570628393361557
# Fold 28 RMSLE for ('model3', 'model4') = 0.0026622689938596176
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.0026527738127468214
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.002653468557639
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.0026585665417133758
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.0026558177185876638
# Fold 28 RMSLE for all models ensemble = 0.0026543597265102736
# Fold 28 best combination: ('model1', 'model2') with RMSLE = 0.0026499991933870977
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.002220633484797946
# Fold 29 RMSLE for model2 = 0.0022304950536404895
# Fold 29 RMSLE for model3 = 0.0022289062627927556
# Fold 29 RMSLE for model4 = 0.0022268267697509846
# Fold 29 RMSLE for ('model1', 'model2') = 0.002219398745406828
# Fold 29 RMSLE for ('model1', 'model3') = 0.002221785127965361
# Fold 29 RMSLE for ('model1', 'model4') = 0.0022219234831184417
# Fold 29 RMSLE for ('model2', 'model3') = 0.002220268822166733
# Fold 29 RMSLE for ('model2', 'model4') = 0.0022252902679772138
# Fold 29 RMSLE for ('model3', 'model4') = 0.0022224057466142034
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.0022184145982779226
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.0022209429281326684
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.002220896916537709
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.002220623088559287
# Fold 29 RMSLE for all models ensemble = 0.0022194059288743427
# Fold 29 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.0022184145982779226
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.0027057252941247974
# Fold 30 RMSLE for model2 = 0.0027083233157490483
# Fold 30 RMSLE for model3 = 0.0027162154683426664
# Fold 30 RMSLE for model4 = 0.00271167325922134
# Fold 30 RMSLE for ('model1', 'model2') = 0.002702007583921074
# Fold 30 RMSLE for ('model1', 'model3') = 0.0027087089633762405
# Fold 30 RMSLE for ('model1', 'model4') = 0.00270720483308205
# Fold 30 RMSLE for ('model2', 'model3') = 0.0027045292222062033
# Fold 30 RMSLE for ('model2', 'model4') = 0.002707053149664754
# Fold 30 RMSLE for ('model3', 'model4') = 0.0027096833917798473
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.0027034118189347175
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.0027043714113159246
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.002707640171012416
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.002705426298147829
# Fold 30 RMSLE for all models ensemble = 0.002704552872046636
# Fold 30 best combination: ('model1', 'model2') with RMSLE = 0.002702007583921074
# ---------------
#
# OOF RMSLE = 0.0025055379391891526
# Sum of RMSLE for each combination:
# ('model1',): 0.07517442962019523
# ('model2',): 0.07600393739410115
# ('model3',): 0.07559638008746439
# ('model4',): 0.07564722656430796
# ('model1', 'model2'): 0.07539188136687756
# ('model1', 'model3'): 0.07529927867281493
# ('model1', 'model4'): 0.0753477908235184
# ('model2', 'model3'): 0.075453870602078
# ('model2', 'model4'): 0.07572534279350214
# ('model3', 'model4'): 0.07543596951463778
# ('model1', 'model2', 'model3'): 0.0753113400350044
# ('model1', 'model2', 'model4'): 0.07544821794076767
# ('model1', 'model3', 'model4'): 0.07532368483123876
# ('model2', 'model3', 'model4'): 0.07546807048973819
# ('model1', 'model2', 'model3', 'model4'): 0.07536053551470961
#
# 19番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                        0.000000                     0.000000           221
# 2                        0.000000                     0.000000             4
# 3                        0.000000                     0.000000            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 7158                     0.000000                     0.000000           240
# 7159                     0.000000                     0.000000             4
# 7160                 25069.498286                 24560.172725           132
# 7161                 93118.705227                130326.946431            98
# 7162                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 7158                           110523.066755
# 7159                                0.000000
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 7158                            98954.793233
# 7159                                0.000000
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                            0.000000e+00
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 7158                           147802.356027  38.651945  -75.914445
# 7159                                0.000000  31.361795 -101.776403
# 7160                            85775.307153  41.005565  -96.154917
# 7161                           156640.371706  39.364417  -93.449361
# 7162                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 7158                         0.000000                         0.000000
# 7159                         0.000000                         0.000000
# 7160                       636.277440                      1477.095292
# 7161                     16355.554326                    -47697.744120
# 7162                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 7158                         0.000000                          0.000000
# 7159                         0.000000                          0.000000
# 7160                      -509.325561                          0.027717
# 7161                     37208.241204                          0.131411
# 7162                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 7158                          0.000000                          0.000000
# 7159                          0.000000                          0.000000
# 7160                          0.062609                         -0.020317
# 7161                         -0.338723                          0.399579
# 7162                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42119.510063  0.002251
# 1                  14            1     58642.578060 -0.002441
# 2                   9            1     99573.708537 -0.001651
# 3                  15            1     51598.092801  0.000489
# 4                  15            0     50759.626543 -0.002401
# ...               ...          ...              ...       ...
# 7158                1            1         0.000000  0.000000
# 7159                9            1         0.000000  0.000000
# 7160                8            0         0.000000  0.000000
# 7161                8            0         0.000000  0.000000
# 7162                9            1         0.000000  0.000000
#
# [7163 rows x 19 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 4650                 19191.516543                 26927.123407            20
# 4651                          NaN                          NaN            92
# 4652                 25344.483061                 25052.338495            80
# 4653                 15031.292599                 15796.850949            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               37907.936721
# 1                               58225.196089
# 2                                        NaN
# 3                               63647.340038
# 4                               77391.157768
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     42119.510063  0.002251
# 1                  14            1     58642.578060 -0.002441
# 2                   9            1     99573.708537 -0.001651
# 3                  15            1     51598.092801  0.000489
# 4                  15            0     50759.626543 -0.002401
# ...               ...          ...              ...       ...
# 4650               15            0     49369.167783 -0.002993
# 4651                8            1    169104.334518  0.003129
# 4652                8            0     31785.978887 -0.002194
# 4653                8            0     65638.057795  0.000383
# 4654                9            1    145772.866696 -0.002301
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, 0.00)

# %%
train_df_GHG14
# Out:
# 0        42214.415787
# 1        58499.609696
# 2        99409.449782
# 3        51623.314588
# 4        50637.897032
#             ...
# 4650     49221.615755
# 4651    169634.209493
# 4652     31716.323514
# 4653     65663.219471
# 4654    145437.817997
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.562651e+04  0.011449
# 1                  14            1     2.897905e+05 -0.009013
# 2                   8            0     4.147768e+04  0.004741
# 3                   8            0     2.860202e+04 -0.022208
# 4                   8            0     4.935281e+04  0.016946
# ...               ...          ...              ...       ...
# 2503                1            1     5.547563e+05  0.027199
# 2504                9            1     9.858563e+04 -0.009746
# 2505                8            0     1.409237e+05  0.022125
# 2506                8            0     2.620963e+05 -0.005393
# 2507                9            1     1.473231e+06  0.065402
#
# [2508 rows x 19 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232603.25258157874

# %%
print(np.expm1(np.log1p(10)))
# Out:
# 10.000000000000002

# %%
def after_act(preds):
    r = preds.copy()
    r_min = r.min()
    max_w = 10.4-np.log1p(r_min)
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            # print(r[i]-np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w))
            r[i] = np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 189302.15107903926

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_75.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,627
# 1     4656   289,790
# 2     4657    41,478
# 3     4658    25,180
# 4     4659    49,353
# ...    ...       ...
# 2503  7158   554,756
# 2504  7159    98,586
# 2505  7160   140,924
# 2506  7161   262,096
# 2507  7162 1,473,231
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,150,055
# 43    4698 1,193,637
# 110   4765 1,383,704
# 114   4769 1,298,798
# 148   4803 1,735,693
# ...    ...       ...
# 2417  7072 1,243,090
# 2423  7078 1,205,521
# 2466  7121 1,676,732
# 2490  7145 1,426,130
# 2507  7162 1,473,231
#
# [113 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Sat Nov 30 08:29:48 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,120     0
# 1                  14            1           58,643    -0
# 2                   9            1           99,574    -0
# 3                  15            1           51,598     0
# 4                  15            0           50,760    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,369    -0
# 4651                8            1          169,104     0
# 4652                8            0           31,786    -0
# 4653                8            0           65,638     0
# 4654                9            1          145,773    -0
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.0030815101056244805

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 4650                       19,192                       26,927            20
# 4651                          NaN                          NaN            92
# 4652                       25,344                       25,052            80
# 4653                       15,031                       15,797            98
# 4654                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,120     0
# 1                  14            1           58,643    -0
# 2                   9            1           99,574    -0
# 3                  15            1           51,598     0
# 4                  15            0           50,760    -0
# ...               ...          ...              ...   ...
# 4650               15            0           49,369    -0
# 4651                8            1          169,104     0
# 4652                8            0           31,786    -0
# 4653                8            0           65,638     0
# 4654                9            1          145,773    -0
#
# [4655 rows x 19 columns]
