# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/042.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_df_42.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_df_42.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions',
#        'test_preds'],
#       dtype='object')

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = abs(np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions']))

# 2. 条件を満たす行のマスクを作成
mask = diff > 0.7

# 3. 除外する行の数をカウント
exclude_num = mask.sum()
train_df = train_all_df.copy()
# 4. 条件を満たさない行だけを保持
train_all_df = train_all_df[~mask].reset_index(drop=True)

# 5. 'oof_predictions' 列を削除
train_all_df.drop('oof_predictions', axis=1, inplace=True)
train_df.drop('oof_predictions', axis=1, inplace=True)
# 6. 結果の表示
print(f"除外された行数: {exclude_num}")
# Out:
# 除外された行数: 1103

# %%
train_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                       25,069                       24,560           132
# 2506                       93,119                      130,327            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   517,178
# 2504                9            1                                   101,406
# 2505                8            0                                   134,966
# 2506                8            0                                   259,370
# 2507                9            1                                 1,307,431
#
# [7163 rows x 18 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)
    final_train_predictions = np.expm1(train_eval_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 6055                          NaN                          NaN           240
# 6056                          NaN                          NaN             4
# 6057                       25,069                       24,560           132
# 6058                       93,119                      130,327            98
# 6059                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 6055                                 110,523
# 6056                                     NaN
# 6057                                 166,520
# 6058                                  71,774
# 6059                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 6055                                  98,955
# 6056                                     NaN
# 6057                                 469,733
# 6058                                 936,032
# 6059                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 6055                               3,467,008
# 6056                                     NaN
# 6057                                  82,559
# 6058                                 336,961
# 6059                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 6055                                 147,802        39        -76
# 6056                                     NaN        31       -102
# 6057                                  85,775        41        -96
# 6058                                 156,640        39        -93
# 6059                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 6055                              NaN                              NaN
# 6056                              NaN                              NaN
# 6057                              636                            1,477
# 6058                           16,356                          -47,698
# 6059                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 6055                              NaN                               NaN
# 6056                              NaN                               NaN
# 6057                             -509                                 0
# 6058                           37,208                                 0
# 6059                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 6055                               NaN                               NaN
# 6056                               NaN                               NaN
# 6057                                 0                                -0
# 6058                                -0                                 0
# 6059                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 6055                1            1                                   517,178
# 6056                9            1                                   101,406
# 6057                8            0                                   134,966
# 6058                8            0                                   259,370
# 6059                9            1                                 1,307,431
#
# [6060 rows x 18 columns]

# %%
train_all = train_all_df.iloc[:, :-1].values
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
test = test_df.values
target = train_all_df.iloc[:, -1].values

# %%
oof_predictions,test_preds, train_preds = get_models_trained(train_all,test,target,30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.31179280869370374
# Fold 1 RMSLE for model2 = 0.30619533434288687
# Fold 1 RMSLE for model3 = 0.30769898793166084
# Fold 1 RMSLE for model4 = 0.311411288036611
# Fold 1 RMSLE for ('model1', 'model2') = 0.3067929337680321
# Fold 1 RMSLE for ('model1', 'model3') = 0.3092939526316895
# Fold 1 RMSLE for ('model1', 'model4') = 0.3096315331416465
# Fold 1 RMSLE for ('model2', 'model3') = 0.3045751693141548
# Fold 1 RMSLE for ('model2', 'model4') = 0.3070922939801744
# Fold 1 RMSLE for ('model3', 'model4') = 0.3072151540638246
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.3063260871986218
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.30718774434327445
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.3081669513957326
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.3055938635503219
# Fold 1 RMSLE for all models ensemble = 0.30651157218317604
# Fold 1 best combination: ('model2', 'model3') with RMSLE = 0.3045751693141548
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.3082973431167573
# Fold 2 RMSLE for model2 = 0.3040066046480525
# Fold 2 RMSLE for model3 = 0.2999754539765284
# Fold 2 RMSLE for model4 = 0.3039266170490885
# Fold 2 RMSLE for ('model1', 'model2') = 0.3032292213178265
# Fold 2 RMSLE for ('model1', 'model3') = 0.30356706023330265
# Fold 2 RMSLE for ('model1', 'model4') = 0.30395928464712824
# Fold 2 RMSLE for ('model2', 'model3') = 0.2992113538240129
# Fold 2 RMSLE for ('model2', 'model4') = 0.3027425735477192
# Fold 2 RMSLE for ('model3', 'model4') = 0.29971141456243394
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.3012917839045107
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.3026453089487292
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.30183285712008906
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.2998897807666957
# Fold 2 RMSLE for all models ensemble = 0.3010898581220165
# Fold 2 best combination: ('model2', 'model3') with RMSLE = 0.2992113538240129
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.30611507165049506
# Fold 3 RMSLE for model2 = 0.3038618457701586
# Fold 3 RMSLE for model3 = 0.3062839960739704
# Fold 3 RMSLE for model4 = 0.3078860804119786
# Fold 3 RMSLE for ('model1', 'model2') = 0.30307327326222633
# Fold 3 RMSLE for ('model1', 'model3') = 0.3058200354161116
# Fold 3 RMSLE for ('model1', 'model4') = 0.3056960572478004
# Fold 3 RMSLE for ('model2', 'model3') = 0.3033650193226942
# Fold 3 RMSLE for ('model2', 'model4') = 0.3043625839514091
# Fold 3 RMSLE for ('model3', 'model4') = 0.30540216771039813
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.3036486648949784
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.30385542063790055
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.30527472720074855
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.3038226998067376
# Fold 3 RMSLE for all models ensemble = 0.303916370841695
# Fold 3 best combination: ('model1', 'model2') with RMSLE = 0.30307327326222633
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.26520195989500506
# Fold 4 RMSLE for model2 = 0.2671388566435937
# Fold 4 RMSLE for model3 = 0.2652461821160854
# Fold 4 RMSLE for model4 = 0.26887212339386724
# Fold 4 RMSLE for ('model1', 'model2') = 0.26283392913697035
# Fold 4 RMSLE for ('model1', 'model3') = 0.2647099588783676
# Fold 4 RMSLE for ('model1', 'model4') = 0.26566969948443037
# Fold 4 RMSLE for ('model2', 'model3') = 0.26286525859064996
# Fold 4 RMSLE for ('model2', 'model4') = 0.26605665175719817
# Fold 4 RMSLE for ('model3', 'model4') = 0.2651788405113783
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.26275077405448516
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.2641379404832802
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.26476954505466055
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.26394034055692095
# Fold 4 RMSLE for all models ensemble = 0.26357877631423615
# Fold 4 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.26275077405448516
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.29591156964240833
# Fold 5 RMSLE for model2 = 0.2857855866010136
# Fold 5 RMSLE for model3 = 0.2942704559788477
# Fold 5 RMSLE for model4 = 0.29844865769388673
# Fold 5 RMSLE for ('model1', 'model2') = 0.2894980806128673
# Fold 5 RMSLE for ('model1', 'model3') = 0.2943504768358972
# Fold 5 RMSLE for ('model1', 'model4') = 0.29612418952338027
# Fold 5 RMSLE for ('model2', 'model3') = 0.28820141682746153
# Fold 5 RMSLE for ('model2', 'model4') = 0.29113921511999996
# Fold 5 RMSLE for ('model3', 'model4') = 0.29446928194339383
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.2902751931468926
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.2918990746090605
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.2945873650535555
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.290779700708428
# Fold 5 RMSLE for all models ensemble = 0.2916825881973631
# Fold 5 best combination: model2 with RMSLE = 0.2857855866010136
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.2927504384441936
# Fold 6 RMSLE for model2 = 0.2871024278968129
# Fold 6 RMSLE for model3 = 0.28758790774040827
# Fold 6 RMSLE for model4 = 0.2865343453456521
# Fold 6 RMSLE for ('model1', 'model2') = 0.2874504164571817
# Fold 6 RMSLE for ('model1', 'model3') = 0.28984629891523117
# Fold 6 RMSLE for ('model1', 'model4') = 0.2883928057122444
# Fold 6 RMSLE for ('model2', 'model3') = 0.2850802804810449
# Fold 6 RMSLE for ('model2', 'model4') = 0.28527519222316766
# Fold 6 RMSLE for ('model3', 'model4') = 0.2856927882103199
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.28692556345390324
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.28646977254251044
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.2876540995811907
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.2847908983268983
# Fold 6 RMSLE for all models ensemble = 0.28621477116720523
# Fold 6 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.2847908983268983
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.2895563333313881
# Fold 7 RMSLE for model2 = 0.27884492070223665
# Fold 7 RMSLE for model3 = 0.29190707657255976
# Fold 7 RMSLE for model4 = 0.28300519657152556
# Fold 7 RMSLE for ('model1', 'model2') = 0.2816587968962694
# Fold 7 RMSLE for ('model1', 'model3') = 0.2902854961325225
# Fold 7 RMSLE for ('model1', 'model4') = 0.2850506597699222
# Fold 7 RMSLE for ('model2', 'model3') = 0.2823029338161994
# Fold 7 RMSLE for ('model2', 'model4') = 0.27950749351096815
# Fold 7 RMSLE for ('model3', 'model4') = 0.28558048128683083
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.2841160984865733
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.28147407692908133
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.2866001660186618
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.28171946920927227
# Fold 7 RMSLE for all models ensemble = 0.28318663034155916
# Fold 7 best combination: model2 with RMSLE = 0.27884492070223665
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.3242360490973152
# Fold 8 RMSLE for model2 = 0.3208951727220215
# Fold 8 RMSLE for model3 = 0.3209942122612117
# Fold 8 RMSLE for model4 = 0.3343425327133131
# Fold 8 RMSLE for ('model1', 'model2') = 0.32005687969856983
# Fold 8 RMSLE for ('model1', 'model3') = 0.3222805772246124
# Fold 8 RMSLE for ('model1', 'model4') = 0.3275325604878192
# Fold 8 RMSLE for ('model2', 'model3') = 0.31847747395073794
# Fold 8 RMSLE for ('model2', 'model4') = 0.3265791891084183
# Fold 8 RMSLE for ('model3', 'model4') = 0.325651212336717
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.31965403218044397
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.32415873170092296
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.32465528463246696
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.322980022370402
# Fold 8 RMSLE for all models ensemble = 0.32257821162283185
# Fold 8 best combination: ('model2', 'model3') with RMSLE = 0.31847747395073794
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.34355660151257233
# Fold 9 RMSLE for model2 = 0.31969700685870595
# Fold 9 RMSLE for model3 = 0.3393918013905295
# Fold 9 RMSLE for model4 = 0.34257275224566675
# Fold 9 RMSLE for ('model1', 'model2') = 0.3294992607870735
# Fold 9 RMSLE for ('model1', 'model3') = 0.3407354719665456
# Fold 9 RMSLE for ('model1', 'model4') = 0.34200842172690654
# Fold 9 RMSLE for ('model2', 'model3') = 0.3276480494656576
# Fold 9 RMSLE for ('model2', 'model4') = 0.32995514664187725
# Fold 9 RMSLE for ('model3', 'model4') = 0.33920789800353335
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.3320895176218345
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.3333787309642504
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.3402651257452671
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.33171613533555394
# Fold 9 RMSLE for all models ensemble = 0.3341251775512094
# Fold 9 best combination: model2 with RMSLE = 0.31969700685870595
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.26845645608236496
# Fold 10 RMSLE for model2 = 0.2755234620833245
# Fold 10 RMSLE for model3 = 0.2660589600715335
# Fold 10 RMSLE for model4 = 0.26916247137566823
# Fold 10 RMSLE for ('model1', 'model2') = 0.269888943352345
# Fold 10 RMSLE for ('model1', 'model3') = 0.2668001370852795
# Fold 10 RMSLE for ('model1', 'model4') = 0.2672406310141999
# Fold 10 RMSLE for ('model2', 'model3') = 0.26887132414057585
# Fold 10 RMSLE for ('model2', 'model4') = 0.2710891574877074
# Fold 10 RMSLE for ('model3', 'model4') = 0.2658257507013023
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.26801641780677515
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.2688616985412592
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.26619842643824093
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.26805175252273594
# Fold 10 RMSLE for all models ensemble = 0.2675303941526907
# Fold 10 best combination: ('model3', 'model4') with RMSLE = 0.2658257507013023
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.28878237290705183
# Fold 11 RMSLE for model2 = 0.28897124732457385
# Fold 11 RMSLE for model3 = 0.2936848282514831
# Fold 11 RMSLE for model4 = 0.3002260179720079
# Fold 11 RMSLE for ('model1', 'model2') = 0.2866101248762805
# Fold 11 RMSLE for ('model1', 'model3') = 0.2909334075990011
# Fold 11 RMSLE for ('model1', 'model4') = 0.293254640896495
# Fold 11 RMSLE for ('model2', 'model3') = 0.2894218636895165
# Fold 11 RMSLE for ('model2', 'model4') = 0.2936031016146445
# Fold 11 RMSLE for ('model3', 'model4') = 0.295447491692259
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.28850434794935825
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.29066289003114576
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.29286113652926105
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.29234898172057716
# Fold 11 RMSLE for all models ensemble = 0.2908701925740694
# Fold 11 best combination: ('model1', 'model2') with RMSLE = 0.2866101248762805
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.2794310159217038
# Fold 12 RMSLE for model2 = 0.2770246601628573
# Fold 12 RMSLE for model3 = 0.28040039483193335
# Fold 12 RMSLE for model4 = 0.27820277777854485
# Fold 12 RMSLE for ('model1', 'model2') = 0.2749073086554286
# Fold 12 RMSLE for ('model1', 'model3') = 0.2793957215347322
# Fold 12 RMSLE for ('model1', 'model4') = 0.27701615959192616
# Fold 12 RMSLE for ('model2', 'model3') = 0.27601925441194847
# Fold 12 RMSLE for ('model2', 'model4') = 0.2763517314583849
# Fold 12 RMSLE for ('model3', 'model4') = 0.2777381992431078
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.27599512623586364
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.2753937051070464
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.27761338329349083
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.2760842885693833
# Fold 12 RMSLE for all models ensemble = 0.2759528433494931
# Fold 12 best combination: ('model1', 'model2') with RMSLE = 0.2749073086554286
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.2786632702642423
# Fold 13 RMSLE for model2 = 0.2713386477325033
# Fold 13 RMSLE for model3 = 0.27330969636271546
# Fold 13 RMSLE for model4 = 0.27579975614302643
# Fold 13 RMSLE for ('model1', 'model2') = 0.2730149891130363
# Fold 13 RMSLE for ('model1', 'model3') = 0.27540927650171326
# Fold 13 RMSLE for ('model1', 'model4') = 0.2752641766699315
# Fold 13 RMSLE for ('model2', 'model3') = 0.27025877666418274
# Fold 13 RMSLE for ('model2', 'model4') = 0.2720524410277949
# Fold 13 RMSLE for ('model3', 'model4') = 0.2721971726691484
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.27237535653868683
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.27281409457337036
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.273721611518309
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.2708362303593235
# Fold 13 RMSLE for all models ensemble = 0.27213603783998114
# Fold 13 best combination: ('model2', 'model3') with RMSLE = 0.27025877666418274
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.27584472599441157
# Fold 14 RMSLE for model2 = 0.27473859140956125
# Fold 14 RMSLE for model3 = 0.2770935388387919
# Fold 14 RMSLE for model4 = 0.2816857583952455
# Fold 14 RMSLE for ('model1', 'model2') = 0.2729873679719068
# Fold 14 RMSLE for ('model1', 'model3') = 0.2758852434419204
# Fold 14 RMSLE for ('model1', 'model4') = 0.277386227188851
# Fold 14 RMSLE for ('model2', 'model3') = 0.27350876976055355
# Fold 14 RMSLE for ('model2', 'model4') = 0.27673968395981086
# Fold 14 RMSLE for ('model3', 'model4') = 0.27770001879176137
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.27355268601336336
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.2751371277022526
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.27658198438174236
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.2753731280116953
# Fold 14 RMSLE for all models ensemble = 0.274892615213931
# Fold 14 best combination: ('model1', 'model2') with RMSLE = 0.2729873679719068
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.2903503440260503
# Fold 15 RMSLE for model2 = 0.2842584359604326
# Fold 15 RMSLE for model3 = 0.29371787190887777
# Fold 15 RMSLE for model4 = 0.2882791679873159
# Fold 15 RMSLE for ('model1', 'model2') = 0.28488396205857747
# Fold 15 RMSLE for ('model1', 'model3') = 0.29157293856335453
# Fold 15 RMSLE for ('model1', 'model4') = 0.2880766319900034
# Fold 15 RMSLE for ('model2', 'model3') = 0.2870884817014272
# Fold 15 RMSLE for ('model2', 'model4') = 0.28462058344381497
# Fold 15 RMSLE for ('model3', 'model4') = 0.2896938056746738
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.2873235903924502
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.2852814561369312
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.2894466324455396
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.2866023068218006
# Fold 15 RMSLE for all models ensemble = 0.2869182037684377
# Fold 15 best combination: model2 with RMSLE = 0.2842584359604326
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.3396438538024317
# Fold 16 RMSLE for model2 = 0.33047540295471406
# Fold 16 RMSLE for model3 = 0.3389726844575296
# Fold 16 RMSLE for model4 = 0.34032675584140215
# Fold 16 RMSLE for ('model1', 'model2') = 0.3332816650174927
# Fold 16 RMSLE for ('model1', 'model3') = 0.3390572805259583
# Fold 16 RMSLE for ('model1', 'model4') = 0.33897503524516925
# Fold 16 RMSLE for ('model2', 'model3') = 0.3330692817053889
# Fold 16 RMSLE for ('model2', 'model4') = 0.3344149164420134
# Fold 16 RMSLE for ('model3', 'model4') = 0.3385458675803331
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.3347494821297818
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.3351438248903412
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.33859691118387075
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.33492786041155154
# Fold 16 RMSLE for all models ensemble = 0.33567108004717616
# Fold 16 best combination: model2 with RMSLE = 0.33047540295471406
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.2916320249816046
# Fold 17 RMSLE for model2 = 0.2901150065845918
# Fold 17 RMSLE for model3 = 0.2884262963866416
# Fold 17 RMSLE for model4 = 0.2853989345263919
# Fold 17 RMSLE for ('model1', 'model2') = 0.2883001590954186
# Fold 17 RMSLE for ('model1', 'model3') = 0.2896964910292159
# Fold 17 RMSLE for ('model1', 'model4') = 0.2872199666130475
# Fold 17 RMSLE for ('model2', 'model3') = 0.2871118197263615
# Fold 17 RMSLE for ('model2', 'model4') = 0.2861219573602647
# Fold 17 RMSLE for ('model3', 'model4') = 0.28551818112011007
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.28777718212033737
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.28659958651487966
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.2871414132945271
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.28566740544756314
# Fold 17 RMSLE for all models ensemble = 0.2865288398209735
# Fold 17 best combination: model4 with RMSLE = 0.2853989345263919
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.2869611475245866
# Fold 18 RMSLE for model2 = 0.28731804891163004
# Fold 18 RMSLE for model3 = 0.28431524516965573
# Fold 18 RMSLE for model4 = 0.2846360872064541
# Fold 18 RMSLE for ('model1', 'model2') = 0.2843646589975999
# Fold 18 RMSLE for ('model1', 'model3') = 0.2848634117629151
# Fold 18 RMSLE for ('model1', 'model4') = 0.283643566826977
# Fold 18 RMSLE for ('model2', 'model3') = 0.2833506852008561
# Fold 18 RMSLE for ('model2', 'model4') = 0.28441998710285626
# Fold 18 RMSLE for ('model3', 'model4') = 0.28198080737316483
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.28349608367872653
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.2834171894458818
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.2828886779283511
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.28251481791449257
# Fold 18 RMSLE for all models ensemble = 0.2827311292061498
# Fold 18 best combination: ('model3', 'model4') with RMSLE = 0.28198080737316483
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.2995406733850515
# Fold 19 RMSLE for model2 = 0.30425133869226706
# Fold 19 RMSLE for model3 = 0.2989109951664352
# Fold 19 RMSLE for model4 = 0.30113453006233376
# Fold 19 RMSLE for ('model1', 'model2') = 0.29952479035946195
# Fold 19 RMSLE for ('model1', 'model3') = 0.2987872399943685
# Fold 19 RMSLE for ('model1', 'model4') = 0.29888171678150716
# Fold 19 RMSLE for ('model2', 'model3') = 0.29924888526447413
# Fold 19 RMSLE for ('model2', 'model4') = 0.30108311796962045
# Fold 19 RMSLE for ('model3', 'model4') = 0.29790797500828553
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.29861988533637435
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.29923358183215676
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.29807340399440524
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.2987475864052958
# Fold 19 RMSLE for all models ensemble = 0.29838477804061614
# Fold 19 best combination: ('model3', 'model4') with RMSLE = 0.29790797500828553
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.300322600410203
# Fold 20 RMSLE for model2 = 0.2946816338926134
# Fold 20 RMSLE for model3 = 0.3015204763721218
# Fold 20 RMSLE for model4 = 0.2982594673852656
# Fold 20 RMSLE for ('model1', 'model2') = 0.2948822463128567
# Fold 20 RMSLE for ('model1', 'model3') = 0.3001946342067319
# Fold 20 RMSLE for ('model1', 'model4') = 0.2979763125855623
# Fold 20 RMSLE for ('model2', 'model3') = 0.2957260322460954
# Fold 20 RMSLE for ('model2', 'model4') = 0.29513938680270313
# Fold 20 RMSLE for ('model3', 'model4') = 0.298264070871527
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.29632197373433283
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.2954266092871805
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.298406579957271
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.2957918937360436
# Fold 20 RMSLE for all models ensemble = 0.2962165706866186
# Fold 20 best combination: model2 with RMSLE = 0.2946816338926134
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.30181300720966847
# Fold 21 RMSLE for model2 = 0.2877451336582024
# Fold 21 RMSLE for model3 = 0.29783854390545283
# Fold 21 RMSLE for model4 = 0.3029088474049471
# Fold 21 RMSLE for ('model1', 'model2') = 0.29243729574457505
# Fold 21 RMSLE for ('model1', 'model3') = 0.2994856454308144
# Fold 21 RMSLE for ('model1', 'model4') = 0.30134834069861693
# Fold 21 RMSLE for ('model2', 'model3') = 0.29054307235104454
# Fold 21 RMSLE for ('model2', 'model4') = 0.2942322438957559
# Fold 21 RMSLE for ('model3', 'model4') = 0.29934629115015543
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.29360055473588054
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.2955250139947026
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.2997958053143096
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.29423387269413176
# Fold 21 RMSLE for all models ensemble = 0.295566917260317
# Fold 21 best combination: model2 with RMSLE = 0.2877451336582024
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.3011611144229865
# Fold 22 RMSLE for model2 = 0.2919456470760208
# Fold 22 RMSLE for model3 = 0.2978839800552474
# Fold 22 RMSLE for model4 = 0.29871862111121045
# Fold 22 RMSLE for ('model1', 'model2') = 0.2939260272731489
# Fold 22 RMSLE for ('model1', 'model3') = 0.29893326173894624
# Fold 22 RMSLE for ('model1', 'model4') = 0.29846778501166227
# Fold 22 RMSLE for ('model2', 'model3') = 0.2925307290160071
# Fold 22 RMSLE for ('model2', 'model4') = 0.2934846694185968
# Fold 22 RMSLE for ('model3', 'model4') = 0.29626125298698663
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.29450648154349246
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.29465516265377406
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.2974254515841915
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.29340573271203685
# Fold 22 RMSLE for all models ensemble = 0.29469885993243805
# Fold 22 best combination: model2 with RMSLE = 0.2919456470760208
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.2978490240551092
# Fold 23 RMSLE for model2 = 0.2892629492990025
# Fold 23 RMSLE for model3 = 0.29674471292476556
# Fold 23 RMSLE for model4 = 0.2945618301306265
# Fold 23 RMSLE for ('model1', 'model2') = 0.29130543115201524
# Fold 23 RMSLE for ('model1', 'model3') = 0.296828932528366
# Fold 23 RMSLE for ('model1', 'model4') = 0.2947234229765975
# Fold 23 RMSLE for ('model2', 'model3') = 0.29118714750294034
# Fold 23 RMSLE for ('model2', 'model4') = 0.2905151199050608
# Fold 23 RMSLE for ('model3', 'model4') = 0.2940757088860893
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.29260674217568505
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.291617046733743
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.2948197951014766
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.2913899296517551
# Fold 23 RMSLE for all models ensemble = 0.2923601305080094
# Fold 23 best combination: model2 with RMSLE = 0.2892629492990025
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.29458571315176735
# Fold 24 RMSLE for model2 = 0.30006675226017404
# Fold 24 RMSLE for model3 = 0.2934551355170621
# Fold 24 RMSLE for model4 = 0.2980789844606477
# Fold 24 RMSLE for ('model1', 'model2') = 0.2951447500107892
# Fold 24 RMSLE for ('model1', 'model3') = 0.29368999291493314
# Fold 24 RMSLE for ('model1', 'model4') = 0.2950364942750126
# Fold 24 RMSLE for ('model2', 'model3') = 0.29475837715858544
# Fold 24 RMSLE for ('model2', 'model4') = 0.29752913686724103
# Fold 24 RMSLE for ('model3', 'model4') = 0.2941625944695534
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.2940435887177765
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.2953396571733574
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.29394721855013756
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.2949105925926121
# Fold 24 RMSLE for all models ensemble = 0.2943146882984738
# Fold 24 best combination: model3 with RMSLE = 0.2934551355170621
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.30086015538460514
# Fold 25 RMSLE for model2 = 0.29974137357618647
# Fold 25 RMSLE for model3 = 0.30286234582872984
# Fold 25 RMSLE for model4 = 0.31108027441637165
# Fold 25 RMSLE for ('model1', 'model2') = 0.29775476157832287
# Fold 25 RMSLE for ('model1', 'model3') = 0.30151019266680107
# Fold 25 RMSLE for ('model1', 'model4') = 0.30487033789446494
# Fold 25 RMSLE for ('model2', 'model3') = 0.29888340855218004
# Fold 25 RMSLE for ('model2', 'model4') = 0.30414947303133516
# Fold 25 RMSLE for ('model3', 'model4') = 0.30539556783768923
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.2987650618057374
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.30172848611374387
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.3035798573075214
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.302239693335934
# Fold 25 RMSLE for all models ensemble = 0.3013204733043042
# Fold 25 best combination: ('model1', 'model2') with RMSLE = 0.29775476157832287
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.32227366376668115
# Fold 26 RMSLE for model2 = 0.3260481716754934
# Fold 26 RMSLE for model3 = 0.32319678581066524
# Fold 26 RMSLE for model4 = 0.33094723950490545
# Fold 26 RMSLE for ('model1', 'model2') = 0.3220031272465179
# Fold 26 RMSLE for ('model1', 'model3') = 0.32243770012693274
# Fold 26 RMSLE for ('model1', 'model4') = 0.32530603287404153
# Fold 26 RMSLE for ('model2', 'model3') = 0.32220721097009497
# Fold 26 RMSLE for ('model2', 'model4') = 0.3274420385539272
# Fold 26 RMSLE for ('model3', 'model4') = 0.3251245454088871
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.32165698451748037
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.32442329378698964
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.32387860353352865
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.3243366926102277
# Fold 26 RMSLE for all models ensemble = 0.32331764779508726
# Fold 26 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.32165698451748037
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.29706262449892373
# Fold 27 RMSLE for model2 = 0.29815048699645735
# Fold 27 RMSLE for model3 = 0.2968839757185257
# Fold 27 RMSLE for model4 = 0.29973535820905745
# Fold 27 RMSLE for ('model1', 'model2') = 0.295377913268851
# Fold 27 RMSLE for ('model1', 'model3') = 0.29655762149777964
# Fold 27 RMSLE for ('model1', 'model4') = 0.29671539818430087
# Fold 27 RMSLE for ('model2', 'model3') = 0.2951865644367865
# Fold 27 RMSLE for ('model2', 'model4') = 0.2975671640902331
# Fold 27 RMSLE for ('model3', 'model4') = 0.2962745653603887
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.2951261451790454
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.29597990443668776
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.29603768690171767
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.2957174721245568
# Fold 27 RMSLE for all models ensemble = 0.29543250664996995
# Fold 27 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.2951261451790454
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.27331505487920293
# Fold 28 RMSLE for model2 = 0.2574714353208272
# Fold 28 RMSLE for model3 = 0.2722497250996136
# Fold 28 RMSLE for model4 = 0.2703656496355394
# Fold 28 RMSLE for ('model1', 'model2') = 0.26243700541676773
# Fold 28 RMSLE for ('model1', 'model3') = 0.27231329559036116
# Fold 28 RMSLE for ('model1', 'model4') = 0.27000504851912777
# Fold 28 RMSLE for ('model2', 'model3') = 0.2623751728354247
# Fold 28 RMSLE for ('model2', 'model4') = 0.2630342882466507
# Fold 28 RMSLE for ('model3', 'model4') = 0.269168971959146
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.2649987489298705
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.26456369364641885
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.2699887565184088
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.2642636191637238
# Fold 28 RMSLE for all models ensemble = 0.26565276645063685
# Fold 28 best combination: model2 with RMSLE = 0.2574714353208272
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.2608526521778172
# Fold 29 RMSLE for model2 = 0.2649983493390908
# Fold 29 RMSLE for model3 = 0.26165090309348366
# Fold 29 RMSLE for model4 = 0.26095976374635116
# Fold 29 RMSLE for ('model1', 'model2') = 0.259481452782648
# Fold 29 RMSLE for ('model1', 'model3') = 0.2607576555810063
# Fold 29 RMSLE for ('model1', 'model4') = 0.25914359180037927
# Fold 29 RMSLE for ('model2', 'model3') = 0.2597478905398696
# Fold 29 RMSLE for ('model2', 'model4') = 0.2610225807118218
# Fold 29 RMSLE for ('model3', 'model4') = 0.2588538307347926
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.25918830132466275
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.259092668761344
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.2590664219485908
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.2590044811317343
# Fold 29 RMSLE for all models ensemble = 0.25871754807242114
# Fold 29 best combination: ('model1', 'model2', 'model3', 'model4') with RMSLE = 0.25871754807242114
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.3184328667649723
# Fold 30 RMSLE for model2 = 0.3125008507355816
# Fold 30 RMSLE for model3 = 0.3165044472364328
# Fold 30 RMSLE for model4 = 0.3233126762492306
# Fold 30 RMSLE for ('model1', 'model2') = 0.31350333863105034
# Fold 30 RMSLE for ('model1', 'model3') = 0.3167957651025438
# Fold 30 RMSLE for ('model1', 'model4') = 0.3194596240123318
# Fold 30 RMSLE for ('model2', 'model3') = 0.31178587444961964
# Fold 30 RMSLE for ('model2', 'model4') = 0.31664837889507336
# Fold 30 RMSLE for ('model3', 'model4') = 0.31720262627305373
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.313441088154615
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.3160233432780997
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.3172911885018907
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.31449722405892333
# Fold 30 RMSLE for all models ensemble = 0.31502194611895096
# Fold 30 best combination: ('model2', 'model3') with RMSLE = 0.31178587444961964
# ---------------
#
# OOF RMSLE = 0.2908230902698547
# Sum of RMSLE for each combination:
# ('model1',): 8.905252536995274
# ('model2',): 8.78015538183159
# ('model3',): 8.8690376170495
# ('model4',): 8.930780563004134
# ('model1', 'model2'): 8.770110110852109
# ('model1', 'model3'): 8.872795173657954
# ('model1', 'model4'): 8.874076353391484
# ('model2', 'model3'): 8.754607577916548
# ('model2', 'model4'): 8.813971498126243
# ('model3', 'model4'): 8.844794534421245
# ('model1', 'model2', 'model3'): 8.781743543962541
# ('model1', 'model2', 'model4'): 8.802126835800319
# ('model1', 'model3', 'model4'): 8.851167068029152
# ('model2', 'model3', 'model4'): 8.786178472627329
# ('model1', 'model2', 'model3', 'model4'): 8.797120125432038

# %%
train_df = train_df.reset_index(drop=True)
train_df.iloc[:, -1]
# Out:
# 0         52,973
# 1         55,910
# 2         55,680
# 3         61,412
# 4         43,100
#           ...
# 7158     517,178
# 7159     101,406
# 7160     134,966
# 7161     259,370
# 7162   1,307,431
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 7163, dtype: float64

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(train_target)
log_oof_predictions = np.log1p(train_preds)
# 差の計算
diff = abs(log_target - log_oof_predictions)
# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線の描画
min_val = min(log_target.min(), log_oof_predictions.min())
max_val = max(log_target.max(), log_oof_predictions.max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='y = x')  # 45度線


# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)
# 凡例の設定
plt.legend(title='Difference > 0.7')

# プロットの表示
plt.tight_layout()
plt.show()

# %%
test_preds.max()
# Out:
# 3320978.353195206

# %%
test_preds.max(), train_preds.min()
# Out:
# (3320978.353195206, 6326.497846968891)

# %%
after_test_preds = test_preds.copy()
after_train_preds = train_preds.copy()

# %%
# def after_times(test_preds):
#     preds = test_preds.copy()
#     low_standard = 10.2-np.log1p(preds.min())
#     higt_standard = np.log1p(preds.max())-14.4
#     for i in range(len(test_preds)):
#         if preds[i] < np.expm1(10.2):
#             preds[i] -= np.expm1(np.log1p(preds[i])*100/102)
#         elif preds[i] > np.expm1(14.4):
#             preds[i] += np.expm1(np.log1p(preds[i])*100/99)

#     return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=after_train_preds, y=train_target, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--')  # 45度線
plt.plot([np.expm1(10.2), np.expm1(10.2)], [10**2, 10**7], 'g--')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=after_test_preds, y=after_test_preds, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--')  # 45度線
plt.plot([np.expm1(10.2), np.expm1(10.2)], [10**2, 10**7], 'g--')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--')
plt.show()

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_43.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    46,714
# 1     4656   288,251
# 2     4657    41,757
# 3     4658    29,371
# 4     4659    48,104
# ...    ...       ...
# 2503  7158   524,018
# 2504  7159    96,415
# 2505  7160   131,125
# 2506  7161   264,873
# 2507  7162 1,319,239
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,247,149
# 110   4765 1,336,441
# 114   4769 1,204,923
# 148   4803 1,897,927
# 178   4833 1,461,238
# ...    ...       ...
# 2417  7072 1,225,969
# 2423  7078 1,250,630
# 2466  7121 1,637,891
# 2490  7145 1,345,805
# 2507  7162 1,319,239
#
# [110 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0         46,714
# 1        288,251
# 2         41,757
# 3         29,371
# 4         48,104
#           ...
# 2503     524,018
# 2504      96,415
# 2505     131,125
# 2506     264,873
# 2507   1,319,239
# Name: test_preds, Length: 2508, dtype: float64

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 6055                          NaN                          NaN           240
# 6056                          NaN                          NaN             4
# 6057                       25,069                       24,560           132
# 6058                       93,119                      130,327            98
# 6059                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 6055                                 110,523
# 6056                                     NaN
# 6057                                 166,520
# 6058                                  71,774
# 6059                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 6055                                  98,955
# 6056                                     NaN
# 6057                                 469,733
# 6058                                 936,032
# 6059                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 6055                               3,467,008
# 6056                                     NaN
# 6057                                  82,559
# 6058                                 336,961
# 6059                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 6055                                 147,802        39        -76
# 6056                                     NaN        31       -102
# 6057                                  85,775        41        -96
# 6058                                 156,640        39        -93
# 6059                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 6055                              NaN                              NaN
# 6056                              NaN                              NaN
# 6057                              636                            1,477
# 6058                           16,356                          -47,698
# 6059                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 6055                              NaN                               NaN
# 6056                              NaN                               NaN
# 6057                             -509                                 0
# 6058                           37,208                                 0
# 6059                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 6055                               NaN                               NaN
# 6056                               NaN                               NaN
# 6057                                 0                                -0
# 6058                                -0                                 0
# 6059                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 6055                1            1                                   517,178
# 6056                9            1                                   101,406
# 6057                8            0                                   134,966
# 6058                8            0                                   259,370
# 6059                9            1                                 1,307,431
#
# [6060 rows x 18 columns]

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(after_train_preds, train_target, "after_train_preds, train_target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
          "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], after_test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Mon Nov 25 04:30:45 2024
