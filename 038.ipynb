# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/038.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pygeohash
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# !pip install optuna
# Out:
# Requirement already satisfied: pygeohash in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df.csv', index_col=0)

train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.drop('test_preds', axis=1, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = abs(np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions']))

# 2. 条件を満たす行のマスクを作成
mask = diff > 0.7

# 3. 除外する行の数をカウント
exclude_num = mask.sum()
train_df = train_all_df.copy()
# 4. 条件を満たさない行だけを保持
train_all_df = train_all_df[~mask].reset_index(drop=True)

# 5. 'oof_predictions' 列を削除
train_all_df.drop('oof_predictions', axis=1, inplace=True)
train_df.drop('oof_predictions', axis=1, inplace=True)
# 6. 結果の表示
print(f"除外された行数: {exclude_num}")
# Out:
# 除外された行数: 1175

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   549,795
# 2504                9            1                                   113,768
# 2505                8            0                                   141,266
# 2506                8            0                                   259,996
# 2507                9            1                                 1,293,278
#
# [7163 rows x 19 columns]

# %% [markdown]
# 'iterations': 254, 'depth': 5, 'learning_rate': 0.08377009991199288, 'l2_leaf_reg': 1, 'bagging_temperature': 0.7204457890870082, 'min_data_in_leaf': 4

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, np.log1p(y_train))
            preds = np.expm1(model.predict(X_valid))
            rmsle = np.sqrt(mean_squared_log_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_log_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_log_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = np.expm1(test_predictions)
    final_train_predictions = np.expm1(train_eval_predictions)

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_all = train_all_df.iloc[:, :-1].values
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
test = test_df.values
target = train_all_df.iloc[:, -1].values

# %%
oof_predictions,test_preds, train_preds = get_models_trained(train_all,test,target,30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.3099353714508171
# Fold 1 RMSLE for model2 = 0.30445065012224826
# Fold 1 RMSLE for model3 = 0.30479118016876705
# Fold 1 RMSLE for model4 = 0.30296686676357987
# Fold 1 RMSLE for ('model1', 'model2') = 0.3042263589404375
# Fold 1 RMSLE for ('model1', 'model3') = 0.3065482113474819
# Fold 1 RMSLE for ('model1', 'model4') = 0.3044660844659007
# Fold 1 RMSLE for ('model2', 'model3') = 0.3009076442790318
# Fold 1 RMSLE for ('model2', 'model4') = 0.3024873902773531
# Fold 1 RMSLE for ('model3', 'model4') = 0.30072899958142746
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.30302120868465077
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.30307663043835587
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.30323902437753
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.3005294467302083
# Fold 1 RMSLE for all models ensemble = 0.3020899077258578
# Fold 1 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.3005294467302083
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.2945397670651645
# Fold 2 RMSLE for model2 = 0.2919994940092245
# Fold 2 RMSLE for model3 = 0.29779138234719243
# Fold 2 RMSLE for model4 = 0.2930702927399889
# Fold 2 RMSLE for ('model1', 'model2') = 0.2916409519591281
# Fold 2 RMSLE for ('model1', 'model3') = 0.2957181041999593
# Fold 2 RMSLE for ('model1', 'model4') = 0.29274611324373884
# Fold 2 RMSLE for ('model2', 'model3') = 0.29316251438542984
# Fold 2 RMSLE for ('model2', 'model4') = 0.2913261625310345
# Fold 2 RMSLE for ('model3', 'model4') = 0.29372231642814717
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.293087670357085
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.29147093884190434
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.2937009860521231
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.2922180382499285
# Fold 2 RMSLE for all models ensemble = 0.2924026255533618
# Fold 2 best combination: ('model2', 'model4') with RMSLE = 0.2913261625310345
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.302998927070051
# Fold 3 RMSLE for model2 = 0.297130625839601
# Fold 3 RMSLE for model3 = 0.2993953387801593
# Fold 3 RMSLE for model4 = 0.30871917086081085
# Fold 3 RMSLE for ('model1', 'model2') = 0.29877780659378916
# Fold 3 RMSLE for ('model1', 'model3') = 0.30088795252035183
# Fold 3 RMSLE for ('model1', 'model4') = 0.30503459624686263
# Fold 3 RMSLE for ('model2', 'model3') = 0.29703852624960964
# Fold 3 RMSLE for ('model2', 'model4') = 0.3021595998894212
# Fold 3 RMSLE for ('model3', 'model4') = 0.3030162963156919
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.2985824531380505
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.3016615165671378
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.3027192829296781
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.300391246616461
# Fold 3 RMSLE for all models ensemble = 0.3006789463622055
# Fold 3 best combination: ('model2', 'model3') with RMSLE = 0.29703852624960964
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.253224818785356
# Fold 4 RMSLE for model2 = 0.24182678677921915
# Fold 4 RMSLE for model3 = 0.25517282921551293
# Fold 4 RMSLE for model4 = 0.24264298038827917
# Fold 4 RMSLE for ('model1', 'model2') = 0.24463181721108668
# Fold 4 RMSLE for ('model1', 'model3') = 0.2536941176498941
# Fold 4 RMSLE for ('model1', 'model4') = 0.24616190566484375
# Fold 4 RMSLE for ('model2', 'model3') = 0.2453781083324129
# Fold 4 RMSLE for ('model2', 'model4') = 0.2410219516701355
# Fold 4 RMSLE for ('model3', 'model4') = 0.24649943311601588
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.24715916299338378
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.24329456175913086
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.24826186427134272
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.24355171101361214
# Fold 4 RMSLE for all models ensemble = 0.24523710511125613
# Fold 4 best combination: ('model2', 'model4') with RMSLE = 0.2410219516701355
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.2695598555345814
# Fold 5 RMSLE for model2 = 0.2627781518520738
# Fold 5 RMSLE for model3 = 0.2709942900508911
# Fold 5 RMSLE for model4 = 0.2638948894719498
# Fold 5 RMSLE for ('model1', 'model2') = 0.26152801369833606
# Fold 5 RMSLE for ('model1', 'model3') = 0.26988914282732296
# Fold 5 RMSLE for ('model1', 'model4') = 0.26402478092868215
# Fold 5 RMSLE for ('model2', 'model3') = 0.26228203963113245
# Fold 5 RMSLE for ('model2', 'model4') = 0.2619289659271509
# Fold 5 RMSLE for ('model3', 'model4') = 0.26458437539274055
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.2633292022037141
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.261591523123104
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.2654303646955339
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.26200677663105904
# Fold 5 RMSLE for all models ensemble = 0.26261967747162607
# Fold 5 best combination: ('model1', 'model2') with RMSLE = 0.26152801369833606
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.311981159732858
# Fold 6 RMSLE for model2 = 0.314393262338491
# Fold 6 RMSLE for model3 = 0.3119747400870452
# Fold 6 RMSLE for model4 = 0.31533739470823
# Fold 6 RMSLE for ('model1', 'model2') = 0.3117975326555298
# Fold 6 RMSLE for ('model1', 'model3') = 0.3116585823985134
# Fold 6 RMSLE for ('model1', 'model4') = 0.31279416711077873
# Fold 6 RMSLE for ('model2', 'model3') = 0.31181214750009867
# Fold 6 RMSLE for ('model2', 'model4') = 0.3139183036680592
# Fold 6 RMSLE for ('model3', 'model4') = 0.3124309095577043
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.31141276834447523
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.31247913806286143
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.31202703138184334
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.3123247356993313
# Fold 6 RMSLE for all models ensemble = 0.31189021055267113
# Fold 6 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.31141276834447523
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.2932785729846636
# Fold 7 RMSLE for model2 = 0.2962802269383601
# Fold 7 RMSLE for model3 = 0.2940829148595591
# Fold 7 RMSLE for model4 = 0.29559561245675037
# Fold 7 RMSLE for ('model1', 'model2') = 0.29267841459731386
# Fold 7 RMSLE for ('model1', 'model3') = 0.2931327557633692
# Fold 7 RMSLE for ('model1', 'model4') = 0.29316851849562364
# Fold 7 RMSLE for ('model2', 'model3') = 0.29271182612993946
# Fold 7 RMSLE for ('model2', 'model4') = 0.2944139553477945
# Fold 7 RMSLE for ('model3', 'model4') = 0.29277614108365696
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.29227305707496204
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.2928712202659451
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.29260557407005644
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.2926264424097748
# Fold 7 RMSLE for all models ensemble = 0.2923181247654678
# Fold 7 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.29227305707496204
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.30466143183978756
# Fold 8 RMSLE for model2 = 0.29801653672395906
# Fold 8 RMSLE for model3 = 0.30312856598738885
# Fold 8 RMSLE for model4 = 0.30196589489366316
# Fold 8 RMSLE for ('model1', 'model2') = 0.298415194591147
# Fold 8 RMSLE for ('model1', 'model3') = 0.3035258612460837
# Fold 8 RMSLE for ('model1', 'model4') = 0.30073260691079146
# Fold 8 RMSLE for ('model2', 'model3') = 0.2973643270669801
# Fold 8 RMSLE for ('model2', 'model4') = 0.29854024507679916
# Fold 8 RMSLE for ('model3', 'model4') = 0.29953000983670863
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.29900294019551005
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.2984634021396736
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.3005312060989026
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.2976422095654218
# Fold 8 RMSLE for all models ensemble = 0.29851989238704396
# Fold 8 best combination: ('model2', 'model3') with RMSLE = 0.2973643270669801
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.29841885002368074
# Fold 9 RMSLE for model2 = 0.2932313036013009
# Fold 9 RMSLE for model3 = 0.30189507275467065
# Fold 9 RMSLE for model4 = 0.2928407084313192
# Fold 9 RMSLE for ('model1', 'model2') = 0.29321805414508917
# Fold 9 RMSLE for ('model1', 'model3') = 0.29951784322104275
# Fold 9 RMSLE for ('model1', 'model4') = 0.2942032757844354
# Fold 9 RMSLE for ('model2', 'model3') = 0.29406951043930446
# Fold 9 RMSLE for ('model2', 'model4') = 0.29177664620421784
# Fold 9 RMSLE for ('model3', 'model4') = 0.29496575540795045
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.29481580085198705
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.2924766643273276
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.2957383343925915
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.2928711557212547
# Fold 9 RMSLE for all models ensemble = 0.2936542132997489
# Fold 9 best combination: ('model2', 'model4') with RMSLE = 0.29177664620421784
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.2778467922762676
# Fold 10 RMSLE for model2 = 0.28849121628460583
# Fold 10 RMSLE for model3 = 0.27566131357583507
# Fold 10 RMSLE for model4 = 0.2869211157931833
# Fold 10 RMSLE for ('model1', 'model2') = 0.28115380450491584
# Fold 10 RMSLE for ('model1', 'model3') = 0.27625639561611626
# Fold 10 RMSLE for ('model1', 'model4') = 0.28092603559011603
# Fold 10 RMSLE for ('model2', 'model3') = 0.2800570520969998
# Fold 10 RMSLE for ('model2', 'model4') = 0.28663760615883516
# Fold 10 RMSLE for ('model3', 'model4') = 0.27951347136516264
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.2786411531171666
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.28241201686392514
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.278477030912153
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.28153764889478083
# Fold 10 RMSLE for all models ensemble = 0.28002217201925017
# Fold 10 best combination: model3 with RMSLE = 0.27566131357583507
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.2893356296776475
# Fold 11 RMSLE for model2 = 0.287640242962527
# Fold 11 RMSLE for model3 = 0.28836922999266185
# Fold 11 RMSLE for model4 = 0.2847598873333469
# Fold 11 RMSLE for ('model1', 'model2') = 0.2855612673852092
# Fold 11 RMSLE for ('model1', 'model3') = 0.2884783984246215
# Fold 11 RMSLE for ('model1', 'model4') = 0.2852146804992005
# Fold 11 RMSLE for ('model2', 'model3') = 0.2849948461914864
# Fold 11 RMSLE for ('model2', 'model4') = 0.28487669431862217
# Fold 11 RMSLE for ('model3', 'model4') = 0.2845456849607381
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.285614197559443
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.2845629423832701
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.28558720910468066
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.2841131591314266
# Fold 11 RMSLE for all models ensemble = 0.28465101275742427
# Fold 11 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.2841131591314266
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.2716281408081712
# Fold 12 RMSLE for model2 = 0.2695782398196862
# Fold 12 RMSLE for model3 = 0.2692144890916211
# Fold 12 RMSLE for model4 = 0.273133356390761
# Fold 12 RMSLE for ('model1', 'model2') = 0.26605879439030716
# Fold 12 RMSLE for ('model1', 'model3') = 0.2698732346639544
# Fold 12 RMSLE for ('model1', 'model4') = 0.26980567183242393
# Fold 12 RMSLE for ('model2', 'model3') = 0.2654390804593983
# Fold 12 RMSLE for ('model2', 'model4') = 0.26981984053032854
# Fold 12 RMSLE for ('model3', 'model4') = 0.2687206664204096
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.2660242715684853
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.26767144319358377
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.26880602013962
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.2671531399692106
# Fold 12 RMSLE for all models ensemble = 0.26698151468411296
# Fold 12 best combination: ('model2', 'model3') with RMSLE = 0.2654390804593983
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.27955916255713986
# Fold 13 RMSLE for model2 = 0.2760997253178631
# Fold 13 RMSLE for model3 = 0.2747350497080709
# Fold 13 RMSLE for model4 = 0.2769275825566632
# Fold 13 RMSLE for ('model1', 'model2') = 0.27476542831717826
# Fold 13 RMSLE for ('model1', 'model3') = 0.2766503815968548
# Fold 13 RMSLE for ('model1', 'model4') = 0.27617762309719757
# Fold 13 RMSLE for ('model2', 'model3') = 0.2721189377914038
# Fold 13 RMSLE for ('model2', 'model4') = 0.2754819544085639
# Fold 13 RMSLE for ('model3', 'model4') = 0.2734654694527066
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.273702131175239
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.27481047156764643
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.2748648962182774
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.27295239313552816
# Fold 13 RMSLE for all models ensemble = 0.27373605622989294
# Fold 13 best combination: ('model2', 'model3') with RMSLE = 0.2721189377914038
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.27894675650695433
# Fold 14 RMSLE for model2 = 0.2644524127388561
# Fold 14 RMSLE for model3 = 0.2757477066211944
# Fold 14 RMSLE for model4 = 0.269479752102608
# Fold 14 RMSLE for ('model1', 'model2') = 0.2685147799061011
# Fold 14 RMSLE for ('model1', 'model3') = 0.2769129058133074
# Fold 14 RMSLE for ('model1', 'model4') = 0.2722328443563443
# Fold 14 RMSLE for ('model2', 'model3') = 0.26729569175931767
# Fold 14 RMSLE for ('model2', 'model4') = 0.2657453797259234
# Fold 14 RMSLE for ('model3', 'model4') = 0.27063302224326036
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.2701617385584934
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.2681407603979051
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.2727612748339866
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.2672283205836123
# Fold 14 RMSLE for all models ensemble = 0.26924932659341566
# Fold 14 best combination: model2 with RMSLE = 0.2644524127388561
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.2694885302699759
# Fold 15 RMSLE for model2 = 0.2664224140966261
# Fold 15 RMSLE for model3 = 0.2674750033088661
# Fold 15 RMSLE for model4 = 0.2684138122510732
# Fold 15 RMSLE for ('model1', 'model2') = 0.2660207363090481
# Fold 15 RMSLE for ('model1', 'model3') = 0.26790973485137076
# Fold 15 RMSLE for ('model1', 'model4') = 0.26738861038139766
# Fold 15 RMSLE for ('model2', 'model3') = 0.26443541340167637
# Fold 15 RMSLE for ('model2', 'model4') = 0.2661111634387206
# Fold 15 RMSLE for ('model3', 'model4') = 0.26563995795778045
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.26556321929925614
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.2659686958245585
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.26647338986099056
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.2647131047443445
# Fold 15 RMSLE for all models ensemble = 0.26539268914359926
# Fold 15 best combination: ('model2', 'model3') with RMSLE = 0.26443541340167637
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.29996546072611596
# Fold 16 RMSLE for model2 = 0.30371179545378835
# Fold 16 RMSLE for model3 = 0.2978222986546159
# Fold 16 RMSLE for model4 = 0.3036435357897432
# Fold 16 RMSLE for ('model1', 'model2') = 0.3000071312816694
# Fold 16 RMSLE for ('model1', 'model3') = 0.2984033457583189
# Fold 16 RMSLE for ('model1', 'model4') = 0.30017829648464894
# Fold 16 RMSLE for ('model2', 'model3') = 0.29882426928792816
# Fold 16 RMSLE for ('model2', 'model4') = 0.30260896962308403
# Fold 16 RMSLE for ('model3', 'model4') = 0.29847056292430046
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.29860378788755687
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.30042662391440267
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.29850890874563435
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.2993901563734147
# Fold 16 RMSLE for all models ensemble = 0.29897378234583183
# Fold 16 best combination: model3 with RMSLE = 0.2978222986546159
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.27996793326880576
# Fold 17 RMSLE for model2 = 0.2792064943632309
# Fold 17 RMSLE for model3 = 0.27923061875728167
# Fold 17 RMSLE for model4 = 0.2804479212358185
# Fold 17 RMSLE for ('model1', 'model2') = 0.27744643313717055
# Fold 17 RMSLE for ('model1', 'model3') = 0.2790508211513754
# Fold 17 RMSLE for ('model1', 'model4') = 0.2788827686474219
# Fold 17 RMSLE for ('model2', 'model3') = 0.27693841776961114
# Fold 17 RMSLE for ('model2', 'model4') = 0.2782868704108886
# Fold 17 RMSLE for ('model3', 'model4') = 0.2777094747291689
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.2772578251640764
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.2776618322255141
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.27810362272034733
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.27698655454729854
# Fold 17 RMSLE for all models ensemble = 0.2772284147341313
# Fold 17 best combination: ('model2', 'model3') with RMSLE = 0.27693841776961114
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.27464836459773767
# Fold 18 RMSLE for model2 = 0.2681172305672802
# Fold 18 RMSLE for model3 = 0.27480583872679165
# Fold 18 RMSLE for model4 = 0.2729564876439668
# Fold 18 RMSLE for ('model1', 'model2') = 0.2686889971558769
# Fold 18 RMSLE for ('model1', 'model3') = 0.27426510890154426
# Fold 18 RMSLE for ('model1', 'model4') = 0.2719512223038719
# Fold 18 RMSLE for ('model2', 'model3') = 0.2686935114883583
# Fold 18 RMSLE for ('model2', 'model4') = 0.26936101859823197
# Fold 18 RMSLE for ('model3', 'model4') = 0.2718807861259659
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.2698787218178314
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.26937897604969635
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.2722021725699253
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.2693242000937534
# Fold 18 RMSLE for all models ensemble = 0.2698918575935047
# Fold 18 best combination: model2 with RMSLE = 0.2681172305672802
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.28745528324739883
# Fold 19 RMSLE for model2 = 0.2828794226106484
# Fold 19 RMSLE for model3 = 0.28558022662980476
# Fold 19 RMSLE for model4 = 0.2909289742981342
# Fold 19 RMSLE for ('model1', 'model2') = 0.28304969722094003
# Fold 19 RMSLE for ('model1', 'model3') = 0.2861405716512374
# Fold 19 RMSLE for ('model1', 'model4') = 0.2879343950516834
# Fold 19 RMSLE for ('model2', 'model3') = 0.2819744679861824
# Fold 19 RMSLE for ('model2', 'model4') = 0.28566292641787594
# Fold 19 RMSLE for ('model3', 'model4') = 0.28657746257190053
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.28319947572776505
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.2850132881679343
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.2865277153953185
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.28414231399760703
# Fold 19 RMSLE for all models ensemble = 0.2844687025035522
# Fold 19 best combination: ('model2', 'model3') with RMSLE = 0.2819744679861824
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.2736699567307283
# Fold 20 RMSLE for model2 = 0.2697118667705711
# Fold 20 RMSLE for model3 = 0.2713347923066186
# Fold 20 RMSLE for model4 = 0.2734614643702608
# Fold 20 RMSLE for ('model1', 'model2') = 0.2697007724032883
# Fold 20 RMSLE for ('model1', 'model3') = 0.2720122902874559
# Fold 20 RMSLE for ('model1', 'model4') = 0.2721764040886565
# Fold 20 RMSLE for ('model2', 'model3') = 0.26822663790673945
# Fold 20 RMSLE for ('model2', 'model4') = 0.27023092224941364
# Fold 20 RMSLE for ('model3', 'model4') = 0.27056612264945584
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.26946505500209633
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.27015425375927016
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.27117196408108446
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.2690590737787036
# Fold 20 RMSLE for all models ensemble = 0.26970088364276257
# Fold 20 best combination: ('model2', 'model3') with RMSLE = 0.26822663790673945
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.2728434430288287
# Fold 21 RMSLE for model2 = 0.2783524724296971
# Fold 21 RMSLE for model3 = 0.2734191453308443
# Fold 21 RMSLE for model4 = 0.2781388020839391
# Fold 21 RMSLE for ('model1', 'model2') = 0.2726597223669915
# Fold 21 RMSLE for ('model1', 'model3') = 0.2725254595083895
# Fold 21 RMSLE for ('model1', 'model4') = 0.2732817330432928
# Fold 21 RMSLE for ('model2', 'model3') = 0.27238483998781693
# Fold 21 RMSLE for ('model2', 'model4') = 0.27697618641981964
# Fold 21 RMSLE for ('model3', 'model4') = 0.2726808869538372
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.2716755354686217
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.27362722460852434
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.2721317307921449
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.27317786981686576
# Fold 21 RMSLE for all models ensemble = 0.2722710344957945
# Fold 21 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.2716755354686217
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.2822500637038922
# Fold 22 RMSLE for model2 = 0.2750588258395446
# Fold 22 RMSLE for model3 = 0.2798533288299893
# Fold 22 RMSLE for model4 = 0.27912309376754446
# Fold 22 RMSLE for ('model1', 'model2') = 0.2753954338948121
# Fold 22 RMSLE for ('model1', 'model3') = 0.2805856177682197
# Fold 22 RMSLE for ('model1', 'model4') = 0.27868194617016884
# Fold 22 RMSLE for ('model2', 'model3') = 0.2738826523364487
# Fold 22 RMSLE for ('model2', 'model4') = 0.2758329813354401
# Fold 22 RMSLE for ('model3', 'model4') = 0.2768151242392652
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.2757343516725597
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.2759338884775632
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.27809774960960376
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.2747202519696381
# Fold 22 RMSLE for all models ensemble = 0.2757492891901072
# Fold 22 best combination: ('model2', 'model3') with RMSLE = 0.2738826523364487
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.2831975874850136
# Fold 23 RMSLE for model2 = 0.2799690337936286
# Fold 23 RMSLE for model3 = 0.28493341139084444
# Fold 23 RMSLE for model4 = 0.27928717645584633
# Fold 23 RMSLE for ('model1', 'model2') = 0.27941081249116645
# Fold 23 RMSLE for ('model1', 'model3') = 0.2835242313146816
# Fold 23 RMSLE for ('model1', 'model4') = 0.2794344035977812
# Fold 23 RMSLE for ('model2', 'model3') = 0.27995407466708166
# Fold 23 RMSLE for ('model2', 'model4') = 0.2784530322107545
# Fold 23 RMSLE for ('model3', 'model4') = 0.27995014746508207
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.2803723154668307
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.2785486708121358
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.28045620491874323
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.2788174832045229
# Fold 23 RMSLE for all models ensemble = 0.2792641516368946
# Fold 23 best combination: ('model2', 'model4') with RMSLE = 0.2784530322107545
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.2589694413627515
# Fold 24 RMSLE for model2 = 0.25533085405269024
# Fold 24 RMSLE for model3 = 0.26064057939020535
# Fold 24 RMSLE for model4 = 0.2610047997059823
# Fold 24 RMSLE for ('model1', 'model2') = 0.2553866318780665
# Fold 24 RMSLE for ('model1', 'model3') = 0.2591284080784738
# Fold 24 RMSLE for ('model1', 'model4') = 0.25869719468415986
# Fold 24 RMSLE for ('model2', 'model3') = 0.2557168310143722
# Fold 24 RMSLE for ('model2', 'model4') = 0.25690860015417416
# Fold 24 RMSLE for ('model3', 'model4') = 0.25841899927366263
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.25622195697920724
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.25652005624290436
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.25824086734368645
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.25638272632125186
# Fold 24 RMSLE for all models ensemble = 0.25657513889065037
# Fold 24 best combination: model2 with RMSLE = 0.25533085405269024
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.2784167782975783
# Fold 25 RMSLE for model2 = 0.27739762214901775
# Fold 25 RMSLE for model3 = 0.2768000237336878
# Fold 25 RMSLE for model4 = 0.2782088031657055
# Fold 25 RMSLE for ('model1', 'model2') = 0.2758082875519654
# Fold 25 RMSLE for ('model1', 'model3') = 0.27709481864769797
# Fold 25 RMSLE for ('model1', 'model4') = 0.27679194417789604
# Fold 25 RMSLE for ('model2', 'model3') = 0.27468502445945003
# Fold 25 RMSLE for ('model2', 'model4') = 0.27643816148805156
# Fold 25 RMSLE for ('model3', 'model4') = 0.27552628430888354
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.27530326577306075
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.27579407434379954
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.2760086328053939
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.2749042845518424
# Fold 25 RMSLE for all models ensemble = 0.27522360438620996
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.27468502445945003
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.26610529433166497
# Fold 26 RMSLE for model2 = 0.26188436685105093
# Fold 26 RMSLE for model3 = 0.26872853739510455
# Fold 26 RMSLE for model4 = 0.2608320432993188
# Fold 26 RMSLE for ('model1', 'model2') = 0.26147815181504874
# Fold 26 RMSLE for ('model1', 'model3') = 0.2669065903522869
# Fold 26 RMSLE for ('model1', 'model4') = 0.26182916409434026
# Fold 26 RMSLE for ('model2', 'model3') = 0.26250701982982916
# Fold 26 RMSLE for ('model2', 'model4') = 0.2600921651030102
# Fold 26 RMSLE for ('model3', 'model4') = 0.2623936920945901
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.2629695368341564
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.26054907356357837
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.263174456338767
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.2609660574832191
# Fold 26 RMSLE for all models ensemble = 0.26160609448918914
# Fold 26 best combination: ('model2', 'model4') with RMSLE = 0.2600921651030102
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.25048252619718137
# Fold 27 RMSLE for model2 = 0.24400124656424046
# Fold 27 RMSLE for model3 = 0.25097215223475633
# Fold 27 RMSLE for model4 = 0.2448470910087843
# Fold 27 RMSLE for ('model1', 'model2') = 0.24507093917128328
# Fold 27 RMSLE for ('model1', 'model3') = 0.2503187525975586
# Fold 27 RMSLE for ('model1', 'model4') = 0.2465710928267293
# Fold 27 RMSLE for ('model2', 'model3') = 0.2452133237516937
# Fold 27 RMSLE for ('model2', 'model4') = 0.243104969281882
# Fold 27 RMSLE for ('model3', 'model4') = 0.24660173454680792
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.24634406159463262
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.24440648435811327
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.24752261798765732
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.24442840354695236
# Fold 27 RMSLE for all models ensemble = 0.24544050465543243
# Fold 27 best combination: ('model2', 'model4') with RMSLE = 0.243104969281882
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.2663778986881785
# Fold 28 RMSLE for model2 = 0.27220661135203555
# Fold 28 RMSLE for model3 = 0.2640873717242617
# Fold 28 RMSLE for model4 = 0.2698436638301549
# Fold 28 RMSLE for ('model1', 'model2') = 0.2660871310166388
# Fold 28 RMSLE for ('model1', 'model3') = 0.2647852833458512
# Fold 28 RMSLE for ('model1', 'model4') = 0.26633289896889734
# Fold 28 RMSLE for ('model2', 'model3') = 0.26525005657452116
# Fold 28 RMSLE for ('model2', 'model4') = 0.2697857173386757
# Fold 28 RMSLE for ('model3', 'model4') = 0.26504557031110376
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.26454781714164904
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.26674122418998447
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.2649033512862054
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.2660264206839469
# Fold 28 RMSLE for all models ensemble = 0.26522256095291424
# Fold 28 best combination: model3 with RMSLE = 0.2640873717242617
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.27754581896061326
# Fold 29 RMSLE for model2 = 0.2832379835942544
# Fold 29 RMSLE for model3 = 0.28291069151796905
# Fold 29 RMSLE for model4 = 0.2771454492813135
# Fold 29 RMSLE for ('model1', 'model2') = 0.27817355614448197
# Fold 29 RMSLE for ('model1', 'model3') = 0.2796326851801469
# Fold 29 RMSLE for ('model1', 'model4') = 0.27588699912211445
# Fold 29 RMSLE for ('model2', 'model3') = 0.28060644306068394
# Fold 29 RMSLE for ('model2', 'model4') = 0.27882545381315643
# Fold 29 RMSLE for ('model3', 'model4') = 0.27784632405500415
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.27889048413751416
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.2770640762886151
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.27732931472026934
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.2784206729746824
# Fold 29 RMSLE for all models ensemble = 0.277642208713015
# Fold 29 best combination: ('model1', 'model4') with RMSLE = 0.27588699912211445
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.2947713598267272
# Fold 30 RMSLE for model2 = 0.2884052232876795
# Fold 30 RMSLE for model3 = 0.29384298558128913
# Fold 30 RMSLE for model4 = 0.3012635172255839
# Fold 30 RMSLE for ('model1', 'model2') = 0.29008765940947384
# Fold 30 RMSLE for ('model1', 'model3') = 0.2937061189081754
# Fold 30 RMSLE for ('model1', 'model4') = 0.29721725917196695
# Fold 30 RMSLE for ('model2', 'model3') = 0.2891173437943625
# Fold 30 RMSLE for ('model2', 'model4') = 0.2935956594240204
# Fold 30 RMSLE for ('model3', 'model4') = 0.2961590861954291
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.2905265336536871
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.29324894437858573
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.2953900925095998
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.29245746499175473
# Fold 30 RMSLE for all models ensemble = 0.29270357653366236
# Fold 30 best combination: model2 with RMSLE = 0.2884052232876795
# ---------------
#
# OOF RMSLE = 0.2768086395511259
# Sum of RMSLE for each combination:
# ('model1',): 8.452070977036334
# ('model2',): 8.372262339103997
# ('model3',): 8.435391108753501
# ('model4',): 8.427802140304305
# ('model1', 'model2'): 8.33744031214349
# ('model1', 'model3'): 8.428733725591659
# ('model1', 'model4'): 8.390925237041968
# ('model2', 'model3'): 8.323042579629302
# ('model2', 'model4'): 8.36240949304144
# ('model3', 'model4'): 8.367414767564556
# ('model1', 'model2', 'model3'): 8.343381699443146
# ('model1', 'model2', 'model4'): 8.346020617136952
# ('model1', 'model3', 'model4'): 8.38099289116369
# ('model2', 'model3', 'model4'): 8.331063463431407
# ('model1', 'model2', 'model3', 'model4'): 8.341405279420588

# %%
train_df = train_df.reset_index(drop=True)
train_df.iloc[:, -1]
# Out:
# 0         52,973
# 1         55,910
# 2         55,680
# 3         61,412
# 4         43,100
#           ...
# 7158     549,795
# 7159     113,768
# 7160     141,266
# 7161     259,996
# 7162   1,293,278
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 7163, dtype: float64

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(train_target)
log_oof_predictions = np.log1p(train_preds)
# 差の計算
diff = abs(log_target - log_oof_predictions)
# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線の描画
min_val = min(log_target.min(), log_oof_predictions.min())
max_val = max(log_target.max(), log_oof_predictions.max())
plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='y = x')  # 45度線


# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)
# 凡例の設定
plt.legend(title='Difference > 0.7')

# プロットの表示
plt.tight_layout()
plt.show()

# %%
test_preds.max()
# Out:
# 2248839.996275968

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
# Step 1: Optuna の Objective 関数
def objective(trial, train_preds, train_target):

    low_sho = trial.suggest_float("low_sho", 9, 11),
    higt_sho = trial.suggest_float("higt_sho", 12, 15),
    low_x = trial.suggest_float("low_x", 80, 120)
    higt_x = trial.suggest_float("higt_x", 80, 120)
    for i in range(len(train_preds)):
        if train_preds[i] < np.expm1(low_sho):
            train_preds[i] = np.expm1(np.log1p(train_preds[i])*100/low_x)

        if train_preds[i] > np.expm1(higt_sho):
            train_preds[i] = np.expm1(np.log1p(train_preds[i])*100/higt_x)
    final_RMSLE = np.sqrt(mean_squared_log_error(target, oof_predictions))
    return final_RMSLE

study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, train_preds, train_target), n_trials=1000)
print("Best trial:")
trial = study.best_trial
print(f"  Value: {trial.value}")
print("  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2024-11-24 13:29:21,031] A new study created in memory with name: no-name-bf2fb467-dd48-46ac-a841-afe59573b743
# [I 2024-11-24 13:29:21,158] Trial 0 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.27612266112804, 'higt_sho': 12.534894179473389, 'low_x': 115.8997055824514, 'higt_x': 90.9321547456308}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,221] Trial 1 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.441940270051244, 'higt_sho': 12.612839524171658, 'low_x': 119.86040311561894, 'higt_x': 86.35252653854069}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,282] Trial 2 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.295336679320213, 'higt_sho': 12.049933416278684, 'low_x': 106.16414968447185, 'higt_x': 100.40911092204361}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,343] Trial 3 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.290876588495824, 'higt_sho': 12.266457752125142, 'low_x': 114.3390830989307, 'higt_x': 112.7084732474359}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,406] Trial 4 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.697038642477562, 'higt_sho': 14.5719265486731, 'low_x': 109.24820086623225, 'higt_x': 118.1703323057528}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,483] Trial 5 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.667475211019731, 'higt_sho': 13.222036227301432, 'low_x': 110.0144144076998, 'higt_x': 96.118694422425}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,558] Trial 6 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.275003801551485, 'higt_sho': 13.19660651196961, 'low_x': 103.3442524035835, 'higt_x': 97.64847657975064}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,627] Trial 7 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.945029280021586, 'higt_sho': 12.44147541625488, 'low_x': 85.51936823050765, 'higt_x': 107.67835949266654}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,687] Trial 8 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.432692378091255, 'higt_sho': 13.214947723297222, 'low_x': 94.55469149409765, 'higt_x': 104.66276581024044}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,748] Trial 9 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.821679807159956, 'higt_sho': 13.418356898243353, 'low_x': 85.83859465141423, 'higt_x': 108.64028974648875}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,830] Trial 10 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.953198057572395, 'higt_sho': 14.601612506707294, 'low_x': 96.08108177129878, 'higt_x': 81.57982533303326}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,910] Trial 11 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.019938954365744, 'higt_sho': 12.694017056790095, 'low_x': 118.55546877054563, 'higt_x': 86.92403627877493}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:21,986] Trial 12 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.415206355682392, 'higt_sho': 12.746900136455565, 'low_x': 119.65262792071894, 'higt_x': 89.6151532904637}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,068] Trial 13 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.131391680073245, 'higt_sho': 14.0501427102033, 'low_x': 113.94393493110034, 'higt_x': 89.613179371409}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,151] Trial 14 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.499242744902558, 'higt_sho': 13.835930721646585, 'low_x': 114.6303961438581, 'higt_x': 80.29713749004779}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,233] Trial 15 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.074302534613679, 'higt_sho': 12.81432973644219, 'low_x': 119.37799090467732, 'higt_x': 93.1890628087014}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,310] Trial 16 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.524346464547477, 'higt_sho': 12.426543598372074, 'low_x': 100.68229816551829, 'higt_x': 85.15207487031313}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,394] Trial 17 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.029373189710075, 'higt_sho': 12.013614785384945, 'low_x': 109.04646442783354, 'higt_x': 91.77447753928773}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,491] Trial 18 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.155564881639387, 'higt_sho': 12.922408715671947, 'low_x': 91.24724294099629, 'higt_x': 85.0241778680767}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,584] Trial 19 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.67905931710899, 'higt_sho': 14.169837411140495, 'low_x': 113.60684797945915, 'higt_x': 102.43272164925042}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,664] Trial 20 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.285204414460237, 'higt_sho': 13.611201399848566, 'low_x': 105.39624355753325, 'higt_x': 95.93284230264058}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,747] Trial 21 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.310929045261991, 'higt_sho': 12.027039355597802, 'low_x': 105.07502737968527, 'higt_x': 99.59501033364064}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,827] Trial 22 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.611253767899903, 'higt_sho': 12.317096760176048, 'low_x': 111.3768066373015, 'higt_x': 93.93449881295587}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,908] Trial 23 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.204020271990466, 'higt_sho': 12.56519427759292, 'low_x': 115.96482122958912, 'higt_x': 101.52162813782775}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:22,991] Trial 24 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.412822944656492, 'higt_sho': 12.191173612524418, 'low_x': 80.61523758700501, 'higt_x': 88.63820297922243}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,078] Trial 25 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.841119654166567, 'higt_sho': 13.032407343825993, 'low_x': 108.12957710268725, 'higt_x': 82.79433242116684}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,160] Trial 26 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.140457156966628, 'higt_sho': 12.583984868088189, 'low_x': 116.2883743139802, 'higt_x': 98.41092550353869}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,240] Trial 27 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.427892950114337, 'higt_sho': 12.157871410790703, 'low_x': 100.90104483035236, 'higt_x': 92.12283002291039}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,320] Trial 28 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.774586524708997, 'higt_sho': 12.515959892499948, 'low_x': 111.85213294536261, 'higt_x': 105.14139467406488}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,408] Trial 29 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.606665637635622, 'higt_sho': 14.933958283691972, 'low_x': 117.17478151974238, 'higt_x': 117.48841407190076}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,499] Trial 30 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.304325220902154, 'higt_sho': 12.322924899496483, 'low_x': 106.11908411255877, 'higt_x': 112.61952096615016}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,587] Trial 31 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.313361357985384, 'higt_sho': 12.242169708939967, 'low_x': 112.55999152613207, 'higt_x': 119.64294712145299}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:23,964] Trial 32 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.59720966238574, 'higt_sho': 12.984445982041022, 'low_x': 107.93546964685751, 'higt_x': 115.79035353484527}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,372] Trial 33 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.215174364418118, 'higt_sho': 12.13543005176116, 'low_x': 117.14027001061312, 'higt_x': 112.56122318355575}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,606] Trial 34 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.93144530177756, 'higt_sho': 12.384029799239368, 'low_x': 110.41065139099666, 'higt_x': 95.73846506242502}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,698] Trial 35 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.677941950000633, 'higt_sho': 12.634320673685476, 'low_x': 102.48745413220469, 'higt_x': 108.26236000535273}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,777] Trial 36 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.503892987382747, 'higt_sho': 13.351260623998362, 'low_x': 119.93338682512872, 'higt_x': 111.92277101581051}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,855] Trial 37 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.340684938649451, 'higt_sho': 13.076916737266231, 'low_x': 115.76539048671793, 'higt_x': 104.7900031839299}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:24,933] Trial 38 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.862090923937032, 'higt_sho': 12.835281341921709, 'low_x': 96.50534042830529, 'higt_x': 83.86823210159204}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:25,019] Trial 39 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.198038496233734, 'higt_sho': 12.00930128497264, 'low_x': 117.7652062845091, 'higt_x': 86.3143560091946}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:25,349] Trial 40 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.005782220503098, 'higt_sho': 12.441024470431836, 'low_x': 110.26958303049551, 'higt_x': 88.04406154867517}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:25,861] Trial 41 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.717195507359207, 'higt_sho': 14.324137236566129, 'low_x': 114.2481261536705, 'higt_x': 117.85280293934034}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:25,998] Trial 42 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.421533336674662, 'higt_sho': 14.656799772251162, 'low_x': 106.27385931235509, 'higt_x': 114.7587437464132}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,078] Trial 43 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.530167369095116, 'higt_sho': 13.231674700676884, 'low_x': 112.81454031197411, 'higt_x': 110.25102027960493}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,166] Trial 44 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.069798339776463, 'higt_sho': 12.697592718184275, 'low_x': 98.63345177834974, 'higt_x': 118.84737704328366}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,272] Trial 45 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.870042219043455, 'higt_sho': 13.650916859918695, 'low_x': 103.49544770711361, 'higt_x': 116.06047110618154}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,350] Trial 46 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.232420643188048, 'higt_sho': 13.954077189301277, 'low_x': 114.69772065561126, 'higt_x': 90.91387585336018}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,467] Trial 47 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.55625706371564, 'higt_sho': 14.446153418271706, 'low_x': 109.16190677474621, 'higt_x': 106.70671774313975}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,554] Trial 48 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.367067525186568, 'higt_sho': 12.795443172889398, 'low_x': 118.46127780927648, 'higt_x': 114.23512477604116}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,632] Trial 49 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.08476939810065, 'higt_sho': 12.260237294956651, 'low_x': 89.87360510512462, 'higt_x': 102.4560551604918}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,728] Trial 50 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.119437655260617, 'higt_sho': 14.890485438368462, 'low_x': 107.51794581528428, 'higt_x': 94.32332034212094}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,808] Trial 51 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.661494609455556, 'higt_sho': 13.702665885708843, 'low_x': 110.78138755431303, 'higt_x': 97.45584461273997}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:26,909] Trial 52 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.498995756215102, 'higt_sho': 13.248166729350928, 'low_x': 114.85202152898249, 'higt_x': 80.42154025599038}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,016] Trial 53 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.752268010972093, 'higt_sho': 12.4976193818213, 'low_x': 112.56418991799134, 'higt_x': 90.42798142349133}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,114] Trial 54 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.299865269271663, 'higt_sho': 13.400938137522923, 'low_x': 109.24968269912821, 'higt_x': 100.62749170304025}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,196] Trial 55 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.469690021001425, 'higt_sho': 12.159621099943138, 'low_x': 118.68093093795379, 'higt_x': 95.9510455550659}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,275] Trial 56 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.597709066615034, 'higt_sho': 12.87114733251969, 'low_x': 104.83702466049975, 'higt_x': 85.8680644316711}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,374] Trial 57 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.247260621193814, 'higt_sho': 13.148920759174384, 'low_x': 115.84089377186281, 'higt_x': 88.21620714195254}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,477] Trial 58 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.010800067287166, 'higt_sho': 13.534755279593684, 'low_x': 113.62614706078146, 'higt_x': 92.57846738369005}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,562] Trial 59 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.809219416778141, 'higt_sho': 13.80594635970795, 'low_x': 103.83405256622439, 'higt_x': 110.5453686411825}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,645] Trial 60 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.929075339111277, 'higt_sho': 12.102997022429415, 'low_x': 111.70500032063528, 'higt_x': 84.01911961619506}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,735] Trial 61 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.378852801839777, 'higt_sho': 12.356918147104782, 'low_x': 101.94056426933774, 'higt_x': 98.88337147911871}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,819] Trial 62 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.152855386784408, 'higt_sho': 13.489715677917133, 'low_x': 98.81852969949752, 'higt_x': 103.08171043007286}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,904] Trial 63 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.454036461052231, 'higt_sho': 12.634592543967939, 'low_x': 106.35347059335585, 'higt_x': 96.72522824632232}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:27,987] Trial 64 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.329276259168253, 'higt_sho': 12.926649466269668, 'low_x': 109.45405277360562, 'higt_x': 94.84597076716194}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,077] Trial 65 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.255805992035295, 'higt_sho': 12.733395474566812, 'low_x': 117.00885517630155, 'higt_x': 100.31443379563596}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,170] Trial 66 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.445539559508912, 'higt_sho': 12.248380910630598, 'low_x': 107.61494828221413, 'higt_x': 106.47990043398852}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,250] Trial 67 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.65045204780613, 'higt_sho': 14.141528873021873, 'low_x': 119.29953844903899, 'higt_x': 90.27057810556525}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,332] Trial 68 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.290603248634142, 'higt_sho': 13.313100352462339, 'low_x': 106.73492891273675, 'higt_x': 97.7568394868357}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,453] Trial 69 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.56721797967049, 'higt_sho': 13.094708852270253, 'low_x': 104.28192329706033, 'higt_x': 87.09838193548691}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,547] Trial 70 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.084954045817186, 'higt_sho': 12.091655246982103, 'low_x': 81.425597492144, 'higt_x': 82.35289752247266}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,648] Trial 71 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.145280183251735, 'higt_sho': 12.487927502697456, 'low_x': 86.99757521849769, 'higt_x': 108.89495857604679}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,806] Trial 72 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.001166696043871, 'higt_sho': 12.3979310154545, 'low_x': 96.10420091859186, 'higt_x': 114.07097682400473}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:28,982] Trial 73 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.924796441328679, 'higt_sho': 12.570258148593265, 'low_x': 83.91170395348601, 'higt_x': 93.35953141689943}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,136] Trial 74 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.178264985873964, 'higt_sho': 12.350568581711306, 'low_x': 91.147571362378, 'higt_x': 103.69432410915074}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,277] Trial 75 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.703141535384168, 'higt_sho': 12.209671295378909, 'low_x': 101.37546681030858, 'higt_x': 116.67195490622953}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,420] Trial 76 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.689167468441248, 'higt_sho': 12.646217606638968, 'low_x': 93.4157955255707, 'higt_x': 91.70061143381356}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,564] Trial 77 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.872050299496992, 'higt_sho': 12.282020071664022, 'low_x': 115.24694377715873, 'higt_x': 119.8283649815556}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,700] Trial 78 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.389825805795105, 'higt_sho': 12.94572214329601, 'low_x': 105.38611155148885, 'higt_x': 99.0975057077784}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,849] Trial 79 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.05781608522095, 'higt_sho': 12.036572324806286, 'low_x': 103.29786143674933, 'higt_x': 111.7720818079581}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:29,988] Trial 80 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.290396284574848, 'higt_sho': 12.45397138504852, 'low_x': 99.66760494846447, 'higt_x': 101.10918715171769}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,144] Trial 81 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.359832873192826, 'higt_sho': 13.211855034343683, 'low_x': 86.39549234811788, 'higt_x': 105.86749011329728}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,293] Trial 82 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.50312217352568, 'higt_sho': 13.007957616065022, 'low_x': 97.50635512299436, 'higt_x': 107.82324754752328}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,441] Trial 83 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.18970384782431, 'higt_sho': 12.791367171160212, 'low_x': 89.01533404128118, 'higt_x': 104.38022961973999}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,585] Trial 84 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.659042332441146, 'higt_sho': 13.476835542771404, 'low_x': 108.49835628518622, 'higt_x': 101.88208634265958}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,725] Trial 85 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.238471972363332, 'higt_sho': 13.124249205289393, 'low_x': 83.97992386352948, 'higt_x': 89.37667405257676}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:30,875] Trial 86 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.35409792144288, 'higt_sho': 13.286483705768017, 'low_x': 110.6136119421263, 'higt_x': 99.7531755190722}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,018] Trial 87 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.442118262709414, 'higt_sho': 13.396063414878679, 'low_x': 93.4702910206766, 'higt_x': 95.38460236951151}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,166] Trial 88 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.497109533345608, 'higt_sho': 12.544773063858951, 'low_x': 112.87840282516807, 'higt_x': 107.27140713768604}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,302] Trial 89 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.207863354370955, 'higt_sho': 14.549106440449144, 'low_x': 117.38949143742441, 'higt_x': 109.2941384112909}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,447] Trial 90 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.346195524855997, 'higt_sho': 12.865015606012053, 'low_x': 118.17609990915135, 'higt_x': 110.5659556359522}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,583] Trial 91 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.796380469330208, 'higt_sho': 13.7477253280519, 'low_x': 84.95362935944813, 'higt_x': 97.35989482723757}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,726] Trial 92 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.736248895090274, 'higt_sho': 13.551053944359678, 'low_x': 94.28704087823537, 'higt_x': 104.99893166707488}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:31,874] Trial 93 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.860698112552443, 'higt_sho': 13.877065329884188, 'low_x': 81.00303024913575, 'higt_x': 109.4117775732438}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,024] Trial 94 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.955714454205069, 'higt_sho': 13.167060128209526, 'low_x': 88.20249921227077, 'higt_x': 112.90675979824769}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,187] Trial 95 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.627438271584106, 'higt_sho': 13.370659091579238, 'low_x': 81.7523401283504, 'higt_x': 118.41639028775343}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,333] Trial 96 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.82450356494961, 'higt_sho': 13.640574447442905, 'low_x': 102.78377348861544, 'higt_x': 106.07901077542657}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,484] Trial 97 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.440042556996328, 'higt_sho': 13.44659822632292, 'low_x': 109.7423296613664, 'higt_x': 103.78837448078659}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,628] Trial 98 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.090978816100867, 'higt_sho': 13.584134631578012, 'low_x': 116.37201088653485, 'higt_x': 96.67491527820066}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,780] Trial 99 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.776194758067122, 'higt_sho': 14.316967987393307, 'low_x': 111.50264036144287, 'higt_x': 115.27011586386932}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:32,938] Trial 100 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.971003921814027, 'higt_sho': 12.305346060945231, 'low_x': 82.54940541022688, 'higt_x': 111.31605903271131}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,098] Trial 101 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.262775118574389, 'higt_sho': 14.755427049497392, 'low_x': 107.1888453658634, 'higt_x': 82.06795840260732}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,247] Trial 102 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.88782718523234, 'higt_sho': 13.064462183033369, 'low_x': 119.92450883662096, 'higt_x': 81.47536945902243}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,391] Trial 103 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.79380730176329, 'higt_sho': 14.52467383023676, 'low_x': 113.83923574757073, 'higt_x': 80.26766398724584}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,484] Trial 104 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.695626642301697, 'higt_sho': 14.784214021310543, 'low_x': 95.60868968651626, 'higt_x': 84.2596125792398}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,566] Trial 105 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.545685842929414, 'higt_sho': 12.168427273172737, 'low_x': 91.01828041868657, 'higt_x': 107.27574666063278}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,649] Trial 106 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.891538249134607, 'higt_sho': 14.991213103114552, 'low_x': 85.77567749145027, 'higt_x': 87.43365660155057}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,736] Trial 107 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.04184111646486, 'higt_sho': 14.325804387368475, 'low_x': 99.96245456328802, 'higt_x': 85.19016719251032}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,819] Trial 108 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.753790852419508, 'higt_sho': 12.051207348005764, 'low_x': 104.60771393558977, 'higt_x': 93.77180179860711}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,904] Trial 109 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.399863664948757, 'higt_sho': 12.44471890238933, 'low_x': 92.0071899312025, 'higt_x': 113.5973867825591}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:33,991] Trial 110 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.053065758126987, 'higt_sho': 13.313623599718962, 'low_x': 105.73219667397028, 'higt_x': 102.24766553492144}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,092] Trial 111 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.1617941605822, 'higt_sho': 12.6958293066116, 'low_x': 118.46761616577749, 'higt_x': 88.80451404786574}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,176] Trial 112 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.107448186081324, 'higt_sho': 12.368928506949622, 'low_x': 119.13206004514785, 'higt_x': 87.09773156478529}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,263] Trial 113 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.212915298592065, 'higt_sho': 12.601289833353238, 'low_x': 108.41880312907197, 'higt_x': 86.29232238687388}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,346] Trial 114 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.117293181862802, 'higt_sho': 13.202902347792655, 'low_x': 116.00521808391076, 'higt_x': 98.14588545150434}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,445] Trial 115 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.962827762981952, 'higt_sho': 12.498816021682769, 'low_x': 97.52057802631424, 'higt_x': 91.7247976458152}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,545] Trial 116 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.602222130144321, 'higt_sho': 14.631651551928497, 'low_x': 116.77400025716842, 'higt_x': 92.58050179216424}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,628] Trial 117 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.28695881840576, 'higt_sho': 12.760509231354119, 'low_x': 87.45180145748287, 'higt_x': 108.24591541670048}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,713] Trial 118 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.011545099588314, 'higt_sho': 12.70834683563069, 'low_x': 115.08341274304067, 'higt_x': 83.40257177222428}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,795] Trial 119 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.32202179837401, 'higt_sho': 14.023093079896167, 'low_x': 112.33292895233934, 'higt_x': 94.51454012645873}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,898] Trial 120 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.498264114783497, 'higt_sho': 12.199500446006768, 'low_x': 100.86562424133557, 'higt_x': 90.94901252361201}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:34,985] Trial 121 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.548291493810796, 'higt_sho': 12.607297458341495, 'low_x': 117.63346982069503, 'higt_x': 89.55202449749478}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,069] Trial 122 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.350990313101553, 'higt_sho': 13.01031686398256, 'low_x': 119.86607843187194, 'higt_x': 85.82447811824296}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,169] Trial 123 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.46584294399954, 'higt_sho': 12.663030394871226, 'low_x': 118.76956498108021, 'higt_x': 88.714359695345}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,254] Trial 124 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.40828144653177, 'higt_sho': 12.552051951513972, 'low_x': 117.89716871779876, 'higt_x': 117.21495723966345}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,340] Trial 125 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.754877012223394, 'higt_sho': 12.886798960938506, 'low_x': 114.67602036066596, 'higt_x': 87.79751132160276}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,429] Trial 126 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.896714738122618, 'higt_sho': 12.417375942254813, 'low_x': 101.94381667571223, 'higt_x': 98.87526422948265}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,523] Trial 127 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.582515331034331, 'higt_sho': 12.095442442953438, 'low_x': 113.3726759596406, 'higt_x': 84.96935817430744}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,611] Trial 128 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.66299697439271, 'higt_sho': 12.828796867126647, 'low_x': 116.6378170263094, 'higt_x': 90.27529196066591}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,694] Trial 129 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.248474879893475, 'higt_sho': 13.261694309587302, 'low_x': 115.59025577516135, 'higt_x': 81.23699620088864}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,777] Trial 130 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.123517008602546, 'higt_sho': 13.440469443107899, 'low_x': 89.99738682599063, 'higt_x': 105.35106631811374}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,865] Trial 131 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.185608596018039, 'higt_sho': 14.39509373667874, 'low_x': 110.85795333928051, 'higt_x': 89.51978648862999}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:35,950] Trial 132 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.03542989682627, 'higt_sho': 14.727576150592206, 'low_x': 117.45008973419007, 'higt_x': 96.37538533765293}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,036] Trial 133 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.827446780225138, 'higt_sho': 14.215503948028521, 'low_x': 84.39438148888117, 'higt_x': 90.93515671615917}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,130] Trial 134 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.098645533804977, 'higt_sho': 14.863737164857364, 'low_x': 114.16999496317653, 'higt_x': 103.13387463918508}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,225] Trial 135 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.14075037255278, 'higt_sho': 14.587805762086438, 'low_x': 83.20846081900477, 'higt_x': 86.85689058000516}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,309] Trial 136 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.072749553334528, 'higt_sho': 14.038917755049154, 'low_x': 119.47572009513425, 'higt_x': 92.85462435180919}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,397] Trial 137 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.37794112017792, 'higt_sho': 13.341356902620838, 'low_x': 85.71415175546156, 'higt_x': 100.64220836863169}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,498] Trial 138 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.988370118948676, 'higt_sho': 12.283691463680093, 'low_x': 112.0212608760302, 'higt_x': 95.35289454597194}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,579] Trial 139 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.313313940399732, 'higt_sho': 12.512119628993315, 'low_x': 95.1808648000414, 'higt_x': 109.87898000862491}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,662] Trial 140 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.231173735318624, 'higt_sho': 14.484005559283533, 'low_x': 98.71493261734634, 'higt_x': 88.52928710159776}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,745] Trial 141 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.533961498807257, 'higt_sho': 13.844013035397587, 'low_x': 113.2770715273776, 'higt_x': 80.85827662036048}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,827] Trial 142 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.417455734549353, 'higt_sho': 12.963880810288732, 'low_x': 109.73178682716298, 'higt_x': 82.79533500900774}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:36,935] Trial 143 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.620526831015447, 'higt_sho': 13.67451952119072, 'low_x': 118.50437484622269, 'higt_x': 81.99414009074981}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,033] Trial 144 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.722150132661827, 'higt_sho': 14.209896062902326, 'low_x': 114.57998260776402, 'higt_x': 115.9969743581847}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,117] Trial 145 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.461067065162128, 'higt_sho': 13.504090508504897, 'low_x': 107.6343743550456, 'higt_x': 85.69030325883215}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,221] Trial 146 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.024568263597498, 'higt_sho': 13.156172496605397, 'low_x': 115.93736978235509, 'higt_x': 108.58678427299097}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,305] Trial 147 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.627712564371416, 'higt_sho': 13.737813763281434, 'low_x': 106.8257745917372, 'higt_x': 83.68041757389811}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,392] Trial 148 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.435130287603037, 'higt_sho': 13.929487835571898, 'low_x': 92.71432427306536, 'higt_x': 111.19821796231305}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,496] Trial 149 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.261428402551395, 'higt_sho': 14.664675719777797, 'low_x': 111.24535162661796, 'higt_x': 80.00851010255047}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,580] Trial 150 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.299940128107366, 'higt_sho': 12.772508119143634, 'low_x': 96.81662581801564, 'higt_x': 112.685531217792}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,683] Trial 151 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.782085601202605, 'higt_sho': 12.645852757221292, 'low_x': 80.16601713018864, 'higt_x': 91.57278512328992}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,770] Trial 152 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.392890023080575, 'higt_sho': 12.71203099622871, 'low_x': 119.46302601775758, 'higt_x': 97.2178153197622}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,854] Trial 153 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.168126120400672, 'higt_sho': 13.09339587612797, 'low_x': 116.97777284343375, 'higt_x': 93.20530025767819}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:37,946] Trial 154 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.985577805371951, 'higt_sho': 12.453694722119282, 'low_x': 118.02738604961522, 'higt_x': 93.84591887064175}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,038] Trial 155 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.34903739300206, 'higt_sho': 12.584821327831785, 'low_x': 103.80225513726776, 'higt_x': 89.91324374497778}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,123] Trial 156 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.516022930687638, 'higt_sho': 12.352527280816142, 'low_x': 118.98299769102704, 'higt_x': 106.68942239524664}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,228] Trial 157 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.93793083584398, 'higt_sho': 14.09279217378756, 'low_x': 105.1942176103018, 'higt_x': 118.98210248122393}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,325] Trial 158 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.327081572821607, 'higt_sho': 12.808789392769453, 'low_x': 119.98866598034823, 'higt_x': 91.10832418280302}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,413] Trial 159 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.546106584209081, 'higt_sho': 13.229836274923068, 'low_x': 115.49771886429815, 'higt_x': 92.2115564385629}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,511] Trial 160 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.277756683297197, 'higt_sho': 12.906622290586933, 'low_x': 116.46693556823013, 'higt_x': 99.54247057714704}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,597] Trial 161 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.560039837803657, 'higt_sho': 12.545037330352512, 'low_x': 99.66554365533412, 'higt_x': 84.73027725237512}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,684] Trial 162 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.48246869192839, 'higt_sho': 12.000858691715536, 'low_x': 102.83902154320461, 'higt_x': 87.84067017671153}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,769] Trial 163 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.373829026460964, 'higt_sho': 12.400772299492802, 'low_x': 100.73072064466515, 'higt_x': 101.40933337961378}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,860] Trial 164 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.185494204576338, 'higt_sho': 12.22820479714924, 'low_x': 101.98728671724585, 'higt_x': 86.65415387835253}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:38,950] Trial 165 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.67249761451571, 'higt_sho': 12.310280394119946, 'low_x': 113.75832519313585, 'higt_x': 89.23190269993412}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,037] Trial 166 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.430906780412695, 'higt_sho': 12.48352123804214, 'low_x': 118.65591522195034, 'higt_x': 104.45917620549535}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,124] Trial 167 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.002615804992798, 'higt_sho': 13.4180592146412, 'low_x': 105.87642557549846, 'higt_x': 115.06821763602431}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,218] Trial 168 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.850891210849284, 'higt_sho': 12.707609941327899, 'low_x': 97.94062844273249, 'higt_x': 98.32708353856674}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,315] Trial 169 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.851740060130592, 'higt_sho': 13.592870108393843, 'low_x': 112.65811475372648, 'higt_x': 82.80799126420476}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,403] Trial 170 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.222791980717558, 'higt_sho': 14.40756627261077, 'low_x': 117.41147670070431, 'higt_x': 94.58613653717671}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,516] Trial 171 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.054238929719912, 'higt_sho': 12.638429867177075, 'low_x': 108.10969243681453, 'higt_x': 90.31957329273257}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,600] Trial 172 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.08226099105776, 'higt_sho': 12.20109449653017, 'low_x': 109.02868065555907, 'higt_x': 92.11848537193063}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,683] Trial 173 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.11321314892503, 'higt_sho': 12.133231767429866, 'low_x': 87.64101932825793, 'higt_x': 95.85710722246193}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,768] Trial 174 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.133803206140854, 'higt_sho': 12.14901669567275, 'low_x': 109.08690589479889, 'higt_x': 88.21567385854847}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,855] Trial 175 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.035482259545384, 'higt_sho': 13.362259647988271, 'low_x': 104.28143389665948, 'higt_x': 80.92054656527635}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:39,941] Trial 176 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.580813634067196, 'higt_sho': 13.300139964445782, 'low_x': 111.69369226224067, 'higt_x': 107.7106485307513}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:40,025] Trial 177 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.647257501867463, 'higt_sho': 12.045200591699006, 'low_x': 119.99767937797515, 'higt_x': 91.2807197935196}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:40,128] Trial 178 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.520692952734924, 'higt_sho': 12.538790166617938, 'low_x': 109.8508195559018, 'higt_x': 85.41269562157983}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:40,214] Trial 179 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.43285457172012, 'higt_sho': 13.051566178658588, 'low_x': 110.35676641686146, 'higt_x': 113.76175761644535}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:40,315] Trial 180 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.064493136014363, 'higt_sho': 12.426199953072729, 'low_x': 85.29698056997316, 'higt_x': 105.54641769124206}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:29:40,408] Trial 181 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.196817161231074, 'higt_sho': 12.838546962742111, 'low_x': 91.8142721885956, 'higt_x': 86.29421813729044}. Best is trial 0 with value: 0.2768086395511259.
# ...
# [I 2024-11-24 13:31:11,271] Trial 940 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.441092218315081, 'higt_sho': 14.5655032076483, 'low_x': 119.46379148470066, 'higt_x': 96.9281806344198}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:11,384] Trial 941 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.168259513337686, 'higt_sho': 12.846885959242634, 'low_x': 83.83535726139945, 'higt_x': 84.81029629949425}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:11,508] Trial 942 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.661522871469401, 'higt_sho': 12.064470060994468, 'low_x': 116.65030127104751, 'higt_x': 114.17859076020842}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:11,617] Trial 943 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.527905170267216, 'higt_sho': 13.928766440394194, 'low_x': 113.21107299003364, 'higt_x': 102.01022850587847}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:11,727] Trial 944 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.137011412956317, 'higt_sho': 12.497288363831293, 'low_x': 108.14371393705169, 'higt_x': 95.30793068413536}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:11,840] Trial 945 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.301491037447894, 'higt_sho': 12.782676080127361, 'low_x': 101.54280673830795, 'higt_x': 82.14579414056922}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,043] Trial 946 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.50975788914837, 'higt_sho': 13.354560974003489, 'low_x': 115.67300571732733, 'higt_x': 89.56919080443063}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,221] Trial 947 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.611885882912572, 'higt_sho': 12.00087578444608, 'low_x': 104.11241986601185, 'higt_x': 87.49456896300062}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,407] Trial 948 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.244832821123357, 'higt_sho': 12.282107700866552, 'low_x': 111.05647716673144, 'higt_x': 99.3776059632382}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,605] Trial 949 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.024627041675313, 'higt_sho': 13.637146850641406, 'low_x': 119.42069404132546, 'higt_x': 91.06073235594998}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,782] Trial 950 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.064892159622591, 'higt_sho': 12.159516188705425, 'low_x': 119.92439232116627, 'higt_x': 88.4831286100711}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:12,969] Trial 951 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.947224491876995, 'higt_sho': 13.000103388163769, 'low_x': 117.8701280730561, 'higt_x': 94.27341552903121}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:13,158] Trial 952 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.222648811892343, 'higt_sho': 12.408462230137335, 'low_x': 97.36787946330575, 'higt_x': 97.81147907119845}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:13,410] Trial 953 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.407191617960976, 'higt_sho': 12.679683528640403, 'low_x': 109.30903290275272, 'higt_x': 117.9214637074178}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:13,599] Trial 954 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.125116674635967, 'higt_sho': 14.40587352026015, 'low_x': 114.55479965524329, 'higt_x': 86.33717433327811}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:13,778] Trial 955 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.48051875338881, 'higt_sho': 12.561200991265107, 'low_x': 85.9563238878115, 'higt_x': 89.95587795902907}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:13,996] Trial 956 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.325030216250052, 'higt_sho': 13.243483600405028, 'low_x': 114.06666333061727, 'higt_x': 100.08050710729157}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:14,212] Trial 957 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.575405757491417, 'higt_sho': 12.938384861511299, 'low_x': 115.16776862940236, 'higt_x': 96.10079105299427}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:14,391] Trial 958 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.158049104826363, 'higt_sho': 13.495354162342444, 'low_x': 105.741930030568, 'higt_x': 84.00952296624449}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:14,635] Trial 959 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.639449533326712, 'higt_sho': 12.317180180024843, 'low_x': 89.60265511739514, 'higt_x': 80.8852105743979}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:14,811] Trial 960 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.919757020712341, 'higt_sho': 13.856148585997119, 'low_x': 102.95623266608726, 'higt_x': 101.34752931128179}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,013] Trial 961 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.36779140729131, 'higt_sho': 12.213029182862686, 'low_x': 118.58433357433584, 'higt_x': 92.98501049561332}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,206] Trial 962 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.032622121920932, 'higt_sho': 12.08945699697088, 'low_x': 84.5250492341477, 'higt_x': 87.07182373724211}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,395] Trial 963 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.279800807780028, 'higt_sho': 14.150181614728204, 'low_x': 113.1534880551059, 'higt_x': 98.51704173449232}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,581] Trial 964 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.255458280622937, 'higt_sho': 14.02141048610155, 'low_x': 100.26207016233815, 'higt_x': 103.34361745451592}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,771] Trial 965 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.777143470321352, 'higt_sho': 13.105530667339652, 'low_x': 117.23493881005895, 'higt_x': 85.54332166177682}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:15,971] Trial 966 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.44814292517269, 'higt_sho': 13.573240394829837, 'low_x': 116.2987503932415, 'higt_x': 92.07196957987561}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:16,163] Trial 967 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.188922143170284, 'higt_sho': 14.678404625852183, 'low_x': 104.98869539474659, 'higt_x': 95.3648989924617}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:16,366] Trial 968 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.773872148683319, 'higt_sho': 12.47514713170219, 'low_x': 98.73457027937297, 'higt_x': 87.90876645419719}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:16,560] Trial 969 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.107909560040014, 'higt_sho': 12.635641669010175, 'low_x': 111.91274012384932, 'higt_x': 90.2552883031974}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:16,749] Trial 970 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.223123274873123, 'higt_sho': 12.72091157063483, 'low_x': 109.79785223084818, 'higt_x': 116.11926474520361}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:16,914] Trial 971 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.561297834187963, 'higt_sho': 12.879938137317113, 'low_x': 92.78900825058466, 'higt_x': 91.22114173097094}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,027] Trial 972 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.400275560023177, 'higt_sho': 13.303172757202079, 'low_x': 88.5007910386757, 'higt_x': 111.03526185945796}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,142] Trial 973 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.842360527369818, 'higt_sho': 13.427103453292435, 'low_x': 118.99174893128813, 'higt_x': 96.7568520823734}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,272] Trial 974 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.08941844007478, 'higt_sho': 12.347416614622162, 'low_x': 106.98264043643603, 'higt_x': 106.25214893443965}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,383] Trial 975 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.693781371818824, 'higt_sho': 13.77415429070546, 'low_x': 110.45094925879756, 'higt_x': 88.91762639177064}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,512] Trial 976 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.364531174488992, 'higt_sho': 12.583534550710395, 'low_x': 108.73465801026632, 'higt_x': 82.89142949065257}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,620] Trial 977 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.583043782598814, 'higt_sho': 12.788237135907613, 'low_x': 117.94565340014638, 'higt_x': 100.80151980591509}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,729] Trial 978 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.444720190572774, 'higt_sho': 12.056446674674172, 'low_x': 113.64139461618589, 'higt_x': 93.77150323759977}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,843] Trial 979 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.332531658166431, 'higt_sho': 14.750833560927664, 'low_x': 115.61510341550415, 'higt_x': 107.33724984163823}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:17,964] Trial 980 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.000458570516171, 'higt_sho': 12.140391988529938, 'low_x': 112.33108211999732, 'higt_x': 109.24915938883798}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,084] Trial 981 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.49150683968726, 'higt_sho': 12.416634440621603, 'low_x': 107.96334421879162, 'higt_x': 101.84214965708087}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,195] Trial 982 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.29621181694117, 'higt_sho': 12.24147330563793, 'low_x': 91.12669473143646, 'higt_x': 85.8292095215817}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,320] Trial 983 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.43887480410477, 'higt_sho': 13.16546629643927, 'low_x': 101.90758087603321, 'higt_x': 80.05436874572689}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,442] Trial 984 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.533378906661303, 'higt_sho': 14.524266109617999, 'low_x': 119.92974461305077, 'higt_x': 102.85960529198954}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,557] Trial 985 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.040607554302689, 'higt_sho': 12.519727353138586, 'low_x': 86.71216012842518, 'higt_x': 104.22945175331239}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,669] Trial 986 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.727148935042434, 'higt_sho': 12.000447786684312, 'low_x': 82.9716101334201, 'higt_x': 108.40616080795283}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,782] Trial 987 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.081789986547482, 'higt_sho': 12.696037932105016, 'low_x': 106.25602198653154, 'higt_x': 105.08182788150464}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:18,892] Trial 988 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.999481405247579, 'higt_sho': 12.44752152552465, 'low_x': 93.68568156994499, 'higt_x': 81.69406883168953}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,013] Trial 989 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.28017222956759, 'higt_sho': 12.540182242506726, 'low_x': 103.65599315955585, 'higt_x': 99.68907611438725}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,124] Trial 990 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.361142615968133, 'higt_sho': 14.258574779478781, 'low_x': 95.49587820170888, 'higt_x': 94.60914525236367}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,241] Trial 991 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.625103451112787, 'higt_sho': 13.716921873877308, 'low_x': 111.37822915019406, 'higt_x': 89.42391635607596}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,368] Trial 992 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.219770662890307, 'higt_sho': 12.758488615597845, 'low_x': 114.81426935138734, 'higt_x': 86.86177761249512}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,487] Trial 993 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.963199834608197, 'higt_sho': 12.109217029917644, 'low_x': 104.62852710595854, 'higt_x': 92.65901379978058}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,597] Trial 994 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.630590885494446, 'higt_sho': 13.381798436735396, 'low_x': 96.76352057974879, 'higt_x': 84.65367294470182}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,711] Trial 995 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.191933425314012, 'higt_sho': 12.304070218984226, 'low_x': 87.98990255355083, 'higt_x': 119.42525044363083}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,821] Trial 996 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.281241415732554, 'higt_sho': 13.036772841503367, 'low_x': 116.96448124243578, 'higt_x': 98.21463662110719}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:19,932] Trial 997 finished with value: 0.2768086395511259 and parameters: {'low_sho': 10.831480879657091, 'higt_sho': 12.831713268127805, 'low_x': 118.72215688090479, 'higt_x': 90.6207370946244}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:20,053] Trial 998 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.174984660428072, 'higt_sho': 12.57953687989868, 'low_x': 113.91400442257653, 'higt_x': 112.34942959632227}. Best is trial 0 with value: 0.2768086395511259.
# [I 2024-11-24 13:31:20,162] Trial 999 finished with value: 0.2768086395511259 and parameters: {'low_sho': 9.583387712195922, 'higt_sho': 12.20332395222654, 'low_x': 115.64102773294894, 'higt_x': 91.97741302896605}. Best is trial 0 with value: 0.2768086395511259.
# Best trial:
#   Value: 0.2768086395511259
#   Params:
#     low_sho: 9.27612266112804
#     higt_sho: 12.534894179473389
#     low_x: 115.8997055824514
#     higt_x: 90.9321547456308

# %%
def after_times(test_preds):
    for i in range(len(test_preds)):
        if test_preds[i] < np.expm1(9.27612266112804):
            test_preds[i] = np.expm1(np.log1p(test_preds[i])*100/115.8997055824514)

        if test_preds[i] > np.expm1(12.534894179473389):
            print(np.log1p(test_preds[i])*100/99)
            test_preds[i] = np.expm1(np.log1p(test_preds[i])*100/90.9321547456308)

    return test_preds
after_test_preds = after_times(test_preds)
# Out:
# 12.733339472345168
# 12.78273764416484
# 14.122876297225826
# 12.75435575335603
# 13.484353144464553
# 13.359358761845833
# 12.77536709123058
# 13.996051325062492
# 13.75821498706356
# 12.944984991976487
# 13.46859448972463
# 14.023699075883524
# 13.49666881445031
# 13.171433671728808
# 14.388035246413956
# 13.81138048137351
# 14.096677042426585
# 12.711997569504524
# 13.30934446330243
# 13.642779558821266
# 14.6665500705438
# 13.558304508096738
# 13.062937525298342
# 12.845938468174912
# 12.797362236835697
# 13.28284638409978
# 14.45550428732313
# 14.568933875072194
# 13.052949739590536
# 13.572756180513643
# 13.472519999890736
# 12.864122545887675
# 13.306025147218632
# 12.858686317200732
# 13.370461340930683
# 13.27313551354975
# 13.628706852505669
# 12.839183069342392
# 13.9138942347471
# 13.952285780307038
# 13.675360864198424
# 14.557959022514964
# 12.679681487163402
# 12.865017616892578
# 14.311038349909607
# 13.78030208568146
# 12.681722901034028
# 13.21038072304463
# 13.02330418587522
# 13.988940057911124
# 14.922891060808292
# 13.906864210053337
# 14.136044087280213
# 14.09060837926828
# 12.676285943928017
# 14.476982676150838
# 12.993453340180764
# 13.711522803495546
# 13.706266889844692
# 12.76606138652448
# 13.894216876814719
# 14.457802737978541
# 12.980606763772442
# 14.05423999519863
# 13.50938227362661
# 13.1464788832442
# 12.827014790554069
# 12.837738597862966
# 13.200230011469683
# 12.721433483054117
# 13.19942895603808
# 12.924791616410703
# 13.693912968012912
# 12.922507221711017
# 12.679027234495278
# 13.830003262142164
# 13.32958437848497
# 13.20166404961372
# 14.505772796678391
# 12.990097417715571
# 13.870736446413407
# 13.649037233414967
# 12.762271170731772
# 13.33832958722109
# 12.710325424652243
# 12.975827840662571
# 14.05034753854391
# 13.796979241145337
# 13.408348582406932
# 14.441574584259829
# 14.410256464580698
# 14.418254819678104
# 13.666934595731338
# 14.439527413184258
# 14.03178496213267
# 14.298134532752723
# 13.778794715921011
# 13.542155087209807
# 13.039932916196456
# 12.87786025615701
# 13.685189312607275
# 13.879925894262135
# 13.423370956678355
# 14.61375222716687
# 14.049219679510482
# 13.283896737324412
# 13.034905833443707
# 14.000623597642111
# 13.301445449239996
# 14.56687646916919
# 13.77763275950684
# 13.396979423447759
# 14.11906272959218
# 13.187579246153323
# 12.66702699176988
# 13.092016219943948
# 13.066316314689285
# 13.677263110810546
# 13.217477440055186
# 13.365379054394031
# 13.790143495851861
# 13.000324497089093
# 13.593577490750283
# 12.752880104422298
# 14.541799909266672
# 13.442738946913552
# 14.297373082358362
# 13.878369305316038
# 12.999473112040867
# 14.288651916998331
# 13.76120442098272
# 14.358976910370833
# 14.009913140976817
# 14.519923536989124
# 13.620397291447016
# 14.059728879931292
# 13.547580817852962
# 13.740047341319613
# 13.37369678451695
# 13.433020153837662
# 13.884829857972566
# 13.854982049851467
# 14.081657429771068
# 12.947980874334526
# 14.036394651993625
# 14.570583666337326
# 12.695019821062044
# 12.84310419019166
# 13.76047482205335
# 12.723065364898385
# 13.70583910334663
# 14.568869330513671
# 13.55031770884446
# 14.487935030648801
# 13.965509129761928
# 14.465425147603465
# 12.699486263953792
# 13.36683111186502
# 14.054993341340412
# 13.66687807842969
# 14.388342527965825
# 14.54516513121591
# 14.0927649857986
# 13.582313304835496
# 13.067612738065705
# 14.027529572871416
# 13.660397347397188
# 13.050730788370197
# 12.843913510591348
# 14.371851018662058
# 13.312214112978308
# 12.71181440002022
# 13.010424188836616
# 13.253630314992586
# 12.701337841939143
# 14.605740331933331
# 12.7750562914651
# 13.696382277589315
# 13.700535354053553
# 13.227170019942873
# 12.691161163189175
# 14.43714620909204
# 13.209062146286144
# 13.903598014741474
# 13.683060784856258
# 14.333680934084091
# 13.7226045217535
# 13.112724522776546
# 13.113722630917469
# 13.7928564668284
# 13.211632287797705
# 12.848238230729073
# 13.2034197824155
# 14.540752630805903
# 13.666658136779358
# 13.61323874793891
# 13.135348374639054
# 12.669928988132721
# 13.974561820695955
# 14.43262133961545
# 14.58362431426033
# 13.593257892962322
# 13.931511074641213
# 14.078695894140324
# 13.9520775998537
# 13.879636576147798
# 13.775409432801677
# 14.046315898606297
# 14.657329630108839
# 12.949313885490454
# 14.67122739159715
# 13.709088443637288
# 13.682243582064663
# 12.666150782046087
# 13.803322409986503
# 13.944359809818367
# 13.947296090390942
# 12.780969634739272
# 12.907606229274373
# 14.533772834792995
# 12.693828290396313
# 12.710892964356454
# 13.735338230714959
# 14.560144025730864
# 13.269467663386317
# 13.722452850421748
# 14.505453390384854
# 14.446936762930441
# 13.698354440488297
# 12.676368998735189
# 14.506319572674103
# 13.698476957391003
# 13.48475457290936
# 13.385190776066944
# 12.806123305641066
# 12.706216601735466
# 14.456043251352066
# 14.117195224645425
# 12.761123479097076
# 12.860556090882506
# 12.834431316693278
# 14.377319874039564
# 14.500423085293363
# 14.140659806150943
# 14.371918174960195
# 12.683525964547105
# 14.51750827638881
# 13.749376691321864
# 13.306420525864706
# 14.116834908717399
# 13.521957837093584
# 13.03743840250048
# 12.959030690237835
# 14.343252442620395
# 12.991539368883727
# 14.484277815484885
# 14.600067808391744
# 13.745547785371869
# 13.003873570761606
# 13.272032235759069
# 14.538346232660217
# 14.358482147001059
# 13.53581862158633
# 14.049572834385007
# 13.496355224602848
# 14.046704358932251
# 14.444085424979324
# 13.551850578538074
# 13.398931389832129
# 12.734490253039251
# 12.84687854556661
# 14.45788177369948
# 13.550199501296966
# 14.581285766135993
# 13.488720792890591
# 14.305873408633643
# 13.87884509291525
# 14.47582334433242
# 14.64378375214467
# 13.144160895393174
# 14.37571845369486
# 12.686806260769643
# 12.973628043764618
# 14.067961870805815
# 13.773749008086332
# 14.513543329579873
# 13.001368993564649
# 12.73597778219113
# 14.423265081873861
# 14.764013559125354
# 14.097520534835528
# 14.290853407301068
# 12.83089906971863
# 13.980688030891127
# 14.388112137145997
# 14.632797568706817
# 12.663939167882006
# 14.769126208739259
# 13.74654069869309
# 13.12747844342659
# 14.396524942515809
# 13.68245214494215
# 12.907085401202767
# 14.893935451228629
# 13.428602820809719
# 13.640253402848444
# 13.121473825982847
# 13.021836460546334
# 12.943685441085398
# 13.51988069740567
# 12.996399980952244
# 13.764292236004483
# 13.523531485108041
# 13.316711365637085
# 12.760451199109687
# 14.420521716189258
# 12.730414672535241
# 14.443178180891552
# 13.600683558284905
# 13.204877462423791
# 12.694606234104029
# 13.203240612225603
# 13.506442743098694
# 12.933316377134258
# 12.671103647179459
# 13.206619008974227
# 12.740937973065783
# 13.034801272592704
# 13.178966844854424
# 14.34457852232444
# 13.685828359565363
# 12.800630208496685
# 13.646894469863232
# 14.722254945241097
# 13.540598628719298
# 13.767620257431629
# 13.379121266680738
# 14.686784678864733
# 14.572424794883476
# 14.41571495078004
# 14.376783379959752
# 13.837434612659592
# 13.40853969821232
# 13.608060028780224
# 14.697975655811529
# 13.316205538108745
# 13.240079921458207
# 13.91491496050611
# 14.448033162758612
# 14.888778766339602
# 12.706049608819528
# 14.619678048769973
# 13.159647541025663
# 12.940681501774923
# 13.167794614683515
# 12.690918258069695
# 12.67286023680804
# 14.365368417398901
# 12.868429576498853
# 13.015692533399276
# 14.424551291942612
# 14.363317658124105
# 13.932042083488296
# 14.450062904872928
# 13.703507583250207
# 13.093487635537558
# 14.103542565384306
# 13.324377084921924
# 14.764201960105193
# 12.93406364243217
# 13.486999072088715
# 14.084300101254668
# 12.695044625965004
# 12.91754782154716
# 13.706730370148156
# 13.567653816400897
# 13.441564763237952
# 12.96765791503145
# 14.058558063575854
# 13.817682014365767
# 13.047306160816959
# 14.595397157844463
# 13.610670365040923
# 14.290776708714304
# 13.041145666708362
# 13.587862066551052
# 14.527916996722022
# 12.87928281336239
# 13.21579647788404
# 14.065482717896108
# 14.575692093322655
# 14.122421474795804
# 14.286764772373001
# 13.483956493206788
# 12.691029942904686
# 13.882847842275357
# 13.785042123009545
# 13.219902497620255
# 13.858551671991977
# 12.720321677553994
# 13.956924623790075
# 14.530207511608838
# 12.910463527078985
# 13.914688072799763
# 13.390943999062612
# 13.311961322743064
# 13.488600022484906
# 13.94922969040437
# 14.411213563462269
# 13.740121091287618
# 14.062636493330986
# 13.289034256311211
# 14.369528942948024

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=train_preds, y=train_target, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--')  # 45度線
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156                 # so that we can inject the orientation
#    2157                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2158                     self.figure.draw(renderer)
#    2159             if bbox_inches:
#    2160                 if bbox_inches == "tight":
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3152
#    3153                 self.patch.draw(renderer)
# -> 3154                 mimage._draw_list_compositing_images(
#    3155                     renderer, self, artists, self.suppressComposite)
#    3156
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3068             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3069
# -> 3070         mimage._draw_list_compositing_images(
#    3071             renderer, self, artists, self.figure.suppressComposite)
#    3072
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1385         renderer.open_group(__name__, gid=self.get_gid())
#    1386
# -> 1387         ticks_to_draw = self._update_ticks()
#    1388         tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1389
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1274         """
#    1275         major_locs = self.get_majorticklocs()
# -> 1276         major_labels = self.major.formatter.format_ticks(major_locs)
#    1277         major_ticks = self.get_major_ticks(len(major_locs))
#    1278         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in format_ticks(self, values)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in <listcomp>(.0)
#     214         """Return the tick labels for all the ticks at once."""
#     215         self.set_locs(values)
# --> 216         return [self(value, i) for i, value in enumerate(values)]
#     217
#     218     def format_data(self, value):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in __call__(self, x, pos)
#    1064         # only label the decades
#    1065         fx = math.log(x) / math.log(b)
# -> 1066         is_x_decade = _is_close_to_int(fx)
#    1067         exponent = round(fx) if is_x_decade else np.floor(fx)
#    1068         coeff = round(b ** (fx - exponent))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/ticker.py in _is_close_to_int(x)
#    2237
#    2238 def _is_close_to_int(x):
# -> 2239     return math.isclose(x, round(x))
#    2240
#    2241
#
# OverflowError: cannot convert float infinity to integer

# %%
test_preds.shape
# Out:
# (2508,)

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_38.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,384
# 1     4656 1,048,728
# 2     4657    41,244
# 3     4658    30,041
# 4     4659    47,426
# ...    ...       ...
# 2503  7158 1,920,483
# 2504  7159   101,406
# 2505  7160   134,966
# 2506  7161   259,370
# 2507  7162 6,227,265
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 4,760,728
# 23    4678 2,375,541
# 32    4687 2,073,298
# 43    4698 4,146,743
# 61    4716 3,200,750
# ...    ...       ...
# 2490  7145 6,516,389
# 2493  7148 3,138,314
# 2500  7155 4,458,517
# 2503  7158 1,920,483
# 2507  7162 6,227,265
#
# [364 rows x 2 columns]

# %%
test_df.iloc[:, -1]
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 2503    1
# 2504    1
# 2505    0
# 2506    0
# 2507    1
# Name: num_missing, Length: 2508, dtype: int64

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 5983                          NaN                          NaN
# 5984                          NaN                          NaN
# 5985                       23,592                       25,069
# 5986                      140,816                       93,119
# 5987                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 5983                          NaN           240
# 5984                          NaN             4
# 5985                       24,560           132
# 5986                      130,327            98
# 5987                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 5983                                 110,523
# 5984                                     NaN
# 5985                                 166,520
# 5986                                  71,774
# 5987                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 5983                                  98,955
# 5984                                     NaN
# 5985                                 469,733
# 5986                                 936,032
# 5987                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 5983                               3,467,008
# 5984                                     NaN
# 5985                                  82,559
# 5986                                 336,961
# 5987                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 5983                                 147,802        39        -76
# 5984                                     NaN        31       -102
# 5985                                  85,775        41        -96
# 5986                                 156,640        39        -93
# 5987                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 5983                              NaN                              NaN
# 5984                              NaN                              NaN
# 5985                              636                            1,477
# 5986                           16,356                          -47,698
# 5987                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 5983                              NaN                               NaN
# 5984                              NaN                               NaN
# 5985                             -509                                 0
# 5986                           37,208                                 0
# 5987                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 5983                               NaN                               NaN
# 5984                               NaN                               NaN
# 5985                                 0                                -0
# 5986                                -0                                 0
# 5987                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 5983                1            1                                   549,795
# 5984                9            1                                   113,768
# 5985                8            0                                   141,266
# 5986                8            0                                   259,996
# 5987                9            1                                 1,293,278
#
# [5988 rows x 19 columns]

# %%
# show_plot(np.exp(oof_predictions), np.exp(target))
show_plot(oof_predictions, target, "oof_predictions, target")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(test_preds),
          "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(test_preds),
          "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
show_plot(train_df.iloc[:, -1], train_preds, "train_df.iloc[:, -1], train_preds")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-ad083e09b4d1> in <cell line: 9>()
#       7 show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(test_preds),
#       8           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# ----> 9 show_plot(train_df.iloc[:, -1], train_preds, "train_df.iloc[:, -1], train_preds")
#
# <ipython-input-228-8f67023728a6> in show_plot(test_preds, target, title)
#      11
#      12 # test_preds のヒストグラム
# ---> 13     sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)
#      14
#      15 # target のヒストグラム
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     668             ]).reset_index(drop=True)
#     669             thin_bar_idx = hist_metadata["widths"].idxmin()
# --> 670             binwidth = hist_metadata.loc[thin_bar_idx, "widths"]
#     671             left_edge = hist_metadata.loc[thin_bar_idx, "edges"]
#     672
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    4219             #  results if our categories are integers that dont match our codes
#    4220             # IntervalIndex: IntervalTree has no get_loc
# -> 4221             row = self.index.get_loc(index)
#    4222             return series._values[row]
#    4223
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: nan

# %%
show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
