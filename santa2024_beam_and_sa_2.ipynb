# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/santa_2024/santa2024_beam_and_sa_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# このノートブックは以下のノートブックを参考にして作成されました。
#
# この場を借りてノートブックを共有してくださったことに感謝したいと思います。
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# また、以下のノートブックを利用してid4以外の答えを作成しています。ありがとうございます。
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# This notebook was created with reference to the following notebook:
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# I would like to take this opportunity to express my gratitude to the author for sharing their notebook.
#
# Additionally, I used the following notebook to generate answers other than id4. Thank you very much.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# 이 노트북은 다음 노트북을 참고하여 작성되었습니다.
#
# 이 자리를 빌려 노트북을 공유해 주신 것에 대해 감사드립니다.
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# 또한, 아래 노트북을 사용하여 id4 이외의 답변을 작성했습니다. 감사합니다.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# このノートブックはGPU環境下で実行に3時間程度かかります。実行される際は注意してください。
#
# 元ノートブックからの変更点として、ビーム幅を可変にしています。
#
# これにより、重要な局面で多くの情報を残すことができます。

# %% [markdown]
# This notebook takes approximately 3 hours to run in a GPU environment. Please be cautious when executing it.
#
# As a modification from the original notebook, the beam width has been made adjustable.
#
# This allows for retaining more information during critical stages.

# %% [markdown]
# 이 노트북은 GPU 환경에서 실행하는 데 약 3시간 정도 소요됩니다. 실행 시 유의하시기 바랍니다.
#
# 원본 노트북에서의 변경점으로, 빔 폭을 가변적으로 설정하였습니다.
#
# 이를 통해 중요한 국면에서 더 많은 정보를 남길 수 있습니다.

# %%
print("Yes")
# Out:
# Yes

# %%
# !pip install accelerate peft bitsandbytes transformers
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.27.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 33.6 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
import gc
import os
import time
import math
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch
import heapq
from tqdm import tqdm

import random
import statistics
from collections import Counter
from dataclasses import dataclass
from typing import Any, Callable, List, Optional, Tuple, Union

import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import bitsandbytes
from pprint import pprint

# %%
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class HuggingFaceModelLoader:
    def __init__(self, model_path: str, load_in_8bit: bool, device_map: str):
        self.model_path = model_path
        self.load_in_8bit = load_in_8bit
        self.device_map = device_map

    def load_model(self) -> transformers.PreTrainedModel:
        if self.load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires a CUDA device')

            quantization_config = transformers.BitsAndBytesConfig(
                load_in_4bit=True,
                bnb_4bit_quant_type="fp4",
                bnb_4bit_use_double_quant=False,
                bnb_4bit_compute_dtype=torch.float16,
            )

            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                quantization_config=quantization_config,
                device_map=self.device_map
            )
        else:
            model = transformers.AutoModelForCausalLM.from_pretrained(
                self.model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=self.device_map
            )

        model.eval()
        return model


class HuggingFaceTokenizer:
    def __init__(self, model_path: str):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path, padding_side="right")
        self.bos_token = self.tokenizer.bos_token or self.tokenizer.cls_token
        self.eos_token = self.tokenizer.eos_token or self.tokenizer.sep_token
        if self.bos_token is None:
            self.bos_token = ""
        if self.eos_token is None:
            self.eos_token = ""

    def tokenize(self, texts: List[str]) -> dict:
        processed_texts = []

        for text in texts:
            combined_text = f"{self.bos_token}{text}{self.eos_token}"
            processed_texts.append(combined_text)

        model_inputs = self.tokenizer(
            processed_texts,
            return_tensors='pt',
            add_special_tokens=False,
            padding=True
        )

        if 'token_type_ids' in model_inputs:
            model_inputs.pop('token_type_ids')

        return model_inputs


class PerplexityCalculator:
    def __init__(self, model_loader, tokenizer, exp_mode=False):
        self.model = model_loader.load_model()
        self.tokenizer = tokenizer
        self.exp_mode = exp_mode
        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

    def get_perplexity(
        self,
        input_texts: Union[str, List[str]],
        batch_size: int = 32
    ) -> Union[float, List[float]]:

        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        num_texts = len(input_texts)
        batches = num_texts // batch_size + (num_texts % batch_size != 0)
        with torch.no_grad():
            for j in range(batches):
                start_idx = j * batch_size
                end_idx = (j + 1) * batch_size
                input_batch = input_texts[start_idx:end_idx]

                with torch.no_grad():
                    model_inputs = self.tokenizer.tokenize(input_batch)
                    model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                    output = self.model(**model_inputs, use_cache=False)
                    logits = output['logits']

                    label = model_inputs['input_ids']
                    if hasattr(self.model.config, 'pad_token_id') and self.model.config.pad_token_id is not None:
                        label[label == self.model.config.pad_token_id] = PAD_TOKEN_LABEL_ID

                    shift_logits = logits[..., :-1, :].contiguous()
                    shift_labels = label[..., 1:].contiguous()

                    token_loss = self.loss_fct(
                        shift_logits.view(-1, shift_logits.size(-1)),
                        shift_labels.view(-1)
                    ).view(len(logits), -1)

                    valid_length = (shift_labels != PAD_TOKEN_LABEL_ID).sum(dim=-1)
                    sequence_loss = torch.sum(token_loss, -1) / valid_length
                    loss_list.extend(sequence_loss.cpu().tolist())

        if self.exp_mode:
            ppl = [exp(i) for i in loss_list]
        else:
            ppl = loss_list

        return ppl[0] if single_input else ppl

# %%
import os
from google.colab import userdata
import os

# Hugging Faceのトークンを環境変数に設定
os.environ["HF_TOKEN"] = "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"

# %%
from huggingface_hub import HfApi, hf_hub_download
import os
from multiprocessing import Pool

# Specify your model repository
model_name = "google/gemma-2-9b"

# Create a directory to store the downloaded model files
download_dir = "/content/model"
os.makedirs(download_dir, exist_ok=True)

# Initialize API
api = HfApi()

# Get the list of all files in the repository
files = api.list_repo_files(model_name)

# **Your Hugging Face token**
hf_token = "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"  # ここにあなたのHugging Faceトークンを入力してください

def download_file(file_path):
    try:
        # Download each file to the specified directory with token
        hf_hub_download(
            repo_id=model_name,
            filename=file_path,
            local_dir=download_dir,
            token=hf_token
        )
        print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {file_path}: {e}")

# Use multiprocessing to download files in parallel
if __name__ == "__main__":
    with Pool(processes=8) as pool:  # Adjust the number of processes based on Colab limits
        pool.map(download_file, files)
# Out:
# Downloaded .gitattributes
# Downloaded config.json
# Downloaded README.md
# Downloaded generation_config.json
# model-00005-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00006-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00007-of-00008.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00008-of-00008.safetensors:   0%|          | 0.00/2.38G [00:00<?, ?B/s]
# Downloaded model-00008-of-00008.safetensors
# model.safetensors.index.json:   0%|          | 0.00/39.1k [00:00<?, ?B/s]
# Downloaded model.safetensors.index.json
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloaded special_tokens_map.json
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Downloaded tokenizer.json
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# Downloaded tokenizer.model
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# Downloaded tokenizer_config.json
# (…)ransformers-4.42.0.dev0-py3-none-any.whl:   0%|          | 0.00/9.21M [00:00<?, ?B/s]
# Downloaded transformers/transformers-4.42.0.dev0-py3-none-any.whl
# Downloaded model-00002-of-00008.safetensors
# Downloaded model-00007-of-00008.safetensors
# Downloaded model-00006-of-00008.safetensors
# Downloaded model-00003-of-00008.safetensors
# Downloaded model-00005-of-00008.safetensors
# Downloaded model-00001-of-00008.safetensors
# Downloaded model-00004-of-00008.safetensors

# %%
model_path = "/content/model"
model_loader = HuggingFaceModelLoader(model_path=model_path, load_in_8bit=False, device_map='auto')
tokenizer = HuggingFaceTokenizer(model_path)
scorer = PerplexityCalculator(model_loader, tokenizer, exp_mode=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
class BeamSearch:
    def __init__(self, beam_width, scorer: PerplexityCalculator):
        self.beam_width = beam_width
        self.scorer = scorer

    def _make_candidates_adding_word(self, intermediate_solution, words):
        """
        Make candidate text so that word duplication does not occur
        """
        candidates = []
        not_used_words = words.copy()

        for used_word in intermediate_solution.split():
            if used_word in not_used_words:
                not_used_words.remove(used_word)

        # Generate candidates by adding unused words to the end
        candidates += [(intermediate_solution + ' ' + word).strip() for word in not_used_words]

        # Generate candidates by adding unused words to the beginning
        candidates += [(word + ' ' + intermediate_solution).strip() for word in not_used_words]

        # Remove duplicates
        candidates = list(set(candidates))

        return candidates

    def _select_new_intermediate_solutions(self, scored_candidates):
        """
        Select top candidates based on beam width while ensuring diversity.
        Include candidates with scores within a diversity threshold (e.g., 1.1 times the best score).
        """

        # Best (lowest) score among all candidates
        best_score = scored_candidates[0][0]

        # To track unique candidates and their scores
        seen = set()
        new_intermediate_solutions = []
        selected_scores = []

        for score, candidate in scored_candidates:
            if candidate in seen:
                continue

            # Add candidate if it meets the diversity threshold
            if score > 1.1 * best_score:
                break  # Stop adding candidates if diversity threshold is exceeded

            # Add the candidate and its score
            new_intermediate_solutions.append(candidate)
            selected_scores.append(score)
            seen.add(candidate)

            # Stop when beam width is reached
            if len(new_intermediate_solutions) >= self.beam_width:
                break

        return new_intermediate_solutions, selected_scores

    def _print_progress(self, intermediate_solutions, current_scores, start_time, words):
        """
        Print progress during the beam search process.
        """
        # Best (lowest) score in current iteration
        best_score = exp(min(current_scores))

        # Count of used and remaining words
        used_word_count = len(intermediate_solutions[0].split())
        remaining_word_count = len(words) - used_word_count

        # Time elapsed for this iteration
        elapsed = time.time() - start_time
        estimated_remaining_time = remaining_word_count * elapsed

        # Print progress
        print("===== Beam Search Progress =====")
        print(f"Best Score (Perplexity): {best_score:.4f}")
        print(f"Intermediate Solutions: {intermediate_solutions}")
        print(f"Words Processed: {used_word_count}/{len(words)}")
        print(f"Estimated Remaining Time: {estimated_remaining_time:.2f} seconds")
        print("================================\n")

    def solve(self, text, batch_size=32):
        words = text.split()
        intermediate_solutions = ['']
        eval_cnt = 0

        # Loop until all words are used in the intermediate solution
        while len(intermediate_solutions[0].split()) < len(words):
            start_time = time.time()
            candidates = []

            for intermediate_solution in intermediate_solutions:
                new_candidates = self._make_candidates_adding_word(intermediate_solution, words)
                for candidate in new_candidates:
                    candidates.append(candidate)

           # Remove duplicate candidates
            candidates = list(set(candidates))
            scores = self.scorer.get_perplexity(candidates, batch_size=batch_size)

            eval_cnt += len(scores)
            scored_candidates = sorted(zip(scores, candidates), key=lambda x: x[0] )

            intermediate_solutions, current_scores = self._select_new_intermediate_solutions(scored_candidates)

            self._print_progress(intermediate_solutions, current_scores, start_time, words)

        return current_scores, intermediate_solutions, eval_cnt

# %%
params = {
    'beam_width': 20,
    'scorer': scorer
}
optimizer = BeamSearch(**params)

# %%
Score = float
Solution = str

# Timer start
start_time = time.time()

# Initialize lists to store results
scores: List[Score] = []
solutions: List[Solution] = []
eval_cnts: List[int] = []

'''
The following code is executed only once.
Since my beam search does not involve randomness, running it multiple times will not produce new solutions.

아래 코드는 한 번만 실행됩니다.
제 빔 서치는 무작위성이 없기 때문에 몇 번 실행해도 새로운 해답이 생성되지 않습니다.
'''
text: str = "sleigh of the magi yuletide cheer is unwrap gifts relax and eat cheer decorations carol sing chimney visit workshop grinch holiday holly jingle naughty nice nutcracker polar beard ornament stocking"
score_results, solution_results, eval_cnt = optimizer.solve(text, batch_size=10)  #
scores.extend(score_results)
solutions.extend(solution_results)
eval_cnts.append(eval_cnt)

# Print the results
print("Scores:", [exp(i) for i in scores])
print("Solutions:", solutions)
print("Evaluation Counts:", eval_cnts)

# Measure and print execution time
execute_time: float = time.time() - start_time
print(f"Execution Time: {execute_time:.2f} seconds")
# Out:
# ===== Beam Search Progress =====
# Best Score (Perplexity): 9110.5421
# Intermediate Solutions: ['yuletide']
# Words Processed: 1/30
# Estimated Remaining Time: 162.41 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 1338.3847
# Intermediate Solutions: ['ornament yuletide', 'sleigh yuletide', 'jingle yuletide', 'magi yuletide']
# Words Processed: 2/30
# Estimated Remaining Time: 214.19 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 629.7434
# Intermediate Solutions: ['ornament yuletide holiday', 'ornament yuletide decorations', 'ornament yuletide nutcracker', 'ornament yuletide unwrap', 'ornament yuletide gifts', 'ornament yuletide holly', 'sleigh yuletide holiday', 'ornament yuletide of']
# Words Processed: 3/30
# Estimated Remaining Time: 752.54 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 434.5099
# Intermediate Solutions: ['ornament yuletide holiday decorations', 'ornament yuletide decorations holiday', 'ornament yuletide holiday gifts', 'ornament yuletide holiday nutcracker', 'ornament yuletide nutcracker holiday', 'ornament yuletide of the', 'ornament yuletide holiday holly', 'ornament yuletide gifts holiday', 'sleigh yuletide holiday decorations', 'ornament yuletide holiday unwrap', 'ornament yuletide holiday cheer', 'ornament yuletide decorations gifts', 'ornament yuletide unwrap holiday', 'ornament yuletide of decorations', 'ornament yuletide holly and', 'sleigh yuletide holiday ornament', 'ornament yuletide of holiday', 'ornament yuletide nutcracker grinch', 'ornament yuletide decorations nutcracker', 'ornament yuletide unwrap gifts']
# Words Processed: 4/30
# Estimated Remaining Time: 1383.13 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 368.7638
# Intermediate Solutions: ['ornament yuletide decorations holiday gifts', 'ornament yuletide of the nutcracker', 'ornament yuletide of the holiday', 'ornament yuletide gifts holiday decorations', 'ornament yuletide holiday gifts decorations', 'ornament yuletide holiday decorations gifts', 'ornament yuletide of decorations holiday', 'ornament yuletide nutcracker holiday gifts', 'ornament yuletide holly and nutcracker', 'ornament yuletide decorations gifts holiday', 'ornament yuletide nutcracker holiday decorations', 'ornament yuletide decorations holiday nutcracker', 'ornament yuletide holiday decorations nutcracker', 'ornament yuletide holiday holly nutcracker', 'ornament yuletide holiday unwrap gifts', 'ornament yuletide decorations holiday cheer', 'ornament yuletide holiday gifts and', 'ornament yuletide of the holly', 'ornament yuletide of the decorations', 'ornament yuletide of holiday decorations']
# Words Processed: 5/30
# Estimated Remaining Time: 3191.69 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 245.6496
# Intermediate Solutions: ['ornament yuletide holiday gifts and decorations', 'ornament yuletide of the holiday decorations', 'ornament yuletide of the nutcracker holiday', 'ornament yuletide of the nutcracker and', 'ornament yuletide of the decorations holiday', 'ornament yuletide of decorations holiday and', 'ornament yuletide holiday gifts and grinch', 'ornament yuletide of the holly and', 'ornament yuletide holiday decorations gifts and', 'ornament yuletide holly and nutcracker holiday', 'ornament yuletide of the holiday and', 'ornament yuletide nutcracker holiday decorations gifts', 'ornament yuletide decorations holiday gifts and', 'ornament yuletide of the decorations and', 'ornament yuletide decorations holiday gifts unwrap', 'ornament yuletide holiday gifts and stocking', 'ornament yuletide nutcracker holiday gifts decorations', 'ornament yuletide of the holiday gifts', 'ornament yuletide decorations holiday gifts nutcracker']
# Words Processed: 6/30
# Estimated Remaining Time: 2981.85 seconds
# ================================
#
# ===== Beam Search Progress =====
# Best Score (Perplexity): 256.4349
# Intermediate Solutions: ['ornament yuletide of the nutcracker and gifts', 'ornament yuletide of the nutcracker and sleigh', 'ornament yuletide of the decorations and holiday', 'ornament yuletide of the holiday and decorations', 'ornament yuletide of the nutcracker and decorations', 'ornament yuletide of the decorations and gifts', 'ornament yuletide of the decorations holiday and', 'ornament yuletide of the holiday decorations and', 'ornament yuletide of the nutcracker holiday decorations', 'ornament yuletide of the nutcracker holiday gifts', 'ornament yuletide of the nutcracker and holiday', 'ornament yuletide of decorations holiday and gifts', 'ornament yuletide holiday gifts and decorations of', 'ornament yuletide of the holiday and gifts', 'ornament yuletide of the nutcracker holiday and', 'ornament yuletide decorations holiday gifts and stocking', 'ornament yuletide of the holly and nutcracker', 'ornament yuletide of the nutcracker and grinch', 'ornament yuletide holly and nutcracker holiday decorations', 'ornament yuletide holiday gifts and decorations nutcracker']
# Words Processed: 7/30
# Estimated Remaining Time: 2628.36 seconds
# ================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-370f87bdae63> in <cell line: 20>()
#      18 '''
#      19 text: str = "sleigh of the magi yuletide cheer is unwrap gifts relax and eat cheer decorations carol sing chimney visit workshop grinch holiday holly jingle naughty nice nutcracker polar beard ornament stocking"
# ---> 20 score_results, solution_results, eval_cnt = optimizer.solve(text, batch_size=10)  #
#      21 scores.extend(score_results)
#      22 solutions.extend(solution_results)
#
# <ipython-input-8-859854b1afe9> in solve(self, text, batch_size)
#      99            # Remove duplicate candidates
#     100             candidates = list(set(candidates))
# --> 101             scores = self.scorer.get_perplexity(candidates, batch_size=batch_size)
#     102
#     103             eval_cnt += len(scores)
#
# <ipython-input-4-1524a24b63b0> in get_perplexity(self, input_texts, batch_size)
#      98                     model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}
#      99
# --> 100                     output = self.model(**model_inputs, use_cache=False)
#     101                     logits = output['logits']
#     102
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **loss_kwargs)
#     975         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     976         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 977         outputs = self.model(
#     978             input_ids=input_ids,
#     979             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     761                 )
#     762             else:
# --> 763                 layer_outputs = decoder_layer(
#     764                     hidden_states,
#     765                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     491         residual = hidden_states
#     492         hidden_states = self.pre_feedforward_layernorm(hidden_states)
# --> 493         hidden_states = self.mlp(hidden_states)
#     494         hidden_states = self.post_feedforward_layernorm(hidden_states)
#     495         hidden_states = residual + hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     168                 output = module._old_forward(*args, **kwargs)
#     169         else:
# --> 170             output = module._old_forward(*args, **kwargs)
#     171         return module._hf_hook.post_forward(module, output)
#     172
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/gemma2/modeling_gemma2.py in forward(self, x)
#      93
#      94     def forward(self, x):
# ---> 95         return self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      96
#      97
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     163
#     164     def new_forward(module, *args, **kwargs):
# --> 165         args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     166         if module._hf_hook.no_grad:
#     167             with torch.no_grad():
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in pre_forward(self, module, *args, **kwargs)
#     353                     self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
#     354
# --> 355                 set_module_tensor_to_device(
#     356                     module,
#     357                     name,
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/modeling.py in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map)
#     327                     module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     328         elif isinstance(value, torch.Tensor):
# --> 329             new_value = value.to(device)
#     330         else:
#     331             new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %%
solutions = ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi',
             'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax',
             'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax']

# %%
import random
from typing import List

class TSPListOperations:
    @staticmethod
    def two_rotation(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        i, j = random.sample(range(len(item)), 2)
        # 2つの要素を交換（i, j）→（j, i）
        new_item = item.copy()
        new_item[i], new_item[j] = new_item[j], new_item[i]
        return new_item

    @staticmethod
    def random_rotation(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        start_idx, end_idx = sorted(random.sample(range(len(item)), 2))

        shift = random.randint(1, len(item) - 1)
        sublist = item[start_idx:end_idx + 1]

        shift = shift % len(sublist)  # シフトをサブリストの長さ内に正規化
        rotated_sublist = sublist[shift:] + sublist[:shift]

        new_item = item.copy()
        new_item[start_idx:end_idx + 1] = rotated_sublist

        return new_item

    @staticmethod
    def random_insertion(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        size = random.randint(2, min(8, len(item)))
        if len(item) - size <= 0:
            start = 0
        else:
            start = random.randint(0, len(item) - size)
        end = start + size

        sublist = item[start:end]
        new_item = item.copy()
        del new_item[start:end]

        if random.random() < 0.5:
            insert_pos = random.randint(0, len(new_item))
            new_item[insert_pos:insert_pos] = sublist
        else:
            insert_pos = random.randint(0, len(new_item))
            new_item[insert_pos:insert_pos] = sublist[::-1]  # サブリストを逆順にして挿入

        return new_item

    @staticmethod
    def shuffle_sublist(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()

        size = random.randint(2, min(8, len(item)))
        if len(item) - size <= 0:
            start = 0
        else:
            start = random.randint(0, len(item) - size)
        end = start + size
        sublist = item[start:end]
        random.shuffle(sublist)
        new_item = item.copy()
        new_item[start:end] = sublist
        return new_item

    @staticmethod
    def double_bridge_move(item: List[str]) -> List[str]:
        n = len(item)
        if n < 8:
            # ダブルブリッジ移動は大きなリストでより効果的
            return TSPListOperations.random_insertion(item)

        # ツアーを4つのセグメントに分割
        indices = sorted(random.sample(range(1, n - 1), 3))
        a, b, c = indices
        A = item[:a]
        B = item[a:b]
        C = item[b:c]
        D = item[c:]

        # セグメントを異なる順序で再接続
        if random.choice([True, False]):
            B = B[::-1]
        if random.choice([True, False]):
            D = D[::-1]

        new_item = A + D + C + B
        return new_item

    @staticmethod
    def inversion(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        start, end = sorted(random.sample(range(len(item)), 2))
        new_item = item.copy()
        new_item[start:end + 1] = new_item[start:end + 1][::-1]
        return new_item

    @staticmethod
    def scramble(item: List[str]) -> List[str]:
        if len(item) < 2:
            return item.copy()
        start, end = sorted(random.sample(range(len(item)), 2))
        new_item = item.copy()
        sublist = new_item[start:end + 1]
        random.shuffle(sublist)
        new_item[start:end + 1] = sublist
        return new_item
    def three_opt_move(item: List[str]) -> List[str]:
        n = len(item)
        if n < 6:
            # 3-opt 移動には最低でも6つのノードが必要
            return item.copy()

        # 3つの異なるインデックスを選択
        indices = sorted(random.sample(range(n), 3))
        i, j, k = indices

        # セグメントの分割
        A = item[:i]
        B = item[i:j]
        C = item[j:k]
        D = item[k:]

        # いくつかの再接続パターンからランダムに選択
        reconnections = [
            A + B[::-1] + C + D,
            A + B + C[::-1] + D,
            A + C + B + D,
            A + C[::-1] + B[::-1] + D,
            A + B[::-1] + C[::-1] + D,
        ]
        new_item = random.choice(reconnections)
        return new_item

def neighbor_fn(arr: str, prefix: int = 0, suffix: int = 0) -> str:
    item = arr.split()
    operations = [
        TSPListOperations.two_rotation,
        TSPListOperations.random_rotation,
        TSPListOperations.random_insertion,
        TSPListOperations.shuffle_sublist,
        TSPListOperations.double_bridge_move,
        TSPListOperations.inversion,
        TSPListOperations.scramble,
        TSPListOperations.three_opt_move,
    ]


    op = random.choice(operations)
    item_modified = item[:prefix] + op(item[prefix:len(item)-suffix]) + item[len(item)-suffix:]
    return ' '.join(item_modified)

# %%
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, cost_fn, neighbor_fn, random_state):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        self.cost_fn = cost_fn
        self.neighbor_fn = neighbor_fn
        random.seed(random_state)

    def _acceptance_probability(self, diff, temperature):
        if diff <= 0:
            return 1.0
        return exp(-diff/temperature)

    def _lower_temperature(self, temperature, iteration):
        t1 = self.end_temp + self.start_temp/(1 + math.log(iteration+1))
        t2 = self.start_temp + (self.end_temp - self.start_temp)*(iteration/self.max_iterations)
        return max(t1, t2)

    def _print_progress(
        self,
        iteration: int,
        best_solutions: List[List[str]],
        best_energies: List[float],
        current_solutions: List[List[str]],
        current_energies: List[float],
        temperature: float,
        start_time: float,
        spend_minute: int
    ) -> int:
        current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        elapsed_time = time.time() - start_time
        Estimated_remaining_execution_time = (elapsed_time / (iteration+1)) * (self.max_iterations - iteration)

        # Check if 60 seconds have passed since the last update
        if elapsed_time - 60 * spend_minute > 60:
            spend_minute += 1
            progress = iteration / self.max_iterations * 100  # Progress as percentage

            # Print progress in a structured format
            print("===== Simulated Annealing Progress =====")
            print(f"Time: {current_time}")
            print(f"Iteration: {iteration}/{self.max_iterations} ({progress:.2f}%)")
            print(f"Temperature: {temperature:.4f}")
            print(f"Elapsed Time: {elapsed_time:.2f} seconds")
            print(f"Estimated_remaining_execution_time: {(Estimated_remaining_execution_time//60):.2f} minutes")


            # Print best solutions and energies
            print("\nBest Solutions:")
            idx_items = np.argsort(best_energies)[:5]

            for i, idx in enumerate(idx_items):
                print(f"  Solution {i+1}: {best_solutions[idx]}")
            print("\nBest Energies:")
            print("  " + ", ".join(f"{best_energies[idx]:.4f}" for idx in idx_items))

            # Print current solutions and energies
            print("\nCurrent Solutions:")
            for i, solution in enumerate(current_solutions[:5]):
                print(f"  Solution {i+1}: {solution}")
            print("\nCurrent Energies:")
            print("  " + ", ".join(f"{energy:.4f}" for energy in current_energies[:5]))

            print("========================================\n")

        return spend_minute


    def solve_batch(self, text_list, max_minute=180):
        """
        Perform Simulated Annealing for multiple texts at once.
        """
        solutions = text_list[:]
        current_energies = self.cost_fn(solutions)

        best_solutions = solutions[:]
        best_energies = current_energies[:]

        log_energies = [[] for _ in range(len(text_list))]
        for i in range(len(text_list)):
            log_energies[i].append(current_energies[i])

        temperature = self.start_temp
        start_time = time.time()
        spend_minute = 0

        for iteration in range(self.max_iterations):
            # 1) Generate neighbors
            new_solutions = [self.neighbor_fn(sol) for sol in solutions]

            # 2) Calculate new energies in batch
            new_energies = self.cost_fn(new_solutions)

            # 3) Acceptance and update
            for i in range(len(text_list)):

                diff = new_energies[i] - current_energies[i]
                ap = self._acceptance_probability(diff, temperature)

                if random.random() < ap:
                    solutions[i] = new_solutions[i]
                    current_energies[i] = new_energies[i]

                if current_energies[i] < best_energies[i]:
                    best_solutions[i] = solutions[i][:]
                    best_energies[i] = current_energies[i]

            # 4) Lower temperature
            temperature = self._lower_temperature(temperature, iteration)

            # 5) Log current energies
            for i in range(len(text_list)):
                log_energies[i].append(current_energies[i])

            # 6) Print progress (extracted into separate method)
            spend_minute = self._print_progress(
                iteration,
                best_solutions,
                best_energies,
                solutions,
                current_energies,
                temperature,
                start_time,
                spend_minute
            )

            # 7) Early stop if temperature is below threshold
            if temperature <= self.end_temp or spend_minute >= max_minute:
                print("Exiting.")
                break

        print(f"Execution time: {time.time() - start_time:.4f}s")

        # Convert best solutions back to strings
        return best_solutions, best_energies, log_energies

# %%
def cost_fn(sol):
    return scorer.get_perplexity(sol, batch_size=20)

# %%
torch.cuda.empty_cache()

# %%
sa_params = {
    'start_temp': 0.03,             # Initial temperature
    'end_temp': 0.003,          # Final temperature, decreasing linearly
    'max_iterations': 4500,    #45000 Number of iterations (approximately 4 hours for 100,000 iterations)
    'random_state': 71,          # Seed for the random number generator to ensure reproducibility
    # "alpha": 0.9999,             # Exponential decay rate for temperature reduction
    "cost_fn": cost_fn,
    "neighbor_fn": neighbor_fn
}

# Initialize the SimulatedAnnealing optimizer with the specified parameters
sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
solutions
# Out:
# ['ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit sing workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit relax workshop magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat relax sing visit workshop is magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap visit workshop sing eat relax magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit eat relax workshop magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing relax visit workshop',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap visit eat relax sing workshop is magi',
#  'ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer unwrap eat sing relax visit workshop is magi',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing visit workshop relax',
#  'magi ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap sing visit workshop eat relax']

# %%
best_solutions, best_energies, log_scores = sa_optimizer.solve_batch(solutions)
# Out:
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:15:01
# Iteration: 32/4500 (0.71%)
# Temperature: 0.0298
# Elapsed Time: 61.47 seconds
# Estimated_remaining_execution_time: 138.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit workshop magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop
#   Solution 5: magi yuletide ornament holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop visit
#
# Best Energies:
#   6.1328, 6.1367, 6.1484, 6.1641, 6.1641
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing visit magi workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing magi visit workshop relax
#
# Current Energies:
#   6.1484, 6.1484, 6.1641, 6.1367, 6.2383
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:16:01
# Iteration: 64/4500 (1.42%)
# Temperature: 0.0296
# Elapsed Time: 121.81 seconds
# Estimated_remaining_execution_time: 138.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 3: ornament yuletide holiday gifts and decorations of the magi carol grinch polar beard cheer cheer is unwrap nutcracker visit eat relax workshop sing naughty nice chimney stocking holly jingle sleigh
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#
# Best Energies:
#   6.0977, 6.1055, 6.1328, 6.1367, 6.1484
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat sing magi visit workshop relax
#
# Current Energies:
#   6.0977, 6.1484, 6.1445, 6.1367, 6.2383
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:17:01
# Iteration: 96/4500 (2.13%)
# Temperature: 0.0294
# Elapsed Time: 181.88 seconds
# Estimated_remaining_execution_time: 137.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 3: ornament yuletide holiday gifts and decorations of the magi carol grinch polar beard cheer cheer is unwrap nutcracker visit eat relax workshop sing naughty nice chimney stocking holly jingle sleigh
#   Solution 4: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#
# Best Energies:
#   6.0977, 6.1055, 6.1328, 6.1367, 6.1484
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop chimney magi carol grinch naughty nice sing stocking holly jingle sleigh polar beard cheer cheer and decorations is of the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch holly naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday nutcracker gifts and decorations of the carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday of the nutcracker carol grinch gifts and decorations stocking holly jingle naughty nice chimney sleigh polar beard cheer cheer is unwrap eat sing magi visit workshop relax
#
# Current Energies:
#   6.1680, 6.1484, 6.1445, 6.1562, 6.2578
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:18:01
# Iteration: 128/4500 (2.84%)
# Temperature: 0.0292
# Elapsed Time: 241.46 seconds
# Estimated_remaining_execution_time: 136.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 2: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 3: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#   Solution 4: ornament yuletide holiday gifts and decorations of the magi carol grinch polar beard cheer cheer is unwrap nutcracker visit eat relax workshop sing naughty nice chimney stocking holly jingle sleigh
#   Solution 5: ornament yuletide holiday gifts and decorations of the nutcracker carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#
# Best Energies:
#   6.0703, 6.0859, 6.0977, 6.1328, 6.1367
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop chimney magi carol grinch naughty nice sing stocking holly jingle sleigh polar beard cheer cheer and is decorations of the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh polar beard cheer cheer is unwrap eat relax chimney stocking visit workshop sing holly jingle magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday nutcracker gifts and decorations of the carol magi visit eat relax sing workshop grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap
#   Solution 5: ornament yuletide holiday of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard cheer cheer is unwrap stocking eat sing magi visit workshop relax
#
# Current Energies:
#   6.1992, 6.1875, 6.0859, 6.1562, 6.2617
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:19:00
# Iteration: 160/4500 (3.56%)
# Temperature: 0.0290
# Elapsed Time: 300.96 seconds
# Estimated_remaining_execution_time: 135.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly workshop jingle sleigh polar beard nutcracker
#   Solution 5: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0938, 6.0977
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop chimney magi carol grinch naughty nice sing stocking holly jingle sleigh polar beard cheer cheer and of decorations is the nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh polar beard cheer cheer is unwrap eat relax chimney stocking visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday holly decorations and gifts of the carol magi visit eat relax sing workshop grinch naughty nice chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide holiday of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard cheer cheer is unwrap stocking eat sing magi visit workshop relax
#
# Current Energies:
#   6.2188, 6.1875, 6.0859, 6.2188, 6.2617
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:20:00
# Iteration: 192/4500 (4.27%)
# Temperature: 0.0288
# Elapsed Time: 360.90 seconds
# Estimated_remaining_execution_time: 134.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly sleigh jingle workshop polar beard nutcracker
#   Solution 5: ornament yuletide holiday gifts unwrap eat relax visit workshop sing magi carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is and decorations of the nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0859, 6.0977
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday gifts unwrap eat relax visit workshop chimney magi stocking sing naughty nice grinch carol holly jingle sleigh polar beard cheer cheer the of is and decorations nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh polar beard cheer cheer is unwrap eat relax chimney stocking visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday holly decorations and gifts of the carol magi visit eat relax sing workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard cheer cheer holiday unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.2188, 6.1875, 6.1211, 6.1953, 6.2383
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:21:00
# Iteration: 224/4500 (4.98%)
# Temperature: 0.0287
# Elapsed Time: 420.68 seconds
# Estimated_remaining_execution_time: 133.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#   Solution 5: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly sleigh jingle workshop polar beard nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0859, 6.0859
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday cheer unwrap eat relax visit workshop chimney magi stocking sing naughty nice grinch carol holly jingle sleigh polar beard gifts cheer of the is and decorations nutcracker
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh polar beard cheer cheer is unwrap eat relax chimney stocking visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday holly decorations and gifts of the carol magi visit eat relax sing workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.2617, 6.1875, 6.1211, 6.1953, 6.1758
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:21:59
# Iteration: 256/4500 (5.69%)
# Temperature: 0.0285
# Elapsed Time: 480.15 seconds
# Estimated_remaining_execution_time: 132.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#   Solution 5: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly sleigh jingle workshop polar beard nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0859, 6.0859
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday cheer cheer of the is and decorations unwrap eat relax visit workshop chimney magi stocking sing naughty nice grinch carol holly jingle sleigh polar beard nutcracker gifts
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice sleigh polar beard cheer cheer is unwrap eat relax chimney stocking visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide holiday holly decorations and visit of the carol magi gifts eat relax sing workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.2617, 6.1875, 6.1211, 6.1562, 6.1758
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:22:59
# Iteration: 288/4500 (6.40%)
# Temperature: 0.0283
# Elapsed Time: 540.13 seconds
# Estimated_remaining_execution_time: 131.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#   Solution 5: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly sleigh jingle workshop polar beard nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0859, 6.0859
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday cheer cheer of the is and decorations unwrap eat relax stocking chimney visit magi nutcracker workshop sing naughty nice grinch carol holly jingle sleigh polar beard gifts
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax stocking chimney visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 4: ornament yuletide holiday eat relax sing holly decorations and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the nutcracker carol grinch gifts and decorations holly jingle naughty nice chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.3359, 6.2500, 6.1289, 6.1289, 6.1758
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:23:59
# Iteration: 320/4500 (7.11%)
# Temperature: 0.0281
# Elapsed Time: 600.09 seconds
# Estimated_remaining_execution_time: 130.00 minutes
#
# Best Solutions:
#   Solution 1: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 2: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 4: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#   Solution 5: ornament yuletide relax holiday gifts and decorations of the cheer cheer is unwrap magi sing carol eat visit grinch naughty nice chimney stocking holly sleigh jingle workshop polar beard nutcracker
#
# Best Energies:
#   6.0625, 6.0703, 6.0859, 6.0859, 6.0859
#
# Current Solutions:
#   Solution 1: ornament yuletide holiday cheer cheer the of is and decorations unwrap eat relax nutcracker magi visit chimney nice stocking naughty workshop sing grinch carol holly jingle sleigh polar beard gifts
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax stocking chimney visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 4: ornament yuletide holiday eat relax sing holly decorations and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol nutcracker holly jingle naughty nice chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.5000, 6.2500, 6.1289, 6.1289, 6.2656
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:25:01
# Iteration: 353/4500 (7.84%)
# Temperature: 0.0279
# Elapsed Time: 661.69 seconds
# Estimated_remaining_execution_time: 129.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide decorations and gifts of the nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 2: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 3: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 4: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 5: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#
# Best Energies:
#   6.0352, 6.0625, 6.0703, 6.0742, 6.0859
#
# Current Solutions:
#   Solution 1: ornament holiday cheer cheer the decorations is of unwrap stocking naughty workshop sing and eat relax yuletide nutcracker magi visit grinch chimney nice holly carol jingle sleigh polar beard gifts
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax stocking chimney visit workshop jingle sing holly magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol magi visit naughty nice grinch stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 4: ornament yuletide holiday eat relax sing holly decorations and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap stocking nutcracker jingle
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol nutcracker holly jingle naughty nice chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.6719, 6.2500, 6.1836, 6.1289, 6.2656
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:26:00
# Iteration: 385/4500 (8.56%)
# Temperature: 0.0277
# Elapsed Time: 721.17 seconds
# Estimated_remaining_execution_time: 128.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide decorations and gifts of the nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 2: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 3: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 4: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 5: ornament yuletide decorations and gifts of the holiday magi holly nutcracker grinch naughty nice chimney stocking jingle workshop polar beard eat relax cheer cheer is unwrap carol sing visit sleigh
#
# Best Energies:
#   6.0352, 6.0625, 6.0703, 6.0742, 6.0859
#
# Current Solutions:
#   Solution 1: ornament holiday the cheer cheer of relax unwrap stocking naughty workshop visit sing grinch chimney nice holly carol decorations is jingle sleigh polar beard gifts and eat yuletide nutcracker magi
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax stocking chimney visit workshop holly jingle sing magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol magi visit naughty nice grinch stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 4: ornament yuletide holiday eat relax and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap jingle nutcracker stocking sing holly decorations
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol holly jingle naughty nice nutcracker chimney sleigh polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.6641, 6.2422, 6.1836, 6.1641, 6.1562
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:27:00
# Iteration: 417/4500 (9.27%)
# Temperature: 0.0275
# Elapsed Time: 780.57 seconds
# Estimated_remaining_execution_time: 127.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide decorations and gifts of the nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing magi visit workshop
#   Solution 2: ornament yuletide decorations and gifts of the magi holiday holly nutcracker grinch naughty nice workshop chimney polar beard stocking carol jingle relax cheer cheer is unwrap eat sing visit sleigh
#   Solution 3: magi yuletide holiday ornament gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing visit
#   Solution 4: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#
# Best Energies:
#   6.0352, 6.0430, 6.0625, 6.0703, 6.0742
#
# Current Solutions:
#   Solution 1: ornament holiday the cheer cheer of relax unwrap stocking naughty workshop visit sing holly yuletide nutcracker magi carol grinch chimney decorations jingle is sleigh polar beard gifts and eat nice
#   Solution 2: ornament yuletide holiday gifts and decorations of the nutcracker carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax jingle sing workshop visit holly stocking chimney magi
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol magi visit naughty nice grinch stocking chimney jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#   Solution 4: ornament yuletide holiday eat relax and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap jingle nutcracker stocking sing holly decorations
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol holly jingle naughty nice chimney sleigh nutcracker polar beard holiday cheer cheer unwrap stocking magi eat sing visit workshop relax
#
# Current Energies:
#   6.6562, 6.2383, 6.1836, 6.1641, 6.1875
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:28:01
# Iteration: 450/4500 (10.00%)
# Temperature: 0.0273
# Elapsed Time: 841.85 seconds
# Estimated_remaining_execution_time: 125.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 2: ornament yuletide decorations and gifts of the magi holiday holly nutcracker grinch naughty nice workshop chimney polar beard stocking carol jingle relax cheer cheer is unwrap eat sing visit sleigh
#   Solution 3: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch chimney stocking holly jingle workshop sleigh polar beard naughty nice cheer cheer is unwrap eat relax sing visit
#   Solution 4: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#   Solution 5: ornament yuletide holiday gifts and decorations of the holly nutcracker carol grinch magi visit naughty nice chimney stocking jingle sleigh polar beard cheer cheer is unwrap eat relax sing workshop
#
# Best Energies:
#   5.9609, 6.0430, 6.0508, 6.0703, 6.0742
#
# Current Solutions:
#   Solution 1: ornament holiday the cheer cheer of relax unwrap stocking naughty workshop visit sing holly yuletide nutcracker magi chimney jingle carol grinch decorations is sleigh polar beard gifts and eat nice
#   Solution 2: ornament yuletide holiday gifts and decorations of the magi chimney stocking carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax jingle sing workshop visit holly nutcracker
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly nutcracker carol magi visit naughty nice grinch stocking chimney jingle sleigh polar beard workshop cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday eat relax and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap jingle stocking sing nutcracker holly decorations
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol holly jingle naughty nice chimney sleigh nutcracker polar beard holiday cheer cheer unwrap stocking magi eat sing relax workshop visit
#
# Current Energies:
#   6.6875, 6.1836, 6.1250, 6.1875, 6.2148
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:29:01
# Iteration: 482/4500 (10.71%)
# Temperature: 0.0271
# Elapsed Time: 901.31 seconds
# Estimated_remaining_execution_time: 124.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 2: ornament yuletide holiday gifts of decorations and cheer cheer is unwrap eat relax jingle magi carol sing naughty nice visit sleigh polar beard workshop chimney holly the grinch nutcracker stocking
#   Solution 3: ornament yuletide decorations and gifts of the magi holiday holly nutcracker chimney grinch naughty nice workshop polar beard stocking carol jingle relax cheer cheer is unwrap eat sing visit sleigh
#   Solution 4: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch chimney stocking holly jingle workshop sleigh polar beard naughty nice cheer cheer is unwrap eat relax sing visit
#   Solution 5: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#
# Best Energies:
#   5.9609, 5.9844, 6.0391, 6.0508, 6.0703
#
# Current Solutions:
#   Solution 1: ornament holiday the relax unwrap stocking of cheer cheer naughty workshop visit sing holly yuletide nutcracker magi chimney carol grinch sleigh polar beard jingle gifts and decorations is eat nice
#   Solution 2: ornament yuletide holiday gifts and decorations of the magi chimney stocking carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax holly jingle sing visit workshop nutcracker
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly magi carol nutcracker visit naughty nice grinch workshop chimney jingle sleigh polar beard stocking cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday eat relax and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap jingle stocking sing nutcracker holly decorations
#   Solution 5: ornament yuletide is of the decorations and gifts grinch carol holly jingle naughty nice chimney sleigh nutcracker polar beard holiday cheer cheer unwrap stocking magi eat relax sing workshop visit
#
# Current Energies:
#   6.6953, 6.1133, 6.0898, 6.1875, 6.1250
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:30:00
# Iteration: 514/4500 (11.42%)
# Temperature: 0.0269
# Elapsed Time: 961.02 seconds
# Estimated_remaining_execution_time: 123.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts of decorations and cheer cheer is unwrap eat relax jingle magi carol sing chimney holly the grinch naughty nice visit sleigh polar beard workshop nutcracker stocking
#   Solution 2: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 3: ornament yuletide decorations and gifts of the magi holiday holly nutcracker chimney grinch naughty nice workshop polar beard stocking carol jingle relax cheer cheer is unwrap eat sing visit sleigh
#   Solution 4: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch chimney stocking holly jingle workshop sleigh polar beard naughty nice cheer cheer is unwrap eat relax sing visit
#   Solution 5: ornament yuletide magi holiday gifts and decorations of the nutcracker carol grinch naughty nice chimney stocking holly jingle sleigh polar beard cheer cheer is unwrap eat relax visit workshop sing
#
# Best Energies:
#   5.9414, 5.9609, 6.0391, 6.0508, 6.0703
#
# Current Solutions:
#   Solution 1: ornament holiday the relax unwrap stocking of cheer cheer naughty workshop visit sing holly yuletide nutcracker magi chimney carol grinch sleigh polar beard jingle gifts decorations is eat nice and
#   Solution 2: ornament yuletide holiday gifts and decorations of the magi chimney stocking carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax holly jingle sing visit workshop nutcracker
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly magi carol nutcracker visit workshop chimney jingle sleigh polar naughty nice grinch beard stocking cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday jingle relax and visit of the carol magi gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap eat stocking sing decorations holly nutcracker
#   Solution 5: ornament yuletide is of the decorations and gifts grinch holiday cheer cheer eat relax sing carol unwrap jingle naughty nice chimney nutcracker sleigh polar beard holly stocking magi workshop visit
#
# Current Energies:
#   6.7109, 6.1133, 6.1445, 6.2070, 6.0859
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:31:00
# Iteration: 546/4500 (12.13%)
# Temperature: 0.0267
# Elapsed Time: 1020.63 seconds
# Estimated_remaining_execution_time: 122.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts of decorations and cheer cheer is unwrap eat relax jingle magi carol sing chimney holly the grinch naughty nice visit sleigh polar beard workshop nutcracker stocking
#   Solution 2: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 3: ornament yuletide decorations and gifts of the magi holiday holly nutcracker chimney grinch naughty nice workshop polar beard stocking carol jingle relax cheer cheer is unwrap eat sing visit sleigh
#   Solution 4: magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch chimney stocking holly jingle workshop sleigh polar beard naughty nice cheer cheer is unwrap eat relax sing visit
#   Solution 5: ornament yuletide is of the decorations and gifts unwrap holiday cheer cheer eat relax sing carol grinch jingle naughty nice chimney nutcracker sleigh polar beard holly stocking magi workshop visit
#
# Best Energies:
#   5.9414, 5.9609, 6.0391, 6.0508, 6.0586
#
# Current Solutions:
#   Solution 1: ornament holiday yuletide relax unwrap stocking of cheer cheer naughty and nice eat is decorations gifts carol sing holly the nutcracker magi chimney visit grinch sleigh polar beard jingle workshop
#   Solution 2: ornament yuletide holiday gifts and decorations stocking of the magi chimney carol grinch naughty nice polar sleigh beard cheer cheer is unwrap eat relax holly jingle workshop nutcracker visit sing
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly magi carol nutcracker visit workshop chimney jingle sleigh polar naughty nice grinch beard stocking cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday jingle relax and visit of the magi carol gifts workshop naughty nice grinch chimney sleigh polar beard cheer cheer is unwrap eat nutcracker stocking decorations sing holly
#   Solution 5: ornament yuletide is of the decorations and gifts unwrap holiday cheer cheer eat relax sing carol grinch chimney naughty nice nutcracker polar sleigh jingle beard holly stocking magi workshop visit
#
# Current Energies:
#   6.4141, 6.1719, 6.1445, 6.1523, 6.0625
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:31:59
# Iteration: 578/4500 (12.84%)
# Temperature: 0.0265
# Elapsed Time: 1080.06 seconds
# Estimated_remaining_execution_time: 121.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts of decorations and cheer cheer is unwrap eat relax jingle magi carol sing chimney holly the grinch naughty nice visit sleigh polar beard workshop nutcracker stocking
#   Solution 2: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 3: ornament yuletide the holiday is of decorations and gifts unwrap eat relax visit cheer jingle carol naughty nice nutcracker magi sleigh chimney stocking holly beard grinch polar workshop cheer sing
#   Solution 4: ornament yuletide is of the decorations and gifts unwrap holiday cheer cheer eat relax sing carol grinch chimney naughty nice nutcracker polar sleigh jingle beard holly stocking magi visit workshop
#   Solution 5: sleigh yuletide holiday decorations and gifts stocking of the magi chimney carol grinch naughty nice nutcracker ornament beard cheer cheer is unwrap eat relax sing holly jingle workshop visit polar
#
# Best Energies:
#   5.9414, 5.9609, 6.0039, 6.0117, 6.0352
#
# Current Solutions:
#   Solution 1: ornament holiday yuletide is naughty and nice eat relax carol sing unwrap stocking of cheer chimney decorations gifts cheer holly the magi nutcracker visit grinch sleigh polar beard jingle workshop
#   Solution 2: sleigh yuletide holiday decorations and gifts stocking of the magi chimney carol grinch naughty nice nutcracker ornament beard cheer cheer is unwrap eat relax sing holly jingle workshop visit polar
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly magi carol nutcracker visit workshop chimney jingle sleigh polar naughty nice grinch beard stocking cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday jingle relax and visit of the magi carol gifts workshop naughty nice grinch chimney sleigh polar beard stocking cheer cheer is unwrap eat sing decorations nutcracker holly
#   Solution 5: ornament yuletide is of the decorations and gifts unwrap holiday cheer cheer eat relax sing carol grinch chimney naughty nice nutcracker polar sleigh jingle beard holly stocking magi visit workshop
#
# Current Energies:
#   6.4258, 6.0352, 6.1445, 6.1289, 6.0117
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:33:01
# Iteration: 611/4500 (13.58%)
# Temperature: 0.0263
# Elapsed Time: 1141.32 seconds
# Estimated_remaining_execution_time: 120.00 minutes
#
# Best Solutions:
#   Solution 1: ornament yuletide holiday gifts of decorations and cheer cheer is unwrap eat relax jingle magi carol sing chimney holly the grinch naughty nice visit sleigh polar beard workshop nutcracker stocking
#   Solution 2: ornament yuletide nutcracker carol grinch chimney stocking holly jingle sleigh naughty nice polar beard holiday cheer cheer is unwrap eat relax sing decorations and gifts of the magi visit workshop
#   Solution 3: ornament yuletide the holiday is of decorations and gifts unwrap eat relax visit cheer jingle carol naughty nice nutcracker magi sleigh chimney stocking holly beard grinch polar workshop cheer sing
#   Solution 4: ornament yuletide is of the decorations and gifts unwrap holiday cheer cheer eat relax sing carol grinch chimney naughty nice nutcracker polar sleigh jingle beard holly stocking magi visit workshop
#   Solution 5: sleigh yuletide holiday decorations and gifts stocking of the magi chimney carol grinch naughty nice nutcracker ornament beard cheer cheer is unwrap eat relax sing holly jingle workshop visit polar
#
# Best Energies:
#   5.9414, 5.9609, 6.0039, 6.0117, 6.0352
#
# Current Solutions:
#   Solution 1: sleigh holiday yuletide is naughty and nice eat relax carol sing chimney stocking of cheer unwrap decorations gifts cheer holly the magi nutcracker visit grinch ornament polar beard jingle workshop
#   Solution 2: sleigh yuletide holiday decorations and gifts stocking beard of the magi chimney carol grinch naughty nice nutcracker ornament cheer cheer is unwrap eat relax sing holly jingle workshop visit polar
#   Solution 3: ornament yuletide holiday gifts and decorations of the holly magi carol nutcracker visit workshop chimney jingle sleigh polar naughty nice grinch beard stocking cheer cheer is unwrap eat relax sing
#   Solution 4: ornament yuletide holiday jingle relax and visit of the magi carol gifts workshop naughty nice grinch chimney sleigh polar beard stocking cheer cheer is unwrap eat sing decorations nutcracker holly
#   Solution 5: ornament yuletide is of the decorations and gifts eat holiday cheer cheer unwrap relax sing carol grinch chimney naughty nice nutcracker polar sleigh jingle beard holly stocking magi visit workshop
#
# Current Energies:
#   6.4219, 6.0391, 6.1445, 6.1289, 6.0156
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 10:34:00
# Iteration: 643/4500 (14.29%)
# Temperature: 0.0261
# Elapsed Time: 1200.84 seconds
# Estimated_remaining_execution_time: 119.00 minutes
#
# Best Solutions:
# ...
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing visit relax chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7461, 5.8789, 5.7109, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:28:01
# Iteration: 4324/4500 (96.09%)
# Temperature: 0.0062
# Elapsed Time: 8041.33 seconds
# Estimated_remaining_execution_time: 5.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#   Solution 5: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6992, 5.7109
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit workshop polar
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing visit relax chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7461, 5.8789, 5.7109, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:29:00
# Iteration: 4356/4500 (96.80%)
# Temperature: 0.0062
# Elapsed Time: 8100.77 seconds
# Estimated_remaining_execution_time: 4.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#   Solution 5: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6992, 5.7109
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit workshop polar
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing visit relax chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7461, 5.8789, 5.7109, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:29:59
# Iteration: 4388/4500 (97.51%)
# Temperature: 0.0062
# Elapsed Time: 8160.21 seconds
# Estimated_remaining_execution_time: 3.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#   Solution 5: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6992, 5.7109
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit workshop polar
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer cheer decorations naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing visit relax chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7461, 5.8789, 5.7148, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:31:01
# Iteration: 4421/4500 (98.24%)
# Temperature: 0.0062
# Elapsed Time: 8221.39 seconds
# Estimated_remaining_execution_time: 2.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#   Solution 5: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6992, 5.7109
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit workshop polar
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer cheer decorations naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing visit relax chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7461, 5.8789, 5.7148, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:32:00
# Iteration: 4453/4500 (98.96%)
# Temperature: 0.0062
# Elapsed Time: 8280.77 seconds
# Estimated_remaining_execution_time: 1.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#   Solution 5: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit polar workshop
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6992, 5.7109
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit polar workshop
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer cheer decorations naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer relax carol sing visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7109, 5.8789, 5.7148, 5.6641
# ========================================
#
# ===== Simulated Annealing Progress =====
# Time: 2025-01-08 12:32:59
# Iteration: 4485/4500 (99.67%)
# Temperature: 0.0062
# Elapsed Time: 8340.10 seconds
# Estimated_remaining_execution_time: 0.00 minutes
#
# Best Solutions:
#   Solution 1: sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
#   Solution 2: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#   Solution 3: ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
#   Solution 4: ornament yuletide is holiday of gifts and cheer cheer unwrap eat relax decorations carol sing jingle sleigh workshop naughty nice chimney stocking magi visit nutcracker the grinch polar beard holly
#   Solution 5: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
#
# Best Energies:
#   5.5547, 5.6445, 5.6523, 5.6914, 5.6992
#
# Current Solutions:
#   Solution 1: sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice grinch visit polar beard workshop relax sing carol of the magi chimney stocking nutcracker ornament holiday decorations
#   Solution 2: sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit polar workshop
#   Solution 3: ornament yuletide decorations of the magi carol sing holly jingle naughty nice chimney workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch sleigh visit eat relax cheer
#   Solution 4: ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax decorations cheer cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
#   Solution 5: ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer relax carol sing visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
#
# Current Energies:
#   5.7070, 5.7109, 5.8789, 5.7305, 5.6641
# ========================================
#
# Execution time: 8366.0680s

# %%
print(best_solutions)
# Out:
# ['sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament', 'sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit polar workshop', 'ornament yuletide decorations of the magi carol sing holly jingle naughty nice sleigh workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch eat relax cheer visit chimney', 'ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker', 'ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar', 'ornament yuletide nutcracker carol grinch holly jingle sleigh naughty nice polar beard chimney stocking holiday gifts and decorations visit workshop of the magi eat sing relax unwrap cheer cheer is', 'ornament yuletide decorations unwrap holiday gifts eat relax cheer cheer and visit workshop of the magi grinch chimney sing holly jingle carol nutcracker sleigh naughty nice polar is beard stocking', 'ornament yuletide relax unwrap gifts naughty and nice holiday cheer decorations stocking magi carol sing holly jingle sleigh chimney visit eat cheer nutcracker grinch polar beard of the workshop is', 'ornament yuletide is holiday of gifts and cheer cheer unwrap eat relax decorations carol sing jingle sleigh workshop naughty nice chimney stocking magi visit nutcracker the grinch polar beard holly', 'ornament yuletide unwrap stocking magi grinch holly jingle naughty is nice nutcracker polar beard chimney visit the workshop eat and relax sing carol sleigh decorations gifts of cheer holiday cheer', 'sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly', 'ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer', 'ornament yuletide jingle unwrap relax stocking of the magi holly naughty and nice nutcracker is grinch chimney visit polar beard sleigh workshop eat carol sing holiday decorations gifts cheer cheer', 'magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch polar beard workshop chimney stocking holly jingle sleigh naughty nice cheer is cheer unwrap eat relax sing visit', 'ornament yuletide cheer relax unwrap stocking and eat holiday cheer carol sing holly jingle beard sleigh workshop gifts of the magi grinch decorations nutcracker naughty nice chimney visit polar is', 'ornament yuletide holiday decorations of holly and the magi nutcracker carol grinch sleigh workshop chimney visit polar beard is naughty nice sing jingle relax unwrap stocking gifts eat cheer cheer', 'ornament holiday gifts of yuletide decorations and cheer cheer is unwrap eat relax sing carol jingle sleigh workshop chimney visit holly the magi naughty nice grinch nutcracker polar beard stocking', 'ornament yuletide holiday relax unwrap gifts of magi visit workshop grinch the polar is beard nutcracker eat naughty and nice cheer cheer decorations holly jingle sleigh chimney stocking sing carol', 'sleigh of the magi nutcracker yuletide cheer holiday is unwrap sing carol gifts and grinch jingle relax ornament decorations holly naughty nice stocking chimney polar beard workshop visit eat cheer', 'ornament yuletide relax and eat unwrap gifts of the magi is carol sing holly jingle sleigh cheer cheer naughty nice grinch polar beard visit workshop chimney holiday decorations n ...

# %%
# To visualize whether the scores decreased appropriately, you can use matplotlib to create a plot.

import matplotlib.pyplot as plt
plt.plot(log_scores[0])
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# To visualize whether the scores decreased appropriately, you can use matplotlib to create a plot.

import matplotlib.pyplot as plt

for score in log_scores:
    plt.plot(score)
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
for sol in best_solutions:
    print(scorer.get_perplexity(sol), sol)
# Out:
# 5.69921875 sleigh yuletide cheer unwrap gifts eat cheer holly jingle is naughty and nice sing carol of the magi visit grinch polar beard workshop relax chimney stocking nutcracker holiday decorations ornament
# 5.7109375 sleigh yuletide beard gifts of the magi carol grinch chimney stocking holiday decorations naughty and nice nutcracker cheer cheer is unwrap eat relax sing holly jingle ornament visit polar workshop
# 5.8515625 ornament yuletide decorations of the magi carol sing holly jingle naughty nice sleigh workshop nutcracker polar beard gifts and stocking holiday cheer is unwrap grinch eat relax cheer visit chimney
# 5.7109375 ornament yuletide carol sing unwrap eat gifts of the magi holiday holly jingle relax cheer decorations cheer naughty and nice chimney stocking sleigh workshop is visit grinch polar beard nutcracker
# 5.640625 ornament yuletide is the holiday cheer of decorations and gifts unwrap eat cheer carol sing relax visit chimney stocking holly jingle beard nutcracker magi sleigh workshop naughty nice grinch polar
# 5.83984375 ornament yuletide nutcracker carol grinch holly jingle sleigh naughty nice polar beard chimney stocking holiday gifts and decorations visit workshop of the magi eat sing relax unwrap cheer cheer is
# 5.7734375 ornament yuletide decorations unwrap holiday gifts eat relax cheer cheer and visit workshop of the magi grinch chimney sing holly jingle carol nutcracker sleigh naughty nice polar is beard stocking
# 5.83984375 ornament yuletide relax unwrap gifts naughty and nice holiday cheer decorations stocking magi carol sing holly jingle sleigh chimney visit eat cheer nutcracker grinch polar beard of the workshop is
# 5.69140625 ornament yuletide is holiday of gifts and cheer cheer unwrap eat relax decorations carol sing jingle sleigh workshop naughty nice chimney stocking magi visit nutcracker the grinch polar beard holly
# 5.74609375 ornament yuletide unwrap stocking magi grinch holly jingle naughty is nice nutcracker polar beard chimney visit the workshop eat and relax sing carol sleigh decorations gifts of cheer holiday cheer
# 5.5546875 sleigh yuletide cheer cheer is holiday jingle unwrap gifts eat and relax sing carol visit workshop of the magi naughty nice grinch chimney stocking nutcracker polar beard ornament decorations holly
# 5.65234375 ornament yuletide decorations and gifts unwrap eat relax sing carol cheer jingle sleigh visit workshop naughty nice holly magi nutcracker polar beard chimney stocking is the grinch of holiday cheer
# 5.8125 ornament yuletide jingle unwrap relax stocking of the magi holly naughty and nice nutcracker is grinch chimney visit polar beard sleigh workshop eat carol sing holiday decorations gifts cheer cheer
# 5.94921875 magi yuletide holiday gifts and decorations ornament of the nutcracker carol grinch polar beard workshop chimney stocking holly jingle sleigh naughty nice cheer is cheer unwrap eat relax sing visit
# 5.76953125 ornament yuletide cheer relax unwrap stocking and eat holiday cheer carol sing holly jingle beard sleigh workshop gifts of the magi grinch decorations nutcracker naughty nice chimney visit polar is
# 5.7890625 ornament yuletide holiday decorations of holly and the magi nutcracker carol grinch sleigh workshop chimney visit polar beard is naughty nice sing jingle relax unwrap stocking gifts eat cheer cheer
# 5.78515625 ornament holiday gifts of yuletide decorations and cheer cheer is unwrap eat relax sing carol jingle sleigh workshop chimney visit holly the magi naughty nice grinch nutcracker polar beard stocking
# 5.90234375 ornament yuletide holiday relax unwrap gifts of magi visit workshop grinch the polar is beard nutcracker eat naughty and nice cheer cheer decorations holly jingle sleigh chimney stocking sing carol
# 6.02734375 sleigh of the magi nutcracker yuletide cheer holiday is unwrap sing carol gifts and grinch jingle relax ornament decorations holly naughty nice stocking chimney polar beard workshop visit eat cheer
# 5.7265625 ornament yuletide relax and eat unwrap gifts of the magi is carol sing holly jingle sleigh cheer cheer naughty nice grinch polar beard visit workshop chimney holiday decorations nutcracker stocking
