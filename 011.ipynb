# %% [markdown]
# このノートブックは以下のノートブックを参考にして作成されました。
#
# この場を借りてノートブックを共有してくださったことに感謝したいと思います。
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# また、以下のノートブックを利用してid4以外の答えを作成しています。ありがとうございます。
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# This notebook was created with reference to the following notebook:
#
# https://www.kaggle.com/code/utm529fg/eng-tutorial-3-beam-search
#
# I would like to take this opportunity to express my gratitude to the author for sharing their notebook.
#
# Additionally, I used the following notebook to generate answers other than id4. Thank you very much.
#
# https://www.kaggle.com/code/jazivxt/diminutive-effort-tpu

# %% [markdown]
# このノートブックはGPU環境下で実行に3時間程度かかります。実行される際は注意してください。
#
# 元ノートブックからの変更点として、ベーム幅を可変にしています。
#
# これにより、重要な局面で多くの情報を残すことができます。

# %% [markdown]
# This notebook takes approximately 3 hours to run in a GPU environment. Please be cautious when executing it.
#
# As a modification from the original notebook, the beam width has been made adjustable.
#
# This allows for retaining more information during critical stages.

# %%
print("Yes")
# Out:
# Yes

# %% [markdown]
# # 3-2. Implementation 実装

# %%
"""Evaluation metric for Santa 2024."""

import gc
import os
from math import exp
from collections import Counter
from typing import List, Optional, Union

import numpy as np
import pandas as pd
import transformers
import torch

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
PAD_TOKEN_LABEL_ID = torch.nn.CrossEntropyLoss().ignore_index
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


class ParticipantVisibleError(Exception):
    pass


def score(
    solution: pd.DataFrame,
    submission: pd.DataFrame,
    row_id_column_name: str,
    model_path: str = '/kaggle/input/gemma-2/transformers/gemma-2-9b/2',
    load_in_8bit: bool = False,
    clear_mem: bool = False,
) -> float:
    """
    Calculates the mean perplexity of submitted text permutations compared to an original text.

    Parameters
    ----------
    solution : DataFrame
        DataFrame containing the original text in a column named 'text'.
        Includes a row ID column specified by `row_id_column_name`.

    submission : DataFrame
        DataFrame containing the permuted text in a column named 'text'.
        Must have the same row IDs as the solution.
        Includes a row ID column specified by `row_id_column_name`.

    row_id_column_name : str
        Name of the column containing row IDs.
        Ensures aligned comparison between solution and submission.

    model_path : str, default='/kaggle/input/gemma-2/transformers/gemma-2-9b/2'
        Path to the serialized LLM.

    load_in_8bit : bool, default=False
        Use 8-bit quantization for the model. Requires CUDA.

    clear_mem : bool, default=False
        Clear GPU memory after scoring by clearing the CUDA cache.
        Useful for testing.

    Returns
    -------
    float
        The mean perplexity score. Lower is better.

    Raises
    ------
    ParticipantVisibleError
        If the submission format is invalid or submitted strings are not valid permutations.

    Examples
    --------
    >>> import pandas as pd
    >>> model_path = "/kaggle/input/gemma-2/transformers/gemma-2-9b/2"
    >>> solution = pd.DataFrame({
    ...     'id': [0, 1],
    ...     'text': ["this is a normal english sentence", "the quick brown fox jumps over the lazy dog"]
    ... })
    >>> submission = pd.DataFrame({
    ...     'id': [0, 1],
    ...     'text': ["sentence english normal a is this", "lazy the over jumps fox brown quick the dog"]
    ... })
    >>> score(solution, submission, 'id', model_path=model_path, clear_mem=True) > 0
    True
    """
    # Check that each submitted string is a permutation of the solution string
    sol_counts = solution.loc[:, 'text'].str.split().apply(Counter)
    sub_counts = submission.loc[:, 'text'].str.split().apply(Counter)
    invalid_mask = sol_counts != sub_counts
    if invalid_mask.any():
        raise ParticipantVisibleError(
            'At least one submitted string is not a valid permutation of the solution string.'
        )

    # Calculate perplexity for the submitted strings
    sub_strings = [
        ' '.join(s.split()) for s in submission['text'].tolist()
    ]  # Split and rejoin to normalize whitespace
    scorer = PerplexityCalculator(
        model_path=model_path,
        load_in_8bit=load_in_8bit,
    )  # Initialize the perplexity calculator with a pre-trained model
    perplexities = scorer.get_perplexity(
        sub_strings
    )  # Calculate perplexity for each submitted string

    if clear_mem:
        # Just move on if it fails. Not essential if we have the score.
        try:
            scorer.clear_gpu_memory()
        except:
            print('GPU memory clearing failed.')

    return float(np.mean(perplexities))


class PerplexityCalculator:
    """
    Calculates perplexity of text using a pre-trained language model.

    Adapted from https://github.com/asahi417/lmppl/blob/main/lmppl/ppl_recurrent_lm.py

    Parameters
    ----------
    model_path : str
        Path to the pre-trained language model

    load_in_8bit : bool, default=False
        Use 8-bit quantization for the model. Requires CUDA.

    device_map : str, default="auto"
        Device mapping for the model.
    """

    def __init__(
        self,
        model_path: str,
        load_in_8bit: bool = False,
        device_map: str = 'auto',
    ):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_path)
        # Configure model loading based on quantization setting and device availability
        if load_in_8bit:
            if DEVICE.type != 'cuda':
                raise ValueError('8-bit quantization requires CUDA device')
            quantization_config = transformers.BitsAndBytesConfig(load_in_8bit=True)
            self.model = transformers.AutoModelForCausalLM.from_pretrained(
                model_path,
                quantization_config=quantization_config,
                device_map=device_map,
            )
        else:
            self.model = transformers.AutoModelForCausalLM.from_pretrained(
                model_path,
                torch_dtype=torch.float16 if DEVICE.type == 'cuda' else torch.float32,
                device_map=device_map,
            )

        self.loss_fct = torch.nn.CrossEntropyLoss(reduction='none')

        self.model.eval()

    def get_perplexity(
        self, input_texts: Union[str, List[str]], debug=False
    ) -> Union[float, List[float]]:
        """
        Calculates the perplexity of given texts.

        Parameters
        ----------
        input_texts : str or list of str
            A single string or a list of strings.

        batch_size : int, default=None
            Batch size for processing. Defaults to the number of input texts.

        debug : bool, default=False
            Print debugging information.

        Returns
        -------
        float or list of float
            A single perplexity value if input is a single string,
            or a list of perplexity values if input is a list of strings.

        Examples
        --------
        >>> import pandas as pd
        >>> model_path = "/kaggle/input/gemma-2/transformers/gemma-2-9b/2"
        >>> scorer = PerplexityCalculator(model_path=model_path)

        >>> submission = pd.DataFrame({
        ...     'id': [0, 1, 2],
        ...     'text': ["this is a normal english sentence", "thsi is a slihgtly misspelled zr4g sentense", "the quick brown fox jumps over the lazy dog"]
        ... })
        >>> perplexities = scorer.get_perplexity(submission["text"].tolist())
        >>> perplexities[0] < perplexities[1]
        True
        >>> perplexities[2] < perplexities[0]
        True

        >>> perplexities = scorer.get_perplexity(["this is a sentence", "another sentence"])
        >>> all(p > 0 for p in perplexities)
        True

        >>> scorer.clear_gpu_memory()
        """
        single_input = isinstance(input_texts, str)
        input_texts = [input_texts] if single_input else input_texts

        loss_list = []
        with torch.no_grad():
            # Process each sequence independently
            for text in input_texts:
                # Explicitly add sequence boundary tokens to the text
                text_with_special = f"{self.tokenizer.bos_token}{text}{self.tokenizer.eos_token}"

                # Tokenize
                model_inputs = self.tokenizer(
                    text_with_special,
                    return_tensors='pt',
                    add_special_tokens=False,
                )

                if 'token_type_ids' in model_inputs:
                    model_inputs.pop('token_type_ids')

                model_inputs = {k: v.to(DEVICE) for k, v in model_inputs.items()}

                # Get model output
                output = self.model(**model_inputs, use_cache=False)
                logits = output['logits']

                # Shift logits and labels for calculating loss
                shift_logits = logits[..., :-1, :].contiguous()  # Drop last prediction
                shift_labels = model_inputs['input_ids'][..., 1:].contiguous()  # Drop first input

                # Calculate token-wise loss
                loss = self.loss_fct(
                    shift_logits.view(-1, shift_logits.size(-1)),
                    shift_labels.view(-1)
                )

                # Calculate average loss
                sequence_loss = loss.sum() / len(loss)
                loss_list.append(sequence_loss.cpu().item())

                # Debug output
                if debug:
                    print(f"\nProcessing: '{text}'")
                    print(f"With special tokens: '{text_with_special}'")
                    print(f"Input tokens: {model_inputs['input_ids'][0].tolist()}")
                    print(f"Target tokens: {shift_labels[0].tolist()}")
                    print(f"Input decoded: {self.tokenizer.decode(model_inputs['input_ids'][0])}")
                    print(f"Target decoded: {self.tokenizer.decode(shift_labels[0])}")
                    print(f"Individual losses: {loss.tolist()}")
                    print(f"Average loss: {sequence_loss.item():.4f}")

        ppl = [exp(i) for i in loss_list]

        if debug:
            print("\nFinal perplexities:")
            for text, perp in zip(input_texts, ppl):
                print(f"Text: '{text}'")
                print(f"Perplexity: {perp:.2f}")

        return ppl[0] if single_input else ppl

    def clear_gpu_memory(self) -> None:
        """Clears GPU memory by deleting references and emptying caches."""
        if not torch.cuda.is_available():
            return

        # Delete model and tokenizer if they exist
        if hasattr(self, 'model'):
            del self.model
        if hasattr(self, 'tokenizer'):
            del self.tokenizer

        # Run garbage collection
        gc.collect()

        # Clear CUDA cache and reset memory stats
        with DEVICE:
            torch.cuda.empty_cache()
            torch.cuda.ipc_collect()
            torch.cuda.reset_peak_memory_stats()

# %%
sample_submission = pd.read_csv('/kaggle/input/santa-2024/sample_submission.csv')

# %%
# initialize scorer
scorer = PerplexityCalculator('/kaggle/input/gemma-2/transformers/gemma-2-9b/2')
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
import random
import time
class BeamSearch():
    def __init__(self, beam_width):
        self.beam_width = beam_width

    def _make_candidates_adding_word(self, intermediate_solution, words):
        '''Make candidate text so that word duplication does not occur'''
        candidates = []
        not_used_words = words.copy()
        for used_word in intermediate_solution.split():
            not_used_words.remove(used_word)
        
        candidates += [(intermediate_solution + ' ' + word).lstrip() for word in not_used_words]
        candidates += [(word + ' ' + intermediate_solution).rstrip() for word in not_used_words]

        candidates = list(set(candidates)) # drop duplicate
        
        return candidates
    def solve(self, text):
        words = text.split()
        intermediate_solutions = ['']
        eval_cnt = 0

        while len(intermediate_solutions[0].split()) < len(words):
            start_time = time.time()
            candidates = []
            for intermediate_solution in intermediate_solutions:
                candidates += self._make_candidates_adding_word(intermediate_solution, words)
            
            # 重複を排除
            candidates = list(set(candidates))
            
            scores = scorer.get_perplexity(candidates)
            eval_cnt += len(scores)
            
            # スコアと候補をペアにする
            scored_candidates = list(zip(scores, candidates))
            
            # スコアでソート（低い順）
            scored_candidates.sort(key=lambda x: x[0])
            
            # ビーム幅に基づいて上位k個を選択、重複を避ける
            new_intermediate_solutions = []
            seen = set()
            for score, candidate in scored_candidates:
                if candidate not in seen:
                    new_intermediate_solutions.append(candidate)
                    seen.add(candidate)
                if score < 1.1*scored_candidates[0][0] and len(new_intermediate_solutions) < 7:
                    continue
                if len(new_intermediate_solutions) >= self.beam_width:
                    break
            
            intermediate_solutions = new_intermediate_solutions
            print(f"score, intermediate_solutions:{min(scorer.get_perplexity(intermediate_solutions))}, {intermediate_solutions}")
            print(f"remain_time:{len(new_intermediate_solutions[0].split())}/{len(words)}, {(len(words)-len(new_intermediate_solutions[0].split()))*(time.time()-start_time)}\n")

        # 最終的なベストスコアとソリューションを取得
        final_scores = scorer.get_perplexity(intermediate_solutions)
        best_idx = np.argmin(final_scores)
        best_score = final_scores[best_idx]
        best_solution = intermediate_solutions[best_idx]

        return best_score, best_solution, eval_cnt

# %%
params = {
    'beam_width': 2,
}
optimizer = BeamSearch(**params)

# %%
sample_submission.loc[0]["text"]
# Out:
# 'advent chimney elf family fireplace gingerbread mistletoe ornament reindeer scrooge'

# %%
import time
start_time = time.time()
from tqdm import tqdm
scores = []
solutions = []
eval_cnts = []
# for text in tqdm(sample_submission['text']):
text = sample_submission.loc[4]["text"]
score, solution, eval_cnt = optimizer.solve(text)
scores.append(score)
solutions.append(solution)
eval_cnts.append(eval_cnt)

print(scores)
print(solutions)
print(eval_cnts)
print(f"execute_time:{time.time()-start_time}")
# Out:
# score, intermediate_solutions:6940.724466153628, ['eggnog', 'poinsettia']
# remain_time:1/50, 246.18579816818237
#
# score, intermediate_solutions:1499.4774098942676, ['eggnog fruitcake', 'poinsettia eggnog']
# remain_time:2/50, 901.8105125427246
#
# score, intermediate_solutions:740.344594124485, ['eggnog fruitcake poinsettia', 'poinsettia eggnog fruitcake']
# remain_time:3/50, 869.7348036766052
#
# score, intermediate_solutions:444.9990075779989, ['eggnog fruitcake poinsettia snowglobe', 'eggnog fruitcake poinsettia wreath', 'wreath eggnog fruitcake poinsettia']
# remain_time:4/50, 849.2285361289978
#
# score, intermediate_solutions:334.4738335575232, ['eggnog fruitcake poinsettia wreath snowglobe', 'wreath eggnog fruitcake poinsettia snowglobe']
# remain_time:5/50, 1216.9067823886871
#
# score, intermediate_solutions:313.4337950331619, ['eggnog fruitcake poinsettia wreath snowglobe cookie', 'eggnog fruitcake poinsettia wreath snowglobe candle', 'wreath eggnog fruitcake poinsettia snowglobe star', 'eggnog fruitcake poinsettia wreath snowglobe candy', 'eggnog fruitcake poinsettia wreath snowglobe star', 'wreath eggnog fruitcake poinsettia snowglobe candle', 'eggnog fruitcake poinsettia wreath snowglobe angel']
# remain_time:6/50, 810.2510395050049
#
# score, intermediate_solutions:277.5925587894898, ['eggnog fruitcake poinsettia wreath snowglobe star cookie', 'eggnog fruitcake poinsettia wreath snowglobe angel star', 'wreath eggnog fruitcake poinsettia snowglobe star cookie', 'eggnog fruitcake poinsettia wreath snowglobe star angel', 'eggnog fruitcake poinsettia wreath snowglobe angel cookie', 'wreath eggnog fruitcake poinsettia snowglobe star candy', 'eggnog fruitcake poinsettia wreath snowglobe star candle']
# remain_time:7/50, 2631.5216357707977
#
# score, intermediate_solutions:262.5502983778269, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star candle', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy', 'eggnog fruitcake poinsettia wreath snowglobe star angel candle', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy', 'eggnog fruitcake poinsettia wreath snowglobe star cookie angel']
# remain_time:8/50, 2600.615800380707
#
# score, intermediate_solutions:242.98357091084108, ['wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy candle', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy', 'eggnog fruitcake poinsettia wreath snowglobe star cookie angel candle', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candle angel']
# remain_time:9/50, 2776.275974035263
#
# score, intermediate_solutions:228.71790656459262, ['wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint chocolate', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint candle', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint hohoho', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy candle fireplace']
# remain_time:10/50, 2653.881206512451
#
# score, intermediate_solutions:218.19264402361716, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint chocolate milk', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint candle', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle angel', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle hohoho', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate candle']
# remain_time:11/50, 2532.9413602352142
#
# score, intermediate_solutions:212.0940725846427, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint candle fireplace', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate candle fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate candle', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle fireplace angel', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint candle fireplace hohoho', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint chocolate milk and']
# remain_time:12/50, 2412.537808895111
#
# score, intermediate_solutions:217.25008517145912, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate candle fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk candle', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint chocolate milk and merry', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate candle fireplace hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk hohoho', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate candle fireplace angel']
# remain_time:13/50, 2296.0348789691925
#
# score, intermediate_solutions:210.9101732116565, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk candle fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and merry', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and you', 'eggnog fruitcake poinsettia wreath snowglobe star cookie candy peppermint chocolate milk and merry hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the', 'wreath eggnog fruitcake poinsettia snowglobe star cookie candy peppermint chocolate candle fireplace hohoho merry']
# remain_time:14/50, 2179.8088731765747
#
# score, intermediate_solutions:179.0429793302674, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the hohoho']
# remain_time:15/50, 2048.3105158805847
#
# score, intermediate_solutions:197.90506330271663, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace in', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace merry']
# remain_time:16/50, 570.3897156715393
#
# score, intermediate_solutions:179.4237263083281, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with it', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace in it', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with candle']
# remain_time:17/50, 1306.2390768527985
#
# score, intermediate_solutions:186.09092339135466, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with it in', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with hohoho merry', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with hohoho in', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with it hohoho']
# remain_time:18/50, 1251.7861862182617
#
# score, intermediate_solutions:140.48896119697196, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with hohoho in it']
# remain_time:19/50, 1397.0336122512817
#
# score, intermediate_solutions:150.57316610374772, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it candle']
# remain_time:20/50, 448.7348985671997
#
# score, intermediate_solutions:151.50995623071802, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it hohoho merry', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry night']
# remain_time:21/50, 815.4874985218048
#
# score, intermediate_solutions:167.77878097685274, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it hohoho merry night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it hohoho merry season', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho']
# remain_time:22/50, 595.4706382751465
#
# score, intermediate_solutions:156.89724590760608, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho to that', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho from to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season to']
# remain_time:23/50, 1247.712718963623
#
# score, intermediate_solutions:138.45691003308767, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of hope']
# remain_time:24/50, 841.9155225753784
#
# score, intermediate_solutions:142.11917877388936, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of hope joy', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy']
# remain_time:25/50, 636.2741231918335
#
# score, intermediate_solutions:133.75846469785282, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy hope', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of hope joy peace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace to']
# remain_time:26/50, 1005.296064376831
#
# score, intermediate_solutions:129.46967871066855, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder hope', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy hope wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of hope joy peace wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe']
# remain_time:27/50, 804.2249276638031
#
# score, intermediate_solutions:136.30032530764524, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder hope believe', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder hope wish']
# remain_time:28/50, 741.9844431877136
#
# score, intermediate_solutions:133.34720051128087, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe dream wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder hope believe dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe dream wonder']
# remain_time:29/50, 790.5687267780304
#
# score, intermediate_solutions:128.7765789395743, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream wish believe', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe dream wish wonder', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of peace joy wonder hope believe dream wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of joy peace hope believe dream wonder wish']
# remain_time:30/50, 720.0752782821655
#
# score, intermediate_solutions:140.81269607651225, ['doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish']
# remain_time:31/50, 653.1490132808685
#
# score, intermediate_solutions:137.49536167405645, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to have', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream night candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream night to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to that']
# remain_time:32/50, 584.0192985534668
#
# score, intermediate_solutions:141.76789923314163, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have that', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to have that', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have not', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to have not', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have as', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have']
# remain_time:33/50, 533.1346056461334
#
# score, intermediate_solutions:142.64201724872194, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to have not from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have as we', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have not from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have that night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe dream wish to have that night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that']
# remain_time:34/50, 469.8819389343262
#
# score, intermediate_solutions:147.88489160563532, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have not from that']
# remain_time:35/50, 420.8316671848297
#
# score, intermediate_solutions:149.94316022285247, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have not from that we', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that night to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that from to', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to night candle']
# remain_time:36/50, 369.0561604499817
#
# score, intermediate_solutions:158.39147768600168, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that from to as', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that from as', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope dream believe wish to have not from that we']
# remain_time:37/50, 323.13449883461
#
# score, intermediate_solutions:166.3360030204471, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as candle', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not that from to as', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from candle']
# remain_time:38/50, 276.9530725479126
#
# score, intermediate_solutions:167.30415481951545, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card game', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as from', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as candle from', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night as candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card']
# remain_time:39/50, 236.11329174041748
#
# score, intermediate_solutions:167.95592141003016, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper greeting', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card game night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card greeting', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting candle']
# remain_time:40/50, 198.14846277236938
#
# score, intermediate_solutions:169.57439199193712, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card game night candle', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping greeting', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper greeting wrapping', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card greeting paper']
# remain_time:41/50, 162.04530572891235
#
# score, intermediate_solutions:167.9306156273537, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping bow candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper greeting wrapping bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping bow greeting', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card greeting paper wrapping']
# remain_time:42/50, 131.31957817077637
#
# score, intermediate_solutions:167.82791010694285, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping bow greeting candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper greeting wrapping bow candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card greeting paper wrapping bow', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card paper wrapping bow candle greeting']
# remain_time:43/50, 102.0250871181488
#
# score, intermediate_solutions:176.15029940865546, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that night from as card greeting paper wrapping bow candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy candle']
# remain_time:44/50, 77.09095573425293
#
# score, intermediate_solutions:172.9051778877794, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game doll']
# remain_time:45/50, 55.65245032310486
#
# score, intermediate_solutions:170.7581620782189, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle doll', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game night candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night']
# remain_time:46/50, 38.60354232788086
#
# score, intermediate_solutions:170.08303101265807, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game puzzle doll', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle doll candle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle candle night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game night']
# remain_time:47/50, 23.706434726715088
#
# score, intermediate_solutions:176.34039861978547, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle candle night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game night puzzle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game puzzle doll night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game puzzle night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle doll candle night', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle doll', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle']
# remain_time:48/50, 12.352418422698975
#
# score, intermediate_solutions:200.4088892881328, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle doll workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game night puzzle workshop', 'doll eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle candle night kaggle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle doll candle night kaggle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game puzzle night kaggle', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game puzzle doll night kaggle']
# remain_time:49/50, 4.413154125213623
#
# score, intermediate_solutions:223.76094023954994, ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle candle night kaggle workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy game puzzle doll candle night kaggle workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy doll game puzzle night kaggle workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game puzzle doll night kaggle workshop', 'eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow candle toy game night puzzle doll workshop kaggle']
# remain_time:50/50, 0.0
#
# [223.76094023954994]
# ['eggnog fruitcake poinsettia wreath snowglobe angel star cookie candy peppermint chocolate milk and the fireplace with you in it merry hohoho season of wonder joy peace hope believe wish dream have we not to that as from card greeting paper wrapping bow toy doll game puzzle candle night kaggle workshop']
# [13142]
# execute_time:1541.4849073886871

# %%
#solutions = ['hohoho season merry have you cookie chocolate candy milk eggnog fruitcake peppermint candle snowglobe fireplace wreath poinsettia wish dream hope believe peace joy wonder night star angel greeting card wrapping paper bow kaggle workshop toy doll game puzzle the of and to in that from not it with as we']

# %%
most_best_text = "from and as have in not it of that the to we with you bow angel believe candle candy card chocolate cookie doll dream eggnog fireplace fruitcake game greeting hohoho hope joy kaggle merry milk night peace peppermint poinsettia puzzle season snowglobe star toy wreath wish workshop wonder wrapping paper"

# %%
import math
class SimulatedAnnealing:
    def __init__(self, start_temp, end_temp, max_iterations, random_state, alpha):
        self.start_temp = start_temp
        self.end_temp = end_temp
        self.max_iterations = max_iterations
        random.seed(random_state)
        self.alpha = alpha  # 指数減少率

    def _generate_neighbor(self, solution):
        """
        
        近傍解を生成（ランダムな2単語を入れ替え）
        """
        r = random.choice(range(5))
        if r == 0:
            # Generate a neighborhood solution by swapping two random words.
            neighbor = solution.copy()
            i, j = random.sample(range(len(neighbor)), 2)
            neighbor[i], neighbor[j] = neighbor[j], neighbor[i]
            return neighbor
        elif r==1:
            # 
            shift = solution.copy()
            extract, insert = random.sample(range(len(shift) - 1), 2)
            shift_words = shift[extract:extract+1]
            shift = shift[:extract] + shift[extract+1:]
            shift = shift[:insert] + shift_words + shift[insert:]
            return shift
        elif r == 2:
            neighbor = solution.copy()
            if len(neighbor) < 2:
                return neighbor
            start = random.randint(0, len(neighbor) - 2)
            end = random.randint(start + 1, len(neighbor) - 1)
            neighbor[start:end+1] = reversed(neighbor[start:end+1])
            return neighbor
        else:
            #  block_size = random.choice(range(2, 5))
            #  block_size = 2
            block_size = r-1
            neighbor = solution.copy()
            if len(neighbor) < block_size + 1:
                return neighbor
            start = random.randint(0, len(neighbor) - block_size)
            block = neighbor[start:start + block_size]
            insert_pos = random.randint(0, len(neighbor) - block_size)
            # ブロックを削除
            del neighbor[start:start + block_size]
            # 挿入位置にブロックを挿入
            neighbor = neighbor[:insert_pos] + block + neighbor[insert_pos:]
            return neighbor

    def _acceptance_probability(self, current_energy, new_energy, temperature):
        """
        Calculate the probability of accepting a new solution.
        新しい解を受け入れる確率を計算
        """
        if new_energy < current_energy:
            return 1.0
        return exp((current_energy - new_energy) / temperature)

    def _lower_temperature(self, temperature, iteration):
        """
        温度を指数関数的に減少させる。
        """
        # 指数関数的減少
        new_temperature = self.start_temp * (self.alpha ** iteration)
        
        return new_temperature
    def solve(self, text):
        current_solution = text.split()
        current_energy = scorer.get_perplexity(' '.join(current_solution))

        best_solution = current_solution.copy()
        best_energy = current_energy

        temperature = self.start_temp
        
        log_energies = [current_energy]
        start_time = time.time()
        spend_minute = 0
        for iteration in range(self.max_iterations):
            # generate neighbor
            new_solution = self._generate_neighbor(current_solution)
            new_energy = scorer.get_perplexity(' '.join(new_solution))

            # calculation of acceptance probability
            acceptance = self._acceptance_probability(
                current_energy, new_energy, temperature
            )
            
            # update current solution
            if acceptance > random.random():
                current_solution = new_solution
                current_energy = new_energy
                
            # update best solution
            if new_energy < best_energy:
                best_solution = new_solution.copy()
                best_energy = new_energy
                print(f"best_score:{best_energy}")

            # lower the temperature
            temperature = self._lower_temperature(temperature, iteration)
            # print("temperature:", temperature)

            # log
            log_energies.append(current_energy)
            current_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
            if time.time()-start_time-60*spend_minute > 60:
                spend_minute += 1
                print(f"{current_time} progress:{iteration/self.max_iterations}, current_score:{current_energy}, temperature:{temperature}, best_score:{best_energy}")
                
            if temperature <= self.end_temp:
                print("最低温度に到達しました。終了します。")
                break


　　　　　print(f"execution time:{time.time()-start_time}")
        return ' '.join(best_solution), best_energy, log_energies

# %%
sa_params = {
    'start_temp': 20,          # 最初の温度
    'end_temp': 0.001,             # 最後の温度　線形に下げていく
    'max_iterations': 20000,  # 反復回数100000回で4時間程度か
    'random_state': 42,
    "alpha":0.9999
}
sa_optimizer = SimulatedAnnealing(**sa_params)

# %%
solution, score_2, log_scores = sa_optimizer.solve(solutions[0])
# Out:
# 2024-12-19 11:56:22 progress:0.02365, current_score:343.23836910430924, temperature:7.558184680121949, best_score:223.76094023954994
# 2024-12-19 11:57:22 progress:0.04725, current_score:329.31436324525856, temperature:6.162722317272236, best_score:223.76094023954994
# 2024-12-19 11:58:22 progress:0.07085, current_score:363.21700216641045, temperature:5.345358021055214, best_score:223.76094023954994
# 2024-12-19 11:59:22 progress:0.09435, current_score:356.0200770240245, temperature:4.767268980449284, best_score:223.76094023954994
# 2024-12-19 12:00:21 progress:0.1178, current_score:291.59613323408524, temperature:4.319226124037714, best_score:223.76094023954994
# 2024-12-19 12:01:22 progress:0.1413, current_score:292.96292979533825, temperature:3.952049521751576, best_score:223.76094023954994
# 2024-12-19 12:02:22 progress:0.16485, current_score:270.8064042317932, temperature:3.640862858156467, best_score:223.76094023954994
# 2024-12-19 12:03:22 progress:0.18845, current_score:254.50936553047038, temperature:3.3707531348560806, best_score:223.76094023954994
# 2024-12-19 12:04:22 progress:0.21205, current_score:237.35395711792842, temperature:3.1325474309265395, best_score:223.76094023954994
# 2024-12-19 12:05:22 progress:0.23565, current_score:258.01521858519516, temperature:2.919498966723303, best_score:223.76094023954994
# 2024-12-19 12:06:22 progress:0.25925, current_score:245.13769851877785, temperature:2.7267979024535727, best_score:223.76094023954994
# 2024-12-19 12:07:22 progress:0.28285, current_score:239.72402666165866, temperature:2.5508942318256906, best_score:223.76094023954994
# best_score:220.86118244417946
# best_score:215.42091958192194
# 2024-12-19 12:08:22 progress:0.3065, current_score:227.50032796461647, temperature:2.388763516178628, best_score:215.42091958192194
# 2024-12-19 12:09:22 progress:0.3301, current_score:217.38884037411836, temperature:2.2389937723134565, best_score:215.42091958192194
# best_score:213.23702628476815
# best_score:210.80148526421192
# best_score:205.96187486408058
# best_score:201.87711065312067
# 2024-12-19 12:10:22 progress:0.3537, current_score:201.87711065312067, temperature:2.0995690469731976, best_score:201.87711065312067
# best_score:200.13070924612026
# 2024-12-19 12:11:21 progress:0.3773, current_score:200.13070924612026, temperature:1.9691520918104324, best_score:200.13070924612026
# 2024-12-19 12:12:22 progress:0.40095, current_score:200.13070924612026, temperature:1.8463974723696914, best_score:200.13070924612026
# best_score:199.23947705634268
# best_score:191.29807565247134
# 2024-12-19 12:13:22 progress:0.42455, current_score:191.29807565247134, temperature:1.730916994085316, best_score:191.29807565247134
# best_score:191.27618457772925
# 2024-12-19 12:14:22 progress:0.44815, current_score:195.51901806688073, temperature:1.6216846976115313, best_score:191.27618457772925
# best_score:189.4250216892922
# best_score:186.24654099491036
# best_score:180.11617963770513
# best_score:179.50065755035243
# best_score:179.0168566864088
# best_score:178.11727617584373
# best_score:166.17610119585234
# 2024-12-19 12:15:22 progress:0.47175, current_score:166.62233907140103, temperature:1.5180590192905505, best_score:166.17610119585234
# best_score:165.91600504022688
# best_score:164.22912713268295
# best_score:157.25369209567148
# best_score:153.0652404596082
# 2024-12-19 12:16:22 progress:0.4954, current_score:153.34627988551122, temperature:1.4192885997018365, best_score:153.0652404596082
# best_score:147.47568445009662
# 2024-12-19 12:17:22 progress:0.519, current_score:147.7818316624573, temperature:1.3253192474284248, best_score:147.47568445009662
# best_score:145.71042553000913
# 2024-12-19 12:18:22 progress:0.5426, current_score:145.71042553000913, temperature:1.2355288996740832, best_score:145.71042553000913
# best_score:144.9901047264699
# 2024-12-19 12:19:22 progress:0.5662, current_score:148.43757638456478, temperature:1.1495616316586315, best_score:144.9901047264699
# 2024-12-19 12:20:22 progress:0.5898, current_score:148.9845119384483, temperature:1.0671051384113674, best_score:144.9901047264699
# 2024-12-19 12:21:22 progress:0.6134, current_score:152.4735122050632, temperature:0.9878838859619385, best_score:144.9901047264699
# 2024-12-19 12:22:21 progress:0.637, current_score:150.05946181639433, temperature:0.9116535560914052, best_score:144.9901047264699
# 2024-12-19 12:23:22 progress:0.66065, current_score:149.5604177454299, temperature:0.8380436751109741, best_score:144.9901047264699
# 2024-12-19 12:24:22 progress:0.6843, current_score:150.35412359914935, temperature:0.7670229010509289, best_score:144.9901047264699
# 2024-12-19 12:25:22 progress:0.708, current_score:149.0321172479005, temperature:0.6982726639280905, best_score:144.9901047264699
# 2024-12-19 12:26:22 progress:0.7317, current_score:145.02218769020652, temperature:0.6317861856938407, best_score:144.9901047264699
# best_score:144.5184626397855
# best_score:143.96114791576431
# best_score:143.48703713578246
# 2024-12-19 12:27:22 progress:0.7554, current_score:143.48703713578246, temperature:0.5674191275286837, best_score:143.48703713578246
# best_score:141.78507072435477
# best_score:141.11355682216697
# best_score:141.0191830668786
# best_score:140.63849620881695
# 2024-12-19 12:28:22 progress:0.7791, current_score:140.63849620881695, temperature:0.5050405298879319, best_score:140.63849620881695
# best_score:139.61944869085914
# best_score:138.842615119425
# best_score:138.63898462180646
# 2024-12-19 12:29:22 progress:0.8028, current_score:138.63898462180646, temperature:0.4445312083790256, best_score:138.63898462180646
# best_score:138.0240256210818
# best_score:137.92724572541667
# 2024-12-19 12:30:21 progress:0.82645, current_score:137.92724572541667, temperature:0.38590454388861417, best_score:137.92724572541667
# 2024-12-19 12:31:22 progress:0.8502, current_score:137.92724572541667, temperature:0.328694501609899, best_score:137.92724572541667
# best_score:134.78074272355684
# 2024-12-19 12:32:22 progress:0.8739, current_score:134.78074272355684, temperature:0.2731762241977549, best_score:134.78074272355684
# 2024-12-19 12:33:22 progress:0.89755, current_score:134.78074272355684, temperature:0.21925602895314, best_score:134.78074272355684
# best_score:132.5441981282947
# best_score:130.71915495319084
# 2024-12-19 12:34:22 progress:0.92125, current_score:130.71915495319084, temperature:0.16662861546086916, best_score:130.71915495319084
# best_score:129.8365386395449
# best_score:129.32844220516836
# 2024-12-19 12:35:22 progress:0.94495, current_score:129.32844220516836, temperature:0.11533797050342542, best_score:129.32844220516836
# best_score:128.45993249769896
# 2024-12-19 12:36:22 progress:0.96865, current_score:128.45993249769896, temperature:0.06531786342878831, best_score:128.45993249769896
# best_score:124.47463060455415
# 2024-12-19 12:37:22 progress:0.99235, current_score:124.47463060455415, temperature:0.01650686696238779, best_score:124.47463060455415
# best_score:123.61885042096283
# execution time:2539.304804801941

# %%
import matplotlib.pyplot as plt
plt.plot(log_scores)

plt.title(f'id = {4}, num of word = {len(text.split())}')
plt.xlabel('sa_iteration')
plt.ylabel('score')
plt.legend()
plt.show()

print(f'SA Score: {score_2}')
# Out:
# SA Score: 123.61885042096283

# %%
print(scorer.get_perplexity(solution), solution)
# Out:
# 123.61885042096283 wrapping paper bow fruitcake chocolate peppermint candy cookie milk and eggnog the of to in have not it with that from as we wish you merry season greeting card kaggle workshop toy doll game night puzzle snowglobe candle fireplace wreath poinsettia star angel dream believe wonder joy peace hope hohoho

# %%
print(scorer.get_perplexity(most_best_text))
# Out:
# 94.97277748044158

# %%
scorer.get_perplexity(' '.join(most_best_text.split()[:50]))
# Out:
# 94.97277748044158

# %%
p = '/kaggle/input/santa-2024/sample_submission.csv'
df = pd.read_csv(p)

# %%
t = """reindeer mistletoe elf gingerbread family advent scrooge chimney fireplace ornament
reindeer sleep walk the night and drive mistletoe scrooge laugh chimney jump elf bake gingerbread family give advent fireplace ornament
magi yuletide cheer grinch carol holiday holly jingle naughty nice nutcracker polar beard ornament stocking chimney sleigh workshop gifts decorations
sleigh of the magi yuletide cheer is unwrap gifts and eat cheer holiday decorations holly jingle relax carol sing chimney visit grinch naughty nice polar beard workshop nutcracker ornament stocking
from and as have in not it of that the to we with you bow angel believe candle candy card chocolate cookie doll dream eggnog fireplace fruitcake game greeting hohoho hope joy kaggle merry milk night peace peppermint poinsettia puzzle season snowglobe star toy wreath wish workshop wonder wrapping paper
from and and as and have the in is it of not that the to we with you advent card angel bake beard believe bow candy candle carol cheer cheer chocolate chimney cookie decorations doll dream drive eat eggnog family fireplace fireplace chimney fruitcake game give gifts gingerbread greeting grinch holiday holly hohoho hope jingle jump joy kaggle laugh magi merry milk mistletoe naughty nice night night elf nutcracker ornament ornament of the wrapping paper peace peppermint polar poinsettia puzzle reindeer relax scrooge season sing sleigh sleep snowglobe star stocking toy unwrap visit walk wish wonder workshop workshop wreath yuletide"""

df['text'] = t.split('\n')
df.loc[4, "text"] = solution
df['score'] = df['text'].map(lambda x: scorer.get_perplexity(x))
df.to_csv("submission.csv", index=False)
print(np.mean(df['score']))
df['score']
# Out:
# 259.8156755198523
# 0    468.961335
# 1    421.728839
# 2    302.640572
# 3    207.300886
# 4    123.618850
# 5     34.643570
# Name: score, dtype: float64

# %%
df
# Out:
#    id                                               text       score
# 0   0  reindeer mistletoe elf gingerbread family adve...  468.961335
# 1   1  reindeer sleep walk the night and drive mistle...  421.728839
# 2   2  magi yuletide cheer grinch carol holiday holly...  302.640572
# 3   3  sleigh of the magi yuletide cheer is unwrap gi...  207.300886
# 4   4  wrapping paper bow fruitcake chocolate pepperm...  123.618850
# 5   5  from and and as and have the in is it of not t...   34.643570

# %%
10**20*0.9999**20000
# Out:
# 1.3532174948276005e+19
