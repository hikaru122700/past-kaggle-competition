# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/055.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_054.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_054.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_11_in_lbs', 'TRI_Air_Emissions_12_in_lbs',
#        'TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'oof_predictions',
#        'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 2503                1            1                                   523,079
# 2504                9            1                                   100,312
# 2505                8            0                                   134,940
# 2506                8            0                                   262,619
# 2507                9            1                                 1,295,969
#
#       oof_predictions
# 0              41,547
# 1              59,347
# 2              99,121
# 3              51,450
# 4              51,060
# ...               ...
# 2503              NaN
# 2504              NaN
# 2505              NaN
# 2506              NaN
# 2507              NaN
#
# [7163 rows x 20 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 1

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
test_df = train_all_df[4655:]

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                          32,075                       26,446
# 3                          42,504                       43,906
# 4                          39,898                       40,203
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                          23,385           130
# 3                          42,958            82
# 4                          39,437           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           44,594   NaN
# 1                  14            1          296,645   NaN
# 2                   8            0           41,032   NaN
# 3                   8            0           30,125   NaN
# 4                   8            0           47,570   NaN
# ...               ...          ...              ...   ...
# 2503                1            1          523,079   NaN
# 2504                9            1          100,312   NaN
# 2505                8            0          134,940   NaN
# 2506                8            0          262,619   NaN
# 2507                9            1        1,295,969   NaN
#
# [2508 rows x 20 columns]

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
test_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                          32,075                       26,446
# 3                          42,504                       43,906
# 4                          39,898                       40,203
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                       23,592                       25,069
# 2506                      140,816                       93,119
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                          23,385           130
# 3                          42,958            82
# 4                          39,437           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           44,594   NaN
# 1                  14            1          296,645   NaN
# 2                   8            0           41,032   NaN
# 3                   8            0           30,125   NaN
# 4                   8            0           47,570   NaN
# ...               ...          ...              ...   ...
# 2503                1            1          523,079   NaN
# 2504                9            1          100,312   NaN
# 2505                8            0          134,940   NaN
# 2506                8            0          262,619   NaN
# 2507                9            1        1,295,969   NaN
#
# [2508 rows x 20 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
oof_predictions,test_preds, _ = get_models_trained(train,test,train_target,30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.30021861798524935
# Fold 1 RMSLE for model2 = 0.3064244597794432
# Fold 1 RMSLE for model3 = 0.3016815074599231
# Fold 1 RMSLE for model4 = 0.29822835412843124
# Fold 1 RMSLE for ('model1', 'model2') = 0.30283869815215797
# Fold 1 RMSLE for ('model1', 'model3') = 0.300812915879972
# Fold 1 RMSLE for ('model1', 'model4') = 0.29905748221431416
# Fold 1 RMSLE for ('model2', 'model3') = 0.30372045085818145
# Fold 1 RMSLE for ('model2', 'model4') = 0.30198269568867764
# Fold 1 RMSLE for ('model3', 'model4') = 0.29975081221932726
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.3023508445076411
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.30118165314248974
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.29981739772761057
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.30171970216367067
# Fold 1 RMSLE for all models ensemble = 0.3012207453054888
# Fold 1 best combination: model4 with RMSLE = 0.29822835412843124
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.32948803840027285
# Fold 2 RMSLE for model2 = 0.3319684516519879
# Fold 2 RMSLE for model3 = 0.3288546768980556
# Fold 2 RMSLE for model4 = 0.3303378656201208
# Fold 2 RMSLE for ('model1', 'model2') = 0.3299708295320716
# Fold 2 RMSLE for ('model1', 'model3') = 0.32904562746059024
# Fold 2 RMSLE for ('model1', 'model4') = 0.3296017404392248
# Fold 2 RMSLE for ('model2', 'model3') = 0.32974943032969567
# Fold 2 RMSLE for ('model2', 'model4') = 0.3307063300398228
# Fold 2 RMSLE for ('model3', 'model4') = 0.3292543337514045
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.32941615375473005
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.3299243017017853
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.32921389912942983
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.32974191295425676
# Fold 2 RMSLE for all models ensemble = 0.3295003407338475
# Fold 2 best combination: model3 with RMSLE = 0.3288546768980556
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.3082207098731814
# Fold 3 RMSLE for model2 = 0.30439885526250854
# Fold 3 RMSLE for model3 = 0.30824731040905573
# Fold 3 RMSLE for model4 = 0.30568635023427904
# Fold 3 RMSLE for ('model1', 'model2') = 0.30561896704317515
# Fold 3 RMSLE for ('model1', 'model3') = 0.3080893730075659
# Fold 3 RMSLE for ('model1', 'model4') = 0.30674184725418463
# Fold 3 RMSLE for ('model2', 'model3') = 0.30550257877400194
# Fold 3 RMSLE for ('model2', 'model4') = 0.3044113413766379
# Fold 3 RMSLE for ('model3', 'model4') = 0.30654247340146584
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.3062207425037282
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.3054207117929983
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.3070380156392082
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.3052769783150329
# Fold 3 RMSLE for all models ensemble = 0.30590821538303364
# Fold 3 best combination: model2 with RMSLE = 0.30439885526250854
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.3414571823626847
# Fold 4 RMSLE for model2 = 0.34236857836879464
# Fold 4 RMSLE for model3 = 0.34153239691269
# Fold 4 RMSLE for model4 = 0.341002579568426
# Fold 4 RMSLE for ('model1', 'model2') = 0.34119479441795864
# Fold 4 RMSLE for ('model1', 'model3') = 0.34140435799053903
# Fold 4 RMSLE for ('model1', 'model4') = 0.34109730532750215
# Fold 4 RMSLE for ('model2', 'model3') = 0.34130132359671683
# Fold 4 RMSLE for ('model2', 'model4') = 0.3411937426484115
# Fold 4 RMSLE for ('model3', 'model4') = 0.3411008311191658
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.3411379712260897
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.3410124969581113
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.34115753818638633
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.34105307197600493
# Fold 4 RMSLE for all models ensemble = 0.3410276900451567
# Fold 4 best combination: model4 with RMSLE = 0.341002579568426
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.32871664419543495
# Fold 5 RMSLE for model2 = 0.3374206721133844
# Fold 5 RMSLE for model3 = 0.3286338566012842
# Fold 5 RMSLE for model4 = 0.3319748223532282
# Fold 5 RMSLE for ('model1', 'model2') = 0.33231323191506806
# Fold 5 RMSLE for ('model1', 'model3') = 0.3285746748956563
# Fold 5 RMSLE for ('model1', 'model4') = 0.3301670064057062
# Fold 5 RMSLE for ('model2', 'model3') = 0.3323805988575414
# Fold 5 RMSLE for ('model2', 'model4') = 0.33420083642770326
# Fold 5 RMSLE for ('model3', 'model4') = 0.33010706331940387
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.3309201817709571
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.33206684674388914
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.3295631523869513
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.3320794307468558
# Fold 5 RMSLE for all models ensemble = 0.33109061060538786
# Fold 5 best combination: ('model1', 'model3') with RMSLE = 0.3285746748956563
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.28772515937387444
# Fold 6 RMSLE for model2 = 0.28972314236770247
# Fold 6 RMSLE for model3 = 0.2872754384816408
# Fold 6 RMSLE for model4 = 0.28863288019551886
# Fold 6 RMSLE for ('model1', 'model2') = 0.28804393402161593
# Fold 6 RMSLE for ('model1', 'model3') = 0.2873845050546854
# Fold 6 RMSLE for ('model1', 'model4') = 0.2879605170041541
# Fold 6 RMSLE for ('model2', 'model3') = 0.2879004570143611
# Fold 6 RMSLE for ('model2', 'model4') = 0.28859147818552633
# Fold 6 RMSLE for ('model3', 'model4') = 0.28771305473680875
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.2876206791223921
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.2880332211076673
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.28762200808181176
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.28790940876086707
# Fold 6 RMSLE for all models ensemble = 0.2877282770207127
# Fold 6 best combination: model3 with RMSLE = 0.2872754384816408
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.3120089512528643
# Fold 7 RMSLE for model2 = 0.31597879596652884
# Fold 7 RMSLE for model3 = 0.31359786335654666
# Fold 7 RMSLE for model4 = 0.3129317626169683
# Fold 7 RMSLE for ('model1', 'model2') = 0.3132802458309815
# Fold 7 RMSLE for ('model1', 'model3') = 0.31267746276480474
# Fold 7 RMSLE for ('model1', 'model4') = 0.31229166480213816
# Fold 7 RMSLE for ('model2', 'model3') = 0.31418419231977157
# Fold 7 RMSLE for ('model2', 'model4') = 0.3139658455576902
# Fold 7 RMSLE for ('model3', 'model4') = 0.31304241304853236
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.3132194570107925
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.31302504706693896
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.31261190605383077
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.31358407299650753
# Fold 7 RMSLE for all models ensemble = 0.3130449475388391
# Fold 7 best combination: model1 with RMSLE = 0.3120089512528643
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.30452707285361724
# Fold 8 RMSLE for model2 = 0.3088462204262025
# Fold 8 RMSLE for model3 = 0.30366595111269934
# Fold 8 RMSLE for model4 = 0.3064026493077614
# Fold 8 RMSLE for ('model1', 'model2') = 0.3055793440433824
# Fold 8 RMSLE for ('model1', 'model3') = 0.30395094592342814
# Fold 8 RMSLE for ('model1', 'model4') = 0.305255781692695
# Fold 8 RMSLE for ('model2', 'model3') = 0.3052978734953111
# Fold 8 RMSLE for ('model2', 'model4') = 0.3069266341222129
# Fold 8 RMSLE for ('model3', 'model4') = 0.3047571023321253
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.30469494439927425
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.3056958976409242
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.3045842910333913
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.3054448460170377
# Fold 8 RMSLE for all models ensemble = 0.30501003560213685
# Fold 8 best combination: model3 with RMSLE = 0.30366595111269934
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.3264463119345077
# Fold 9 RMSLE for model2 = 0.3333428965851923
# Fold 9 RMSLE for model3 = 0.3264151239708035
# Fold 9 RMSLE for model4 = 0.330513188113206
# Fold 9 RMSLE for ('model1', 'model2') = 0.3291261457786603
# Fold 9 RMSLE for ('model1', 'model3') = 0.3263143842165017
# Fold 9 RMSLE for ('model1', 'model4') = 0.3282197564533065
# Fold 9 RMSLE for ('model2', 'model3') = 0.3292348855219671
# Fold 9 RMSLE for ('model2', 'model4') = 0.33151782941508867
# Fold 9 RMSLE for ('model3', 'model4') = 0.32817376188797426
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.32805340243716663
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.3294611003053486
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.3274949058459181
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.3294924563035297
# Fold 9 RMSLE for all models ensemble = 0.3285558414426913
# Fold 9 best combination: ('model1', 'model3') with RMSLE = 0.3263143842165017
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.32916207177720863
# Fold 10 RMSLE for model2 = 0.33646338694949196
# Fold 10 RMSLE for model3 = 0.3313283978312497
# Fold 10 RMSLE for model4 = 0.3318780827352317
# Fold 10 RMSLE for ('model1', 'model2') = 0.3322011634830715
# Fold 10 RMSLE for ('model1', 'model3') = 0.3301349790265483
# Fold 10 RMSLE for ('model1', 'model4') = 0.3303726837753714
# Fold 10 RMSLE for ('model2', 'model3') = 0.333291156738774
# Fold 10 RMSLE for ('model2', 'model4') = 0.33370596570607086
# Fold 10 RMSLE for ('model3', 'model4') = 0.3314300420632467
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.3317269732073806
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.3319563620844155
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.3305979617612649
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.3326701700205622
# Fold 10 RMSLE for all models ensemble = 0.33167866318316747
# Fold 10 best combination: model1 with RMSLE = 0.32916207177720863
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.3156323749852435
# Fold 11 RMSLE for model2 = 0.3188100080798553
# Fold 11 RMSLE for model3 = 0.3151565937101172
# Fold 11 RMSLE for model4 = 0.3183459249727753
# Fold 11 RMSLE for ('model1', 'model2') = 0.31631851505312353
# Fold 11 RMSLE for ('model1', 'model3') = 0.3152545274696128
# Fold 11 RMSLE for ('model1', 'model4') = 0.31679305342005204
# Fold 11 RMSLE for ('model2', 'model3') = 0.31616320490267075
# Fold 11 RMSLE for ('model2', 'model4') = 0.3179642864290578
# Fold 11 RMSLE for ('model3', 'model4') = 0.31650409757948617
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.3157039177031217
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.3168347573319459
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.3161189641932034
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.3166901018864198
# Fold 11 RMSLE for all models ensemble = 0.3162555336206846
# Fold 11 best combination: model3 with RMSLE = 0.3151565937101172
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.32845962720852595
# Fold 12 RMSLE for model2 = 0.32297780922800895
# Fold 12 RMSLE for model3 = 0.32726418631280424
# Fold 12 RMSLE for model4 = 0.32419319232556915
# Fold 12 RMSLE for ('model1', 'model2') = 0.3249111502961821
# Fold 12 RMSLE for ('model1', 'model3') = 0.3277233140374412
# Fold 12 RMSLE for ('model1', 'model4') = 0.3260830024875138
# Fold 12 RMSLE for ('model2', 'model3') = 0.3243694400795963
# Fold 12 RMSLE for ('model2', 'model4') = 0.323103178877868
# Fold 12 RMSLE for ('model3', 'model4') = 0.3254312673411846
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.32548070427909953
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.324528813869901
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.3263372521294391
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.32413116200430453
# Fold 12 RMSLE for all models ensemble = 0.3250441991215571
# Fold 12 best combination: model2 with RMSLE = 0.32297780922800895
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.3253349076081808
# Fold 13 RMSLE for model2 = 0.33092362147820753
# Fold 13 RMSLE for model3 = 0.3269196422770766
# Fold 13 RMSLE for model4 = 0.32571303668711826
# Fold 13 RMSLE for ('model1', 'model2') = 0.32736001629938893
# Fold 13 RMSLE for ('model1', 'model3') = 0.32596295429274963
# Fold 13 RMSLE for ('model1', 'model4') = 0.32529817106485087
# Fold 13 RMSLE for ('model2', 'model3') = 0.32805826985665726
# Fold 13 RMSLE for ('model2', 'model4') = 0.3278361041032514
# Fold 13 RMSLE for ('model3', 'model4') = 0.3259232042217809
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.32692590521311765
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.32666628205155335
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.3256409908508407
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.32707845142408
# Fold 13 RMSLE for all models ensemble = 0.32649680801457714
# Fold 13 best combination: ('model1', 'model4') with RMSLE = 0.32529817106485087
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.3241305587570186
# Fold 14 RMSLE for model2 = 0.3195793568726186
# Fold 14 RMSLE for model3 = 0.3231842025365045
# Fold 14 RMSLE for model4 = 0.3264508007918696
# Fold 14 RMSLE for ('model1', 'model2') = 0.321133498601998
# Fold 14 RMSLE for ('model1', 'model3') = 0.32349370976336544
# Fold 14 RMSLE for ('model1', 'model4') = 0.3250151658666788
# Fold 14 RMSLE for ('model2', 'model3') = 0.32072451617434156
# Fold 14 RMSLE for ('model2', 'model4') = 0.3225580940097887
# Fold 14 RMSLE for ('model3', 'model4') = 0.3245461344514439
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.32161344376480366
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.32274164316899756
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.3242725454884706
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.32245644171811033
# Fold 14 RMSLE for all models ensemble = 0.322700722686321
# Fold 14 best combination: model2 with RMSLE = 0.3195793568726186
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.3261875462122463
# Fold 15 RMSLE for model2 = 0.3320295057193358
# Fold 15 RMSLE for model3 = 0.32916606129039927
# Fold 15 RMSLE for model4 = 0.3250761404608376
# Fold 15 RMSLE for ('model1', 'model2') = 0.3283371401470649
# Fold 15 RMSLE for ('model1', 'model3') = 0.32753726592995425
# Fold 15 RMSLE for ('model1', 'model4') = 0.32542260059325795
# Fold 15 RMSLE for ('model2', 'model3') = 0.3299000090101309
# Fold 15 RMSLE for ('model2', 'model4') = 0.3279541593423242
# Fold 15 RMSLE for ('model3', 'model4') = 0.32688301804145814
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.32841160026085475
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.32706097014979824
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.3265491353036588
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.32807408217661477
# Fold 15 RMSLE for all models ensemble = 0.3274495803712011
# Fold 15 best combination: model4 with RMSLE = 0.3250761404608376
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.2944543284697883
# Fold 16 RMSLE for model2 = 0.29366315812260907
# Fold 16 RMSLE for model3 = 0.29516033994530216
# Fold 16 RMSLE for model4 = 0.2934555904394891
# Fold 16 RMSLE for ('model1', 'model2') = 0.2932402586644371
# Fold 16 RMSLE for ('model1', 'model3') = 0.2946794406020732
# Fold 16 RMSLE for ('model1', 'model4') = 0.2937683187458338
# Fold 16 RMSLE for ('model2', 'model3') = 0.29382267673722223
# Fold 16 RMSLE for ('model2', 'model4') = 0.29308293141035135
# Fold 16 RMSLE for ('model3', 'model4') = 0.29412928958574375
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.2937439023097693
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.2931991228546017
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.2941375690752205
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.29354003624149827
# Fold 16 RMSLE for all models ensemble = 0.29358919013304224
# Fold 16 best combination: ('model2', 'model4') with RMSLE = 0.29308293141035135
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.3275883338829005
# Fold 17 RMSLE for model2 = 0.3278340513811717
# Fold 17 RMSLE for model3 = 0.32730809526307336
# Fold 17 RMSLE for model4 = 0.3289217975394031
# Fold 17 RMSLE for ('model1', 'model2') = 0.3271256567606691
# Fold 17 RMSLE for ('model1', 'model3') = 0.32732282547280345
# Fold 17 RMSLE for ('model1', 'model4') = 0.3280714284026147
# Fold 17 RMSLE for ('model2', 'model3') = 0.32699762047145964
# Fold 17 RMSLE for ('model2', 'model4') = 0.32798602981496794
# Fold 17 RMSLE for ('model3', 'model4') = 0.32788916481758235
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.32700588061307473
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.3275987963209377
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.32770164948614533
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.32749199013850844
# Fold 17 RMSLE for all models ensemble = 0.3273916475350599
# Fold 17 best combination: ('model2', 'model3') with RMSLE = 0.32699762047145964
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.3072810887830629
# Fold 18 RMSLE for model2 = 0.3043282053378166
# Fold 18 RMSLE for model3 = 0.3061942262290934
# Fold 18 RMSLE for model4 = 0.30475002071034724
# Fold 18 RMSLE for ('model1', 'model2') = 0.30503107835643717
# Fold 18 RMSLE for ('model1', 'model3') = 0.30659997629462504
# Fold 18 RMSLE for ('model1', 'model4') = 0.3058356649687375
# Fold 18 RMSLE for ('model2', 'model3') = 0.3045618474842542
# Fold 18 RMSLE for ('model2', 'model4') = 0.30398931569827653
# Fold 18 RMSLE for ('model3', 'model4') = 0.3051788906574536
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.3052193136144184
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.304785127944384
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.3058037628437144
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.30440528126449445
# Fold 18 RMSLE for all models ensemble = 0.3049803825077815
# Fold 18 best combination: ('model2', 'model4') with RMSLE = 0.30398931569827653
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.32970194068486564
# Fold 19 RMSLE for model2 = 0.3305919370671368
# Fold 19 RMSLE for model3 = 0.32929682600101623
# Fold 19 RMSLE for model4 = 0.33007730844785155
# Fold 19 RMSLE for ('model1', 'model2') = 0.3294873552299399
# Fold 19 RMSLE for ('model1', 'model3') = 0.3293796762589725
# Fold 19 RMSLE for ('model1', 'model4') = 0.3297365350754255
# Fold 19 RMSLE for ('model2', 'model3') = 0.32944798909428474
# Fold 19 RMSLE for ('model2', 'model4') = 0.3299131341647454
# Fold 19 RMSLE for ('model3', 'model4') = 0.32953240037947745
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.3292963315151549
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.3295750927010492
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.32950201948471486
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.32951185580252407
# Fold 19 RMSLE for all models ensemble = 0.3294155482167843
# Fold 19 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.3292963315151549
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.3175317049574124
# Fold 20 RMSLE for model2 = 0.3174946601866098
# Fold 20 RMSLE for model3 = 0.3164248851764072
# Fold 20 RMSLE for model4 = 0.31789229537802066
# Fold 20 RMSLE for ('model1', 'model2') = 0.31673337721132827
# Fold 20 RMSLE for ('model1', 'model3') = 0.3167564892571229
# Fold 20 RMSLE for ('model1', 'model4') = 0.3173975251691967
# Fold 20 RMSLE for ('model2', 'model3') = 0.3164413904524773
# Fold 20 RMSLE for ('model2', 'model4') = 0.3171815261628232
# Fold 20 RMSLE for ('model3', 'model4') = 0.316727323659607
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.3164745884512794
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.31692561564855315
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.31685286399993196
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.31662084020438724
# Fold 20 RMSLE for all models ensemble = 0.31664121462020267
# Fold 20 best combination: model3 with RMSLE = 0.3164248851764072
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.3417979256306587
# Fold 21 RMSLE for model2 = 0.3482271161083701
# Fold 21 RMSLE for model3 = 0.3412955763923025
# Fold 21 RMSLE for model4 = 0.3440782213482508
# Fold 21 RMSLE for ('model1', 'model2') = 0.3443927000350115
# Fold 21 RMSLE for ('model1', 'model3') = 0.34139111284432033
# Fold 21 RMSLE for ('model1', 'model4') = 0.34277938507165534
# Fold 21 RMSLE for ('model2', 'model3') = 0.3442625676743444
# Fold 21 RMSLE for ('model2', 'model4') = 0.3457158769028651
# Fold 21 RMSLE for ('model3', 'model4') = 0.3425350691856584
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.3432059861783857
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.34416021076691544
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.34218337757164213
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.3440496103441432
# Fold 21 RMSLE for all models ensemble = 0.34334318389928725
# Fold 21 best combination: model3 with RMSLE = 0.3412955763923025
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.35938627408486695
# Fold 22 RMSLE for model2 = 0.36096442284697905
# Fold 22 RMSLE for model3 = 0.3596103013430174
# Fold 22 RMSLE for model4 = 0.35794899878578407
# Fold 22 RMSLE for ('model1', 'model2') = 0.35960187012713946
# Fold 22 RMSLE for ('model1', 'model3') = 0.3593761731950487
# Fold 22 RMSLE for ('model1', 'model4') = 0.3585070434651657
# Fold 22 RMSLE for ('model2', 'model3') = 0.3597840582631992
# Fold 22 RMSLE for ('model2', 'model4') = 0.3590091909317471
# Fold 22 RMSLE for ('model3', 'model4') = 0.3585331020108676
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.3594538839288455
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.3589076518878035
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.35874666523620496
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.3589754313537265
# Fold 22 RMSLE for all models ensemble = 0.35896370304730785
# Fold 22 best combination: model4 with RMSLE = 0.35794899878578407
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.35136566972216926
# Fold 23 RMSLE for model2 = 0.3507118919923546
# Fold 23 RMSLE for model3 = 0.35227068218359675
# Fold 23 RMSLE for model4 = 0.35098492651835084
# Fold 23 RMSLE for ('model1', 'model2') = 0.35043079457114656
# Fold 23 RMSLE for ('model1', 'model3') = 0.351705641183646
# Fold 23 RMSLE for ('model1', 'model4') = 0.35097887556289875
# Fold 23 RMSLE for ('model2', 'model3') = 0.3509932339026518
# Fold 23 RMSLE for ('model2', 'model4') = 0.350478609861188
# Fold 23 RMSLE for ('model3', 'model4') = 0.3513897239703874
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.35090804459954594
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.35049894463215864
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.35129730731177883
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.3508309333182492
# Fold 23 RMSLE for all models ensemble = 0.35082764881064604
# Fold 23 best combination: ('model1', 'model2') with RMSLE = 0.35043079457114656
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.3168751165421803
# Fold 24 RMSLE for model2 = 0.31997042542763593
# Fold 24 RMSLE for model3 = 0.3131346129585806
# Fold 24 RMSLE for model4 = 0.3189748639285665
# Fold 24 RMSLE for ('model1', 'model2') = 0.3177079654585505
# Fold 24 RMSLE for ('model1', 'model3') = 0.31474943099805996
# Fold 24 RMSLE for ('model1', 'model4') = 0.3177000784860513
# Fold 24 RMSLE for ('model2', 'model3') = 0.31588377707936993
# Fold 24 RMSLE for ('model2', 'model4') = 0.31908029070305005
# Fold 24 RMSLE for ('model3', 'model4') = 0.31573733217207084
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.3159304189524583
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.31801464256186907
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.3159736872559581
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.3167473755144319
# Fold 24 RMSLE for all models ensemble = 0.3165948395942553
# Fold 24 best combination: model3 with RMSLE = 0.3131346129585806
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.31171744406415036
# Fold 25 RMSLE for model2 = 0.3116012457158723
# Fold 25 RMSLE for model3 = 0.31051885397371476
# Fold 25 RMSLE for model4 = 0.3114430218883202
# Fold 25 RMSLE for ('model1', 'model2') = 0.31055627011674325
# Fold 25 RMSLE for ('model1', 'model3') = 0.3109530096942517
# Fold 25 RMSLE for ('model1', 'model4') = 0.31120907879224513
# Fold 25 RMSLE for ('model2', 'model3') = 0.30996812868137275
# Fold 25 RMSLE for ('model2', 'model4') = 0.31103148533799146
# Fold 25 RMSLE for ('model3', 'model4') = 0.31044489348145055
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.3102299841720218
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.3107138077366544
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.31074982931623035
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.31024602770243
# Fold 25 RMSLE for all models ensemble = 0.31038041637860675
# Fold 25 best combination: ('model2', 'model3') with RMSLE = 0.30996812868137275
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.31119580836188504
# Fold 26 RMSLE for model2 = 0.32000925536625396
# Fold 26 RMSLE for model3 = 0.3139402551691418
# Fold 26 RMSLE for model4 = 0.309875914106015
# Fold 26 RMSLE for ('model1', 'model2') = 0.31501621704062355
# Fold 26 RMSLE for ('model1', 'model3') = 0.31235584542178363
# Fold 26 RMSLE for ('model1', 'model4') = 0.31027529712043816
# Fold 26 RMSLE for ('model2', 'model3') = 0.31642513915248627
# Fold 26 RMSLE for ('model2', 'model4') = 0.3145593685518292
# Fold 26 RMSLE for ('model3', 'model4') = 0.311562763131003
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.3144479820715426
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.3131457694955849
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.311307058310208
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.31403959271370663
# Fold 26 RMSLE for all models ensemble = 0.3131696070984222
# Fold 26 best combination: model4 with RMSLE = 0.309875914106015
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.2963595373721039
# Fold 27 RMSLE for model2 = 0.2990596589186108
# Fold 27 RMSLE for model3 = 0.2975208945496587
# Fold 27 RMSLE for model4 = 0.2972682391181875
# Fold 27 RMSLE for ('model1', 'model2') = 0.2970410973447308
# Fold 27 RMSLE for ('model1', 'model3') = 0.29675907496045545
# Fold 27 RMSLE for ('model1', 'model4') = 0.29655128377692286
# Fold 27 RMSLE for ('model2', 'model3') = 0.29761035547788656
# Fold 27 RMSLE for ('model2', 'model4') = 0.2976810718531122
# Fold 27 RMSLE for ('model3', 'model4') = 0.2970318634473845
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.2969662916948368
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.296933649691519
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.29669102852860574
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.29727124169438573
# Fold 27 RMSLE for all models ensemble = 0.2968920369197757
# Fold 27 best combination: model1 with RMSLE = 0.2963595373721039
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.32961435294803604
# Fold 28 RMSLE for model2 = 0.3303952481145622
# Fold 28 RMSLE for model3 = 0.3286364896307372
# Fold 28 RMSLE for model4 = 0.328481630427807
# Fold 28 RMSLE for ('model1', 'model2') = 0.32934440648332997
# Fold 28 RMSLE for ('model1', 'model3') = 0.328943669822638
# Fold 28 RMSLE for ('model1', 'model4') = 0.32882866808698585
# Fold 28 RMSLE for ('model2', 'model3') = 0.3288036560217924
# Fold 28 RMSLE for ('model2', 'model4') = 0.32882901761346695
# Fold 28 RMSLE for ('model3', 'model4') = 0.3283442930391287
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.3288575336517112
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.3288348778938006
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.32863709757654824
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.32848781871803495
# Fold 28 RMSLE for all models ensemble = 0.32863198567536794
# Fold 28 best combination: ('model3', 'model4') with RMSLE = 0.3283442930391287
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.32934978237293216
# Fold 29 RMSLE for model2 = 0.331289181625581
# Fold 29 RMSLE for model3 = 0.3277520169656405
# Fold 29 RMSLE for model4 = 0.3296616785145574
# Fold 29 RMSLE for ('model1', 'model2') = 0.32968485752760457
# Fold 29 RMSLE for ('model1', 'model3') = 0.3283779172832081
# Fold 29 RMSLE for ('model1', 'model4') = 0.3293223051135863
# Fold 29 RMSLE for ('model2', 'model3') = 0.3290008583147685
# Fold 29 RMSLE for ('model2', 'model4') = 0.3300815058608267
# Fold 29 RMSLE for ('model3', 'model4') = 0.3284692883947631
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.3288731131439585
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.3295612778067255
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.32865715952413416
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.3290557240952834
# Fold 29 RMSLE for all models ensemble = 0.32897711822438974
# Fold 29 best combination: model3 with RMSLE = 0.3277520169656405
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.31646595618185835
# Fold 30 RMSLE for model2 = 0.31660685348897577
# Fold 30 RMSLE for model3 = 0.3130487928717299
# Fold 30 RMSLE for model4 = 0.31671734712497746
# Fold 30 RMSLE for ('model1', 'model2') = 0.3160107755581926
# Fold 30 RMSLE for ('model1', 'model3') = 0.3146429603496499
# Fold 30 RMSLE for ('model1', 'model4') = 0.31631900573944904
# Fold 30 RMSLE for ('model2', 'model3') = 0.3143659221485585
# Fold 30 RMSLE for ('model2', 'model4') = 0.3161583211580382
# Fold 30 RMSLE for ('model3', 'model4') = 0.3145890421646443
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.31488368133738015
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.31601792349401847
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.3151078402563099
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.3148974798986849
# Fold 30 RMSLE for all models ensemble = 0.3151662203023638
# Fold 30 best combination: model3 with RMSLE = 0.3130487928717299
# ---------------
#
# OOF RMSLE = 0.31992746901745295
# Sum of RMSLE for each combination:
# ('model1',): 9.62840103883898
# ('model2',): 9.694003072549801
# ('model3',): 9.62503605781386
# ('model4',): 9.637899484387273
# ('model1', 'model2'): 9.639632355101787
# ('model1', 'model3'): 9.622354241352074
# ('model1', 'model4'): 9.62665827237816
# ('model2', 'model3'): 9.640147608485847
# ('model2', 'model4'): 9.651396197955414
# ('model3', 'model4'): 9.623254049612031
# ('model1', 'model2', 'model3'): 9.628993857395528
# ('model1', 'model2', 'model4'): 9.634482616553338
# ('model1', 'model3', 'model4'): 9.621968879588763
# ('model2', 'model3', 'model4'): 9.633573528468343
# ('model1', 'model2', 'model3', 'model4'): 9.627676953638096

# %%
test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
train_df["preds"] = np.expm1(np.log1p(train_df["oof_predictions"])+oof_predictions)

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                       24,101                       19,192
# 4651                          NaN                          NaN
# 4652                       24,257                       25,344
# 4653                       25,345                       15,031
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 4650               15            0                                    45,925
# 4651                8            1                                   180,682
# 4652                8            0                                    30,586
# 4653                8            0                                    64,875
# 4654                9            1                                   131,885
#
#       oof_predictions   preds
# 0              41,547  41,803
# 1              59,347  58,019
# 2              99,121 102,828
# 3              51,450  51,470
# 4              51,060  50,993
# ...               ...     ...
# 4650           46,740  48,592
# 4651          170,355 166,250
# 4652           31,492  31,936
# 4653           66,290  64,096
# 4654          146,419 146,721
#
# [4654 rows x 21 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
# 対数変換
log_target = train_target
log_oof_predictions = oof_predictions

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (0.01, 0.01)

# %%
# 対数変換
log_target = np.log1p(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
log_oof_predictions = np.log1p(train_df["preds"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)
# after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return np.array(bin_centers), np.array(y_means)
x = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
y = train_df["preds"]
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 228941.697432405

# %%
# x = after_test_preds
# y = after_test_preds
# ビンに分けて平均を計算
num_bins = 100
bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 228941.697432405

# %%
submit [ 1 ]  =  test_df["oof_predictions"]
submit.to_csv('SMBC_55.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    44,594
# 1     4656   296,645
# 2     4657    41,032
# 3     4658    30,125
# 4     4659    47,570
# ...    ...       ...
# 2503  7158   523,079
# 2504  7159   100,312
# 2505  7160   134,940
# 2506  7161   262,619
# 2507  7162 1,295,969
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,178,469
# 110   4765 1,336,832
# 114   4769 1,152,868
# 148   4803 1,737,242
# 178   4833 1,435,507
# ...    ...       ...
# 2417  7072 1,186,077
# 2423  7078 1,213,594
# 2466  7121 1,536,581
# 2490  7145 1,385,582
# 2507  7162 1,295,969
#
# [104 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Wed Nov 27 07:23:56 2024

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], train_df["preds"])
# Out:
# 0.3196771288874377

# %%
train_df
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 0                          26,645                       23,410
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          28,338                       30,841
# ...                           ...                          ...
# 4650                       24,101                       19,192
# 4651                          NaN                          NaN
# 4652                       24,257                       25,344
# 4653                       25,345                       15,031
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  GHG_Direct_Emissions_14_in_metric_tons.1  \
# 0                   8            0                                    52,973
# 1                  14            1                                    55,910
# 2                   9            1                                    55,680
# 3                  15            1                                    61,412
# 4                  15            0                                    43,100
# ...               ...          ...                                       ...
# 4650               15            0                                    45,925
# 4651                8            1                                   180,682
# 4652                8            0                                    30,586
# 4653                8            0                                    64,875
# 4654                9            1                                   131,885
#
#       oof_predictions   preds
# 0              41,547  41,803
# 1              59,347  58,019
# 2              99,121 102,828
# 3              51,450  51,470
# 4              51,060  50,993
# ...               ...     ...
# 4650           46,740  48,592
# 4651          170,355 166,250
# 4652           31,492  31,936
# 4653           66,290  64,096
# 4654          146,419 146,721
#
# [4654 rows x 21 columns]
