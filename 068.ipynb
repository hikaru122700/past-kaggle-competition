# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_067.csv', index_col=0)

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_067.csv', index_col=0)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["GHG_Direct_Emissions_12_in_metric_tons"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
          train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
          "train_G13-train_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
          "train_log_G13-train_log_G14")
show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
          np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
          "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_13_in_lbs', 'PrimaryNAICS',
#        'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           42,892
# 1                  14            1           57,720
# 2                   9            1           97,385
# 3                  15            1           52,143
# 4                  15            0           51,220
# ...               ...          ...              ...
# 2503                1            1          537,502
# 2504                9            1           99,339
# 2505                8            0          137,959
# 2506                8            0          261,207
# 2507                9            1        1,383,562
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   549,521
# 2504                                    98,313
# 2505                                   140,770
# 2506                                   259,066
# 2507                                 1,456,483
#
# [7163 rows x 18 columns]

# %%
diff = np.log1p(train_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_df['oof_predictions'])

# 2. 条件を満たす行のマスクを作成
mask = diff > 1
# 3. 除外する行の数をカウント
exclude_num = mask.sum()
# 4. 条件を満たさない行だけを保持
train_df = train_df[~mask]
print(f"除外された行の数: {exclude_num}")
# Out:
# 除外された行の数: 0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           42,892
# 1                  14            1           57,720
# 2                   9            1           97,385
# 3                  15            1           52,143
# 4                  15            0           51,220
# ...               ...          ...              ...
# 2503                1            1          537,502
# 2504                9            1           99,339
# 2505                8            0          137,959
# 2506                8            0          261,207
# 2507                9            1        1,383,562
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                       42,214
# 1                                       58,500
# 2                                       99,409
# 3                                       51,623
# 4                                       50,638
# ...                                        ...
# 2503                                   549,521
# 2504                                    98,313
# 2505                                   140,770
# 2506                                   259,066
# 2507                                 1,456,483
#
# [7163 rows x 18 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (4655, 7163, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:4655]
test_df = train_all_df[4655:]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0           42,892
# 1                  14            1           57,720
# 2                   9            1           97,385
# 3                  15            1           52,143
# 4                  15            0           51,220
# ...               ...          ...              ...
# 2503                1            1          537,502
# 2504                9            1           99,339
# 2505                8            0          137,959
# 2506                8            0          261,207
# 2507                9            1        1,383,562
#
#       GHG_Direct_Emissions_14_in_metric_tons.1  diff
# 0                                       42,214    -0
# 1                                       58,500     0
# 2                                       99,409     0
# 3                                       51,623    -0
# 4                                       50,638    -0
# ...                                        ...   ...
# 2503                                   549,521     0
# 2504                                    98,313    -0
# 2505                                   140,770     0
# 2506                                   259,066    -0
# 2507                                 1,456,483     0
#
# [7163 rows x 19 columns]

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")

    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           42,892    -0
# 1                  14            1           57,720     0
# 2                   9            1           97,385     0
# 3                  15            1           52,143    -0
# 4                  15            0           51,220    -0
# ...               ...          ...              ...   ...
# 4650               15            0           52,280    -0
# 4651                8            1          168,315     0
# 4652                8            0           31,986    -0
# 4653                8            0           64,828     0
# 4654                9            1          146,588    -0
#
# [4655 rows x 18 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
# Out:
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.019805640880808956
# Fold 1 RMSLE for model2 = 0.01769561487640758
# Fold 1 RMSLE for model3 = 0.020644371869008454
# Fold 1 RMSLE for model4 = 0.01699811283565564
# Fold 1 RMSLE for ('model1', 'model2') = 0.018584253167643117
# Fold 1 RMSLE for ('model1', 'model3') = 0.020181363728457403
# Fold 1 RMSLE for ('model1', 'model4') = 0.018177723465727935
# Fold 1 RMSLE for ('model2', 'model3') = 0.01886435651249795
# Fold 1 RMSLE for ('model2', 'model4') = 0.017293486279731297
# Fold 1 RMSLE for ('model3', 'model4') = 0.018477265003888205
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.019155837896796684
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.017966453366339744
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.018883020696436575
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.018126380498395257
# Fold 1 RMSLE for all models ensemble = 0.018501131120655098
# Fold 1 best combination: model4 with RMSLE = 0.01699811283565564
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.017481908630914738
# Fold 2 RMSLE for model2 = 0.017577836223288807
# Fold 2 RMSLE for model3 = 0.017629836620396612
# Fold 2 RMSLE for model4 = 0.0171243789288095
# Fold 2 RMSLE for ('model1', 'model2') = 0.017431558757423384
# Fold 2 RMSLE for ('model1', 'model3') = 0.01749385428380543
# Fold 2 RMSLE for ('model1', 'model4') = 0.017244230853251802
# Fold 2 RMSLE for ('model2', 'model3') = 0.017414180335684454
# Fold 2 RMSLE for ('model2', 'model4') = 0.017304914366139415
# Fold 2 RMSLE for ('model3', 'model4') = 0.017209521941489943
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.017407478681728494
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.01730410801978274
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.01728387720738378
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.017264252451876228
# Fold 2 RMSLE for all models ensemble = 0.0172974895970149
# Fold 2 best combination: model4 with RMSLE = 0.0171243789288095
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.017592368102962427
# Fold 3 RMSLE for model2 = 0.01832180448978428
# Fold 3 RMSLE for model3 = 0.017371988055132823
# Fold 3 RMSLE for model4 = 0.0177937314681309
# Fold 3 RMSLE for ('model1', 'model2') = 0.01782971704211121
# Fold 3 RMSLE for ('model1', 'model3') = 0.017406139610346136
# Fold 3 RMSLE for ('model1', 'model4') = 0.01762725862367784
# Fold 3 RMSLE for ('model2', 'model3') = 0.017559056941304187
# Fold 3 RMSLE for ('model2', 'model4') = 0.01800747574853857
# Fold 3 RMSLE for ('model3', 'model4') = 0.01742214650753627
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.017542982271391006
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.01779436909092299
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.017451540088537415
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.017608053843560064
# Fold 3 RMSLE for all models ensemble = 0.01757784268054283
# Fold 3 best combination: model3 with RMSLE = 0.017371988055132823
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.02344052890687446
# Fold 4 RMSLE for model2 = 0.02443115189653585
# Fold 4 RMSLE for model3 = 0.023082019333273595
# Fold 4 RMSLE for model4 = 0.02451314580449175
# Fold 4 RMSLE for ('model1', 'model2') = 0.023871543043400063
# Fold 4 RMSLE for ('model1', 'model3') = 0.02319410402556111
# Fold 4 RMSLE for ('model1', 'model4') = 0.023947111482950267
# Fold 4 RMSLE for ('model2', 'model3') = 0.0236471202078431
# Fold 4 RMSLE for ('model2', 'model4') = 0.024434027844875902
# Fold 4 RMSLE for ('model3', 'model4') = 0.023748002202721306
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.02354403462043179
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.024069602392131656
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.023613697870405254
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.02392150905949088
# Fold 4 RMSLE for all models ensemble = 0.023777352882216166
# Fold 4 best combination: model3 with RMSLE = 0.023082019333273595
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.018804313826149825
# Fold 5 RMSLE for model2 = 0.019833389018474448
# Fold 5 RMSLE for model3 = 0.018849412350115398
# Fold 5 RMSLE for model4 = 0.01835576902913395
# Fold 5 RMSLE for ('model1', 'model2') = 0.019133586033864933
# Fold 5 RMSLE for ('model1', 'model3') = 0.01876363202051334
# Fold 5 RMSLE for ('model1', 'model4') = 0.018448765408837966
# Fold 5 RMSLE for ('model2', 'model3') = 0.018981279053113306
# Fold 5 RMSLE for ('model2', 'model4') = 0.01901906375264606
# Fold 5 RMSLE for ('model3', 'model4') = 0.018326444278371646
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.018890214804010545
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.01882316417942432
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.018461132580360026
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.018696081820878337
# Fold 5 RMSLE for all models ensemble = 0.018686874913460653
# Fold 5 best combination: ('model3', 'model4') with RMSLE = 0.018326444278371646
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.016692179197148275
# Fold 6 RMSLE for model2 = 0.016626697355286324
# Fold 6 RMSLE for model3 = 0.017495354518327528
# Fold 6 RMSLE for model4 = 0.01691414266153193
# Fold 6 RMSLE for ('model1', 'model2') = 0.016582998059051574
# Fold 6 RMSLE for ('model1', 'model3') = 0.01688279550816672
# Fold 6 RMSLE for ('model1', 'model4') = 0.01669648812352027
# Fold 6 RMSLE for ('model2', 'model3') = 0.016772125299556857
# Fold 6 RMSLE for ('model2', 'model4') = 0.016681529733028843
# Fold 6 RMSLE for ('model3', 'model4') = 0.016679058300759362
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.01668050040082181
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.016623289435168623
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.01665721546904503
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.016608069363185603
# Fold 6 RMSLE for all models ensemble = 0.016605271377642998
# Fold 6 best combination: ('model1', 'model2') with RMSLE = 0.016582998059051574
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.018693699324336937
# Fold 7 RMSLE for model2 = 0.01933295522296556
# Fold 7 RMSLE for model3 = 0.019137914797146518
# Fold 7 RMSLE for model4 = 0.018839429890209158
# Fold 7 RMSLE for ('model1', 'model2') = 0.01892985187514118
# Fold 7 RMSLE for ('model1', 'model3') = 0.01888986977655455
# Fold 7 RMSLE for ('model1', 'model4') = 0.018741372391207243
# Fold 7 RMSLE for ('model2', 'model3') = 0.01908748985741058
# Fold 7 RMSLE for ('model2', 'model4') = 0.01904221298208025
# Fold 7 RMSLE for ('model3', 'model4') = 0.018935778634519097
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.018940015341994305
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.018887371309459
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.018844042476129072
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.018994327715295932
# Fold 7 RMSLE for all models ensemble = 0.01890573088672311
# Fold 7 best combination: model1 with RMSLE = 0.018693699324336937
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.016758585442020305
# Fold 8 RMSLE for model2 = 0.016924276391879763
# Fold 8 RMSLE for model3 = 0.016793356405928304
# Fold 8 RMSLE for model4 = 0.01652975053839741
# Fold 8 RMSLE for ('model1', 'model2') = 0.016778953400417095
# Fold 8 RMSLE for ('model1', 'model3') = 0.016749512748899555
# Fold 8 RMSLE for ('model1', 'model4') = 0.016624341811990562
# Fold 8 RMSLE for ('model2', 'model3') = 0.01674383870182728
# Fold 8 RMSLE for ('model2', 'model4') = 0.01669259652318326
# Fold 8 RMSLE for ('model3', 'model4') = 0.016611153050583978
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.016734675308101427
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.016685540034067893
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.01665093135932938
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.016660120953566455
# Fold 8 RMSLE for all models ensemble = 0.01667417253691432
# Fold 8 best combination: model4 with RMSLE = 0.01652975053839741
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.02015829570612968
# Fold 9 RMSLE for model2 = 0.019842003250386736
# Fold 9 RMSLE for model3 = 0.01963894958027939
# Fold 9 RMSLE for model4 = 0.019658023899308028
# Fold 9 RMSLE for ('model1', 'model2') = 0.01993236687204341
# Fold 9 RMSLE for ('model1', 'model3') = 0.0197940360676014
# Fold 9 RMSLE for ('model1', 'model4') = 0.0198856340201912
# Fold 9 RMSLE for ('model2', 'model3') = 0.01961581507280713
# Fold 9 RMSLE for ('model2', 'model4') = 0.019707415132467758
# Fold 9 RMSLE for ('model3', 'model4') = 0.019555147823224834
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.01974780701577463
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.01982697298701573
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.01972055135998577
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.019597147006126983
# Fold 9 RMSLE for all models ensemble = 0.019710489977839855
# Fold 9 best combination: ('model3', 'model4') with RMSLE = 0.019555147823224834
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.022209373839638374
# Fold 10 RMSLE for model2 = 0.022849473825443105
# Fold 10 RMSLE for model3 = 0.02246099634699682
# Fold 10 RMSLE for model4 = 0.023055831709447888
# Fold 10 RMSLE for ('model1', 'model2') = 0.02239240341011321
# Fold 10 RMSLE for ('model1', 'model3') = 0.02224146780341236
# Fold 10 RMSLE for ('model1', 'model4') = 0.022509232808578115
# Fold 10 RMSLE for ('model2', 'model3') = 0.022356061762889047
# Fold 10 RMSLE for ('model2', 'model4') = 0.02291318163137301
# Fold 10 RMSLE for ('model3', 'model4') = 0.022548079181444566
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.02227039233554732
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.022572034374110976
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.022384849253215107
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.022545575748175752
# Fold 10 RMSLE for all models ensemble = 0.022418074236454363
# Fold 10 best combination: model1 with RMSLE = 0.022209373839638374
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.01794286457525401
# Fold 11 RMSLE for model2 = 0.01758851598175122
# Fold 11 RMSLE for model3 = 0.017892642412840876
# Fold 11 RMSLE for model4 = 0.018034209966340184
# Fold 11 RMSLE for ('model1', 'model2') = 0.017675862819624136
# Fold 11 RMSLE for ('model1', 'model3') = 0.017886480241717174
# Fold 11 RMSLE for ('model1', 'model4') = 0.017961988260916276
# Fold 11 RMSLE for ('model2', 'model3') = 0.01762015806352686
# Fold 11 RMSLE for ('model2', 'model4') = 0.017747326505369917
# Fold 11 RMSLE for ('model3', 'model4') = 0.01790200730531567
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.017700847912406895
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.017775176118678716
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.017903564144437282
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.01772926789007266
# Fold 11 RMSLE for all models ensemble = 0.017766358132640103
# Fold 11 best combination: model2 with RMSLE = 0.01758851598175122
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.016389925819219178
# Fold 12 RMSLE for model2 = 0.017081971487394057
# Fold 12 RMSLE for model3 = 0.01653709891429243
# Fold 12 RMSLE for model4 = 0.016684260820713948
# Fold 12 RMSLE for ('model1', 'model2') = 0.01667191588453024
# Fold 12 RMSLE for ('model1', 'model3') = 0.016445885327373466
# Fold 12 RMSLE for ('model1', 'model4') = 0.016516106526216986
# Fold 12 RMSLE for ('model2', 'model3') = 0.016698676607073033
# Fold 12 RMSLE for ('model2', 'model4') = 0.01685651888979095
# Fold 12 RMSLE for ('model3', 'model4') = 0.01655971275270109
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.016583672818999733
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.016669063678040264
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.016497212405826637
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.01668403932677039
# Fold 12 RMSLE for all models ensemble = 0.01660031630301344
# Fold 12 best combination: model1 with RMSLE = 0.016389925819219178
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.018745606740617066
# Fold 13 RMSLE for model2 = 0.017883272549354675
# Fold 13 RMSLE for model3 = 0.01932569883528636
# Fold 13 RMSLE for model4 = 0.01828070752506577
# Fold 13 RMSLE for ('model1', 'model2') = 0.0181798536707502
# Fold 13 RMSLE for ('model1', 'model3') = 0.018990831921982223
# Fold 13 RMSLE for ('model1', 'model4') = 0.01845646925796017
# Fold 13 RMSLE for ('model2', 'model3') = 0.018434318834951002
# Fold 13 RMSLE for ('model2', 'model4') = 0.017972485018607424
# Fold 13 RMSLE for ('model3', 'model4') = 0.01866469348890066
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.018496965828267795
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.01816969620626174
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.018677348948067624
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.01831011289056025
# Fold 13 RMSLE for all models ensemble = 0.018395428027109816
# Fold 13 best combination: model2 with RMSLE = 0.017883272549354675
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.016245615255265574
# Fold 14 RMSLE for model2 = 0.016051413930619964
# Fold 14 RMSLE for model3 = 0.0163338038922199
# Fold 14 RMSLE for model4 = 0.015773230246066045
# Fold 14 RMSLE for ('model1', 'model2') = 0.016073806441672465
# Fold 14 RMSLE for ('model1', 'model3') = 0.016257904729115598
# Fold 14 RMSLE for ('model1', 'model4') = 0.01595578949761028
# Fold 14 RMSLE for ('model2', 'model3') = 0.016051023686319155
# Fold 14 RMSLE for ('model2', 'model4') = 0.01587537048156074
# Fold 14 RMSLE for ('model3', 'model4') = 0.01595578761881276
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.016100128610728275
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.01594979882556244
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.016036304010369467
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.015929580451376813
# Fold 14 RMSLE for all models ensemble = 0.015991762904667233
# Fold 14 best combination: model4 with RMSLE = 0.015773230246066045
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.025833756899456994
# Fold 15 RMSLE for model2 = 0.027943934237911455
# Fold 15 RMSLE for model3 = 0.026237085869289592
# Fold 15 RMSLE for model4 = 0.025759574764603346
# Fold 15 RMSLE for ('model1', 'model2') = 0.02680422427040693
# Fold 15 RMSLE for ('model1', 'model3') = 0.025815726523939715
# Fold 15 RMSLE for ('model1', 'model4') = 0.025759336145651637
# Fold 15 RMSLE for ('model2', 'model3') = 0.026601991261140993
# Fold 15 RMSLE for ('model2', 'model4') = 0.026823143867397987
# Fold 15 RMSLE for ('model3', 'model4') = 0.025620681904906063
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.026317939198221535
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.02644525033819906
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.025660896602450606
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.026249786203122887
# Fold 15 RMSLE for all models ensemble = 0.02613395533710944
# Fold 15 best combination: ('model3', 'model4') with RMSLE = 0.025620681904906063
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.02036360272419647
# Fold 16 RMSLE for model2 = 0.02089398526210291
# Fold 16 RMSLE for model3 = 0.020779686853227827
# Fold 16 RMSLE for model4 = 0.020362085979591434
# Fold 16 RMSLE for ('model1', 'model2') = 0.02055726472789078
# Fold 16 RMSLE for ('model1', 'model3') = 0.02050809921312
# Fold 16 RMSLE for ('model1', 'model4') = 0.020344367309301885
# Fold 16 RMSLE for ('model2', 'model3') = 0.02066357039970582
# Fold 16 RMSLE for ('model2', 'model4') = 0.020586029144330407
# Fold 16 RMSLE for ('model3', 'model4') = 0.020476270387815344
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.020541652295433536
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.0204810659430613
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.020423096967647096
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.02054051009608821
# Fold 16 RMSLE for all models ensemble = 0.020483526922818858
# Fold 16 best combination: ('model1', 'model4') with RMSLE = 0.020344367309301885
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.020580269901320725
# Fold 17 RMSLE for model2 = 0.02240288122315253
# Fold 17 RMSLE for model3 = 0.020922334341203382
# Fold 17 RMSLE for model4 = 0.02153318102457555
# Fold 17 RMSLE for ('model1', 'model2') = 0.021381115674565174
# Fold 17 RMSLE for ('model1', 'model3') = 0.020686850834754134
# Fold 17 RMSLE for ('model1', 'model4') = 0.02102368387984799
# Fold 17 RMSLE for ('model2', 'model3') = 0.02144282511840741
# Fold 17 RMSLE for ('model2', 'model4') = 0.021913635390507637
# Fold 17 RMSLE for ('model3', 'model4') = 0.021109197541560678
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.021124998207162484
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.021417295057554343
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.020915671259336698
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.02144525458339717
# Fold 17 RMSLE for all models ensemble = 0.021208867817540347
# Fold 17 best combination: model1 with RMSLE = 0.020580269901320725
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.01723440536830256
# Fold 18 RMSLE for model2 = 0.018248713367706372
# Fold 18 RMSLE for model3 = 0.017494591980241603
# Fold 18 RMSLE for model4 = 0.017922543710553924
# Fold 18 RMSLE for ('model1', 'model2') = 0.01765731976904662
# Fold 18 RMSLE for ('model1', 'model3') = 0.01732254768022084
# Fold 18 RMSLE for ('model1', 'model4') = 0.01752361900897685
# Fold 18 RMSLE for ('model2', 'model3') = 0.017745949257892316
# Fold 18 RMSLE for ('model2', 'model4') = 0.01805649455750653
# Fold 18 RMSLE for ('model3', 'model4') = 0.017618877667021363
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.01754670035750383
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.017727326050733752
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.017467391445372835
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.017780227416584315
# Fold 18 RMSLE for all models ensemble = 0.0176185278094716
# Fold 18 best combination: model1 with RMSLE = 0.01723440536830256
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.020070711583875654
# Fold 19 RMSLE for model2 = 0.022419346190800278
# Fold 19 RMSLE for model3 = 0.020627659510665152
# Fold 19 RMSLE for model4 = 0.020885441664553136
# Fold 19 RMSLE for ('model1', 'model2') = 0.021026391347552447
# Fold 19 RMSLE for ('model1', 'model3') = 0.020109815315841512
# Fold 19 RMSLE for ('model1', 'model4') = 0.020406242807518522
# Fold 19 RMSLE for ('model2', 'model3') = 0.020935349510191766
# Fold 19 RMSLE for ('model2', 'model4') = 0.021568787243818943
# Fold 19 RMSLE for ('model3', 'model4') = 0.020461111972967697
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.020570339432400796
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.020958381051042575
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.020257702555046893
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.020881424727305167
# Fold 19 RMSLE for all models ensemble = 0.02062465647543029
# Fold 19 best combination: model1 with RMSLE = 0.020070711583875654
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.01648285889625396
# Fold 20 RMSLE for model2 = 0.016385683742300438
# Fold 20 RMSLE for model3 = 0.016598486600201672
# Fold 20 RMSLE for model4 = 0.016248796469331663
# Fold 20 RMSLE for ('model1', 'model2') = 0.01631732756633769
# Fold 20 RMSLE for ('model1', 'model3') = 0.01652298609042008
# Fold 20 RMSLE for ('model1', 'model4') = 0.016335844467652287
# Fold 20 RMSLE for ('model2', 'model3') = 0.016351753422644107
# Fold 20 RMSLE for ('model2', 'model4') = 0.016259273174100277
# Fold 20 RMSLE for ('model3', 'model4') = 0.01637665593646596
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.016366942724958408
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.01628126794924412
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.016401345450846143
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.016301775225088883
# Fold 20 RMSLE for all models ensemble = 0.0163264242883133
# Fold 20 best combination: model4 with RMSLE = 0.016248796469331663
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.017584146144589956
# Fold 21 RMSLE for model2 = 0.01917131493204123
# Fold 21 RMSLE for model3 = 0.017088487951548267
# Fold 21 RMSLE for model4 = 0.018396577781100498
# Fold 21 RMSLE for ('model1', 'model2') = 0.01821783854906811
# Fold 21 RMSLE for ('model1', 'model3') = 0.017300688047770796
# Fold 21 RMSLE for ('model1', 'model4') = 0.017940473806116908
# Fold 21 RMSLE for ('model2', 'model3') = 0.017879358426428738
# Fold 21 RMSLE for ('model2', 'model4') = 0.01873437740168854
# Fold 21 RMSLE for ('model3', 'model4') = 0.017619948747669402
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.017747430773027238
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.018268774111257054
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.017597017784049363
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.01803223651073147
# Fold 21 RMSLE for all models ensemble = 0.01789258920352889
# Fold 21 best combination: model3 with RMSLE = 0.017088487951548267
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.015912808319401475
# Fold 22 RMSLE for model2 = 0.017160553380174644
# Fold 22 RMSLE for model3 = 0.015664564857122826
# Fold 22 RMSLE for model4 = 0.0165185353114142
# Fold 22 RMSLE for ('model1', 'model2') = 0.016469816799266745
# Fold 22 RMSLE for ('model1', 'model3') = 0.015764647708800067
# Fold 22 RMSLE for ('model1', 'model4') = 0.016192361352300906
# Fold 22 RMSLE for ('model2', 'model3') = 0.01629239952350681
# Fold 22 RMSLE for ('model2', 'model4') = 0.01681043238338746
# Fold 22 RMSLE for ('model3', 'model4') = 0.01603703940265926
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.01615138249015365
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.01647755444424351
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.0159866444116206
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.01635764522070657
# Fold 22 RMSLE for all models ensemble = 0.016234375334192412
# Fold 22 best combination: model3 with RMSLE = 0.015664564857122826
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.01988126622234987
# Fold 23 RMSLE for model2 = 0.01914034233850604
# Fold 23 RMSLE for model3 = 0.019674157048604
# Fold 23 RMSLE for model4 = 0.020104000031478886
# Fold 23 RMSLE for ('model1', 'model2') = 0.01942860607400682
# Fold 23 RMSLE for ('model1', 'model3') = 0.01972520667190072
# Fold 23 RMSLE for ('model1', 'model4') = 0.019971857122635044
# Fold 23 RMSLE for ('model2', 'model3') = 0.019225304505157977
# Fold 23 RMSLE for ('model2', 'model4') = 0.019566120345812187
# Fold 23 RMSLE for ('model3', 'model4') = 0.01978392545105308
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.019425005299474662
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.01963819191854341
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.019807243986510032
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.019487319073776817
# Fold 23 RMSLE for all models ensemble = 0.019575803512698067
# Fold 23 best combination: model2 with RMSLE = 0.01914034233850604
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.01645051666602117
# Fold 24 RMSLE for model2 = 0.017714640567789573
# Fold 24 RMSLE for model3 = 0.016981946297294596
# Fold 24 RMSLE for model4 = 0.016922390597465573
# Fold 24 RMSLE for ('model1', 'model2') = 0.016981123289982185
# Fold 24 RMSLE for ('model1', 'model3') = 0.01668004569422179
# Fold 24 RMSLE for ('model1', 'model4') = 0.016653339262307963
# Fold 24 RMSLE for ('model2', 'model3') = 0.01724439245310176
# Fold 24 RMSLE for ('model2', 'model4') = 0.01727749230927868
# Fold 24 RMSLE for ('model3', 'model4') = 0.01691060757187446
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.016941047077044944
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.016950977344916792
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.01673563006346324
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.01712319916264187
# Fold 24 RMSLE for all models ensemble = 0.016927601311532002
# Fold 24 best combination: model1 with RMSLE = 0.01645051666602117
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.019232792105800575
# Fold 25 RMSLE for model2 = 0.019447426795656704
# Fold 25 RMSLE for model3 = 0.019253107256120144
# Fold 25 RMSLE for model4 = 0.019086747481513337
# Fold 25 RMSLE for ('model1', 'model2') = 0.01906696954168612
# Fold 25 RMSLE for ('model1', 'model3') = 0.019217368852873302
# Fold 25 RMSLE for ('model1', 'model4') = 0.019115584291899728
# Fold 25 RMSLE for ('model2', 'model3') = 0.019026591932760836
# Fold 25 RMSLE for ('model2', 'model4') = 0.019124048493646642
# Fold 25 RMSLE for ('model3', 'model4') = 0.019079289123927444
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.019034139895658962
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.01905060469692412
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.019119629373790553
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.019014176997233494
# Fold 25 RMSLE for all models ensemble = 0.01902943427860253
# Fold 25 best combination: ('model2', 'model3', 'model4') with RMSLE = 0.019014176997233494
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.020870081453727145
# Fold 26 RMSLE for model2 = 0.020452322841667803
# Fold 26 RMSLE for model3 = 0.020198302342408974
# Fold 26 RMSLE for model4 = 0.020571642341581594
# Fold 26 RMSLE for ('model1', 'model2') = 0.020575608010819684
# Fold 26 RMSLE for ('model1', 'model3') = 0.020492916836227386
# Fold 26 RMSLE for ('model1', 'model4') = 0.020676733177056976
# Fold 26 RMSLE for ('model2', 'model3') = 0.020175954704281296
# Fold 26 RMSLE for ('model2', 'model4') = 0.020446810360324415
# Fold 26 RMSLE for ('model3', 'model4') = 0.02030655635971721
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.02038438538930891
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.020544720049118267
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.020473963090212734
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.02027732268530944
# Fold 26 RMSLE for all models ensemble = 0.020407285256932688
# Fold 26 best combination: ('model2', 'model3') with RMSLE = 0.020175954704281296
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.0177334936211275
# Fold 27 RMSLE for model2 = 0.01860777137473635
# Fold 27 RMSLE for model3 = 0.018082292513731564
# Fold 27 RMSLE for model4 = 0.017585182874497486
# Fold 27 RMSLE for ('model1', 'model2') = 0.018066434528340274
# Fold 27 RMSLE for ('model1', 'model3') = 0.01785752460245124
# Fold 27 RMSLE for ('model1', 'model4') = 0.017592164374715714
# Fold 27 RMSLE for ('model2', 'model3') = 0.018116696070022118
# Fold 27 RMSLE for ('model2', 'model4') = 0.018067172166588423
# Fold 27 RMSLE for ('model3', 'model4') = 0.01764946691575557
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.017970075180098667
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.017886206503986785
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.017666137424646775
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.017895086728510087
# Fold 27 RMSLE for all models ensemble = 0.017835677744740003
# Fold 27 best combination: model4 with RMSLE = 0.017585182874497486
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.01965309278563862
# Fold 28 RMSLE for model2 = 0.020218891135324397
# Fold 28 RMSLE for model3 = 0.02012290284025295
# Fold 28 RMSLE for model4 = 0.019091776884014866
# Fold 28 RMSLE for ('model1', 'model2') = 0.019814734661660408
# Fold 28 RMSLE for ('model1', 'model3') = 0.01987188638047307
# Fold 28 RMSLE for ('model1', 'model4') = 0.019322449888290624
# Fold 28 RMSLE for ('model2', 'model3') = 0.020025684028660066
# Fold 28 RMSLE for ('model2', 'model4') = 0.019612473752248737
# Fold 28 RMSLE for ('model3', 'model4') = 0.019539007960777083
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.019872358137876252
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.019558959484221015
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.019563048673994055
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.019696500524795383
# Fold 28 RMSLE for all models ensemble = 0.01966014520673533
# Fold 28 best combination: model4 with RMSLE = 0.019091776884014866
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.018173471298104975
# Fold 29 RMSLE for model2 = 0.018899112742846377
# Fold 29 RMSLE for model3 = 0.018338400579743196
# Fold 29 RMSLE for model4 = 0.01762320027293517
# Fold 29 RMSLE for ('model1', 'model2') = 0.01841615487528738
# Fold 29 RMSLE for ('model1', 'model3') = 0.018222044823532565
# Fold 29 RMSLE for ('model1', 'model4') = 0.017825718063970163
# Fold 29 RMSLE for ('model2', 'model3') = 0.018414462886069925
# Fold 29 RMSLE for ('model2', 'model4') = 0.018211222302242112
# Fold 29 RMSLE for ('model3', 'model4') = 0.017827822624448972
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.018310325038735115
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.018123679112524372
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.017930025788020748
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.0181053665968649
# Fold 29 RMSLE for all models ensemble = 0.01809947098890394
# Fold 29 best combination: model4 with RMSLE = 0.01762320027293517
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.017985929507929037
# Fold 30 RMSLE for model2 = 0.019397723978867906
# Fold 30 RMSLE for model3 = 0.01834000336724535
# Fold 30 RMSLE for model4 = 0.01876738487857126
# Fold 30 RMSLE for ('model1', 'model2') = 0.01859123867646677
# Fold 30 RMSLE for ('model1', 'model3') = 0.018094847611358524
# Fold 30 RMSLE for ('model1', 'model4') = 0.018325107576578445
# Fold 30 RMSLE for ('model2', 'model3') = 0.018707198291371997
# Fold 30 RMSLE for ('model2', 'model4') = 0.019018462911796263
# Fold 30 RMSLE for ('model3', 'model4') = 0.018506455034091096
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.018426872449620376
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.0186207844684333
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.01829032441115278
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.01871350716943461
# Fold 30 RMSLE for all models ensemble = 0.018498982427036292
# Fold 30 best combination: model1 with RMSLE = 0.017985929507929037
# ---------------
#
# OOF RMSLE = 0.01860230860237365
# Sum of RMSLE for each combination:
# ('model1',): 0.5650041097454364
# ('model2',): 0.5805450206111573
# ('model3',): 0.5695974541401462
# ('model4',): 0.5659337873910839
# ('model1', 'model2'): 0.5694408388401703
# ('model1', 'model3'): 0.5653710806814121
# ('model1', 'model4'): 0.5638013950674585
# ('model2', 'model3'): 0.568694982728148
# ('model2', 'model4'): 0.5716235806940686
# ('model3', 'model4'): 0.56351771269298
# ('model1', 'model2', 'model3'): 0.5665271477936801
# ('model1', 'model2', 'model4'): 0.5675476785409707
# ('model1', 'model3', 'model4'): 0.5633610571576896
# ('model2', 'model3', 'model4'): 0.566575857940923
# ('model1', 'model2', 'model3', 'model4'): 0.5654656194924809

# %%
test_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN             4
# 1                             NaN           221
# 2                          23,385           130
# 3                          42,958            82
# 4                          39,437           181
# ...                           ...           ...
# 2503                          NaN           240
# 2504                          NaN             4
# 2505                       24,560           132
# 2506                      130,327            98
# 2507                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     88,951
# 1                                        NaN
# 2                                     84,908
# 3                                     49,005
# 4                                     84,960
# ...                                      ...
# 2503                                 110,523
# 2504                                     NaN
# 2505                                 166,520
# 2506                                  71,774
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     65,803
# 1                                        NaN
# 2                                      6,213
# 3                                         52
# 4                                     15,351
# ...                                      ...
# 2503                                  98,955
# 2504                                     NaN
# 2505                                 469,733
# 2506                                 936,032
# 2507                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     28,993
# 1                                    311,926
# 2                                     34,733
# 3                                     14,262
# 4                                     40,007
# ...                                      ...
# 2503                               3,467,008
# 2504                                     NaN
# 2505                                  82,559
# 2506                                 336,961
# 2507                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     32,965        38        -98
# 1                                    268,668        32       -109
# 2                                     39,045        41        -79
# 3                                     20,205        45        -93
# 4                                     63,935        33       -117
# ...                                      ...       ...        ...
# 2503                                 147,802        39        -76
# 2504                                     NaN        31       -102
# 2505                                  85,775        41        -96
# 2506                                 156,640        39        -93
# 2507                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                               3,800                           -5,629
# 3                               5,174                            1,402
# 4                              -5,413                              306
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                              636                            1,477
# 2506                           16,356                          -47,698
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                              -3,061                                 0
# 3                                -948                                 0
# 4                                -766                                -0
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                             -509                                 0
# 2506                           37,208                                 0
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                   -0                                -0
# 3                                    0                                -0
# 4                                    0                                -0
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                                 0                                -0
# 2506                                -0                                 0
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   9            1           45,533     0
# 1                  14            1          293,456    -0
# 2                   8            0           41,167    -0
# 3                   8            0           28,483    -0
# 4                   8            0           48,696     0
# ...               ...          ...              ...   ...
# 2503                1            1          549,521     0
# 2504                9            1           98,313    -0
# 2505                8            0          140,770     0
# 2506                8            0          259,066    -0
# 2507                9            1        1,456,483     0
#
# [2508 rows x 18 columns]

# %%
test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
train_df["preds"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)

# %%
train_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           42,892    -0  42,717
# 1                  14            1           57,720     0  57,777
# 2                   9            1           97,385     0  97,735
# 3                  15            1           52,143    -0  52,062
# 4                  15            0           51,220    -0  51,047
# ...               ...          ...              ...   ...     ...
# 4650               15            0           52,280    -0  51,792
# 4651                8            1          168,315     0 168,450
# 4652                8            0           31,986    -0  31,956
# 4653                8            0           64,828     0  64,743
# 4654                9            1          146,588    -0 146,522
#
# [4655 rows x 19 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.44, -0.00)

# %%
train_df_GHG14
# Out:
# 0       42,214
# 1       58,500
# 2       99,409
# 3       51,623
# 4       50,638
#          ...
# 4650    49,222
# 4651   169,634
# 4652    31,716
# 4653    65,663
# 4654   145,438
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 4655, dtype: float64

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["preds"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.45)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
def after_times(test_preds):
    preds = test_preds.copy()
    # for i in range(len(preds)):
    #     if preds[i] < np.expm1(10.25):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    #     if preds[i] > np.expm1(14):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    for i in range(len(preds)):
        if preds[i] < np.expm1(10.2):
            preds[i] = np.expm1(np.log1p(preds[i])*100/102)
        if preds[i] > np.expm1(14):
            preds[i] = np.expm1(np.log1p(preds[i])*100/99)
    # for i in range(len(preds)):
    #     elif preds[i] < np.expm1(10.4):
    #         preds[i] = np.expm1(np.log1p(preds[i])*100/102)

    # for i in range(len(preds)):
    #     preds[i] = np.expm1(np.log1p(preds[i])+0.1)

    return preds
# after_test_preds = after_times(test_preds)
# after_train_preds = after_times(train_preds)
# after_oof_predictions = after_times(oof_predictions)

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0       1
# 0     4655 249,574
# 1     4656 249,574
# 2     4657 249,574
# 3     4658 249,574
# 4     4659 249,574
# ...    ...     ...
# 2503  7158 249,574
# 2504  7159 249,574
# 2505  7160 249,574
# 2506  7161 249,574
# 2507  7162 249,574
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["preds"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 233508.23938174153

# %%
# def adjust_predictions(test_x, bins, bin_centers, y_means):
#     """
#     テストデータの予測値をビン平均で補正します。

#     Parameters:
#     - test_x: テストデータの予測値の配列
#     - bins: トレーニングデータで使用したビンの境界
#     - bin_centers: 各ビンの中心値
#     - y_means: 各ビン内の y の平均値

#     Returns:
#     - adjusted_predictions: 補正後の予測値
#     """
#     # テストデータをビンに割り当て
#     bin_indices = np.digitize(test_x, bins)

#     # 補正後の予測値を初期化
#     adjusted_predictions = np.copy(test_x)

#     for i in range(1, len(bins)):
#         mask = bin_indices == i
#         if np.any(mask):
#             # 補正係数を計算（y_mean / bin_center）
#             correction_factor = np.log1p(y_means[i-1]) / np.log1p(bin_centers[i-1])
#             adjusted_predictions[mask] = test_x[mask] / correction_factor

#     # ビンの範囲外のデータを処理（例えば、最小ビンより小さい値や最大ビンより大きい値）
#     # 最小ビンより小さい値は最初のビンに、
#     # 最大ビンより大きい値は最後のビンに割り当て
#     adjusted_predictions[bin_indices == 0] = y_means[0]
#     adjusted_predictions[bin_indices > len(y_means)] = y_means[-1]

#     return adjusted_predictions

# # テストデータの定義（例）
# # test_x = test_df["GHG_Direct_Emissions_14_in_metric_tons"]

# # 実際のデータに合わせて定義してください
# x_test = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]  # テストデータの予測値

# # 予測値を調整

# # 調整後の予測値をデータフレームに追加
# test_df["GHG_Direct_Emissions_14_in_metric_tons.1"] = adjust_predictions(x_test, bins, bin_centers, y_means)
# train_df["preds"] = adjust_predictions(train_df["preds"], bins, bin_centers, y_means)

# %%
np.expm1(10.2)
# Out:
# 26902.18607429754

# %%
def after_act(preds):
    r = preds.copy()
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            r[i] = np.expm1(np.log1p(r[i])*100/102)
        # if r[i] > np.expm1(14):
        #     r[i] = np.expm1(np.log1p(r[i])*100/99)
    return r

after_test_preds = after_act(test_df["GHG_Direct_Emissions_14_in_metric_tons.1"])
after_train_preds = after_act(train_df["preds"])
# after_test_preds = after_act(after_test_preds)
# after_train_preds = after_act(after_train_preds)

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 232356.23495827208

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_68.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    45,425
# 1     4656   293,792
# 2     4657    41,133
# 3     4658    23,450
# 4     4659    48,609
# ...    ...       ...
# 2503  7158   550,239
# 2504  7159    98,563
# 2505  7160   140,716
# 2506  7161   260,133
# 2507  7162 1,452,465
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,158,457
# 43    4698 1,186,180
# 110   4765 1,367,687
# 114   4769 1,282,855
# 148   4803 1,739,646
# ...    ...       ...
# 2417  7072 1,234,993
# 2423  7078 1,204,090
# 2466  7121 1,662,224
# 2490  7145 1,413,590
# 2507  7162 1,452,465
#
# [110 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Thu Nov 28 16:39:55 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           42,892    -0  42,717
# 1                  14            1           57,720     0  57,777
# 2                   9            1           97,385     0  97,735
# 3                  15            1           52,143    -0  52,062
# 4                  15            0           51,220    -0  51,047
# ...               ...          ...              ...   ...     ...
# 4650               15            0           52,280    -0  51,792
# 4651                8            1          168,315     0 168,450
# 4652                8            0           31,986    -0  31,956
# 4653                8            0           64,828     0  64,743
# 4654                9            1          146,588    -0 146,522
#
# [4655 rows x 19 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["preds"])
# Out:
# 0.01568110406364513

# %%
train_df
# Out:
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          31,810           118
# 1                             NaN           221
# 2                             NaN             4
# 3                             NaN            21
# 4                          25,154            21
# ...                           ...           ...
# 4650                       26,927            20
# 4651                          NaN            92
# 4652                       25,052            80
# 4653                       15,797            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 4650                                  77,141
# 4651                                  82,220
# 4652                                  28,607
# 4653                                  88,532
# 4654                                 112,513
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 4650                                  48,631
# 4651                                  64,716
# 4652                                  19,290
# 4653                                  72,952
# 4654                                  53,843
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 4650                                  47,793
# 4651                                 230,047
# 4652                                  31,161
# 4653                                  58,935
# 4654                                 466,623
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 4650                                  26,264        31        -93
# 4651                                 560,694        34       -118
# 4652                                  41,109        45        -90
# 4653                                  53,984        38        -98
# 4654                                  66,177        37       -105
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 4650                            8,851                           -4,910
# 4651                              NaN                              NaN
# 4652                            2,857                            1,088
# 4653                            8,122                          -10,314
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 4650                            7,736                                 1
# 4651                              NaN                               NaN
# 4652                             -292                                 0
# 4653                              766                                 0
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 4650                                -0                                 0
# 4651                               NaN                               NaN
# 4652                                 0                                -0
# 4653                                -0                                 0
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff   preds
# 0                   8            0           42,892    -0  42,717
# 1                  14            1           57,720     0  57,777
# 2                   9            1           97,385     0  97,735
# 3                  15            1           52,143    -0  52,062
# 4                  15            0           51,220    -0  51,047
# ...               ...          ...              ...   ...     ...
# 4650               15            0           52,280    -0  51,792
# 4651                8            1          168,315     0 168,450
# 4652                8            0           31,986    -0  31,956
# 4653                8            0           64,828     0  64,743
# 4654                9            1          146,588    -0 146,522
#
# [4655 rows x 19 columns]

# %%
submit
# Out:
#          0         1
# 0     4655    45,425
# 1     4656   293,792
# 2     4657    41,133
# 3     4658    23,450
# 4     4659    48,609
# ...    ...       ...
# 2503  7158   550,239
# 2504  7159    98,563
# 2505  7160   140,716
# 2506  7161   260,133
# 2507  7162 1,452,465
#
# [2508 rows x 2 columns]
