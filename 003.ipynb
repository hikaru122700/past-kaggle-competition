# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/%E5%9B%BD%E5%9C%9F%E4%BA%A4%E9%80%9A%E7%9C%81/003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install optuna
# !pip install catboost
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
# ライブラリの読み込み
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.metrics import mean_squared_log_error
from sklearn.model_selection import KFold
from itertools import combinations
import gc

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import optuna
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from sklearn.metrics import log_loss
import time
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)

# %%
# データの読み込み
# INPUT_DIRにtrain.csvなどのデータを置いているディレクトリを指定してください。

path  = "/content/drive/My Drive/signate/国土交通省/"

train = pd.read_csv(path + "train.csv")
test = pd.read_csv(path + "test.csv")
sample_sub = pd.read_csv(path + "sample_submit.csv", header=None)

# %%
len(train), len(test)
# Out:
# (584507, 384540)

# %%
test.head(3)
# Out:
#    index  target_ym building_id  building_status building_create_date  \
# 0      0     202207     a372446                1  2014-06-27 20:30:14
# 1      1     202301     a276097                1  2014-06-28 02:47:45
# 2      2     202307     a290359                1  2014-06-27 21:18:44
#
#   building_modify_date  building_type building_name  building_name_ruby  \
# 0  2024-02-09 00:10:05              3    シャーメゾンエランA                 NaN
# 1  2024-08-15 02:24:34              1       マルコフォート                 NaN
# 2  2024-04-01 19:59:13              3   リバーサイドハウス松浪                 NaN
#
#   homes_building_name homes_building_name_ruby  unit_count  \
# 0       シャーメゾンELAN A棟            シャーメゾンエラン Aトウ         6.0
# 1             マルコフォート                  マルコフオート        15.0
# 2           リバーサイドハウス                リバーサイドハウス         NaN
#
#            full_address         lon        lat  building_structure  \
# 0  山口県山陽小野田市大字西高泊618-12  131.175432  34.007274                10.0
# 1       東京都調布市菊野台3丁目3-3  139.569165  35.653207                 4.0
# 2     大阪府泉佐野市下瓦屋1丁目2-48  135.328353  34.418698                10.0
#
#    total_floor_area  building_area  floor_count  basement_floor_count  \
# 0               NaN            NaN          2.0                   NaN
# 1               NaN            NaN          3.0                   1.0
# 2               NaN            NaN          2.0                   NaN
#
#    year_built  building_land_area  land_area_all  unit_area_min  \
# 0    201101.0                 NaN            NaN            NaN
# 1    198703.0                 NaN            NaN           18.0
# 2    198904.0                 NaN            NaN            NaN
#
#    unit_area_max  building_land_chimoku  land_youto  land_toshi  land_chisei  \
# 0            NaN                    NaN         NaN         NaN          NaN
# 1           20.0                    NaN         NaN         NaN          NaN
# 2            NaN                    NaN         NaN         NaN          NaN
#
#    land_area_kind  land_setback_flg  land_setback  land_kenpei  land_youseki  \
# 0             NaN               NaN           NaN          NaN           NaN
# 1             NaN               1.0           NaN          NaN           NaN
# 2             NaN               1.0           0.0          0.0           0.0
#
#    land_road_cond land_seigen  building_area_kind  management_form  \
# 0             NaN         NaN                 NaN              NaN
# 1             NaN         NaN                 NaN              NaN
# 2             NaN         NaN                 NaN              NaN
#
#    management_association_flg reform_exterior reform_exterior_other  \
# 0                         NaN             NaN                   NaN
# 1                         NaN             NaN                   NaN
# 2                         NaN             NaN                   NaN
#
#    reform_exterior_date reform_common_area  reform_common_area_date  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
#
#                       building_tag_id   unit_id unit_name  name_ruby  \
# 0  210301/321001/210101/210401/320901  23270592       202        NaN
# 1  210101/321001/320901/210301/210201    853089       303        NaN
# 2  210302/210202/320901/321001/210101  23809363       101        NaN
#
#    room_floor  balcony_area  dwelling_unit_window_angle  room_count  \
# 0         2.0           NaN                         6.0         2.0
# 1         3.0           NaN                         5.0         1.0
# 2         1.0           NaN                         5.0         3.0
#
#    unit_area  floor_plan_code  reform_date reform_place reform_place_other  \
# 0  62.509998            250.0          NaN          NaN                NaN
# 1  19.440001            120.0          NaN          NaN                NaN
# 2  63.000000            350.0          NaN          NaN                NaN
#
#   reform_wet_area reform_wet_area_other  reform_wet_area_date reform_interior  \
# 0             NaN                   NaN                   NaN             NaN
# 1             NaN                   NaN                   NaN             NaN
# 2             NaN                   NaN                   NaN             NaN
#
#   reform_interior_other  reform_interior_date reform_etc renovation_date  \
# 0                   NaN                   NaN        NaN             NaN
# 1                   NaN                   NaN        NaN             NaN
# 2                   NaN                   NaN        NaN             NaN
#
#   renovation_etc                                        unit_tag_id  \
# 0            NaN  340201/230103/310501/230201/230501/220501/3401...
# 1            NaN  230801/240104/310501/263101/290101/230201/2605...
# 2            NaN  290101/340401/223101/220401/220201/220101/2302...
#
#         bukken_id snapshot_create_date             new_date  \
# 0  37220460000756  2022-04-18 00:00:00  2022-04-18 00:00:00
# 1   1038270025409  2023-01-30 00:00:00  2023-01-30 00:00:00
# 2   1398630020406  2023-06-24 00:00:00  2023-06-24 00:00:00
#
#   snapshot_modify_date       timelimit_date  flg_open  flg_own  bukken_type  \
# 0  2022-07-25 14:00:26  2022-08-01 00:00:00         1        1         3102
# 1  2023-01-30 16:44:45  2023-02-06 00:00:00         1        1         3101
# 2  2023-07-27 06:01:56  2023-08-03 00:00:00         1        1         3101
#
#    flg_investment  empty_number empty_contents  post1  post2  addr1_1  \
# 0             0.0           NaN          A0202  756.0   57.0       35
# 1             0.0           2.0            303  182.0    7.0       13
# 2             0.0           NaN            101  598.0   62.0       27
#
#    addr1_2 addr2_name addr3_name addr4_name           nl           el  \
# 0      216      大字西高泊     618-12        NaN  122414490.0  472240000.0
# 1      208     菊野台３丁目        NaN        3-3  128339891.0  502460485.0
# 2      213     下瓦屋１丁目        NaN       2-48  123895830.0  487192181.0
#
#   rosen_name1 eki_name1 bus_stop1  bus_time1  walk_distance1 rosen_name2  \
# 0      JR山陽本線       小野田        高須        4.0           160.0         NaN
# 1         京王線        柴崎       NaN        NaN           240.0         京王線
# 2         南海線       井原里       NaN        NaN           240.0         南海線
#
#   eki_name2 bus_stop2  bus_time2  walk_distance2       traffic_other  \
# 0       NaN       NaN        NaN             NaN                 NaN
# 1     つつじヶ丘       NaN        NaN           800.0                 NaN
# 2        鶴原       NaN        NaN          1440.0  南海電鉄南海本線 泉佐野 徒歩21分
#
#    traffic_car  snapshot_land_area  snapshot_land_shidou  land_shidou_a  \
# 0          NaN                 NaN                   NaN            NaN
# 1          NaN                 NaN                   NaN            NaN
# 2          NaN                 NaN                   NaN            NaN
#
#    land_shidou_b  land_mochibun_a  land_mochibun_b  house_area  flg_new  \
# 0            NaN              NaN              NaN        62.0        0
# 1            NaN              NaN              NaN        19.0        0
# 2            NaN              NaN              NaN        61.0        0
#
#    house_kanrinin  room_kaisuu  snapshot_window_angle  madori_number_all  \
# 0             NaN          2.0                    5.0                  2
# 1             NaN          3.0                    5.0                  1
# 2             NaN          1.0                    3.0                  3
#
#    madori_kind_all  money_kyoueki  money_kyoueki_tax  money_rimawari_now  \
# 0               50           3000                3.0                 NaN
# 1               20           2000                3.0                 NaN
# 2               50              0                3.0                 NaN
#
#    money_shuuzen  money_shuuzenkikin money_sonota_str1  money_sonota1  \
# 0            NaN                 NaN            鍵販売手数料        11000.0
# 1            NaN                 NaN               消毒料        16500.0
# 2            NaN                 NaN        全保連火災保険セット         1590.0
#
#   money_sonota_str2  money_sonota2 money_sonota_str3  money_sonota3  \
# 0  安心サポート24プラス利用料月額          770.0            町内会費月額          500.0
# 1         入居安心サービス料        16500.0               NaN            NaN
# 2               NaN            NaN               NaN            NaN
#
#    parking_money  parking_money_tax  parking_kubun  parking_distance  \
# 0            NaN                2.0            1.0               NaN
# 1            0.0                NaN            4.0               NaN
# 2            0.0                2.0            1.0               NaN
#
#    parking_number                     parking_memo  genkyo_code  \
# 0             NaN                          1台無料 地上          2.0
# 1             NaN                              NaN          3.0
# 2             NaN  賃料に含む。 1台無料 駐1台 屋外 平置 地上 屋根無 並列          2.0
#
#    usable_status  usable_date school_ele_name  school_ele_distance  \
# 0              1          NaN             NaN                  NaN
# 1              3     202303.0         市立調和小学校                710.0
# 2              1          NaN             NaN                  NaN
#
#    school_ele_code school_jun_name  school_jun_distance  school_jun_code  \
# 0              NaN             NaN                  NaN              NaN
# 1              NaN         調布第六中学校               1100.0              NaN
# 2              NaN             NaN                  NaN              NaN
#
#    convenience_distance  super_distance  hospital_distance  park_distance  \
# 0                   NaN             NaN                NaN            NaN
# 1                 190.0            30.0                NaN            NaN
# 2                1256.0           867.0                NaN            NaN
#
#    drugstore_distance  bank_distance  shopping_street_distance est_other_name  \
# 0                 NaN            NaN                       NaN            NaN
# 1               120.0            NaN                       NaN            NaN
# 2              1060.0            NaN                       NaN      いこらも〜る泉佐野
#
#    est_other_distance                                           statuses  \
# 0                 NaN  110102/110903/121002/210301/220101/220201/2203...
# 1                 NaN  210201/220501/230102/240104/290902/260101/2904...
# 2               862.0  110301/110902/121002/210101/210202/210301/2201...
#
#    parking_keiyaku                       money_hoshou_company  \
# 0              1.0  【個人契約】 初回契約事務手数料：22，000円（税込）、月額保証料：賃料等の1％
# 1              NaN                                        NaN
# 2              NaN                           初回保証委託料は総賃料の50％要
#
#    free_rent_duration  free_rent_gen_timing
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN

# %%
train.head(3)
# Out:
#    target_ym  money_room building_id  building_status building_create_date  \
# 0     202007       38000     a000002                1  2014-06-27 21:18:41
# 1     202107      103000     a000004                1  2017-02-05 20:43:26
# 2     202101       50000     a000005                1  2014-06-27 20:32:50
#
#   building_modify_date  building_type building_name  building_name_ruby  \
# 0  2024-05-25 00:45:07              3   Plaisirりんくう                 NaN
# 1  2024-08-17 12:12:51              1      向原パークハイツ                 NaN
# 2  2023-09-17 23:53:57              3       エナージ美香保                 NaN
#
#   homes_building_name homes_building_name_ruby  unit_count  \
# 0          プレジール りんくう                プレジールりんくう        22.0
# 1            向原パークハイツ              ムカイハラパークハイツ         NaN
# 2             エナージ美香保                  エナジーミカホ         NaN
#
#            full_address         lon        lat  building_structure  \
# 0      大阪府泉佐野市笠松1丁目6-51  135.309302  34.411514                 1.0
# 1       東京都板橋区向原1丁目11-1  139.684556  35.741834                 4.0
# 2  北海道札幌市東区北21条東2丁目2-36  141.352789  43.087834                 1.0
#
#    total_floor_area  building_area  floor_count  basement_floor_count  \
# 0               NaN            NaN          2.0                   NaN
# 1               NaN            NaN          3.0                   NaN
# 2               NaN            NaN          3.0                   NaN
#
#    year_built  building_land_area  land_area_all  unit_area_min  \
# 0    200210.0                 NaN            NaN            NaN
# 1    197612.0                 NaN            NaN      44.099998
# 2    199607.0                 NaN            NaN            NaN
#
#    unit_area_max  building_land_chimoku  land_youto  land_toshi  land_chisei  \
# 0            NaN                    NaN         NaN         NaN          NaN
# 1      44.099998                    NaN         NaN         NaN          NaN
# 2            NaN                    NaN         NaN         NaN          NaN
#
#    land_area_kind  land_setback_flg  land_setback  land_kenpei  land_youseki  \
# 0             NaN               1.0           0.0          0.0           0.0
# 1             NaN               NaN           NaN          NaN           NaN
# 2             NaN               NaN           NaN          NaN           NaN
#
#    land_road_cond land_seigen  building_area_kind  management_form  \
# 0             NaN         NaN                 NaN              NaN
# 1             NaN         NaN                 NaN              NaN
# 2             NaN         NaN                 2.0              3.0
#
#    management_association_flg reform_exterior reform_exterior_other  \
# 0                         NaN             NaN                   NaN
# 1                         NaN             NaN                   NaN
# 2                         1.0             NaN                   NaN
#
#    reform_exterior_date reform_common_area  reform_common_area_date  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
#
#                                     building_tag_id   unit_id unit_name  \
# 0  321101/310201/320901/321001/210202/210301/210101  23810544       202
# 1         210101/330501/320901/321001/210301/210201  33983775       110
# 2                              210202/210301/210101  26682627       103
#
#    name_ruby  room_floor  balcony_area  dwelling_unit_window_angle  \
# 0        NaN         2.0           2.0                         5.0
# 1        NaN         1.0           4.0                         5.0
# 2        NaN         2.0           NaN                         3.0
#
#    room_count  unit_area  floor_plan_code  reform_date reform_place  \
# 0         1.0  23.180000            120.0          NaN          NaN
# 1         2.0  47.700001            230.0          NaN          NaN
# 2         2.0  46.349998            250.0          NaN          NaN
#
#   reform_place_other reform_wet_area reform_wet_area_other  \
# 0                NaN             NaN                   NaN
# 1                NaN             NaN                   NaN
# 2                NaN             NaN                   NaN
#
#    reform_wet_area_date reform_interior reform_interior_other  \
# 0                   NaN             NaN                   NaN
# 1                   NaN             NaN                   NaN
# 2                   NaN             NaN                   NaN
#
#    reform_interior_date reform_etc renovation_date renovation_etc  \
# 0                   NaN        NaN             NaN            NaN
# 1                   NaN        NaN             NaN            NaN
# 2                   NaN        NaN             NaN            NaN
#
#                                          unit_tag_id       bukken_id  \
# 0  230801/310501/220301/290901/230101/240104/2205...   1344300002216
# 1  340101/253401/220401/290901/220201/230202/2943...   1279070015508
# 2  230801/290101/220501/220201/220101/240103/2909...  31040620023451
#
#   snapshot_create_date             new_date snapshot_modify_date  \
# 0  2020-07-30 00:00:00  2020-07-30 00:00:00  2020-07-30 16:21:04
# 1  2021-07-09 00:00:00  2021-07-09 00:00:00  2021-07-30 23:36:05
# 2  2020-08-15 00:00:00  2021-01-06 00:00:00  2021-01-27 04:11:31
#
#         timelimit_date  flg_open  flg_own  bukken_type  flg_investment  \
# 0  2020-08-06 00:00:00         1        1         3102             0.0
# 1  2021-08-06 00:00:00         1        0         3101             0.0
# 2  2021-02-03 00:00:00         1        0         3102             NaN
#
#    empty_number empty_contents  post1  post2  addr1_1  addr1_2 addr2_name  \
# 0           2.0            202  598.0   44.0       27      213         笠松
# 1           NaN            110  173.0   36.0       13      119      向原１丁目
# 2           NaN            103   65.0   21.0        1      103  北二十一条東２丁目
#
#   addr3_name addr4_name           nl           el rosen_name1 eki_name1  \
# 0        NaN     1-6-51  123869683.0  487123547.0         南海線       泉佐野
# 1       11-1        NaN  128659541.0  502875929.0   東京メトロ有楽町線      小竹向原
# 2        NaN       2-36  155106911.0  508882127.0     札幌市営南北線      北24条
#
#   bus_stop1  bus_time1  walk_distance1 rosen_name2 eki_name2 bus_stop2  \
# 0       NaN        0.0          1040.0         NaN       NaN       NaN
# 1       NaN        NaN           320.0   東京メトロ有楽町線        千川       NaN
# 2       NaN        NaN           880.0     札幌市営南北線      北18条       NaN
#
#    bus_time2  walk_distance2            traffic_other  traffic_car  \
# 0        NaN             NaN                      NaN          NaN
# 1        NaN           400.0      東京地下鉄副都心線 小竹向原 徒歩4分          NaN
# 2        NaN          1120.0  札幌市営地下鉄東豊線 北13条東駅 徒歩16分          NaN
#
#    snapshot_land_area  snapshot_land_shidou  land_shidou_a  land_shidou_b  \
# 0                 NaN                   NaN            NaN            NaN
# 1                 NaN                   NaN            NaN            NaN
# 2                 NaN                   NaN            NaN            NaN
#
#    land_mochibun_a  land_mochibun_b  house_area  flg_new  house_kanrinin  \
# 0              NaN              NaN       23.18        0             NaN
# 1              NaN              NaN       47.70        0             NaN
# 2              NaN              NaN       46.35        0             NaN
#
#    room_kaisuu  snapshot_window_angle  madori_number_all  madori_kind_all  \
# 0          2.0                    5.0                  1               20
# 1          1.0                    5.0                  2               30
# 2          2.0                    3.0                  2               50
#
#    money_kyoueki  money_kyoueki_tax  money_rimawari_now  money_shuuzen  \
# 0         3000.0                3.0                 NaN            NaN
# 1         6000.0                3.0                 NaN            NaN
# 2         1500.0                2.0                 NaN            NaN
#
#    money_shuuzenkikin money_sonota_str1  money_sonota1 money_sonota_str2  \
# 0                 NaN        木下の賃貸　友の会費         1760.0             カギ交換代
# 1                 NaN               NaN            NaN               NaN
# 2                 NaN               町会費          200.0           その他初期費用
#
#    money_sonota2 money_sonota_str3  money_sonota3  parking_money  \
# 0        16500.0         木下の消毒サービス        26400.0         8800.0
# 1            NaN               NaN            NaN        22000.0
# 2        33000.0               NaN            NaN         8800.0
#
#    parking_money_tax  parking_kubun  parking_distance  parking_number  \
# 0                2.0            1.0               0.0             1.0
# 1                2.0            3.0             300.0             NaN
# 2                2.0            1.0               0.0             NaN
#
#   parking_memo  genkyo_code  usable_status  usable_date school_ele_name  \
# 0          NaN          3.0              3     202009.0             NaN
# 1          NaN          2.0              1          NaN       板橋区立向原小学校
# 2          NaN          NaN              1          NaN           幌北小学校
#
#    school_ele_distance  school_ele_code school_jun_name  school_jun_distance  \
# 0                  NaN              NaN             NaN                  NaN
# 1                291.0              NaN       板橋区立向原中学校                340.0
# 2                538.0              NaN           北辰中学校                644.0
#
#    school_jun_code  convenience_distance  super_distance  hospital_distance  \
# 0              NaN                 239.0          1280.0                NaN
# 1              NaN                 399.0           434.0                NaN
# 2              NaN                 201.0           741.0              574.0
#
#    park_distance  drugstore_distance  bank_distance  shopping_street_distance  \
# 0            NaN                 NaN            NaN                       NaN
# 1            NaN               435.0            NaN                       NaN
# 2            NaN                 NaN            NaN                       NaN
#
#   est_other_name  est_other_distance  \
# 0            NaN                 NaN
# 1          小竹向原駅               320.0
# 2            NaN                 NaN
#
#                                             statuses  parking_keiyaku  \
# 0  110702/210202/220101/220201/220301/230101/2308...              NaN
# 1  110301/210101/210201/210301/220101/220201/2203...              NaN
# 2  110201/110901/121001/210101/210202/220101/2202...              NaN
#
#              money_hoshou_company  free_rent_duration  free_rent_gen_timing
# 0                             NaN                 NaN                   NaN
# 1            初回賃料等の50％、更新時1年毎に1万円                 NaN                   NaN
# 2  ？月額家賃の50％、毎年10，000円　？月額家賃の100％                 NaN                   NaN

# %%
all_df = pd.concat([train, test])
all_df.drop("index", axis=1, inplace=True)

# %%
all_df["AMT_CREDIT"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AMT_CREDIT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-78b22f8cb70e> in <cell line: 1>()
# ----> 1 all_df["AMT_CREDIT"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'AMT_CREDIT'

# %%
# 追加の特徴量生成

# 1. 地理情報の関係
# 緯度（lat）と経度（lon）の積および比率
if 'lat' in all_df.columns and 'lon' in all_df.columns:
    all_df['LAT_LON_PRODUCT'] = all_df['lat'] * all_df['lon']  # 緯度 × 経度
    all_df['LAT_DIV_LON'] = all_df['lat'] / (all_df['lon'] + 1e-6)    # 緯度 / 経度

# 2. 建物の状態と面積の関係
# building_status × building_area
if 'building_status' in all_df.columns and 'building_area' in all_df.columns:
    all_df['BUILDING_STATUS_PRODUCT'] = all_df['building_status'] * all_df['building_area']  # 建物の状態 × 建築面積

# 3. 管理費と面積の関係
# money_kyoueki / unit_area_max
if 'money_kyoueki' in all_df.columns and 'unit_area_max' in all_df.columns:
    all_df['MONEY_KYOUEKI_DIV_UNIT_AREA_MAX'] = all_df['money_kyoueki'] / (all_df['unit_area_max'] + 1e-6)  # 管理費 / 最大専有面積

# # money_kyoueki × unit_area_min
if 'money_kyoueki' in all_df.columns and 'unit_area_min' in all_df.columns:
    all_df['MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN'] = all_df['money_kyoueki'] * all_df['unit_area_min']  # 管理費 × 最小専有面積

# 4. 交通利便性の関係
# walk_distance1 × walk_distance2
if 'walk_distance1' in all_df.columns and 'walk_distance2' in all_df.columns:
    all_df['WALK_DISTANCE_PRODUCT'] = all_df['walk_distance1'] * all_df['walk_distance2']  # 徒歩距離1 × 徒歩距離2

# # bus_time1 / (walk_distance1 + 1e-6)
if 'bus_time1' in all_df.columns and 'walk_distance1' in all_df.columns:
    all_df['BUS_TIME_DIV_WALK_DISTANCE1'] = all_df['bus_time1'] / (all_df['walk_distance1'] + 1e-6)  # バス時間1 / 徒歩距離1

# 5. 築年数と延べ床面積の関係
# AGE_BUILDING × total_floor_area
if 'AGE_BUILDING' in all_df.columns and 'total_floor_area' in all_df.columns:
    all_df['AGE_BUILDING_PRODUCT_TOTAL_FLOOR_AREA'] = all_df['AGE_BUILDING'] * all_df['total_floor_area']  # 築年数 × 延べ床面積

# 6. その他の有用な組み合わせ

# # 延べ床面積と建築面積の関係
if 'total_floor_area' in all_df.columns and 'building_area' in all_df.columns:
    all_df['TOTAL_FLOOR_AREA_DIV_BUILDING_AREA'] = all_df['total_floor_area'] / (all_df['building_area'] + 1e-6)  # 延べ床面積 / 建築面積

# # 土地持分の割合
if 'land_mochibun_a' in all_df.columns and 'land_mochibun_b' in all_df.columns:
    all_df['LAND_MOCHIBUN_RATIO'] = all_df['land_mochibun_a'] / (all_df['land_mochibun_b'] + 1e-6)  # 土地持分分母 / 土地持分分子

# # 接道状況と土地面積の関係
if 'land_road_cond' in all_df.columns and 'land_area_all' in all_df.columns:
    all_df['LAND_ROAD_COND_DIV_LAND_AREA_ALL'] = all_df['land_road_cond'] / (all_df['land_area_all'] + 1e-6)  # 接道状況 / 敷地全体面積

# # 駐車場距離と駐車場空き台数の関係
if 'parking_distance' in all_df.columns and 'parking_number' in all_df.columns:
    all_df['PARKING_DISTANCE_DIV_PARKING_NUMBER'] = all_df['parking_distance'] / (all_df['parking_number'] + 1e-6)  # 駐車場距離 / 駐車場空き台数

# # 駐車場料金と距離の関係
if 'parking_money' in all_df.columns and 'parking_distance' in all_df.columns:
    all_df['PARKING_MONEY_DIV_PARKING_DISTANCE'] = all_df['parking_money'] / (all_df['parking_distance'] + 1e-6)  # 駐車場料金 / 駐車場距離

# %%
all_df.head(3)
# Out:
#    target_ym  money_room building_id  building_status building_create_date  \
# 0     202007     38000.0     a000002                1  2014-06-27 21:18:41
# 1     202107    103000.0     a000004                1  2017-02-05 20:43:26
# 2     202101     50000.0     a000005                1  2014-06-27 20:32:50
#
#   building_modify_date  building_type building_name  building_name_ruby  \
# 0  2024-05-25 00:45:07              3   Plaisirりんくう                 NaN
# 1  2024-08-17 12:12:51              1      向原パークハイツ                 NaN
# 2  2023-09-17 23:53:57              3       エナージ美香保                 NaN
#
#   homes_building_name homes_building_name_ruby  unit_count  \
# 0          プレジール りんくう                プレジールりんくう        22.0
# 1            向原パークハイツ              ムカイハラパークハイツ         NaN
# 2             エナージ美香保                  エナジーミカホ         NaN
#
#            full_address         lon        lat  building_structure  \
# 0      大阪府泉佐野市笠松1丁目6-51  135.309302  34.411514                 1.0
# 1       東京都板橋区向原1丁目11-1  139.684556  35.741834                 4.0
# 2  北海道札幌市東区北21条東2丁目2-36  141.352789  43.087834                 1.0
#
#    total_floor_area  building_area  floor_count  basement_floor_count  \
# 0               NaN            NaN          2.0                   NaN
# 1               NaN            NaN          3.0                   NaN
# 2               NaN            NaN          3.0                   NaN
#
#    year_built  building_land_area  land_area_all  unit_area_min  \
# 0    200210.0                 NaN            NaN            NaN
# 1    197612.0                 NaN            NaN      44.099998
# 2    199607.0                 NaN            NaN            NaN
#
#    unit_area_max  building_land_chimoku  land_youto  land_toshi  land_chisei  \
# 0            NaN                    NaN         NaN         NaN          NaN
# 1      44.099998                    NaN         NaN         NaN          NaN
# 2            NaN                    NaN         NaN         NaN          NaN
#
#    land_area_kind  land_setback_flg  land_setback  land_kenpei  land_youseki  \
# 0             NaN               1.0           0.0          0.0           0.0
# 1             NaN               NaN           NaN          NaN           NaN
# 2             NaN               NaN           NaN          NaN           NaN
#
#    land_road_cond land_seigen  building_area_kind  management_form  \
# 0             NaN         NaN                 NaN              NaN
# 1             NaN         NaN                 NaN              NaN
# 2             NaN         NaN                 2.0              3.0
#
#    management_association_flg reform_exterior reform_exterior_other  \
# 0                         NaN             NaN                   NaN
# 1                         NaN             NaN                   NaN
# 2                         1.0             NaN                   NaN
#
#    reform_exterior_date reform_common_area  reform_common_area_date  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
#
#                                     building_tag_id   unit_id unit_name  \
# 0  321101/310201/320901/321001/210202/210301/210101  23810544       202
# 1         210101/330501/320901/321001/210301/210201  33983775       110
# 2                              210202/210301/210101  26682627       103
#
#    name_ruby  room_floor  balcony_area  dwelling_unit_window_angle  \
# 0        NaN         2.0           2.0                         5.0
# 1        NaN         1.0           4.0                         5.0
# 2        NaN         2.0           NaN                         3.0
#
#    room_count  unit_area  floor_plan_code  reform_date reform_place  \
# 0         1.0  23.180000            120.0          NaN          NaN
# 1         2.0  47.700001            230.0          NaN          NaN
# 2         2.0  46.349998            250.0          NaN          NaN
#
#   reform_place_other reform_wet_area reform_wet_area_other  \
# 0                NaN             NaN                   NaN
# 1                NaN             NaN                   NaN
# 2                NaN             NaN                   NaN
#
#    reform_wet_area_date reform_interior reform_interior_other  \
# 0                   NaN             NaN                   NaN
# 1                   NaN             NaN                   NaN
# 2                   NaN             NaN                   NaN
#
#    reform_interior_date reform_etc renovation_date renovation_etc  \
# 0                   NaN        NaN             NaN            NaN
# 1                   NaN        NaN             NaN            NaN
# 2                   NaN        NaN             NaN            NaN
#
#                                          unit_tag_id       bukken_id  \
# 0  230801/310501/220301/290901/230101/240104/2205...   1344300002216
# 1  340101/253401/220401/290901/220201/230202/2943...   1279070015508
# 2  230801/290101/220501/220201/220101/240103/2909...  31040620023451
#
#   snapshot_create_date             new_date snapshot_modify_date  \
# 0  2020-07-30 00:00:00  2020-07-30 00:00:00  2020-07-30 16:21:04
# 1  2021-07-09 00:00:00  2021-07-09 00:00:00  2021-07-30 23:36:05
# 2  2020-08-15 00:00:00  2021-01-06 00:00:00  2021-01-27 04:11:31
#
#         timelimit_date  flg_open  flg_own  bukken_type  flg_investment  \
# 0  2020-08-06 00:00:00         1        1         3102             0.0
# 1  2021-08-06 00:00:00         1        0         3101             0.0
# 2  2021-02-03 00:00:00         1        0         3102             NaN
#
#    empty_number empty_contents  post1  post2  addr1_1  addr1_2 addr2_name  \
# 0           2.0            202  598.0   44.0       27      213         笠松
# 1           NaN            110  173.0   36.0       13      119      向原１丁目
# 2           NaN            103   65.0   21.0        1      103  北二十一条東２丁目
#
#   addr3_name addr4_name           nl           el rosen_name1 eki_name1  \
# 0        NaN     1-6-51  123869683.0  487123547.0         南海線       泉佐野
# 1       11-1        NaN  128659541.0  502875929.0   東京メトロ有楽町線      小竹向原
# 2        NaN       2-36  155106911.0  508882127.0     札幌市営南北線      北24条
#
#   bus_stop1  bus_time1  walk_distance1 rosen_name2 eki_name2 bus_stop2  \
# 0       NaN        0.0          1040.0         NaN       NaN       NaN
# 1       NaN        NaN           320.0   東京メトロ有楽町線        千川       NaN
# 2       NaN        NaN           880.0     札幌市営南北線      北18条       NaN
#
#    bus_time2  walk_distance2            traffic_other  traffic_car  \
# 0        NaN             NaN                      NaN          NaN
# 1        NaN           400.0      東京地下鉄副都心線 小竹向原 徒歩4分          NaN
# 2        NaN          1120.0  札幌市営地下鉄東豊線 北13条東駅 徒歩16分          NaN
#
#    snapshot_land_area  snapshot_land_shidou  land_shidou_a  land_shidou_b  \
# 0                 NaN                   NaN            NaN            NaN
# 1                 NaN                   NaN            NaN            NaN
# 2                 NaN                   NaN            NaN            NaN
#
#    land_mochibun_a  land_mochibun_b  house_area  flg_new  house_kanrinin  \
# 0              NaN              NaN       23.18        0             NaN
# 1              NaN              NaN       47.70        0             NaN
# 2              NaN              NaN       46.35        0             NaN
#
#    room_kaisuu  snapshot_window_angle  madori_number_all  madori_kind_all  \
# 0          2.0                    5.0                  1               20
# 1          1.0                    5.0                  2               30
# 2          2.0                    3.0                  2               50
#
#    money_kyoueki  money_kyoueki_tax  money_rimawari_now  money_shuuzen  \
# 0         3000.0                3.0                 NaN            NaN
# 1         6000.0                3.0                 NaN            NaN
# 2         1500.0                2.0                 NaN            NaN
#
#    money_shuuzenkikin money_sonota_str1  money_sonota1 money_sonota_str2  \
# 0                 NaN        木下の賃貸　友の会費         1760.0             カギ交換代
# 1                 NaN               NaN            NaN               NaN
# 2                 NaN               町会費          200.0           その他初期費用
#
#    money_sonota2 money_sonota_str3  money_sonota3  parking_money  \
# 0        16500.0         木下の消毒サービス        26400.0         8800.0
# 1            NaN               NaN            NaN        22000.0
# 2        33000.0               NaN            NaN         8800.0
#
#    parking_money_tax  parking_kubun  parking_distance  parking_number  \
# 0                2.0            1.0               0.0             1.0
# 1                2.0            3.0             300.0             NaN
# 2                2.0            1.0               0.0             NaN
#
#   parking_memo  genkyo_code  usable_status  usable_date school_ele_name  \
# 0          NaN          3.0              3     202009.0             NaN
# 1          NaN          2.0              1          NaN       板橋区立向原小学校
# 2          NaN          NaN              1          NaN           幌北小学校
#
#    school_ele_distance  school_ele_code school_jun_name  school_jun_distance  \
# 0                  NaN              NaN             NaN                  NaN
# 1                291.0              NaN       板橋区立向原中学校                340.0
# 2                538.0              NaN           北辰中学校                644.0
#
#    school_jun_code  convenience_distance  super_distance  hospital_distance  \
# 0              NaN                 239.0          1280.0                NaN
# 1              NaN                 399.0           434.0                NaN
# 2              NaN                 201.0           741.0              574.0
#
#    park_distance  drugstore_distance  bank_distance  shopping_street_distance  \
# 0            NaN                 NaN            NaN                       NaN
# 1            NaN               435.0            NaN                       NaN
# 2            NaN                 NaN            NaN                       NaN
#
#   est_other_name  est_other_distance  \
# 0            NaN                 NaN
# 1          小竹向原駅               320.0
# 2            NaN                 NaN
#
#                                             statuses  parking_keiyaku  \
# 0  110702/210202/220101/220201/220301/230101/2308...              NaN
# 1  110301/210101/210201/210301/220101/220201/2203...              NaN
# 2  110201/110901/121001/210101/210202/220101/2202...              NaN
#
#              money_hoshou_company  free_rent_duration  free_rent_gen_timing  \
# 0                             NaN                 NaN                   NaN
# 1            初回賃料等の50％、更新時1年毎に1万円                 NaN                   NaN
# 2  ？月額家賃の50％、毎年10，000円　？月額家賃の100％                 NaN                   NaN
#
#    LAT_LON_PRODUCT  LAT_DIV_LON  BUILDING_STATUS_PRODUCT  \
# 0      4656.197883     0.254317                      NaN
# 1      4992.582161     0.255875                      NaN
# 2      6090.585502     0.304825                      NaN
#
#    MONEY_KYOUEKI_DIV_UNIT_AREA_MAX  MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN  \
# 0                              NaN                                  NaN
# 1                       136.054423                           264599.991
# 2                              NaN                                  NaN
#
#    WALK_DISTANCE_PRODUCT  BUS_TIME_DIV_WALK_DISTANCE1  \
# 0                    NaN                          0.0
# 1               128000.0                          NaN
# 2               985600.0                          NaN
#
#    TOTAL_FLOOR_AREA_DIV_BUILDING_AREA  LAND_MOCHIBUN_RATIO  \
# 0                                 NaN                  NaN
# 1                                 NaN                  NaN
# 2                                 NaN                  NaN
#
#    LAND_ROAD_COND_DIV_LAND_AREA_ALL  PARKING_DISTANCE_DIV_PARKING_NUMBER  \
# 0                               NaN                                  0.0
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
#
#    PARKING_MONEY_DIV_PARKING_DISTANCE
# 0                        8.800000e+09
# 1                        7.333333e+01
# 2                        8.800000e+09

# %%
# ユニークな値の数を取得
unique_count = all_df["money_hoshou_company"].nunique(dropna=True)
print(f"ユニークな building_name の数: {unique_count}")
# Out:
# ユニークな building_name の数: 191552

# %%
type("money_hoshou_company")
# Out:
# str

# %%
# 1. 'full_address' 列の先頭3文字を抽出して 'prefecture' 列に追加
all_df["prefecture"] = all_df["full_address"].str[:3]

# 2. LabelEncoder のインスタンスを作成
le = LabelEncoder()

# 3. 'prefecture' 列にラベルエンコーディングを適用し、新しい列 'prefecture_encoded' に保存
all_df["prefecture_encoded"] = le.fit_transform(all_df["prefecture"])
all_df["prefecture_encoded"]
# Out:
# 0          9
# 1         26
# 2          4
# 3         21
# 4         21
#           ..
# 384535    25
# 384536    21
# 384537    26
# 384538    21
# 384539    26
# Name: prefecture_encoded, Length: 969047, dtype: int64

# %%
for x in all_df.columns:
    if all_df[x].dtype == 'object' or "ruby" in x or "id" in x:
        print(x)
        print(all_df[x].head(1))
        all_df.drop(x, axis=1, inplace=True)
# Out:
# building_id
# 0    a000002
# Name: building_id, dtype: object
# building_create_date
# 0    2014-06-27 21:18:41
# Name: building_create_date, dtype: object
# building_modify_date
# 0    2024-05-25 00:45:07
# Name: building_modify_date, dtype: object
# building_name
# 0    Plaisirりんくう
# Name: building_name, dtype: object
# building_name_ruby
# 0   NaN
# Name: building_name_ruby, dtype: float64
# homes_building_name
# 0    プレジール りんくう
# Name: homes_building_name, dtype: object
# homes_building_name_ruby
# 0    プレジールりんくう
# Name: homes_building_name_ruby, dtype: object
# full_address
# 0    大阪府泉佐野市笠松1丁目6-51
# Name: full_address, dtype: object
# land_seigen
# 0    NaN
# Name: land_seigen, dtype: object
# reform_exterior
# 0    NaN
# Name: reform_exterior, dtype: object
# reform_exterior_other
# 0    NaN
# Name: reform_exterior_other, dtype: object
# reform_common_area
# 0    NaN
# Name: reform_common_area, dtype: object
# building_tag_id
# 0    321101/310201/320901/321001/210202/210301/210101
# Name: building_tag_id, dtype: object
# unit_id
# 0    23810544
# Name: unit_id, dtype: int64
# unit_name
# 0    202
# Name: unit_name, dtype: object
# name_ruby
# 0   NaN
# Name: name_ruby, dtype: float64
# reform_place
# 0    NaN
# Name: reform_place, dtype: object
# reform_place_other
# 0    NaN
# Name: reform_place_other, dtype: object
# reform_wet_area
# 0    NaN
# Name: reform_wet_area, dtype: object
# reform_wet_area_other
# 0    NaN
# Name: reform_wet_area_other, dtype: object
# reform_interior
# 0    NaN
# Name: reform_interior, dtype: object
# reform_interior_other
# 0    NaN
# Name: reform_interior_other, dtype: object
# reform_etc
# 0    NaN
# Name: reform_etc, dtype: object
# renovation_date
# 0    NaN
# Name: renovation_date, dtype: object
# renovation_etc
# 0    NaN
# Name: renovation_etc, dtype: object
# unit_tag_id
# 0    230801/310501/220301/290901/230101/240104/2205...
# Name: unit_tag_id, dtype: object
# bukken_id
# 0    1344300002216
# Name: bukken_id, dtype: int64
# snapshot_create_date
# 0    2020-07-30 00:00:00
# Name: snapshot_create_date, dtype: object
# new_date
# 0    2020-07-30 00:00:00
# Name: new_date, dtype: object
# snapshot_modify_date
# 0    2020-07-30 16:21:04
# Name: snapshot_modify_date, dtype: object
# timelimit_date
# 0    2020-08-06 00:00:00
# Name: timelimit_date, dtype: object
# empty_contents
# 0    202
# Name: empty_contents, dtype: object
# addr2_name
# 0    笠松
# Name: addr2_name, dtype: object
# addr3_name
# 0    NaN
# Name: addr3_name, dtype: object
# addr4_name
# 0    1-6-51
# Name: addr4_name, dtype: object
# rosen_name1
# 0    南海線
# Name: rosen_name1, dtype: object
# eki_name1
# 0    泉佐野
# Name: eki_name1, dtype: object
# bus_stop1
# 0    NaN
# Name: bus_stop1, dtype: object
# rosen_name2
# 0    NaN
# Name: rosen_name2, dtype: object
# eki_name2
# 0    NaN
# Name: eki_name2, dtype: object
# bus_stop2
# 0    NaN
# Name: bus_stop2, dtype: object
# traffic_other
# 0    NaN
# Name: traffic_other, dtype: object
# snapshot_land_shidou
# 0   NaN
# Name: snapshot_land_shidou, dtype: float64
# land_shidou_a
# 0   NaN
# Name: land_shidou_a, dtype: float64
# land_shidou_b
# 0   NaN
# Name: land_shidou_b, dtype: float64
# money_sonota_str1
# 0    木下の賃貸　友の会費
# Name: money_sonota_str1, dtype: object
# money_sonota_str2
# 0    カギ交換代
# Name: money_sonota_str2, dtype: object
# money_sonota_str3
# 0    木下の消毒サービス
# Name: money_sonota_str3, dtype: object
# parking_memo
# 0    NaN
# Name: parking_memo, dtype: object
# school_ele_name
# 0    NaN
# Name: school_ele_name, dtype: object
# school_jun_name
# 0    NaN
# Name: school_jun_name, dtype: object
# est_other_name
# 0    NaN
# Name: est_other_name, dtype: object
# statuses
# 0    110702/210202/220101/220201/220301/230101/2308...
# Name: statuses, dtype: object
# money_hoshou_company
# 0    NaN
# Name: money_hoshou_company, dtype: object
# prefecture
# 0    大阪府
# Name: prefecture, dtype: object

# %%
all_df
# Out:
#         target_ym  money_room  building_status  building_type  unit_count  \
# 0          202007     38000.0                1              3        22.0
# 1          202107    103000.0                1              1         NaN
# 2          202101     50000.0                1              3         NaN
# 3          202007     37000.0                1              3         NaN
# 4          202101     33000.0                1              3         NaN
# ...           ...         ...              ...            ...         ...
# 384535     202301         NaN                1              3         NaN
# 384536     202301         NaN                1              1        60.0
# 384537     202207         NaN                1              1         4.0
# 384538     202201         NaN                1              1        67.0
# 384539     202207         NaN                1              1        24.0
#
#                lon        lat  building_structure  total_floor_area  \
# 0       135.309302  34.411514                 1.0               NaN
# 1       139.684556  35.741834                 4.0               NaN
# 2       141.352789  43.087834                 1.0               NaN
# 3       133.335824  34.502380                 3.0               NaN
# 4       133.335824  34.502380                 3.0               NaN
# ...            ...        ...                 ...               ...
# 384535  138.885862  37.545584                 1.0               NaN
# 384536  132.467261  34.397480                 4.0               NaN
# 384537  139.443328  35.687886                11.0               NaN
# 384538  132.463112  34.395376                 5.0               NaN
# 384539  139.812066  35.713599                 4.0               NaN
#
#         building_area  floor_count  basement_floor_count  year_built  \
# 0                 NaN          2.0                   NaN    200210.0
# 1                 NaN          3.0                   NaN    197612.0
# 2                 NaN          3.0                   NaN    199607.0
# 3                 NaN          2.0                   NaN    199309.0
# 4                 NaN          2.0                   NaN    199309.0
# ...               ...          ...                   ...         ...
# 384535            NaN          2.0                   NaN    200603.0
# 384536            NaN         12.0                   NaN    200701.0
# 384537            NaN          2.0                   NaN    201911.0
# 384538            NaN         13.0                   NaN    200511.0
# 384539            NaN          7.0                   NaN    200709.0
#
#         building_land_area  land_area_all  unit_area_min  unit_area_max  \
# 0                      NaN            NaN            NaN            NaN
# 1                      NaN            NaN      44.099998      44.099998
# 2                      NaN            NaN            NaN            NaN
# 3                      NaN            NaN            NaN            NaN
# 4                      NaN            NaN            NaN            NaN
# ...                    ...            ...            ...            ...
# 384535                 NaN            NaN            NaN            NaN
# 384536                 NaN            NaN            NaN            NaN
# 384537                 NaN            NaN            NaN            NaN
# 384538                 NaN            NaN            NaN            NaN
# 384539                 NaN            NaN      26.670000      29.450001
#
#         building_land_chimoku  land_youto  land_toshi  land_chisei  \
# 0                         NaN         NaN         NaN          NaN
# 1                         NaN         NaN         NaN          NaN
# 2                         NaN         NaN         NaN          NaN
# 3                         NaN        12.0         1.0          NaN
# 4                         NaN        12.0         1.0          NaN
# ...                       ...         ...         ...          ...
# 384535                    NaN         NaN         NaN          NaN
# 384536                    NaN         NaN         NaN          NaN
# 384537                    NaN         NaN         NaN          NaN
# 384538                    NaN         NaN         NaN          NaN
# 384539                    NaN         4.0         1.0          NaN
#
#         land_area_kind  land_setback_flg  land_setback  land_kenpei  \
# 0                  NaN               1.0           0.0          0.0
# 1                  NaN               NaN           NaN          NaN
# 2                  NaN               NaN           NaN          NaN
# 3                  NaN               NaN           NaN          NaN
# 4                  NaN               NaN           NaN          NaN
# ...                ...               ...           ...          ...
# 384535             NaN               NaN           NaN          NaN
# 384536             NaN               1.0           NaN          0.0
# 384537             NaN               NaN           NaN          NaN
# 384538             NaN               1.0           NaN          0.0
# 384539             NaN               NaN           NaN         80.0
#
#         land_youseki  land_road_cond  building_area_kind  management_form  \
# 0                0.0             NaN                 NaN              NaN
# 1                NaN             NaN                 NaN              NaN
# 2                NaN             NaN                 2.0              3.0
# 3                NaN             NaN                 NaN              NaN
# 4                NaN             NaN                 NaN              NaN
# ...              ...             ...                 ...              ...
# 384535           NaN             NaN                 NaN              NaN
# 384536           0.0             NaN                 NaN              NaN
# 384537           NaN             NaN                 NaN              NaN
# 384538           0.0             NaN                 NaN              NaN
# 384539         300.0            10.0                 NaN              NaN
#
#         management_association_flg  reform_exterior_date  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              1.0                   NaN
# 3                              1.0                   NaN
# 4                              1.0                   NaN
# ...                            ...                   ...
# 384535                         NaN                   NaN
# 384536                         NaN                   NaN
# 384537                         NaN                   NaN
# 384538                         NaN                   NaN
# 384539                         NaN                   NaN
#
#         reform_common_area_date  room_floor  balcony_area  \
# 0                           NaN         2.0           2.0
# 1                           NaN         1.0           4.0
# 2                           NaN         2.0           NaN
# 3                           NaN         1.0           NaN
# 4                           NaN         2.0           NaN
# ...                         ...         ...           ...
# 384535                      NaN         NaN           NaN
# 384536                      NaN         5.0           0.0
# 384537                      NaN         1.0           NaN
# 384538                      NaN         2.0           0.0
# 384539                      NaN         2.0           NaN
#
#         dwelling_unit_window_angle  room_count  unit_area  floor_plan_code  \
# 0                              5.0         1.0  23.180000            120.0
# 1                              5.0         2.0  47.700001            230.0
# 2                              3.0         2.0  46.349998            250.0
# 3                              6.0         2.0  39.740002            230.0
# 4                              6.0         2.0  39.740002            230.0
# ...                            ...         ...        ...              ...
# 384535                         1.0         2.0  67.070000            250.0
# 384536                         5.0         2.0  43.650002            220.0
# 384537                         5.0         1.0  38.939999            150.0
# 384538                         1.0         1.0  25.500000            120.0
# 384539                         4.0         1.0  29.420000            110.0
#
#         reform_date  reform_wet_area_date  reform_interior_date  flg_open  \
# 0               NaN                   NaN                   NaN         1
# 1               NaN                   NaN                   NaN         1
# 2               NaN                   NaN                   NaN         1
# 3               NaN                   NaN                   NaN         1
# 4               NaN                   NaN                   NaN         1
# ...             ...                   ...                   ...       ...
# 384535          NaN                   NaN                   NaN         1
# 384536          NaN                   NaN                   NaN         1
# 384537          NaN                   NaN                   NaN         1
# 384538          NaN                   NaN                   NaN         1
# 384539          NaN                   NaN                   NaN         1
#
#         flg_own  bukken_type  flg_investment  empty_number  post1  post2  \
# 0             1         3102             0.0           2.0  598.0   44.0
# 1             0         3101             0.0           NaN  173.0   36.0
# 2             0         3102             NaN           NaN   65.0   21.0
# 3             1         3102             NaN           2.0  720.0   92.0
# 4             1         3102             NaN           NaN  720.0   92.0
# ...         ...          ...             ...           ...    ...    ...
# 384535        0         3102             NaN           NaN  954.0  112.0
# 384536        1         3101             NaN           NaN  730.0   14.0
# 384537        1         3101             0.0           NaN  186.0    4.0
# 384538        0         3101             0.0          12.0  730.0   13.0
# 384539        1         3101             0.0           NaN  131.0   33.0
#
#         addr1_1  addr1_2           nl           el  bus_time1  walk_distance1  \
# 0            27      213  123869683.0  487123547.0        0.0          1040.0
# 1            13      119  128659541.0  502875929.0        NaN           320.0
# 2             1      103  155106911.0  508882127.0        NaN           880.0
# 3            34      207  124196872.0  480018303.0       25.0           700.0
# 4            34      207  124196970.0  480018256.0        NaN          2012.0
# ...         ...      ...          ...          ...        ...             ...
# 384535       15      211  135153255.0  500000608.0        9.0           240.0
# 384536       34      101  123819149.0  476890933.0        NaN           320.0
# 384537       13      215  128464858.0  502007534.0        NaN          1040.0
# 384538       34      101  123811615.0  476876161.0        0.0           320.0
# 384539       13      107  128557240.0  503335280.0        NaN           560.0
#
#         bus_time2  walk_distance2  traffic_car  snapshot_land_area  \
# 0             NaN             NaN          NaN                 NaN
# 1             NaN           400.0          NaN                 NaN
# 2             NaN          1120.0          NaN                 NaN
# 3            15.0           700.0          NaN                 NaN
# 4             NaN          3532.0          NaN                 NaN
# ...           ...             ...          ...                 ...
# 384535        NaN             NaN          NaN                 NaN
# 384536        NaN           960.0          NaN                 NaN
# 384537        NaN          1680.0          NaN                 NaN
# 384538        NaN           320.0          NaN                 NaN
# 384539        NaN           400.0          NaN                 NaN
#
#         land_mochibun_a  land_mochibun_b  house_area  flg_new  house_kanrinin  \
# 0                   NaN              NaN       23.18        0             NaN
# 1                   NaN              NaN       47.70        0             NaN
# 2                   NaN              NaN       46.35        0             NaN
# 3                   NaN              NaN       39.74        0             NaN
# 4                   NaN              NaN       39.74        0             NaN
# ...                 ...              ...         ...      ...             ...
# 384535              NaN              NaN       67.00        0             NaN
# 384536              NaN              NaN       43.00        1             NaN
# 384537              NaN              NaN       38.00        0             3.0
# 384538              NaN              NaN       25.50        0             NaN
# 384539              NaN              NaN       29.00        0             NaN
#
#         room_kaisuu  snapshot_window_angle  madori_number_all  \
# 0               2.0                    5.0                  1
# 1               1.0                    5.0                  2
# 2               2.0                    3.0                  2
# 3               1.0                    6.0                  2
# 4               2.0                    7.0                  2
# ...             ...                    ...                ...
# 384535          2.0                    1.0                  2
# 384536          5.0                    5.0                  2
# 384537          1.0                    5.0                  1
# 384538          2.0                    1.0                  1
# 384539          2.0                    4.0                  1
#
#         madori_kind_all  money_kyoueki  money_kyoueki_tax  money_rimawari_now  \
# 0                    20         3000.0                3.0                 NaN
# 1                    30         6000.0                3.0                 NaN
# 2                    50         1500.0                2.0                 NaN
# 3                    30         2000.0                NaN                 NaN
# 4                    30         2000.0                NaN                 NaN
# ...                 ...            ...                ...                 ...
# 384535               50            0.0                NaN                 NaN
# 384536               20            0.0                2.0                 NaN
# 384537               50         7000.0                3.0                 NaN
# 384538               20         3000.0                3.0                 NaN
# 384539               10         7400.0                2.0                 NaN
#
#         money_shuuzen  money_shuuzenkikin  money_sonota1  money_sonota2  \
# 0                 NaN                 NaN         1760.0        16500.0
# 1                 NaN                 NaN            NaN            NaN
# 2                 NaN                 NaN          200.0        33000.0
# 3                 NaN                 NaN            NaN            NaN
# 4                 NaN                 NaN        33000.0            NaN
# ...               ...                 ...            ...            ...
# 384535            NaN                 NaN            NaN            NaN
# 384536            NaN                 NaN            NaN            NaN
# 384537            NaN                 NaN        15000.0            NaN
# 384538            NaN                 NaN         1100.0         3300.0
# 384539            NaN                 NaN            NaN            NaN
#
#         money_sonota3  parking_money  parking_money_tax  parking_kubun  \
# 0             26400.0         8800.0                2.0            1.0
# 1                 NaN        22000.0                2.0            3.0
# 2                 NaN         8800.0                2.0            1.0
# 3                 NaN         3300.0                2.0            1.0
# 4                 NaN         3300.0                2.0            1.0
# ...               ...            ...                ...            ...
# 384535            NaN            NaN                NaN            1.0
# 384536            NaN        33600.0                2.0            2.0
# 384537            NaN        10000.0                2.0            3.0
# 384538        19800.0        33000.0                2.0            1.0
# 384539            NaN            NaN                NaN            4.0
#
#         parking_distance  parking_number  genkyo_code  usable_status  \
# 0                    0.0             1.0          3.0              3
# 1                  300.0             NaN          2.0              1
# 2                    0.0             NaN          NaN              1
# 3                    NaN             7.0          2.0              1
# 4                    0.0             NaN          2.0              1
# ...                  ...             ...          ...            ...
# 384535               NaN             2.0          NaN              1
# 384536               NaN             NaN          2.0              1
# 384537              10.0             NaN          1.0              3
# 384538               0.0             1.0          2.0              2
# 384539               NaN             NaN          2.0              1
#
#         usable_date  school_ele_distance  school_ele_code  \
# 0          202009.0                  NaN              NaN
# 1               NaN                291.0              NaN
# 2               NaN                538.0              NaN
# 3               NaN                  NaN              NaN
# 4               NaN                  NaN              NaN
# ...             ...                  ...              ...
# 384535          NaN                  NaN              NaN
# 384536          NaN                260.0              NaN
# 384537     202209.0                  NaN              NaN
# 384538          NaN                490.0              NaN
# 384539          NaN                  NaN              NaN
#
#         school_jun_distance  school_jun_code  convenience_distance  \
# 0                       NaN              NaN                 239.0
# 1                     340.0              NaN                 399.0
# 2                     644.0              NaN                 201.0
# 3                       NaN              NaN                   NaN
# 4                       NaN              NaN                   NaN
# ...                     ...              ...                   ...
# 384535                  NaN              NaN                   NaN
# 384536                280.0              NaN                 300.0
# 384537                  NaN              NaN                 249.0
# 384538                633.0              NaN                 188.0
# 384539                  NaN              NaN                 130.0
#
#         super_distance  hospital_distance  park_distance  drugstore_distance  \
# 0               1280.0                NaN            NaN                 NaN
# 1                434.0                NaN            NaN               435.0
# 2                741.0              574.0            NaN                 NaN
# 3               1114.0                NaN            NaN                 NaN
# 4                  NaN                NaN            NaN                 NaN
# ...                ...                ...            ...                 ...
# 384535           882.0                NaN            NaN                 NaN
# 384536           380.0              440.0            NaN               530.0
# 384537           430.0                NaN            NaN               530.0
# 384538           315.0              422.0         1342.0               163.0
# 384539           220.0              730.0            NaN               820.0
#
#         bank_distance  shopping_street_distance  est_other_distance  \
# 0                 NaN                       NaN                 NaN
# 1                 NaN                       NaN               320.0
# 2                 NaN                       NaN                 NaN
# 3                 NaN                       NaN              1114.0
# 4                 NaN                       NaN               469.0
# ...               ...                       ...                 ...
# 384535            NaN                       NaN                 NaN
# 384536          600.0                       NaN                 NaN
# 384537            NaN                       NaN               460.0
# 384538          117.0                       NaN                 NaN
# 384539         2390.0                       NaN               790.0
#
#         parking_keiyaku  free_rent_duration  free_rent_gen_timing  \
# 0                   NaN                 NaN                   NaN
# 1                   NaN                 NaN                   NaN
# 2                   NaN                 NaN                   NaN
# 3                   NaN                 NaN                   NaN
# 4                   NaN                 NaN                   NaN
# ...                 ...                 ...                   ...
# 384535              1.0                 NaN                   NaN
# 384536              NaN                 NaN                   NaN
# 384537              NaN                 NaN                   NaN
# 384538              NaN                 NaN                   NaN
# 384539              NaN                 NaN                   NaN
#
#         LAT_LON_PRODUCT  LAT_DIV_LON  BUILDING_STATUS_PRODUCT  \
# 0           4656.197883     0.254317                      NaN
# 1           4992.582161     0.255875                      NaN
# 2           6090.585502     0.304825                      NaN
# 3           4600.403304     0.258763                      NaN
# 4           4600.403304     0.258763                      NaN
# ...                 ...          ...                      ...
# 384535      5214.550850     0.270334                      NaN
# 384536      4556.539987     0.259668                      NaN
# 384537      4976.437548     0.255931                      NaN
# 384538      4556.118480     0.259660                      NaN
# 384539      4993.192008     0.255440                      NaN
#
#         MONEY_KYOUEKI_DIV_UNIT_AREA_MAX  MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN  \
# 0                                   NaN                                  NaN
# 1                            136.054423                         264599.99100
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 384535                              NaN                                  NaN
# 384536                              NaN                                  NaN
# 384537                              NaN                                  NaN
# 384538                              NaN                                  NaN
# 384539                       251.273329                         197358.00074
#
#         WALK_DISTANCE_PRODUCT  BUS_TIME_DIV_WALK_DISTANCE1  \
# 0                         NaN                     0.000000
# 1                    128000.0                          NaN
# 2                    985600.0                          NaN
# 3                    490000.0                     0.035714
# 4                   7106384.0                          NaN
# ...                       ...                          ...
# 384535                    NaN                     0.037500
# 384536               307200.0                          NaN
# 384537              1747200.0                          NaN
# 384538               102400.0                     0.000000
# 384539               224000.0                          NaN
#
#         TOTAL_FLOOR_AREA_DIV_BUILDING_AREA  LAND_MOCHIBUN_RATIO  \
# 0                                      NaN                  NaN
# 1                                      NaN                  NaN
# 2                                      NaN                  NaN
# 3                                      NaN                  NaN
# 4                                      NaN                  NaN
# ...                                    ...                  ...
# 384535                                 NaN                  NaN
# 384536                                 NaN                  NaN
# 384537                                 NaN                  NaN
# 384538                                 NaN                  NaN
# 384539                                 NaN                  NaN
#
#         LAND_ROAD_COND_DIV_LAND_AREA_ALL  PARKING_DISTANCE_DIV_PARKING_NUMBER  \
# 0                                    NaN                                  0.0
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 384535                               NaN                                  NaN
# 384536                               NaN                                  NaN
# 384537                               NaN                                  NaN
# 384538                               NaN                                  0.0
# 384539                               NaN                                  NaN
#
#         PARKING_MONEY_DIV_PARKING_DISTANCE  prefecture_encoded
# 0                             8.800000e+09                   9
# 1                             7.333333e+01                  26
# 2                             8.800000e+09                   4
# 3                                      NaN                  21
# 4                             3.300000e+09                  21
# ...                                    ...                 ...
# 384535                                 NaN                  25
# 384536                                 NaN                  21
# 384537                        9.999999e+02                  26
# 384538                        3.300000e+10                  21
# 384539                                 NaN                  26
#
# [969047 rows x 111 columns]

# %%
all_df.columns
# Out:
# Index(['target_ym', 'money_room', 'building_status', 'building_type',
#        'unit_count', 'lon', 'lat', 'building_structure', 'total_floor_area',
#        'building_area',
#        ...
#        'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX',
#        'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN', 'WALK_DISTANCE_PRODUCT',
#        'BUS_TIME_DIV_WALK_DISTANCE1', 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA',
#        'LAND_MOCHIBUN_RATIO', 'LAND_ROAD_COND_DIV_LAND_AREA_ALL',
#        'PARKING_DISTANCE_DIV_PARKING_NUMBER',
#        'PARKING_MONEY_DIV_PARKING_DISTANCE', 'prefecture_encoded'],
#       dtype='object', length=111)

# %%
train = all_df[:len(train)]
test = all_df[len(train):]

# %%
# 目的変数と説明変数に分割
train_x = train.drop("money_room", axis=1)
train_y = train["money_room"]
test_x = test.drop("money_room", axis=1)

# %%
# 学習データを学習データとバリデーションデータに分ける
from sklearn.model_selection import KFold

kf = KFold(n_splits=5, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
import optuna
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import time

def evaluate(features):
    dtrain = xgb.DMatrix(tr_x[features], label=tr_y)
    dvalid = xgb.DMatrix(va_x[features], label=va_y)
    params = {'verbosity': 0, 'random_state': 71}
    num_round = 10  # 実際にはもっと多いround数が適切
    early_stopping_rounds = 3
    watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
    model = xgb.train(params, dtrain, num_round,
                      evals=watchlist, early_stopping_rounds=early_stopping_rounds,
                      verbose_eval=0)
    va_pred = model.predict(dvalid)

    # RMSEを計算
    rmse = mean_squared_error(va_y, va_pred, squared=False)
    return rmse

def objective(trial):
    selected_features = []
    for col in train_x.columns:
        use_feature = trial.suggest_categorical(col, [True, False])
        if use_feature:
            selected_features.append(col)

    if len(selected_features) == 0:
        return float('inf')  # RMSEで全く特徴量なしの場合は非常に大きな値を返す

    score = evaluate(selected_features)
    return score

# Optunaによる最適化（RMSEは小さいほど良いので direction='minimize'）
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
best_trial = study.best_trial

print("Best Score (RMSE):", best_trial.value)
print("Best Feature Set:")
best_features = [k for k, v in best_trial.params.items() if v == True]
print(best_features)
# Out:
# [I 2024-12-10 05:11:28,526] A new study created in memory with name: no-name-4c84f50b-0321-4a17-a01f-bc539d8d2f56
# [I 2024-12-10 05:11:29,654] Trial 0 finished with value: 21119.843331735232 and parameters: {'target_ym': False, 'building_status': True, 'building_type': False, 'unit_count': True, 'lon': True, 'lat': True, 'building_structure': False, 'total_floor_area': True, 'building_area': False, 'floor_count': False, 'basement_floor_count': True, 'year_built': True, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': False, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': False, 'management_form': False, 'management_association_flg': True, 'reform_exterior_date': False, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': True, 'unit_area': False, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': True, 'reform_interior_date': False, 'flg_open': True, 'flg_own': False, 'bukken_type': True, 'flg_investment': True, 'empty_number': False, 'post1': False, 'post2': False, 'addr1_1': True, 'addr1_2': False, 'nl': False, 'el': False, 'bus_time1': False, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': False, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': True, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': False, 'money_kyoueki_tax': False, 'money_rimawari_now': False, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': True, 'parking_kubun': False, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': False, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': True, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': True, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': False, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': False, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': True}. Best is trial 0 with value: 21119.843331735232.
# [I 2024-12-10 05:11:30,802] Trial 1 finished with value: 32666.06099837666 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': True, 'building_structure': True, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': True, 'land_area_all': True, 'unit_area_min': False, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': False, 'land_setback': False, 'land_kenpei': False, 'land_youseki': True, 'land_road_cond': False, 'building_area_kind': False, 'management_form': True, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': True, 'unit_area': False, 'floor_plan_code': True, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': True, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': True, 'empty_number': False, 'post1': False, 'post2': True, 'addr1_1': True, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': False, 'walk_distance2': True, 'traffic_car': True, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': True, 'room_kaisuu': True, 'snapshot_window_angle': True, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': False, 'money_rimawari_now': False, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': True, 'parking_kubun': False, 'parking_distance': False, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': True, 'school_ele_distance': False, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': False}. Best is trial 0 with value: 21119.843331735232.
# [I 2024-12-10 05:11:31,819] Trial 2 finished with value: 16881.413940509177 and parameters: {'target_ym': False, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': False, 'floor_count': False, 'basement_floor_count': False, 'year_built': False, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': True, 'building_land_chimoku': True, 'land_youto': False, 'land_toshi': True, 'land_chisei': True, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': True, 'management_form': True, 'management_association_flg': True, 'reform_exterior_date': False, 'reform_common_area_date': True, 'room_floor': False, 'balcony_area': True, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': True, 'reform_interior_date': True, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': False, 'post1': True, 'post2': True, 'addr1_1': True, 'addr1_2': False, 'nl': False, 'el': True, 'bus_time1': False, 'walk_distance1': False, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': True, 'snapshot_land_area': False, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': True, 'room_kaisuu': True, 'snapshot_window_angle': True, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': False, 'money_kyoueki_tax': False, 'money_rimawari_now': False, 'money_shuuzen': True, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': True, 'parking_kubun': False, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': False, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': False, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': False}. Best is trial 2 with value: 16881.413940509177.
# [I 2024-12-10 05:11:33,347] Trial 3 finished with value: 34667.71472414312 and parameters: {'target_ym': False, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': False, 'total_floor_area': False, 'building_area': False, 'floor_count': False, 'basement_floor_count': True, 'year_built': True, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': False, 'building_land_chimoku': True, 'land_youto': True, 'land_toshi': False, 'land_chisei': True, 'land_area_kind': False, 'land_setback_flg': False, 'land_setback': True, 'land_kenpei': False, 'land_youseki': True, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': True, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': False, 'balcony_area': False, 'dwelling_unit_window_angle': False, 'room_count': True, 'unit_area': True, 'floor_plan_code': True, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': True, 'flg_open': False, 'flg_own': False, 'bukken_type': True, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': True, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': False, 'walk_distance1': True, 'bus_time2': False, 'walk_distance2': True, 'traffic_car': True, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': False, 'house_area': True, 'flg_new': False, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': False, 'money_shuuzen': True, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': False, 'parking_distance': False, 'parking_number': False, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': True, 'school_jun_distance': True, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': False, 'hospital_distance': True, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': False, 'est_other_distance': False, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': False, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': False}. Best is trial 2 with value: 16881.413940509177.
# [I 2024-12-10 05:11:34,471] Trial 4 finished with value: 18281.768745383517 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': False, 'lat': False, 'building_structure': False, 'total_floor_area': False, 'building_area': False, 'floor_count': False, 'basement_floor_count': False, 'year_built': False, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': True, 'land_chisei': True, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': True, 'management_form': True, 'management_association_flg': True, 'reform_exterior_date': False, 'reform_common_area_date': True, 'room_floor': False, 'balcony_area': True, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': True, 'reform_interior_date': True, 'flg_open': True, 'flg_own': True, 'bukken_type': True, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': True, 'addr1_1': False, 'addr1_2': False, 'nl': False, 'el': False, 'bus_time1': False, 'walk_distance1': False, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': True, 'snapshot_land_area': True, 'land_mochibun_a': True, 'land_mochibun_b': False, 'house_area': True, 'flg_new': True, 'house_kanrinin': True, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': True, 'madori_kind_all': False, 'money_kyoueki': False, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': True, 'money_shuuzenkikin': True, 'money_sonota1': True, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': False, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': True, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': True, 'hospital_distance': True, 'park_distance': True, 'drugstore_distance': True, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': False}. Best is trial 2 with value: 16881.413940509177.
# [I 2024-12-10 05:11:35,559] Trial 5 finished with value: 15856.644761636066 and parameters: {'target_ym': True, 'building_status': True, 'building_type': True, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': True, 'year_built': True, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': True, 'flg_open': False, 'flg_own': True, 'bukken_type': True, 'flg_investment': True, 'empty_number': True, 'post1': False, 'post2': False, 'addr1_1': True, 'addr1_2': True, 'nl': True, 'el': False, 'bus_time1': False, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': True, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': True, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': False, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': True, 'usable_status': False, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': True, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 5 with value: 15856.644761636066.
# [I 2024-12-10 05:11:36,743] Trial 6 finished with value: 23893.28847942408 and parameters: {'target_ym': True, 'building_status': True, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': True, 'basement_floor_count': True, 'year_built': False, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': False, 'land_chisei': True, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': True, 'land_youseki': True, 'land_road_cond': True, 'building_area_kind': True, 'management_form': True, 'management_association_flg': True, 'reform_exterior_date': True, 'reform_common_area_date': False, 'room_floor': False, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': False, 'bukken_type': True, 'flg_investment': True, 'empty_number': True, 'post1': False, 'post2': True, 'addr1_1': True, 'addr1_2': True, 'nl': True, 'el': False, 'bus_time1': False, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': True, 'snapshot_land_area': False, 'land_mochibun_a': False, 'land_mochibun_b': False, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': True, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': False, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': True, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': True, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': False, 'parking_distance': True, 'parking_number': True, 'genkyo_code': False, 'usable_status': True, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': True, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': False, 'hospital_distance': True, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 5 with value: 15856.644761636066.
# [I 2024-12-10 05:11:37,829] Trial 7 finished with value: 15744.816701314092 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': True, 'lon': True, 'lat': True, 'building_structure': False, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': True, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': True, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': True, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': False, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': True, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': False, 'parking_distance': True, 'parking_number': True, 'genkyo_code': False, 'usable_status': False, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': False, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': True}. Best is trial 7 with value: 15744.816701314092.
# [I 2024-12-10 05:11:38,907] Trial 8 finished with value: 22969.30233148816 and parameters: {'target_ym': False, 'building_status': True, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': True, 'building_structure': False, 'total_floor_area': False, 'building_area': True, 'floor_count': False, 'basement_floor_count': True, 'year_built': False, 'building_land_area': True, 'land_area_all': True, 'unit_area_min': True, 'unit_area_max': True, 'building_land_chimoku': True, 'land_youto': True, 'land_toshi': False, 'land_chisei': True, 'land_area_kind': True, 'land_setback_flg': False, 'land_setback': False, 'land_kenpei': True, 'land_youseki': True, 'land_road_cond': False, 'building_area_kind': True, 'management_form': True, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': False, 'balcony_area': True, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': True, 'floor_plan_code': True, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': True, 'flg_open': True, 'flg_own': True, 'bukken_type': False, 'flg_investment': True, 'empty_number': True, 'post1': False, 'post2': False, 'addr1_1': True, 'addr1_2': True, 'nl': False, 'el': False, 'bus_time1': True, 'walk_distance1': False, 'bus_time2': False, 'walk_distance2': False, 'traffic_car': True, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': False, 'house_kanrinin': False, 'room_kaisuu': True, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': False, 'money_rimawari_now': True, 'money_shuuzen': True, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': False, 'est_other_distance': False, 'parking_keiyaku': False, 'free_rent_duration': True, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': False, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': True}. Best is trial 7 with value: 15744.816701314092.
# [I 2024-12-10 05:11:39,957] Trial 9 finished with value: 26287.77638399233 and parameters: {'target_ym': True, 'building_status': True, 'building_type': False, 'unit_count': True, 'lon': True, 'lat': False, 'building_structure': False, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': True, 'year_built': True, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': True, 'building_land_chimoku': True, 'land_youto': True, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': False, 'land_setback': True, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': True, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': True, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': False, 'floor_plan_code': True, 'reform_date': True, 'reform_wet_area_date': True, 'reform_interior_date': True, 'flg_open': True, 'flg_own': True, 'bukken_type': True, 'flg_investment': True, 'empty_number': False, 'post1': False, 'post2': True, 'addr1_1': False, 'addr1_2': True, 'nl': False, 'el': False, 'bus_time1': True, 'walk_distance1': False, 'bus_time2': False, 'walk_distance2': True, 'traffic_car': True, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': False, 'house_area': False, 'flg_new': True, 'house_kanrinin': True, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': False, 'money_kyoueki_tax': True, 'money_rimawari_now': False, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': False, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': False, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': False, 'school_ele_distance': False, 'school_ele_code': True, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': False, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': True, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': False, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 7 with value: 15744.816701314092.
# [I 2024-12-10 05:11:40,908] Trial 10 finished with value: 24615.611203738637 and parameters: {'target_ym': True, 'building_status': False, 'building_type': False, 'unit_count': True, 'lon': False, 'lat': False, 'building_structure': False, 'total_floor_area': True, 'building_area': True, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': True, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': True, 'reform_exterior_date': True, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': True, 'dwelling_unit_window_angle': False, 'room_count': True, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': True, 'reform_interior_date': False, 'flg_open': False, 'flg_own': False, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': False, 'walk_distance2': False, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': False, 'flg_new': False, 'house_kanrinin': True, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': False, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': False, 'parking_distance': False, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': False, 'school_ele_distance': False, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': False, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': False, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': True}. Best is trial 7 with value: 15744.816701314092.
# [I 2024-12-10 05:11:42,045] Trial 11 finished with value: 15368.078580255846 and parameters: {'target_ym': True, 'building_status': True, 'building_type': True, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 11 with value: 15368.078580255846.
# [I 2024-12-10 05:11:43,170] Trial 12 finished with value: 15535.996440234763 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': True, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 11 with value: 15368.078580255846.
# [I 2024-12-10 05:11:45,041] Trial 13 finished with value: 15368.078580255846 and parameters: {'target_ym': True, 'building_status': True, 'building_type': True, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 11 with value: 15368.078580255846.
# [I 2024-12-10 05:11:46,837] Trial 14 finished with value: 15824.722639914266 and parameters: {'target_ym': True, 'building_status': True, 'building_type': False, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': True, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': False, 'flg_new': False, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': True, 'school_ele_distance': False, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 11 with value: 15368.078580255846.
# [I 2024-12-10 05:11:48,737] Trial 15 finished with value: 15368.078580255846 and parameters: {'target_ym': True, 'building_status': True, 'building_type': True, 'unit_count': True, 'lon': False, 'lat': True, 'building_structure': True, 'total_floor_area': True, 'building_area': True, 'floor_count': False, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': False, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': True, 'land_kenpei': False, 'land_youseki': False, 'land_road_cond': False, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': False, 'reform_common_area_date': False, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': False, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': True, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': False, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': False, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': True, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': False, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': True, 'madori_number_all': True, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': False, 'money_sonota1': True, 'money_sonota2': False, 'money_sonota3': True, 'parking_money': True, 'parking_money_tax': True, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': False, 'usable_status': False, 'usable_date': True, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': True, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': False, 'bank_distance': True, 'shopping_street_distance': False, 'est_other_distance': True, 'parking_keiyaku': False, 'free_rent_duration': False, 'free_rent_gen_timing': False, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': False, 'BUILDING_STATUS_PRODUCT': True, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': True, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': True, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': True, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': False, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 11 with value: 15368.078580255846.
# ...
# [I 2024-12-10 05:12:31,355] Trial 45 finished with value: 16734.623772726787 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': False, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': True, 'land_area_all': False, 'unit_area_min': True, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': True, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': True, 'flg_investment': True, 'empty_number': True, 'post1': False, 'post2': False, 'addr1_1': True, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': False, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': False, 'parking_money_tax': False, 'parking_kubun': False, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': False, 'super_distance': True, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': True, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 40 with value: 15067.25772969483.
# [I 2024-12-10 05:12:32,513] Trial 46 finished with value: 16799.701598752257 and parameters: {'target_ym': True, 'building_status': False, 'building_type': False, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': True, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': True, 'year_built': False, 'building_land_area': False, 'land_area_all': True, 'unit_area_min': False, 'unit_area_max': False, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': True, 'land_youseki': True, 'land_road_cond': True, 'building_area_kind': False, 'management_form': False, 'management_association_flg': True, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': True, 'reform_interior_date': True, 'flg_open': False, 'flg_own': False, 'bukken_type': True, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': True, 'addr1_2': True, 'nl': True, 'el': False, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': False, 'flg_new': False, 'house_kanrinin': True, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': False, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': True, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': False, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': False, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 40 with value: 15067.25772969483.
# [I 2024-12-10 05:12:33,943] Trial 47 finished with value: 31066.32690628074 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': True, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': True, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': False, 'land_setback': False, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': False, 'management_form': True, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': True, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': True, 'floor_plan_code': True, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': True, 'flg_own': True, 'bukken_type': True, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': True, 'addr1_1': True, 'addr1_2': True, 'nl': True, 'el': True, 'bus_time1': False, 'walk_distance1': False, 'bus_time2': False, 'walk_distance2': False, 'traffic_car': False, 'snapshot_land_area': True, 'land_mochibun_a': True, 'land_mochibun_b': False, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': True, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': False, 'money_kyoueki_tax': True, 'money_rimawari_now': False, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': False, 'parking_number': False, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': True, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': False, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': True, 'prefecture_encoded': True}. Best is trial 40 with value: 15067.25772969483.
# [I 2024-12-10 05:12:35,478] Trial 48 finished with value: 18485.64291148503 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': False, 'total_floor_area': False, 'building_area': True, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': True, 'land_toshi': True, 'land_chisei': True, 'land_area_kind': False, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': False, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': False, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': True, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': True, 'flg_investment': False, 'empty_number': True, 'post1': True, 'post2': False, 'addr1_1': True, 'addr1_2': True, 'nl': False, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': True, 'snapshot_land_area': True, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': False, 'money_kyoueki': True, 'money_kyoueki_tax': True, 'money_rimawari_now': True, 'money_shuuzen': True, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': True, 'parking_number': False, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': False, 'convenience_distance': True, 'super_distance': True, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': False, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': False, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': True}. Best is trial 40 with value: 15067.25772969483.
# [I 2024-12-10 05:12:36,617] Trial 49 finished with value: 15482.522612866725 and parameters: {'target_ym': True, 'building_status': False, 'building_type': True, 'unit_count': False, 'lon': True, 'lat': False, 'building_structure': True, 'total_floor_area': False, 'building_area': False, 'floor_count': True, 'basement_floor_count': False, 'year_built': True, 'building_land_area': False, 'land_area_all': False, 'unit_area_min': False, 'unit_area_max': True, 'building_land_chimoku': False, 'land_youto': False, 'land_toshi': True, 'land_chisei': False, 'land_area_kind': True, 'land_setback_flg': True, 'land_setback': False, 'land_kenpei': True, 'land_youseki': False, 'land_road_cond': True, 'building_area_kind': True, 'management_form': False, 'management_association_flg': False, 'reform_exterior_date': True, 'reform_common_area_date': True, 'room_floor': True, 'balcony_area': False, 'dwelling_unit_window_angle': True, 'room_count': False, 'unit_area': False, 'floor_plan_code': False, 'reform_date': False, 'reform_wet_area_date': False, 'reform_interior_date': False, 'flg_open': False, 'flg_own': True, 'bukken_type': True, 'flg_investment': False, 'empty_number': False, 'post1': True, 'post2': False, 'addr1_1': True, 'addr1_2': False, 'nl': True, 'el': True, 'bus_time1': True, 'walk_distance1': True, 'bus_time2': True, 'walk_distance2': False, 'traffic_car': False, 'snapshot_land_area': False, 'land_mochibun_a': True, 'land_mochibun_b': True, 'house_area': True, 'flg_new': True, 'house_kanrinin': False, 'room_kaisuu': False, 'snapshot_window_angle': False, 'madori_number_all': False, 'madori_kind_all': True, 'money_kyoueki': True, 'money_kyoueki_tax': False, 'money_rimawari_now': True, 'money_shuuzen': False, 'money_shuuzenkikin': True, 'money_sonota1': False, 'money_sonota2': True, 'money_sonota3': False, 'parking_money': True, 'parking_money_tax': False, 'parking_kubun': True, 'parking_distance': True, 'parking_number': True, 'genkyo_code': True, 'usable_status': True, 'usable_date': False, 'school_ele_distance': True, 'school_ele_code': False, 'school_jun_distance': False, 'school_jun_code': True, 'convenience_distance': True, 'super_distance': False, 'hospital_distance': False, 'park_distance': False, 'drugstore_distance': True, 'bank_distance': False, 'shopping_street_distance': True, 'est_other_distance': True, 'parking_keiyaku': True, 'free_rent_duration': True, 'free_rent_gen_timing': True, 'LAT_LON_PRODUCT': True, 'LAT_DIV_LON': True, 'BUILDING_STATUS_PRODUCT': False, 'MONEY_KYOUEKI_DIV_UNIT_AREA_MAX': False, 'MONEY_KYOUEKI_PRODUCT_UNIT_AREA_MIN': False, 'WALK_DISTANCE_PRODUCT': False, 'BUS_TIME_DIV_WALK_DISTANCE1': True, 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA': True, 'LAND_MOCHIBUN_RATIO': False, 'LAND_ROAD_COND_DIV_LAND_AREA_ALL': True, 'PARKING_DISTANCE_DIV_PARKING_NUMBER': True, 'PARKING_MONEY_DIV_PARKING_DISTANCE': False, 'prefecture_encoded': False}. Best is trial 40 with value: 15067.25772969483.
# Best Score (RMSE): 15067.25772969483
# Best Feature Set:
# ['target_ym', 'building_type', 'lon', 'building_structure', 'building_area', 'floor_count', 'year_built', 'unit_area_max', 'land_toshi', 'land_area_kind', 'land_setback_flg', 'land_kenpei', 'land_road_cond', 'reform_exterior_date', 'reform_common_area_date', 'room_floor', 'dwelling_unit_window_angle', 'unit_area', 'flg_own', 'bukken_type', 'empty_number', 'post1', 'addr1_1', 'addr1_2', 'nl', 'el', 'bus_time1', 'walk_distance1', 'bus_time2', 'snapshot_land_area', 'land_mochibun_a', 'land_mochibun_b', 'house_area', 'flg_new', 'madori_kind_all', 'money_kyoueki', 'money_kyoueki_tax', 'money_rimawari_now', 'money_shuuzenkikin', 'money_sonota2', 'parking_money', 'parking_kubun', 'parking_distance', 'genkyo_code', 'usable_status', 'school_ele_distance', 'convenience_distance', 'drugstore_distance', 'shopping_street_distance', 'est_other_distance', 'parking_keiyaku', 'free_rent_duration', 'free_rent_gen_timing', 'LAT_LON_PRODUCT', 'LAT_DIV_LON', 'TOTAL_FLOOR_AREA_DIV_BUILDING_AREA', 'PARKING_DISTANCE_DIV_PARKING_NUMBER', 'prefecture_encoded']

# %%
# @title デフォルトのタイトル テキスト
from sklearn.linear_model import LogisticRegression

import numpy as np
import gc
from itertools import combinations
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from itertools import combinations
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error  # r2_score から mean_squared_error に変更
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # 評価指標の累計を保持する辞書
    sum_metric = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_metric[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと評価指標の初期化
        metric_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params2 = {
            'iterations': 254,
            'depth': 5,
            'learning_rate': 0.08377009991199288,
            'l2_leaf_reg': 1,
            'bagging_temperature': 0.7204457890870082,
            'min_data_in_leaf': 4,
            "random_state": 13,
            "verbose": 0
        }
        model2 = CatBoostRegressor(**params2)

        # モデル3: XGBRegressor
        params3 = {
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmse = mean_squared_error(y_valid, preds, squared=False)  # RMSEを計算
            print(f"Fold {fold + 1} RMSE for {name} = {rmse}")
            metric_dict[(name,)] = rmse  # キーをタプルに変更
            valid_pred_dict[(name,)] = preds
            sum_metric[comb] += rmse  # 各組み合わせの累積RMSEを更新

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[(comb_part,)] for comb_part in comb], axis=0)
                rmse_comb = mean_squared_error(y_valid, preds_comb, squared=False)  # RMSEを計算
                print(f"Fold {fold + 1} RMSE for {comb} = {rmse_comb}")
                metric_dict[comb] = rmse_comb
                valid_pred_dict[comb] = preds_comb
                sum_metric[comb] += rmse_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[(model,)] for model in model_names], axis=0)
        rmse_all = mean_squared_error(y_valid, preds_all, squared=False)  # RMSEを計算
        print(f"Fold {fold + 1} RMSE for all models ensemble = {rmse_all}")
        metric_dict[tuple(model_names)] = rmse_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_metric[tuple(model_names)] += rmse_all

        # 最適な組み合わせを選択（RMSEが低い組み合わせを選択）
        best_combination = min(metric_dict, key=metric_dict.get)
        best_rmse = metric_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSE = {best_rmse}")

        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル（この場合は常にタプルになるため不要）
            oof_predictions[valid_index] = valid_pred_dict[(best_combination,)]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds / kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 全体のRMSEを計算
    final_rmse = mean_squared_error(target, oof_predictions, squared=False)
    print(f"OOF RMSE = {final_rmse}")

    # 各組み合わせの累積評価指標と選択回数を表示
    print("Sum of RMSE for each combination:")
    for comb, metric in sum_metric.items():
        print(f"{comb}: {metric}")

    print("\nNumber of times each combination was selected:")
    for comb, count in combination_count.items():
        print(f"{comb}: {count}")

    return oof_predictions, test_predictions, train_eval_predictions

# 使用例（回帰データを用いる場合）
# oof_predictions, test_preds, train_preds = get_models_trained(X, X_test, y, 5, X)

# %%
train[list(best_features)]
# Out:
#         target_ym  building_type         lon  building_structure  \
# 0          202007              3  135.309302                 1.0
# 1          202107              1  139.684556                 4.0
# 2          202101              3  141.352789                 1.0
# 3          202007              3  133.335824                 3.0
# 4          202101              3  133.335824                 3.0
# ...           ...            ...         ...                 ...
# 584502     202001              3  137.545725                 3.0
# 584503     202107              3  142.441907                 1.0
# 584504     202001              1  139.769836                 4.0
# 584505     201907              3  142.402382                 1.0
# 584506     202101              3  142.402382                 1.0
#
#         building_area  floor_count  year_built  unit_area_max  land_toshi  \
# 0                 NaN          2.0    200210.0            NaN         NaN
# 1                 NaN          3.0    197612.0      44.099998         NaN
# 2                 NaN          3.0    199607.0            NaN         NaN
# 3                 NaN          2.0    199309.0            NaN         1.0
# 4                 NaN          2.0    199309.0            NaN         1.0
# ...               ...          ...         ...            ...         ...
# 584502            NaN          2.0    201202.0            NaN         NaN
# 584503            NaN          2.0    201501.0            NaN         1.0
# 584504            NaN          4.0    199403.0      41.049999         NaN
# 584505            NaN          2.0    199610.0            NaN         NaN
# 584506            NaN          2.0    199610.0            NaN         NaN
#
#         land_area_kind  land_setback_flg  land_kenpei  land_road_cond  \
# 0                  NaN               1.0          0.0             NaN
# 1                  NaN               NaN          NaN             NaN
# 2                  NaN               NaN          NaN             NaN
# 3                  NaN               NaN          NaN             NaN
# 4                  NaN               NaN          NaN             NaN
# ...                ...               ...          ...             ...
# 584502             NaN               NaN          NaN             NaN
# 584503             NaN               NaN          NaN             NaN
# 584504             NaN               NaN          NaN             NaN
# 584505             NaN               NaN          NaN             NaN
# 584506             NaN               NaN          NaN             NaN
#
#         reform_exterior_date  reform_common_area_date  room_floor  \
# 0                        NaN                      NaN         2.0
# 1                        NaN                      NaN         1.0
# 2                        NaN                      NaN         2.0
# 3                        NaN                      NaN         1.0
# 4                        NaN                      NaN         2.0
# ...                      ...                      ...         ...
# 584502                   NaN                      NaN         2.0
# 584503                   NaN                      NaN         2.0
# 584504                   NaN                      NaN         4.0
# 584505                   NaN                      NaN         2.0
# 584506                   NaN                      NaN         2.0
#
#         dwelling_unit_window_angle  unit_area  flg_own  bukken_type  \
# 0                              5.0  23.180000        1         3102
# 1                              5.0  47.700001        0         3101
# 2                              3.0  46.349998        0         3102
# 3                              6.0  39.740002        1         3102
# 4                              6.0  39.740002        1         3102
# ...                            ...        ...      ...          ...
# 584502                         3.0  57.470001        0         3102
# 584503                         4.0  69.139999        0         3102
# 584504                         5.0  41.049999        1         3101
# 584505                         4.0  51.840000        0         3102
# 584506                         4.0  51.840000        0         3102
#
#         empty_number  post1  addr1_1  addr1_2           nl           el  \
# 0                2.0  598.0       27      213  123869683.0  487123547.0
# 1                NaN  173.0       13      119  128659541.0  502875929.0
# 2                NaN   65.0        1      103  155106911.0  508882127.0
# 3                2.0  720.0       34      207  124196872.0  480018303.0
# 4                NaN  720.0       34      207  124196970.0  480018256.0
# ...              ...    ...      ...      ...          ...          ...
# 584502           NaN  431.0       22      221  124963095.0  495175024.0
# 584503           NaN   79.0        1      204  157718441.0  512804890.0
# 584504           NaN  116.0       13      118  128641810.0  503183080.0
# 584505           NaN   79.0        1      204  157623041.0  512660281.0
# 584506           NaN   79.0        1      204  157622549.0  512660790.0
#
#         bus_time1  walk_distance1  bus_time2  snapshot_land_area  \
# 0             0.0          1040.0        NaN                 NaN
# 1             NaN           320.0        NaN                 NaN
# 2             NaN           880.0        NaN                 NaN
# 3            25.0           700.0       15.0                 NaN
# 4             NaN          2012.0        NaN                 NaN
# ...           ...             ...        ...                 ...
# 584502        NaN           400.0        NaN                 NaN
# 584503        NaN           400.0        NaN                 NaN
# 584504        NaN           640.0        NaN                 NaN
# 584505        NaN          1200.0        NaN                 NaN
# 584506        NaN            80.0        NaN                 NaN
#
#         land_mochibun_a  land_mochibun_b  house_area  flg_new  \
# 0                   NaN              NaN       23.18        0
# 1                   NaN              NaN       47.70        0
# 2                   NaN              NaN       46.35        0
# 3                   NaN              NaN       39.74        0
# 4                   NaN              NaN       39.74        0
# ...                 ...              ...         ...      ...
# 584502              NaN              NaN       57.47        0
# 584503              NaN              NaN       69.14        0
# 584504              NaN              NaN       41.05        0
# 584505              NaN              NaN       51.84        0
# 584506              NaN              NaN       51.84        0
#
#         madori_kind_all  money_kyoueki  money_kyoueki_tax  money_rimawari_now  \
# 0                    20         3000.0                3.0                 NaN
# 1                    30         6000.0                3.0                 NaN
# 2                    50         1500.0                2.0                 NaN
# 3                    30         2000.0                NaN                 NaN
# 4                    30         2000.0                NaN                 NaN
# ...                 ...            ...                ...                 ...
# 584502               50         3000.0                2.0                 NaN
# 584503               50         2000.0                3.0                 NaN
# 584504               50         5000.0                2.0                 NaN
# 584505               50            0.0                2.0                 NaN
# 584506               50            0.0                3.0                 NaN
#
#         money_shuuzenkikin  money_sonota2  parking_money  parking_kubun  \
# 0                      NaN        16500.0         8800.0            1.0
# 1                      NaN            NaN        22000.0            3.0
# 2                      NaN        33000.0         8800.0            1.0
# 3                      NaN            NaN         3300.0            1.0
# 4                      NaN            NaN         3300.0            1.0
# ...                    ...            ...            ...            ...
# 584502                 NaN        11000.0         3300.0            1.0
# 584503                 NaN            NaN         3300.0            1.0
# 584504                 NaN            NaN            NaN            NaN
# 584505                 NaN        28080.0            NaN            1.0
# 584506                 NaN            NaN            0.0            1.0
#
#         parking_distance  genkyo_code  usable_status  school_ele_distance  \
# 0                    0.0          3.0              3                  NaN
# 1                  300.0          2.0              1                291.0
# 2                    0.0          NaN              1                538.0
# 3                    NaN          2.0              1                  NaN
# 4                    0.0          2.0              1                  NaN
# ...                  ...          ...            ...                  ...
# 584502               0.0          NaN              3                463.0
# 584503               NaN          2.0              1                  NaN
# 584504               NaN          2.0              1                  NaN
# 584505               0.0          NaN              1               1092.0
# 584506               NaN          2.0              2                  NaN
#
#         convenience_distance  drugstore_distance  shopping_street_distance  \
# 0                      239.0                 NaN                       NaN
# 1                      399.0               435.0                       NaN
# 2                      201.0                 NaN                       NaN
# 3                        NaN                 NaN                       NaN
# 4                        NaN                 NaN                       NaN
# ...                      ...                 ...                       ...
# 584502                 283.0                 NaN                       NaN
# 584503                1032.0               522.0                       NaN
# 584504                 180.0               100.0                       NaN
# 584505                   NaN                 NaN                       NaN
# 584506                 399.0               655.0                       NaN
#
#         est_other_distance  parking_keiyaku  free_rent_duration  \
# 0                      NaN              NaN                 NaN
# 1                    320.0              NaN                 NaN
# 2                      NaN              NaN                 NaN
# 3                   1114.0              NaN                 NaN
# 4                    469.0              NaN                 NaN
# ...                    ...              ...                 ...
# 584502                 NaN              NaN                 NaN
# 584503                 NaN              NaN                 NaN
# 584504                 NaN              NaN                 NaN
# 584505                 NaN              1.0                 NaN
# 584506                 NaN              NaN                 1.0
#
#         free_rent_gen_timing  LAT_LON_PRODUCT  LAT_DIV_LON  \
# 0                        NaN      4656.197883     0.254317
# 1                        NaN      4992.582161     0.255875
# 2                        NaN      6090.585502     0.304825
# 3                        NaN      4600.403304     0.258763
# 4                        NaN      4600.403304     0.258763
# ...                      ...              ...          ...
# 584502                   NaN      4774.710030     0.252379
# 584503                   NaN      6240.827166     0.307586
# 584504                   NaN      4994.965650     0.255685
# 584505                   NaN      6235.280434     0.307483
# 584506                   NaN      6235.280434     0.307483
#
#         TOTAL_FLOOR_AREA_DIV_BUILDING_AREA  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 584502                                 NaN
# 584503                                 NaN
# 584504                                 NaN
# 584505                                 NaN
# 584506                                 NaN
#
#         PARKING_DISTANCE_DIV_PARKING_NUMBER  prefecture_encoded
# 0                                       0.0                   9
# 1                                       NaN                  26
# 2                                       NaN                   4
# 3                                       NaN                  21
# 4                                       NaN                  21
# ...                                     ...                 ...
# 584502                                  NaN                  42
# 584503                                  NaN                   4
# 584504                                  NaN                  26
# 584505                                  NaN                   4
# 584506                                  NaN                   4
#
# [584507 rows x 58 columns]

# %%
# 目的変数と説明変数に分割
X = train[list(best_features)].values
y = train["money_room"].values
X_test = test[list(best_features)].values

# %%
oof_predictions, test_preds, train_preds = get_models_trained(X, X_test, y, 5, X)
# Out:
# Starting Fold 1
# Fold 1 RMSE for model1 = 15942.900670364914
# Fold 1 RMSE for model2 = 12817.76771176307
# Fold 1 RMSE for model3 = 14617.835028387739
# Fold 1 RMSE for model4 = 15301.483229443977
# Fold 1 RMSE for ('model1', 'model2') = 13791.523321501758
# Fold 1 RMSE for ('model1', 'model3') = 15233.034180067789
# Fold 1 RMSE for ('model1', 'model4') = 15452.989068953362
# Fold 1 RMSE for ('model2', 'model3') = 13272.927230711102
# Fold 1 RMSE for ('model2', 'model4') = 13617.047642791566
# Fold 1 RMSE for ('model3', 'model4') = 14790.144551751346
# Fold 1 RMSE for ('model1', 'model2', 'model3') = 13990.218090118253
# Fold 1 RMSE for ('model1', 'model2', 'model4') = 14162.129676932636
# Fold 1 RMSE for ('model1', 'model3', 'model4') = 15115.708300689717
# Fold 1 RMSE for ('model2', 'model3', 'model4') = 13781.066639524759
# Fold 1 RMSE for all models ensemble = 14214.82857827639
# Fold 1 best combination: ('model2',) with RMSE = 12817.76771176307
# ---------------
#
# Starting Fold 2
# Fold 2 RMSE for model1 = 122168.06974215661
# Fold 2 RMSE for model2 = 121873.81096413931
# Fold 2 RMSE for model3 = 122055.54683618638
# Fold 2 RMSE for model4 = 122046.61828727223
# Fold 2 RMSE for ('model1', 'model2') = 121965.2568843804
# Fold 2 RMSE for ('model1', 'model3') = 122105.2305471184
# Fold 2 RMSE for ('model1', 'model4') = 122084.86971456927
# Fold 2 RMSE for ('model2', 'model3') = 121928.98134427913
# Fold 2 RMSE for ('model2', 'model4') = 121932.75100740665
# Fold 2 RMSE for ('model3', 'model4') = 122033.01899836272
# Fold 2 RMSE for ('model1', 'model2', 'model3') = 121988.94815372338
# Fold 2 RMSE for ('model1', 'model2', 'model4') = 121982.55803119998
# Fold 2 RMSE for ('model1', 'model3', 'model4') = 122069.13844695479
# Fold 2 RMSE for ('model2', 'model3', 'model4') = 121955.89393766176
# Fold 2 RMSE for all models ensemble = 121994.52683073268
# Fold 2 best combination: ('model2',) with RMSE = 121873.81096413931
# ---------------
#
# Starting Fold 3
# Fold 3 RMSE for model1 = 14469.490084960604
# Fold 3 RMSE for model2 = 13343.252799629077
# Fold 3 RMSE for model3 = 13573.453028339596
# Fold 3 RMSE for model4 = 13636.768150774025
# Fold 3 RMSE for ('model1', 'model2') = 13149.927485098611
# Fold 3 RMSE for ('model1', 'model3') = 13964.736602318484
# Fold 3 RMSE for ('model1', 'model4') = 13865.45959921204
# Fold 3 RMSE for ('model2', 'model3') = 12870.66629593875
# Fold 3 RMSE for ('model2', 'model4') = 12966.062185318766
# Fold 3 RMSE for ('model3', 'model4') = 13434.968418675906
# Fold 3 RMSE for ('model1', 'model2', 'model3') = 13177.029195573336
# Fold 3 RMSE for ('model1', 'model2', 'model4') = 13164.731255330147
# Fold 3 RMSE for ('model1', 'model3', 'model4') = 13709.229031080207
# Fold 3 RMSE for ('model2', 'model3', 'model4') = 12947.93984315578
# Fold 3 RMSE for all models ensemble = 13187.61087274219
# Fold 3 best combination: ('model2', 'model3') with RMSE = 12870.66629593875
# ---------------
#
# Starting Fold 4
# Fold 4 RMSE for model1 = 19188.501508625293
# Fold 4 RMSE for model2 = 18645.1599421742
# Fold 4 RMSE for model3 = 17829.76441068258
# Fold 4 RMSE for model4 = 18210.707137362373
# Fold 4 RMSE for ('model1', 'model2') = 17559.768455479785
# Fold 4 RMSE for ('model1', 'model3') = 18473.88945368948
# Fold 4 RMSE for ('model1', 'model4') = 18563.711342355793
# Fold 4 RMSE for ('model2', 'model3') = 17033.179569312597
# Fold 4 RMSE for ('model2', 'model4') = 17311.514850612624
# Fold 4 RMSE for ('model3', 'model4') = 17890.699298983847
# Fold 4 RMSE for ('model1', 'model2', 'model3') = 17401.455822930686
# Fold 4 RMSE for ('model1', 'model2', 'model4') = 17521.76785817782
# Fold 4 RMSE for ('model1', 'model3', 'model4') = 18276.163652501
# Fold 4 RMSE for ('model2', 'model3', 'model4') = 17134.783186476052
# Fold 4 RMSE for all models ensemble = 17474.6305077223
# Fold 4 best combination: ('model2', 'model3') with RMSE = 17033.179569312597
# ---------------
#
# Starting Fold 5
# Fold 5 RMSE for model1 = 15514.117683347398
# Fold 5 RMSE for model2 = 13905.964482569494
# Fold 5 RMSE for model3 = 14452.003375785189
# Fold 5 RMSE for model4 = 14874.01086495628
# Fold 5 RMSE for ('model1', 'model2') = 13956.738388781503
# Fold 5 RMSE for ('model1', 'model3') = 14939.112239002488
# Fold 5 RMSE for ('model1', 'model4') = 15018.642200065133
# Fold 5 RMSE for ('model2', 'model3') = 13547.845120710399
# Fold 5 RMSE for ('model2', 'model4') = 13829.680671847358
# Fold 5 RMSE for ('model3', 'model4') = 14494.700259558806
# Fold 5 RMSE for ('model1', 'model2', 'model3') = 13996.518701765177
# Fold 5 RMSE for ('model1', 'model2', 'model4') = 14107.291318057474
# Fold 5 RMSE for ('model1', 'model3', 'model4') = 14774.405993026357
# Fold 5 RMSE for ('model2', 'model3', 'model4') = 13808.731509378356
# Fold 5 RMSE for all models ensemble = 14109.815716315943
# Fold 5 best combination: ('model2', 'model3') with RMSE = 13547.845120710399
# ---------------
#
# OOF RMSE = 55958.77629630272
# Sum of RMSE for each combination:
# ('model1',): 0
# ('model2',): 0
# ('model3',): 0
# ('model4',): 0
# ('model1', 'model2'): 180423.21453524203
# ('model1', 'model3'): 184716.00302219662
# ('model1', 'model4'): 184985.6719251556
# ('model2', 'model3'): 178653.599560952
# ('model2', 'model4'): 179657.05635797695
# ('model3', 'model4'): 182643.5315273326
# ('model1', 'model2', 'model3'): 180554.16996411083
# ('model1', 'model2', 'model4'): 180938.47813969807
# ('model1', 'model3', 'model4'): 183944.64542425208
# ('model2', 'model3', 'model4'): 855415.6544151575
# ('model1', 'model2', 'model3', 'model4'): 239661.3991457492
#
# Number of times each combination was selected:
# ('model1',): 0
# ('model2',): 2
# ('model3',): 0
# ('model4',): 0
# ('model1', 'model2'): 0
# ('model1', 'model3'): 0
# ('model1', 'model4'): 0
# ('model2', 'model3'): 3
# ('model2', 'model4'): 0
# ('model3', 'model4'): 0
# ('model1', 'model2', 'model3'): 0
# ('model1', 'model2', 'model4'): 0
# ('model1', 'model3', 'model4'): 0
# ('model2', 'model3', 'model4'): 0
# ('model1', 'model2', 'model3', 'model4'): 0

# %%
sample_sub
# Out:
#              0      1
# 0            0  25310
# 1            1  70766
# 2            2  97844
# 3            3  84854
# 4            4  18753
# ...        ...    ...
# 384535  384535  72137
# 384536  384536  59275
# 384537  384537  81590
# 384538  384538  53852
# 384539  384539  63753
#
# [384540 rows x 2 columns]

# %%
# 予測結果を提出用のフォーマットに格納
sample_sub.iloc[:, 1] = test_preds
sample_sub
# Out:
#              0             1
# 0            0  67820.988004
# 1            1  52049.910235
# 2            2  59608.876177
# 3            3  49097.910263
# 4            4  81699.360095
# ...        ...           ...
# 384535  384535  70067.743841
# 384536  384536  85159.259700
# 384537  384537  90203.818790
# 384538  384538  59419.133380
# 384539  384539  88003.663203
#
# [384540 rows x 2 columns]

# %%
sample_sub.to_csv("国土交通省_003.csv", index=False, header=False)
