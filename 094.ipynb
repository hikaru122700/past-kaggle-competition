# %% [markdown]
# <a href="https://colab.research.google.com/github/hikaru122700/kaggle-private/blob/SMBC/094.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install catboost
# !pip install lightgbm
# !pip install xgboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm) (1.13.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from tqdm import tqdm
import joblib
import math

# import pygeohash as pgh

from concurrent.futures import ThreadPoolExecutor

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import gc
gc.collect()
import matplotlib.pyplot as plt


import os
from catboost import CatBoostClassifier

# %%
path  = "/content/drive/My Drive/signate/SMBC Group GREEN×DATA Challenge 2024/"
# 予測モデルを訓練するためのデータセット
train_df = pd.read_csv(path+'train_all_df_093.csv')

# train_df.drop("GHG_Direct_Emissions_14_in_metric_tons", axis=1, inplace=True)
# 予測モデルに推論（予測)させるデータセット
test_df = pd.read_csv(path+'test_all_df_093.csv')

# %%
# すべての列を表示するように設定
pd.set_option('display.max_columns', None)
train_df.columns
# Out:
# Index(['TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
#        'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1'],
#       dtype='object')

# %%
train_df = train_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

# %%
train_df_060 = pd.read_csv(path+'train_all_df_060.csv')
train_df_060.iloc[1119:, :]
# Out:
#       TRI_Air_Emissions_11_in_lbs  TRI_Air_Emissions_12_in_lbs  \
# 1119                 33573.984771                 27691.372510
# 1120                          NaN                          NaN
# 1121                 15769.087207                 17223.969527
# 1122                          NaN                          NaN
# 1123                 30643.194107                 34202.870598
# ...                           ...                          ...
# 4650                 24101.026379                 19191.516543
# 4651                          NaN                          NaN
# 4652                 24256.968166                 25344.483061
# 4653                 25345.077827                 15031.292599
# 4654                          NaN                          NaN
#
#       TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 1119                 29531.772147            82
# 1120                          NaN            21
# 1121                 14451.509512           147
# 1122                          NaN             3
# 1123                 30363.253058            21
# ...                           ...           ...
# 4650                 26927.123407            20
# 4651                          NaN            92
# 4652                 25052.338495            80
# 4653                 15796.850949            98
# 4654                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 1119                            76957.791208
# 1120                            72874.379509
# 1121                            25203.960001
# 1122                                     NaN
# 1123                           305757.037478
# ...                                      ...
# 4650                            77141.021213
# 4651                            82220.042676
# 4652                            28607.351065
# 4653                            88531.792834
# 4654                           112513.353843
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 1119                            49590.840696
# 1120                           188701.992178
# 1121                            50606.672273
# 1122                                     NaN
# 1123                           218576.699790
# ...                                      ...
# 4650                            48631.025258
# 4651                            64715.871307
# 4652                            19289.908089
# 4653                            72951.833989
# 4654                            53842.618671
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 1119                            47884.127681
# 1120                           245700.971833
# 1121                            43583.464216
# 1122                                     NaN
# 1123                           295789.568177
# ...                                      ...
# 4650                            47793.361605
# 4651                           230047.214696
# 4652                            31161.166202
# 4653                            58934.618361
# 4654                           466623.402620
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 1119                            26206.461981  30.220520  -93.742096
# 1120                           521373.221691  27.567140  -99.505230
# 1121                            68569.211500  35.811390  -83.967210
# 1122                                     NaN        NaN         NaN
# 1123                           192767.142277  32.017180 -109.894337
# ...                                      ...        ...         ...
# 4650                            26264.074210  31.395000  -92.716700
# 4651                           560693.884154  34.063540 -117.529290
# 4652                            41108.719593  44.889130  -89.624800
# 4653                            53983.891144  37.786820  -97.530970
# 4654                            66176.706458  37.218333 -104.785833
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 1119                      1966.146709                     -5882.612261
# 1120                              NaN                              NaN
# 1121                       630.093954                      1454.882320
# 1122                              NaN                              NaN
# 1123                     -4088.201978                      3559.676491
# ...                               ...                              ...
# 4650                      8850.589715                     -4909.509837
# 4651                              NaN                              NaN
# 4652                      2857.424868                      1087.514895
# 4653                      8121.896740                    -10313.785228
# 4654                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 1119                      1840.399637                          0.062204
# 1120                              NaN                               NaN
# 1121                     -2772.460015                          0.041621
# 1122                              NaN                               NaN
# 1123                     -3839.617540                         -0.117709
# ...                               ...                               ...
# 4650                      7735.606864                          0.580350
# 4651                              NaN                               NaN
# 4652                      -292.144565                          0.133527
# 4653                       765.558350                          0.471568
# 4654                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 1119                         -0.175213                          0.066461
# 1120                               NaN                               NaN
# 1121                          0.092262                         -0.160965
# 1122                               NaN                               NaN
# 1123                          0.116165                         -0.112260
# ...                                ...                               ...
# 4650                         -0.203705                          0.403074
# 4651                               NaN                               NaN
# 4652                          0.044833                         -0.011527
# 4653                         -0.406934                          0.050931
# 4654                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 1119                8            0     44716.650823
# 1120               15            1    251942.311116
# 1121                8            0     40922.371684
# 1122                9            1     61169.098865
# 1123               15            0    268182.786286
# ...               ...          ...              ...
# 4650               15            0     46740.289062
# 4651                8            1    170354.516977
# 4652                8            0     31492.170648
# 4653                8            0     66290.436080
# 4654                9            1    146419.312500
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 1119                              45777.122845
# 1120                             246021.200746
# 1121                              42127.751931
# 1122                              57020.151719
# 1123                             271530.824987
# ...                                        ...
# 4650                              49221.615755
# 4651                             169634.209493
# 4652                              31716.323514
# 4653                              65663.219471
# 4654                             145437.817997
#
# [3536 rows x 20 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 22956.125554                 23592.402994
# 6043                124460.895022                140816.449347
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                 25069.498286                 24560.172725           132
# 6043                 93118.705227                130326.946431            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.105144e+04
# 1                  14            1     6.074737e+04
# 2                   9            1     9.984973e+04
# 3                  15            1     5.213393e+04
# 4                  15            0     4.988675e+04
# ...               ...          ...              ...
# 6040                1            1     5.765767e+05
# 6041                9            1     1.001873e+05
# 6042                8            0     1.315022e+05
# 6043                8            0     2.677709e+05
# 6044                9            1     1.333286e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.098466e+04
# 1                                 6.021565e+04
# 2                                 1.018654e+05
# 3                                 5.198007e+04
# 4                                 4.899637e+04
# ...                                        ...
# 6040                              5.798506e+05
# 6041                              1.017332e+05
# 6042                              1.330859e+05
# 6043                              2.654853e+05
# 6044                              1.382436e+06
#
# [6045 rows x 21 columns]

# %%
test_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    28275.061385                 32075.140635
# 3                    37330.205714                 42503.897432
# 4                    45310.722699                 39897.800897
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 22956.125554                 23592.402994
# 2506                124460.895022                140816.449347
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions    test_preds
# 0                   9            1     4.503991e+04  4.506929e+04
# 1                  14            1     2.981288e+05  2.975597e+05
# 2                   8            0     4.142984e+04  4.115429e+04
# 3                   8            0     2.926387e+04  2.836366e+04
# 4                   8            0     4.776136e+04  4.837460e+04
# ...               ...          ...              ...           ...
# 2503                1            1     5.245456e+05  5.276594e+05
# 2504                9            1     1.004395e+05  1.019951e+05
# 2505                8            0     1.365536e+05  1.389812e+05
# 2506                8            0     2.649483e+05  2.627149e+05
# 2507                9            1     1.307649e+06  1.355972e+06
#
# [2508 rows x 21 columns]

# %%
before_train = pd.read_csv(path+'train.csv', index_col=0)
before_test = pd.read_csv(path+'test.csv', index_col=0)
before_test
# Out:
#                                      FacilityName   Latitude   Longitude  \
# 4655                           ROGER AOTSCHEGAROW  38.033040  -97.973170
# 4656                  EPNG STATION 6543 LORDSBURG  32.316030 -108.606800
# 4657  OWENS-BROCKWAY GLASS CONTAINER INC PLANT 19  41.251500  -78.742440
# 4658                  WALDORF CORP (DBA ROCKTENN)  44.959660  -93.193410
# 4659               SOLAR TURBINES INC KEARNY MESA  32.818720 -117.125800
# ...                                           ...        ...         ...
# 7158                     BEULAH SANITARY LANDFILL  38.651945  -75.914445
# 7159                             SONORA GAS PLANT  31.361795 -101.776403
# 7160                          ASH GROVE CEMENT CO  41.005565  -96.154917
# 7161                          SHOW ME ETHANOL LLC  39.364417  -93.449361
# 7162                       XTO - NEW TEAGUE PLANT  31.591369  -96.216360
#
#                         LocationAddress        City State        ZIP  \
# 4655         1910 SOUTH BROADACRES ROAD  HUTCHINSON    KS      67501
# 4656                                NaN   LORDSBURG    NM      88045
# 4657                     3831 ROUTE 219   BROCKPORT    PA      15823
# 4658                    2250 WABASH AVE  SAINT PAUL    MN  551141895
# 4659              4200 RUFFIN RD MZ T-2   SAN DIEGO    CA      92123
# ...                                 ...         ...   ...        ...
# 7158  ROUTE 331 & ROUTE 16- BEULAH ROAD     HURLOCK    MD      21643
# 7159                                NaN      RANKIN    TX      79778
# 7160                       16215 HWY 50  LOUISVILLE    NE  680372881
# 7161                     26530 E HWY 24  CARROLLTON    MO      64633
# 7162                        230 FCR 640      TEAGUE    TX      75860
#
#           County  FIPScode  PrimaryNAICS  SecondPrimaryNAICS  \
# 4655        RENO   20155.0        211112                 NaN
# 4656     HIDALGO   35023.0        486210                 NaN
# 4657   JEFFERSON   42065.0        327213                 NaN
# 4658      RAMSEY   27123.0        322130                 NaN
# 4659   SAN DIEGO    6073.0        333611                 NaN
# ...          ...       ...           ...                 ...
# 7158  DORCHESTER   24019.0        562212                 NaN
# 7159       UPTON   48461.0        211112                 NaN
# 7160        CASS   31025.0        327310                 NaN
# 7161     CARROLL   29033.0        325193                 NaN
# 7162   FREESTONE   48161.0        211111                 NaN
#
#                                            IndustryType  \
# 4655  Natural Gas and Natural Gas Liquids Suppliers,...
# 4656                  Petroleum and Natural Gas Systems
# 4657                                           Minerals
# 4658                                     Pulp and Paper
# 4659                                              Other
# ...                                                 ...
# 7158                                              Waste
# 7159                  Petroleum and Natural Gas Systems
# 7160                                           Minerals
# 7161                                        Other,Waste
# 7162                  Petroleum and Natural Gas Systems
#
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 4655                          NaN                          NaN
# 4656                          NaN                          NaN
# 4657                 28275.061385                 32075.140635
# 4658                 37330.205714                 42503.897432
# 4659                 45310.722699                 39897.800897
# ...                           ...                          ...
# 7158                          NaN                          NaN
# 7159                          NaN                          NaN
# 7160                 22956.125554                 23592.402994
# 7161                124460.895022                140816.449347
# 7162                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  \
# 4655                          NaN                          NaN
# 4656                          NaN                          NaN
# 4657                 26445.792090                 23385.161510
# 4658                 43906.102080                 42958.306538
# 4659                 40203.428231                 39437.099224
# ...                           ...                          ...
# 7158                          NaN                          NaN
# 7159                          NaN                          NaN
# 7160                 25069.498286                 24560.172725
# 7161                 93118.705227                130326.946431
# 7162                          NaN                          NaN
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 4655                            88951.390376
# 4656                                     NaN
# 4657                            84908.372871
# 4658                            49004.603631
# 4659                            84959.769922
# ...                                      ...
# 7158                           110523.066755
# 7159                                     NaN
# 7160                           166520.232511
# 7161                            71773.803649
# 7162                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 4655                            65803.021457
# 4656                                     NaN
# 4657                             6212.899604
# 4658                               52.038452
# 4659                            15351.359676
# ...                                      ...
# 7158                            98954.793233
# 7159                                     NaN
# 7160                           469732.826538
# 7161                           936031.894142
# 7162                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 4655                            2.899329e+04
# 4656                            3.119260e+05
# 4657                            3.473291e+04
# 4658                            1.426237e+04
# 4659                            4.000654e+04
# ...                                      ...
# 7158                            3.467008e+06
# 7159                                     NaN
# 7160                            8.255855e+04
# 7161                            3.369613e+05
# 7162                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons
# 4655                            32965.487915
# 4656                           268668.069110
# 4657                            39045.247387
# 4658                            20204.924986
# 4659                            63935.249120
# ...                                      ...
# 7158                           147802.356027
# 7159                                     NaN
# 7160                            85775.307153
# 7161                           156640.371706
# 7162                           350096.803939
#
# [2508 rows x 20 columns]

# %%
def show_plot(test_preds, target, title):
# 共通のビンエッジを定義するため、両方のデータの範囲を取得
    min_val = min(test_preds.min(), target.min())
    max_val = max(test_preds.max(), target.max())

# ビンエッジを共通化（例えば、100ビン）
    bins = np.logspace(np.log10(min_val), np.log10(max_val), 50)

# ヒストグラムを正規化してプロット
    plt.figure(figsize=(7, 5))

# test_preds のヒストグラム
    sns.histplot(test_preds, bins=bins, stat='density', kde=True, color='blue', label='before', alpha=0.6)

# target のヒストグラム
    sns.histplot(target, bins=bins, stat='density', kde=True, color='orange', label='after', alpha=0.6)

# ログスケールを適用
    plt.xscale('log')

# ラベルとタイトルの設定
    plt.xlabel('Values (Log Scale)')
    plt.ylabel('Density')
    plt.title(title)

# 凡例の表示
    plt.legend()

# グリッドの追加（オプション）
    plt.grid(True, which="both", ls="--", linewidth=0.5)

# プロットの表示
    plt.show()

# %%
x=train_df["oof_predictions"]
y=train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
# 実測値と予測値を対数スケールでプロット
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('before')
plt.ylabel('target')
plt.title('Actual vs Predicted Values (Log-Log Scale)')
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--')  # 45度線
plt.show()

# %%
# show_plot(train_df["GHG_Direct_Emissions_13_in_metric_tons"],
#           train_df["GHG_Direct_Emissions_14_in_metric_tons.1"],
#           "train_G13-train_G14")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
#           np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_log_G13-train_log_G14")
# show_plot(np.log(train_df["GHG_Direct_Emissions_12_in_metric_tons"]),
#           np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]),
#           "train_log_G12-train_log_G13")

# %%
train_all_df = pd.concat([train_df, test_df], axis=0)
train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"][len(train_df):] = test_df["test_preds"]
print(train_all_df.columns)
train_all_df.drop('test_preds', axis=1, inplace=True)

test_df.rename(columns={'test_preds': 'oof_predictions'}, inplace=True)
# Out:
# Index(['TRI_Air_Emissions_10_in_lbs', 'TRI_Air_Emissions_11_in_lbs',
#        'TRI_Air_Emissions_12_in_lbs', 'TRI_Air_Emissions_13_in_lbs',
#        'PrimaryNAICS', 'GHG_Direct_Emissions_10_in_metric_tons',
#        'GHG_Direct_Emissions_11_in_metric_tons',
#        'GHG_Direct_Emissions_12_in_metric_tons',
#        'GHG_Direct_Emissions_13_in_metric_tons', 'Latitude', 'Longitude',
#        'TRI_Air_Emissions_YoY_Change_11', 'TRI_Air_Emissions_YoY_Change_12',
#        'TRI_Air_Emissions_YoY_Change_13', 'TRI_Air_Emissions_Growth_Rate_11',
#        'TRI_Air_Emissions_Growth_Rate_12', 'TRI_Air_Emissions_Growth_Rate_13',
#        'Economic_Sector', 'num_missing', 'oof_predictions',
#        'GHG_Direct_Emissions_14_in_metric_tons.1', 'test_preds'],
#       dtype='object')

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 22956.125554                 23592.402994
# 2506                124460.895022                140816.449347
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.105144e+04
# 1                  14            1     6.074737e+04
# 2                   9            1     9.984973e+04
# 3                  15            1     5.213393e+04
# 4                  15            0     4.988675e+04
# ...               ...          ...              ...
# 2503                1            1     5.245456e+05
# 2504                9            1     1.004395e+05
# 2505                8            0     1.365536e+05
# 2506                8            0     2.649483e+05
# 2507                9            1     1.307649e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.098466e+04
# 1                                 6.021565e+04
# 2                                 1.018654e+05
# 3                                 5.198007e+04
# 4                                 4.899637e+04
# ...                                        ...
# 2503                              5.276594e+05
# 2504                              1.019951e+05
# 2505                              1.389812e+05
# 2506                              2.627149e+05
# 2507                              1.355972e+06
#
# [8553 rows x 21 columns]

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 22956.125554                 23592.402994
# 2506                124460.895022                140816.449347
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  \
# 0                   8            0     4.105144e+04
# 1                  14            1     6.074737e+04
# 2                   9            1     9.984973e+04
# 3                  15            1     5.213393e+04
# 4                  15            0     4.988675e+04
# ...               ...          ...              ...
# 2503                1            1     5.245456e+05
# 2504                9            1     1.004395e+05
# 2505                8            0     1.365536e+05
# 2506                8            0     2.649483e+05
# 2507                9            1     1.307649e+06
#
#       GHG_Direct_Emissions_14_in_metric_tons.1
# 0                                 4.098466e+04
# 1                                 6.021565e+04
# 2                                 1.018654e+05
# 3                                 5.198007e+04
# 4                                 4.899637e+04
# ...                                        ...
# 2503                              5.276594e+05
# 2504                              1.019951e+05
# 2505                              1.389812e+05
# 2506                              2.627149e+05
# 2507                              1.355972e+06
#
# [8553 rows x 21 columns]

# %%
len(train_df), len(train_all_df), len(test_df)
# Out:
# (6045, 8553, 2508)

# %%
# 1. RMSLEの計算（ベクトル化）
# 'test_preds' と 'oof_predictions' を明示的に指定
diff = np.log1p(train_all_df['GHG_Direct_Emissions_14_in_metric_tons.1']) - np.log1p(train_all_df['oof_predictions'])
train_all_df['diff'] = diff
train_df = train_all_df[:len(train_df)]
test_df = train_all_df[len(train_df):]

# %%
train_all_df["diff"]
# Out:
# 0      -0.001628
# 1      -0.008791
# 2       0.019985
# 3      -0.002956
# 4      -0.018009
#           ...
# 2503    0.005919
# 2504    0.015370
# 2505    0.017621
# 2506   -0.008465
# 2507    0.036287
# Name: diff, Length: 8553, dtype: float64

# %%
train_all_df["oof_predictions"].fillna(train_all_df["GHG_Direct_Emissions_14_in_metric_tons.1"], inplace=True)
train_all_df["diff"].fillna(0, inplace=True)

# %%
train_all_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)
train_df_GHG14 = train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
train_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
test_df["oof_predictions"] = test_df["GHG_Direct_Emissions_14_in_metric_tons.1"]
test_df.drop('GHG_Direct_Emissions_14_in_metric_tons.1', axis=1, inplace=True)

# %%
from itertools import combinations

def get_models_trained(train, test, target, num_folds, train_eval):
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=13)

    oof_predictions = np.zeros(len(train))
    test_predictions = np.zeros(len(test))
    train_eval_predictions = np.zeros(len(train_eval))

    # エラーの累計を保持する辞書
    sum_error = {}
    # 各組み合わせの選択回数を保持する辞書
    combination_count = {}

    # 個別モデルの名前リスト
    model_names = ["model1", "model2", "model3", "model4"]

    # 全ての組み合わせを生成（1, 2, 3, 4モデル）
    all_combinations = []
    for r in range(1, 5):
        all_combinations.extend(combinations(model_names, r))

    # 初期化
    for comb in all_combinations:
        sum_error[comb] = 0
        combination_count[comb] = 0

    for fold, (train_index, valid_index) in enumerate(kf.split(train, target)):
        print(f"Starting Fold {fold + 1}")
        X_train, X_valid = train[train_index], train[valid_index]
        y_train, y_valid = target[train_index], target[valid_index]

        # モデルと損失の初期化
        model_dict = {}
        loss_dict = {}
        valid_pred_dict = {}

        # モデル1: XGBRegressor
        params1 = {
            "n_estimators": 626,
            "max_depth": 3,
            "random_state": 13,
            "min_child_weight": 0.001190123543553736,
            "learning_rate": 0.010519736270936835,
            "subsample": 0.7304788478701394,
            "colsample_bylevel": 0.604447278915981,
            "colsample_bytree": 0.7616852136157319,
            "reg_alpha": 0.115175569924065,
            "reg_lambda": 0.07155347824929895
        }
        model1 = XGBRegressor(**params1)

        # モデル2: CatBoostRegressor
        params                       = {'iterations': 254,
                                        'depth': 5,
                                        'learning_rate': 0.08377009991199288,
                                        'l2_leaf_reg': 1,
                                        'bagging_temperature': 0.7204457890870082,
                                        'min_data_in_leaf': 4,
                                        "random_state":13,
                                         "verbose":0}
        model2                       = CatBoostRegressor(**params)

        # モデル3: XGBRegressor
        params3 ={
            "n_estimators": 897,
            "max_depth": 4,
            "min_child_weight": 1.9636282677053687,
            "learning_rate": 0.006151391207761763,
            "subsample": 0.8251910979922186,
            "colsample_bylevel": 0.6454805596196158,
            "colsample_bytree": 0.598042694363472,
            "reg_alpha": 2.1719824223479005,
            "reg_lambda": 0.009192236594241635,
        }
        model3 = XGBRegressor(**params3)

        # モデル4: CatBoostRegressor
        params4 = {
            "iterations": 940,
            "depth": 3,
            "learning_rate": 0.019908189422344794,
            "l2_leaf_reg": 1,
            "bagging_temperature": 0.5063893392618839,
            "min_data_in_leaf": 1,
            'random_state': 42
        }
        model4 = CatBoostRegressor(**params4, verbose=0)

        # 各モデルの訓練と予測
        models = {
            "model1": model1,
            "model2": model2,
            "model3": model3,
            "model4": model4
        }

        for name, model in models.items():
            model.fit(X_train, y_train)
            preds = model.predict(X_valid)
            rmsle = np.sqrt(mean_squared_error(y_valid, preds))
            print(f"Fold {fold + 1} RMSLE for {name} = {rmsle}")
            loss_dict[name] = rmsle
            valid_pred_dict[name] = preds
            sum_error[(name,)] += rmsle

        # すべての2モデルおよび3モデルの組み合わせを評価
        for r in [2, 3]:
            for comb in combinations(model_names, r):
                # 平均予測
                preds_comb = np.mean([valid_pred_dict[model] for model in comb], axis=0)
                rmsle_comb = np.sqrt(mean_squared_error(y_valid, preds_comb))
                print(f"Fold {fold + 1} RMSLE for {comb} = {rmsle_comb}")
                loss_dict[comb] = rmsle_comb
                valid_pred_dict[comb] = preds_comb
                sum_error[comb] += rmsle_comb

        # 全モデルのアンサンブル
        preds_all = np.mean([valid_pred_dict[model] for model in model_names], axis=0)
        rmsle_all = np.sqrt(mean_squared_error(y_valid, preds_all))
        print(f"Fold {fold + 1} RMSLE for all models ensemble = {rmsle_all}")
        loss_dict[tuple(model_names)] = rmsle_all
        valid_pred_dict[tuple(model_names)] = preds_all
        sum_error[tuple(model_names)] += rmsle_all

        # 最適な組み合わせを選択
        best_combination = min(loss_dict, key=loss_dict.get)
        best_rmsle = loss_dict[best_combination]
        print(f"Fold {fold + 1} best combination: {best_combination} with RMSLE = {best_rmsle}")


        # OOF予測とテスト予測の更新
        if isinstance(best_combination, tuple):
            # 複数モデルのアンサンブル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = np.mean([models[model].predict(test) for model in best_combination], axis=0)
            train_eval_preds = np.mean([models[model].predict(train_eval) for model in best_combination], axis=0)
        else:
            # 単一モデル
            oof_predictions[valid_index] = valid_pred_dict[best_combination]
            test_preds = models[best_combination].predict(test)
            train_eval_preds = models[best_combination].predict(train_eval)

        # 各組み合わせの選択回数をインクリメント
        # combination_count[best_combination] += 1

        test_predictions += test_preds / kf.n_splits
        train_eval_predictions += train_eval_preds/ kf.n_splits

        # メモリの解放
        del X_train, X_valid, y_train, y_valid, model1, model2, model3, model4
        gc.collect()

        print('---------------\n')

    # 最終的なOOF RMSLEの計算
    final_RMSLE = np.sqrt(mean_squared_error(target, oof_predictions))
    print(f"OOF RMSLE = {final_RMSLE}")

    # テスト予測の逆変換
    final_test_predictions = test_predictions
    final_train_predictions = train_eval_predictions

    # 各組み合わせの累積エラーと選択回数を表示
    print("Sum of RMSLE for each combination:")
    for comb, error in sum_error.items():
        print(f"{comb}: {error}")

    # print("\nNumber of times each combination was selected:")
    # for comb, count in combination_count.items():
    #     print(f"{comb}: {count}")
    print()
    return oof_predictions, final_test_predictions, final_train_predictions

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 22956.125554                 23592.402994
# 6043                124460.895022                140816.449347
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                 25069.498286                 24560.172725           132
# 6043                 93118.705227                130326.946431            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.105144e+04 -0.001628
# 1                  14            1     6.074737e+04 -0.008791
# 2                   9            1     9.984973e+04  0.019985
# 3                  15            1     5.213393e+04 -0.002956
# 4                  15            0     4.988675e+04 -0.018009
# ...               ...          ...              ...       ...
# 6040                1            1     5.765767e+05  0.005662
# 6041                9            1     1.001873e+05  0.015313
# 6042                8            0     1.315022e+05  0.011971
# 6043                8            0     2.677709e+05 -0.008572
# 6044                9            1     1.333286e+06  0.036201
#
# [6045 rows x 21 columns]

# %%
train = train_df.iloc[:, :-1].values
train_target = train_df.iloc[:, -1].values
train_all = train_all_df.iloc[:, :-1].values
train_all_target = train_all_df.iloc[:, -1].values
test = test_df.iloc[:, :-1].values

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 22956.125554                 23592.402994
# 2506                124460.895022                140816.449347
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.105144e+04 -0.001628
# 1                  14            1     6.074737e+04 -0.008791
# 2                   9            1     9.984973e+04  0.019985
# 3                  15            1     5.213393e+04 -0.002956
# 4                  15            0     4.988675e+04 -0.018009
# ...               ...          ...              ...       ...
# 2503                1            1     5.245456e+05  0.005919
# 2504                9            1     1.004395e+05  0.015370
# 2505                8            0     1.365536e+05  0.017621
# 2506                8            0     2.649483e+05 -0.008465
# 2507                9            1     1.307649e+06  0.036287
#
# [8553 rows x 21 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 22956.125554                 23592.402994
# 6043                124460.895022                140816.449347
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                 25069.498286                 24560.172725           132
# 6043                 93118.705227                130326.946431            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.105144e+04 -0.001628
# 1                  14            1     6.074737e+04 -0.008791
# 2                   9            1     9.984973e+04  0.019985
# 3                  15            1     5.213393e+04 -0.002956
# 4                  15            0     4.988675e+04 -0.018009
# ...               ...          ...              ...       ...
# 6040                1            1     5.765767e+05  0.005662
# 6041                9            1     1.001873e+05  0.015313
# 6042                8            0     1.315022e+05  0.011971
# 6043                8            0     2.677709e+05 -0.008572
# 6044                9            1     1.333286e+06  0.036201
#
# [6045 rows x 21 columns]

# %%
train_df_GHG14 = pd.Series(train_df_GHG14)

# %%
len(train_df_GHG14)
# Out:
# 6045

# %%
import time
epock = 10
for i in range(epock):
    st = time.time()
    train = train_df.iloc[:, :-1].values
    train_all = train_all_df.iloc[:, :-1].values
    train_all_target = train_all_df.iloc[:, -1].values
    oof_predictions,test_preds, train_preds  = get_models_trained(train_all, test, train_all_target, 30, train)
    train_all_df["oof_predictions"] = np.expm1(np.log1p(train_all_df["oof_predictions"])+oof_predictions)
    train_df["oof_predictions"] = np.expm1(np.log1p(train_df["oof_predictions"])+train_preds)
    test_df["oof_predictions"] = np.expm1(np.log1p(test_df["oof_predictions"])+test_preds)
    # train_all_df のインデックスをリセット
    train_all_df = train_all_df.reset_index(drop=True)

# train_df_GHG14 のインデックスをリセット
    train_df_GHG14 = train_df_GHG14.reset_index(drop=True)
    train_all_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_all_df['oof_predictions'])
    train_all_df.fillna(0, inplace=True)
    train_df['diff'] = np.log1p(train_df_GHG14) - np.log1p(train_df['oof_predictions'])
    print(f"{i}番目の学習が終わりました。\n")
    print(f"推定時間は{int(((epock-1-i)*(time.time()-st))/60)}\n")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Fold 18 RMSLE for ('model1', 'model2') = 0.008595655158573183
# Fold 18 RMSLE for ('model1', 'model3') = 0.008725242703861111
# Fold 18 RMSLE for ('model1', 'model4') = 0.008419945174002194
# Fold 18 RMSLE for ('model2', 'model3') = 0.008941225860679466
# Fold 18 RMSLE for ('model2', 'model4') = 0.00863727321290249
# Fold 18 RMSLE for ('model3', 'model4') = 0.008743194013370884
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.008736295363902885
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.008539907483029572
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.00861757273655781
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.00875820743520198
# Fold 18 RMSLE for all models ensemble = 0.008655900097168536
# Fold 18 best combination: model1 with RMSLE = 0.008414111611737551
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.01123143023702696
# Fold 19 RMSLE for model2 = 0.01187582951734262
# Fold 19 RMSLE for model3 = 0.011456627249152652
# Fold 19 RMSLE for model4 = 0.011671860872767842
# Fold 19 RMSLE for ('model1', 'model2') = 0.011482130270037957
# Fold 19 RMSLE for ('model1', 'model3') = 0.011318118745394458
# Fold 19 RMSLE for ('model1', 'model4') = 0.011429782290027843
# Fold 19 RMSLE for ('model2', 'model3') = 0.011589346404595309
# Fold 19 RMSLE for ('model2', 'model4') = 0.011738313834460699
# Fold 19 RMSLE for ('model3', 'model4') = 0.011543144704182018
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.011443453492654144
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.011535723805831996
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.011422706577396852
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.01160870666932784
# Fold 19 RMSLE for all models ensemble = 0.011495550270653026
# Fold 19 best combination: model1 with RMSLE = 0.01123143023702696
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.022616366229592105
# Fold 20 RMSLE for model2 = 0.02302366059633974
# Fold 20 RMSLE for model3 = 0.021721714330135825
# Fold 20 RMSLE for model4 = 0.022519320236338018
# Fold 20 RMSLE for ('model1', 'model2') = 0.022794996869362677
# Fold 20 RMSLE for ('model1', 'model3') = 0.022111799116551707
# Fold 20 RMSLE for ('model1', 'model4') = 0.02254699980707404
# Fold 20 RMSLE for ('model2', 'model3') = 0.022260001327117557
# Fold 20 RMSLE for ('model2', 'model4') = 0.022745939008551024
# Fold 20 RMSLE for ('model3', 'model4') = 0.022029615780090717
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.022367593040346006
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.022688025581858208
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.02221100490637687
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.0223201848930202
# Fold 20 RMSLE for all models ensemble = 0.02238766011699328
# Fold 20 best combination: model3 with RMSLE = 0.021721714330135825
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.011824574006295406
# Fold 21 RMSLE for model2 = 0.011520785972743182
# Fold 21 RMSLE for model3 = 0.011800964075894656
# Fold 21 RMSLE for model4 = 0.0114365722935504
# Fold 21 RMSLE for ('model1', 'model2') = 0.011605002435939487
# Fold 21 RMSLE for ('model1', 'model3') = 0.011788299410568637
# Fold 21 RMSLE for ('model1', 'model4') = 0.011587802866879132
# Fold 21 RMSLE for ('model2', 'model3') = 0.011604623255248775
# Fold 21 RMSLE for ('model2', 'model4') = 0.011453185175258613
# Fold 21 RMSLE for ('model3', 'model4') = 0.011595700967100697
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.011649595361785952
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.01153338431698072
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.01164725693746937
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.011539428069391098
# Fold 21 RMSLE for all models ensemble = 0.0115857323129668
# Fold 21 best combination: model4 with RMSLE = 0.0114365722935504
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.010283109129731724
# Fold 22 RMSLE for model2 = 0.009435565610752365
# Fold 22 RMSLE for model3 = 0.01004292922956408
# Fold 22 RMSLE for model4 = 0.00987377367737815
# Fold 22 RMSLE for ('model1', 'model2') = 0.009836972400246974
# Fold 22 RMSLE for ('model1', 'model3') = 0.010132706830300205
# Fold 22 RMSLE for ('model1', 'model4') = 0.010040935090236448
# Fold 22 RMSLE for ('model2', 'model3') = 0.009699637178237205
# Fold 22 RMSLE for ('model2', 'model4') = 0.009618310977010876
# Fold 22 RMSLE for ('model3', 'model4') = 0.009914978674930654
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.009879553975823002
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.009821346364816965
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.01001721596655569
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.009730964013681646
# Fold 22 RMSLE for all models ensemble = 0.00985644190032732
# Fold 22 best combination: model2 with RMSLE = 0.009435565610752365
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.008445676376625069
# Fold 23 RMSLE for model2 = 0.008105535206125978
# Fold 23 RMSLE for model3 = 0.00853317183588984
# Fold 23 RMSLE for model4 = 0.008531322101678429
# Fold 23 RMSLE for ('model1', 'model2') = 0.008237704283219772
# Fold 23 RMSLE for ('model1', 'model3') = 0.00847233309488093
# Fold 23 RMSLE for ('model1', 'model4') = 0.00846712528898293
# Fold 23 RMSLE for ('model2', 'model3') = 0.008265809499932726
# Fold 23 RMSLE for ('model2', 'model4') = 0.008292608345232388
# Fold 23 RMSLE for ('model3', 'model4') = 0.008499516557779552
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.008313383149042829
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.008323091943496725
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.008471716039817136
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.008340215737478129
# Fold 23 RMSLE for all models ensemble = 0.008356903400009927
# Fold 23 best combination: model2 with RMSLE = 0.008105535206125978
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.009849507216582882
# Fold 24 RMSLE for model2 = 0.010047645510515183
# Fold 24 RMSLE for model3 = 0.010056971099100195
# Fold 24 RMSLE for model4 = 0.009827487522521404
# Fold 24 RMSLE for ('model1', 'model2') = 0.00991735933877005
# Fold 24 RMSLE for ('model1', 'model3') = 0.009933804493049014
# Fold 24 RMSLE for ('model1', 'model4') = 0.009832728635789479
# Fold 24 RMSLE for ('model2', 'model3') = 0.010011690644116764
# Fold 24 RMSLE for ('model2', 'model4') = 0.009912246451661806
# Fold 24 RMSLE for ('model3', 'model4') = 0.009927241878977408
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.009944083163886267
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.009880448200987511
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.00989341897310356
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.009941324992085502
# Fold 24 RMSLE for all models ensemble = 0.009910962053417278
# Fold 24 best combination: model4 with RMSLE = 0.009827487522521404
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.011844241320031527
# Fold 25 RMSLE for model2 = 0.011486845315455001
# Fold 25 RMSLE for model3 = 0.012095604004983086
# Fold 25 RMSLE for model4 = 0.011819461067557024
# Fold 25 RMSLE for ('model1', 'model2') = 0.011600739186278516
# Fold 25 RMSLE for ('model1', 'model3') = 0.011938989679164276
# Fold 25 RMSLE for ('model1', 'model4') = 0.011797443745542558
# Fold 25 RMSLE for ('model2', 'model3') = 0.011705215778833872
# Fold 25 RMSLE for ('model2', 'model4') = 0.011614209732004332
# Fold 25 RMSLE for ('model3', 'model4') = 0.011911072673230778
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.011728301470907317
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.011655487298594619
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.011870045746155891
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.011724388038737755
# Fold 25 RMSLE for all models ensemble = 0.011736198463792839
# Fold 25 best combination: model2 with RMSLE = 0.011486845315455001
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.009113021972350243
# Fold 26 RMSLE for model2 = 0.008969372678892078
# Fold 26 RMSLE for model3 = 0.009063281041862431
# Fold 26 RMSLE for model4 = 0.009185515326345352
# Fold 26 RMSLE for ('model1', 'model2') = 0.008999610459863321
# Fold 26 RMSLE for ('model1', 'model3') = 0.009065080179235852
# Fold 26 RMSLE for ('model1', 'model4') = 0.009133319436229774
# Fold 26 RMSLE for ('model2', 'model3') = 0.008951592456598458
# Fold 26 RMSLE for ('model2', 'model4') = 0.009046014566838316
# Fold 26 RMSLE for ('model3', 'model4') = 0.009101873522897189
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.008991099421940686
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.009049819274167611
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.009093253251298157
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.009020073622574815
# Fold 26 RMSLE for all models ensemble = 0.009033062801206651
# Fold 26 best combination: ('model2', 'model3') with RMSLE = 0.008951592456598458
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.008015772276000971
# Fold 27 RMSLE for model2 = 0.007704004852513314
# Fold 27 RMSLE for model3 = 0.008124291739129923
# Fold 27 RMSLE for model4 = 0.008442605223667903
# Fold 27 RMSLE for ('model1', 'model2') = 0.0077823052503741205
# Fold 27 RMSLE for ('model1', 'model3') = 0.008029833473499302
# Fold 27 RMSLE for ('model1', 'model4') = 0.008076775632153685
# Fold 27 RMSLE for ('model2', 'model3') = 0.007774389833570478
# Fold 27 RMSLE for ('model2', 'model4') = 0.007956420516954934
# Fold 27 RMSLE for ('model3', 'model4') = 0.008044251565158596
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.00783387330945686
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.007898881421147452
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.008001081519311158
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007868287981859415
# Fold 27 RMSLE for all models ensemble = 0.007878603232469037
# Fold 27 best combination: model2 with RMSLE = 0.007704004852513314
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.011457175851595112
# Fold 28 RMSLE for model2 = 0.010605690297398792
# Fold 28 RMSLE for model3 = 0.012019324846921857
# Fold 28 RMSLE for model4 = 0.010805474555126359
# Fold 28 RMSLE for ('model1', 'model2') = 0.01097232986434536
# Fold 28 RMSLE for ('model1', 'model3') = 0.011717525733199764
# Fold 28 RMSLE for ('model1', 'model4') = 0.011093756779089381
# Fold 28 RMSLE for ('model2', 'model3') = 0.011242689128360706
# Fold 28 RMSLE for ('model2', 'model4') = 0.010675761042036122
# Fold 28 RMSLE for ('model3', 'model4') = 0.01135068278251365
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.01129478861240127
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.010899722311798261
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.011374191375252592
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.011071126673317687
# Fold 28 RMSLE for all models ensemble = 0.011152206127684867
# Fold 28 best combination: model2 with RMSLE = 0.010605690297398792
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.011826026925982322
# Fold 29 RMSLE for model2 = 0.013033744988564699
# Fold 29 RMSLE for model3 = 0.011840498098141056
# Fold 29 RMSLE for model4 = 0.013684078558888382
# Fold 29 RMSLE for ('model1', 'model2') = 0.012256468293769933
# Fold 29 RMSLE for ('model1', 'model3') = 0.011812668697931033
# Fold 29 RMSLE for ('model1', 'model4') = 0.012590126731401509
# Fold 29 RMSLE for ('model2', 'model3') = 0.012198432766047668
# Fold 29 RMSLE for ('model2', 'model4') = 0.013337017634807638
# Fold 29 RMSLE for ('model3', 'model4') = 0.01254073378043147
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.01203844239959811
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.012690529955108741
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.012265468386304027
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.012642350830608095
# Fold 29 RMSLE for all models ensemble = 0.012385746261311685
# Fold 29 best combination: ('model1', 'model3') with RMSLE = 0.011812668697931033
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009409609663920609
# Fold 30 RMSLE for model2 = 0.009681519378786243
# Fold 30 RMSLE for model3 = 0.009628683856282613
# Fold 30 RMSLE for model4 = 0.00980683402790374
# Fold 30 RMSLE for ('model1', 'model2') = 0.009505769916050753
# Fold 30 RMSLE for ('model1', 'model3') = 0.009496320794849286
# Fold 30 RMSLE for ('model1', 'model4') = 0.009579584880275951
# Fold 30 RMSLE for ('model2', 'model3') = 0.009584201534682379
# Fold 30 RMSLE for ('model2', 'model4') = 0.009720417689660997
# Fold 30 RMSLE for ('model3', 'model4') = 0.009665097328358485
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.009513748142901483
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009591732248759947
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009568608082527044
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009640267504386641
# Fold 30 RMSLE for all models ensemble = 0.009571921220260805
# Fold 30 best combination: model1 with RMSLE = 0.009409609663920609
# ---------------
#
# OOF RMSLE = 0.011253335390896527
# Sum of RMSLE for each combination:
# ('model1',): 0.3404525079272879
# ('model2',): 0.3393666228192871
# ('model3',): 0.33973286831268307
# ('model4',): 0.3419906239496424
# ('model1', 'model2'): 0.3381854502109583
# ('model1', 'model3'): 0.33920329617755135
# ('model1', 'model4'): 0.3399006510750992
# ('model2', 'model3'): 0.3371118125866801
# ('model2', 'model4'): 0.3395855641535282
# ('model3', 'model4'): 0.33895685325095787
# ('model1', 'model2', 'model3'): 0.3376015004661591
# ('model1', 'model2', 'model4'): 0.33876631554209824
# ('model1', 'model3', 'model4'): 0.33888868353349266
# ('model2', 'model3', 'model4'): 0.33795225605973045
# ('model1', 'model2', 'model3', 'model4'): 0.3380408539946269
#
# 1番目の学習が終わりました。
#
# 推定時間は23
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.008390622517657478
# Fold 1 RMSLE for model2 = 0.008075394010504396
# Fold 1 RMSLE for model3 = 0.00859332518710006
# Fold 1 RMSLE for model4 = 0.008542128788515652
# Fold 1 RMSLE for ('model1', 'model2') = 0.008207367304659135
# Fold 1 RMSLE for ('model1', 'model3') = 0.008474392334412998
# Fold 1 RMSLE for ('model1', 'model4') = 0.008442289817190382
# Fold 1 RMSLE for ('model2', 'model3') = 0.008301503138200678
# Fold 1 RMSLE for ('model2', 'model4') = 0.008287128136532963
# Fold 1 RMSLE for ('model3', 'model4') = 0.00854644185214528
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.008319354001240464
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.008304322929327987
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.008480705265591465
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.00836996794970741
# Fold 1 RMSLE for all models ensemble = 0.008364623541423873
# Fold 1 best combination: model2 with RMSLE = 0.008075394010504396
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.009533482661865279
# Fold 2 RMSLE for model2 = 0.009364616221026923
# Fold 2 RMSLE for model3 = 0.00950698732015535
# Fold 2 RMSLE for model4 = 0.00962340884109678
# Fold 2 RMSLE for ('model1', 'model2') = 0.009419226239857855
# Fold 2 RMSLE for ('model1', 'model3') = 0.009497074494173257
# Fold 2 RMSLE for ('model1', 'model4') = 0.00956966551942568
# Fold 2 RMSLE for ('model2', 'model3') = 0.009380177496528311
# Fold 2 RMSLE for ('model2', 'model4') = 0.009469287375285006
# Fold 2 RMSLE for ('model3', 'model4') = 0.009530222525954726
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.009420130753106585
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.009479085584556185
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.009524892281633121
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.009447117467658687
# Fold 2 RMSLE for all models ensemble = 0.009462913829928874
# Fold 2 best combination: model2 with RMSLE = 0.009364616221026923
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.014792673175810742
# Fold 3 RMSLE for model2 = 0.01622373534049703
# Fold 3 RMSLE for model3 = 0.014114904768839677
# Fold 3 RMSLE for model4 = 0.015764106688752024
# Fold 3 RMSLE for ('model1', 'model2') = 0.015468436809079975
# Fold 3 RMSLE for ('model1', 'model3') = 0.014443085435449051
# Fold 3 RMSLE for ('model1', 'model4') = 0.015260916735307545
# Fold 3 RMSLE for ('model2', 'model3') = 0.015104616185812778
# Fold 3 RMSLE for ('model2', 'model4') = 0.015981291876283013
# Fold 3 RMSLE for ('model3', 'model4') = 0.014907266175433887
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.014991980943622064
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.01556255977243161
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.014863597404357887
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.015319427154931765
# Fold 3 RMSLE for all models ensemble = 0.015179454509441113
# Fold 3 best combination: model3 with RMSLE = 0.014114904768839677
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.01054560066941864
# Fold 4 RMSLE for model2 = 0.011030451958208896
# Fold 4 RMSLE for model3 = 0.010558955995784648
# Fold 4 RMSLE for model4 = 0.010767335818891811
# Fold 4 RMSLE for ('model1', 'model2') = 0.010759103340524793
# Fold 4 RMSLE for ('model1', 'model3') = 0.010545052879202316
# Fold 4 RMSLE for ('model1', 'model4') = 0.010652057895695639
# Fold 4 RMSLE for ('model2', 'model3') = 0.01075363204170575
# Fold 4 RMSLE for ('model2', 'model4') = 0.010871101060544522
# Fold 4 RMSLE for ('model3', 'model4') = 0.01065706512565414
# Fold 4 RMSLE for ('model1', 'model2', 'model3') = 0.010677161880137192
# Fold 4 RMSLE for ('model1', 'model2', 'model4') = 0.010753840848623316
# Fold 4 RMSLE for ('model1', 'model3', 'model4') = 0.010616095186074927
# Fold 4 RMSLE for ('model2', 'model3', 'model4') = 0.010752157235940888
# Fold 4 RMSLE for all models ensemble = 0.01069653497211021
# Fold 4 best combination: ('model1', 'model3') with RMSLE = 0.010545052879202316
# ---------------
#
# Starting Fold 5
# Fold 5 RMSLE for model1 = 0.013736741127228084
# Fold 5 RMSLE for model2 = 0.013248644038297591
# Fold 5 RMSLE for model3 = 0.01298399213479346
# Fold 5 RMSLE for model4 = 0.013144951415895523
# Fold 5 RMSLE for ('model1', 'model2') = 0.013460990081581062
# Fold 5 RMSLE for ('model1', 'model3') = 0.013322638282888495
# Fold 5 RMSLE for ('model1', 'model4') = 0.013415899560412154
# Fold 5 RMSLE for ('model2', 'model3') = 0.0130695837170806
# Fold 5 RMSLE for ('model2', 'model4') = 0.013180048677929596
# Fold 5 RMSLE for ('model3', 'model4') = 0.013031932653947118
# Fold 5 RMSLE for ('model1', 'model2', 'model3') = 0.013271570184509631
# Fold 5 RMSLE for ('model1', 'model2', 'model4') = 0.013344074087191437
# Fold 5 RMSLE for ('model1', 'model3', 'model4') = 0.01324625492725339
# Fold 5 RMSLE for ('model2', 'model3', 'model4') = 0.013083218739257767
# Fold 5 RMSLE for all models ensemble = 0.013230996407728277
# Fold 5 best combination: model3 with RMSLE = 0.01298399213479346
# ---------------
#
# Starting Fold 6
# Fold 6 RMSLE for model1 = 0.009248804686947483
# Fold 6 RMSLE for model2 = 0.009479590188895074
# Fold 6 RMSLE for model3 = 0.009049271161243854
# Fold 6 RMSLE for model4 = 0.009525198404124599
# Fold 6 RMSLE for ('model1', 'model2') = 0.00931093419445724
# Fold 6 RMSLE for ('model1', 'model3') = 0.009120651314824924
# Fold 6 RMSLE for ('model1', 'model4') = 0.009348312256806867
# Fold 6 RMSLE for ('model2', 'model3') = 0.009198928308056874
# Fold 6 RMSLE for ('model2', 'model4') = 0.009476061234811923
# Fold 6 RMSLE for ('model3', 'model4') = 0.00923476291256782
# Fold 6 RMSLE for ('model1', 'model2', 'model3') = 0.009193644576070963
# Fold 6 RMSLE for ('model1', 'model2', 'model4') = 0.00936535147158041
# Fold 6 RMSLE for ('model1', 'model3', 'model4') = 0.009221190408081273
# Fold 6 RMSLE for ('model2', 'model3', 'model4') = 0.009287423485786218
# Fold 6 RMSLE for all models ensemble = 0.009259545303765644
# Fold 6 best combination: model3 with RMSLE = 0.009049271161243854
# ---------------
#
# Starting Fold 7
# Fold 7 RMSLE for model1 = 0.008380608852769995
# Fold 7 RMSLE for model2 = 0.0085676189494309
# Fold 7 RMSLE for model3 = 0.008511840030167127
# Fold 7 RMSLE for model4 = 0.008528211404009497
# Fold 7 RMSLE for ('model1', 'model2') = 0.00842193301032086
# Fold 7 RMSLE for ('model1', 'model3') = 0.008432621405628995
# Fold 7 RMSLE for ('model1', 'model4') = 0.008444447924578024
# Fold 7 RMSLE for ('model2', 'model3') = 0.008479709350571626
# Fold 7 RMSLE for ('model2', 'model4') = 0.008502854472658247
# Fold 7 RMSLE for ('model3', 'model4') = 0.008514145046180092
# Fold 7 RMSLE for ('model1', 'model2', 'model3') = 0.008430658341295036
# Fold 7 RMSLE for ('model1', 'model2', 'model4') = 0.008444430599188073
# Fold 7 RMSLE for ('model1', 'model3', 'model4') = 0.008460479803777838
# Fold 7 RMSLE for ('model2', 'model3', 'model4') = 0.008486543452691548
# Fold 7 RMSLE for all models ensemble = 0.008450313250136697
# Fold 7 best combination: model1 with RMSLE = 0.008380608852769995
# ---------------
#
# Starting Fold 8
# Fold 8 RMSLE for model1 = 0.01384083883336327
# Fold 8 RMSLE for model2 = 0.013523340155844806
# Fold 8 RMSLE for model3 = 0.013247784417024315
# Fold 8 RMSLE for model4 = 0.013464125533808824
# Fold 8 RMSLE for ('model1', 'model2') = 0.013665607408131412
# Fold 8 RMSLE for ('model1', 'model3') = 0.013491731945046246
# Fold 8 RMSLE for ('model1', 'model4') = 0.013632216333111681
# Fold 8 RMSLE for ('model2', 'model3') = 0.013330779626248745
# Fold 8 RMSLE for ('model2', 'model4') = 0.013472964759422076
# Fold 8 RMSLE for ('model3', 'model4') = 0.013335181050382337
# Fold 8 RMSLE for ('model1', 'model2', 'model3') = 0.013482449609081053
# Fold 8 RMSLE for ('model1', 'model2', 'model4') = 0.013583877226764351
# Fold 8 RMSLE for ('model1', 'model3', 'model4') = 0.013475943742762935
# Fold 8 RMSLE for ('model2', 'model3', 'model4') = 0.013368964377218587
# Fold 8 RMSLE for all models ensemble = 0.013472680585777181
# Fold 8 best combination: model3 with RMSLE = 0.013247784417024315
# ---------------
#
# Starting Fold 9
# Fold 9 RMSLE for model1 = 0.010283509355164599
# Fold 9 RMSLE for model2 = 0.010827818707909227
# Fold 9 RMSLE for model3 = 0.010164219495821504
# Fold 9 RMSLE for model4 = 0.011265757152555064
# Fold 9 RMSLE for ('model1', 'model2') = 0.01044667530691172
# Fold 9 RMSLE for ('model1', 'model3') = 0.010200833161633796
# Fold 9 RMSLE for ('model1', 'model4') = 0.010647850427920144
# Fold 9 RMSLE for ('model2', 'model3') = 0.010334089630452185
# Fold 9 RMSLE for ('model2', 'model4') = 0.011012990824333685
# Fold 9 RMSLE for ('model3', 'model4') = 0.01053989517506552
# Fold 9 RMSLE for ('model1', 'model2', 'model3') = 0.010293634182417548
# Fold 9 RMSLE for ('model1', 'model2', 'model4') = 0.010673296562249654
# Fold 9 RMSLE for ('model1', 'model3', 'model4') = 0.010424933883071972
# Fold 9 RMSLE for ('model2', 'model3', 'model4') = 0.010589327764850245
# Fold 9 RMSLE for all models ensemble = 0.010477655680179086
# Fold 9 best combination: model3 with RMSLE = 0.010164219495821504
# ---------------
#
# Starting Fold 10
# Fold 10 RMSLE for model1 = 0.011114752290691865
# Fold 10 RMSLE for model2 = 0.010598079084353713
# Fold 10 RMSLE for model3 = 0.010628307084681035
# Fold 10 RMSLE for model4 = 0.011167420163645508
# Fold 10 RMSLE for ('model1', 'model2') = 0.010781381376891237
# Fold 10 RMSLE for ('model1', 'model3') = 0.010836026543214927
# Fold 10 RMSLE for ('model1', 'model4') = 0.011080639113070926
# Fold 10 RMSLE for ('model2', 'model3') = 0.010562698637579913
# Fold 10 RMSLE for ('model2', 'model4') = 0.0108588160923464
# Fold 10 RMSLE for ('model3', 'model4') = 0.010866257393038694
# Fold 10 RMSLE for ('model1', 'model2', 'model3') = 0.010708745762872326
# Fold 10 RMSLE for ('model1', 'model2', 'model4') = 0.01088914988023976
# Fold 10 RMSLE for ('model1', 'model3', 'model4') = 0.010913256125901022
# Fold 10 RMSLE for ('model2', 'model3', 'model4') = 0.010750962188433359
# Fold 10 RMSLE for all models ensemble = 0.010807794250872088
# Fold 10 best combination: ('model2', 'model3') with RMSLE = 0.010562698637579913
# ---------------
#
# Starting Fold 11
# Fold 11 RMSLE for model1 = 0.010954561079365066
# Fold 11 RMSLE for model2 = 0.010418104123542
# Fold 11 RMSLE for model3 = 0.010675652920104582
# Fold 11 RMSLE for model4 = 0.010631778049612609
# Fold 11 RMSLE for ('model1', 'model2') = 0.010659447840516832
# Fold 11 RMSLE for ('model1', 'model3') = 0.01079694802231597
# Fold 11 RMSLE for ('model1', 'model4') = 0.010784557364944033
# Fold 11 RMSLE for ('model2', 'model3') = 0.010509969800332268
# Fold 11 RMSLE for ('model2', 'model4') = 0.010500292023866717
# Fold 11 RMSLE for ('model3', 'model4') = 0.010645987303779645
# Fold 11 RMSLE for ('model1', 'model2', 'model3') = 0.010646442559925475
# Fold 11 RMSLE for ('model1', 'model2', 'model4') = 0.010641493980165354
# Fold 11 RMSLE for ('model1', 'model3', 'model4') = 0.010738635133192433
# Fold 11 RMSLE for ('model2', 'model3', 'model4') = 0.010544453047059208
# Fold 11 RMSLE for all models ensemble = 0.010639377917871253
# Fold 11 best combination: model2 with RMSLE = 0.010418104123542
# ---------------
#
# Starting Fold 12
# Fold 12 RMSLE for model1 = 0.009090053110971238
# Fold 12 RMSLE for model2 = 0.009693171266200227
# Fold 12 RMSLE for model3 = 0.009008164726481502
# Fold 12 RMSLE for model4 = 0.009261018650314269
# Fold 12 RMSLE for ('model1', 'model2') = 0.0093548620935753
# Fold 12 RMSLE for ('model1', 'model3') = 0.009037776280117229
# Fold 12 RMSLE for ('model1', 'model4') = 0.009162140268390004
# Fold 12 RMSLE for ('model2', 'model3') = 0.009295422915987466
# Fold 12 RMSLE for ('model2', 'model4') = 0.009455381832872844
# Fold 12 RMSLE for ('model3', 'model4') = 0.009116708607866356
# Fold 12 RMSLE for ('model1', 'model2', 'model3') = 0.009217527155660757
# Fold 12 RMSLE for ('model1', 'model2', 'model4') = 0.009316037054300588
# Fold 12 RMSLE for ('model1', 'model3', 'model4') = 0.009100792378130825
# Fold 12 RMSLE for ('model2', 'model3', 'model4') = 0.009278547342937189
# Fold 12 RMSLE for all models ensemble = 0.009223788556583056
# Fold 12 best combination: model3 with RMSLE = 0.009008164726481502
# ---------------
#
# Starting Fold 13
# Fold 13 RMSLE for model1 = 0.012747478729275657
# Fold 13 RMSLE for model2 = 0.012934784793463027
# Fold 13 RMSLE for model3 = 0.012739846487162077
# Fold 13 RMSLE for model4 = 0.013054348419734093
# Fold 13 RMSLE for ('model1', 'model2') = 0.012753241951456157
# Fold 13 RMSLE for ('model1', 'model3') = 0.012731322891423003
# Fold 13 RMSLE for ('model1', 'model4') = 0.012788075324981047
# Fold 13 RMSLE for ('model2', 'model3') = 0.012757474234759562
# Fold 13 RMSLE for ('model2', 'model4') = 0.012964137720283176
# Fold 13 RMSLE for ('model3', 'model4') = 0.01280212059049814
# Fold 13 RMSLE for ('model1', 'model2', 'model3') = 0.012727176027096566
# Fold 13 RMSLE for ('model1', 'model2', 'model4') = 0.012809600506437029
# Fold 13 RMSLE for ('model1', 'model3', 'model4') = 0.012749052529694306
# Fold 13 RMSLE for ('model2', 'model3', 'model4') = 0.012818549364734625
# Fold 13 RMSLE for all models ensemble = 0.012764400243004346
# Fold 13 best combination: ('model1', 'model2', 'model3') with RMSLE = 0.012727176027096566
# ---------------
#
# Starting Fold 14
# Fold 14 RMSLE for model1 = 0.01162559024765927
# Fold 14 RMSLE for model2 = 0.011967957454245849
# Fold 14 RMSLE for model3 = 0.011414967485107062
# Fold 14 RMSLE for model4 = 0.011068799313742946
# Fold 14 RMSLE for ('model1', 'model2') = 0.011760563318179242
# Fold 14 RMSLE for ('model1', 'model3') = 0.011502115444459572
# Fold 14 RMSLE for ('model1', 'model4') = 0.01130012284451501
# Fold 14 RMSLE for ('model2', 'model3') = 0.011649342467377718
# Fold 14 RMSLE for ('model2', 'model4') = 0.011485125487157865
# Fold 14 RMSLE for ('model3', 'model4') = 0.011208753661013232
# Fold 14 RMSLE for ('model1', 'model2', 'model3') = 0.011626497128818095
# Fold 14 RMSLE for ('model1', 'model2', 'model4') = 0.011502377825621583
# Fold 14 RMSLE for ('model1', 'model3', 'model4') = 0.01132615571027953
# Fold 14 RMSLE for ('model2', 'model3', 'model4') = 0.011435587617824922
# Fold 14 RMSLE for all models ensemble = 0.011466807030303347
# Fold 14 best combination: model4 with RMSLE = 0.011068799313742946
# ---------------
#
# Starting Fold 15
# Fold 15 RMSLE for model1 = 0.011159457584648733
# Fold 15 RMSLE for model2 = 0.01088492017512775
# Fold 15 RMSLE for model3 = 0.010859666402897946
# Fold 15 RMSLE for model4 = 0.011155057928844256
# Fold 15 RMSLE for ('model1', 'model2') = 0.010997000836303932
# Fold 15 RMSLE for ('model1', 'model3') = 0.011001396830397789
# Fold 15 RMSLE for ('model1', 'model4') = 0.011143340570337355
# Fold 15 RMSLE for ('model2', 'model3') = 0.010849143443324851
# Fold 15 RMSLE for ('model2', 'model4') = 0.010991166238935741
# Fold 15 RMSLE for ('model3', 'model4') = 0.010990041890937958
# Fold 15 RMSLE for ('model1', 'model2', 'model3') = 0.010942919360388633
# Fold 15 RMSLE for ('model1', 'model2', 'model4') = 0.011036328439446992
# Fold 15 RMSLE for ('model1', 'model3', 'model4') = 0.01104054146673928
# Fold 15 RMSLE for ('model2', 'model3', 'model4') = 0.010935739161342694
# Fold 15 RMSLE for all models ensemble = 0.010985651345241605
# Fold 15 best combination: ('model2', 'model3') with RMSLE = 0.010849143443324851
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.012605411035307393
# Fold 16 RMSLE for model2 = 0.012934124296835275
# Fold 16 RMSLE for model3 = 0.012003090200137066
# Fold 16 RMSLE for model4 = 0.013483479459492182
# Fold 16 RMSLE for ('model1', 'model2') = 0.012640733561929235
# Fold 16 RMSLE for ('model1', 'model3') = 0.012271624010340558
# Fold 16 RMSLE for ('model1', 'model4') = 0.012952855188551904
# Fold 16 RMSLE for ('model2', 'model3') = 0.012314247363780319
# Fold 16 RMSLE for ('model2', 'model4') = 0.013146466292229833
# Fold 16 RMSLE for ('model3', 'model4') = 0.012612180763107937
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.012373018236965823
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.012882307147309013
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.012582927091409048
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.012653411954570037
# Fold 16 RMSLE for all models ensemble = 0.012606164665929346
# Fold 16 best combination: model3 with RMSLE = 0.012003090200137066
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.013797561093211699
# Fold 17 RMSLE for model2 = 0.013000461311556672
# Fold 17 RMSLE for model3 = 0.013666439081492433
# Fold 17 RMSLE for model4 = 0.013109999455610869
# Fold 17 RMSLE for ('model1', 'model2') = 0.013333401675499413
# Fold 17 RMSLE for ('model1', 'model3') = 0.013714888933410201
# Fold 17 RMSLE for ('model1', 'model4') = 0.013437667785976172
# Fold 17 RMSLE for ('model2', 'model3') = 0.013238832246981445
# Fold 17 RMSLE for ('model2', 'model4') = 0.013010421873009465
# Fold 17 RMSLE for ('model3', 'model4') = 0.013358460278868209
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.013409870281015274
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.013246507297146977
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.013496723410384605
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.013183698828437302
# Fold 17 RMSLE for all models ensemble = 0.013326859600484745
# Fold 17 best combination: model2 with RMSLE = 0.013000461311556672
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.00806031854133708
# Fold 18 RMSLE for model2 = 0.008339816277267827
# Fold 18 RMSLE for model3 = 0.00838182980073343
# Fold 18 RMSLE for model4 = 0.008291617922376872
# Fold 18 RMSLE for ('model1', 'model2') = 0.008170948349635245
# Fold 18 RMSLE for ('model1', 'model3') = 0.008192814741705232
# Fold 18 RMSLE for ('model1', 'model4') = 0.00815595735107065
# Fold 18 RMSLE for ('model2', 'model3') = 0.00832177141727786
# Fold 18 RMSLE for ('model2', 'model4') = 0.008290076057460022
# Fold 18 RMSLE for ('model3', 'model4') = 0.008320255508157227
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.008217715403619959
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.008197326087317632
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.008215833549248618
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.008301653349423406
# Fold 18 RMSLE for all models ensemble = 0.008228707498392857
# Fold 18 best combination: model1 with RMSLE = 0.00806031854133708
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.01124641065364215
# Fold 19 RMSLE for model2 = 0.011749039430991657
# Fold 19 RMSLE for model3 = 0.011210670269830204
# Fold 19 RMSLE for model4 = 0.011560648350559017
# Fold 19 RMSLE for ('model1', 'model2') = 0.01145114853800483
# Fold 19 RMSLE for ('model1', 'model3') = 0.011212174802497013
# Fold 19 RMSLE for ('model1', 'model4') = 0.011379539864726144
# Fold 19 RMSLE for ('model2', 'model3') = 0.011424397590152404
# Fold 19 RMSLE for ('model2', 'model4') = 0.01160410207850341
# Fold 19 RMSLE for ('model3', 'model4') = 0.0113727270886299
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.011349171773719762
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.011464638344133766
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.011315541820004129
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.011453656482536335
# Fold 19 RMSLE for all models ensemble = 0.01138992824546237
# Fold 19 best combination: model3 with RMSLE = 0.011210670269830204
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.02283861819693755
# Fold 20 RMSLE for model2 = 0.022760647171408077
# Fold 20 RMSLE for model3 = 0.021721489508312902
# Fold 20 RMSLE for model4 = 0.023181197594606528
# Fold 20 RMSLE for ('model1', 'model2') = 0.02274004054452382
# Fold 20 RMSLE for ('model1', 'model3') = 0.022238309737161868
# Fold 20 RMSLE for ('model1', 'model4') = 0.022967719237033467
# Fold 20 RMSLE for ('model2', 'model3') = 0.022108740927723754
# Fold 20 RMSLE for ('model2', 'model4') = 0.02294851463064278
# Fold 20 RMSLE for ('model3', 'model4') = 0.022330331832981748
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.022336617937648965
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.02287167611784263
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.022489542150271564
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.02243276321140621
# Fold 20 RMSLE for all models ensemble = 0.02252122429346645
# Fold 20 best combination: model3 with RMSLE = 0.021721489508312902
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.011601699548227786
# Fold 21 RMSLE for model2 = 0.011128827595141493
# Fold 21 RMSLE for model3 = 0.011434158247643635
# Fold 21 RMSLE for model4 = 0.011038987241529616
# Fold 21 RMSLE for ('model1', 'model2') = 0.011319963170943123
# Fold 21 RMSLE for ('model1', 'model3') = 0.011498607569297319
# Fold 21 RMSLE for ('model1', 'model4') = 0.011291627053069856
# Fold 21 RMSLE for ('model2', 'model3') = 0.011235910191374389
# Fold 21 RMSLE for ('model2', 'model4') = 0.011047612236377746
# Fold 21 RMSLE for ('model3', 'model4') = 0.011224198460722564
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.011339364420716778
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.01120743354465924
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.01133140742362058
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.011158764180706325
# Fold 21 RMSLE for all models ensemble = 0.011254040425942139
# Fold 21 best combination: model4 with RMSLE = 0.011038987241529616
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.009777382955810708
# Fold 22 RMSLE for model2 = 0.008727338993077337
# Fold 22 RMSLE for model3 = 0.00937314759784908
# Fold 22 RMSLE for model4 = 0.009387991215390246
# Fold 22 RMSLE for ('model1', 'model2') = 0.009227087604030109
# Fold 22 RMSLE for ('model1', 'model3') = 0.009553142556625469
# Fold 22 RMSLE for ('model1', 'model4') = 0.009524105119188934
# Fold 22 RMSLE for ('model2', 'model3') = 0.009020510375202075
# Fold 22 RMSLE for ('model2', 'model4') = 0.00902161457417499
# Fold 22 RMSLE for ('model3', 'model4') = 0.00933090941548502
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.009258423097793672
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.00924392275780378
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.009454924843691967
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.009111307437860636
# Fold 22 RMSLE for all models ensemble = 0.009260916465207674
# Fold 22 best combination: model2 with RMSLE = 0.008727338993077337
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.008034195922534515
# Fold 23 RMSLE for model2 = 0.007865494970396205
# Fold 23 RMSLE for model3 = 0.008041260625873566
# Fold 23 RMSLE for model4 = 0.008104389601206673
# Fold 23 RMSLE for ('model1', 'model2') = 0.007917151531398237
# Fold 23 RMSLE for ('model1', 'model3') = 0.008024302972151662
# Fold 23 RMSLE for ('model1', 'model4') = 0.008049832696713227
# Fold 23 RMSLE for ('model2', 'model3') = 0.007912627907353378
# Fold 23 RMSLE for ('model2', 'model4') = 0.00795376903847056
# Fold 23 RMSLE for ('model3', 'model4') = 0.008056497052786495
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.00794177030451273
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.0079643560168971
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.008038063961130817
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.007964560767171953
# Fold 23 RMSLE for all models ensemble = 0.0079729408129235
# Fold 23 best combination: model2 with RMSLE = 0.007865494970396205
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.009692994404776415
# Fold 24 RMSLE for model2 = 0.009905992989468431
# Fold 24 RMSLE for model3 = 0.009804088170704594
# Fold 24 RMSLE for model4 = 0.009787191178880736
# Fold 24 RMSLE for ('model1', 'model2') = 0.009766582602393506
# Fold 24 RMSLE for ('model1', 'model3') = 0.009734324549714303
# Fold 24 RMSLE for ('model1', 'model4') = 0.0097226079816515
# Fold 24 RMSLE for ('model2', 'model3') = 0.009812219164400504
# Fold 24 RMSLE for ('model2', 'model4') = 0.00981655284428787
# Fold 24 RMSLE for ('model3', 'model4') = 0.009780865161589868
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.009760967836716343
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.009759598448851351
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.009740765532190662
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.009793426132974214
# Fold 24 RMSLE for all models ensemble = 0.009759430660963563
# Fold 24 best combination: model1 with RMSLE = 0.009692994404776415
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.011363410208873667
# Fold 25 RMSLE for model2 = 0.011408846067749464
# Fold 25 RMSLE for model3 = 0.011406319507564667
# Fold 25 RMSLE for model4 = 0.011476576593049945
# Fold 25 RMSLE for ('model1', 'model2') = 0.011334161458870017
# Fold 25 RMSLE for ('model1', 'model3') = 0.011364944002810042
# Fold 25 RMSLE for ('model1', 'model4') = 0.011386423354459144
# Fold 25 RMSLE for ('model2', 'model3') = 0.011348629059372534
# Fold 25 RMSLE for ('model2', 'model4') = 0.011388203285773387
# Fold 25 RMSLE for ('model3', 'model4') = 0.011402423364902405
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.011334672538024185
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.011353998008407772
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.011374280752770064
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.011362773297966542
# Fold 25 RMSLE for all models ensemble = 0.011349242503176878
# Fold 25 best combination: ('model1', 'model2') with RMSLE = 0.011334161458870017
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.00902746083362993
# Fold 26 RMSLE for model2 = 0.008858530978179027
# Fold 26 RMSLE for model3 = 0.008943954024549061
# Fold 26 RMSLE for model4 = 0.009111401476473553
# Fold 26 RMSLE for ('model1', 'model2') = 0.008919077370052675
# Fold 26 RMSLE for ('model1', 'model3') = 0.008972196464399623
# Fold 26 RMSLE for ('model1', 'model4') = 0.009056441806522281
# Fold 26 RMSLE for ('model2', 'model3') = 0.008864420694189275
# Fold 26 RMSLE for ('model2', 'model4') = 0.008961854081478437
# Fold 26 RMSLE for ('model3', 'model4') = 0.009013668658604961
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.008910355307023783
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.00897248494356759
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.009009597854661412
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.008938496645182885
# Fold 26 RMSLE for all models ensemble = 0.008954302162917906
# Fold 26 best combination: model2 with RMSLE = 0.008858530978179027
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.007861165566410934
# Fold 27 RMSLE for model2 = 0.007873686679485067
# Fold 27 RMSLE for model3 = 0.007645168210992921
# Fold 27 RMSLE for model4 = 0.008329945460557542
# Fold 27 RMSLE for ('model1', 'model2') = 0.007807958249581001
# Fold 27 RMSLE for ('model1', 'model3') = 0.007725441525267797
# Fold 27 RMSLE for ('model1', 'model4') = 0.007993987962057813
# Fold 27 RMSLE for ('model2', 'model3') = 0.007672268224940592
# Fold 27 RMSLE for ('model2', 'model4') = 0.0080430328298652
# Fold 27 RMSLE for ('model3', 'model4') = 0.00787049472138866
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.0077157844782826624
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.007923613606759158
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.007835031003312424
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007832720015930158
# Fold 27 RMSLE for all models ensemble = 0.007814002481600442
# Fold 27 best combination: model3 with RMSLE = 0.007645168210992921
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.010263826512436042
# Fold 28 RMSLE for model2 = 0.010109955260988852
# Fold 28 RMSLE for model3 = 0.010548522684814517
# Fold 28 RMSLE for model4 = 0.01014951268579015
# Fold 28 RMSLE for ('model1', 'model2') = 0.010120970402002579
# Fold 28 RMSLE for ('model1', 'model3') = 0.010392401522500441
# Fold 28 RMSLE for ('model1', 'model4') = 0.01018190299042069
# Fold 28 RMSLE for ('model2', 'model3') = 0.01027435470349633
# Fold 28 RMSLE for ('model2', 'model4') = 0.01007265863511501
# Fold 28 RMSLE for ('model3', 'model4') = 0.010323585971773972
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.01024784531901153
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.010108767545721176
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.01029222073136128
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.010208350838120677
# Fold 28 RMSLE for all models ensemble = 0.010207641861446359
# Fold 28 best combination: ('model2', 'model4') with RMSLE = 0.01007265863511501
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.011868711926577413
# Fold 29 RMSLE for model2 = 0.01324304736608687
# Fold 29 RMSLE for model3 = 0.011808530859774732
# Fold 29 RMSLE for model4 = 0.013960005639483864
# Fold 29 RMSLE for ('model1', 'model2') = 0.0123784732870567
# Fold 29 RMSLE for ('model1', 'model3') = 0.011827831120509873
# Fold 29 RMSLE for ('model1', 'model4') = 0.012709281630329654
# Fold 29 RMSLE for ('model2', 'model3') = 0.012326111141873826
# Fold 29 RMSLE for ('model2', 'model4') = 0.01357327074083383
# Fold 29 RMSLE for ('model3', 'model4') = 0.012652307676964633
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.01213142290743608
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.012844445805849421
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.012341563880567816
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.012803163125191742
# Fold 29 RMSLE for all models ensemble = 0.012506135705080784
# Fold 29 best combination: model3 with RMSLE = 0.011808530859774732
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009297413731580353
# Fold 30 RMSLE for model2 = 0.009367507571542052
# Fold 30 RMSLE for model3 = 0.009376813603984598
# Fold 30 RMSLE for model4 = 0.009633556076219192
# Fold 30 RMSLE for ('model1', 'model2') = 0.009296815344959531
# Fold 30 RMSLE for ('model1', 'model3') = 0.00931458605228578
# Fold 30 RMSLE for ('model1', 'model4') = 0.00944258826400188
# Fold 30 RMSLE for ('model2', 'model3') = 0.00932120169662522
# Fold 30 RMSLE for ('model2', 'model4') = 0.009476736858325735
# Fold 30 RMSLE for ('model3', 'model4') = 0.00946325278404185
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.009298695404903383
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009396273834652791
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009397024473089405
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009407477812196642
# Fold 30 RMSLE for all models ensemble = 0.00936936750342786
# Fold 30 best combination: ('model1', 'model2') with RMSLE = 0.009296815344959531
# ---------------
#
# OOF RMSLE = 0.01108809869492018
# Sum of RMSLE for each combination:
# ('model1',): 0.332781356054131
# ('model2',): 0.3341115434277216
# ('model3',): 0.32742336801162164
# ('model4',): 0.3375701465247704
# ('model1', 'model2'): 0.3318912848033268
# ('model1', 'model3'): 0.3294712578258657
# ('model1', 'model4'): 0.3339250702424598
# ('model2', 'model3'): 0.3287733136987632
# ('model2', 'model4'): 0.33486353386981205
# ('model3', 'model4'): 0.3310389407044705
# ('model1', 'model2', 'model3'): 0.3295755877136332
# ('model1', 'model2', 'model4'): 0.3331431762750437
# ('model1', 'model3', 'model4'): 0.3310979747242566
# ('model2', 'model3', 'model4'): 0.33107421043005014
# ('model1', 'model2', 'model3', 'model4'): 0.33100344231078954
#
# 2番目の学習が終わりました。
#
# 推定時間は20
#
# Starting Fold 1
# Fold 1 RMSLE for model1 = 0.007902555970441356
# Fold 1 RMSLE for model2 = 0.007823495536989097
# Fold 1 RMSLE for model3 = 0.00802560534201699
# Fold 1 RMSLE for model4 = 0.008053544396322287
# Fold 1 RMSLE for ('model1', 'model2') = 0.007839163227302623
# Fold 1 RMSLE for ('model1', 'model3') = 0.007941988404269653
# Fold 1 RMSLE for ('model1', 'model4') = 0.007950664072915288
# Fold 1 RMSLE for ('model2', 'model3') = 0.007892264968748515
# Fold 1 RMSLE for ('model2', 'model4') = 0.007905357750893672
# Fold 1 RMSLE for ('model3', 'model4') = 0.008015940530974838
# Fold 1 RMSLE for ('model1', 'model2', 'model3') = 0.007882429198891455
# Fold 1 RMSLE for ('model1', 'model2', 'model4') = 0.007888978466965698
# Fold 1 RMSLE for ('model1', 'model3', 'model4') = 0.00796139195796085
# Fold 1 RMSLE for ('model2', 'model3', 'model4') = 0.007927969612174533
# Fold 1 RMSLE for all models ensemble = 0.007910670852826129
# Fold 1 best combination: model2 with RMSLE = 0.007823495536989097
# ---------------
#
# Starting Fold 2
# Fold 2 RMSLE for model1 = 0.009542830447951145
# Fold 2 RMSLE for model2 = 0.00971030257324224
# Fold 2 RMSLE for model3 = 0.009344980297758243
# Fold 2 RMSLE for model4 = 0.009655766304395928
# Fold 2 RMSLE for ('model1', 'model2') = 0.009575489234931798
# Fold 2 RMSLE for ('model1', 'model3') = 0.009425879738453503
# Fold 2 RMSLE for ('model1', 'model4') = 0.009589865307622784
# Fold 2 RMSLE for ('model2', 'model3') = 0.009455919127412784
# Fold 2 RMSLE for ('model2', 'model4') = 0.009646338898562711
# Fold 2 RMSLE for ('model3', 'model4') = 0.009472050804031278
# Fold 2 RMSLE for ('model1', 'model2', 'model3') = 0.009469965341528837
# Fold 2 RMSLE for ('model1', 'model2', 'model4') = 0.009593053316870595
# Fold 2 RMSLE for ('model1', 'model3', 'model4') = 0.009489771071742618
# Fold 2 RMSLE for ('model2', 'model3', 'model4') = 0.009509594995129135
# Fold 2 RMSLE for all models ensemble = 0.009509596367891802
# Fold 2 best combination: model3 with RMSLE = 0.009344980297758243
# ---------------
#
# Starting Fold 3
# Fold 3 RMSLE for model1 = 0.014880923711833341
# Fold 3 RMSLE for model2 = 0.01517815155415453
# Fold 3 RMSLE for model3 = 0.014116127120960156
# Fold 3 RMSLE for model4 = 0.015882639894378426
# Fold 3 RMSLE for ('model1', 'model2') = 0.014998853372029268
# Fold 3 RMSLE for ('model1', 'model3') = 0.014489136054725101
# Fold 3 RMSLE for ('model1', 'model4') = 0.01536553795782322
# Fold 3 RMSLE for ('model2', 'model3') = 0.014599388774897828
# Fold 3 RMSLE for ('model2', 'model4') = 0.01551519882013253
# Fold 3 RMSLE for ('model3', 'model4') = 0.014967049121923617
# Fold 3 RMSLE for ('model1', 'model2', 'model3') = 0.014685926951317292
# Fold 3 RMSLE for ('model1', 'model2', 'model4') = 0.015286415862951794
# Fold 3 RMSLE for ('model1', 'model3', 'model4') = 0.014934019078978959
# Fold 3 RMSLE for ('model2', 'model3', 'model4') = 0.015017045301468537
# Fold 3 RMSLE for all models ensemble = 0.014976696848877723
# Fold 3 best combination: model3 with RMSLE = 0.014116127120960156
# ---------------
#
# Starting Fold 4
# Fold 4 RMSLE for model1 = 0.010592161354229808
# Fold 4 RMSLE for model2 = 0.011207727357059199
# Fold 4 RMSLE for model3 = 0.010544530234367378
# Fold 4 RMSLE for model4 = 0.011018159681813253
# Fold 4 RMSLE for ('model1', 'model2') = 0.010877394838697606
# ...
# Fold 15 best combination: model3 with RMSLE = 0.010856258259619018
# ---------------
#
# Starting Fold 16
# Fold 16 RMSLE for model1 = 0.012769241616200674
# Fold 16 RMSLE for model2 = 0.013801928404433644
# Fold 16 RMSLE for model3 = 0.012006907274396166
# Fold 16 RMSLE for model4 = 0.01380630015864891
# Fold 16 RMSLE for ('model1', 'model2') = 0.01316288256388026
# Fold 16 RMSLE for ('model1', 'model3') = 0.01236344301553578
# Fold 16 RMSLE for ('model1', 'model4') = 0.013236028985679223
# Fold 16 RMSLE for ('model2', 'model3') = 0.012744156001875765
# Fold 16 RMSLE for ('model2', 'model4') = 0.013756108714302419
# Fold 16 RMSLE for ('model3', 'model4') = 0.012822075765619416
# Fold 16 RMSLE for ('model1', 'model2', 'model3') = 0.01272096375828033
# Fold 16 RMSLE for ('model1', 'model2', 'model4') = 0.013360710175049618
# Fold 16 RMSLE for ('model1', 'model3', 'model4') = 0.012788788391483301
# Fold 16 RMSLE for ('model2', 'model3', 'model4') = 0.01307638112675242
# Fold 16 RMSLE for all models ensemble = 0.012973001555439269
# Fold 16 best combination: model3 with RMSLE = 0.012006907274396166
# ---------------
#
# Starting Fold 17
# Fold 17 RMSLE for model1 = 0.013193690198187039
# Fold 17 RMSLE for model2 = 0.013740118404094252
# Fold 17 RMSLE for model3 = 0.012696278978746641
# Fold 17 RMSLE for model4 = 0.013100190942096225
# Fold 17 RMSLE for ('model1', 'model2') = 0.013435317348808214
# Fold 17 RMSLE for ('model1', 'model3') = 0.012933095543334253
# Fold 17 RMSLE for ('model1', 'model4') = 0.013135299266299616
# Fold 17 RMSLE for ('model2', 'model3') = 0.013173919828072532
# Fold 17 RMSLE for ('model2', 'model4') = 0.013397022997334852
# Fold 17 RMSLE for ('model3', 'model4') = 0.012881238805420095
# Fold 17 RMSLE for ('model1', 'model2', 'model3') = 0.013170841911661648
# Fold 17 RMSLE for ('model1', 'model2', 'model4') = 0.013315058057012752
# Fold 17 RMSLE for ('model1', 'model3', 'model4') = 0.01297872394561519
# Fold 17 RMSLE for ('model2', 'model3', 'model4') = 0.013141255865806629
# Fold 17 RMSLE for all models ensemble = 0.0131475291654059
# Fold 17 best combination: model3 with RMSLE = 0.012696278978746641
# ---------------
#
# Starting Fold 18
# Fold 18 RMSLE for model1 = 0.007986278432808951
# Fold 18 RMSLE for model2 = 0.008267615048362896
# Fold 18 RMSLE for model3 = 0.007875038661687477
# Fold 18 RMSLE for model4 = 0.008109821848348398
# Fold 18 RMSLE for ('model1', 'model2') = 0.008061884332950091
# Fold 18 RMSLE for ('model1', 'model3') = 0.007896508122958761
# Fold 18 RMSLE for ('model1', 'model4') = 0.007983862201939885
# Fold 18 RMSLE for ('model2', 'model3') = 0.008025700621863266
# Fold 18 RMSLE for ('model2', 'model4') = 0.008149844042270897
# Fold 18 RMSLE for ('model3', 'model4') = 0.007974175098057208
# Fold 18 RMSLE for ('model1', 'model2', 'model3') = 0.007978390426817417
# Fold 18 RMSLE for ('model1', 'model2', 'model4') = 0.008046535887344183
# Fold 18 RMSLE for ('model1', 'model3', 'model4') = 0.007938453327794498
# Fold 18 RMSLE for ('model2', 'model3', 'model4') = 0.008038368301779106
# Fold 18 RMSLE for all models ensemble = 0.007992971897051433
# Fold 18 best combination: model3 with RMSLE = 0.007875038661687477
# ---------------
#
# Starting Fold 19
# Fold 19 RMSLE for model1 = 0.011395654543084907
# Fold 19 RMSLE for model2 = 0.011621956363894882
# Fold 19 RMSLE for model3 = 0.011262079025303242
# Fold 19 RMSLE for model4 = 0.01185480355298713
# Fold 19 RMSLE for ('model1', 'model2') = 0.011479913285243518
# Fold 19 RMSLE for ('model1', 'model3') = 0.011321207068908106
# Fold 19 RMSLE for ('model1', 'model4') = 0.011564490721470668
# Fold 19 RMSLE for ('model2', 'model3') = 0.011416101305181595
# Fold 19 RMSLE for ('model2', 'model4') = 0.011645079835960078
# Fold 19 RMSLE for ('model3', 'model4') = 0.011497105016904987
# Fold 19 RMSLE for ('model1', 'model2', 'model3') = 0.011398717247175068
# Fold 19 RMSLE for ('model1', 'model2', 'model4') = 0.011542519351456733
# Fold 19 RMSLE for ('model1', 'model3', 'model4') = 0.011446157345750734
# Fold 19 RMSLE for ('model2', 'model3', 'model4') = 0.011498956704785636
# Fold 19 RMSLE for all models ensemble = 0.011463675889571341
# Fold 19 best combination: model3 with RMSLE = 0.011262079025303242
# ---------------
#
# Starting Fold 20
# Fold 20 RMSLE for model1 = 0.022959090511124654
# Fold 20 RMSLE for model2 = 0.02334475589911565
# Fold 20 RMSLE for model3 = 0.021721478355698678
# Fold 20 RMSLE for model4 = 0.023909255676843225
# Fold 20 RMSLE for ('model1', 'model2') = 0.02310640711099951
# Fold 20 RMSLE for ('model1', 'model3') = 0.022304833717667172
# Fold 20 RMSLE for ('model1', 'model4') = 0.02337881955153229
# Fold 20 RMSLE for ('model2', 'model3') = 0.022438536251642716
# Fold 20 RMSLE for ('model2', 'model4') = 0.023605428134096412
# Fold 20 RMSLE for ('model3', 'model4') = 0.022685923187268205
# Fold 20 RMSLE for ('model1', 'model2', 'model3') = 0.022597143814882942
# Fold 20 RMSLE for ('model1', 'model2', 'model4') = 0.023350032096759815
# Fold 20 RMSLE for ('model1', 'model3', 'model4') = 0.022765248177938017
# Fold 20 RMSLE for ('model2', 'model3', 'model4') = 0.02288368723326386
# Fold 20 RMSLE for all models ensemble = 0.02288858788202613
# Fold 20 best combination: model3 with RMSLE = 0.021721478355698678
# ---------------
#
# Starting Fold 21
# Fold 21 RMSLE for model1 = 0.010327752698425898
# Fold 21 RMSLE for model2 = 0.010361269536381832
# Fold 21 RMSLE for model3 = 0.010175667280514228
# Fold 21 RMSLE for model4 = 0.010397458628686336
# Fold 21 RMSLE for ('model1', 'model2') = 0.010312357085315544
# Fold 21 RMSLE for ('model1', 'model3') = 0.010240477489468967
# Fold 21 RMSLE for ('model1', 'model4') = 0.010319141463784636
# Fold 21 RMSLE for ('model2', 'model3') = 0.01023207017910078
# Fold 21 RMSLE for ('model2', 'model4') = 0.010328625661575216
# Fold 21 RMSLE for ('model3', 'model4') = 0.010248889992001997
# Fold 21 RMSLE for ('model1', 'model2', 'model3') = 0.010252732997587728
# Fold 21 RMSLE for ('model1', 'model2', 'model4') = 0.01030595330059167
# Fold 21 RMSLE for ('model1', 'model3', 'model4') = 0.010259160659838255
# Fold 21 RMSLE for ('model2', 'model3', 'model4') = 0.010255918617267261
# Fold 21 RMSLE for all models ensemble = 0.010262521818788126
# Fold 21 best combination: model3 with RMSLE = 0.010175667280514228
# ---------------
#
# Starting Fold 22
# Fold 22 RMSLE for model1 = 0.008982122035187206
# Fold 22 RMSLE for model2 = 0.009207793197682924
# Fold 22 RMSLE for model3 = 0.008426718966158897
# Fold 22 RMSLE for model4 = 0.008783780329289177
# Fold 22 RMSLE for ('model1', 'model2') = 0.00906583237867908
# Fold 22 RMSLE for ('model1', 'model3') = 0.008685700422459626
# Fold 22 RMSLE for ('model1', 'model4') = 0.008853459798562783
# Fold 22 RMSLE for ('model2', 'model3') = 0.008784517462580806
# Fold 22 RMSLE for ('model2', 'model4') = 0.008970585870298574
# Fold 22 RMSLE for ('model3', 'model4') = 0.008591639558244825
# Fold 22 RMSLE for ('model1', 'model2', 'model3') = 0.00883630300989496
# Fold 22 RMSLE for ('model1', 'model2', 'model4') = 0.00895396338822086
# Fold 22 RMSLE for ('model1', 'model3', 'model4') = 0.00870327361387454
# Fold 22 RMSLE for ('model2', 'model3', 'model4') = 0.008774165790313782
# Fold 22 RMSLE for all models ensemble = 0.008812728103702623
# Fold 22 best combination: model3 with RMSLE = 0.008426718966158897
# ---------------
#
# Starting Fold 23
# Fold 23 RMSLE for model1 = 0.007664282671958641
# Fold 23 RMSLE for model2 = 0.00776769079105592
# Fold 23 RMSLE for model3 = 0.00756283719971776
# Fold 23 RMSLE for model4 = 0.0076611131564313295
# Fold 23 RMSLE for ('model1', 'model2') = 0.0076931743135658145
# Fold 23 RMSLE for ('model1', 'model3') = 0.007602341733286329
# Fold 23 RMSLE for ('model1', 'model4') = 0.007644026669913379
# Fold 23 RMSLE for ('model2', 'model3') = 0.007640583457368882
# Fold 23 RMSLE for ('model2', 'model4') = 0.00769276622898773
# Fold 23 RMSLE for ('model3', 'model4') = 0.0076030858868507845
# Fold 23 RMSLE for ('model1', 'model2', 'model3') = 0.007638800298499946
# Fold 23 RMSLE for ('model1', 'model2', 'model4') = 0.007669622648371041
# Fold 23 RMSLE for ('model1', 'model3', 'model4') = 0.00761215580512928
# Fold 23 RMSLE for ('model2', 'model3', 'model4') = 0.007639300068085615
# Fold 23 RMSLE for all models ensemble = 0.007636950507031272
# Fold 23 best combination: model3 with RMSLE = 0.00756283719971776
# ---------------
#
# Starting Fold 24
# Fold 24 RMSLE for model1 = 0.009722914261251556
# Fold 24 RMSLE for model2 = 0.010039760283110395
# Fold 24 RMSLE for model3 = 0.009673049022698237
# Fold 24 RMSLE for model4 = 0.009805775143729416
# Fold 24 RMSLE for ('model1', 'model2') = 0.009838054600131771
# Fold 24 RMSLE for ('model1', 'model3') = 0.009687681274814931
# Fold 24 RMSLE for ('model1', 'model4') = 0.009754806695974892
# Fold 24 RMSLE for ('model2', 'model3') = 0.009821746974276136
# Fold 24 RMSLE for ('model2', 'model4') = 0.00989501564621111
# Fold 24 RMSLE for ('model3', 'model4') = 0.009731715180064906
# Fold 24 RMSLE for ('model1', 'model2', 'model3') = 0.009772529958887671
# Fold 24 RMSLE for ('model1', 'model2', 'model4') = 0.009820242993575064
# Fold 24 RMSLE for ('model1', 'model3', 'model4') = 0.00972167478066189
# Fold 24 RMSLE for ('model2', 'model3', 'model4') = 0.009808269891260456
# Fold 24 RMSLE for all models ensemble = 0.00977691916201743
# Fold 24 best combination: model3 with RMSLE = 0.009673049022698237
# ---------------
#
# Starting Fold 25
# Fold 25 RMSLE for model1 = 0.011419657369674626
# Fold 25 RMSLE for model2 = 0.011580320139725937
# Fold 25 RMSLE for model3 = 0.011245101112058863
# Fold 25 RMSLE for model4 = 0.0118074119360626
# Fold 25 RMSLE for ('model1', 'model2') = 0.011452731855795822
# Fold 25 RMSLE for ('model1', 'model3') = 0.011320147187750894
# Fold 25 RMSLE for ('model1', 'model4') = 0.011580848746185032
# Fold 25 RMSLE for ('model2', 'model3') = 0.011354899223847189
# Fold 25 RMSLE for ('model2', 'model4') = 0.011649773737662187
# Fold 25 RMSLE for ('model3', 'model4') = 0.011499794076168284
# Fold 25 RMSLE for ('model1', 'model2', 'model3') = 0.011362772815954422
# Fold 25 RMSLE for ('model1', 'model2', 'model4') = 0.011547323141070969
# Fold 25 RMSLE for ('model1', 'model3', 'model4') = 0.011458875090420926
# Fold 25 RMSLE for ('model2', 'model3', 'model4') = 0.011487257786492793
# Fold 25 RMSLE for all models ensemble = 0.011457893054046606
# Fold 25 best combination: model3 with RMSLE = 0.011245101112058863
# ---------------
#
# Starting Fold 26
# Fold 26 RMSLE for model1 = 0.008968998820579034
# Fold 26 RMSLE for model2 = 0.009074625032940284
# Fold 26 RMSLE for model3 = 0.008798521365192031
# Fold 26 RMSLE for model4 = 0.00906107507444776
# Fold 26 RMSLE for ('model1', 'model2') = 0.008996539847983268
# Fold 26 RMSLE for ('model1', 'model3') = 0.00887578711751847
# Fold 26 RMSLE for ('model1', 'model4') = 0.009004292765528487
# Fold 26 RMSLE for ('model2', 'model3') = 0.008908409185520931
# Fold 26 RMSLE for ('model2', 'model4') = 0.00904393829064687
# Fold 26 RMSLE for ('model3', 'model4') = 0.008922065206883635
# Fold 26 RMSLE for ('model1', 'model2', 'model3') = 0.008920031042290619
# Fold 26 RMSLE for ('model1', 'model2', 'model4') = 0.009008246272524842
# Fold 26 RMSLE for ('model1', 'model3', 'model4') = 0.008931097552207199
# Fold 26 RMSLE for ('model2', 'model3', 'model4') = 0.008951458025889524
# Fold 26 RMSLE for all models ensemble = 0.0089498048368267
# Fold 26 best combination: model3 with RMSLE = 0.008798521365192031
# ---------------
#
# Starting Fold 27
# Fold 27 RMSLE for model1 = 0.007781403036851977
# Fold 27 RMSLE for model2 = 0.007971775102244576
# Fold 27 RMSLE for model3 = 0.007618690656815339
# Fold 27 RMSLE for model4 = 0.007868426620748593
# Fold 27 RMSLE for ('model1', 'model2') = 0.007831089754577645
# Fold 27 RMSLE for ('model1', 'model3') = 0.007682781614582824
# Fold 27 RMSLE for ('model1', 'model4') = 0.007794986991993555
# Fold 27 RMSLE for ('model2', 'model3') = 0.007723057319955374
# Fold 27 RMSLE for ('model2', 'model4') = 0.007842280490954577
# Fold 27 RMSLE for ('model3', 'model4') = 0.007718657329056415
# Fold 27 RMSLE for ('model1', 'model2', 'model3') = 0.007730480644037459
# Fold 27 RMSLE for ('model1', 'model2', 'model4') = 0.0078055894503363905
# Fold 27 RMSLE for ('model1', 'model3', 'model4') = 0.007724072672955727
# Fold 27 RMSLE for ('model2', 'model3', 'model4') = 0.007741610594895329
# Fold 27 RMSLE for all models ensemble = 0.0077428929144796885
# Fold 27 best combination: model3 with RMSLE = 0.007618690656815339
# ---------------
#
# Starting Fold 28
# Fold 28 RMSLE for model1 = 0.00906114363491714
# Fold 28 RMSLE for model2 = 0.009112654041865459
# Fold 28 RMSLE for model3 = 0.008951477474527656
# Fold 28 RMSLE for model4 = 0.009093729611665415
# Fold 28 RMSLE for ('model1', 'model2') = 0.009046134454499064
# Fold 28 RMSLE for ('model1', 'model3') = 0.008995404194689279
# Fold 28 RMSLE for ('model1', 'model4') = 0.009045545480358722
# Fold 28 RMSLE for ('model2', 'model3') = 0.008973660037019236
# Fold 28 RMSLE for ('model2', 'model4') = 0.009069263348229654
# Fold 28 RMSLE for ('model3', 'model4') = 0.008977600422272261
# Fold 28 RMSLE for ('model1', 'model2', 'model3') = 0.008992786875384812
# Fold 28 RMSLE for ('model1', 'model2', 'model4') = 0.009041774722753476
# Fold 28 RMSLE for ('model1', 'model3', 'model4') = 0.008996399310050456
# Fold 28 RMSLE for ('model2', 'model3', 'model4') = 0.008991578498253553
# Fold 28 RMSLE for all models ensemble = 0.00899947682220135
# Fold 28 best combination: model3 with RMSLE = 0.008951477474527656
# ---------------
#
# Starting Fold 29
# Fold 29 RMSLE for model1 = 0.012059560209640253
# Fold 29 RMSLE for model2 = 0.013338676262106388
# Fold 29 RMSLE for model3 = 0.011821245463532495
# Fold 29 RMSLE for model4 = 0.014568875506322224
# Fold 29 RMSLE for ('model1', 'model2') = 0.01254389579605661
# Fold 29 RMSLE for ('model1', 'model3') = 0.011932445092286284
# Fold 29 RMSLE for ('model1', 'model4') = 0.013050892060128508
# Fold 29 RMSLE for ('model2', 'model3') = 0.012403935254624575
# Fold 29 RMSLE for ('model2', 'model4') = 0.013924900193292617
# Fold 29 RMSLE for ('model3', 'model4') = 0.012903404111363115
# Fold 29 RMSLE for ('model1', 'model2', 'model3') = 0.012253188197172341
# Fold 29 RMSLE for ('model1', 'model2', 'model4') = 0.013126336513575025
# Fold 29 RMSLE for ('model1', 'model3', 'model4') = 0.012558310655129128
# Fold 29 RMSLE for ('model2', 'model3', 'model4') = 0.01302612293802045
# Fold 29 RMSLE for all models ensemble = 0.012714588243465379
# Fold 29 best combination: model3 with RMSLE = 0.011821245463532495
# ---------------
#
# Starting Fold 30
# Fold 30 RMSLE for model1 = 0.009365745142935396
# Fold 30 RMSLE for model2 = 0.009831264421893
# Fold 30 RMSLE for model3 = 0.009249392204925246
# Fold 30 RMSLE for model4 = 0.00993522343233506
# Fold 30 RMSLE for ('model1', 'model2') = 0.00956481046145553
# Fold 30 RMSLE for ('model1', 'model3') = 0.009289251154176347
# Fold 30 RMSLE for ('model1', 'model4') = 0.009618332101967815
# Fold 30 RMSLE for ('model2', 'model3') = 0.009487070336141816
# Fold 30 RMSLE for ('model2', 'model4') = 0.00986268066225046
# Fold 30 RMSLE for ('model3', 'model4') = 0.009535017219462885
# Fold 30 RMSLE for ('model1', 'model2', 'model3') = 0.009435152712523421
# Fold 30 RMSLE for ('model1', 'model2', 'model4') = 0.009672423107102852
# Fold 30 RMSLE for ('model1', 'model3', 'model4') = 0.009468656528846523
# Fold 30 RMSLE for ('model2', 'model3', 'model4') = 0.009613996892213449
# Fold 30 RMSLE for all models ensemble = 0.009541569496418306
# Fold 30 best combination: model3 with RMSLE = 0.009249392204925246
# ---------------
#
# OOF RMSLE = 0.010959170559797391
# Sum of RMSLE for each combination:
# ('model1',): 0.32821571216549716
# ('model2',): 0.33746037087035646
# ('model3',): 0.3185503833630485
# ('model4',): 0.3374696055708646
# ('model1', 'model2'): 0.3314688305441971
# ('model1', 'model3'): 0.32291071881890226
# ('model1', 'model4'): 0.3315416102015498
# ('model2', 'model3'): 0.3263290284683703
# ('model2', 'model4'): 0.3364633967068875
# ('model3', 'model4'): 0.32665671287176734
# ('model1', 'model2', 'model3'): 0.3265026482066887
# ('model1', 'model2', 'model4'): 0.33275356559062375
# ('model1', 'model3', 'model4'): 0.32667574008038136
# ('model2', 'model3', 'model4'): 0.3293763197093315
# ('model1', 'model2', 'model3', 'model4'): 0.32862575891108464
#
# 9番目の学習が終わりました。
#
# 推定時間は0

# %%
train_all_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                        0.000000                     0.000000
# 2                        0.000000                     0.000000
# 3                        0.000000                     0.000000
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 8548                     0.000000                     0.000000
# 8549                     0.000000                     0.000000
# 8550                 22956.125554                 23592.402994
# 8551                124460.895022                140816.449347
# 8552                     0.000000                     0.000000
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                        0.000000                     0.000000           221
# 2                        0.000000                     0.000000             4
# 3                        0.000000                     0.000000            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 8548                     0.000000                     0.000000           240
# 8549                     0.000000                     0.000000             4
# 8550                 25069.498286                 24560.172725           132
# 8551                 93118.705227                130326.946431            98
# 8552                     0.000000                     0.000000             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                   0.000000
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 8548                           110523.066755
# 8549                                0.000000
# 8550                           166520.232511
# 8551                            71773.803649
# 8552                                0.000000
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                   0.000000
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 8548                            98954.793233
# 8549                                0.000000
# 8550                           469732.826538
# 8551                           936031.894142
# 8552                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                               0.000000e+00
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 8548                            3.467008e+06
# 8549                            0.000000e+00
# 8550                            8.255855e+04
# 8551                            3.369613e+05
# 8552                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                   0.000000  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 8548                           147802.356027  38.651945  -75.914445
# 8549                                0.000000  31.361795 -101.776403
# 8550                            85775.307153  41.005565  -96.154917
# 8551                           156640.371706  39.364417  -93.449361
# 8552                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                            0.000000                         0.000000
# 2                            0.000000                         0.000000
# 3                            0.000000                         0.000000
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 8548                         0.000000                         0.000000
# 8549                         0.000000                         0.000000
# 8550                       636.277440                      1477.095292
# 8551                     16355.554326                    -47697.744120
# 8552                         0.000000                         0.000000
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 8548                         0.000000                          0.000000
# 8549                         0.000000                          0.000000
# 8550                      -509.325561                          0.027717
# 8551                     37208.241204                          0.131411
# 8552                         0.000000                          0.000000
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                             0.000000                          0.000000
# 2                             0.000000                          0.000000
# 3                             0.000000                          0.000000
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 8548                          0.000000                          0.000000
# 8549                          0.000000                          0.000000
# 8550                          0.062609                         -0.020317
# 8551                         -0.338723                          0.399579
# 8552                          0.000000                          0.000000
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.100001e+04 -0.000374
# 1                  14            1     6.027524e+04 -0.000989
# 2                   9            1     1.013700e+05  0.004874
# 3                  15            1     5.193587e+04  0.000851
# 4                  15            0     4.919586e+04 -0.004063
# ...               ...          ...              ...       ...
# 8548                1            1     5.293676e+05  0.000000
# 8549                9            1     1.019445e+05  0.000000
# 8550                8            0     1.386703e+05  0.000000
# 8551                8            0     2.627613e+05  0.000000
# 8552                9            1     1.349075e+06  0.000000
#
# [8553 rows x 21 columns]

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                    31566.709644                 26644.986107
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                    29553.796627                 28337.832145
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                 22956.125554                 23592.402994
# 6043                124460.895022                140816.449347
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                    23410.379903                 31809.857564           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                    30840.825454                 25153.901905            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                 25069.498286                 24560.172725           132
# 6043                 93118.705227                130326.946431            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               64816.958901
# 1                               55507.543666
# 2                                        NaN
# 3                               54811.222708
# 4                               81812.306362
# ...                                      ...
# 6040                           110523.066755
# 6041                                     NaN
# 6042                           166520.232511
# 6043                            71773.803649
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               36588.744606
# 1                               72387.334115
# 2                                        NaN
# 3                               69339.923002
# 4                               53823.561587
# ...                                      ...
# 6040                            98954.793233
# 6041                                     NaN
# 6042                           469732.826538
# 6043                           936031.894142
# 6044                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               3.790794e+04
# 1                               5.822520e+04
# 2                                        NaN
# 3                               6.364734e+04
# 4                               7.739116e+04
# ...                                      ...
# 6040                            3.467008e+06
# 6041                                     NaN
# 6042                            8.255855e+04
# 6043                            3.369613e+05
# 6044                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               45598.125851  40.141389  -87.581111
# 1                               76376.547318  38.475305  -81.278957
# 2                                        NaN  39.299820  -80.857170
# 3                               53799.011225  35.490363 -119.042957
# 4                               17662.966241  41.532802  -81.636448
# ...                                      ...        ...         ...
# 6040                           147802.356027  38.651945  -75.914445
# 6041                                     NaN  31.361795 -101.776403
# 6042                            85775.307153  41.005565  -96.154917
# 6043                           156640.371706  39.364417  -93.449361
# 6044                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                        -4921.723537                     -3234.606204
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                        -1215.964481                      2502.993309
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                       636.277440                      1477.095292
# 6043                     16355.554326                    -47697.744120
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                         8399.477661                         -0.155915
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                        -5686.923550                         -0.041144
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                      -509.325561                          0.027717
# 6043                     37208.241204                          0.131411
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                            -0.121396                          0.358793
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                             0.088327                         -0.184396
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                          0.062609                         -0.020317
# 6043                         -0.338723                          0.399579
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   8            0     4.090082e+04  0.002048
# 1                  14            1     6.632440e+04 -0.096624
# 2                   9            1     1.126121e+05 -0.100296
# 3                  15            1     5.663580e+04 -0.085779
# 4                  15            0     4.926228e+04 -0.005412
# ...               ...          ...              ...       ...
# 6040                1            1     6.083564e+05 -0.047990
# 6041                9            1     1.142346e+05 -0.115899
# 6042                8            0     1.323684e+05  0.005406
# 6043                8            0     2.656624e+05 -0.000667
# 6044                9            1     1.469172e+06 -0.060851
#
# [6045 rows x 21 columns]

# %%
oof_predictions = pd.Series(oof_predictions, name='oof_predictions')

# %%
from scipy import stats
# 対数変換
log_target = np.log1p(test_df["oof_predictions"])
log_oof_predictions = test_preds

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.49, 0.00)

# %%
train_df_GHG14
# Out:
# 0       4.098466e+04
# 1       6.021565e+04
# 2       1.018654e+05
# 3       5.198007e+04
# 4       4.899637e+04
#             ...
# 6040    5.798506e+05
# 6041    1.017332e+05
# 6042    1.330859e+05
# 6043    2.654853e+05
# 6044    1.382436e+06
# Name: GHG_Direct_Emissions_14_in_metric_tons.1, Length: 6045, dtype: float64

# %%
test_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    28275.061385                 32075.140635
# 3                    37330.205714                 42503.897432
# 4                    45310.722699                 39897.800897
# ...                           ...                          ...
# 2503                          NaN                          NaN
# 2504                          NaN                          NaN
# 2505                 22956.125554                 23592.402994
# 2506                124460.895022                140816.449347
# 2507                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                             NaN                          NaN             4
# 1                             NaN                          NaN           221
# 2                    26445.792090                 23385.161510           130
# 3                    43906.102080                 42958.306538            82
# 4                    40203.428231                 39437.099224           181
# ...                           ...                          ...           ...
# 2503                          NaN                          NaN           240
# 2504                          NaN                          NaN             4
# 2505                 25069.498286                 24560.172725           132
# 2506                 93118.705227                130326.946431            98
# 2507                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                               88951.390376
# 1                                        NaN
# 2                               84908.372871
# 3                               49004.603631
# 4                               84959.769922
# ...                                      ...
# 2503                           110523.066755
# 2504                                     NaN
# 2505                           166520.232511
# 2506                            71773.803649
# 2507                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                               65803.021457
# 1                                        NaN
# 2                                6212.899604
# 3                                  52.038452
# 4                               15351.359676
# ...                                      ...
# 2503                            98954.793233
# 2504                                     NaN
# 2505                           469732.826538
# 2506                           936031.894142
# 2507                           841773.060989
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                               2.899329e+04
# 1                               3.119260e+05
# 2                               3.473291e+04
# 3                               1.426237e+04
# 4                               4.000654e+04
# ...                                      ...
# 2503                            3.467008e+06
# 2504                                     NaN
# 2505                            8.255855e+04
# 2506                            3.369613e+05
# 2507                            4.082144e+06
#
#       GHG_Direct_Emissions_13_in_metric_tons   Latitude   Longitude  \
# 0                               32965.487915  38.033040  -97.973170
# 1                              268668.069110  32.316030 -108.606800
# 2                               39045.247387  41.251500  -78.742440
# 3                               20204.924986  44.959660  -93.193410
# 4                               63935.249120  32.818720 -117.125800
# ...                                      ...        ...         ...
# 2503                           147802.356027  38.651945  -75.914445
# 2504                                     NaN  31.361795 -101.776403
# 2505                            85775.307153  41.005565  -96.154917
# 2506                           156640.371706  39.364417  -93.449361
# 2507                           350096.803939  31.591369  -96.216360
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                         3800.079250                     -5629.348545
# 3                         5173.691718                      1402.204648
# 4                        -5412.921803                       305.627335
# ...                               ...                              ...
# 2503                              NaN                              NaN
# 2504                              NaN                              NaN
# 2505                       636.277440                      1477.095292
# 2506                     16355.554326                    -47697.744120
# 2507                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                        -3060.630580                          0.134397
# 3                         -947.795542                          0.138593
# 4                         -766.329007                         -0.119462
# ...                               ...                               ...
# 2503                              NaN                               NaN
# 2504                              NaN                               NaN
# 2505                      -509.325561                          0.027717
# 2506                     37208.241204                          0.131411
# 2507                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                            -0.175505                         -0.115732
# 3                             0.032990                         -0.021587
# 4                             0.007660                         -0.019061
# ...                                ...                               ...
# 2503                               NaN                               NaN
# 2504                               NaN                               NaN
# 2505                          0.062609                         -0.020317
# 2506                         -0.338723                          0.399579
# 2507                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions      diff
# 0                   9            1     4.864828e+04  0.000652
# 1                  14            1     3.277151e+05 -0.001911
# 2                   8            0     4.072421e+04 -0.006673
# 3                   8            0     2.732870e+04 -0.031244
# 4                   8            0     4.886299e+04  0.012758
# ...               ...          ...              ...       ...
# 2503                1            1     5.567251e+05  0.005919
# 2504                9            1     1.165673e+05  0.015370
# 2505                8            0     1.407857e+05  0.017621
# 2506                8            0     2.607554e+05 -0.008465
# 2507                9            1     1.495389e+06  0.036287
#
# [2508 rows x 21 columns]

# %%
# 対数変換
log_target = np.log1p(train_df_GHG14)
log_oof_predictions = np.log1p(train_df["oof_predictions"])

# 差の計算
diff = abs(log_target - log_oof_predictions)

# diffが0.7を超えるかどうかのマスク作成
diff_threshold = 0.7
mask = diff > diff_threshold

# プロットの作成
plt.figure(figsize=(10, 8))

sns.scatterplot(
    x=log_target,
    y=log_oof_predictions,
    hue=mask,
    palette={False: 'blue', True: 'red'},
    alpha=0.5,
    edgecolor=None
)

plt.xlabel('Actual Values (y_test) [Log Scale]')
plt.ylabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 線形回帰の計算
slope, intercept, r_value, p_value, std_err = stats.linregress(log_target, log_oof_predictions)
regression_line = slope * log_target + intercept

# 回帰線のプロット
plt.plot(log_target, regression_line, color='green', label='Linear Regression')

# 回帰式の作成
equation = f'y = {slope:.2f}x + {intercept:.2f}'
r_squared = r_value**2
equation_r2 = f'R² = {r_squared:.2f}'

# 回帰式をグラフ内の右下に表示
plt.text(
    0.95, 0.05,  # グラフ内の相対位置 (x, y) 0-1
    f'{equation}\n{equation_r2}',
    transform=plt.gca().transAxes,
    fontsize=12,
    horizontalalignment='right',
    verticalalignment='bottom',
    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5)
)

# 重心の計算
centroid_x = np.mean(log_target)
centroid_y = np.mean(log_oof_predictions)

# 重心をプロットに追加（plt.scatterを使用）
plt.scatter(
    centroid_x,
    centroid_y,
    color='green',
    marker='*',
    s=200,  # マーカーのサイズ
    label='Centroid'
)

# 凡例の設定
plt.legend(title='Legend')

# プロットの表示
plt.tight_layout()
plt.show()

# 重心の座標を表示
print(f"重心 (Centroid) の座標: ({centroid_x:.2f}, {centroid_y:.2f})")
# Out:
# 重心 (Centroid) の座標: (11.45, 11.50)

# %%
print(np.expm1(10.2))
print(np.log1p(26902.18607429754))
np.expm1(np.log1p(26902.18607429754)*100/102)
# Out:
# 26902.18607429754
# 10.2
# 22025.465794806678

# %%
submit = pd.read_csv(path+'sample_submission.csv',  header = None)
submit
# Out:
#          0              1
# 0     4655  249574.303827
# 1     4656  249574.303827
# 2     4657  249574.303827
# 3     4658  249574.303827
# 4     4659  249574.303827
# ...    ...            ...
# 2503  7158  249574.303827
# 2504  7159  249574.303827
# 2505  7160  249574.303827
# 2506  7161  249574.303827
# 2507  7162  249574.303827
#
# [2508 rows x 2 columns]

# %%
def calculate_binned_average(x, y, num_bins=50):
    """
    x を num_bins 個のビンに分け、それぞれのビン内の y の平均を計算します。

    Parameters:
    - x: 予測値の配列
    - y: 実測値の配列
    - num_bins: ビンの数

    Returns:
    - bins: ビンの境界
    - bin_centers: 各ビンの中心値
    - y_means: 各ビン内の y の平均値
    """
    # 対数スケールのビンを作成
    log_min = np.log10(x.min())
    log_max = np.log10(x.max())
    bins = np.logspace(log_min, log_max, num=num_bins)

    # ビンのインデックスを取得
    bin_indices = np.digitize(x, bins)

    # 各ビン内の y の平均を計算
    y_means = []
    bin_centers = []
    for i in range(1, len(bins)):
        mask = bin_indices == i
        if np.any(mask):
            y_mean = y[mask].mean()
            y_means.append(y_mean)
            bin_center = (bins[i-1] + bins[i]) / 2
            bin_centers.append(bin_center)

    return bins, np.array(bin_centers), np.array(y_means)


x = train_df_GHG14
y = train_df["oof_predictions"]
# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')


# 基準点の垂直線のプロット
plt.plot([np.expm1(10.4), np.expm1(10.4)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.4), np.expm1(14.4)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 224708.98604667318

# %%
print(np.expm1(np.log1p(10)))
# Out:
# 10.000000000000002

# %%
def after_act(preds):
    r = preds.copy()
    r_min = r.min()
    max_w = 10.4-np.log1p(r_min)
    for i in range(len(r)):
        if r[i] < np.expm1(10.4):
            # print(r[i]-np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w))
            r[i] = np.expm1(np.log1p(r[i])-0.5*(10.4-np.log1p(r[i]))/max_w)
    return r

after_test_preds = after_act(test_df["oof_predictions"])
after_train_preds = after_act(train_df["oof_predictions"])

# %%
x = after_train_preds
y = train_df_GHG14

# ビンに分けて平均を計算
num_bins = 100
bins, bin_centers, y_means = calculate_binned_average(x, y, num_bins=num_bins)

# ジオメトリック平均の計算（ビンごとの y のジオメトリック平均）
geometric_mean_y_per_bin = np.exp(np.mean(np.log(y_means)))
print(f"各ビンの y のジオメトリック平均: {geometric_mean_y_per_bin}")

# プロットの作成
plt.figure(figsize=(10, 8))
sns.scatterplot(x=x, y=y, alpha=0.5, label='Data Points')
plt.xscale('log')
plt.yscale('log')
plt.ylabel('Actual Values (y_test) [Log Scale]')
plt.xlabel('Predicted Values (test_preds) [Log Scale]')
plt.title('Actual vs Predicted Values (Log-Log Scale)')

# 45度線のプロット
# plt.plot([train_target.min(), train_target.max()], [train_target.min(), train_target.max()], 'r--', label='45-degree line')

# 基準点の垂直線のプロット
plt.plot([np.expm1(10.1), np.expm1(10.1)], [10**2, 10**7], 'g--', label='Low Threshold')
plt.plot([np.expm1(14.0), np.expm1(14.0)], [10**2, 10**7], 'g--', label='High Threshold')

# ビンごとの平均値の線を追加
plt.plot(bin_centers, y_means, color='b', linestyle='-', marker='o', markersize=4, label='Binned Mean')
# 45度線のプロット
plt.plot([x.min(), x.max()], [x.min(), x.max()], 'r--', label='45-degree line')

# 凡例の追加
plt.legend()

# プロットの表示
plt.show()
# Out:
# 各ビンの y のジオメトリック平均: 191001.20420287308

# %%
submit [ 1 ]  =  after_test_preds
submit.to_csv('SMBC_94.csv', index = False)
submit
# Out:
#          0         1
# 0     4655    48,648
# 1     4656   327,715
# 2     4657    40,724
# 3     4658    23,376
# 4     4659    48,863
# ...    ...       ...
# 2503  7158   556,725
# 2504  7159   116,567
# 2505  7160   140,786
# 2506  7161   260,755
# 2507  7162 1,495,389
#
# [2508 rows x 2 columns]

# %%
np.expm1(14)
# Out:
# 1202603.2841647768

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
threshold_input = 14
threshold = np.expm1(threshold_input)/1.05  # ≈ 1.718

# フィルタリング条件を定義
condition = (submit.iloc[:, 1] > threshold) & (submit.iloc[:, 0] > 1)

# 条件に合致する行を抽出
filtered_submit = submit[condition]
filtered_submit
# Out:
#          0         1
# 16    4671 1,225,496
# 43    4698 1,183,839
# 73    4728 1,153,485
# 110   4765 1,427,230
# 114   4769 1,334,294
# ...    ...       ...
# 2423  7078 1,299,507
# 2466  7121 1,649,609
# 2490  7145 1,462,361
# 2500  7155 1,150,880
# 2507  7162 1,495,389
#
# [117 rows x 2 columns]

# %%
# # show_plot(np.exp(oof_predictions), np.exp(target))
# show_plot(oof_predictions, target, "oof_predictions, target")
# show_plot(np.log(train_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]),
#           "train_df[GHG_Direct_Emissions_13_in_metric_tons], np.log(train_df[GHG_Direct_Emissions_14_in_metric_tons.1])")
# show_plot(np.log(test_df["GHG_Direct_Emissions_13_in_metric_tons"]), np.log(after_test_preds),
#           "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")
# show_plot(np.log(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"]), np.log(after_test_preds),
#           "train_df[GHG_Direct_Emissions_14_in_metric_tons], test_preds")
# show_plot(train_df.iloc[:, -1], after_train_preds, "train_df.iloc[:, -1], train_preds")

# %%
# show_plot(train_df["GHG_Direct_Emissions_14_in_metric_tons.1"], test_preds, "test_df[GHG_Direct_Emissions_13_in_metric_tons], test_preds")

# %%
import time
print(time.ctime())
# Out:
# Mon Dec  2 07:10:15 2024

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                          31,567                       26,645
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          29,554                       28,338
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                       22,956                       23,592
# 6043                      124,461                      140,816
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                       25,069                       24,560           132
# 6043                       93,119                      130,327            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 6040                                 110,523
# 6041                                     NaN
# 6042                                 166,520
# 6043                                  71,774
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 6040                                  98,955
# 6041                                     NaN
# 6042                                 469,733
# 6043                                 936,032
# 6044                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 6040                               3,467,008
# 6041                                     NaN
# 6042                                  82,559
# 6043                                 336,961
# 6044                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 6040                                 147,802        39        -76
# 6041                                     NaN        31       -102
# 6042                                  85,775        41        -96
# 6043                                 156,640        39        -93
# 6044                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                              636                            1,477
# 6043                           16,356                          -47,698
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                             -509                                 0
# 6043                           37,208                                 0
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                                 0                                -0
# 6043                                -0                                 0
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           40,901     0
# 1                  14            1           66,324    -0
# 2                   9            1          112,612    -0
# 3                  15            1           56,636    -0
# 4                  15            0           49,262    -0
# ...               ...          ...              ...   ...
# 6040                1            1          608,356    -0
# 6041                9            1          114,235    -0
# 6042                8            0          132,368     0
# 6043                8            0          265,662    -0
# 6044                9            1        1,469,172    -0
#
# [6045 rows x 21 columns]

# %%
def culc(x, y):
    return  np.sqrt(mean_squared_log_error(x, y))

culc(train_df_GHG14, train_df["oof_predictions"])
# Out:
# 0.06932625368191836

# %%
train_df
# Out:
#       TRI_Air_Emissions_10_in_lbs  TRI_Air_Emissions_11_in_lbs  \
# 0                          31,567                       26,645
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                          29,554                       28,338
# ...                           ...                          ...
# 6040                          NaN                          NaN
# 6041                          NaN                          NaN
# 6042                       22,956                       23,592
# 6043                      124,461                      140,816
# 6044                          NaN                          NaN
#
#       TRI_Air_Emissions_12_in_lbs  TRI_Air_Emissions_13_in_lbs  PrimaryNAICS  \
# 0                          23,410                       31,810           118
# 1                             NaN                          NaN           221
# 2                             NaN                          NaN             4
# 3                             NaN                          NaN            21
# 4                          30,841                       25,154            21
# ...                           ...                          ...           ...
# 6040                          NaN                          NaN           240
# 6041                          NaN                          NaN             4
# 6042                       25,069                       24,560           132
# 6043                       93,119                      130,327            98
# 6044                          NaN                          NaN             3
#
#       GHG_Direct_Emissions_10_in_metric_tons  \
# 0                                     64,817
# 1                                     55,508
# 2                                        NaN
# 3                                     54,811
# 4                                     81,812
# ...                                      ...
# 6040                                 110,523
# 6041                                     NaN
# 6042                                 166,520
# 6043                                  71,774
# 6044                                     NaN
#
#       GHG_Direct_Emissions_11_in_metric_tons  \
# 0                                     36,589
# 1                                     72,387
# 2                                        NaN
# 3                                     69,340
# 4                                     53,824
# ...                                      ...
# 6040                                  98,955
# 6041                                     NaN
# 6042                                 469,733
# 6043                                 936,032
# 6044                                 841,773
#
#       GHG_Direct_Emissions_12_in_metric_tons  \
# 0                                     37,908
# 1                                     58,225
# 2                                        NaN
# 3                                     63,647
# 4                                     77,391
# ...                                      ...
# 6040                               3,467,008
# 6041                                     NaN
# 6042                                  82,559
# 6043                                 336,961
# 6044                               4,082,144
#
#       GHG_Direct_Emissions_13_in_metric_tons  Latitude  Longitude  \
# 0                                     45,598        40        -88
# 1                                     76,377        38        -81
# 2                                        NaN        39        -81
# 3                                     53,799        35       -119
# 4                                     17,663        42        -82
# ...                                      ...       ...        ...
# 6040                                 147,802        39        -76
# 6041                                     NaN        31       -102
# 6042                                  85,775        41        -96
# 6043                                 156,640        39        -93
# 6044                                 350,097        32        -96
#
#       TRI_Air_Emissions_YoY_Change_11  TRI_Air_Emissions_YoY_Change_12  \
# 0                              -4,922                           -3,235
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                              -1,216                            2,503
# ...                               ...                              ...
# 6040                              NaN                              NaN
# 6041                              NaN                              NaN
# 6042                              636                            1,477
# 6043                           16,356                          -47,698
# 6044                              NaN                              NaN
#
#       TRI_Air_Emissions_YoY_Change_13  TRI_Air_Emissions_Growth_Rate_11  \
# 0                               8,399                                -0
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                              -5,687                                -0
# ...                               ...                               ...
# 6040                              NaN                               NaN
# 6041                              NaN                               NaN
# 6042                             -509                                 0
# 6043                           37,208                                 0
# 6044                              NaN                               NaN
#
#       TRI_Air_Emissions_Growth_Rate_12  TRI_Air_Emissions_Growth_Rate_13  \
# 0                                   -0                                 0
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                    0                                -0
# ...                                ...                               ...
# 6040                               NaN                               NaN
# 6041                               NaN                               NaN
# 6042                                 0                                -0
# 6043                                -0                                 0
# 6044                               NaN                               NaN
#
#       Economic_Sector  num_missing  oof_predictions  diff
# 0                   8            0           40,901     0
# 1                  14            1           66,324    -0
# 2                   9            1          112,612    -0
# 3                  15            1           56,636    -0
# 4                  15            0           49,262    -0
# ...               ...          ...              ...   ...
# 6040                1            1          608,356    -0
# 6041                9            1          114,235    -0
# 6042                8            0          132,368     0
# 6043                8            0          265,662    -0
# 6044                9            1        1,469,172    -0
#
# [6045 rows x 21 columns]
